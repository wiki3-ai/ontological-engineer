# %%
# Install required packages (run once)
# %pip install -q langchain langchain-text-splitters langchain-openai langchain-community wikipedia pydantic
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from langchain_openai import ChatOpenAI
from langchain_community.document_loaders import WikipediaLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.prompts import ChatPromptTemplate
from pydantic import BaseModel, Field
from typing import List, Literal
import json
from datetime import datetime
import hashlib

print("Dependencies loaded")
# Out:
# Dependencies loaded

# %% [markdown]
# ## Wikipedia Loader & Chunking

# %%
article_title = "Albert Einstein"
loader = WikipediaLoader(query=article_title, load_max_docs=1, doc_content_chars_max=100000)
docs = loader.load()

raw_content = docs[0].page_content if docs else ""

print(f"Fetched: {article_title}")
print(f"Content length: {len(raw_content)} characters")
print(f"Preview: {raw_content[:300]}...")
# Out:
# Fetched: Albert Einstein
# Content length: 87959 characters
# Preview: Albert Einstein (14 March 1879 – 18 April 1955) was a German-born theoretical physicist best known for developing the theory of relativity. Einstein also made important contributions to quantum theory. His mass–energy equivalence formula E = mc2, which arises from special relativity, has been called...

# %% [markdown]
# ## Configure LLM for Knowledge Graph Extraction

# %%
# Configuration: Choose your LLM provider
USE_LM_STUDIO = True  # Set to False to use OpenAI

if USE_LM_STUDIO:
    llm = ChatOpenAI(
        model="qwen/qwen3-coder-30b",  # LM Studio uses whatever model is loaded
        temperature=0,
        base_url=os.environ.get("LM_STUDIO_BASE_URL", "http://host.docker.internal:1234/v1"),
        api_key="lm-studio",  # LM Studio doesn't require a real key
    )
else:
    llm = ChatOpenAI(
        model="gpt-4o-mini",
        temperature=0,
        api_key=os.environ.get("OPENAI_API_KEY"),
    )

# Define the extraction schema using Pydantic
class Entity(BaseModel):
    id: str = Field(description="Unique entity identifier (e.g., person_1, org_2)")
    label: str = Field(description="Entity name or label")
    type: Literal["Person", "Organization", "Place", "Concept", "Event", "Work"] = Field(description="Entity type")
    description: str = Field(description="Brief entity description from text")

class Relation(BaseModel):
    source_id: str = Field(description="Source entity ID")
    target_id: str = Field(description="Target entity ID")
    relation_type: str = Field(description="Type of relationship (e.g., BORN_IN, WORKED_AT, DISCOVERED)")
    description: str = Field(description="Description of the relationship")

class KnowledgeGraph(BaseModel):
    """Extracted knowledge graph with entities and relations."""
    entities: List[Entity] = Field(description="List of entities extracted from the text")
    relations: List[Relation] = Field(description="List of relationships between entities")

# Use with_structured_output for reliable JSON extraction
structured_llm = llm.with_structured_output(KnowledgeGraph)

print(f"LLM configured: {'LM Studio (local)' if USE_LM_STUDIO else 'OpenAI'}")
# Out:
# LLM configured: LM Studio (local)

# %% [markdown]
# ## Extract Knowledge Graph from Text

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=8000,
    chunk_overlap=128,
)

chunks = splitter.split_text(raw_content)
print(f"Split into {len(chunks)} chunks")
print(f"Chunk 1 preview: {chunks[0][:150]}...")
# Out:
# Split into 13 chunks
# Chunk 1 preview: Albert Einstein (14 March 1879 – 18 April 1955) was a German-born theoretical physicist best known for developing the theory of relativity. Einstein a...

# %%
extraction_prompt = ChatPromptTemplate.from_messages([
    ("system", """You are an expert at extracting knowledge graphs from text.
Extract entities and relationships from the provided text.
Assign unique IDs to each entity using the format: type_number (e.g., "person_1", "org_2", "place_3").
Identify relationships between entities that appear in the same context.
Focus on factual relationships like: BORN_IN, WORKED_AT, DISCOVERED, FOUNDED, RECEIVED, MARRIED_TO, DEVELOPED, etc."""),
    ("human", "Extract entities and relationships from this text:\n\n{text}")
])

extraction_chain = extraction_prompt | structured_llm
print("Extraction chain created")
# Out:
# Extraction chain created

# %%
all_entities = {}
all_relations = []
process_chunks = 2

for i in range(min(process_chunks, len(chunks))):
    print(f"Processing chunk {i + 1}/{min(process_chunks, len(chunks))}...")
    try:
        result = extraction_chain.invoke({"text": chunks[i]})
        
        # Deduplicate entities by label
        for entity in result.entities:
            key = entity.label.lower()
            if key not in all_entities:
                all_entities[key] = {
                    "id": f"{entity.type.lower()}_{len(all_entities) + 1}",
                    "label": entity.label,
                    "type": entity.type,
                    "description": entity.description,
                }
        
        # Map relations to deduplicated entity IDs
        for relation in result.relations:
            source_entity = next((e for e in result.entities if e.id == relation.source_id), None)
            target_entity = next((e for e in result.entities if e.id == relation.target_id), None)
            
            if source_entity and target_entity:
                source_key = source_entity.label.lower()
                target_key = target_entity.label.lower()
                
                all_relations.append({
                    "source_id": all_entities.get(source_key, {}).get("id", relation.source_id),
                    "target_id": all_entities.get(target_key, {}).get("id", relation.target_id),
                    "relation_type": relation.relation_type,
                    "description": relation.description,
                })
        
        print(f"  Extracted {len(result.entities)} entities, {len(result.relations)} relations")
    except Exception as error:
        print(f"  Error processing chunk {i + 1}: {error}")

print(f"\nTotal unique entities: {len(all_entities)}")
print(f"Total relations: {len(all_relations)}")
# Out:
# Processing chunk 1/2...
#   Extracted 53 entities, 60 relations
# Processing chunk 2/2...
#   Extracted 35 entities, 53 relations
#
# Total unique entities: 79
# Total relations: 113

# %% [markdown]
# ## Inspect Extracted Knowledge Graph

# %%
print("\n=== ENTITIES ===")
for entity in all_entities.values():
    print(f"[{entity['id']}] {entity['label']} ({entity['type']})")
    print(f"  → {entity['description']}")
# Out:
# === ENTITIES ===
# [person_1] Albert Einstein (Person)
#   → German-born theoretical physicist
# [place_2] Ulm (Place)
#   → Birthplace of Albert Einstein
# [place_3] Kingdom of Württemberg (Place)
#   → Location where Albert Einstein was born
# [place_4] German Empire (Place)
#   → Country where Albert Einstein was born
# [person_5] Hermann Einstein (Person)
#   → Albert Einstein's father
# [person_6] Pauline Koch (Person)
#   → Albert Einstein's mother
# [place_7] Munich (Place)
#   → City where Einstein's family moved
# [place_8] Ludwigsvorstadt-Isarvorstadt (Place)
#   → Borough in Munich where Einstein's family lived
# [organization_9] Elektrotechnische Fabrik J. Einstein & Cie (Organization)
#   → Company founded by Hermann and Jakob Einstein
# [place_10] Italy (Place)
#   → Country where Einstein's family moved
# [place_11] Milan (Place)
#   → City in Italy where Einstein's family moved
# [place_12] Pavia (Place)
#   → City in Italy where Einstein's family settled
# [place_13] Palazzo Cornazzani (Place)
#   → Residence where Einstein's family settled in Pavia
# [organization_14] Luitpold Gymnasium (Organization)
#   → School where Einstein received secondary education
# [place_15] St. Peter's Catholic elementary school (Place)
#   → School where Einstein attended elementary education
# [place_16] Aarau (Place)
#   → City where Einstein completed secondary education
# [organization_17] Argovian cantonal school (Organization)
#   → School where Einstein completed secondary education
# [person_18] Marie Winteler (Person)
#   → Girl Einstein fell in love with
# [person_19] Jost Winteler (Person)
#   → Marie Winteler's father
# [person_20] Maja Einstein (Person)
#   → Albert Einstein's sister
# [person_21] Paul Winteler (Person)
#   → Marie Winteler's brother
# [organization_22] federal polytechnic school (Organization)
#   → School where Einstein applied for entrance examination
# [place_23] Zurich (Place)
#   → City where Einstein enrolled in the federal polytechnic school
# [organization_24] Swiss federal polytechnic school (Organization)
#   → School where Einstein enrolled
# [organization_25] University of Zurich (Organization)
#   → University where Einstein submitted his PhD dissertation
# [organization_26] Prussian Academy of Sciences (Organization)
#   → Academy where Einstein joined in Berlin
# [organization_27] Humboldt University of Berlin (Organization)
#   → University where Einstein joined in Berlin
# [organization_28] Kaiser Wilhelm Institute for Physics (Organization)
#   → Institute where Einstein became director
# [place_29] Berlin (Place)
#   → City where Einstein moved in 1914
# [place_30] Kingdom of Prussia (Place)
#   → Country where Einstein became a citizen again
# [place_31] United States (Place)
#   → Country where Einstein was visiting when Hitler came to power
# [person_32] Adolf Hitler (Person)
#   → Leader who came to power in Germany
# [person_33] Franklin D. Roosevelt (Person)
#   → President of the United States
# [organization_34] Manhattan Project (Organization)
#   → Project that researched nuclear weapons
# [person_35] Satyendra Nath Bose (Person)
#   → Physicist who worked with Einstein
# [organization_36] Bose–Einstein statistics (Organization)
#   → Statistics developed by Einstein and Bose
# [organization_37] Swiss Patent Office (Organization)
#   → Office where Einstein worked in Bern
# [place_38] Bern (Place)
#   → City where Einstein worked at the Swiss Patent Office
# [place_39] Kant's Critique of Pure Reason (Place)
#   → Philosophical work that influenced Einstein
# [person_40] Max Talmud (Person)
#   → Family tutor of Einstein
# [place_41] Euclidean geometry (Place)
#   → Mathematical field Einstein studied
# [place_42] Pythagorean theorem (Place)
#   → Mathematical theorem Einstein proved
# [place_43] integral and differential calculus (Place)
#   → Mathematical fields Einstein mastered
# [place_44] mathematical structure (Place)
#   → Concept Einstein believed nature could be understood as
# [place_45] special theory of relativity (Place)
#   → Theory Einstein introduced in 1905
# [place_46] general theory of relativity (Place)
#   → Theory Einstein proposed in 1915
# [place_47] cosmological constant (Place)
#   → Concept introduced by Einstein in 1917
# [place_48] laser and maser (Place)
#   → Devices based on Einstein's work
# [place_49] quantum electrodynamics (Place)
#   → Field of physics that benefited from Einstein's work
# [place_50] quantum optics (Place)
#   → Field of physics that benefited from Einstein's work
# [place_51] unified field theory (Place)
#   → Theory Einstein attempted to develop
# [place_52] geometric theory of gravitation (Place)
#   → Theory Einstein generalized to include electromagnetism
# [person_53] Marcel Grossmann (Person)
#   → Einstein's fellow student and friend who helped him academically
# [person_54] Mileva Marić (Person)
#   → Einstein's first wife and fellow student
# [person_55] Lieserl Einstein (Person)
#   → Einstein and Marić's daughter
# [person_56] Hans Albert Einstein (Person)
#   → Einstein and Marić's son
# [person_57] Eduard Einstein (Person)
#   → Einstein and Marić's son
# [person_58] Elsa Löwenthal (Person)
#   → Einstein's second wife
# [person_59] Betty Neumann (Person)
#   → Einstein's secretary and romantic interest
# [person_60] Hans Mühsam (Person)
#   → Einstein's close friend
# [person_61] Margarete Lebach (Person)
#   → Einstein's romantic interest
# [person_62] Estella Katzenellenbogen (Person)
#   → Einstein's romantic interest
# [person_63] Toni Mendel (Person)
#   → Einstein's romantic interest
# [person_64] Ethel Michanowski (Person)
#   → Einstein's romantic interest
# [person_65] Margarita Konenkova (Person)
#   → Einstein's romantic interest after his wife's death
# [person_66] Sergei Konenkov (Person)
#   → Margarita Konenkova's husband and a sculptor
# [organization_67] Olympia Academy (Organization)
#   → Scientific discussion group formed by Einstein
# [organization_68] Hebrew University of Jerusalem (Organization)
#   → Publisher of Einstein's letters
# [place_69] Württemberg (Place)
#   → German Kingdom where Einstein renounced citizenship
# [place_70] Germany (Place)
#   → Country of Einstein's birth
# [place_71] Switzerland (Place)
#   → Country where Einstein lived and worked
# [place_72] Novi Sad (Place)
#   → City where Marić's daughter was born
# [place_73] Olsberg (Place)
#   → City where Marie Winteler worked
# [place_74] Burghölzli (Place)
#   → Psychiatric hospital in Zurich where Eduard was committed
# [place_75] Princeton (Place)
#   → City where Einstein worked at the Institute for Advanced Study
# [place_76] Austria (Place)
#   → Country where Margarete Lebach was from
# [place_77] Russia (Place)
#   → Country where Margarita Konenkova was from
# [place_78] Serbia (Place)
#   → Country where Mileva Marić was from
# [place_79] Israel (Place)
#   → Country where Hebrew University is located

# %%
print("\n=== RELATIONS ===")
entities_list = list(all_entities.values())
for relation in all_relations:
    source = next((e for e in entities_list if e["id"] == relation["source_id"]), None)
    target = next((e for e in entities_list if e["id"] == relation["target_id"]), None)
    source_label = source["label"] if source else "?"
    target_label = target["label"] if target else "?"
    print(f"{source_label} --[{relation['relation_type']}]--> {target_label}")
# Out:
# === RELATIONS ===
# Albert Einstein --[BORN_IN]--> Ulm
# Albert Einstein --[BORN_IN]--> Kingdom of Württemberg
# Albert Einstein --[BORN_IN]--> German Empire
# Albert Einstein --[PARENT_OF]--> Hermann Einstein
# Albert Einstein --[PARENT_OF]--> Pauline Koch
# Albert Einstein --[LIVED_IN]--> Munich
# Albert Einstein --[LIVED_IN]--> Ludwigsvorstadt-Isarvorstadt
# Hermann Einstein --[FOUNDED]--> Elektrotechnische Fabrik J. Einstein & Cie
# Albert Einstein --[LIVED_IN]--> Italy
# Albert Einstein --[LIVED_IN]--> Milan
# Albert Einstein --[LIVED_IN]--> Pavia
# Albert Einstein --[LIVED_IN]--> Palazzo Cornazzani
# Albert Einstein --[LIVED_IN]--> Munich
# Albert Einstein --[ATTENDED]--> Luitpold Gymnasium
# Albert Einstein --[ATTENDED]--> St. Peter's Catholic elementary school
# Albert Einstein --[LIVED_IN]--> Aarau
# Albert Einstein --[ATTENDED]--> Argovian cantonal school
# Albert Einstein --[FALL_IN_LOVE_WITH]--> Marie Winteler
# Albert Einstein --[FAMILY_RELATIONSHIP]--> Jost Winteler
# Albert Einstein --[SIBLING_OF]--> Maja Einstein
# Maja Einstein --[MARRIED_TO]--> Paul Winteler
# Albert Einstein --[APPLIED_TO]--> federal polytechnic school
# Albert Einstein --[LIVED_IN]--> Zurich
# Albert Einstein --[ATTENDED]--> Swiss federal polytechnic school
# Albert Einstein --[SUBMITTED_PHD_TO]--> University of Zurich
# Albert Einstein --[WORKED_AT]--> Prussian Academy of Sciences
# Albert Einstein --[WORKED_AT]--> Humboldt University of Berlin
# Albert Einstein --[DIRECTED]--> Kaiser Wilhelm Institute for Physics
# Albert Einstein --[LIVED_IN]--> Berlin
# Albert Einstein --[CITIZEN_OF]--> Kingdom of Prussia
# Albert Einstein --[LIVED_IN]--> United States
# Albert Einstein --[LIVED_IN]--> Adolf Hitler
# Albert Einstein --[WROTE_TO]--> Franklin D. Roosevelt
# Albert Einstein --[RELATED_TO]--> Manhattan Project
# Albert Einstein --[WORKED_WITH]--> Satyendra Nath Bose
# Albert Einstein --[CREATED]--> Bose–Einstein statistics
# Albert Einstein --[WORKED_AT]--> Swiss Patent Office
# Albert Einstein --[LIVED_IN]--> Bern
# Albert Einstein --[INFLUENCED_BY]--> Kant's Critique of Pure Reason
# Albert Einstein --[TUTORED_BY]--> Max Talmud
# Albert Einstein --[STUDIED]--> Euclidean geometry
# Albert Einstein --[PROVED]--> Pythagorean theorem
# Albert Einstein --[MASTERED]--> integral and differential calculus
# Albert Einstein --[BELIEVED_IN]--> mathematical structure
# Albert Einstein --[DEVELOPED]--> special theory of relativity
# Albert Einstein --[DEVELOPED]--> general theory of relativity
# Albert Einstein --[INTRODUCED]--> cosmological constant
# Albert Einstein --[RELATED_TO]--> laser and maser
# Albert Einstein --[RELATED_TO]--> quantum electrodynamics
# Albert Einstein --[RELATED_TO]--> quantum optics
# Albert Einstein --[ATTEMPTED_TO_DEVELOP]--> unified field theory
# Albert Einstein --[GENERALIZED]--> geometric theory of gravitation
# Albert Einstein --[RELATED_TO]--> special theory of relativity
# Albert Einstein --[RELATED_TO]--> general theory of relativity
# Albert Einstein --[RELATED_TO]--> cosmological constant
# Albert Einstein --[RELATED_TO]--> laser and maser
# Albert Einstein --[RELATED_TO]--> quantum electrodynamics
# Albert Einstein --[RELATED_TO]--> quantum optics
# Albert Einstein --[RELATED_TO]--> unified field theory
# Albert Einstein --[RELATED_TO]--> geometric theory of gravitation
# Albert Einstein --[FRIEND_OF]--> Marcel Grossmann
# Albert Einstein --[MARRIED_TO]--> Mileva Marić
# Albert Einstein --[ROMANTIC_INTEREST]--> Marie Winteler
# Albert Einstein --[PARENT_OF]--> Lieserl Einstein
# Albert Einstein --[PARENT_OF]--> Hans Albert Einstein
# Albert Einstein --[PARENT_OF]--> Eduard Einstein
# Albert Einstein --[MARRIED_TO]--> Elsa Löwenthal
# Albert Einstein --[ROMANTIC_INTEREST]--> Betty Neumann
# Albert Einstein --[FRIEND_OF]--> Hans Mühsam
# Albert Einstein --[ROMANTIC_INTEREST]--> Margarete Lebach
# Albert Einstein --[ROMANTIC_INTEREST]--> Estella Katzenellenbogen
# Albert Einstein --[ROMANTIC_INTEREST]--> Toni Mendel
# Albert Einstein --[ROMANTIC_INTEREST]--> Ethel Michanowski
# Albert Einstein --[ROMANTIC_INTEREST]--> Margarita Konenkova
# Albert Einstein --[MARRIED_TO]--> Sergei Konenkov
# Albert Einstein --[WORKED_AT]--> Swiss Patent Office
# Albert Einstein --[STUDIED_AT]--> federal polytechnic school
# Albert Einstein --[MEMBER_OF]--> Olympia Academy
# Albert Einstein --[PUBLISHED_BY]--> Hebrew University of Jerusalem
# Albert Einstein --[BORN_IN]--> Württemberg
# Albert Einstein --[BORN_IN]--> Germany
# Albert Einstein --[LIVED_IN]--> Switzerland
# Albert Einstein --[LIVED_IN]--> Bern
# Albert Einstein --[LIVED_IN]--> Zurich
# Albert Einstein --[LIVED_IN]--> Novi Sad
# Albert Einstein --[LIVED_IN]--> Olsberg
# Albert Einstein --[LIVED_IN]--> Berlin
# Albert Einstein --[LIVED_IN]--> United States
# Albert Einstein --[LIVED_IN]--> Burghölzli
# Albert Einstein --[WORKED_AT]--> Princeton
# Albert Einstein --[LIVED_IN]--> Austria
# Albert Einstein --[LIVED_IN]--> Russia
# Albert Einstein --[BORN_IN]--> Serbia
# Albert Einstein --[LIVED_IN]--> Israel
# Marcel Grossmann --[STUDIED_AT]--> federal polytechnic school
# Mileva Marić --[STUDIED_AT]--> federal polytechnic school
# Marie Winteler --[LIVED_IN]--> Olsberg
# Lieserl Einstein --[BORN_IN]--> Novi Sad
# Hans Albert Einstein --[BORN_IN]--> Bern
# Eduard Einstein --[BORN_IN]--> Zurich
# Elsa Löwenthal --[LIVED_IN]--> Berlin
# Betty Neumann --[LIVED_IN]--> Switzerland
# Hans Mühsam --[LIVED_IN]--> Switzerland
# Margarete Lebach --[LIVED_IN]--> Austria
# Estella Katzenellenbogen --[LIVED_IN]--> Switzerland
# Toni Mendel --[LIVED_IN]--> Switzerland
# Ethel Michanowski --[LIVED_IN]--> Switzerland
# Margarita Konenkova --[LIVED_IN]--> Russia
# Sergei Konenkov --[LIVED_IN]--> Russia
# Swiss Patent Office --[LOCATED_IN]--> Bern
# federal polytechnic school --[LOCATED_IN]--> Switzerland
# Olympia Academy --[LOCATED_IN]--> Bern
# Hebrew University of Jerusalem --[LOCATED_IN]--> Israel

# %% [markdown]
# ## Generate Embeddings

# %%
def get_mock_embedding(text: str) -> list[float]:
    """Generate deterministic mock embeddings using SHA-256 hash."""
    hash_bytes = hashlib.sha256(text.encode()).digest()
    
    # Expand hash to 384 dimensions (typical embedding size)
    embedding = []
    for i in range(384):
        embedding.append((hash_bytes[i % len(hash_bytes)] - 128) / 128)
    return embedding

entity_embeddings = {}
for entity in all_entities.values():
    entity_embeddings[entity["id"]] = {
        **entity,
        "embedding": get_mock_embedding(entity["label"] + entity["description"]),
    }

print(f"Generated embeddings for {len(entity_embeddings)} entities")
# Out:
# Generated embeddings for 79 entities

# %% [markdown]
# ## Export to DuckDB-Wasm Format

# %%
duckdb_format = {
    "metadata": {
        "source": article_title,
        "extracted_at": datetime.now().isoformat(),
        "entity_count": len(all_entities),
        "relation_count": len(all_relations),
    },
    "entities": list(entity_embeddings.values()),
    "relations": all_relations,
}

print("\n=== EXPORT ===")
print(json.dumps(duckdb_format, indent=2)[:500] + "...")
# Out:
# === EXPORT ===
# {
#   "metadata": {
#     "source": "Albert Einstein",
#     "extracted_at": "2025-12-18T03:56:35.983919",
#     "entity_count": 79,
#     "relation_count": 113
#   },
#   "entities": [
#     {
#       "id": "person_1",
#       "label": "Albert Einstein",
#       "type": "Person",
#       "description": "German-born theoretical physicist",
#       "embedding": [
#         -0.296875,
#         -0.9765625,
#         0.8359375,
#         -0.2890625,
#         -0.515625,
#         0.7265625,
#         0.9921875,
#         0.28125,
#         0...

# %%
# Optional: Save to file
# with open("knowledge_graph.json", "w") as f:
#     json.dump(duckdb_format, f, indent=2)
# print("Saved to knowledge_graph.json")
