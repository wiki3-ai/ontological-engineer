# %% [markdown]
# # Chunks: Aitch (rapper)
#
# ## Provenance
#
# ```yaml
# source_url: https://en.wikipedia.org/wiki/Aitch_%28rapper%29
# article_title: Aitch (rapper)
# license: CC BY-SA 4.0
# chunking_strategy: section-based with max_size=1500
# generated_by: ontological_engineer
# generated_at: 2025-12-20T06:41:20.875943
# ```
#
# ## Description
#
# This notebook contains text chunks from the Wikipedia article.
# Each chunk preserves section context via breadcrumb metadata.
# Each content cell is followed by a CID signature for provenance tracking.

# %% [markdown]
# **Context:** Aitch (rapper) > Aitch (rapper)
# **Chunk:** 1 of 6
#
# ---
#
# Harrison James Armstrong (born 9 December 1999), known professionally as Aitch, is an English rapper from Manchester. He rose to fame in 2018 with the track "Straight Rhymez". His debut studio album Close to Home (2022) reached number two on the UK Albums Chart.
# Aitch has released eleven top-10 singles in the UK, including "Taste (Make It Shake)" and "Baby", which both peaked at number two on the UK Singles Chart. The name Aitch derives from the pronunciation of the letter 'h', which is the first letter of his Christian name.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidkj2et2neahfvrf6iue7yknl435yqe3rumuc2liajnv3fxgmhbsa",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreidkj2et2neahfvrf6iue7yknl435yqe3rumuc2liajnv3fxgmhbsa",
#   "prov:label": "chunk:0",
#   "_cell": 1,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibge62y6l4etpp3wlvl6itqise5biifxj2n4k5jsb62cjxg3zah3m"
#   },
#   "_chunk_num": 0
# }

# %% [markdown]
# **Context:** Aitch (rapper) > Early life
# **Chunk:** 2 of 6
#
# ---
#
# Harrison James Armstrong was born on 9 December 1999 in New Moston, Manchester. He has Irish ancestry through his mother. He is a supporter of the football club Manchester United. After leaving school, he went to college and played sports, but eventually dropped out and worked in construction with his grandfather.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicrboqat4wuddu2gqjssexqktjjy6fbfmao5zmohz7md5qe6m4rxe",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreicrboqat4wuddu2gqjssexqktjjy6fbfmao5zmohz7md5qe6m4rxe",
#   "prov:label": "chunk:1",
#   "_cell": 3,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibge62y6l4etpp3wlvl6itqise5biifxj2n4k5jsb62cjxg3zah3m"
#   },
#   "_chunk_num": 1
# }

# %% [markdown]
# **Context:** Aitch (rapper) > 2015: Beginnings
# **Chunk:** 3 of 6
#
# ---
#
# Aitch first garnered attention in 2015 when a YouTube video of him rapping to friends gained local popularity. He originally did not want the video published, but changed his mind when it gained 10,000 views. A friend continued uploading Aitch's freestyles to see if it would gain more views.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia5ihb52xgzlxpffxnv7nwib26qiikncxolswkyd2w6i2uitmm5bu",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreia5ihb52xgzlxpffxnv7nwib26qiikncxolswkyd2w6i2uitmm5bu",
#   "prov:label": "chunk:2",
#   "_cell": 5,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibge62y6l4etpp3wlvl6itqise5biifxj2n4k5jsb62cjxg3zah3m"
#   },
#   "_chunk_num": 2
# }

# %% [markdown]
# **Context:** Aitch (rapper) > 2016–2018: Freestyles, On Your Marks and Breakthrough
# **Chunk:** 4 of 6
#
# ---
#
# Aitch made multiple appearances on the P110 YouTube channel, starting in September 2016 with a freestyle. In June 2017, he premiered his song "Back To Basics" on the channel. On 9 December 2017, he released his EP, On Your Marks. In May 2018, he released his breakthrough track "Straight Rhymez", earning him national attention.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia2u75f3gn44ipx6qclvevz6iogmgis6zirhxxm5lh2reu5wuqluq",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreia2u75f3gn44ipx6qclvevz6iogmgis6zirhxxm5lh2reu5wuqluq",
#   "prov:label": "chunk:3",
#   "_cell": 7,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibge62y6l4etpp3wlvl6itqise5biifxj2n4k5jsb62cjxg3zah3m"
#   },
#   "_chunk_num": 3
# }

# %% [markdown]
# **Context:** Aitch (rapper) > 2019–present: AitcH2O, Polaris, Close to Home and other projects
# **Chunk:** 5 of 6
#
# ---
#
# In August 2019, he released his song "Taste (Make It Shake)" which became his biggest song at the time, peaking at number eight on the UK Singles Chart. He then released his second EP, AitcH2O, in September, which reached number three on the UK Albums Chart. In March 2020, he collaborated with AJ Tracey and Tay Keith on the track "Rain" which peaked at number three on the UK Singles Chart. In May, his third EP, Polaris was released. In June 2021, Aitch released the single "Learning Curve". He followed this up with "Party Round My Place" in September.
# In 2021, Aitch appeared on Never Mind the Buzzcocks.
# On 3 February 2022, Aitch was featured on ArrDee's single "War". The single debuted at number 6 on the UK Official Singles Top 100 Chart and debuted at number 21 on the UK Official Singles Sales Chart Top 100 on 11 February 2022. On 10 March 2022, Aitch released the single "Baby" featuring American singer Ashanti (who is credited as co-lead on the single) which heavily samples the latter's 2003 hit "Rock wit U (Awww Baby)". Less than 24 hours later, the single debuted at number 65 on the UK Official Singles Sales Chart Top 100. It debuted on the UK Official Singles Top 100 on 18 March 2022 at number 2.
# In August 2022, Aitch released "My G", featuring Ed Sheeran, which is about Aitch's sister Gracie who has Down syndrome

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifxvibnwxtjdkpbtixjhvg2fkusychg6u6wj2vtt7cq3lhspkhwuu",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreifxvibnwxtjdkpbtixjhvg2fkusychg6u6wj2vtt7cq3lhspkhwuu",
#   "prov:label": "chunk:4",
#   "_cell": 9,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibge62y6l4etpp3wlvl6itqise5biifxj2n4k5jsb62cjxg3zah3m"
#   },
#   "_chunk_num": 4
# }

# %% [markdown]
# **Context:** Aitch (rapper) > 2019–present: AitcH2O, Polaris, Close to Home and other projects
# **Chunk:** 6 of 6
#
# ---
#
# . His debut studio album, Close to Home was released on 19 August 2022, and reached number two on the UK Albums Chart.
# On 9 September 2023, he performed during the half time of the Sidemen Charity Match at the London Stadium. In November 2025, Aitch participated in the twenty-fifth series of I'm a Celebrity...Get Me Out of Here!, finishing the show in 4th place, despite being the bookmakers' favourite to win before the show.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicvm3vt3hsuoyzbwdt7fozo47nd7fbx74uhftj6gqkguojq3eartq",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreicvm3vt3hsuoyzbwdt7fozo47nd7fbx74uhftj6gqkguojq3eartq",
#   "prov:label": "chunk:5",
#   "_cell": 11,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibge62y6l4etpp3wlvl6itqise5biifxj2n4k5jsb62cjxg3zah3m"
#   },
#   "_chunk_num": 5
# }
