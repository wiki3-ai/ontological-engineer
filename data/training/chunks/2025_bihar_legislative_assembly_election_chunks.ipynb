# %% [markdown]
# # Chunks: 2025 Bihar Legislative Assembly election
#
# ## Provenance
#
# ```yaml
# source_url: https://en.wikipedia.org/wiki/2025_Bihar_Legislative_Assembly_election
# article_title: 2025 Bihar Legislative Assembly election
# license: CC BY-SA 4.0
# chunking_strategy: section-based with max_size=1500
# generated_by: ontological_engineer
# generated_at: 2025-12-20T05:01:31.591751
# ```
#
# ## Description
#
# This notebook contains text chunks from the Wikipedia article.
# Each chunk preserves section context via breadcrumb metadata.
# Each content cell is followed by a CID signature for provenance tracking.

# %% [markdown]
# **Context:** 2025 Bihar Legislative Assembly election > 2025 Bihar Legislative Assembly election
# **Chunk:** 1 of 20
#
# ---
#
# Legislative Assembly elections were held in Bihar from  6 to 11 November 2025, to elect the 243 members of the Bihar Legislative Assembly. The votes were counted and the results were declared on 14 November 2025.
# The Bharatiya Janata Party (BJP)-led National Democratic Alliance (NDA) won a landslide victory securing 202 of the 243 seats in which the election was held, defeating the Rashtriya Janata Dal (RJD)-led Mahagathbandhan (MGB) which secured just 35 seats. Incumbent chief minister Nitish Kumar took the oath for a record tenth time. Incumbent deputy chief ministers Samrat Chaudhary and Vijay Kumar Sinha took the oath as the deputy chief ministers for the second consecutive time.
# For the first time, the BJP won the most seats in a Bihar Legislative Assembly election. The RJD, led by Tejashwi Yadav, fell to third for the first time since 2010, while Kumar's Janata Dal (United) recorded its best result since 2010. The Indian National Congress (INC) fared poorly in the election, while the Lok Janshakti Party (Ram Vilas) and Rashtriya Lok Morcha secured seats for the first time.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreif2nralrjjj53iixvlygqqanrsvzfrmj6n2fyghy6rhgupjn64c6m",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreif2nralrjjj53iixvlygqqanrsvzfrmj6n2fyghy6rhgupjn64c6m",
#   "prov:label": "chunk:0",
#   "_cell": 1,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifsljyek33oprgfiatm5w3nbfqrlajvfeewn673fal45exs2zwzqm"
#   },
#   "_chunk_num": 0
# }

# %% [markdown]
# **Context:** 2025 Bihar Legislative Assembly election > Background
# **Chunk:** 2 of 20
#
# ---
#
# The tenure of Bihar Legislative Assembly is scheduled to end on 22 November 2025. The previous assembly elections were held in October–November 2020. After the election, the National Democratic Alliance formed the state government, with Nitish Kumar becoming Chief Minister.
# On 9 August 2022, the JD(U) ended its alliance with the BJP and Nitish Kumar resigned as Chief Minister. On 10 August 2022, JD(U) joined the Mahagathbandhan alliance with the RJD and the INC, with Nitish Kumar again taking oath as Chief Minister of the state.
# In January 2024, the JD(U) ended its alliance with Mahagathbandhan and Nitish Kumar resigned as Chief Minister. He formed the new government with BJP-led NDA and was sworn in as the Chief Minister again.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiffli5cl4e3sah3c3o6qdy5rxe7yxeytvp2xbmtontkmpwq4fhfha",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreiffli5cl4e3sah3c3o6qdy5rxe7yxeytvp2xbmtontkmpwq4fhfha",
#   "prov:label": "chunk:1",
#   "_cell": 3,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifsljyek33oprgfiatm5w3nbfqrlajvfeewn673fal45exs2zwzqm"
#   },
#   "_chunk_num": 1
# }

# %% [markdown]
# **Context:** 2025 Bihar Legislative Assembly election > Schedule
# **Chunk:** 3 of 20
#
# ---
#
# The Election Commission of India announced the schedule for the Bihar Legislative Assembly election on 6 October 2025.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihfzve2qh3s3dosvwubicpdfsgjrrhuqcendzshuvgxa4rwoz53bi",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreihfzve2qh3s3dosvwubicpdfsgjrrhuqcendzshuvgxa4rwoz53bi",
#   "prov:label": "chunk:2",
#   "_cell": 5,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifsljyek33oprgfiatm5w3nbfqrlajvfeewn673fal45exs2zwzqm"
#   },
#   "_chunk_num": 2
# }

# %% [markdown]
# **Context:** 2025 Bihar Legislative Assembly election > Mahagathbandhan
# **Chunk:** 4 of 20
#
# ---
#
# On 23 October 2025, Tejashwi Yadav was announced as the Chief Ministerial face of the Mahagathbandhan for the election, with Mukesh Sahani being the Deputy CM face.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreig4rr4f5trdm3w2e65txq7uontchh4aav6v7l34azjg3x4njheefm",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreig4rr4f5trdm3w2e65txq7uontchh4aav6v7l34azjg3x4njheefm",
#   "prov:label": "chunk:3",
#   "_cell": 7,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifsljyek33oprgfiatm5w3nbfqrlajvfeewn673fal45exs2zwzqm"
#   },
#   "_chunk_num": 3
# }

# %% [markdown]
# **Context:** 2025 Bihar Legislative Assembly election > Campaign
# **Chunk:** 5 of 20
#
# ---
#
# The campaign centered on a mix of local and socio-economic issues. Unemployment and migration were prominent themes: parties noted that many Bihar youth migrate out of state for work, and competing manifestos promised large-scale job creation. Caste politics also remained a key factor. All major parties pledged to support a new caste census and "social justice" measures, reflecting widespread calls to address the state's caste-based inequalities. Corruption and governance were attacked by the opposition; for example, RJD leader Tejashwi Yadav accused the Nitish Kumar government of "institutionalising corruption" and misusing government schemes (like a women's outreach programme) for electioneering. The ruling alliance countered by criticizing the RJD's past ("jungle raj") and highlighting its own welfare record. A major flashpoint was the voter roll revision (Special Intensive Revision, SIR) carried out by the Election Commission. Opposition parties claimed the intensive revision was a partisan tool, alleging mass deletions of voters and promising protests or even an election boycott.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibs7sw3yzw2jofjmsgv3pzzu6k7vsqkc4zseybq72vwj2oy3g77qi",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreibs7sw3yzw2jofjmsgv3pzzu6k7vsqkc4zseybq72vwj2oy3g77qi",
#   "prov:label": "chunk:4",
#   "_cell": 9,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifsljyek33oprgfiatm5w3nbfqrlajvfeewn673fal45exs2zwzqm"
#   },
#   "_chunk_num": 4
# }

# %% [markdown]
# **Context:** 2025 Bihar Legislative Assembly election > Party campaign strategies
# **Chunk:** 6 of 20
#
# ---
#
# NDA (BJP, JD(U), LJP(R), RLM, HAM(S)): The ruling coalition ran on a platform of development and social welfare. It emphasized caste-based outreach and welfare delivery, and frequently invoked Prime Minister Modi's leadership. The BJP also attacked the RJD over law and order and historic scams, while JD(U) emphasized Nitish Kumar's governance. Seat-sharing talks between BJP and JD(U) indicated a near-equal division.
# RJD (leading Mahagathbandhan): The RJD centered its campaign on employment, youth issues, and anti-incumbency. Tejashwi Yadav pledged massive job creation and ran a digital-heavy campaign, including AI-generated videos and memes. The RJD organized backward caste meetings and positioned itself as the party of Dalits, OBCs, and the poor.
# Jan Suraaj Party: Led by Prashant Kishor, Jan Suraaj positioned itself as an alternative to both NDA and the INDIA bloc. Kishor organized the Bihar Badlav Yatra, pledged to contest all 243 seats, and focused on governance, education, and clean politics. Between October 2022 and October 2024, he undertook padayatra across Bihar, walking over 5,000 km and visiting more than 5,500 villages to engage with local communities directly

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihe6xnte5x3uhkopvvyzd65d46gsraj4apgybd3xbvydibgvjjfny",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreihe6xnte5x3uhkopvvyzd65d46gsraj4apgybd3xbvydibgvjjfny",
#   "prov:label": "chunk:5",
#   "_cell": 11,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifsljyek33oprgfiatm5w3nbfqrlajvfeewn673fal45exs2zwzqm"
#   },
#   "_chunk_num": 5
# }

# %% [markdown]
# **Context:** 2025 Bihar Legislative Assembly election > Party campaign strategies
# **Chunk:** 7 of 20
#
# ---
#
# . At the party's launch, Kishor announced provisions such as candidate selection through US-style primaries, the right to recall legislators who fail to perform, and a pledge that 90% of candidates would be first-time contestants.
# Congress: As a partner in the Mahagathbandhan, the Congress highlighted youth migration and unemployment, notably through leader Kanhaiya Kumar's padyatra. Rahul Gandhi planned a multi-day campaign tour of Bihar in August 2025, criticizing voter list issues and advocating electoral reforms.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreickob2nxbfjkughdsi7tahrbnpjaren5aq4jg72f3xilinsgdlcfm",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreickob2nxbfjkughdsi7tahrbnpjaren5aq4jg72f3xilinsgdlcfm",
#   "prov:label": "chunk:6",
#   "_cell": 13,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifsljyek33oprgfiatm5w3nbfqrlajvfeewn673fal45exs2zwzqm"
#   },
#   "_chunk_num": 6
# }

# %% [markdown]
# **Context:** 2025 Bihar Legislative Assembly election > Unemployment
# **Chunk:** 8 of 20
#
# ---
#
# Bihar faces a severe unemployment crisis, particularly among youth and educated graduates. Many young Biharis are forced to migrate to other states for work due to lack of opportunities. Both the ruling NDA and opposition Mahagathbandhan had made job creation and youth empowerment key promises, with pledges such as government jobs for every household, skill centers, and massive investment packages.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigcoxxzfvp3pa34tc7t4n4xnpewqaolkzzo3w3kwn234sin3i3oce",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreigcoxxzfvp3pa34tc7t4n4xnpewqaolkzzo3w3kwn234sin3i3oce",
#   "prov:label": "chunk:7",
#   "_cell": 15,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifsljyek33oprgfiatm5w3nbfqrlajvfeewn673fal45exs2zwzqm"
#   },
#   "_chunk_num": 7
# }

# %% [markdown]
# **Context:** 2025 Bihar Legislative Assembly election > Allegations of electoral roll manipulation
# **Chunk:** 9 of 20
#
# ---
#
# Allegations of voter roll manipulation were made by the opposition Mahagathbandhan. The Election Commission carried out a Special Intensive Revision (SIR), resulting in mass deletions of over six million names of people, who had died, migrated out of the state or were duplicates, from the electoral rolls. Congress leader Rahul Gandhi had accused the government and Election Commission of allegedly stealing votes.  While the NDA defended the SIR as necessary to ensure accurate electoral rolls by removing dead voter's names, ineligible voters and voters who have moved out of the state.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicpb6fq7lpyhl2rewxmwx7y5lsoqrjpa22k3ro6o4ewznldz52viq",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreicpb6fq7lpyhl2rewxmwx7y5lsoqrjpa22k3ro6o4ewznldz52viq",
#   "prov:label": "chunk:8",
#   "_cell": 17,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifsljyek33oprgfiatm5w3nbfqrlajvfeewn673fal45exs2zwzqm"
#   },
#   "_chunk_num": 8
# }

# %% [markdown]
# **Context:** 2025 Bihar Legislative Assembly election > Migration
# **Chunk:** 10 of 20
#
# ---
#
# Driven by lack of employment, lakhs of Bihari youth migrate to other states each year. Both camps have made migration a major talking point, linking it directly to economic stagnation and poor governance.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiefnmrsvud52mn7uwbkbmoyb4ispsntcfjzsdittsfqup6ceyquyi",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreiefnmrsvud52mn7uwbkbmoyb4ispsntcfjzsdittsfqup6ceyquyi",
#   "prov:label": "chunk:9",
#   "_cell": 19,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifsljyek33oprgfiatm5w3nbfqrlajvfeewn673fal45exs2zwzqm"
#   },
#   "_chunk_num": 9
# }

# %% [markdown]
# **Context:** 2025 Bihar Legislative Assembly election > Corruption
# **Chunk:** 11 of 20
#
# ---
#
# Corruption continues to be a significant issue in Bihar’s governance. It hampers development and the effective implementation of welfare programs. Allegations include bribery, favoritism, and financial mismanagement in various sectors such as public distribution, infrastructure projects, and government recruitment. The prevalence of corruption undermines public confidence in political leadership.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibpbgn3naw2ak72tpurmmx25i4zebktpfd2cokyqbn2o3fxp4yham",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreibpbgn3naw2ak72tpurmmx25i4zebktpfd2cokyqbn2o3fxp4yham",
#   "prov:label": "chunk:10",
#   "_cell": 21,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifsljyek33oprgfiatm5w3nbfqrlajvfeewn673fal45exs2zwzqm"
#   },
#   "_chunk_num": 10
# }

# %% [markdown]
# **Context:** 2025 Bihar Legislative Assembly election > Development deficit
# **Chunk:** 12 of 20
#
# ---
#
# Despite various government efforts, Bihar remains underdeveloped in critical areas like infrastructure, healthcare, and education. Many rural areas lack access to adequate roads, electricity, hospitals, and schools. These shortcomings are persistent voter concerns influencing election outcomes.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicnbltitnu2woliluybe6pkaiqwfcoy7ynw2vhe6b2kozego6o5i4",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreicnbltitnu2woliluybe6pkaiqwfcoy7ynw2vhe6b2kozego6o5i4",
#   "prov:label": "chunk:11",
#   "_cell": 23,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifsljyek33oprgfiatm5w3nbfqrlajvfeewn673fal45exs2zwzqm"
#   },
#   "_chunk_num": 11
# }

# %% [markdown]
# **Context:** 2025 Bihar Legislative Assembly election > Law and order
# **Chunk:** 13 of 20
#
# ---
#
# Law and order problems, including caste-based violence, crime rates, and political intimidation, affect public safety. Improving policing and justice systems was a key election promise by competing parties.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiee745kfkhij2e6r7lffcf5vixmgfflipbob6tthhldeizfymvciy",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreiee745kfkhij2e6r7lffcf5vixmgfflipbob6tthhldeizfymvciy",
#   "prov:label": "chunk:12",
#   "_cell": 25,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifsljyek33oprgfiatm5w3nbfqrlajvfeewn673fal45exs2zwzqm"
#   },
#   "_chunk_num": 12
# }

# %% [markdown]
# **Context:** 2025 Bihar Legislative Assembly election > Special Intensive Revision of electoral rolls
# **Chunk:** 14 of 20
#
# ---
#
# On 24 June 2025, the Election Commission (EC) notified that it will conduct a Special Intensive Revision of electoral rolls in Bihar before the elections. The exercise requires all the voters from the state to fill forms to be included in the voter list. People whose names were not in the 2003 voter lists need to provide additional documents. The notification also mentioned that the documents needed to be submitted within a month (with 25 July being the deadline).
# Further, the voters need to provide one of the eleven documents mandated by the EC, with the common documents such as the Aadhaar card, voter ID card and ration cards, not included as valid documents. A significant number of people in Bihar do not have any of the 11 documents. Furthermore, a significant population of the state migrate in other parts of India for work or study and it is estimated that at least 75 lakh (7.5 million) people from Bihar migrate to other parts of India. Critics have argued it would be difficult for such voters to be a part of this exercise. Such factors have led to fears of mass exclusion of voters. Opposition parties – such as the INDIA alliance – alleged that such an exercise will favor the ruling NDA alliance. The Election Commission denied these allegations and claimed that the exercise is lawful and constitutional.
# The SIR was challenged in the Supreme Court

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihzfodraqfqz4yab2676ezjlt6vrxoutdad7iix3pjz52d4prgghi",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreihzfodraqfqz4yab2676ezjlt6vrxoutdad7iix3pjz52d4prgghi",
#   "prov:label": "chunk:13",
#   "_cell": 27,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifsljyek33oprgfiatm5w3nbfqrlajvfeewn673fal45exs2zwzqm"
#   },
#   "_chunk_num": 13
# }

# %% [markdown]
# **Context:** 2025 Bihar Legislative Assembly election > Special Intensive Revision of electoral rolls
# **Chunk:** 15 of 20
#
# ---
#
# . On 10 July, the court advised the Election Commission to consider the Aadhaar card, voter ID card and ration cards as valid documents for the exercise. On 21 July, the Election Commission responded by saying that it will not accept the Aadhaar card, voter ID card and ration cards as valid documents, as suggested by the Supreme Court.
# In August, Tejashwi Yadav, leader of the opposition of Bihar, alleged his name was removed from the voter list after the SIR exercise, however his name did appear in the list after checking. The Election commission dismissed the allegations as factually incorrect and declared the EPIC number shown by him to the media was fake. The poll body asked him to submit the fake voter ID card to the ECI office by 16 August 2025.
# In August 2025, Rahul Gandhi made allegations against BJP about election commission. The ECI dismissed the allegations as misleading, and asked him to submit the allegations under oath or apologise to the nation.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihl3vgxnat7wwpttsye3ysr722icveaht3xvs7qw3eumrxg5mdbay",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreihl3vgxnat7wwpttsye3ysr722icveaht3xvs7qw3eumrxg5mdbay",
#   "prov:label": "chunk:14",
#   "_cell": 29,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifsljyek33oprgfiatm5w3nbfqrlajvfeewn673fal45exs2zwzqm"
#   },
#   "_chunk_num": 14
# }

# %% [markdown]
# **Context:** 2025 Bihar Legislative Assembly election > AI doctored videos
# **Chunk:** 16 of 20
#
# ---
#
# Ahead of the elections, two doctored videos falsely showing Indian Army officials criticising tri-military "Trishul 2025" exercises as a political stunt were circulated widely on X. Fact-checks by iVerify and Indian media established that the viral videos were fabricated using dubbed or synthetic audio to spread misinformation.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihrebd3fnji4jttk5we5pnhtzec3dyk3e3mhcsscjjuureedhmw7m",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreihrebd3fnji4jttk5we5pnhtzec3dyk3e3mhcsscjjuureedhmw7m",
#   "prov:label": "chunk:15",
#   "_cell": 31,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifsljyek33oprgfiatm5w3nbfqrlajvfeewn673fal45exs2zwzqm"
#   },
#   "_chunk_num": 15
# }

# %% [markdown]
# **Context:** 2025 Bihar Legislative Assembly election > Government formation
# **Chunk:** 17 of 20
#
# ---
#
# Following the election result, the incumbent chief minister Nitish Kumar tendered his resignation to the governor on 17 November. He took oath for a record tenth time as chief minister on 20 November. Incumbent deputy chief ministers Samrat Chaudhary and Vijay Kumar Sinha took oath for the second consecutive time.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiees3gbrjlrfz5d6bsn5nt4gaar32ajezr2krtvyytopcmrrzg7na",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreiees3gbrjlrfz5d6bsn5nt4gaar32ajezr2krtvyytopcmrrzg7na",
#   "prov:label": "chunk:16",
#   "_cell": 33,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifsljyek33oprgfiatm5w3nbfqrlajvfeewn673fal45exs2zwzqm"
#   },
#   "_chunk_num": 16
# }

# %% [markdown]
# **Context:** 2025 Bihar Legislative Assembly election > Reactions
# **Chunk:** 18 of 20
#
# ---
#
# After the election results were announced, Prime Minister Narendra Modi reacted to NDA's landslide election victory by emphasizing development, good governance, and unity. He thanked the people of Bihar for their historic mandate and praised party workers for their hard work. Chief minister Nitish Kumar thanked Modi and the other NDA allies for their support.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic6srvm3wd2jmv5ygtyvoa3bp3svrkrglbsqhc2jxwfgvms6jqk6e",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreic6srvm3wd2jmv5ygtyvoa3bp3svrkrglbsqhc2jxwfgvms6jqk6e",
#   "prov:label": "chunk:17",
#   "_cell": 35,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifsljyek33oprgfiatm5w3nbfqrlajvfeewn673fal45exs2zwzqm"
#   },
#   "_chunk_num": 17
# }

# %% [markdown]
# **Context:** 2025 Bihar Legislative Assembly election > See also
# **Chunk:** 19 of 20
#
# ---
#
# 2025 elections in India
# 2025 Indian electoral controversy
# Elections in Bihar
# Politics of Bihar
# Special Intensive Revision (SIR)

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreig5rd6k574pdtgppzyc57hmhzf5n7pffzjdfg7mmylw43jjjj5oui",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreig5rd6k574pdtgppzyc57hmhzf5n7pffzjdfg7mmylw43jjjj5oui",
#   "prov:label": "chunk:18",
#   "_cell": 37,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifsljyek33oprgfiatm5w3nbfqrlajvfeewn673fal45exs2zwzqm"
#   },
#   "_chunk_num": 18
# }

# %% [markdown]
# **Context:** 2025 Bihar Legislative Assembly election > External links
# **Chunk:** 20 of 20
#
# ---
#
# Election Commission of Bihar Constituency wise information Official Portal
# Election Commission of India official website Bihar page

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreib2mk36zcn6rhgspbnzrrr6354pwkwmenozbeaz5lyf3xiuvusi34",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreib2mk36zcn6rhgspbnzrrr6354pwkwmenozbeaz5lyf3xiuvusi34",
#   "prov:label": "chunk:19",
#   "_cell": 39,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifsljyek33oprgfiatm5w3nbfqrlajvfeewn673fal45exs2zwzqm"
#   },
#   "_chunk_num": 19
# }
