# %% [markdown]
# # Chunks: Last Samurai Standing (TV series)
#
# ## Provenance
#
# ```yaml
# source_url: https://en.wikipedia.org/wiki/Last_Samurai_Standing_(TV_series)
# article_title: Last Samurai Standing (TV series)
# license: CC BY-SA 4.0
# chunking_strategy: section-based with max_size=1500
# generated_by: ontological_engineer
# generated_at: 2025-12-20T06:29:39.245771
# ```
#
# ## Description
#
# This notebook contains text chunks from the Wikipedia article.
# Each chunk preserves section context via breadcrumb metadata.
# Each content cell is followed by a CID signature for provenance tracking.

# %% [markdown]
# **Context:** Last Samurai Standing (TV series) > Last Samurai Standing (TV series)
# **Chunk:** 1 of 5
#
# ---
#
# Last Samurai Standing (Japanese: イクサガミ, Hepburn: Ikusagami) is a 2025 Japanese Netflix original live-action television series adapted from the novel of the same name written by Shogo Imamura. Starring Junichi Okada, Yumia Fujisaki and Kaya Kiyohara, and set in the late 19th century during the Meiji period, the series  takes place at the Tenryūji monastery in Kyoto.
# The first two episodes of the series premiered at the 30th Busan International Film Festival in the On Screen section on September 18, 2025. Following its festival release, the six episodes series became available to stream worldwide on Netflix from November 13, 2025. A second season was confirmed by Netflix Japan.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidkojpp5sk7nnchnyvm7cwj5ebkq7fmqfnkcv62u5ydlothuct3tq",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreidkojpp5sk7nnchnyvm7cwj5ebkq7fmqfnkcv62u5ydlothuct3tq",
#   "prov:label": "chunk:0",
#   "_cell": 1,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidsciasgrtfwllozaeqimbqfqns3iw345lstvmknffv7jmskoz54u"
#   },
#   "_chunk_num": 0
# }

# %% [markdown]
# **Context:** Last Samurai Standing (TV series) > Synopsis
# **Chunk:** 2 of 5
#
# ---
#
# During the Meiji era (late 19th century), 292 fighters come together at Tenryū-ji Temple in Kyoto, drawn by the chance to win a grand prize of ¥100,000. The challenge is clear: take each other's wooden tags and make it all the way to Tokyo. The winner takes the prize. One of the warriors, Shujiro Saga, joins the dangerous contest with a personal mission: to help his sick wife and child.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreida5hygjq6wpt7jvsdfart3ks362poufhlstahv76hnkkyqsz7hbq",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreida5hygjq6wpt7jvsdfart3ks362poufhlstahv76hnkkyqsz7hbq",
#   "prov:label": "chunk:1",
#   "_cell": 3,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidsciasgrtfwllozaeqimbqfqns3iw345lstvmknffv7jmskoz54u"
#   },
#   "_chunk_num": 1
# }

# %% [markdown]
# **Context:** Last Samurai Standing (TV series) > Production
# **Chunk:** 3 of 5
#
# ---
#
# Netflix announced the production of a "Last Samurai Standing" series, starring Junichi Okada, who is also  producer and action choreographer. Michihito Fujii and Kento Yamaguchi are its writer and director, produced by Office Shirous. About his multi-role in the drama, Okada said:
#
# When Netflix executive producer Mr. Takahashi reached out to me, I was still acting in historical dramas. Back then, I was already thinking of ways to make this genre a hit, not just in Japan, but all over the world. I saw their potential for action, drama, social commentary, and entertainment, but I knew they could be taken further. That’s when I came across Imamura’s novel. It was written in a way that modern audiences could enjoy, and I was excited about the idea of adapting it.
# The adaption of the novel into a multi-episode drama series involved significant creative challenges for the directors Michihito Fujii and Junichi Okada, it was like producing three feature-length films. They worked carefully to preserve the original story’s core themes, while enhancing its visual and dramatic appeal. The production featured nearly 300 actors, each requiring his own costume, which demanded consistent coordination and commitment from the entire crew.
# A second season was confirmed by Netflix, the series' director and lead actor, after Netflix France leaked the news.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicssy3gt26nesiist4gylpxb3cuuesmv6yyxdk7cdsvb4mnlbqivu",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreicssy3gt26nesiist4gylpxb3cuuesmv6yyxdk7cdsvb4mnlbqivu",
#   "prov:label": "chunk:2",
#   "_cell": 5,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidsciasgrtfwllozaeqimbqfqns3iw345lstvmknffv7jmskoz54u"
#   },
#   "_chunk_num": 2
# }

# %% [markdown]
# **Context:** Last Samurai Standing (TV series) > Release
# **Chunk:** 4 of 5
#
# ---
#
# Last Samurai Standing was selected for the 'On Screen' section at the 30th Busan International Film Festival, where the first two episodes of the series were screened on September 18, 2025. The series started streaming from November 13, 2025 on Netflix.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiektr7bzxob774c2ktnmx3wnlc5ibzhia3vmvn5fmi3hf4usds73q",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreiektr7bzxob774c2ktnmx3wnlc5ibzhia3vmvn5fmi3hf4usds73q",
#   "prov:label": "chunk:3",
#   "_cell": 7,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidsciasgrtfwllozaeqimbqfqns3iw345lstvmknffv7jmskoz54u"
#   },
#   "_chunk_num": 3
# }

# %% [markdown]
# **Context:** Last Samurai Standing (TV series) > External links
# **Chunk:** 5 of 5
#
# ---
#
# Official website  (in Japanese)
# Last Samurai Standing at IMDb
# Last Samurai Standing on Netflix
# Official trailer on YouTube

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreictw4tm5mex3yukfp4otgk3o2ijt2nwrpppixibmjs4ruenq3uqpq",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreictw4tm5mex3yukfp4otgk3o2ijt2nwrpppixibmjs4ruenq3uqpq",
#   "prov:label": "chunk:4",
#   "_cell": 9,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidsciasgrtfwllozaeqimbqfqns3iw345lstvmknffv7jmskoz54u"
#   },
#   "_chunk_num": 4
# }
