# %% [markdown]
# # Chunks: The Beast in Me (TV series)
#
# ## Provenance
#
# ```yaml
# source_url: https://en.wikipedia.org/wiki/The_Beast_in_Me_(TV_series)
# article_title: The Beast in Me (TV series)
# license: CC BY-SA 4.0
# chunking_strategy: section-based with max_size=1500
# generated_by: ontological_engineer
# generated_at: 2025-12-20T05:01:33.783733
# ```
#
# ## Description
#
# This notebook contains text chunks from the Wikipedia article.
# Each chunk preserves section context via breadcrumb metadata.
# Each content cell is followed by a CID signature for provenance tracking.

# %% [markdown]
# **Context:** The Beast in Me (TV series) > The Beast in Me (TV series)
# **Chunk:** 1 of 7
#
# ---
#
# The Beast in Me is an American psychological crime thriller television miniseries for Netflix, starring Claire Danes and Matthew Rhys. Created by Gabe Rotter, the series follows an author (Danes) who begins writing a book about her new next-door neighbor (Rhys), a real estate executive who allegedly killed his wife. Executive producers on the series include Jodie Foster and Conan O'Brien. The series premiered on November 13, 2025, and received generally positive reviews. It has received nominations for three major Golden Globe Awards.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicy4sxpu2wujsktkk3py2silbaen646sxmsz6jclgne4ydnc4kwym",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreicy4sxpu2wujsktkk3py2silbaen646sxmsz6jclgne4ydnc4kwym",
#   "prov:label": "chunk:0",
#   "_cell": 1,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibzkhcbql4tkuxhbquqfj4c5q7xvyqtwnhbdg6xxjycefcmy2qsrq"
#   },
#   "_chunk_num": 0
# }

# %% [markdown]
# **Context:** The Beast in Me (TV series) > Main
# **Chunk:** 2 of 7
#
# ---
#
# Claire Danes as Aggie Wiggs, a grieving author who struggles to write her next book
# Matthew Rhys as Nile Jarvis, the son of a real estate magnate who moves next door to Aggie's house in Oyster Bay, New York, on Long Island to live in a more secluded manner with his second wife as he allegedly killed his first wife
# Brittany Snow as Nina Jarvis, Nile's second wife who is a gallerist in Manhattan
# Natalie Morales as Shelley Morris, Aggie's ex-wife who is a painter

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigjivsapejlwsrlm633bnmppatgduyxot2tmfeigglew7lnfriy3a",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreigjivsapejlwsrlm633bnmppatgduyxot2tmfeigglew7lnfriy3a",
#   "prov:label": "chunk:1",
#   "_cell": 3,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibzkhcbql4tkuxhbquqfj4c5q7xvyqtwnhbdg6xxjycefcmy2qsrq"
#   },
#   "_chunk_num": 1
# }

# %% [markdown]
# **Context:** The Beast in Me (TV series) > Recurring
# **Chunk:** 3 of 7
#
# ---
#
# Jonathan Banks as Martin Jarvis, Nile's father who is a ruthless real estate mogul
# David Lyons as Agent Brian Abbott, an FBI agent who previously investigated the Jarvis family
# Tim Guinee as Rick "Wrecking Ball" Jarvis, Nile's uncle who is also his security detail
# Deirdre O'Connell as Carol McGiddish, Aggie's literary agent and trusted friend
# Bubba Weiler as Teddy Fenig, a young drunk driver who killed Aggie's son
# Hettienne Park as Agent Erika Breton, an FBI agent who is Abbott's supervisor and lover
# Aleyse Shannon as Olivia Benitez, a city council member who opposes Nile's business plans
# Julie Ann Emery as Lila Jarvis, Martin Jarvis' wife and Nile's stepmother
# Amir Arison as Frank Breton, FBI Agent Erika Breton's ex-husband

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifqeyvcjnokqhzfzjtok3jcd3jnvtn3gwbtmrnp6lat3rf6lpjaua",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreifqeyvcjnokqhzfzjtok3jcd3jnvtn3gwbtmrnp6lat3rf6lpjaua",
#   "prov:label": "chunk:2",
#   "_cell": 5,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibzkhcbql4tkuxhbquqfj4c5q7xvyqtwnhbdg6xxjycefcmy2qsrq"
#   },
#   "_chunk_num": 2
# }

# %% [markdown]
# **Context:** The Beast in Me (TV series) > Guest starring
# **Chunk:** 4 of 7
#
# ---
#
# Leonard Gerome as Cooper Morris-Wiggs, Aggie and Shelley's six-year-old son who died in a drunk driving accident
# Brennan Brown as Phineas Gold, a city councilman whose campaign the Jarvises bankrolled
# Will Brill as Christopher Ingram, the brother of Nile's missing wife
# Kate Burton as Mariah Ingram, the mother of Nile's missing wife
# Bill Irwin as James Ingram, the father of Nile's missing wife
# Mozhan Navabi as Esme Noor, a political strategist hired by the Jarvises to do opposition research on city council members opposing Jarvis Yards
# Raphael Sbarge as Nick Ryder, the Jarvises' attorney
# Becky Ann Baker as Tessa Baldwin, Abbott's superior in the FBI
# Leila George as Madison Jarvis (née Ingram), Nile's missing wife

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieihqwy27c6g6ouralymywvjshigpiwmeqdm3royh7kuprgkvmv2u",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreieihqwy27c6g6ouralymywvjshigpiwmeqdm3royh7kuprgkvmv2u",
#   "prov:label": "chunk:3",
#   "_cell": 7,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibzkhcbql4tkuxhbquqfj4c5q7xvyqtwnhbdg6xxjycefcmy2qsrq"
#   },
#   "_chunk_num": 3
# }

# %% [markdown]
# **Context:** The Beast in Me (TV series) > Development
# **Chunk:** 5 of 7
#
# ---
#
# The series is produced by 20th Television and created, written and executive produced by Gabe Rotter. Rotter initially wrote the script 6–7 years prior to production. It is executive produced by Jodie Foster, Conan O'Brien, Daniel Pearle, who also served as writer, Antonio Campos, who also directed, Jeff Ross and David Kissinger via Conaco, Howard Gordon, who served as showrunner, and Claire Danes, who also stars.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihe33osuwgwzkwjdxmdz654piapne3cte2en3rxyy5lc4yimuvgpa",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreihe33osuwgwzkwjdxmdz654piapne3cte2en3rxyy5lc4yimuvgpa",
#   "prov:label": "chunk:4",
#   "_cell": 9,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibzkhcbql4tkuxhbquqfj4c5q7xvyqtwnhbdg6xxjycefcmy2qsrq"
#   },
#   "_chunk_num": 4
# }

# %% [markdown]
# **Context:** The Beast in Me (TV series) > Casting
# **Chunk:** 6 of 7
#
# ---
#
# Matthew Rhys joined the cast for the Netflix production in August 2024.
# Brittany Snow, Natalie Morales, David Lyons and Tim Guinee joined the cast in October 2024.
# Deirdre O'Connell, Jonathan Banks, Hettienne Park, Aleyse Shannon, Will Brill, Kate Burton, Bill Irwin, Amir Arison, and Julie Ann Emery joined the cast in November 2024.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidv5wqinljhpfhjea4fxulw42qr3lw24zgeymv4nz75fpbx3fqy5y",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreidv5wqinljhpfhjea4fxulw42qr3lw24zgeymv4nz75fpbx3fqy5y",
#   "prov:label": "chunk:5",
#   "_cell": 11,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibzkhcbql4tkuxhbquqfj4c5q7xvyqtwnhbdg6xxjycefcmy2qsrq"
#   },
#   "_chunk_num": 5
# }

# %% [markdown]
# **Context:** The Beast in Me (TV series) > Reception
# **Chunk:** 7 of 7
#
# ---
#
# The review aggregator website Rotten Tomatoes reported an 83% approval rating based on 66 critic reviews. The website's critics consensus reads, "A cut above the usual murder mystery, The Beast in Me stages a psychological duel that crackles with tension thanks to Claire Danes and Matthew Rhys' superb performances." Metacritic, which uses a weighted average, gave a score of 71 out of 100 based on 29 critics, indicating "generally favorable" reviews.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigurfypevcajaearvlk4yot76we42fgelay74lh3mgh6ufatiagym",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreigurfypevcajaearvlk4yot76we42fgelay74lh3mgh6ufatiagym",
#   "prov:label": "chunk:6",
#   "_cell": 13,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibzkhcbql4tkuxhbquqfj4c5q7xvyqtwnhbdg6xxjycefcmy2qsrq"
#   },
#   "_chunk_num": 6
# }
