# %% [markdown]
# # Chunks: I'm a Celebrity...Get Me Out of Here! (British TV series) series 25
#
# ## Provenance
#
# ```yaml
# source_url: https://en.wikipedia.org/wiki/I%27m_a_Celebrity...Get_Me_Out_of_Here%21_%28British_TV_series%29_series_25
# article_title: I'm a Celebrity...Get Me Out of Here! (British TV series) series 25
# license: CC BY-SA 4.0
# chunking_strategy: section-based with max_size=1500
# generated_by: ontological_engineer
# generated_at: 2025-12-20T06:41:33.345881
# ```
#
# ## Description
#
# This notebook contains text chunks from the Wikipedia article.
# Each chunk preserves section context via breadcrumb metadata.
# Each content cell is followed by a CID signature for provenance tracking.

# %% [markdown]
# **Context:** I'm a Celebrity...Get Me Out of Here! (British TV series) series 25 > I'm a Celebrity...Get Me Out of Here! (British TV series) series 25
# **Chunk:** 1 of 9
#
# ---
#
# I'm a Celebrity...Get Me Out of Here! returned for its twenty-fifth series on 16 November 2025 on ITV, and was again filmed in Australia with Ant & Dec returning to present the series. Joel Dommett and Kemi Rodgers returned to front the spin-off show I'm a Celebrity: Unpacked.
# The series concluded on 7 December 2025, when Angryginge was declared the winner of the series, and ultimately the new "King of the Jungle", with Tom Read Wilson and Shona McGarty finishing in second and third place respectively.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibln4bcqbafx377ehnsdyszeejardhesrkyijn5u5mzz6dmujpqxe",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreibln4bcqbafx377ehnsdyszeejardhesrkyijn5u5mzz6dmujpqxe",
#   "prov:label": "chunk:0",
#   "_cell": 1,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibmun5ivuradycvpno4wyblu6kciexk3ib3ks7godzwkbcp3ot2li"
#   },
#   "_chunk_num": 0
# }

# %% [markdown]
# **Context:** I'm a Celebrity...Get Me Out of Here! (British TV series) series 25 > Production
# **Chunk:** 2 of 9
#
# ---
#
# Following the conclusion of the previous series, ITV confirmed that the show would return for a twenty-fifth series in November 2025. Prior to the beginning of the series, ITV revealed a new logo for the programme, for the first time since the eighth series. It features a change of design, with the text maintaining the same colours, but with all lettering now in capitals and "I'm a Celebrity" written in a thicker font. The lettering is no longer situated amongst the trees in the jungle, but is instead layered on top of the background. Joel Dommett and Kemi Rodgers were announced to be returning to host the spin-off show I'm a Celebrity: Unpacked, whilst Sam Thompson did not return as co-host, however is due to appear as a guest.
# The first teaser for the series was unveiled in October 2025, and featured a tarantula crawling along a  sideboard in a house that had been decorated for Christmas, with a narrator saying "'Twas the night in October, and all through the house creatures were stirring, and I don't mean a mouse" before the words "'Tis nearly the season" appeared on screen followed by the jungle drums from the theme tune. Other versions of the trailer began airing one of which featured a girl reaching into a stocking hung from the fireplace and pulling out a star covered in gunge, before shaking it with some of the gunge landing on a family photo

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie65vzyu5vpnv2cehh7bvrjny6dufhetvkg6wbcs23zlll2hjvvja",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreie65vzyu5vpnv2cehh7bvrjny6dufhetvkg6wbcs23zlll2hjvvja",
#   "prov:label": "chunk:1",
#   "_cell": 3,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibmun5ivuradycvpno4wyblu6kciexk3ib3ks7godzwkbcp3ot2li"
#   },
#   "_chunk_num": 1
# }

# %% [markdown]
# **Context:** I'm a Celebrity...Get Me Out of Here! (British TV series) series 25 > Production
# **Chunk:** 3 of 9
#
# ---
#
# . A full length trailer was released on 1 November, which featured a family sitting around a table for Christmas dinner, with Ant and Dec serving up dishes similar to that consumed the eating trials, as Ant says "It's that time of year again" to which Dec responds "It comes around so fast, doesn't it?". One family members eats one of the fish eyes before it concludes with the family laughing covered in mealworms and partaking in pulling crackers with gunge inside. Ant remarks "'Tis the season" before Dec interrupts and says "for I'm a Celebrity...Get Me Out of Here" followed by the jungle drums. A further trailer featured Ant & Dec in pyjamas entering the living room as Ant exclaims "He's been, he's been". The camera then shows campmates wrapped in jungle themed wrapping paper as Dec tears one open and says "I've always wanted this one". The start date was confirmed for 16 November 2025.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibddiwn2h2m44lygxqddeyqjxo576xcpohehoufntbkyrejixn4ri",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreibddiwn2h2m44lygxqddeyqjxo576xcpohehoufntbkyrejixn4ri",
#   "prov:label": "chunk:2",
#   "_cell": 5,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibmun5ivuradycvpno4wyblu6kciexk3ib3ks7godzwkbcp3ot2li"
#   },
#   "_chunk_num": 2
# }

# %% [markdown]
# **Context:** I'm a Celebrity...Get Me Out of Here! (British TV series) series 25 > Celebrities
# **Chunk:** 4 of 9
#
# ---
#
# The official line-up was announced by ITV on 10 November 2025. On 19 November 2025, Tom Read Wilson and Vogue Williams were confirmed as this year's late arrivals.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiga3usar26mg3frnjtzlgdd4icmhalojbr52u5scryeoddocwezym",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreiga3usar26mg3frnjtzlgdd4icmhalojbr52u5scryeoddocwezym",
#   "prov:label": "chunk:3",
#   "_cell": 7,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibmun5ivuradycvpno4wyblu6kciexk3ib3ks7godzwkbcp3ot2li"
#   },
#   "_chunk_num": 3
# }

# %% [markdown]
# **Context:** I'm a Celebrity...Get Me Out of Here! (British TV series) series 25 > Results and elimination
# **Chunk:** 5 of 9
#
# ---
#
# Indicates that the celebrity was immune from the vote
#   Indicates that the celebrity received the most votes from the public
#   Indicates that the celebrity received the fewest votes and was eliminated immediately (no bottom two)
#   Indicates that the celebrity was named as being in the bottom two

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibkbsoiq5rrfxuxcux4gtxjrtisrtu77mxef7phj3qets6gjny23m",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreibkbsoiq5rrfxuxcux4gtxjrtisrtu77mxef7phj3qets6gjny23m",
#   "prov:label": "chunk:4",
#   "_cell": 9,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibmun5ivuradycvpno4wyblu6kciexk3ib3ks7godzwkbcp3ot2li"
#   },
#   "_chunk_num": 4
# }

# %% [markdown]
# **Context:** I'm a Celebrity...Get Me Out of Here! (British TV series) series 25 > Notes
# **Chunk:** 6 of 9
#
# ---
#
# ^Note 1:  Eddie, Lisa, Shona, Tom and Vogue were immune from the first public vote, as a result of winning the live Bushtucker trial.
# ^Note 2:  The public were voting for who they wanted to win rather than to save.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicn4u3mhcwc54eomnxpsxxethlu73mir3uvo53djdmmiq4j2nsg2y",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreicn4u3mhcwc54eomnxpsxxethlu73mir3uvo53djdmmiq4j2nsg2y",
#   "prov:label": "chunk:5",
#   "_cell": 11,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibmun5ivuradycvpno4wyblu6kciexk3ib3ks7godzwkbcp3ot2li"
#   },
#   "_chunk_num": 5
# }

# %% [markdown]
# **Context:** I'm a Celebrity...Get Me Out of Here! (British TV series) series 25 > Bushtucker trials
# **Chunk:** 7 of 9
#
# ---
#
# The contestants take part in daily trials to earn food. These trials aim to test both physical and mental abilities. The winner is usually determined by the number of stars collected during the trial, with each star representing a meal earned by the winning contestant for their fellow campmates. For this series, ITV introduced a new rule in which the same celebrity cannot be voted to take part in a bushtucker trial for more than two consecutive days in a row.
#
#   The public voted for who they wanted to face the trial
#   The contestants decided who would face the trial
#   The trial was compulsory and neither the public nor celebrities decided who took part

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigawe763cgeswslhe3jxb5tarcjz2io4mxx3hy72ny4ycdzz3c6e4",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreigawe763cgeswslhe3jxb5tarcjz2io4mxx3hy72ny4ycdzz3c6e4",
#   "prov:label": "chunk:6",
#   "_cell": 13,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibmun5ivuradycvpno4wyblu6kciexk3ib3ks7godzwkbcp3ot2li"
#   },
#   "_chunk_num": 6
# }

# %% [markdown]
# **Context:** I'm a Celebrity...Get Me Out of Here! (British TV series) series 25 > Deals on Wheels challenges
# **Chunk:** 8 of 9
#
# ---
#
# As well as competing in the Bushtucker trials, celebrities have to complete in "Deals on Wheels challenges" in order to earn treats for the camp. At least two celebrities are chosen to compete in the challenge. These are often mental challenges, rather than challenges including critters. They must complete the challenge they have been given in order to win 'Dingo Dollars'.
# After completion of the challenge, the celebrities will take the Dingo Dollars and purchase a snack from Kiosk Kev, who for this series was located in an ice cream van. Before they are allowed to take the prize, the other celebrities back at the living quarters must answer a trivia question. If they get the question right, they will earn the treat, but if they get it wrong, the celebrities will go back empty-handed.
#
#   The celebrities got the question correct
#   The celebrities got the question wrong
#   No question was asked

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidfkoljmwuth3eby5qcigxw7whv5lvbwqc7t6gtebysajc4226ske",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreidfkoljmwuth3eby5qcigxw7whv5lvbwqc7t6gtebysajc4226ske",
#   "prov:label": "chunk:7",
#   "_cell": 15,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibmun5ivuradycvpno4wyblu6kciexk3ib3ks7godzwkbcp3ot2li"
#   },
#   "_chunk_num": 7
# }

# %% [markdown]
# **Context:** I'm a Celebrity...Get Me Out of Here! (British TV series) series 25 > Ratings
# **Chunk:** 9 of 9
#
# ---
#
# Official ratings are taken from BARB, utilising the four-screen dashboard which includes viewers who watched the programme on laptops, smartphones and tablets within 7 days of the original broadcast.
#
#
# == References ==

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiely3tlpwh2sapcteq6utjrwbi5kyjt7usmslwebtwrlxw6ekaghy",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreiely3tlpwh2sapcteq6utjrwbi5kyjt7usmslwebtwrlxw6ekaghy",
#   "prov:label": "chunk:8",
#   "_cell": 17,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibmun5ivuradycvpno4wyblu6kciexk3ib3ks7godzwkbcp3ot2li"
#   },
#   "_chunk_num": 8
# }
