# %% [markdown]
# # Chunks: List of World Series champions
#
# ## Provenance
#
# ```yaml
# source_url: https://en.wikipedia.org/wiki/List_of_World_Series_champions
# article_title: List of World Series champions
# license: CC BY-SA 4.0
# chunking_strategy: section-based with max_size=1500
# generated_by: ontological_engineer
# generated_at: 2025-12-20T06:41:18.381079
# ```
#
# ## Description
#
# This notebook contains text chunks from the Wikipedia article.
# Each chunk preserves section context via breadcrumb metadata.
# Each content cell is followed by a CID signature for provenance tracking.

# %% [markdown]
# **Context:** List of World Series champions > List of World Series champions
# **Chunk:** 1 of 7
#
# ---
#
# The World Series is the annual championship series of Major League Baseball (MLB) and concludes the MLB postseason. First played in 1903, the World Series championship is a best-of-seven playoff and is a contest between the champions of baseball's National League (NL) and American League (AL). Often referred to as the "Fall Classic", the modern World Series has been played every year since 1903 with two exceptions: in 1904, when the NL champion New York Giants declined to play the AL champion Boston Americans; and in 1994, when the series was canceled due to the players' strike. The best-of-seven style has been the format of all World Series except in 1903, 1919, 1920, 1921, when the winner was determined through a best-of-nine playoff. Although the large majority of contests have been played entirely during the month of October, a small number of Series have also had games played during September and November. The Series-winning team is awarded the Commissioner's Trophy. Players, coaches and others associated with the team are generally given World Series rings to commemorate their victory; however, they have received other items such as pocket watches and medallions in the past.
# A total of 121 World Series have been contested through 2025, with the AL champion winning 68 and the NL champion winning 53. The New York Yankees of the AL have played in 41 World Series, winning 27 – the most championship appearances and most victories by any MLB team

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreienkozamhvvyxsbsyk6u6t46fsfrt7tgw7lkkpacck56dp2pi3tx4",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreienkozamhvvyxsbsyk6u6t46fsfrt7tgw7lkkpacck56dp2pi3tx4",
#   "prov:label": "chunk:0",
#   "_cell": 1,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiexhawizmenin2l5s55s3ojxu7cl47kggzcacuwropiif456t6x7i"
#   },
#   "_chunk_num": 0
# }

# %% [markdown]
# **Context:** List of World Series champions > List of World Series champions
# **Chunk:** 2 of 7
#
# ---
#
# . The Dodgers and the Yankees are tied for the most losses with 14 each. The St. Louis Cardinals have won 11 championships, the most among NL clubs and second-most all-time behind the Yankees. The Dodgers have represented the NL the most in the World Series with 23 appearances. The Seattle Mariners are the only MLB franchise that has never appeared in a World Series; the Milwaukee Brewers, San Diego Padres, Tampa Bay Rays, and Colorado Rockies have all played in the Series but have never won it, with the Padres and the Rays appearing twice. The Los Angeles Angels and Washington Nationals are the only teams who have won their only World Series appearance, and the Miami Marlins are the only team with multiple World Series appearances and no losses with two. The Toronto Blue Jays are the only franchise from outside the United States to appear in and win a World Series, winning in 1992 and 1993. The Houston Astros are the only franchise to have represented both the NL (2005) and the AL (2017, 2019, 2021, 2022), winning the Series in 2017 and 2022.  The 1919 and 2017 World Series were both marred with cheating scandals: the Black Sox Scandal and the Houston Astros sign stealing scandal. The most recent World Series champions are the Los Angeles Dodgers.
# The last team to repeat as champions were the Dodgers in 2025

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreib7eqyddwmx4ekddqihyxgyczhnypmuudzqsyf4rvnbqgqjl6cm5i",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreib7eqyddwmx4ekddqihyxgyczhnypmuudzqsyf4rvnbqgqjl6cm5i",
#   "prov:label": "chunk:1",
#   "_cell": 3,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiexhawizmenin2l5s55s3ojxu7cl47kggzcacuwropiif456t6x7i"
#   },
#   "_chunk_num": 1
# }

# %% [markdown]
# **Context:** List of World Series champions > List of World Series champions
# **Chunk:** 3 of 7
#
# ---
#
# . Two World Series matchups (in 1982 and 2005) have no current possibility of a rematch due to one of the contending teams switching to the opposing league – the Milwaukee Brewers moved to the NL in 1998, and the Houston Astros moved to the AL in 2013.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidd6kta7ivj42aqfreibktsjmfwfp2xdzvg3yjp4r7vaeomfkhxci",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreidd6kta7ivj42aqfreibktsjmfwfp2xdzvg3yjp4r7vaeomfkhxci",
#   "prov:label": "chunk:2",
#   "_cell": 5,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiexhawizmenin2l5s55s3ojxu7cl47kggzcacuwropiif456t6x7i"
#   },
#   "_chunk_num": 2
# }

# %% [markdown]
# **Context:** List of World Series champions > Results
# **Chunk:** 4 of 7
#
# ---
#
# Numbers in parentheses in the table are World Series appearances as of the date of that World Series, and are used as follows:
#
# Winning team and Losing team columns indicate the number of times that team has appeared in a World Series as well as each respective team's World Series record to date.
#
# Legend
#
# V  The 1903, 1919, 1920, and 1921 World Series were in a best-of-nine format (carried by the first team to win five games).
# T  The 1907, 1912, and 1922 World Series each included one tied game.
# A  The Brewers were in the American League from 1969 to 1997, after which they moved to the National League.
# N  The Astros were in the National League from 1962 to 2012, after which they moved to the American League.
# W  Indicates a team that made the playoffs as a wild card team (rather than by winning a division).
# Source for this Table

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaqt4idxsrnzcu22sxotnurw5lcpujnml5yhgw72ajdxlxluxjuqy",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreiaqt4idxsrnzcu22sxotnurw5lcpujnml5yhgw72ajdxlxluxjuqy",
#   "prov:label": "chunk:3",
#   "_cell": 7,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiexhawizmenin2l5s55s3ojxu7cl47kggzcacuwropiif456t6x7i"
#   },
#   "_chunk_num": 3
# }

# %% [markdown]
# **Context:** List of World Series champions > Records by franchise
# **Chunk:** 5 of 7
#
# ---
#
# In the sortable table below, teams are ordered first by number of wins, then by number of appearances, and finally by year of first appearance. In the "Season(s)" column, bold years indicate winning appearances.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaaoac752d352ajpbyud6m7nh4kmylxszwieetkrtgv3vigmhj3zi",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreiaaoac752d352ajpbyud6m7nh4kmylxszwieetkrtgv3vigmhj3zi",
#   "prov:label": "chunk:4",
#   "_cell": 9,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiexhawizmenin2l5s55s3ojxu7cl47kggzcacuwropiif456t6x7i"
#   },
#   "_chunk_num": 4
# }

# %% [markdown]
# **Context:** List of World Series champions > Frequent matchups
# **Chunk:** 6 of 7
#
# ---
#
# The following are the 20 matchups of teams that have occurred two or more times in the World Series. All teams that have participated in these were "Classic Eight" members of either the American or National League; no expansion team (created in 1961 or later) has faced the same opponent more than once in a World Series.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifts3q7u7xjwmjwvcpfpem6j3mejsfju4emhlhbwlxzoojexrowhe",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreifts3q7u7xjwmjwvcpfpem6j3mejsfju4emhlhbwlxzoojexrowhe",
#   "prov:label": "chunk:5",
#   "_cell": 11,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiexhawizmenin2l5s55s3ojxu7cl47kggzcacuwropiif456t6x7i"
#   },
#   "_chunk_num": 5
# }

# %% [markdown]
# **Context:** List of World Series champions > See also
# **Chunk:** 7 of 7
#
# ---
#
# World Series Most Valuable Player Award
# List of World Series sweeps
# List of National League pennant winners
# List of American League pennant winners
# List of Major League Baseball franchise postseason streaks
# List of Major League Baseball franchise postseason droughts
# List of pre-World Series baseball champions

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidochutwmxdybbrinagszu66z2ewqeusoy4m7q5yucisvqb7jhwta",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreidochutwmxdybbrinagszu66z2ewqeusoy4m7q5yucisvqb7jhwta",
#   "prov:label": "chunk:6",
#   "_cell": 13,
#   "_type": "chunk",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiexhawizmenin2l5s55s3ojxu7cl47kggzcacuwropiif456t6x7i"
#   },
#   "_chunk_num": 6
# }
