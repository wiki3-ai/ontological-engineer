# %% [markdown]
# # RDF Triples: Albert Einstein
#
# ## Provenance
#
# ```yaml
# source_url: https://en.wikipedia.org/wiki/Albert_Einstein
# article_title: Albert Einstein
# license: CC BY-SA 4.0
# license_url: https://creativecommons.org/licenses/by-sa/4.0/
# source_notebook: albert_einstein_facts.ipynb
# generated_by: wiki_to_kg_pipeline.ipynb
# generated_at: 2025-12-18T06:43:43.278080
# llm_provider: lm_studio
# llm_model: qwen/qwen3-coder-30b
# llm_temperature: 1
# rdf_format: Turtle
# ```
#
# ## RDF Prefixes
#
# The following prefixes are used throughout this notebook:
#
# ```turtle
# @prefix schema: <https://schema.org/> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix wiki3: <https://wiki3.ai/vocab/> .
# @base <https://en.wikipedia.org/wiki/Albert_Einstein> .
#
# ```
#
# ## Processing Instructions
#
# This notebook contains RDF triples in Turtle format, one cell per source facts cell.
# Each cell corresponds to factual statements from the facts notebook.
#
# An LLM/agent processes this notebook by:
# 1. Reading the corresponding facts cell
# 2. Converting statements to RDF using schema.org vocabulary
# 3. Entity URIs use source URL with fragment identifiers (e.g., `<#person_albert_einstein>`)
#
# Triples can be edited, corrected, or expanded by humans before final export.
#
# ## Prompt Template
#
# The following prompt was used to convert facts to RDF:
#
# ```
# You are an expert at converting factual statements to RDF triples in Turtle format.
#
# Convert the following factual statements to RDF using schema.org vocabulary where possible.
#
# Source: {source_url}
# Section: {breadcrumb}
#
# Use these prefixes:
# {prefixes}
#
# Entity registry (use these URIs):
# {entity_registry}
#
# Guidelines:
# - Use schema.org properties (schema:birthDate, schema:birthPlace, schema:worksFor, etc.)
# - For relationships not in schema.org, use wiki3: prefix
# - Include rdfs:label for entities
# - Use xsd datatypes for dates and numbers
# - Entity URIs should use the source URL as base with fragment identifiers
#
# ---
# {facts}
# ---
#
# Generate Turtle RDF:
#
# ```

# %% [raw]
# {
#   "source_url": "https://en.wikipedia.org/wiki/Albert_Einstein",
#   "entities": {
#     "albert_einstein": {
#       "id": "person_albert_einstein",
#       "uri": "https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein",
#       "label": "Albert Einstein",
#       "type": "Person",
#       "descriptions": [
#         "Subject of Wikipedia article: Albert Einstein"
#       ],
#       "source_chunks": [],
#       "aliases": [
#         "Einstein"
#       ]
#     }
#   },
#   "aliases": {
#     "einstein": "albert_einstein"
#   }
# }

# %% [raw]
# # Chunk 1
# # Context: Albert Einstein > Introduction
#
# <#person_albert_einstein> a schema:Person ;
#     schema:birthDate "1879-03-14"^^xsd:date ;
#     schema:birthPlace <https://en.wikipedia.org/wiki/German_Empire> ;
#     schema:deathDate "1955-04-18"^^xsd:date ;
#     schema:jobTitle "Theoretical physicist" ;
#     schema:knowsAbout "Theory of relativity", "Quantum theory", "Mass–energy equivalence" ;
#     schema:award <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics_1921> ;
#     schema:alumniOf <https://en.wikipedia.org/wiki/Swiss_federal_polytechnic_school> ;
#     schema:worksFor <https://en.wikipedia.org/wiki/Swiss_Patent_Office>, <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences>, <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin>, <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute_for_Physics> ;
#     schema:hasCredential <https://en.wikipedia.org/wiki/PhD> ;
#     schema:nationality <https://en.wikipedia.org/wiki/Germany>, <https://en.wikipedia.org/wiki/Switzerland>, <https://en.wikipedia.org/wiki/United_States> ;
#     schema:residence <https://en.wikipedia.org/wiki/Bern>, <https://en.wikipedia.org/wiki/Berlin>, <https://en.wikipedia.org/wiki/United_States> ;
#     schema:subjectOf <https://en.wikipedia.org/wiki/Kingdom_of_W%C3%BCrttemberg>, <https://en.wikipedia.org/wiki/ Kingdom_of_Prussia> ;
#     schema:spouse <https://en.wikipedia.org/wiki/Elsa_Einstein> ;
#     schema:sibling <https://en.wikipedia.org/wiki/Hans_Einstein>, <https://en.wikipedia.org/wiki/Natalie_Einstein> ;
#     schema:award <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics_1921> ;
#     schema:hasOccupation "Theoretical physicist", "Nobel laureate", "Scientist" ;
#     schema:hasPart <https://en.wikipedia.org/wiki/E%3Dmc%5E2> ;
#     schema:relatedTo <https://en.wikipedia.org/wiki/Adolf_Hitler>, <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt> ;
#     schema:hasChild <https://en.wikipedia.org/wiki/Thomas_Einstein>, <https://en.wikipedia.org/wiki/Margot_Einstein> ;
#     schema:affiliation <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> ;
#     schema:hasInterest "Relativity", "Quantum mechanics", "Nuclear physics" .
#
# <https://en.wikipedia.org/wiki/German_Empire> a schema:Country ;
#     rdfs:label "German Empire" .
#
# <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics_1921> a schema:Award ;
#     rdfs:label "Nobel Prize in Physics 1921" ;
#     schema:year "1921"^^xsd:gYear .
#
# <https://en.wikipedia.org/wiki/Swiss_federal_polytechnic_school> a schema:CollegeOrUniversity ;
#     rdfs:label "Swiss Federal Polytechnic School" .
#
# <https://en.wikipedia.org/wiki/Swiss_Patent_Office> a schema:Organization ;
#     rdfs:label "Swiss Patent Office" .
#
# <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> a schema:Organization ;
#     rdfs:label "Prussian Academy of Sciences" .
#
# <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> a schema:CollegeOrUniversity ;
#     rdfs:label "Humboldt University of Berlin" .
#
# <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute_for_Physics> a schema:Organization ;
#     rdfs:label "Kaiser Wilhelm Institute for Physics" .
#
# <https://en.wikipedia.org/wiki/United_States> a schema:Country ;
#     rdfs:label "United States" .
#
# <https://en.wikipedia.org/wiki/Kingdom_of_W%C3%BCrttemberg> a schema:Country ;
#     rdfs:label "Kingdom of Württemberg" .
#
# <https://en.wikipedia.org/wiki/ Kingdom_of_Prussia> a schema:Country ;
#     rdfs:label "Kingdom of Prussia" .
#
# <https://en.wikipedia.org/wiki/E%3Dmc%5E2> a schema:CreativeWork ;
#     rdfs:label "E = mc²" ;
#     schema:hasPart <https://en.wikipedia.org/wiki/Special_relativity> .
#
# <https://en.wikipedia.org/wiki/Special_relativity> a schema:CreativeWork ;
#     rdfs:label "Special Relativity" .
#
# <https://en.wikipedia.org/wiki/Adolf_Hitler> a schema:Person ;
#     rdfs:label "Adolf Hitler" .
#
# <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt> a schema:Person ;
#     rdfs:label "Franklin D. Roosevelt" .
#
# <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> a schema:CollegeOrUniversity ;
#     rdfs:label "Institute for Advanced Study" .
#
# <https://en.wikipedia.org/wiki/Thomas_Einstein> a schema:Person ;
#     rdfs:label "Thomas Einstein" .
#
# <https://en.wikipedia.org/wiki/Margot_Einstein> a schema:Person ;
#     rdfs:label "Margot Einstein" .
#
# <https://en.wikipedia.org/wiki/Elsa_Einstein> a schema:Person ;
#     rdfs:label "Elsa Einstein" .
#
# <https://en.wikipedia.org/wiki/Hans_Einstein> a schema:Person ;
#     rdfs:label "Hans Einstein" .
#
# <https://en.wikipedia.org/wiki/Natalie_Einstein> a schema:Person ;
#     rdfs:label "Natalie Einstein" .
#
# <https://en.wikipedia.org/wiki/PhD> a schema:EducationalOccupationalCredential ;
#     rdfs:label "Doctor of Philosophy" .
#
# <https://en.wikipedia.org/wiki/Manhattan_Project> a schema:CreativeWork ;
#     rdfs:label "Manhattan Project" .
#
# <#person_albert_einstein> wiki3:hasCitizenship <https://en.wikipedia.org/wiki/Germany>, <https://en.wikipedia.org/wiki/Switzerland>, <https://en.wikipedia.org/wiki/United_States> ;
#     wiki3:hasNationality <https://en.wikipedia.org/wiki/Germany>, <https://en.wikipedia.org/wiki/Switzerland>, <https://en.wikipedia.org/wiki/United_States> ;
#     wiki3:hasResidence <https://en.wikipedia.org/wiki/Bern>, <https://en.wikipedia.org/wiki/Berlin>, <https://en.wikipedia.org/wiki/United_States> ;
#     wiki3:isSubjectOf <https://en.wikipedia.org/wiki/Kingdom_of_W%C3%BCrttemberg>, <https://en.wikipedia.org/wiki/ Kingdom_of_Prussia> ;
#     wiki3:isMemberOf <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences>, <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> ;
#     wiki3:isAffiliatedWith <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> ;
#     wiki3:published <https://en.wikipedia.org/wiki/E%3Dmc%5E2>, <https://en.wikipedia.org/wiki/Special_relativity> ;
#     wiki3:receivedAward <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics_1921> ;
#     wiki3:enrolledIn <https://en.wikipedia.org/wiki/Swiss_federal_polytechnic_school> ;
#     wiki3:graduatedFrom <https://en.wikipedia.org/wiki/Swiss_federal_polytechnic_school> ;
#     wiki3:submittedDissertation <https://en.wikipedia.org/wiki/PhD> ;
#     wiki3:endorsedLetterTo <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt> ;
#     wiki3:recommendedResearch <https://en.wikipedia.org/wiki/Manhattan_Project> .
#
# <#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date ;
#     schema:deathDate "1955-04-18"^^xsd:date ;
#     schema:birthPlace <https://en.wikipedia.org/wiki/German_Empire> ;
#     schema:jobTitle "Theoretical physicist" ;
#     schema:award <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics_1921> ;
#     schema:alumniOf <https://en.wikipedia.org/wiki/Swiss_federal_polytechnic_school> ;
#     schema:worksFor <https://en.wikipedia.org/wiki/Swiss_Patent_Office>, <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences>, <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin>, <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute_for_Physics> ;
#     schema:hasCredential <https://en.wikipedia.org/wiki/PhD> ;
#     schema:nationality <https://en.wikipedia.org/wiki/Germany>, <https://en.wikipedia.org/wiki/Switzerland>, <https://en.wikipedia.org/wiki/United_States> ;
#     schema:residence <https://en.wikipedia.org/wiki/Bern>, <https://en.wikipedia.org/wiki/Berlin>, <https://en.wikipedia.org/wiki/United_States> ;
#     schema:subjectOf <https://en.wikipedia.org/wiki/Kingdom_of_W%C3%BCrttemberg>, <https://en.wikipedia.org/wiki/ Kingdom_of_Prussia> ;
#     schema:spouse <https://en.wikipedia.org/wiki/Elsa_Einstein> ;
#     schema:sibling <https://en.wikipedia.org/wiki/Hans_Einstein>, <https://en.wikipedia.org/wiki/Natalie_Einstein> ;
#     schema:award <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics_1921> ;
#     schema:hasOccupation "Theoretical physicist", "Nobel laureate", "Scientist" ;
#     schema:hasPart <https://en.wikipedia.org/wiki/E%3Dmc%5E2> ;
#     schema:relatedTo <https://en.wikipedia.org/wiki/Adolf_Hitler>, <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt> ;
#     schema:hasChild <https://en.wikipedia.org/wiki/Thomas_Einstein>, <https://en.wikipedia.org/wiki/Margot_Einstein> ;
#     schema:affiliation <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> ;
#     schema:hasInterest "Relativity", "Quantum mechanics", "Nuclear physics" .
#
# <https://en.wikipedia.org/wiki/German_Empire> a schema:Country ;
#     rdfs:label "German Empire" .
#
# <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics_1921> a schema:Award ;
#     rdfs:label "Nobel Prize in Physics 1921" ;
#     schema:year "1921"^^xsd:gYear .
#
# <https://en.wikipedia.org/wiki/Swiss_federal_polytechnic_school> a schema:CollegeOrUniversity ;
#     rdfs:label "Swiss Federal Polytechnic School" .
#
# <https://en.wikipedia.org/wiki/Swiss_Patent_Office> a schema:Organization ;
#     rdfs:label "Swiss Patent Office" .
#
# <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> a schema:Organization ;
#     rdfs:label "Prussian Academy of Sciences" .
#
# <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> a schema:CollegeOrUniversity ;
#     rdfs:label "Humboldt University of Berlin" .
#
# <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute_for_Physics> a schema:Organization ;
#     rdfs:label "Kaiser Wilhelm Institute for Physics" .
#
# <https://en.wikipedia.org/wiki/United_States> a schema:Country ;
#     rdfs:label "United States" .
#
# <https://en.wikipedia.org/wiki/Kingdom_of_W%C3%BCrttemberg> a schema:Country ;
#     rdfs:label "Kingdom of Württemberg" .
#
# <https://en.wikipedia.org/wiki/ Kingdom_of_Prussia> a schema:Country ;
#     rdfs:label "Kingdom of Prussia" .
#
# <https://en.wikipedia.org/wiki/E%3Dmc%5E2> a schema:CreativeWork ;
#     rdfs:label "E = mc²" ;
#     schema:hasPart <https://en.wikipedia.org/wiki/Special_relativity> .
#
# <https://en.wikipedia.org/wiki/Special_relativity> a schema:CreativeWork ;
#     rdfs:label "Special Relativity" .
#
# <https://en.wikipedia.org/wiki/Adolf_Hitler> a schema:Person ;
#     rdfs:label "Adolf Hitler" .
#
# <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt> a schema:Person ;
#     rdfs:label "Franklin D. Roosevelt" .
#
# <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> a schema:CollegeOrUniversity ;
#     rdfs:label "Institute for Advanced Study" .
#
# <https://en.wikipedia.org/wiki/Thomas_Einstein> a schema:Person ;
#     rdfs:label "Thomas Einstein" .
#
# <https://en.wikipedia.org/wiki/Margot_Einstein> a schema:Person ;
#     rdfs:label "Margot Einstein" .
#
# <https://en.wikipedia.org/wiki/Elsa_Einstein> a schema:Person ;
#     rdfs:label "Elsa Einstein" .
#
# <https://en.wikipedia.org/wiki/Hans_Einstein> a schema:Person ;
#     rdfs:label "Hans Einstein" .
#
# <https://en.wikipedia.org/wiki/Natalie_Einstein> a schema:Person ;
#     rdfs:label "Natalie Einstein" .
#
# <https://en.wikipedia.org/wiki/PhD> a schema:EducationalOccupationalCredential ;
#     rdfs:label "Doctor of Philosophy" .
#
# <https://en.wikipedia.org/wiki/Manhattan_Project> a schema:CreativeWork ;
#     rdfs:label "Manhattan Project" .
#
# <#person_albert_einstein> wiki3:hasCitizenship <https://en.wikipedia.org/wiki/Germany>, <https://en.wikipedia.org/wiki/Switzerland>, <https://en.wikipedia.org/wiki/United_States> ;
#     wiki3:hasNationality <https://en.wikipedia.org/wiki/Germany>, <https://en.wikipedia.org/wiki/Switzerland>, <https://en.wikipedia.org/wiki/United_States> ;
#     wiki3:hasResidence <https://en.wikipedia.org/wiki/Bern>, <https://en.wikipedia.org/wiki/Berlin>, <https://en.wikipedia.org/wiki/United_States> ;
#     wiki3:isSubjectOf <https://en.wikipedia.org/wiki/Kingdom_of_W%C3%BCrttemberg>, <https://en.wikipedia.org/wiki/ Kingdom_of_Prussia> ;
#     wiki3:isMemberOf <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences>, <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> ;
#     wiki3:isAffiliatedWith <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> ;
#     wiki3:published <https://en.wikipedia.org/wiki/E%3Dmc%5E2>, <https://en.wikipedia.org/wiki/Special_relativity> ;
#     wiki3:receivedAward <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics_1921> ;
#     wiki3:enrolledIn <https://en.wikipedia.org/wiki/Swiss_federal_polytechnic_school> ;
#     wiki3:graduatedFrom <https://en.wikipedia.org/wiki/Swiss_federal_polytechnic_school> ;
#     wiki3:submittedDissertation <https://en.wikipedia.org/wiki/PhD> ;
#     wiki3:endorsedLetterTo <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt> ;
#     wiki3:recommendedResearch <https://en.wikipedia.org/wiki/Manhattan_Project> .

# %% [raw]
# # Chunk 2
# # Context: Albert Einstein > Introduction
#
# <#person_albert_einstein> schema:jobTitle "Physicist" ;
#     rdfs:label "Albert Einstein" .
#
# <#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date ;
#     schema:birthPlace <#place_ulm> .
#
# <#person_albert_einstein> wiki3:contributedTo <#work_photoelectric_effect> ;
#     wiki3:contributedTo <#work_brownian_motion> ;
#     wiki3:contributedTo <#work_special_relativity> ;
#     wiki3:contributedTo <#work_mass_energy_equivalence> .
#
# <#work_photoelectric_effect> rdfs:label "Theory of the Photoelectric Effect" ;
#     schema:datePublished "1905"^^xsd:gYear ;
#     schema:author <#person_albert_einstein> .
#
# <#work_brownian_motion> rdfs:label "Explanation of Brownian Motion" ;
#     schema:datePublished "1905"^^xsd:gYear ;
#     schema:author <#person_albert_einstein> .
#
# <#work_special_relativity> rdfs:label "Special Theory of Relativity" ;
#     schema:datePublished "1905"^^xsd:gYear ;
#     schema:author <#person_albert_einstein> .
#
# <#work_mass_energy_equivalence> rdfs:label "Mass-Energy Equivalence" ;
#     schema:datePublished "1905"^^xsd:gYear ;
#     schema:author <#person_albert_einstein> .
#
# <#work_general_relativity_proposed> rdfs:label "General Theory of Relativity (Proposed)" ;
#     schema:datePublished "1915"^^xsd:gYear ;
#     schema:author <#person_albert_einstein> .
#
# <#work_general_relativity_universe> rdfs:label "General Relativity and Universe Structure" ;
#     schema:datePublished "1916"^^xsd:gYear ;
#     schema:author <#person_albert_einstein> .
#
# <#work_cosmological_constant> rdfs:label "Cosmological Constant Paper" ;
#     schema:datePublished "1916"^^xsd:gYear ;
#     schema:author <#person_albert_einstein> .
#
# <#work_spontaneous_stimulated_emission> rdfs:label "Spontaneous and Stimulated Emission" ;
#     schema:datePublished "1917"^^xsd:gYear ;
#     schema:author <#person_albert_einstein> .
#
# <#work_quantum_physics_radiation> rdfs:label "Quantum Physics of Radiation" ;
#     schema:datePublished "1905"^^xsd:gYear ;
#     schema:author <#person_albert_einstein> .
#
# <#work_bose_einstein_statistics> rdfs:label "Bose–Einstein Statistics" ;
#     schema:datePublished "1924"^^xsd:gYear ;
#     schema:author <#person_albert_einstein> ;
#     wiki3:coAuthor <#person_satyendra_nath_bose> .
#
# <#person_satyendra_nath_bose> rdfs:label "Satyendra Nath Bose" ;
#     schema:jobTitle "Physicist" .
#
# <#work_unified_field_theory> rdfs:label "Unified Field Theory" ;
#     schema:datePublished "1940s"^^xsd:gYear ;
#     schema:author <#person_albert_einstein> .
#
# <#person_albert_einstein> wiki3:advocatedAgainst "Quantum randomness" ;
#     wiki3:quoted "God does not play dice." .
#
# <#person_albert_einstein> wiki3:becameIsolatedFrom "Mainstream modern physics" ;
#     wiki3:reasonForIsolation "Unsuccessful attempts at unified field theory" .
#
# <#place_ulm> rdfs:label "Ulm, Germany" ;
#     schema:addressCountry <#country_germany> .
#
# <#country_germany> rdfs:label "Germany" .

# %% [raw]
# # Chunk 3
# # Context: Albert Einstein > Life and career
#
# <#person_albert_einstein> a schema:Person ;
#     schema:birthDate "1879-03-14"^^xsd:date ;
#     schema:birthPlace <#place_ulm> ;
#     schema:parent <#person_hermann_einstein>, <#person_pauline_koch> ;
#     schema:alumniOf <#school_st_peters_catholic_elementary_school>, <#school_luitpold_gymnasium> .
#
# <#place_ulm> a schema:Place ;
#     rdfs:label "Ulm"@en .
#
# <#person_hermann_einstein> a schema:Person ;
#     rdfs:label "Hermann Einstein"@en ;
#     schema:occupation <#occupation_salesman>, <#occupation_engineer> .
#
# <#person_pauline_koch> a schema:Person ;
#     rdfs:label "Pauline Koch"@en ;
#     schema:children <#person_albert_einstein> .
#
# <#occupation_salesman> a schema:Occupation ;
#     rdfs:label "Salesman"@en .
#
# <#occupation_engineer> a schema:Occupation ;
#     rdfs:label "Engineer"@en .
#
# <#school_st_peters_catholic_elementary_school> a schema:EducationalOrganization ;
#     rdfs:label "St. Peter's Catholic elementary school"@en .
#
# <#school_luitpold_gymnasium> a schema:EducationalOrganization ;
#     rdfs:label "Luitpold Gymnasium"@en .
#
# <#company_einstein_cie> a schema:Organization ;
#     rdfs:label "Elektrotechnische Fabrik J. Einstein & Cie"@en ;
#     schema:founder <#person_hermann_einstein>, <#person_jakob_einstein> ;
#     schema:location <#place_munich> ;
#     schema:knowsAbout "electrical equipment based on direct current"@en .
#
# <#person_jakob_einstein> a schema:Person ;
#     rdfs:label "Jakob Einstein"@en .
#
# <#place_munich> a schema:Place ;
#     rdfs:label "Munich"@en .
#
# <#event_family_move_to_munich> a wiki3:LifeEvent ;
#     rdfs:label "Family moved to Munich"@en ;
#     schema:startDate "1880"^^xsd:gYear ;
#     schema:location <#place_munich> .
#
# <#event_first_compass> a wiki3:LifeEvent ;
#     rdfs:label "First compass received"@en ;
#     schema:startDate "1880"^^xsd:gYear ;
#     schema:location <#place_munich> ;
#     schema:participant <#person_albert_einstein> .
#
# <#event_learning_disability_concern> a wiki3:LifeEvent ;
#     rdfs:label "Concern about learning disability"@en ;
#     schema:startDate "1880"^^xsd:gYear ;
#     schema:participant <#person_albert_einstein> .

# %% [raw]
# # Chunk 4
# # Context: Albert Einstein > Life and career > Childhood, youth and education
#
# <#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date ;
#     schema:birthPlace <#place_munich> ;
#     rdfs:label "Albert Einstein" .
#
# <#place_munich> rdfs:label "Munich" ;
#     schema:addressCountry <#country_germany> .
#
# <#country_germany> rdfs:label "Germany" .
#
# <#person_hermann_einstein> rdfs:label "Hermann Einstein" ;
#     schema:familyName "Einstein" ;
#     schema:givenName "Hermann" ;
#     wiki3:hasChild <#person_albert_einstein> .
#
# <#person_jakob_einstein> rdfs:label "Jakob Einstein" ;
#     schema:familyName "Einstein" ;
#     schema:givenName "Jakob" ;
#     wiki3:hasChild <#person_albert_einstein> .
#
# <#company_einstein_firm> rdfs:label "Einstein Company" ;
#     wiki3:hasOwner <#person_hermann_einstein> ;
#     wiki3:hasOwner <#person_jakob_einstein> ;
#     wiki3:bidForContract <#contract_munich_electric_lighting> .
#
# <#contract_munich_electric_lighting> rdfs:label "Electric Lighting Contract in Munich" ;
#     schema:contractualRelationship <#company_einstein_firm> ;
#     schema:startDate "1894-01-01"^^xsd:date ;
#     schema:endDate "1894-12-31"^^xsd:date .
#
# <#company_einstein_firm> schema:hasCapital "Insufficient" ;
#     wiki3:failedToUpgradeTechnology <#technology_ac_current> .
#
# <#technology_ac_current> rdfs:label "Alternating Current Technology" ;
#     schema:description "Technology to replace Direct Current" .
#
# <#company_einstein_firm> wiki3:forcedToSellFactory <#factory_munich> .
#
# <#factory_munich> rdfs:label "Munich Factory" ;
#     schema:address <#place_munich> .
#
# <#person_albert_einstein> wiki3:ageWhenStayingInMunich "15"^^xsd:integer .
#
# <#person_albert_einstein> schema:parent <#person_hermann_einstein> ;
#     schema:parent <#person_jakob_einstein> .
#
# <#person_hermann_einstein> schema:child <#person_albert_einstein> .
#
# <#person_albert_einstein> wiki3:desiredStudyField <#field_electrical_engineering> .
#
# <#field_electrical_engineering> rdfs:label "Electrical Engineering" ;
#     schema:alternateName "Electrical Engineering" .
#
# <#person_albert_einstein> schema:alumniOf <#school_gymnasium_munich> .
#
# <#school_gymnasium_munich> rdfs:label "Gymnasium Munich" ;
#     schema:address <#place_munich> .
#
# <#person_albert_einstein> wiki3:hasPersonalityTrait <#trait_fractious> .
#
# <#trait_fractious> rdfs:label "Fractious" ;
#     schema:description "Disruptive or difficult behavior" .
#
# <#person_albert_einstein> wiki3:dislikedTeachingMethod <#method_rote_learning> .
#
# <#method_rote_learning> rdfs:label "Rote Learning" ;
#     schema:description "Teaching method involving memorization" .
#
# <#person_albert_einstein> wiki3:wroteEssay <#essay_on_ether_in_magnetic_field> .
#
# <#essay_on_ether_in_magnetic_field> rdfs:label "On the Investigation of the State of the Ether in a Magnetic Field" ;
#     schema:dateCreated "1894-01-01"^^xsd:date ;
#     schema:author <#person_albert_einstein> .
#
# <#person_albert_einstein> wiki3:joinedFamilyIn <#place_pavia> .
#
# <#place_pavia> rdfs:label "Pavia" ;
#     schema:addressCountry <#country_italy> .
#
# <#country_italy> rdfs:label "Italy" .
#
# <#person_albert_einstein> wiki3:familyMovedTo <#place_milan> .
#
# <#place_milan> rdfs:label "Milan" ;
#     schema:addressCountry <#country_italy> .
#
# <#person_albert_einstein> wiki3:familySettledIn <#place_palazzo_cornazzani> .
#
# <#place_palazzo_cornazzani> rdfs:label "Palazzo Cornazzani" ;
#     schema:address <#place_pavia> .
#
# <#person_albert_einstein> wiki3:releasedFromCareBy <#authority_luitpold> .
#
# <#authority_luitpold> rdfs:label "Luitpold Authorities" ;
#     schema:address <#place_munich> .
#
# <#person_albert_einstein> wiki3:attendedSchoolIn <#place_munich> .
#
# <#person_albert_einstein> wiki3:completedSchoolingIn <#place_munich> .
#
# <#person_albert_einstein> wiki3:ageAtTimeOfFamilyMove "15"^^xsd:integer .
#
# <#person_albert_einstein> wiki3:residedIn <#place_pavia> ;
#     schema:birthPlace <#place_munich> .

# %% [raw]
# # Chunk 5
# # Context: Albert Einstein > Life and career > Childhood, youth and education
#
# <#person_albert_einstein> schema:knowsAbout <#topic_physics> ;
#     schema:knowsAbout <#topic_mathematics> .
#
# <#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date ;
#     schema:birthPlace <#place_germany> .
#
# <#person_max_talmud> a schema:Person ;
#     rdfs:label "Max Talmud" .
#
# <#person_albert_einstein> wiki3:hasTutor <#person_max_talmud> .
#
# <#person_max_talmud> schema:hasOccupation <#occupation_tutor> ;
#     rdfs:label "Tutor" .
#
# <#person_albert_einstein> wiki3:masteredMathematics <#topic_calculus> ;
#     schema:age "14"^^xsd:integer .
#
# <#person_albert_einstein> wiki3:discoveredProof <#theorem_pythagorean> ;
#     schema:age "12"^^xsd:integer .
#
# <#person_albert_einstein> wiki3:taughtHimself <#topic_algebra> ;
#     schema:age "12"^^xsd:integer .
#
# <#person_albert_einstein> wiki3:taughtHimself <#topic_calculus> ;
#     schema:age "12"^^xsd:integer .
#
# <#person_albert_einstein> wiki3:taughtHimself <#topic_geometry> ;
#     schema:age "12"^^xsd:integer .
#
# <#person_albert_einstein> wiki3:loved <#topic_algebra> ;
#     schema:age "12"^^xsd:integer .
#
# <#person_albert_einstein> wiki3:loved <#topic_geometry> ;
#     schema:age "12"^^xsd:integer .
#
# <#person_max_talmud> wiki3:said <#statement_1> ;
#     rdfs:label "Statement about Einstein's early mathematical skills" .
#
# <#statement_1> a wiki3:Quote ;
#     rdfs:label "Max Talmud's statement about Einstein" ;
#     wiki3:content "Albert Einstein worked through an entire geometry textbook very quickly." .
#
# <#person_max_talmud> wiki3:said <#statement_2> ;
#     rdfs:label "Statement about Einstein's higher mathematics devotion" .
#
# <#statement_2> a wiki3:Quote ;
#     rdfs:label "Max Talmud's statement about Einstein's devotion to higher mathematics" ;
#     wiki3:content "Albert Einstein devoted himself to higher mathematics after reading the geometry book." .
#
# <#person_max_talmud> wiki3:said <#statement_3> ;
#     rdfs:label "Statement about Einstein's mathematical genius" .
#
# <#statement_3> a wiki3:Quote ;
#     rdfs:label "Max Talmud's statement about Einstein's mathematical genius" ;
#     wiki3:content "Albert Einstein's mathematical genius was so advanced that he could not follow it." .
#
# <#topic_physics> a schema:Thing ;
#     rdfs:label "Physics" .
#
# <#topic_mathematics> a schema:Thing ;
#     rdfs:label "Mathematics" .
#
# <#topic_calculus> a schema:Thing ;
#     rdfs:label "Calculus" .
#
# <#topic_algebra> a schema:Thing ;
#     rdfs:label "Algebra" .
#
# <#topic_geometry> a schema:Thing ;
#     rdfs:label "Geometry" .
#
# <#theorem_pythagorean> a schema:Thing ;
#     rdfs:label "Pythagorean Theorem" .
#
# <#place_germany> a schema:Place ;
#     rdfs:label "Germany" .
#
# <#occupation_tutor> a schema:Occupation ;
#     rdfs:label "Tutor" .

# %% [raw]
# # Chunk 6
# # Context: Albert Einstein > Life and career > Childhood, youth and education
#
# <#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date ;
#     schema:birthPlace <#place_germany> ;
#     rdfs:label "Albert Einstein" .
#
# <#person_albert_einstein> wiki3:hadRelationshipWith <#person_marie_winteler> ;
#     rdfs:label "Albert Einstein fell in love with Marie Winteler" .
#
# <#person_marie_winteler> rdfs:label "Marie Winteler" .
#
# <#person_paul_winteler> rdfs:label "Paul Winteler" .
#
# <#person_maja_einstein> rdfs:label "Maja Einstein" .
#
# <#person_albert_einstein> wiki3:marriedTo <#person_paul_winteler> ;
#     rdfs:label "Albert Einstein's sister Maja married Paul Winteler" .
#
# <#person_albert_einstein> wiki3:attended <#school_argovian_cantonal_school> ;
#     rdfs:label "Albert Einstein attended Argovian Cantonal School" .
#
# <#school_argovian_cantonal_school> rdfs:label "Argovian Cantonal School" ;
#     schema:alumniOf <#person_albert_einstein> .
#
# <#person_albert_einstein> schema:alumniOf <#school_argovian_cantonal_school> ;
#     rdfs:label "Albert Einstein graduated from Argovian Cantonal School" .
#
# <#school_argovian_cantonal_school> schema:graduationDate "1896"^^xsd:gYear ;
#     rdfs:label "Graduation from Argovian Cantonal School in 1896" .
#
# <#person_albert_einstein> wiki3:tookEntranceExamFor <#institution_federal_polytechnic_school> ;
#     rdfs:label "Albert Einstein sat entrance examination for Federal Polytechnic School" .
#
# <#institution_federal_polytechnic_school> rdfs:label "Federal Polytechnic School in Zurich" .
#
# <#person_albert_einstein> schema:birthDate "1895-01-01"^^xsd:date ;
#     rdfs:label "Albert Einstein at age 16 in 1895" .
#
# <#person_albert_einstein> wiki3:failedGeneralPartOfEntranceExam <#institution_federal_polytechnic_school> ;
#     rdfs:label "Albert Einstein failed general part of entrance exam" .
#
# <#person_albert_einstein> wiki3:excelledInPhysicsAndMathematics <#institution_federal_polytechnic_school> ;
#     rdfs:label "Albert Einstein excelled in physics and mathematics on entrance exam" .
#
# <#person_albert_einstein> wiki3:studiedPhilosophy <#person_immanuel_kant> ;
#     rdfs:label "Albert Einstein studied Kant's Critique of Pure Reason" .
#
# <#person_immanuel_kant> rdfs:label "Immanuel Kant" .
#
# <#person_albert_einstein> wiki3:favoritePhilosopher <#person_immanuel_kant> ;
#     rdfs:label "Kant became Albert Einstein's favorite philosopher" .
#
# <#person_albert_einstein> wiki3:understoodKantBetterThanOthers <#person_immanuel_kant> ;
#     rdfs:label "Albert Einstein understood Kant's works better than ordinary people" .
#
# <#place_germany> rdfs:label "Germany" .

# %% [raw]
# # Chunk 7
# # Context: Albert Einstein > Life and career > Childhood, youth and education
#
# <#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date ;
#     schema:birthPlace <#place_ulm> ;
#     rdfs:label "Albert Einstein" .
#
# <#person_mileva_marić> a schema:Person ;
#     rdfs:label "Mileva Marić" .
#
# <#person_marcel_grossmann> a schema:Person ;
#     rdfs:label "Marcel Grossmann" .
#
# <#person_marie_winteler> a schema:Person ;
#     rdfs:label "Marie Winteler" .
#
# <#place_ulm> a schema:Place ;
#     rdfs:label "Ulm, Germany" .
#
# <#place_olsberg> a schema:Place ;
#     rdfs:label "Olsberg, Switzerland" .
#
# <#institution_federal_polytechnic_school> a schema:CollegeOrUniversity ;
#     rdfs:label "Federal Polytechnic School" .
#
# <#person_albert_einstein> schema:nationality <#country_germany> ;
#     schema:alumniOf <#institution_federal_polytechnic_school> ;
#     schema:worksFor <#institution_federal_polytechnic_school> .
#
# <#country_germany> a schema:Country ;
#     rdfs:label "Germany" .
#
# <#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date ;
#     schema:birthPlace <#place_ulm> ;
#     rdfs:label "Albert Einstein" .
#
# <#person_albert_einstein> wiki3:renouncedCitizenship <#country_württemberg> ;
#     schema:alumniOf <#institution_federal_polytechnic_school> .
#
# <#country_württemberg> a schema:Country ;
#     rdfs:label "Kingdom of Württemberg" .
#
# <#person_albert_einstein> wiki3:earnedMatura "1896-09"^^xsd:date ;
#     schema:alumniOf <#institution_federal_polytechnic_school> .
#
# <#person_albert_einstein> wiki3:enrolledInProgram "1896-09"^^xsd:date ;
#     schema:alumniOf <#institution_federal_polytechnic_school> .
#
# <#person_albert_einstein> schema:knows <#person_marcel_grossmann> ;
#     schema:knows <#person_mileva_marić> .
#
# <#person_mileva_marić> schema:alumniOf <#institution_federal_polytechnic_school> ;
#     schema:worksFor <#institution_federal_polytechnic_school> .
#
# <#person_marie_winteler> schema:worksFor <#place_olsberg> .
#
# <#person_albert_einstein> wiki3:becameLoverOf <#person_mileva_marić> .
#
# <#person_albert_einstein> wiki3:discussedPhysicsWith <#person_mileva_marić> .
#
# <#person_albert_einstein> wiki3:hadCorrespondenceWith <#person_mileva_marić> .
#
# <#person_albert_einstein> wiki3:statedInLetterTo <#person_mileva_marić> "exploring science with her was more enjoyable than reading textbooks alone" .
#
# <#person_mileva_marić> schema:birthDate "1875-07-23"^^xsd:date ;
#     schema:nationality <#country_serbia> .
#
# <#country_serbia> a schema:Country ;
#     rdfs:label "Serbia" .
#
# <#person_mileva_marić> wiki3:wasFreshmanInProgram <#institution_federal_polytechnic_school> ;
#     wiki3:wasAmongFiveFreshmen <#institution_federal_polytechnic_school> .
#
# <#person_albert_einstein> wiki3:spentTimeDiscussingPhysicsWith <#person_mileva_marić> .
#
# <#person_albert_einstein> wiki3:believedMilevaInfluencedHisWork true ;
#     wiki3:historiansDisagreeAboutMilevaContribution true .

# %% [raw]
# # Chunk 8
# # Context: Albert Einstein > Life and career > Marriages, relationships and children
#
# <#person_albert_einstein> schema:knows <#person_mileva_marić> .
# <#person_albert_einstein> schema:knows <#person_elsa_lowenthal> .
# <#person_albert_einstein> schema:knows <#person_betty_neumann> .
# <#person_albert_einstein> schema:knows <#person_marie_winteler> .
# <#person_mileva_marić> schema:birthPlace <#place_novi_sad> .
# <#person_mileva_marić> rdfs:label "Mileva Marić" .
# <#person_elsa_lowenthal> rdfs:label "Elsa Löwenthal" .
# <#person_betty_neumann> rdfs:label "Betty Neumann" .
# <#person_marie_winteler> rdfs:label "Marie Winteler" .
# <#person_lieserl_einstein> rdfs:label "Lieserl Einstein" ;
#     schema:birthDate "1902-01-01"^^xsd:date ;
#     schema:birthPlace <#place_novi_sad> .
# <#person_hans_albert_einstein> rdfs:label "Hans Albert Einstein" ;
#     schema:birthDate "1904-05-01"^^xsd:date ;
#     schema:birthPlace <#place_bern> .
# <#person_eduard_einstein> rdfs:label "Eduard Einstein" ;
#     schema:birthDate "1910-07-01"^^xsd:date ;
#     schema:birthPlace <#place_zurich> .
# <#person_albert_einstein> schema:spouse <#person_mileva_marić> .
# <#person_albert_einstein> schema:spouse <#person_elsa_lowenthal> .
# <#person_mileva_marić> schema:spouse <#person_albert_einstein> .
# <#person_elsa_lowenthal> schema:spouse <#person_albert_einstein> .
# <#person_lieserl_einstein> wiki3:childOf <#person_albert_einstein> .
# <#person_lieserl_einstein> wiki3:childOf <#person_mileva_marić> .
# <#person_hans_albert_einstein> wiki3:childOf <#person_albert_einstein> .
# <#person_hans_albert_einstein> wiki3:childOf <#person_mileva_marić> .
# <#person_eduard_einstein> wiki3:childOf <#person_albert_einstein> .
# <#person_eduard_einstein> wiki3:childOf <#person_mileva_marić> .
# <#person_albert_einstein> wiki3:divorcedFrom <#person_mileva_marić> .
# <#person_mileva_marić> wiki3:divorcedFrom <#person_albert_einstein> .
# <#person_mileva_marić> wiki3:childOf <#person_marić_parents> .
# <#person_marić_parents> rdfs:label "Marić Parents" .
# <#person_elsa_lowenthal> wiki3:cousinOf <#person_albert_einstein> .
# <#person_mileva_marić> wiki3:marriedTo <#person_albert_einstein> ;
#     schema:birthDate "1897-07-27"^^xsd:date .
# <#person_elsa_lowenthal> schema:birthDate "1876-07-26"^^xsd:date ;
#     schema:birthPlace <#place_berlin> .
# <#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date ;
#     schema:birthPlace <#place_ulm> .
# <#person_mileva_marić> wiki3:relationWith <#person_albert_einstein> ;
#     schema:birthDate "1897-07-27"^^xsd:date ;
#     schema:birthPlace <#place_novi_sad> .
# <#person_elsa_lowenthal> wiki3:relationWith <#person_albert_einstein> ;
#     schema:birthDate "1876-07-26"^^xsd:date ;
#     schema:birthPlace <#place_berlin> .
# <#person_betty_neumann> wiki3:relationWith <#person_albert_einstein> .
# <#person_marie_winteler> wiki3:relationWith <#person_albert_einstein> .
# <#person_albert_einstein> wiki3:divorceDate "1919-02-14"^^xsd:date .
# <#person_mileva_marić> wiki3:divorceDate "1919-02-14"^^xsd:date .
# <#person_albert_einstein> wiki3:divorceGrounds "living apart for five years" .
# <#person_mileva_marić> wiki3:divorceGrounds "living apart for five years" .
# <#person_albert_einstein> wiki3:agreedToGiveNobelPrizeMoneyTo <#person_mileva_marić> .
# <#person_albert_einstein> schema:award <#award_nobel_prize_in_physics_1921> .
# <#award_nobel_prize_in_physics_1921> rdfs:label "Nobel Prize in Physics 1921" ;
#     schema:awardDate "1921-01-01"^^xsd:date .
# <#person_albert_einstein> wiki3:marriedTo <#person_elsa_lowenthal> ;
#     schema:birthDate "1879-03-14"^^xsd:date .
# <#person_elsa_lowenthal> wiki3:marriedTo <#person_albert_einstein> ;
#     schema:birthDate "1876-07-26"^^xsd:date ;
#     schema:birthPlace <#place_berlin> .
# <#person_elsa_lowenthal> wiki3:diagnosedWith <#condition_heart_and_kidney_problems> ;
#     schema:deathDate "1936-12-01"^^xsd:date .
# <#condition_heart_and_kidney_problems> rdfs:label "Heart and kidney problems" .
# <#person_albert_einstein> wiki3:emigratedTo <#place_united_states> ;
#     schema:deathDate "1955-04-18"^^xsd:date .
# <#place_united_states> rdfs:label "United States" .
# <#place_novi_sad> rdfs:label "Novi Sad" .
# <#place_bern> rdfs:label "Bern" .
# <#place_zurich> rdfs:label "Zurich" .
# <#place_berlin> rdfs:label "Berlin" .
# <#place_ulm> rdfs:label "Ulm" .

# %% [raw]
# # Chunk 9
# # Context: Albert Einstein > Life and career > Marriages, relationships and children
#
# <#person_albert_einstein> schema:spouse <#person_mileva_marić> ;
#     schema:birthDate "1879-03-14"^^xsd:date ;
#     schema:birthPlace <#place_ulanator> ;
#     rdfs:label "Albert Einstein" .
#
# <#person_mileva_marić> a schema:Person ;
#     rdfs:label "Mileva Marić" .
#
# <#person_elsa_lowenthal> a schema:Person ;
#     rdfs:label "Elsa Löwenthal" .
#
# <#person_margarete_lebach> a schema:Person ;
#     rdfs:label "Margarete Lebach" .
#
# <#person_estella_katzenellenbogen> a schema:Person ;
#     rdfs:label "Estella Katzenellenbogen" .
#
# <#person_toni_mendel> a schema:Person ;
#     rdfs:label "Toni Mendel" .
#
# <#person_ethel_michanowski> a schema:Person ;
#     rdfs:label "Ethel Michanowski" .
#
# <#person_margarita_konenkova> a schema:Person ;
#     rdfs:label "Margarita Konenkova" .
#
# <#person_sergei_konenkov> a schema:Person ;
#     rdfs:label "Sergei Konenkov" .
#
# <#person_eduard_einstein> a schema:Person ;
#     rdfs:label "Eduard Einstein" .
#
# <#place_ulanator> a schema:Place ;
#     rdfs:label "Ulm" .
#
# <#place_princeton> a schema:Place ;
#     rdfs:label "Princeton" .
#
# <#place_zurich> a schema:Place ;
#     rdfs:label "Zurich" .
#
# <#place_berlin> a schema:Place ;
#     rdfs:label "Berlin" .
#
# <#organization_hebrew_university> a schema:Organization ;
#     rdfs:label "Hebrew University of Jerusalem" .
#
# <#organization_institute_for_advanced_study> a schema:Organization ;
#     rdfs:label "Institute for Advanced Study" .
#
# <#person_albert_einstein> schema:spouse <#person_elsa_lowenthal> .
#
# <#person_mileva_marić> schema:marriageEndDate "1919-12-31"^^xsd:date ;
#     schema:marriageStartDate "1903-01-01"^^xsd:date .
#
# <#person_elsa_lowenthal> schema:marriageStartDate "1919-01-01"^^xsd:date ;
#     schema:marriageEndDate "1955-04-18"^^xsd:date .
#
# <#organization_hebrew_university> schema:affiliation <#person_albert_einstein> .
#
# <#person_albert_einstein> wiki3:romanticRelationshipWith <#person_margarete_lebach> ;
#     wiki3:romanticRelationshipWith <#person_estella_katzenellenbogen> ;
#     wiki3:romanticRelationshipWith <#person_toni_mendel> ;
#     wiki3:romanticRelationshipWith <#person_ethel_michanowski> .
#
# <#person_margarete_lebach> schema:maritalStatus "Married" ;
#     schema:nationality "Austrian" .
#
# <#person_estella_katzenellenbogen> schema:owns <#business_florist> .
#
# <#business_florist> a schema:Organization ;
#     rdfs:label "Florist business" .
#
# <#person_toni_mendel> schema:affiliation <#organization_hebrew_university> .
#
# <#person_ethel_michanowski> schema:affiliation <#place_berlin> .
#
# <#person_albert_einstein> wiki3:romanticRelationshipWith <#person_margarita_konenkova> ;
#     schema:spouse <#person_margarita_konenkova> .
#
# <#person_margarita_konenkova> wiki3:associatedWith <#person_sergei_konenkov> ;
#     schema:nationality "Russian" .
#
# <#person_sergei_konenkov> schema:affiliation <#organization_institute_for_advanced_study> ;
#     schema:hasPart <#artwork_bronze_bust_einstein> .
#
# <#artwork_bronze_bust_einstein> a schema:CreativeWork ;
#     rdfs:label "Bronze bust of Albert Einstein" .
#
# <#person_eduard_einstein> schema:parent <#person_albert_einstein> ;
#     schema:diagnosis <#condition_schizophrenia> .
#
# <#condition_schizophrenia> a schema:MedicalCondition ;
#     rdfs:label "Schizophrenia" .
#
# <#person_eduard_einstein> schema:residence <#place_zurich> ;
#     schema:residence <#place_princeton> .
#
# <#person_eduard_einstein> schema:affiliation <#organization_institute_for_advanced_study> ;
#     schema:affiliation <#place_zurich> .
#
# <#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
#
# <#person_eduard_einstein> schema:deathDate "1965-04-07"^^xsd:date ;
#     schema:residence <#place_zurich> .
#
# <#place_zurich> schema:affiliation <#organization_burgholzli> .
#
# <#organization_burgholzli> a schema:Organization ;
#     rdfs:label "Psychiatric University Hospital Burghölzli" .
#
# <#person_eduard_einstein> schema:affiliation <#organization_burgholzli> .

# %% [raw]
# # Chunk 10
# # Context: Albert Einstein > Life and career > Assistant at the Swiss Patent Office (1902–1909)
#
# <#person_albert_einstein> schema:alumniOf <#organization_federal_polytechnic_school> .
# <#organization_federal_polytechnic_school> rdfs:label "Federal Polytechnic School" .
# <#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <#person_albert_einstein> schema:nationality <#country_switzerland> .
# <#country_switzerland> rdfs:label "Switzerland" .
# <#person_albert_einstein> schema:workFor <#organization_swiss_patent_office> .
# <#organization_swiss_patent_office> rdfs:label "Swiss Patent Office" .
# <#person_albert_einstein> schema:jobTitle "Assistant Examiner" .
# <#person_albert_einstein> schema:startDate "1902-01-01"^^xsd:date .
# <#person_albert_einstein> schema:endDate "1909-12-31"^^xsd:date .
# <#person_albert_einstein> schema:award <#award_permanent_position> .
# <#award_permanent_position> rdfs:label "Permanent Position" .
# <#person_albert_einstein> schema:hasOccupation <#occupation_teacher> .
# <#occupation_teacher> rdfs:label "Teacher" .
# <#person_albert_einstein> schema:hasOccupation <#occupation_patent_examiner> .
# <#occupation_patent_examiner> rdfs:label "Patent Examiner" .
# <#person_albert_einstein> wiki3:patentEvaluation <#patent_gravel_sorter> .
# <#patent_gravel_sorter> rdfs:label "Gravel Sorter Patent" .
# <#person_albert_einstein> wiki3:patentEvaluation <#patent_electric_typewriter> .
# <#patent_electric_typewriter> rdfs:label "Electric Typewriter Patent" .
# <#person_albert_einstein> wiki3:formedGroup <#group_olympia_academy> .
# <#group_olympia_academy> rdfs:label "Olympia Academy" .
# <#group_olympia_academy> wiki3:meetingTopic "Science and Philosophy" .
# <#group_olympia_academy> wiki3:member <#person_marie_curie_marić> .
# <#person_marie_curie_marić> rdfs:label "Marie Curie (Marić)" .
# <#group_olympia_academy> wiki3:influencedBy <#person_henri_poincaré> .
# <#person_henri_poincaré> rdfs:label "Henri Poincaré" .
# <#group_olympia_academy> wiki3:influencedBy <#person_ernst_mach> .
# <#person_ernst_mach> rdfs:label "Ernst Mach" .
# <#group_olympia_academy> wiki3:influencedBy <#person_david_hume> .
# <#person_david_hume> rdfs:label "David Hume" .
# <#person_albert_einstein> wiki3:influencedBy <#person_henri_poincaré> .
# <#person_albert_einstein> wiki3:influencedBy <#person_ernst_mach> .
# <#person_albert_einstein> wiki3:influencedBy <#person_david_hume> .
# <#person_albert_einstein> schema:birthPlace <#place_ulan_bator> .
# <#place_ulan_bator> rdfs:label "Ulan Bator" .

# %% [raw]
# # Chunk 11
# # Context: Albert Einstein > Life and career > First scientific papers (1900–1905)
#
# <#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date ;
#     schema:birthPlace <https://en.wikipedia.org/wiki/Ulm> ;
#     rdfs:label "Albert Einstein" .
#
# <#person_marcel_grossmann> a schema:Person ;
#     rdfs:label "Marcel Grossmann" .
#
# <#work_folgerungen_aus_den_capillaritätserscheinungen> a schema:ScholarlyArticle ;
#     schema:name "Folgerungen aus den Capillaritätserscheinungen" ;
#     schema:datePublished "1901"^^xsd:gYear ;
#     schema:publication <https://en.wikipedia.org/wiki/Annalen_der_Physik> ;
#     schema:author <#person_albert_einstein> ;
#     rdfs:label "Folgerungen aus den Capillaritätserscheinungen" .
#
# <#work_dissertation_on_molecular_dimensions> a schema:Thesis ;
#     schema:name "A New Determination of Molecular Dimensions" ;
#     schema:datePublished "1905"^^xsd:gYear ;
#     schema:author <#person_albert_einstein> ;
#     schema:creator <#person_albert_einstein> ;
#     schema:about <https://en.wikipedia.org/wiki/Molecular_dimension> ;
#     rdfs:label "A New Determination of Molecular Dimensions" .
#
# <#work_photoelectric_effect> a schema:ScholarlyArticle ;
#     schema:name "On a Heuristic Viewpoint Concerning the Production and Transformation of Light" ;
#     schema:datePublished "1905"^^xsd:gYear ;
#     schema:author <#person_albert_einstein> ;
#     rdfs:label "On a Heuristic Viewpoint Concerning the Production and Transformation of Light" .
#
# <#work_brownian_motion> a schema:ScholarlyArticle ;
#     schema:name "On the Movement of Small Particles Suspended in a Stationary Liquid, as Required by the Molecular Kinetic Theory of Heat" ;
#     schema:datePublished "1905"^^xsd:gYear ;
#     schema:author <#person_albert_einstein> ;
#     rdfs:label "On the Movement of Small Particles Suspended in a Stationary Liquid, as Required by the Molecular Kinetic Theory of Heat" .
#
# <#work_special_relativity> a schema:ScholarlyArticle ;
#     schema:name "On the Electrodynamics of Moving Bodies" ;
#     schema:datePublished "1905"^^xsd:gYear ;
#     schema:author <#person_albert_einstein> ;
#     rdfs:label "On the Electrodynamics of Moving Bodies" .
#
# <#work_mass_energy_equivalence> a schema:ScholarlyArticle ;
#     schema:name "Does the Inertia of a Body Depend Upon Its Energy Content?" ;
#     schema:datePublished "1905"^^xsd:gYear ;
#     schema:author <#person_albert_einstein> ;
#     rdfs:label "Does the Inertia of a Body Depend Upon Its Energy Content?" .
#
# <#university_of_zurich> a schema:CollegeOrUniversity ;
#     schema:name "University of Zurich" ;
#     rdfs:label "University of Zurich" .
#
# <#university_of_bern> a schema:CollegeOrUniversity ;
#     schema:name "University of Bern" ;
#     rdfs:label "University of Bern" .
#
# <#university_charles_ferdinand_prague> a schema:CollegeOrUniversity ;
#     schema:name "German Charles-Ferdinand University in Prague" ;
#     rdfs:label "German Charles-Ferdinand University in Prague" .
#
# <#person_alfred_kleiner> a schema:Person ;
#     rdfs:label "Alfred Kleiner" .
#
# <#person_albert_einstein> schema:alumniOf <#university_of_zurich> ;
#     schema:worksFor <#university_of_bern> ;
#     schema:worksFor <#university_charles_ferdinand_prague> ;
#     wiki3:hasDissertation <#work_dissertation_on_molecular_dimensions> ;
#     wiki3:publishedWork <#work_folgerungen_aus_den_capillaritätserscheinungen> ;
#     wiki3:publishedWork <#work_photoelectric_effect> ;
#     wiki3:publishedWork <#work_brownian_motion> ;
#     wiki3:publishedWork <#work_special_relativity> ;
#     wiki3:publishedWork <#work_mass_energy_equivalence> ;
#     wiki3:hasAcademicAdvisor <#person_marcel_grossmann> ;
#     wiki3:awardedPhDBy <#university_of_zurich> ;
#     schema:award <https://en.wikipedia.org/wiki/Annus_mirabilis_(physics)> .
#
# <#work_dissertation_on_molecular_dimensions> schema:dedicatedTo <#person_marcel_grossmann> .
#
# <#person_albert_einstein> schema:award "1905 Annus Mirabilis" ;
#     wiki3:heldPosition <https://en.wikipedia.org/wiki/Junior_teaching_position> ;
#     wiki3:heldPosition <https://en.wikipedia.org/wiki/Associate_professor> ;
#     wiki3:heldPosition <https://en.wikipedia.org/wiki/Full_professor> .
#
# <#person_albert_einstein> schema:hasOccupation <https://en.wikipedia.org/wiki/Physicist> ;
#     schema:hasOccupation <https://en.wikipedia.org/wiki/Scientist> .
#
# <#university_of_zurich> schema:location <https://en.wikipedia.org/wiki/Zurich> ;
#     rdfs:label "University of Zurich" .
#
# <#university_of_bern> schema:location <https://en.wikipedia.org/wiki/Bern> ;
#     rdfs:label "University of Bern" .
#
# <#university_charles_ferdinand_prague> schema:location <https://en.wikipedia.org/wiki/Prague> ;
#     rdfs:label "German Charles-Ferdinand University in Prague" .
#
# <#person_albert_einstein> wiki3:yearOfFirstPublication "1901"^^xsd:gYear ;
#     wiki3:yearOfDoctoralDegreeAwarded "1906"^^xsd:gYear ;
#     wiki3:yearOfAnnusMirabilis "1905"^^xsd:gYear ;
#     wiki3:yearOfHeldPositionAtUniversityOfBern "1908"^^xsd:gYear ;
#     wiki3:yearOfHeldPositionAtUniversityOfZurich "1909"^^xsd:gYear ;
#     wiki3:yearOfPromotionToFullProfessor "1911"^^xsd:gYear ;
#     wiki3:yearOfMovingToPrague "1911"^^xsd:gYear .
#
# <#person_albert_einstein> wiki3:publishedIn <https://en.wikipedia.org/wiki/Annalen_der_Physik> ;
#     wiki3:publishedNumberOfPapersInPrague "11"^^xsd:integer .

# %% [raw]
# # Chunk 12
# # Context: Albert Einstein > Life and career > Academic career in Europe (1908–1933)
#
# <#person_albert_einstein> schema:affiliation <#organization_eth_zurich> ;
#     schema:alumniOf <#organization_eth_zurich> ;
#     schema:birthDate "1879-03-14"^^xsd:date ;
#     schema:birthPlace <#place_germany> ;
#     schema:hasOccupation <#occupation_physicist> ;
#     schema:workLocation <#place_berlin> ;
#     schema:worksFor <#organization_eth_zurich> ;
#     schema:worksFor <#organization_prussian_academy_of_sciences> ;
#     schema:worksFor <#organization_humboldt_university> .
#
# <#event_solvay_conference_1911> a schema:Event ;
#     rdfs:label "Solvay Conference on Physics 1911" ;
#     schema:startDate "1911-10-30"^^xsd:date ;
#     schema:endDate "1911-11-03"^^xsd:date ;
#     schema:location <#place_brussels> ;
#     schema:name "Solvay Conference on Physics 1911" ;
#     schema:organizer <#organization_solvay_institute> .
#
# <#person_albert_einstein> schema:attends <#event_solvay_conference_1911> .
#
# <#organization_eth_zurich> a schema:CollegeOrUniversity ;
#     rdfs:label "ETH Zurich" ;
#     schema:name "ETH Zurich" .
#
# <#organization_prussian_academy_of_sciences> a schema:Organization ;
#     rdfs:label "Prussian Academy of Sciences" ;
#     schema:name "Prussian Academy of Sciences" .
#
# <#organization_humboldt_university> a schema:CollegeOrUniversity ;
#     rdfs:label "Humboldt University of Berlin" ;
#     schema:name "Humboldt University of Berlin" .
#
# <#person_marcel_grossmann> a schema:Person ;
#     rdfs:label "Marcel Grossmann" ;
#     schema:name "Marcel Grossmann" .
#
# <#person_max_planck> a schema:Person ;
#     rdfs:label "Max Planck" ;
#     schema:name "Max Planck" .
#
# <#person_walther_nernst> a schema:Person ;
#     rdfs:label "Walther Nernst" ;
#     schema:name "Walther Nernst" .
#
# <#person_elsa_loewenthal> a schema:Person ;
#     rdfs:label "Elsa Löwenthal" ;
#     schema:name "Elsa Löwenthal" .
#
# <#place_germany> a schema:Place ;
#     rdfs:label "Germany" ;
#     schema:name "Germany" .
#
# <#place_brussels> a schema:Place ;
#     rdfs:label "Brussels" ;
#     schema:name "Brussels" .
#
# <#place_berlin> a schema:Place ;
#     rdfs:label "Berlin" ;
#     schema:name "Berlin" .
#
# <#occupation_physicist> a schema:Occupation ;
#     rdfs:label "Physicist" ;
#     schema:name "Physicist" .
#
# <#organization_solvay_institute> a schema:Organization ;
#     rdfs:label "Solvay Institute" ;
#     schema:name "Solvay Institute" .
#
# <#person_albert_einstein> wiki3:assistedBy <#person_marcel_grossmann> ;
#     schema:memberOf <#organization_prussian_academy_of_sciences> ;
#     schema:member <#organization_prussian_academy_of_sciences> .
#
# <#person_albert_einstein> wiki3:visitedBy <#person_max_planck> ;
#     wiki3:visitedBy <#person_walther_nernst> .
#
# <#person_max_planck> wiki3:visited <#person_albert_einstein> ;
#     wiki3:visited <#organization_eth_zurich> .
#
# <#person_walther_nernst> wiki3:visited <#person_albert_einstein> ;
#     wiki3:visited <#organization_eth_zurich> .
#
# <#person_albert_einstein> schema:startDate "1913-07-24"^^xsd:date ;
#     schema:workLocation <#place_berlin> ;
#     schema:worksFor <#organization_prussian_academy_of_sciences> ;
#     schema:worksFor <#organization_humboldt_university> .
#
# <#person_albert_einstein> wiki3:residedIn <#place_berlin> ;
#     schema:birthDate "1879-03-14"^^xsd:date ;
#     schema:birthPlace <#place_germany> .
#
# <#person_elsa_loewenthal> wiki3:partnerOf <#person_albert_einstein> ;
#     schema:residence <#place_berlin> .
#
# <#organization_eth_zurich> wiki3:teachingArea <#topic_thermodynamics> ;
#     wiki3:teachingArea <#topic_analytical_mechanics> ;
#     wiki3:researchArea <#topic_molecular_theory_of_heat> ;
#     wiki3:researchArea <#topic_continuum_mechanics> ;
#     wiki3:researchArea <#topic_relativistic_theory_of_gravitation> .
#
# <#person_albert_einstein> schema:hasOccupation <#occupation_physicist> ;
#     schema:worksFor <#organization_eth_zurich> .
#
# <#topic_thermodynamics> a schema:Thing ;
#     rdfs:label "Thermodynamics" ;
#     schema:name "Thermodynamics" .
#
# <#topic_analytical_mechanics> a schema:Thing ;
#     rdfs:label "Analytical Mechanics" ;
#     schema:name "Analytical Mechanics" .
#
# <#topic_molecular_theory_of_heat> a schema:Thing ;
#     rdfs:label "Molecular Theory of Heat" ;
#     schema:name "Molecular Theory of Heat" .
#
# <#topic_continuum_mechanics> a schema:Thing ;
#     rdfs:label "Continuum Mechanics" ;
#     schema:name "Continuum Mechanics" .
#
# <#topic_relativistic_theory_of_gravitation> a schema:Thing ;
#     rdfs:label "Relativistic Theory of Gravitation" ;
#     schema:name "Relativistic Theory of Gravitation" .

# %% [raw]
# # Chunk 13
# # Context: Albert Einstein > Life and career > Academic career in Europe (1908–1933)
#
# <#person_albert_einstein> schema:hasOccupation <https://schema.org/Physicist> .
# <#person_albert_einstein> schema:award <#award_nobel_prize_in_physics_1922> .
# <#person_albert_einstein> schema:award <#award_copley_medal_1925> .
# <#person_albert_einstein> schema:award <#award_foreign_member_royal_netherlands_academy_1920> .
# <#person_albert_einstein> schema:award <#award_foreign_member_royal_society_1921> .
# <#person_albert_einstein> schema:award <#award_international_honorary_member_american_academy_arts_sciences_1922> .
# <#person_albert_einstein> schema:award <#award_international_member_american_philosophical_society_1930> .
# <#person_albert_einstein> schema:hasCredential <#degree_phd_physics_1905> .
# <#person_albert_einstein> schema:worksFor <#organization_german_physical_society> .
# <#person_albert_einstein> schema:worksFor <#organization_kaiser_wilhelm_institute_physics> .
# <#person_albert_einstein> schema:worksFor <#organization_royal_society> .
# <#person_albert_einstein> schema:worksFor <#organization_royal_netherlands_academy> .
# <#person_albert_einstein> schema:worksFor <#organization_american_academy_arts_sciences> .
# <#person_albert_einstein> schema:worksFor <#organization_american_philosophical_society> .
# <#person_albert_einstein> schema:worksFor <#organization_ninety_three_manifesto> .
# <#person_albert_einstein> schema:worksFor <#organization_alternative_manifesto_europeans> .
# <#person_albert_einstein> schema:worksFor <#organization_general_relativity_skeptics_1922> .
# <#person_albert_einstein> schema:worksFor <#organization_s_n_bose_1924> .
#
# <#award_nobel_prize_in_physics_1922> a schema:Award ;
#     schema:name "Nobel Prize in Physics" ;
#     schema:startDate "1922-01-01"^^xsd:date ;
#     schema:awardRecipient <#person_albert_einstein> ;
#     schema:description "For services to Theoretical Physics, especially for his discovery of the law of the photoelectric effect" .
#
# <#award_copley_medal_1925> a schema:Award ;
#     schema:name "Copley Medal" ;
#     schema:startDate "1925-01-01"^^xsd:date ;
#     schema:awardRecipient <#person_albert_einstein> .
#
# <#award_foreign_member_royal_netherlands_academy_1920> a schema:Award ;
#     schema:name "Foreign Member of the Royal Netherlands Academy of Arts and Sciences" ;
#     schema:startDate "1920-01-01"^^xsd:date ;
#     schema:awardRecipient <#person_albert_einstein> .
#
# <#award_foreign_member_royal_society_1921> a schema:Award ;
#     schema:name "Foreign Member of the Royal Society" ;
#     schema:startDate "1921-01-01"^^xsd:date ;
#     schema:awardRecipient <#person_albert_einstein> .
#
# <#award_international_honorary_member_american_academy_arts_sciences_1922> a schema:Award ;
#     schema:name "International Honorary Member of the American Academy of Arts and Sciences" ;
#     schema:startDate "1922-01-01"^^xsd:date ;
#     schema:awardRecipient <#person_albert_einstein> .
#
# <#award_international_member_american_philosophical_society_1930> a schema:Award ;
#     schema:name "International Member of the American Philosophical Society" ;
#     schema:startDate "1930-01-01"^^xsd:date ;
#     schema:awardRecipient <#person_albert_einstein> .
#
# <#degree_phd_physics_1905> a schema:Education ;
#     schema:name "PhD in Physics" ;
#     schema:startDate "1905-01-01"^^xsd:date ;
#     schema:alumniOf <#organization_ethz> .
#
# <#organization_german_physical_society> a schema:Organization ;
#     schema:name "German Physical Society" ;
#     rdfs:label "German Physical Society" .
#
# <#organization_kaiser_wilhelm_institute_physics> a schema:Organization ;
#     schema:name "Kaiser Wilhelm Institute for Physics" ;
#     rdfs:label "Kaiser Wilhelm Institute for Physics" .
#
# <#organization_royal_society> a schema:Organization ;
#     schema:name "Royal Society" ;
#     rdfs:label "Royal Society" .
#
# <#organization_royal_netherlands_academy> a schema:Organization ;
#     schema:name "Royal Netherlands Academy of Arts and Sciences" ;
#     rdfs:label "Royal Netherlands Academy of Arts and Sciences" .
#
# <#organization_american_academy_arts_sciences> a schema:Organization ;
#     schema:name "American Academy of Arts and Sciences" ;
#     rdfs:label "American Academy of Arts and Sciences" .
#
# <#organization_american_philosophical_society> a schema:Organization ;
#     schema:name "American Philosophical Society" ;
#     rdfs:label "American Philosophical Society" .
#
# <#organization_ninety_three_manifesto> a schema:Organization ;
#     schema:name "Manifesto of the Ninety-Three" ;
#     rdfs:label "Manifesto of the Ninety-Three" .
#
# <#organization_alternative_manifesto_europeans> a schema:Organization ;
#     schema:name "Alternative 'Manifesto to the Europeans'" ;
#     rdfs:label "Alternative 'Manifesto to the Europeans'" .
#
# <#organization_general_relativity_skeptics_1922> a schema:Organization ;
#     schema:name "General Relativity Skeptics (1922)" ;
#     rdfs:label "General Relativity Skeptics (1922)" .
#
# <#organization_s_n_bose_1924> a schema:Organization ;
#     schema:name "S. N. Bose (1924)" ;
#     rdfs:label "S. N. Bose (1924)" .
#
# <#organization_ethz> a schema:Organization ;
#     schema:name "ETH Zurich" ;
#     rdfs:label "ETH Zurich" .
#
# <#event_einstein_president_german_physical_society_1916> a schema:Event ;
#     schema:name "Election as President of German Physical Society" ;
#     schema:startDate "1916-01-01"^^xsd:date ;
#     schema:organizer <#organization_german_physical_society> ;
#     schema:attendee <#person_albert_einstein> .
#
# <#event_kaiser_wilhelm_institute_opening_1915> a schema:Event ;
#     schema:name "Kaiser Wilhelm Institute for Physics Opens" ;
#     schema:startDate "1915-01-01"^^xsd:date ;
#     schema:location <#place_berlin> ;
#     schema:attendee <#person_albert_einstein> .
#
# <#event_war_outbreak_1914> a schema:Event ;
#     schema:name "Outbreak of World War I" ;
#     schema:startDate "1914-07-01"^^xsd:date .
#
# <#event_manifesto_ninety_three_1914> a schema:Event ;
#     schema:name "Publication of Manifesto of the Ninety-Three" ;
#     schema:startDate "1914-10-01"^^xsd:date .
#
# <#event_einstein_signs_alternative_manifesto_1914> a schema:Event ;
#     schema:name "Einstein signs Alternative Manifesto to Europeans" ;
#     schema:startDate "1914-10-01"^^xsd:date ;
#     schema:organizer <#organization_alternative_manifesto_europeans> ;
#     schema:attendee <#person_albert_einstein> .
#
# <#place_berlin> a schema:Place ;
#     schema:name "Berlin" ;
#     rdfs:label "Berlin" .

# %% [raw]
# # Chunk 14
# # Context: Albert Einstein > Life and career > Academic career in Europe (1908–1933)
#
# <#person_albert_einstein> schema:resignedFrom <#prussian_academy> ;
#     schema:workLocation <#berlin> ;
#     schema:hasOccupation <#physicist> .
#
# <#prussian_academy> a schema:Organization ;
#     rdfs:label "Prussian Academy" .
#
# <#berlin> a schema:Place ;
#     rdfs:label "Berlin" .
#
# <#physicist> a schema:Occupation ;
#     rdfs:label "Physicist" .
#
# <#person_albert_einstein> schema:hasAchievement <#general_relativity> ;
#     schema:hasAchievement <#einstein_de_haas_effect> ;
#     schema:hasAchievement <#quantum_theory_radiation> ;
#     schema:hasAchievement <#bose_einstein_statistics> .
#
# <#general_relativity> a schema:CreativeWork ;
#     rdfs:label "General Theory of Relativity" ;
#     schema:description "General theory of relativity developed by Albert Einstein" .
#
# <#einstein_de_haas_effect> a schema:CreativeWork ;
#     rdfs:label "Einstein–de Haas effect" ;
#     schema:description "Einstein–de Haas effect proven by Albert Einstein" .
#
# <#quantum_theory_radiation> a schema:CreativeWork ;
#     rdfs:label "Quantum theory of radiation" ;
#     schema:description "Contribution to quantum theory of radiation by Albert Einstein" .
#
# <#bose_einstein_statistics> a schema:CreativeWork ;
#     rdfs:label "Bose–Einstein statistics" ;
#     schema:description "Bose–Einstein statistics developed by Albert Einstein" .
#
# <#person_albert_einstein> schema:startDate "1933-03"^^xsd:date ;
#     schema:endDate "1933-03"^^xsd:date ;
#     wiki3:resignedFromPrussianAcademy "true"^^xsd:boolean .

# %% [raw]
# # Chunk 15
# # Context: Albert Einstein > Life and career > Putting general relativity to the test (1919)
#
# <#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <#person_albert_einstein> schema:birthPlace <https://en.wikipedia.org/wiki/Ulm> .
# <#person_albert_einstein> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .
# <#person_albert_einstein> schema:worksFor <https://en.wikipedia.org/wiki/Princeton_University> .
# <#person_albert_einstein> rdfs:label "Albert Einstein" .
#
# <#equivalence_principle> rdfs:label "Equivalence Principle" ;
#     wiki3:formulatedBy <#person_albert_einstein> ;
#     wiki3:formulatedInYear "1907"^^xsd:integer .
#
# <#light_bending_calculation_1911> rdfs:label "Light Bending Calculation (1911)" ;
#     wiki3:formulatedBy <#person_albert_einstein> ;
#     wiki3:formulatedInYear "1911"^^xsd:integer ;
#     wiki3:usedPrinciple <#equivalence_principle> .
#
# <#light_bending_calculation_1913> rdfs:label "Light Bending Calculation (1913)" ;
#     wiki3:formulatedBy <#person_albert_einstein> ;
#     wiki3:formulatedInYear "1913"^^xsd:integer ;
#     wiki3:usedTensor <https://en.wikipedia.org/wiki/Riemann_curvature_tensor> .
#
# <#general_relativity_theory> rdfs:label "General Relativity Theory" ;
#     wiki3:developedBy <#person_albert_einstein> ;
#     wiki3:completedInYear "1915"^^xsd:integer ;
#     wiki3:basedOn <https://en.wikipedia.org/wiki/Riemannian_geometry> .
#
# <#gravitational_lensing_application> rdfs:label "Gravitational Lensing Application" ;
#     wiki3:appliedBy <#person_albert_einstein> ;
#     wiki3:appliedInYear "1915"^^xsd:integer ;
#     wiki3:relatedTo <#general_relativity_theory> .
#
# <#mercury_orbit_precession> rdfs:label "Precession of Mercury's Orbit" ;
#     wiki3:analyzedBy <#person_albert_einstein> ;
#     wiki3:analyzedInYear "1915"^^xsd:integer ;
#     wiki3:relatedTo <#general_relativity_theory> .
#
# <#eclipse_1919> rdfs:label "Solar Eclipse of 29 May 1919" ;
#     wiki3:occurredOn "1919-05-29"^^xsd:date ;
#     wiki3:usedForTesting <#general_relativity_theory> .
#
# <#observation_eddington_1919> rdfs:label "Observation by Sir Arthur Eddington" ;
#     wiki3:conductedBy <https://en.wikipedia.org/wiki/Arthur_Eddington> ;
#     wiki3:conductedOn <#eclipse_1919> ;
#     wiki3:consistentWith <#general_relativity_theory> .
#
# <#news_report_1919> rdfs:label "News Report on Einstein's Theory" ;
#     wiki3:publishedBy <https://en.wikipedia.org/wiki/The_Times> ;
#     wiki3:headline "Revolution in Science – New Theory of the Universe – Newtonian Ideas Overthrown" ;
#     wiki3:publishedOn "1919-11-07"^^xsd:date ;
#     wiki3:about <#general_relativity_theory> .

# %% [raw]
# # Chunk 16
# # Context: Albert Einstein > Life and career > Coming to terms with fame (1921–1923)
#
# <#person_albert_einstein> schema:hasOccupation <#occupation_scientist> .
# <#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <#person_albert_einstein> schema:birthPlace <#place_germany> .
# <#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <#person_albert_einstein> schema:deathPlace <#place_united_states> .
# <#person_albert_einstein> schema:alumniOf <#institution_ethz> .
# <#person_albert_einstein> schema:worksFor <#institution_princeton> .
# <#person_albert_einstein> schema:worksFor <#institution_columbia> .
# <#person_albert_einstein> schema:worksFor <#institution_bpr> .
# <#person_albert_einstein> schema:hasCredential <#degree_phd> .
# <#institution_ethz> rdfs:label "ETH Zurich" .
# <#institution_princeton> rdfs:label "Princeton University" .
# <#institution_columbia> rdfs:label "Columbia University" .
# <#institution_bpr> rdfs:label "Berlin Physical Society" .
# <#occupation_scientist> rdfs:label "Scientist" .
# <#degree_phd> rdfs:label "PhD" .
# <#place_germany> rdfs:label "Germany" .
# <#place_united_states> rdfs:label "United States" .
# <#person_albert_einstein> wiki3:visitedPlace <#place_new_york_city> .
# <#person_albert_einstein> wiki3:visitedPlace <#place_washington_d_c> .
# <#person_albert_einstein> wiki3:visitedPlace <#place_london> .
# <#place_new_york_city> rdfs:label "New York City" .
# <#place_washington_d_c> rdfs:label "Washington, D.C." .
# <#place_london> rdfs:label "London" .
# <#person_john_f_hylan> rdfs:label "John Francis Hylan" .
# <#person_john_f_hylan> schema:hasOccupation <#occupation_mayor> .
# <#occupation_mayor> rdfs:label "Mayor" .
# <#person_john_f_hylan> schema:worksFor <#place_new_york_city> .
# <#person_albert_einstein> wiki3:metPerson <#person_john_f_hylan> .
# <#person_albert_einstein> wiki3:visitedPlace <#place_white_house> .
# <#place_white_house> rdfs:label "White House" .
# <#person_albert_einstein> wiki3:visitedPlace <#place_kings_college_london> .
# <#place_kings_college_london> rdfs:label "King's College London" .
# <#person_albert_einstein> wiki3:visitedPlace <#place_british_scientific_organizations> .
# <#person_albert_einstein> wiki3:visitedPlace <#place_intellectual_organizations> .
# <#person_albert_einstein> wiki3:visitedPlace <#place_political_organizations> .
# <#person_viscount_haldane> rdfs:label "Viscount Haldane" .
# <#person_viscount_haldane> schema:hasOccupation <#occupation_philosopher> .
# <#person_viscount_haldane> schema:hasOccupation <#occupation_statesman> .
# <#occupation_philosopher> rdfs:label "Philosopher" .
# <#occupation_statesman> rdfs:label "Statesman" .
# <#person_albert_einstein> wiki3:metPerson <#person_viscount_haldane> .
# <#person_albert_einstein> schema:hasCredential <#degree_1921> .
# <#degree_1921> rdfs:label "Celebrity Scientist" .
# <#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <#person_albert_einstein> schema:birthPlace <#place_germany> .
# <#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <#person_albert_einstein> schema:deathPlace <#place_united_states> .
# <#person_albert_einstein> wiki3:timeInAmerica "1921-04-02"^^xsd:date .
# <#person_albert_einstein> wiki3:timeInAmerica "1921-04-23"^^xsd:date .
# <#person_albert_einstein> schema:hasOccupation <#occupation_scientist> .
# <#person_albert_einstein> schema:worksFor <#institution_princeton> .
# <#person_albert_einstein> schema:worksFor <#institution_columbia> .
# <#person_albert_einstein> schema:alumniOf <#institution_ethz> .
# <#person_albert_einstein> wiki3:publishedEssay "1921-07"^^xsd:date .
# <#essay_my_first_impression> rdfs:label "My First Impression of the U.S.A." .
# <#essay_my_first_impression> schema:author <#person_albert_einstein> .
# <#essay_my_first_impression> schema:datePublished "1921-07"^^xsd:date .
# <#essay_my_first_impression> schema:isBasedOn <#book_democracy_in_america> .
# <#book_democracy_in_america> rdfs:label "Democracy in America" .
# <#book_democracy_in_america> schema:author <#person_alexandre_de_tocqueville> .
# <#person_alexandre_de_tocqueville> rdfs:label "Alexis de Tocqueville" .
# <#person_albert_einstein> wiki3:describedAmericaAs "friendly" .
# <#person_albert_einstein> wiki3:describedAmericaAs "self-confident" .
# <#person_albert_einstein> wiki3:describedAmericaAs "optimistic" .
# <#person_albert_einstein> wiki3:describedAmericaAs "without envy" .
# <#person_albert_einstein> wiki3:visitedPlace <#place_united_states> .
# <#person_albert_einstein> wiki3:visitedPlace <#place_europe> .
# <#person_albert_einstein> wiki3:traveledVia <#place_london> .
# <#person_albert_einstein> schema:hasOccupation <#occupation_scientist> .
# <#person_albert_einstein> schema:worksFor <#institution_princeton> .
# <#person_albert_einstein> schema:worksFor <#institution_columbia> .
# <#person_albert_einstein> schema:alumniOf <#institution_ethz> .
# <#person_albert_einstein> wiki3:timeInAmerica "1921-04-02"^^xsd:date .
# <#person_albert_einstein> wiki3:timeInAmerica "1921-04-23"^^xsd:date .
# <#person_albert_einstein> wiki3:visitedPlace <#place_new_york_city> .
# <#person_albert_einstein> wiki3:visitedPlace <#place_washington_d_c> .
# <#person_albert_einstein> wiki3:visitedPlace <#place_london> .
# <#person_john_f_hylan> rdfs:label "John Francis Hylan" .
# <#person_john_f_hylan> schema:hasOccupation <#occupation_mayor> .
# <#person_john_f_hylan> schema:worksFor <#place_new_york_city> .
# <#person_albert_einstein> wiki3:metPerson <#person_john_f_hylan> .
# <#person_albert_einstein> wiki3:visitedPlace <#place_white_house> .
# <#place_white_house> rdfs:label "White House" .
# <#person_albert_einstein> wiki3:visitedPlace <#place_kings_college_london> .
# <#place_kings_college_london> rdfs:label "King's College London" .
# <#person_albert_einstein> wiki3:visitedPlace <#place_british_scientific_organizations> .
# <#person_albert_einstein> wiki3:visitedPlace <#place_intellectual_organizations> .
# <#person_albert_einstein> wiki3:visitedPlace <#place_political_organizations> .
# <#person_viscount_haldane> rdfs:label "Viscount Haldane" .
# <#person_viscount_haldane> schema:hasOccupation <#occupation_philosopher> .
# <#person_viscount_haldane> schema:hasOccupation <#occupation_statesman> .
# <#person_albert_einstein> wiki3:metPerson <#person_viscount_haldane> .
# <#person_albert_einstein> wiki3:publishedEssay "1921-07"^^xsd:date .
# <#essay_my_first_impression> rdfs:label "My First Impression of the U.S.A." .
# <#essay_my_first_impression> schema:author <#person_albert_einstein> .
# <#essay_my_first_impression> schema:datePublished "1921-07"^^xsd:date .
# <#essay_my_first_impression> schema:isBasedOn <#book_democracy_in_america> .
# <#book_democracy_in_america> rdfs:label "Democracy in America" .
# <#book_democracy_in_america> schema:author <#person_alexandre_de_tocqueville> .
# <#person_alexandre_de_tocqueville> rdfs:label "Alexis de Tocqueville" .
# <#person_albert_einstein> wiki3:describedAmericaAs "friendly" .
# <#person_albert_einstein> wiki3:describedAmericaAs "self-confident" .
# <#person_albert_einstein> wiki3:describedAmericaAs "optimistic" .
# <#person_albert_einstein> wiki3:describedAmericaAs "without envy" .

# %% [raw]
# # Chunk 17
# # Context: Albert Einstein > Life and career > Coming to terms with fame (1921–1923)
#
# <#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date ;
#     schema:birthPlace <#place_germany> ;
#     rdfs:label "Albert Einstein" .
#
# <#place_germany> rdfs:label "Germany" .
#
# <#person_albert_einstein> wiki3:undertookTourInYear "1922"^^xsd:gYear ;
#     rdfs:label "Albert Einstein undertook a six-month tour of Asia in 1922" .
#
# <#person_albert_einstein> wiki3:visitedPlace <#place_japan> ;
#     rdfs:label "Albert Einstein visited Japan during his Asian tour" .
#
# <#person_albert_einstein> wiki3:visitedPlace <#place_singapore> ;
#     rdfs:label "Albert Einstein visited Singapore during his Asian tour" .
#
# <#person_albert_einstein> wiki3:visitedPlace <#place_sri_lanka> ;
#     rdfs:label "Albert Einstein visited Sri Lanka during his Asian tour" .
#
# <#person_albert_einstein> wiki3:metAt <#event_meeting_with_emperor> ;
#     rdfs:label "Albert Einstein met Emperor Yoshihito and his wife at the Imperial Palace in Japan" .
#
# <#event_meeting_with_emperor> rdfs:label "Meeting with Emperor Yoshihito and his wife at the Imperial Palace" ;
#     wiki3:location <#place_imperial_palace> .
#
# <#place_imperial_palace> rdfs:label "Imperial Palace, Japan" .
#
# <#person_albert_einstein> wiki3:attendedEvent <#event_tokyo_spectators> ;
#     rdfs:label "Thousands of spectators gathered in Tokyo to see Einstein" .
#
# <#event_tokyo_spectators> rdfs:label "Thousands of spectators gathered in Tokyo to see Einstein" .
#
# <#person_albert_einstein> wiki3:wroteLetterTo <#person_sons> ;
#     rdfs:label "Einstein wrote a letter to his sons describing Japanese people as modest, intelligent, and considerate" .
#
# <#person_sons> rdfs:label "Einstein's sons" .
#
# <#person_albert_einstein> wiki3:wroteInDiary "Japanese people are modest, intelligent and considerate" ;
#     rdfs:label "Einstein described Japanese people as modest, intelligent, and considerate in a letter to his sons" .
#
# <#person_albert_einstein> wiki3:wroteInDiary "The intellectual needs of Japan seemed weaker than their artistic ones" ;
#     rdfs:label "Einstein wrote in his diary that the intellectual needs of Japan seemed weaker than their artistic ones" .
#
# <#person_albert_einstein> wiki3:wroteInDiary "Even the children are spiritless and look obtuse" ;
#     rdfs:label "Einstein wrote in his diary that Chinese children are spiritless and look obtuse" .
#
# <#person_albert_einstein> wiki3:wroteInDiary "Chinese people might supplant other races" ;
#     rdfs:label "Einstein expressed concern that Chinese people might supplant other races in his diary" .
#
# <#person_albert_einstein> wiki3:visitedPlace <#place_mandatory_palestine> ;
#     rdfs:label "In Mandatory Palestine, Einstein spent twelve days during his tour" .
#
# <#place_mandatory_palestine> rdfs:label "Mandatory Palestine" ;
#     wiki3:duration "12"^^xsd:integer ;
#     wiki3:unit "days" .
#
# <#person_albert_einstein> wiki3:wasWelcomedBy <#person_sir_herbert_samuel> ;
#     rdfs:label "Sir Herbert Samuel, the British High Commissioner, welcomed Einstein with ceremonial honors including a cannon salute" .
#
# <#person_sir_herbert_samuel> rdfs:label "Sir Herbert Samuel" ;
#     schema:jobTitle "British High Commissioner" .
#
# <#event_cannon_salute> rdfs:label "Ceremonial honors including a cannon salute" .
#
# <#person_albert_einstein> wiki3:attendedEvent <#event_palestine_reception> ;
#     rdfs:label "A reception held in Einstein's honor in Palestine was stormed by people wanting to hear him speak" .
#
# <#event_palestine_reception> rdfs:label "Reception held in Einstein's honor in Palestine" .
#
# <#person_albert_einstein> wiki3:spokeAt <#event_palestine_reception> ;
#     rdfs:label "At the reception, Einstein said he was happy that Jews were beginning to be recognized as a force in the world" .
#
# <#person_albert_einstein> wiki3:expressedOpinionAbout <#place_china> ;
#     rdfs:label "Einstein expressed uncomplimentary views of China in his diary" .
#
# <#place_china> rdfs:label "China" .
#
# <#person_albert_einstein> wiki3:expressedOpinionAbout <#place_india> ;
#     rdfs:label "Einstein expressed uncomplimentary views of India in his diary" .
#
# <#place_india> rdfs:label "India" .

# %% [raw]
# # Chunk 18
# # Context: Albert Einstein > Life and career > Coming to terms with fame (1921–1923)
#
# <#person_albert_einstein> schema:hasOccupation <#occupation_physicist> .
# <#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <#person_albert_einstein> schema:birthPlace <#place_germany> .
# <#person_albert_einstein> schema:alumniOf <#institution_princeton_university> .
# <#person_albert_einstein> schema:worksFor <#organization_berlin_academy> .
# <#person_albert_einstein> schema:hasOccupation <#occupation_peace_campaigner> .
# <#person_albert_einstein> schema:hasOccupation <#occupation_nobel_laureate> .
#
# <#event_tour_eastern_hemisphere_1922> a schema:Event ;
#     rdfs:label "Tour of the Eastern Hemisphere" ;
#     schema:name "Tour of the Eastern Hemisphere" ;
#     schema:startDate "1922-01-01"^^xsd:date ;
#     schema:endDate "1922-12-31"^^xsd:date ;
#     wiki3:hasParticipant <#person_albert_einstein> .
#
# <#event_nobel_ceremony_1922> a schema:Event ;
#     rdfs:label "Nobel Prize Ceremony" ;
#     schema:name "Nobel Prize Ceremony" ;
#     schema:startDate "1922-12-01"^^xsd:date ;
#     schema:endDate "1922-12-31"^^xsd:date ;
#     wiki3:hasParticipant <#person_albert_einstein> .
#
# <#person_german_diplomat> a schema:Person ;
#     rdfs:label "German Diplomat" ;
#     wiki3:represents <#person_albert_einstein> .
#
# <#event_nobel_banquet_1922> a schema:Event ;
#     rdfs:label "Nobel Banquet" ;
#     schema:name "Nobel Banquet" ;
#     schema:startDate "1922-12-01"^^xsd:date ;
#     schema:endDate "1922-12-31"^^xsd:date ;
#     wiki3:hasSpeaker <#person_german_diplomat> .
#
# <#speech_praise_einstein_1922> a schema:Speech ;
#     rdfs:label "Speech Praising Einstein" ;
#     schema:text "Praised Einstein as both a physicist and peace campaigner" ;
#     schema:startDate "1922-12-01"^^xsd:date ;
#     schema:endDate "1922-12-31"^^xsd:date ;
#     wiki3:givenBy <#person_german_diplomat> .
#
# <#event_visit_spain_1923> a schema:Event ;
#     rdfs:label "Visit to Spain" ;
#     schema:name "Visit to Spain" ;
#     schema:startDate "1923-01-01"^^xsd:date ;
#     schema:endDate "1923-12-31"^^xsd:date ;
#     wiki3:hasParticipant <#person_albert_einstein> .
#
# <#organization_spanish_academy_of_sciences> a schema:Organization ;
#     rdfs:label "Spanish Academy of Sciences" ;
#     wiki3:awards <#award_diploma_1923> .
#
# <#award_diploma_1923> a schema:Award ;
#     rdfs:label "Diploma from Spanish Academy of Sciences" ;
#     schema:name "Diploma from Spanish Academy of Sciences" ;
#     schema:startDate "1923-01-01"^^xsd:date ;
#     schema:endDate "1923-12-31"^^xsd:date ;
#     wiki3:awardedTo <#person_albert_einstein> ;
#     wiki3:awardedBy <#organization_spanish_academy_of_sciences> .
#
# <#person_king_alfonso_xiii> a schema:Person ;
#     rdfs:label "King Alfonso XIII" ;
#     wiki3:awarded <#award_diploma_1923> .
#
# <#person_santiago_ramón_y_cajal> a schema:Person ;
#     rdfs:label "Santiago Ramón y Cajal" ;
#     schema:hasOccupation <#occupation_neuroanatomist> ;
#     schema:hasOccupation <#occupation_nobel_laureate> .
#
# <#meeting_einstein_cajal_1923> a schema:Meeting ;
#     rdfs:label "Meeting between Einstein and Santiago Ramón y Cajal" ;
#     schema:startDate "1923-01-01"^^xsd:date ;
#     schema:endDate "1923-12-31"^^xsd:date ;
#     wiki3:participant <#person_albert_einstein> ;
#     wiki3:participant <#person_santiago_ramón_y_cajal> .

# %% [raw]
# # Chunk 19
# # Context: Albert Einstein > Life and career > Serving the League of Nations (1922–1932)
#
# <#person_albert_einstein> schema:memberOf <#organization_international_committee_on_intellectual_cooperation> .
# <#organization_international_committee_on_intellectual_cooperation> schema:name "International Committee on Intellectual Cooperation" .
# <#organization_international_committee_on_intellectual_cooperation> schema:parentOrganization <#organization_league_of_nations> .
# <#organization_league_of_nations> schema:name "League of Nations" .
# <#person_albert_einstein> schema:startDate "1922-01-01"^^xsd:date .
# <#person_albert_einstein> schema:endDate "1932-12-31"^^xsd:date .
# <#person_albert_einstein> wiki3:appointedAsDelegateOf <#country_germany> .
# <#person_albert_einstein> wiki3:replacedBy <#person_gonzague_de_reynold> .
# <#person_gonzague_de_reynold> schema:name "Gonzague de Reynold" .
# <#person_oskar_halecki> schema:name "Oskar Halecki" .
# <#person_giuseppe_motta> schema:name "Giuseppe Motta" .
# <#person_oskar_halecki> wiki3:influencedAppointmentOf <#person_albert_einstein> .
# <#person_giuseppe_motta> wiki3:influencedAppointmentOf <#person_albert_einstein> .
# <#person_oskar_halecki> schema:worksFor <#organization_league_of_nations> .
# <#person_giuseppe_motta> schema:worksFor <#organization_league_of_nations> .
# <#person_hendrik_lorentz> schema:name "Hendrik Lorentz" .
# <#person_hendrik_lorentz> schema:memberOf <#organization_international_committee_on_intellectual_cooperation> .
# <#person_marie_curie> schema:name "Marie Curie" .
# <#person_marie_curie> schema:memberOf <#organization_international_committee_on_intellectual_cooperation> .
# <#person_albert_einstein> schema:spouse <#person_einstein_wife> .
# <#person_einstein_wife> schema:name "Einstein's wife" .
# <#person_albert_einstein> wiki3:visitedCountry <#country_brazil> .
# <#person_albert_einstein> wiki3:visitedCountry <#country_uruguay> .
# <#person_albert_einstein> wiki3:visitedCountry <#country_argentina> .
# <#tripod_south_american_tour> schema:name "South American tour" .
# <#person_albert_einstein> schema:work <#tripod_south_american_tour> .
# <#person_jorge_duclout> schema:name "Jorge Duclout" .
# <#person_mauricio_nirenstein> schema:name "Mauricio Nirenstein" .
# <#person_jorge_duclout> wiki3:suggestedTourTo <#person_albert_einstein> .
# <#person_mauricio_nirenstein> wiki3:suggestedTourTo <#person_albert_einstein> .
# <#organization_university_of_buenos_aires_council> schema:name "Council of the University of Buenos Aires" .
# <#organization_asociacion_hebraica_argentina> schema:name "Asociación Hebraica Argentina" .
# <#organization_argentine_germanic_cultural_institution> schema:name "Argentine-Germanic Cultural Institution" .
# <#tripod_south_american_tour> schema:financier <#organization_university_of_buenos_aires_council> .
# <#tripod_south_american_tour> schema:financier <#organization_asociacion_hebraica_argentina> .
# <#tripod_south_american_tour> schema:financier <#organization_argentine_germanic_cultural_institution> .
# <#person_albert_einstein> schema:startDate "1925-03-01"^^xsd:date .
# <#person_albert_einstein> schema:endDate "1925-04-30"^^xsd:date .

# %% [raw]
# # Chunk 20
# # Context: Albert Einstein > Life and career > Touring the US (1930–1931)
#
# <#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <#person_albert_einstein> schema:birthPlace <https://en.wikipedia.org/wiki/Ulm> .
# <#person_albert_einstein> wiki3:visitedCountry <https://en.wikipedia.org/wiki/United_States> .
# <#person_albert_einstein> wiki3:visitStartDate "1930-12-01"^^xsd:date .
# <#person_albert_einstein> wiki3:visitEndDate "1931-12-01"^^xsd:date .
# <#person_albert_einstein> schema:hasCredential <#credential_research_fellowship_caltech_1930> .
# <#credential_research_fellowship_caltech_1930> a schema: EducationalOccupationalCredential ;
#     schema:credentialCategory "Research Fellowship" ;
#     schema:educationalLevel "Postgraduate" ;
#     schema:issuer <https://en.wikipedia.org/wiki/California_Institute_of_Technology> ;
#     schema:validFrom "1930-01-01"^^xsd:date ;
#     schema:validThrough "1930-02-28"^^xsd:date ;
#     rdfs:label "Research Fellowship at California Institute of Technology (1930)" .
# <#person_albert_einstein> wiki3:declinedInvitations "true"^^xsd:boolean .
# <#person_albert_einstein> wiki3:visitedCity <#city_new_york> .
# <#city_new_york> a schema:City ;
#     rdfs:label "New York City" .
# <#person_albert_einstein> wiki3:visitedChinatown "true"^^xsd:boolean .
# <#person_albert_einstein> wiki3:metEditorOf <#publication_new_york_times> .
# <#publication_new_york_times> a schema:Periodical ;
#     rdfs:label "The New York Times" .
# <#person_albert_einstein> wiki3:attendedPerformance <#event_carmen_metropolitan_opera> .
# <#event_carmen_metropolitan_opera> a schema:MusicEvent ;
#     schema:name "Carmen at the Metropolitan Opera" ;
#     schema:location <https://en.wikipedia.org/wiki/Metropolitan_Opera_House> ;
#     rdfs:label "Carmen at the Metropolitan Opera" .
# <#person_albert_einstein> wiki3:receivedCheer "true"^^xsd:boolean .
# <#person_albert_einstein> wiki3:receivedKeysToCity <#city_new_york> .
# <#person_albert_einstein> wiki3:describedBy <#person_nicholas_murray_butler> .
# <#person_nicholas_murray_butler> a schema:Person ;
#     schema:name "Nicholas Murray Butler" ;
#     schema:jobTitle "President of Columbia University" ;
#     rdfs:label "Nicholas Murray Butler" .
# <#person_albert_einstein> wiki3:visitedRiversideChurch <#person_harry_emerson_fosdick> .
# <#person_harry_emerson_fosdick> a schema:Person ;
#     schema:name "Harry Emerson Fosdick" ;
#     schema:jobTitle "Pastor at Riverside Church" ;
#     rdfs:label "Harry Emerson Fosdick" .
# <#person_albert_einstein> wiki3:tourOfChurch <#place_riverside_church> .
# <#place_riverside_church> a schema:Place ;
#     schema:name "Riverside Church" ;
#     rdfs:label "Riverside Church" .
# <#person_albert_einstein> wiki3:seenStatueOfSelf <#place_riverside_church> .
# <#person_albert_einstein> wiki3:joinedCelebration <#event_hanukkah_madison_square_garden> .
# <#event_hanukkah_madison_square_garden> a schema:Event ;
#     schema:name "Hanukkah Celebration at Madison Square Garden" ;
#     schema:attendeeCount 15000 ;
#     rdfs:label "Hanukkah Celebration at Madison Square Garden" .

# %% [raw]
# # Chunk 21
# # Context: Albert Einstein > Life and career > Touring the US (1930–1931)
#
# <#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date ;
#     schema:birthPlace <#place_germany> ;
#     rdfs:label "Albert Einstein" .
#
# <#person_robert_a_millikan> a schema:Person ;
#     rdfs:label "Robert A. Millikan" .
#
# <#person_upton_sinclair> a schema:Person ;
#     rdfs:label "Upton Sinclair" .
#
# <#person_charlie_chaplin> a schema:Person ;
#     rdfs:label "Charlie Chaplin" .
#
# <#person_walter_isaacson> a schema:Person ;
#     rdfs:label "Walter Isaacson" .
#
# <#person_elsa_einstein> a schema:Person ;
#     rdfs:label "Elsa Einstein" .
#
# <#place_california> a schema:Place ;
#     rdfs:label "California" .
#
# <#place_berlin> a schema:Place ;
#     rdfs:label "Berlin" .
#
# <#place_hollywood> a schema:Place ;
#     rdfs:label "Hollywood" .
#
# <#event_tour_to_california> a schema:Event ;
#     rdfs:label "Tour to California (1930–1931)" ;
#     schema:startDate "1930-01-01"^^xsd:date ;
#     schema:endDate "1931-12-31"^^xsd:date ;
#     schema:location <#place_california> .
#
# <#event_city_lights_premiere> a schema:Event ;
#     rdfs:label "City Lights premiere" ;
#     schema:startDate "1931-02-07"^^xsd:date ;
#     schema:location <#place_hollywood> .
#
# <#work_city_lights> a schema:CreativeWork ;
#     rdfs:label "City Lights" ;
#     schema:creator <#person_charlie_chaplin> .
#
# <#person_albert_einstein> schema:hasEvent <#event_tour_to_california> .
#
# <#person_albert_einstein> wiki3:met <#person_robert_a_millikan> ;
#     wiki3:hadFriend <#person_upton_sinclair> ;
#     wiki3:hadFriend <#person_charlie_chaplin> .
#
# <#person_robert_a_millikan> schema:jobTitle "President of Caltech" ;
#     schema:award <#award_nobel_prize> .
#
# <#award_nobel_prize> a schema:Award ;
#     rdfs:label "Nobel Prize" .
#
# <#person_charlie_chaplin> wiki3:visited <#person_albert_einstein> ;
#     schema:worksFor <#organization_universal_studios> .
#
# <#organization_universal_studios> a schema:Organization ;
#     rdfs:label "Universal Studios" .
#
# <#person_charlie_chaplin> wiki3:invited <#person_albert_einstein> ;
#     schema:hasCreativeWork <#work_city_lights> .
#
# <#person_albert_einstein> wiki3:attended <#event_city_lights_premiere> ;
#     wiki3:wasSpecialGuestAt <#event_city_lights_premiere> .
#
# <#person_elsa_einstein> wiki3:wasWith <#person_albert_einstein> .
#
# <#event_city_lights_premiere> schema:attendee <#person_albert_einstein> ;
#     schema:attendee <#person_elsa_einstein> .
#
# <#person_charlie_chaplin> wiki3:saidTo <#person_albert_einstein> "They cheer me because they understand me, and they cheer you because no one understands you." .
#
# <#person_charlie_chaplin> wiki3:recalledThat <#person_albert_einstein> "lived in a modest flat with a piano where he had begun writing his theory" .
#
# <#person_charlie_chaplin> wiki3:speculatedThat <#person_albert_einstein> "the piano may have been used as kindling wood by the Nazis" .
#
# <#person_walter_isaacson> wiki3:described <#event_city_lights_premiere> "one of the most memorable scenes in the new era of celebrity" .
#
# <#person_charlie_chaplin> wiki3:visited <#person_albert_einstein> ;
#     schema:location <#place_berlin> .
#
# <#person_albert_einstein> wiki3:hadAwkwardFriendshipWith <#person_robert_a_millikan> ;
#     wiki3:wasPacifist .
#
# <#person_robert_a_millikan> wiki3:supportedPatrioticMilitarism ;
#     wiki3:wasNobelLaureate .
#
# <#person_upton_sinclair> wiki3:wasPacifist .
#
# <#person_charlie_chaplin> wiki3:wasPacifist .

# %% [raw]
# # Chunk 22
# # Context: Albert Einstein > Life and career > Emigration to the US (1933)
#
# <#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date ;
#     schema:birthPlace <https://en.wikipedia.org/wiki/Ulm> ;
#     rdfs:label "Albert Einstein" .
#
# <#person_albert_einstein> wiki3:visitedCountry <https://en.wikipedia.org/wiki/United_States> ;
#     wiki3:visitDate "1933-02-01"^^xsd:date ;
#     wiki3:visitEndDate "1933-02-28"^^xsd:date .
#
# <#person_albert_einstein> wiki3:unableToReturnToCountry <https://en.wikipedia.org/wiki/Germany> ;
#     wiki3:reasonForNotReturning "rise of the Nazis under Adolf Hitler" ;
#     wiki3:yearOfInabilityToReturn "1933"^^xsd:gYear .
#
# <#person_albert_einstein> schema:worksFor <https://en.wikipedia.org/wiki/California_Institute_of_Technology> ;
#     wiki3:professorshipType "visiting professor" ;
#     wiki3:startDate "1933-01-01"^^xsd:date ;
#     wiki3:endDate "1933-12-31"^^xsd:date .
#
# <#person_albert_einstein> wiki3:familyApartmentRaidsByGestapo "1933-02-01"^^xsd:date ;
#     wiki3:familyApartmentRaidsEndDate "1933-03-31"^^xsd:date ;
#     wiki3:locationOfRaids <https://en.wikipedia.org/wiki/Berlin> .
#
# <#person_albert_einstein> wiki3:returnedToEurope "1933-03-01"^^xsd:date ;
#     wiki3:locationOfReturn <https://en.wikipedia.org/wiki/Europe> .
#
# <#person_albert_einstein> wiki3:learnedAboutEnablingAct "1933-03-23"^^xsd:date ;
#     wiki3:actName "Enabling Act" ;
#     wiki3:countryOfPassage <https://en.wikipedia.org/wiki/German_Reichstag> ;
#     wiki3:actTransformation "de facto legal dictatorship" .
#
# <#person_albert_einstein> wiki3:unableToProceedToBerlin "1933-03-01"^^xsd:date ;
#     wiki3:reasonForInability "due to Nazi actions" .
#
# <#person_albert_einstein> wiki3:heardAboutCottageRaids "1933-03-01"^^xsd:date ;
#     wiki3:locationOfCottage <https://en.wikipedia.org/wiki/Berlin> .
#
# <#person_albert_einstein> wiki3:sailboatConfiscated "1933-03-01"^^xsd:date ;
#     wiki3:reasonForConfiscation "Nazi actions" .
#
# <#person_albert_einstein> wiki3:landedInAntwerp "1933-03-28"^^xsd:date ;
#     wiki3:locationOfLanding <https://en.wikipedia.org/wiki/Antwerp> .
#
# <#person_albert_einstein> wiki3:renouncedGermanCitizenship "1933-03-01"^^xsd:date ;
#     wiki3:actionTaken "surrendered passport" .
#
# <#person_albert_einstein> wiki3:sailboatSoldByNazis "1933-03-01"^^xsd:date ;
#     wiki3:reasonForSale "Nazi confiscation" .
#
# <#person_albert_einstein> wiki3:cottageConvertedToHitlerYouthCamp "1933-03-01"^^xsd:date ;
#     wiki3:reasonForConversion "Nazi actions" .

# %% [raw]
# # Chunk 23
# # Context: Albert Einstein > Life and career > Emigration to the US (1933) > Refugee status
#
# <#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date ;
#     schema:birthPlace <https://en.wikipedia.org/wiki/Ulm> ;
#     rdfs:label "Albert Einstein" .
#
# <#person_max_born> schema:birthDate "1882-12-11"^^xsd:date ;
#     schema:birthPlace <https://en.wikipedia.org/wiki/Cologne> ;
#     rdfs:label "Max Born" .
#
# <#event_nazi_book_burning_1933> a schema:Event ;
#     schema:name "Nazi book burning" ;
#     schema:startDate "1933-05-10"^^xsd:date ;
#     schema:description "Book burnings organized by the Nazi regime targeting Jewish and leftist intellectuals." ;
#     rdfs:label "Nazi book burning of 1933" .
#
# <#event_emigration_to_us_1933> a schema:Event ;
#     schema:name "Emigration to the United States" ;
#     schema:startDate "1933-01-01"^^xsd:date ;
#     schema:endDate "1933-12-31"^^xsd:date ;
#     rdfs:label "Emigration to the United States (1933)" .
#
# <#person_joseph_goebbels> schema:birthDate "1897-07-29"^^xsd:date ;
#     schema:birthPlace <https://en.wikipedia.org/wiki/Berlin> ;
#     rdfs:label "Joseph Goebbels" .
#
# <#organization_german_student_union> schema:name "German Student Union" ;
#     rdfs:label "German Student Union" .
#
# <#organization_nazi_propaganda_ministry> schema:name "Nazi Propaganda Ministry" ;
#     rdfs:label "Nazi Propaganda Ministry" .
#
# <#publication_german_magazine> schema:name "German Magazine" ;
#     rdfs:label "German Magazine" .
#
# <#person_albert_einstein> wiki3:was_targeted_by <#event_nazi_book_burning_1933> ;
#     wiki3:was_influenced_by <#event_emigration_to_us_1933> ;
#     wiki3:expressed_opinion_on <#event_nazi_book_burning_1933> ;
#     schema:hasOccupation <https://en.wikipedia.org/wiki/Physicist> .
#
# <#event_nazi_book_burning_1933> schema:location <https://en.wikipedia.org/wiki/Berlin> ;
#     wiki3:involved_organization <#organization_german_student_union> ;
#     wiki3:involved_person <#person_joseph_goebbels> ;
#     schema:description "Book burning event targeting Jewish and leftist authors, including Einstein's works." .
#
# <#person_joseph_goebbels> schema:hasOccupation <https://en.wikipedia.org/wiki/Propaganda_minister> ;
#     wiki3:stated <#quote_jewish_intellectualism_dead> .
#
# <#quote_jewish_intellectualism_dead> a schema:CreativeWork ;
#     schema:text "Jewish intellectualism is dead" ;
#     rdfs:label "Quote by Joseph Goebbels on Jewish intellectualism" .
#
# <#publication_german_magazine> wiki3:listed_person_as_enemy <#person_albert_einstein> ;
#     schema:hasPart <#issue_with_bounty> .
#
# <#issue_with_bounty> a schema:CreativeWork ;
#     schema:name "Issue with bounty on Einstein's head" ;
#     schema:text "Not yet hanged" ;
#     schema:contentLocation <https://en.wikipedia.org/wiki/Germany> ;
#     schema:datePublished "1933"^^xsd:gYear ;
#     wiki3:offered_bounty <#bounty_5000_dollars> .
#
# <#bounty_5000_dollars> a schema:MonetaryAmount ;
#     schema:amount "5000.0"^^xsd:decimal ;
#     schema:currencies "USD" .
#
# <#person_albert_einstein> wiki3:emigrated_to <https://en.wikipedia.org/wiki/United_States> ;
#     schema:birthPlace <https://en.wikipedia.org/wiki/Germany> .
#
# <#person_albert_einstein> wiki3:expressed_opinion_to <#person_max_born> ;
#     schema:relatedTo <#person_max_born> .
#
# <#person_max_born> schema:hasOccupation <https://en.wikipedia.org/wiki/Physicist> ;
#     rdfs:label "Max Born" .
#
# <#person_albert_einstein> wiki3:wrote_to <#person_max_born> ;
#     schema:worksFor <https://en.wikipedia.org/wiki/Princeton_University> .
#
# <#event_emigration_to_us_1933> wiki3:caused_by <#event_nazi_book_burning_1933> ;
#     schema:startDate "1933-01-01"^^xsd:date .
#
# <#person_albert_einstein> wiki3:commented_on <#event_nazi_book_burning_1933> ;
#     schema:hasOccupation <https://en.wikipedia.org/wiki/Physicist> ;
#     schema:worksFor <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> .

# %% [raw]
# # Chunk 24
# # Context: Albert Einstein > Life and career > Emigration to the US (1933) > Refugee status
#
# <#person_albert_einstein> schema:hasOccupation <#occupation_refugee> ;
#     rdfs:label "Albert Einstein" .
#
# <#occupation_refugee> a schema:Occupation ;
#     rdfs:label "Refugee" .
#
# <#person_albert_einstein> wiki3:withoutPermanentHome "true"^^xsd:boolean ;
#     wiki3:worriedAboutScientistsInGermany "true"^^xsd:boolean ;
#     wiki3:rentedHouseInDeHaanBelgium "true"^^xsd:boolean ;
#     wiki3:livedInDeHaanBelgium "true"^^xsd:boolean ;
#     wiki3:visitedEngland "true"^^xsd:boolean ;
#     wiki3:invitedToStayNearCromer "true"^^xsd:boolean ;
#     wiki3:bodyguardsWatchedOverAlbertEinstein "true"^^xsd:boolean .
#
# <#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date ;
#     schema:birthPlace <#place_germany> ;
#     rdfs:label "Albert Einstein" .
#
# <#place_germany> a schema:Place ;
#     rdfs:label "Germany" .
#
# <#organization_academic_assistance_council> a schema:Organization ;
#     rdfs:label "Academic Assistance Council" ;
#     schema:foundingDate "1933-04-01"^^xsd:date ;
#     schema:founder <#person_william_beveridge> .
#
# <#person_william_beveridge> a schema:Person ;
#     rdfs:label "William Beveridge" .
#
# <#person_albert_einstein> schema:memberOf <#organization_academic_assistance_council> ;
#     wiki3:helpedByOrganization "Academic Assistance Council" .
#
# <#person_albert_einstein> schema:residence <#place_de_haan_belgium> .
#
# <#place_de_haan_belgium> a schema:Place ;
#     rdfs:label "De Haan, Belgium" .
#
# <#person_albert_einstein> schema:residence <#place_england> .
#
# <#place_england> a schema:Place ;
#     rdfs:label "England" .
#
# <#person_oliver_locker_lampson> a schema:Person ;
#     rdfs:label "Commander Oliver Locker-Lampson" ;
#     schema:knows <#person_albert_einstein> .
#
# <#person_oliver_locker_lampson> schema:friendOf <#person_albert_einstein> ;
#     wiki3:bodyguardsWatchedOverAlbertEinstein "true"^^xsd:boolean .
#
# <#event_bodyguard_photo> a schema:CreativeWork ;
#     rdfs:label "Photo of bodyguards guarding Albert Einstein" ;
#     schema:publisher <#organization_daily_herald> ;
#     schema:datePublished "1933-07-24"^^xsd:date .
#
# <#organization_daily_herald> a schema:Organization ;
#     rdfs:label "Daily Herald" .
#
# <#person_albert_einstein> schema:startDate "1933-07-24"^^xsd:date ;
#     schema:endDate "1933-08-24"^^xsd:date .
#
# <#person_albert_einstein> wiki3:durationInDeHaanBelgium "few months"^^xsd:string ;
#     wiki3:durationInEngland "six weeks"^^xsd:string .

# %% [raw]
# # Chunk 25
# # Context: Albert Einstein > Life and career > Emigration to the US (1933) > Refugee status
#
# <#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Winston_Churchill> .
# <#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Austen_Chamberlain> .
# <#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Lloyd_George> .
# <#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Frederick_Lindemann> .
# <#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Martin_Gilbert> .
# <#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/%C4%B0smet_%C4%B0n%C3%B6n%C3%BC> .
# <#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Robert_Locker-Lampson> .
# <#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Albert_Einstein> .
#
# <#person_albert_einstein> wiki3:contacted <https://en.wikipedia.org/wiki/Winston_Churchill> .
# <#person_albert_einstein> wiki3:contacted <https://en.wikipedia.org/wiki/Austen_Chamberlain> .
# <#person_albert_einstein> wiki3:contacted <https://en.wikipedia.org/wiki/Lloyd_George> .
# <#person_albert_einstein> wiki3:contacted <https://en.wikipedia.org/wiki/Frederick_Lindemann> .
#
# <https://en.wikipedia.org/wiki/Winston_Churchill> wiki3:respondedToRequestOf <#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Frederick_Lindemann> wiki3:wasSentToGermanyBy <https://en.wikipedia.org/wiki/Winston_Churchill> .
# <https://en.wikipedia.org/wiki/Frederick_Lindemann> wiki3:wasSentToGermanyFor <https://en.wikipedia.org/wiki/University_of_Oxford> .
# <https://en.wikipedia.org/wiki/Frederick_Lindemann> wiki3:wasSentToGermanyFor <https://en.wikipedia.org/wiki/University_of_Cambridge> .
# <https://en.wikipedia.org/wiki/Winston_Churchill> wiki3:observedThat <https://en.wikipedia.org/wiki/Germany>'sPersecutionOfJewsLoweredTheirTechnicalStandards .
#
# <#person_albert_einstein> wiki3:wroteTo <https://en.wikipedia.org/wiki/%C4%B0smet_%C4%B0n%C3%B6n%C3%BC> ;
#     schema:hasPart <https://en.wikipedia.org/wiki/September_1933> .
#
# <#person_albert_einstein> wiki3:requestedPlacementOf <https://en.wikipedia.org/wiki/Scientist> ;
#     rdfs:label "Jewish scientists" .
#
# <https://en.wikipedia.org/wiki/%C4%B0smet_%C4%B0n%C3%B6n%C3%BC> wiki3:invited <https://en.wikipedia.org/wiki/Scientist> ;
#     schema:hasPart <https://en.wikipedia.org/wiki/September_1933> ;
#     schema:hasPart <https://en.wikipedia.org/wiki/1000_scientists> .
#
# <#person_albert_einstein> wiki3:madePublicAppearancesRegarding <https://en.wikipedia.org/wiki/Crisis_in_Europe> .
# <#person_albert_einstein> wiki3:denouncedGermanyTreatmentOfJews <https://en.wikipedia.org/wiki/Germany> .
#
# <#person_albert_einstein> wiki3:introducedBill <https://en.wikipedia.org/wiki/Bill_promoting_Jewish_citizenship_in_Palestine> ;
#     schema:hasPart <https://en.wikipedia.org/wiki/Palestine> .
#
# <#person_albert_einstein> wiki3:describedHimselfAs <https://en.wikipedia.org/wiki/Citizen_of_the_world> .
#
# <#person_albert_einstein> wiki3:submittedBill <https://en.wikipedia.org/wiki/Bill_promoting_Jewish_citizenship_in_Palestine> .
# <https://en.wikipedia.org/wiki/Robert_Locker-Lampson> wiki3:submittedBill <https://en.wikipedia.org/wiki/Bill_extending_British_citizenship_to_Albert_Einstein> .
#
# <https://en.wikipedia.org/wiki/Bill_promoting_Jewish_citizenship_in_Palestine> schema:wasFailed <xsd:boolean> "true"^^xsd:boolean .
# <https://en.wikipedia.org/wiki/Bill_extending_British_citizenship_to_Albert_Einstein> schema:wasFailed <xsd:boolean> "true"^^xsd:boolean .
#
# <#person_albert_einstein> schema:acceptedOfferFrom <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> ;
#     schema:jobTitle "Resident Scholar" .
#
# <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> schema:locatedIn <https://en.wikipedia.org/wiki/Princeton,_New_Jersey> .

# %% [raw]
# # Chunk 26
# # Context: Albert Einstein > Life and career > Emigration to the US (1933) > Resident scholar at the Institute for Advanced Study
#
# <#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date ;
#     schema:birthPlace <https://en.wikipedia.org/wiki/Ulm> ;
#     schema:hasOccupation <https://en.wikipedia.org/wiki/Physicist> ;
#     rdfs:label "Albert Einstein" .
#
# <https://en.wikipedia.org/wiki/Albert_Einstein#speech_at_royal_albert_hall> a schema:SpeechEvent ;
#     schema:location <https://en.wikipedia.org/wiki/Royal_Albert_Hall> ;
#     schema:startDate "1933-10-03"^^xsd:date ;
#     schema:performer <#person_albert_einstein> ;
#     rdfs:label "Speech by Albert Einstein at Royal Albert Hall" .
#
# <https://en.wikipedia.org/wiki/Albert_Einstein#speech_at_royal_albert_hall> schema:attendeeCount "1000"^^xsd:integer ;
#     wiki3:wasCheered "true"^^xsd:boolean .
#
# <https://en.wikipedia.org/wiki/Albert_Einstein#move_to_us> a schema:MoveEvent ;
#     schema:startDate "1933-10-07"^^xsd:date ;
#     schema:location <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> ;
#     schema:performer <#person_albert_einstein> ;
#     rdfs:label "Albert Einstein's move to the United States and position at Institute for Advanced Study" .
#
# <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> a schema:Organization ;
#     rdfs:label "Institute for Advanced Study" ;
#     wiki3:refugeForScientists <https://en.wikipedia.org/wiki/Nazi_Germany> ;
#     wiki3:established "1930"^^xsd:integer .
#
# <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> schema:employee <#person_albert_einstein> ;
#     schema:worksFor <https://en.wikipedia.org/wiki/Princeton_University> .
#
# <#person_albert_einstein> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .
#
# <#person_albert_einstein> schema:hasOccupation <https://en.wikipedia.org/wiki/Physicist> .
#
# <#person_albert_einstein> wiki3:wasOfferedPositionAt <https://en.wikipedia.org/wiki/Christ_Church,_Oxford> ;
#     wiki3:wasOfferedFiveYearFellowship "true"^^xsd:boolean ;
#     wiki3:startDate "1931-05"^^xsd:date ;
#     wiki3:endDate "1933-06"^^xsd:date .
#
# <#person_albert_einstein> wiki3:wasUndecidedAboutFuture "true"^^xsd:boolean ;
#     wiki3:hadOffersFrom <https://en.wikipedia.org/wiki/University_of_Berlin> ;
#     wiki3:hadOffersFrom <https://en.wikipedia.org/wiki/University_of_Göttingen> .
#
# <#person_albert_einstein> wiki3:decidedToStayInUS "true"^^xsd:boolean ;
#     wiki3:appliedForCitizenship "1935"^^xsd:date .
#
# <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study#first_four> a schema:Organization ;
#     rdfs:label "First four selected at Institute for Advanced Study" ;
#     wiki3:member <#person_albert_einstein> ;
#     wiki3:member <https://en.wikipedia.org/wiki/John_von_Neumann> ;
#     wiki3:member <https://en.wikipedia.org/wiki/Kurt_Gödel> ;
#     wiki3:member <https://en.wikipedia.org/wiki/Hermann_Weyl> .
#
# <#person_albert_einstein> wiki3:developedFriendshipWith <https://en.wikipedia.org/wiki/Kurt_Gödel> ;
#     wiki3:tookLongWalksWith <https://en.wikipedia.org/wiki/Kurt_Gödel> .
#
# <https://en.wikipedia.org/wiki/Bruria_Kaufman> a schema:Person ;
#     rdfs:label "Bruria Kaufman" ;
#     wiki3:wasAssistantTo <#person_albert_einstein> ;
#     schema:hasOccupation <https://en.wikipedia.org/wiki/Physicist> .
#
# <#person_albert_einstein> wiki3:triedToDevelopUnifiedFieldTheory "true"^^xsd:boolean ;
#     wiki3:refutedQuantumPhysicsInterpretation "true"^^xsd:boolean ;
#     schema:worksFor <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> .
#
# <#person_albert_einstein> schema:residence <https://en.wikipedia.org/wiki/Princeton,_New_Jersey> ;
#     schema:homeLocation <https://en.wikipedia.org/wiki/Albert_Einstein_House> .
#
# <https://en.wikipedia.org/wiki/Albert_Einstein_House> a schema:Place ;
#     rdfs:label "Albert Einstein House" ;
#     wiki3:isNationalHistoricLandmark "true"^^xsd:boolean ;
#     wiki3:landmarkDate "1976"^^xsd:date .

# %% [raw]
# # Chunk 27
# # Context: Albert Einstein > Life and career > Emigration to the US (1933) > World War II and the Manhattan Project
#
# <#person_albert_einstein> a schema:Person ;
#     schema:name "Albert Einstein" ;
#     schema:birthDate "1879-03-14"^^xsd:date ;
#     schema:birthPlace <https://en.wikipedia.org/wiki/Ulm> ;
#     schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> ;
#     schema:worksFor <https://en.wikipedia.org/wiki/Princeton_University> .
#
# <https://en.wikipedia.org/wiki/Le%C3%B3_Szil%C3%A1rd> a schema:Person ;
#     schema:name "Leó Szilárd" ;
#     schema:birthDate "1898-02-11"^^xsd:date ;
#     schema:birthPlace <https://en.wikipedia.org/wiki/Budapest> .
#
# <https://en.wikipedia.org/wiki/Edward_Teller> a schema:Person ;
#     schema:name "Edward Teller" ;
#     schema:birthDate "1908-01-15"^^xsd:date ;
#     schema:birthPlace <https://en.wikipedia.org/wiki/Budapest> .
#
# <https://en.wikipedia.org/wiki/Eugene_Wigner> a schema:Person ;
#     schema:name "Eugene Wigner" ;
#     schema:birthDate "1902-11-17"^^xsd:date ;
#     schema:birthPlace <https://en.wikipedia.org/wiki/Budapest> .
#
# <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt> a schema:Person ;
#     schema:name "Franklin D. Roosevelt" ;
#     schema:birthDate "1882-01-30"^^xsd:date ;
#     schema:birthPlace <https://en.wikipedia.org/wiki/New_York_City> .
#
# <https://en.wikipedia.org/wiki/Manhattan_Project> a schema:Project ;
#     schema:name "Manhattan Project" ;
#     schema:description "The U.S. effort to develop atomic weapons during World War II." .
#
# <https://en.wikipedia.org/wiki/World_War_II> a schema:Event ;
#     schema:name "World War II" ;
#     schema:startDate "1939-09-01"^^xsd:date ;
#     schema:endDate "1945-09-02"^^xsd:date .
#
# <https://en.wikipedia.org/wiki/Atomic_bomb> a schema:Thing ;
#     schema:name "Atomic bomb" ;
#     rdfs:label "Atomic Bomb" .
#
# <#person_albert_einstein> wiki3:warnedAbout <https://en.wikipedia.org/wiki/Atomic_bomb> ;
#     wiki3:signedLetterToPresident <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt> ;
#     wiki3:wasInvolvedIn <https://en.wikipedia.org/wiki/Manhattan_Project> ;
#     wiki3:wasAssociatedWith <https://en.wikipedia.org/wiki/Le%C3%B3_Szil%C3%A1rd> ;
#     wiki3:wasAssociatedWith <https://en.wikipedia.org/wiki/Edward_Teller> ;
#     wiki3:wasAssociatedWith <https://en.wikipedia.org/wiki/Eugene_Wigner> ;
#     wiki3:visitedBy <https://en.wikipedia.org/wiki/Le%C3%B3_Szil%C3%A1rd> ;
#     wiki3:visitedBy <https://en.wikipedia.org/wiki/Eugene_Wigner> .
#
# <https://en.wikipedia.org/wiki/Le%C3%B3_Szil%C3%A1rd> wiki3:visited <#person_albert_einstein> ;
#     wiki3:warnedAbout <https://en.wikipedia.org/wiki/Atomic_bomb> .
#
# <https://en.wikipedia.org/wiki/Eugene_Wigner> wiki3:visited <#person_albert_einstein> ;
#     wiki3:warnedAbout <https://en.wikipedia.org/wiki/Atomic_bomb> .
#
# <https://en.wikipedia.org/wiki/Le%C3%B3_Szil%C3%A1rd> wiki3:co-authoredLetterWith <#person_albert_einstein> .
#
# <https://en.wikipedia.org/wiki/Edward_Teller> wiki3:wasAssociatedWith <#person_albert_einstein> .
#
# <https://en.wikipedia.org/wiki/Eugene_Wigner> wiki3:wasAssociatedWith <#person_albert_einstein> .
#
# <#person_albert_einstein> wiki3:signedLetterToPresident <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt> ;
#     wiki3:usedConnectionToMeet <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt> .
#
# <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt> wiki3:metWith <#person_albert_einstein> ;
#     wiki3:receivedLetterFrom <#person_albert_einstein> .
#
# <https://en.wikipedia.org/wiki/Manhattan_Project> wiki3:wasInitiatedBy <https://en.wikipedia.org/wiki/United_States> .
#
# <#person_albert_einstein> wiki3:believedInResponsibilityToAlert <https://en.wikipedia.org/wiki/United_States> .
#
# <#person_albert_einstein> schema:hasOccupation "Physicist" ;
#     schema:hasOccupation "Pacifist" .
#
# <https://en.wikipedia.org/wiki/1939> a schema:DateTime ;
#     schema:name "1939" ;
#     rdfs:label "Year 1939" .
#
# <https://en.wikipedia.org/wiki/July_1939> a schema:DateTime ;
#     schema:name "July 1939" ;
#     rdfs:label "Month July 1939" .
#
# <https://en.wikipedia.org/wiki/Atomic_bomb> wiki3:wasPossibilityOf <https://en.wikipedia.org/wiki/German_scientists> ;
#     wiki3:wasPossibleUnderCondition <https://en.wikipedia.org/wiki/Nazi_Germany> .
#
# <#person_albert_einstein> wiki3:wasNotAwareOf <https://en.wikipedia.org/wiki/Atomic_bomb> .
#
# <#person_albert_einstein> wiki3:contributedToInitiationOf <https://en.wikipedia.org/wiki/Manhattan_Project> ;
#     wiki3:influenced <https://en.wikipedia.org/wiki/United_States> .
#
# <https://en.wikipedia.org/wiki/Manhattan_Project> wiki3:wasBasedOn <https://en.wikipedia.org/wiki/U.S._nuclear_weapons_research> .
#
# <https://en.wikipedia.org/wiki/United_States> wiki3:enteredRaceFor <https://en.wikipedia.org/wiki/Atomic_bomb> ;
#     wiki3:usedResourcesIn <https://en.wikipedia.org/wiki/Manhattan_Project> .

# %% [raw]
# # Chunk 28
# # Context: Albert Einstein > Life and career > Emigration to the US (1933) > World War II and the Manhattan Project
#
# <#person_albert_einstein> schema:hasOccupation <#occupation_scientist> .
# <#person_albert_einstein> schema:hasOccupation <#occupation_pacifist> .
# <#person_albert_einstein> schema:hasOccupation <#occupation_physicist> .
# <#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <#person_albert_einstein> schema:birthPlace <#place_germany> .
# <#person_albert_einstein> rdfs:label "Albert Einstein" .
#
# <#occupation_scientist> rdfs:label "Scientist" .
# <#occupation_pacifist> rdfs:label "Pacifist" .
# <#occupation_physicist> rdfs:label "Physicist" .
# <#place_germany> rdfs:label "Germany" .
#
# <#person_albert_einstein> wiki3:signedLetterToPresident <#letter_1939_roosevelt> .
# <#letter_1939_roosevelt> schema:about <#topic_atomic_bombs> .
# <#letter_1939_roosevelt> schema:dateCreated "1939-08-02"^^xsd:date .
# <#letter_1939_roosevelt> rdfs:label "Letter to President Roosevelt (1939)" .
#
# <#topic_atomic_bombs> rdfs:label "Atomic Bombs" .
# <#topic_atomic_bombs> wiki3:relatedTo <#topic_nuclear_weapon_development> .
#
# <#person_albert_einstein> wiki3:expressedOpinion <#opinion_war_is_disease> .
# <#opinion_war_is_disease> schema:content "War is a disease." .
# <#opinion_war_is_disease> rdfs:label "War is a disease" .
#
# <#person_albert_einstein> wiki3:expressedOpinion <#opinion_resistance_to_war> .
# <#opinion_resistance_to_war> schema:content "Resistance to war." .
# <#opinion_resistance_to_war> rdfs:label "Resistance to war" .
#
# <#person_albert_einstein> wiki3:saidInYear 1954 .
# <#person_albert_einstein> wiki3:expressedOpinion <#opinion_greatest_mistake> .
# <#opinion_greatest_mistake> schema:content "Signing the letter to President Roosevelt was my greatest mistake in life." .
# <#opinion_greatest_mistake> rdfs:label "Greatest mistake in life" .
#
# <#person_albert_einstein> wiki3:saidInYear 1954 .
# <#person_albert_einstein> wiki3:expressedOpinion <#opinion_justification_for_letter> .
# <#opinion_justification_for_letter> schema:content "There was justification for signing the letter to President Roosevelt because of the danger that the Germans would make atom bombs." .
# <#opinion_justification_for_letter> rdfs:label "Justification for signing the letter" .
#
# <#person_albert_einstein> wiki3:signedManifesto <#manifesto_1955_waas> .
# <#manifesto_1955_waas> schema:dateCreated "1955"^^xsd:gYear .
# <#manifesto_1955_waas> rdfs:label "Manifesto with Bertrand Russell" .
#
# <#person_bertrand_russell> rdfs:label "Bertrand Russell" .
# <#person_bertrand_russell> schema:hasOccupation <#occupation_philosopher> .
# <#occupation_philosopher> rdfs:label "Philosopher" .
#
# <#person_albert_einstein> wiki3:memberOf <#organization_waas> .
# <#organization_waas> rdfs:label "World Academy of Art and Science" .
# <#organization_waas> wiki3:founder <#person_albert_einstein> .
# <#organization_waas> schema:foundingDate "1960"^^xsd:gYear .
# <#organization_waas> schema:purpose "Responsible and ethical advances of science" .
# <#organization_waas> schema:relatedTo <#topic_nuclear_weapon_development> .
# <#organization_waas> schema:relatedTo <#topic_ethics_in_science> .
# <#organization_waas> wiki3:posthumousMembership <#person_albert_einstein> .
# <#organization_waas> schema:hasMember <#person_bertrand_russell> .

# %% [raw]
# # Chunk 29
# # Context: Albert Einstein > Life and career > Emigration to the US (1933) > US citizenship
#
# <#person_albert_einstein> schema:nationality <https://www.wikidata.org/wiki/Q38> .
# <#person_albert_einstein> schema:residence <https://www.wikidata.org/wiki/Q657343> .
# <#person_albert_einstein> schema:birthPlace <https://www.wikidata.org/wiki/Q32740> .
# <#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <#person_albert_einstein> wiki3:submittedCitizenshipApplication "1939"^^xsd:gYear .
# <#person_albert_einstein> wiki3:naturalizationDate "1940-10-20"^^xsd:date .
# <#person_albert_einstein> wiki3:naturalizationLocation <https://www.wikidata.org/wiki/Q657343> .
# <#person_albert_einstein> wiki3:renouncedCitizenship <https://www.wikidata.org/wiki/Q38> .
# <#person_albert_einstein> wiki3:emigratedTo <https://www.wikidata.org/wiki/Q38> .
# <#person_albert_einstein> wiki3:emigrationYear "1933"^^xsd:gYear .
# <#person_albert_einstein> wiki3:usCitizenshipGrantedAfterResidency "true"^^xsd:boolean .
# <#person_albert_einstein> wiki3:yearsOfResidencyBeforeCitizenship "7"^^xsd:integer .
# <#person_albert_einstein> rdfs:label "Albert Einstein"@en .
# <#person_albert_einstein> wiki3:usCitizenshipStatus "Naturalized"@en .
# <#person_albert_einstein> wiki3:usCitizenshipYear "1940"^^xsd:gYear .

# %% [raw]
# # Chunk 30: US citizenship
# # Context: Albert Einstein > Life and career > Emigration to the US (1933) > US citizenship
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 31: US citizenship
# # Context: Albert Einstein > Life and career > Emigration to the US (1933) > US citizenship
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 32: Personal views
# # Context: Albert Einstein > Life and career > Personal views
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 33: Political views
# # Context: Albert Einstein > Life and career > Personal views > Political views
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 34: Relationship with Zionism
# # Context: Albert Einstein > Life and career > Personal views > Relationship with Zionism
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 35: Religious and philosophical views
# # Context: Albert Einstein > Life and career > Personal views > Religious and philosophical views
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 36: Religious and philosophical views
# # Context: Albert Einstein > Life and career > Personal views > Religious and philosophical views
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 37: Love of music
# # Context: Albert Einstein > Life and career > Personal views > Love of music
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 38: Love of music
# # Context: Albert Einstein > Life and career > Personal views > Love of music
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 39: Death
# # Context: Albert Einstein > Life and career > Death
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 40: Scientific career
# # Context: Albert Einstein > Scientific career
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 41: Theory of critical opalescence
# # Context: Albert Einstein > Scientific career > Statistical mechanics > Theory of critical opalescence
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 42: Special relativity
# # Context: Albert Einstein > Scientific career > Special relativity
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 43: General relativity
# # Context: Albert Einstein > Scientific career > General relativity
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 44: Gravitational waves
# # Context: Albert Einstein > Scientific career > General relativity > Gravitational waves
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 45: Physical cosmology
# # Context: Albert Einstein > Scientific career > General relativity > Physical cosmology
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 46: Physical cosmology
# # Context: Albert Einstein > Scientific career > General relativity > Physical cosmology
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 47: Energy momentum pseudotensor
# # Context: Albert Einstein > Scientific career > General relativity > Energy momentum pseudotensor
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 48: Einstein–Cartan theory
# # Context: Albert Einstein > Scientific career > General relativity > Einstein–Cartan theory
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 49: Equations of motion
# # Context: Albert Einstein > Scientific career > General relativity > Equations of motion
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 50: Old quantum theory
# # Context: Albert Einstein > Scientific career > Old quantum theory
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 51: Bose–Einstein statistics
# # Context: Albert Einstein > Scientific career > Old quantum theory > Bose–Einstein statistics
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 52: Zero-point energy
# # Context: Albert Einstein > Scientific career > Old quantum theory > Zero-point energy
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 53: Quantum mechanics
# # Context: Albert Einstein > Scientific career > Quantum mechanics
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 54: Einstein–Podolsky–Rosen paradox
# # Context: Albert Einstein > Scientific career > Quantum mechanics > Einstein–Podolsky–Rosen paradox
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 55: Einstein–Podolsky–Rosen paradox
# # Context: Albert Einstein > Scientific career > Quantum mechanics > Einstein–Podolsky–Rosen paradox
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 56: Einstein–Podolsky–Rosen paradox
# # Context: Albert Einstein > Scientific career > Quantum mechanics > Einstein–Podolsky–Rosen paradox
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 57: Unified field theory
# # Context: Albert Einstein > Scientific career > Unified field theory
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 58: Einstein–de Haas experiment
# # Context: Albert Einstein > Scientific career > Collaboration with other scientists > Einstein–de Haas experiment
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 59: Legacy
# # Context: Albert Einstein > Legacy
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 60: Scientific
# # Context: Albert Einstein > Legacy > Scientific
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 61: In popular culture
# # Context: Albert Einstein > In popular culture
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 62: Publications
# # Context: Albert Einstein > Publications
#
# # [RDF triples to be generated from corresponding facts cell]

# %% [raw]
# # Chunk 63: Archival materials collections
# # Context: Albert Einstein > External links > Archival materials collections
#
# # [RDF triples to be generated from corresponding facts cell]
