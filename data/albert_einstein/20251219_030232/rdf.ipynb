# %% [markdown]
# # RDF Triples: Albert Einstein
#
# ## Provenance
#
# ```yaml
# source_url: https://en.wikipedia.org/wiki/Albert_Einstein
# article_title: Albert Einstein
# license: CC BY-SA 4.0
# license_url: https://creativecommons.org/licenses/by-sa/4.0/
# source_notebook: facts.ipynb
# generated_by: wiki_to_kg_pipeline.ipynb
# generated_at: 2025-12-18T23:14:48.342333
# llm_provider: lm_studio
# llm_model: qwen/qwen3-coder-30b
# llm_temperature: 1
# rdf_format: Turtle
# ```
#
# ## RDF Prefixes
#
# ```turtle
# @prefix schema: <https://schema.org/> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix wiki3: <https://wiki3.ai/vocab/> .
# @base <https://en.wikipedia.org/wiki/Albert_Einstein> .
#
# ```
#
# ## Processing Instructions
#
# This notebook contains RDF triples in Turtle format, one cell per source statement.
# Each content cell is followed by a signature cell with CID provenance.
#
# To regenerate a specific cell: delete both the content cell and its signature, then re-run the pipeline.
#
# ## Prompt Template
#
# ```
# You are an expert at converting factual statements to RDF triples in Turtle format.
#
# Convert the following factual statements to RDF using schema.org vocabulary where possible.
#
# Source: {source_url}
# Section: {breadcrumb}
#
# Use these prefixes:
# {prefixes}
#
# Entity registry (use these URIs):
# {entity_registry}
#
# Guidelines:
# - Use schema.org properties (schema:birthDate, schema:birthPlace, schema:worksFor, etc.)
# - For relationships not in schema.org, use wiki3: prefix
# - Include rdfs:label for entities
# - Use xsd datatypes for dates and numbers
# - Entity URIs should use the source URL as base with fragment identifiers
#
# ---
# {facts}
# ---
#
# Generate Turtle RDF:
#
# ```

# %% [raw]
# {
#   "source_url": "https://en.wikipedia.org/wiki/Albert_Einstein",
#   "entities": {
#     "albert_einstein": {
#       "id": "person_albert_einstein",
#       "uri": "https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein",
#       "label": "Albert Einstein",
#       "type": "Person",
#       "descriptions": [
#         "Subject of Wikipedia article: Albert Einstein"
#       ],
#       "source_chunks": [],
#       "aliases": [
#         "Einstein"
#       ]
#     }
#   },
#   "aliases": {
#     "einstein": "albert_einstein"
#   }
# }

# %% [raw]
# # Statement [1.1]: Albert Einstein was a German-born theoretical physicist.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality schema:Germany .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation schema:Researcher .

# %% [raw]
# {"cell": 2, "stmt_key": "1_1", "chunk_num": 1, "stmt_idx": 1, "type": "rdf", "cid": "c8b20ededcbcc96ba66a3fbb9f2d2c2881b7b2945635d9d5b1cd6697476f3160", "from_cid": "79ba89701100776971220da0a401e76270f4532db3b9deab8c0e88a0437b851d"}

# %% [raw]
# # Statement [1.2]: Albert Einstein developed the theory of relativity.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator "theory of relativity" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator <https://en.wikipedia.org/wiki/Theory_of_relativity> .
# <https://en.wikipedia.org/wiki/Theory_of_relativity> rdf:type schema:CreativeWork .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator <https://en.wikipedia.org/wiki/Theory_of_relativity> .
# <https://en.wikipedia.org/wiki/Theory_of_relativity> rdf:type schema:CreativeWork .

# %% [raw]
# {"cell": 4, "stmt_key": "1_2", "chunk_num": 1, "stmt_idx": 2, "type": "rdf", "cid": "676d674aee21d3317910b48f41ffc6e0a2c92410f05612d70c627d0ec7007b19", "from_cid": "5a542422fdf3bf263b00a36289863a73f58394c193434857daa58f74eb30dd44"}

# %% [raw]
# # Statement [1.3]: Albert Einstein made important contributions to quantum theory.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor schema:Specialty .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "quantum theory" .
# "quantum theory" rdf:type schema:Specialty .

# %% [raw]
# {"cell": 6, "stmt_key": "1_3", "chunk_num": 1, "stmt_idx": 3, "type": "rdf", "cid": "14b5665b8998850a07e54db26d9a6c5176f132996dceb42625f80e5e9ac8114d", "from_cid": "a7df5ee100428ecc2acdd4a608f0e0584ccab7ea59105f16a0789e1f3896bd84"}

# %% [raw]
# # Statement [1.4]: Albert Einstein's mass–energy equivalence formula E = mc2 arises from special relativity.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasPart "E = mc2" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knownFor "Mass-energy equivalence" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Special Relativity" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knownFor "Mass-energy equivalence formula E = mc2" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Theory of Special Relativity" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "Mass-energy equivalence" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Special Relativity" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knownFor "E = mc2" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Special Relativity" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knownFor "E = mc2" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Special Relativity" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knownFor "Mass-energy equivalence formula E = mc2" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Special Relativity" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knownFor "E = mc2" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Special Relativity" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "E = mc2" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Special Relativity" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knownFor "E = mc2" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Special Relativity" .

# %% [raw]
# {"cell": 8, "stmt_key": "1_4", "chunk_num": 1, "stmt_idx": 4, "type": "rdf", "cid": "74d011031504826241110bbf9cdb05dfa1293a3c47cb5845d12f22d212c188be", "from_cid": "2b43ae873d4591a9b62c93928968870e4cb97819df5ec51fda774d549577ab95"}

# %% [raw]
# # Statement [1.5]: Albert Einstein received the 1921 Nobel Prize in Physics.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "1921 Nobel Prize in Physics" .

# %% [raw]
# {"cell": 10, "stmt_key": "1_5", "chunk_num": 1, "stmt_idx": 5, "type": "rdf", "cid": "c42e521a8ebddc296437ca7ae373ca09d1137adada5b3e6bf5b216357b82d338", "from_cid": "ba22410f26b37c84173b8dae0e295dfe3b7cd6a033f147acaaf0b8b8cf904984"}

# %% [raw]
# # Statement [1.6]: Albert Einstein was born on 14 March 1879.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .

# %% [raw]
# {"cell": 12, "stmt_key": "1_6", "chunk_num": 1, "stmt_idx": 6, "type": "rdf", "cid": "a655b39e375bb4677faed7e2037807ab0fd232c8331ea9230a45bd74f052afc2", "from_cid": "cbabea9601d0b563c2b511c733d1ebc9339a9346cf2e62049c93fbebafe949e6"}

# %% [raw]
# # Statement [1.7]: Albert Einstein died on 18 April 1955.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 14, "stmt_key": "1_7", "chunk_num": 1, "stmt_idx": 7, "type": "rdf", "cid": "62f408c600ed948ceda292b82b55f5f775669d28cd8ff77b4ebd2354f8699b75", "from_cid": "b0e67f805f2eff1d2efaec2c0d0484e2afa7c3b1f224f3fb1993127adcaaf4ac"}

# %% [raw]
# # Statement [1.8]: Albert Einstein was a subject of the Kingdom of Württemberg.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "Kingdom of Württemberg" .

# %% [raw]
# {"cell": 16, "stmt_key": "1_8", "chunk_num": 1, "stmt_idx": 8, "type": "rdf", "cid": "addd58109b91e2380e61574a736b7fc421587ed822c9eb5fe2b7caf9f3b34ebd", "from_cid": "2854db29b44aa8c2fad35bb9ced1c0b374d60663ed2073d862f38c7efac779a4"}

# %% [raw]
# # Statement [1.9]: Albert Einstein moved to Switzerland in 1895.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation "Switzerland" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation "Switzerland" .

# %% [raw]
# {"cell": 18, "stmt_key": "1_9", "chunk_num": 1, "stmt_idx": 9, "type": "rdf", "cid": "fd2cb647ff70e1372a7900d43bcbe1b4897e9eab986e6c875a6a32fd0b332e20", "from_cid": "e6dd13f285db88000a302238e410c5798980ef6f28365ef24e50ea61c422cc1f"}

# %% [raw]
# # Statement [1.10]: Albert Einstein forsaking his German citizenship in 1896.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality <https://www.wikidata.org/entity/Q183> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality <https://www.wikidata.org/entity/Q183> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality <https://www.wikidata.org/entity/Q183> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality <https://www.wikidata.org/entity/Q183> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .

# %% [raw]
# {"cell": 20, "stmt_key": "1_10", "chunk_num": 1, "stmt_idx": 10, "type": "rdf", "cid": "e190831bc953b84dfb73ec30fc90933163a138e1cf5d739aeaa3baa906ac6567", "from_cid": "720e4659c55a3a926d3b7c1d618a82f1cda8a0bf6004bef486e1126628a45b59"}

# %% [raw]
# # Statement [1.11]: Albert Einstein enrolled in the mathematics and physics teaching diploma program at the Swiss federal polytechnic school in Zurich in 1897.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential <#math_physics_diploma_program> .
# <#math_physics_diploma_program> rdf:type schema:EducationalOccupationalProgram .
# <#math_physics_diploma_program> schema:name "Mathematics and Physics Teaching Diploma Program" .
# <#math_physics_diploma_program> schema:provider "Swiss Federal Polytechnic School in Zurich" .
# <#math_physics_diploma_program> schema:startDate "1897"^^xsd:gYear .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#diploma_program> rdf:type schema:EducationalOccupationalProgram .
# <#diploma_program> schema:name "Mathematics and Physics Teaching Diploma Program" .
# <#diploma_program> schema:provider "Swiss Federal Polytechnic School in Zurich" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential <#diploma_program> .
# <#diploma_program> schema:startDate "1897"^^xsd:gYear .

# %% [raw]
# {"cell": 22, "stmt_key": "1_11", "chunk_num": 1, "stmt_idx": 11, "type": "rdf", "cid": "19e233bf0a378e3cc19c3ffab5df0a3c16a8bf0b96298883705dffc3a702919d", "from_cid": "0409c73184920d8f1832598b79d2f1cc46bfbbe88c48a726c62f69220a2d56d3"}

# %% [raw]
# # Statement [1.12]: Albert Einstein graduated from the Swiss federal polytechnic school in Zurich in 1900.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Swiss_federal_polytechnic_school> .
# <https://en.wikipedia.org/wiki/Swiss_federal_polytechnic_school> rdf:type schema:CollegeOrUniversity .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Swiss_federal_polytechnic_school> .
# <https://en.wikipedia.org/wiki/Swiss_federal_polytechnic_school> rdf:type schema:CollegeOrUniversity .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Swiss_federal_polytechnic_school> .
# <https://en.wikipedia.org/wiki/Swiss_federal_polytechnic_school> rdf:type schema:CollegeOrUniversity .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Swiss_federal_polytechnic_school> .
# <https://en.wikipedia.org/wiki/Swiss_federal_polytechnic_school> rdf:type schema:CollegeOrUniversity .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Swiss_federal_polytechnic_school> .
# <https://en.wikipedia.org/wiki/Swiss_federal_polytechnic_school> rdf:type schema:CollegeOrUniversity .

# %% [raw]
# {"cell": 24, "stmt_key": "1_12", "chunk_num": 1, "stmt_idx": 12, "type": "rdf", "cid": "1e02dc8772086db34f1fefd4a15b5859f371e8420129f51f6305c6f4ae27fa7c", "from_cid": "962dafb0bb954624e68d5421a3aea727531eb4da7fff1721b26bd8f0c0aef630"}

# %% [raw]
# # Statement [1.13]: Albert Einstein acquired Swiss citizenship in 1901.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "Swiss"@en .

# %% [raw]
# {"cell": 26, "stmt_key": "1_13", "chunk_num": 1, "stmt_idx": 13, "type": "rdf", "cid": "a69cde1c4b77f027e1efe26c644da3fd491a6b588e5ba3af551d9223568a92b2", "from_cid": "c2221f22015ea4c7091dd69ed03c045a94e46c1dc956255740dba92bf7c2408e"}

# %% [raw]
# # Statement [1.14]: Albert Einstein worked at the Swiss Patent Office in Bern.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <https://example.org/swiss_patent_office> .
# <https://example.org/swiss_patent_office> rdf:type schema:GovernmentOffice .
# <https://example.org/swiss_patent_office> schema:location <https://example.org/bern> .
# <https://example.org/bern> rdf:type schema:City .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <https://example.org/swiss_patent_office> .
# <https://example.org/swiss_patent_office> rdf:type schema:GovernmentOffice .
# <https://example.org/swiss_patent_office> schema:location <https://example.org/bern> .
# <https://example.org/bern> rdf:type schema:City .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <https://example.org/swiss_patent_office> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <https://example.org/swiss_patent_office> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <https://example.org/swiss_patent_office> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <https://example.org/swiss_patent_office> .
# <https://example.org/swiss_patent_office> rdf:type schema:Organization .
# <https://example.org/swiss_patent_office> schema:location <https://example.org/bern> .
# <https://example.org/bern> rdf:type schema:City .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <https://example.org/swiss_patent_office> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <https://example.org/swiss_patent_office> .

# %% [raw]
# {"cell": 28, "stmt_key": "1_14", "chunk_num": 1, "stmt_idx": 14, "type": "rdf", "cid": "161d15245028561dcec19294a5035cf9bdc92de3a30c542dcc6b100a3f9dfc03", "from_cid": "1d1882ee24a5bfe147e8a6bad797b17541a7c15cd584ab6ec7197205800fce98"}

# %% [raw]
# # Statement [1.15]: Albert Einstein submitted a successful PhD dissertation to the University of Zurich in 1905.
# # Error: ValidationError: 1 validation error for emit_triples
# triples
#   Input should be a valid list [type

# %% [raw]
# {"cell": 30, "stmt_key": "1_15", "chunk_num": 1, "stmt_idx": 15, "type": "rdf", "cid": "6c4ea711df648fd6753d94522c3a297d855dd82badfa0411d7259ec6fff3e2ad", "from_cid": "c95389c3206d9b257889549163faf02ad23086a96bd892ba35fc63501b3911de"}

# %% [raw]
# # Statement [1.16]: Albert Einstein moved to Berlin in 1914.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation "Berlin"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation "Berlin" .

# %% [raw]
# {"cell": 32, "stmt_key": "1_16", "chunk_num": 1, "stmt_idx": 16, "type": "rdf", "cid": "1a283710b51ee7d8f5013bb5b439891d37d6a45b813ffe95408de223e59c10b1", "from_cid": "39ddc4b533bcfd8dc14dfe0df9f40a1381b5c6ad91e603c8880243f5d2d73635"}

# %% [raw]
# # Statement [1.17]: Albert Einstein joined the Prussian Academy of Sciences in 1914.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:members <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> .
# <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> schema:members <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:member <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> .
# <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> schema:member <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .

# %% [raw]
# {"cell": 34, "stmt_key": "1_17", "chunk_num": 1, "stmt_idx": 17, "type": "rdf", "cid": "10cb184ef97e6f95a33cf67bd3b9b44fb71772d763f7d3d1e996371d0bf61c57", "from_cid": "31c9dd638470030ee5635805c7a4b847204a3e5cf363f35271450d02e74e7bbe"}

# %% [raw]
# # Statement [1.18]: Albert Einstein joined the Humboldt University of Berlin in 1914.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> .
# <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> rdf:type schema:CollegeOrUniversity .

# %% [raw]
# {"cell": 36, "stmt_key": "1_18", "chunk_num": 1, "stmt_idx": 18, "type": "rdf", "cid": "833fcc5fd17a42cd80f86be91517e5726a90be56f4cd6795ed420a8d88f1b63a", "from_cid": "c0e2e677cd5d9ba6476f2d60315dcc6a9e444a766d6024ae17f8aa0d9a07cd47"}

# %% [raw]
# # Statement [1.19]: Albert Einstein became director of the Kaiser Wilhelm Institute for Physics in 1917.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation <#role_director> .
# <#role_director> rdf:type schema:OrganizationRole .
# <#role_director> schema:roleName "Director" .
# <#role_director> schema:jobStartDate "1917"^^xsd:date .
# <#role_director> schema:worksFor "Kaiser Wilhelm Institute for Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>_director_of_Kaiser_Wilhelm_Institute_for_Physics .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation <#director_role> .
# <#director_role> rdf:type schema:Role .
# <#director_role> schema:roleName "Director" .
# <#director_role> schema:jobStartDate "1917"^^xsd:date .
# <#director_role> schema:worksFor "Kaiser Wilhelm Institute for Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation <#einstein_director_role> .
# <#einstein_director_role> rdf:type schema:Role .
# <#einstein_director_role> schema:roleName "Director" .
# <#einstein_director_role> schema:jobStartDate "1917"^^xsd:date .
# <#einstein_director_role> schema:worksFor "Kaiser Wilhelm Institute for Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Director of Kaiser Wilhelm Institute for Physics"@en .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Director of Kaiser Wilhelm Institute for Physics"@en .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Director"@en .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation <#director_role_1917> .
# <#director_role_1917> rdf:type schema:Role .
# <#director_role_1917> schema:roleName "Director" .
# <#director_role_1917> schema:jobStartDate "1917"^^xsd:date .
# <#director_role_1917> schema:worksFor "Kaiser Wilhelm Institute for Physics" .

# %% [raw]
# {"cell": 38, "stmt_key": "1_19", "chunk_num": 1, "stmt_idx": 19, "type": "rdf", "cid": "e98ee5231cd28ed93de190437d312d93f1fda729d21ebc11e13e86ea9a2ce03a", "from_cid": "b3797409272e0dc442a144b19eebee58b44806c1ba907f727b66340ee081a8f7"}

# %% [raw]
# # Statement [1.20]: Albert Einstein became a subject of the Kingdom of Prussia in 1914.
# # Error: ValidationError: 1 validation error for emit_triples
# triples
#   Input should be a valid list [type

# %% [raw]
# {"cell": 40, "stmt_key": "1_20", "chunk_num": 1, "stmt_idx": 20, "type": "rdf", "cid": "7bb76c664600125a72585fcc08343409d0e8d3d758d210bbb503210479d7e1d1", "from_cid": "7a072cc16d27bf569714f137738b887f05c5324c95fd645b8210c40f64c4c8e3"}

# %% [raw]
# # Statement [1.21]: Adolf Hitler came to power in Germany in 1933.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#adolf_hitler> rdf:type schema:Person .
# <#germany> rdf:type schema:Country .
# <#adolf_hitler> schema:name "Adolf Hitler" .
# <#germany> schema:name "Germany" .
# <#adolf_hitler> schema:birthDate "1889-04-20"^^xsd:date .
# <#adolf_hitler> rdf:type schema:Person .
# <#germany> rdf:type schema:Country .
# <#adolf_hitler> schema:name "Adolf Hitler" .
# <#germany> schema:name "Germany" .
# <#adolf_hitler> schema:birthDate "1889-04-20"^^xsd:date .
# <#adolf_hitler> schema:hasOccupation "Politician" .
# <#adolf_hitler> schema:jobStartDate "1933-01-01"^^xsd:date .
# <#adolf_hitler> schema:worksFor <#germany> .
# <#adolf_hitler> rdf:type schema:Person .
# <#germany> rdf:type schema:Country .
# <#adolf_hitler> schema:name "Adolf Hitler" .
# <#germany> schema:name "Germany" .
# <#adolf_hitler> schema:hasOccupation "Politician" .
# <#adolf_hitler> schema:jobStartDate "1933-01-01"^^xsd:date .
# <#adolf_hitler> schema:worksFor <#germany> .

# %% [raw]
# {"cell": 42, "stmt_key": "1_21", "chunk_num": 1, "stmt_idx": 21, "type": "rdf", "cid": "66784489d8778aeb7d096f470f63847b533a19f3a5bc0218fc61f6c162a194c2", "from_cid": "327c9e3d0fe188f5459b89ed3a262698267c91f99cf9e20d7450a112820badaf"}

# %% [raw]
# # Statement [1.22]: Albert Einstein was visiting the United States in 1933.
# # Error: ValidationError: 1 validation error for emit_triples
# triples
#   Input should be a valid list [type

# %% [raw]
# {"cell": 44, "stmt_key": "1_22", "chunk_num": 1, "stmt_idx": 22, "type": "rdf", "cid": "90d06b9f87b8ee1e2553ca50589cf2f803a944f2900aad05bb2b715324fbfad5", "from_cid": "975a7140245ff451fb59c5a1ba8760915d48880d9451ec81f3b58765dd813d25"}

# %% [raw]
# # Statement [1.23]: Albert Einstein decided to remain in the United States in 1933.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation <https://en.wikipedia.org/wiki/United_States> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation <https://en.wikipedia.org/wiki/United_States> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation <https://en.wikipedia.org/wiki/United_States> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .

# %% [raw]
# {"cell": 46, "stmt_key": "1_23", "chunk_num": 1, "stmt_idx": 23, "type": "rdf", "cid": "b4f210dbf749c5467adc58d41cb1f313f928416b32c3d8b2c26817fe510eaef1", "from_cid": "81d420f2062e790719ed4d2c6b14b5fc6747a70a808baa89ce8df9d99e112a9c"}

# %% [raw]
# # Statement [1.24]: Albert Einstein was granted American citizenship in 1940.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality <https://www.wikidata.org/wiki/Q30> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:additionalType "American citizenship in 1940"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality <https://www.wikidata.org/wiki/Q30> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality <https://www.wikidata.org/wiki/Q30> .

# %% [raw]
# {"cell": 48, "stmt_key": "1_24", "chunk_num": 1, "stmt_idx": 24, "type": "rdf", "cid": "83c501e09b2390b7099263def2017a339b25fb59644783a343b0e9feaf46337a", "from_cid": "20cdbe7d7f4b31ec70f00be952d6ab4553819258d741c22d7bf28d5750f79a0c"}

# %% [raw]
# # Statement [1.25]: Albert Einstein endorsed a letter to President Franklin D. Roosevelt in 1939.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:action <#endorsement_action> .
# <#endorsement_action> rdf:type schema:EndorseAction .
# <#endorsement_action> schema:agent <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#endorsement_action> schema:dateCreated "1939"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#letter_to_roosevelt> rdf:type schema:Message .
# <#letter_to_roosevelt> schema:recipient "Franklin D. Roosevelt" .
# <#endorsement_action> rdf:type schema:EndorseAction .
# <#endorsement_action> schema:agent <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#endorsement_action> schema:object <#letter_to_roosevelt> .
# <#endorsement_action> schema:startTime "1939"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#letter_to_roosevelt> rdf:type schema:Message .
# <#letter_to_roosevelt> schema:recipient "Franklin D. Roosevelt" .
# <#endorsement_action> rdf:type schema:EndorseAction .
# <#endorsement_action> schema:agent <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#endorsement_action> schema:actionStatus schema:CompletedActionStatus .
# <#endorsement_action> schema:startTime "1939"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#endorsement_action> rdf:type schema:EndorseAction .
# <#endorsement_action> schema:agent <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#endorsement_action> schema:startTime "1939"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#endorsement_action> rdf:type schema:EndorseAction .
# <#endorsement_action> schema:agent <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#endorsement_action> schema:startTime "1939"^^xsd:date .
# <#endorsement_action> schema:result "letter to President Franklin D. Roosevelt" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#endorsement_action> rdf:type schema:EndorseAction .
# <#endorsement_action> schema:agent <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#endorsement_action> schema:startTime "1939"^^xsd:date .
# <#endorsement_action> schema:result "letter to President Franklin D. Roosevelt" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#endorsement_action> rdf:type schema:EndorseAction .
# <#endorsement_action> schema:agent <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#endorsement_action> schema:startTime "1939"^^xsd:date .
# <#endorsement_action> schema:result "letter to President Franklin D. Roosevelt" .

# %% [raw]
# {"cell": 50, "stmt_key": "1_25", "chunk_num": 1, "stmt_idx": 25, "type": "rdf", "cid": "3ef7e9be455405a83e4cf7ca5b908a11265bb327d4aaba43f6c0a061c663cb8d", "from_cid": "f35920481868d3d63a1f593d0c63829d140d3040018dd677100dfd6ead5dc536"}

# %% [raw]
# # Statement [1.26]: President Franklin D. Roosevelt was alerted to the potential German nuclear weapons program by Albert Einstein in 1939.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt#person_franklin_roosevelt> .
# <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt#person_franklin_roosevelt> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt#person_franklin_roosevelt> schema:name "Franklin D. Roosevelt" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Nobel Prize in Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt#person_franklin_roosevelt> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt#person_franklin_roosevelt> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Nobel Prize in Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt#person_franklin_roosevelt> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt#person_franklin_roosevelt> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt#person_franklin_roosevelt> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt#person_franklin_roosevelt> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Nobel Prize in Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt#person_franklin_roosevelt> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt#person_franklin_roosevelt> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Nobel Prize in Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt#person_franklin_roosevelt> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt#person_franklin_roosevelt> schema:name "Franklin D. Roosevelt" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt#person_franklin_roosevelt> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Nobel Prize in Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt#person_franklin_roosevelt> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt#person_franklin_roosevelt> schema:name "Franklin D. Roosevelt" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Franklin_D._Roosevelt#person_franklin_roosevelt> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Nobel Prize in Physics" .

# %% [raw]
# {"cell": 52, "stmt_key": "1_26", "chunk_num": 1, "stmt_idx": 26, "type": "rdf", "cid": "5f55fe79a9a1f19a6a4786f0e338cc522950054aa813893ab1e457f5acf53b03", "from_cid": "0215b53dfbaa68c601f564fe80d639e96876b0f66894af459f87759fdd0b5b2d"}

# %% [raw]
# # Statement [1.27]: Albert Einstein recommended that the United States begin similar nuclear research to that of Germany in 1939.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:action "recommended" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:about "nuclear research" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:startDate "1939"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasRecommendation <#recommendation_nuclear_research> .
# <#recommendation_nuclear_research> rdf:type schema:Recommendation .
# <#recommendation_nuclear_research> schema:about "nuclear research" .
# <#recommendation_nuclear_research> schema:startDate "1939"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#recommendation_1939> rdf:type schema:Recommendation .
# <#recommendation_1939> schema:agent <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#recommendation_1939> schema:about "nuclear research" .
# <#recommendation_1939> schema:startDate "1939"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#recommendation_1939> rdf:type schema:Recommendation .
# <#recommendation_1939> schema:author <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#recommendation_1939> schema:about "nuclear research" .
# <#recommendation_1939> schema:startDate "1939"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#recommendation_1939> rdf:type schema:Recommendation .
# <#recommendation_1939> schema:agent <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#recommendation_1939> schema:about "nuclear research" .
# <#recommendation_1939> schema:startDate "1939"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#recommendation_1939> rdf:type schema:Recommendation .
# <#recommendation_1939> schema:agent <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#recommendation_1939> schema:about "nuclear research" .
# <#recommendation_1939> schema:startDate "1939"^^xsd:date .

# %% [raw]
# {"cell": 54, "stmt_key": "1_27", "chunk_num": 1, "stmt_idx": 27, "type": "rdf", "cid": "0155f04db3b88693149d683f7af5df2f2be7d6168ff6f0a8ed20a9867dfb8e60", "from_cid": "fbce7db212211f802ffcc39ad42ea6737e06602ecb3e1b7fa0ef45dc31e8c41c"}

# %% [raw]
# # Statement [1.28]: The Manhattan Project was carried out as a result of Albert Einstein's recommendation in 1939.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "https://en.wikipedia.org/wiki/Manhattan_Project" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Manhattan_Project> rdf:type schema:Project .
# <https://en.wikipedia.org/wiki/Manhattan_Project> schema:cause <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Manhattan_Project> schema:source <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Manhattan_Project> rdf:type schema:Project .
# <https://en.wikipedia.org/wiki/Manhattan_Project> schema:name "Manhattan Project" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Manhattan_Project> schema:source <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Manhattan_Project> schema:cause <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Manhattan_Project> rdf:type schema:Project .
# <https://en.wikipedia.org/wiki/Manhattan_Project> schema:name "Manhattan Project" .
# <https://en.wikipedia.org/wiki/Manhattan_Project> schema:cause <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .

# %% [raw]
# {"cell": 56, "stmt_key": "1_28", "chunk_num": 1, "stmt_idx": 28, "type": "rdf", "cid": "4085aed77d5cdf0bcdc9a573263bb2ed38a0c6342e65baba8a120e7cbc8ea6a4", "from_cid": "68122621b2933b8ff45902945044480235f6f9e24d35d5cc5162c7e12354a8ba"}

# %% [raw]
# # Statement [2.1]: In 1905, Albert Einstein published four groundbreaking papers.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Researcher .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Four groundbreaking papers published in 1905" .

# %% [raw]
# {"cell": 58, "stmt_key": "2_1", "chunk_num": 2, "stmt_idx": 1, "type": "rdf", "cid": "0f1c2f422321e5d9cefd537e2cb21968cf5e64c04e1cc78a604ab514e0acb5f8", "from_cid": "52aebc9b4189f97c550fcbbf3abcbcba988ec838d8839219d4deaa94731af088"}

# %% [raw]
# # Statement [2.2]: In 1905, the year 1905 is sometimes described as Albert Einstein's annus mirabilis.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#year_1905> rdf:type xsd:date .
# <#year_1905> schema:name "1905" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knownFor "1905" .
# <#year_1905> schema:description "Albert Einstein's annus mirabilis" .
# <#year_1905> rdf:type xsd:date .
# <#year_1905> schema:name "1905" .
# <#year_1905> schema:description "Albert Einstein's annus mirabilis" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#year_1905> schema:about <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#year_1905> schema:comment "Albert Einstein's annus mirabilis" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#year_1905> rdf:type xsd:date .
# <#year_1905> schema:name "1905" .
# <#year_1905> schema:comment "Albert Einstein's annus mirabilis" .

# %% [raw]
# {"cell": 60, "stmt_key": "2_2", "chunk_num": 2, "stmt_idx": 2, "type": "rdf", "cid": "2aa08752af5e839edc7c7f7970b5240a7c34ce778641d8a53531ca3986ae5fd3", "from_cid": "cccad7767947d604ff638b76c2f604f29691f342a6bf373ca969bdae4efbff79"}

# %% [raw]
# # Statement [2.3]: In 1905, Albert Einstein outlined a theory of the photoelectric effect in one of his four groundbreaking papers.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knownFor "Photoelectric effect theory" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:publication "Photoelectric effect theory" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:works "Photoelectric effect theory" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knownFor "Photoelectric effect theory" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1905"^^xsd:gYear .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:author "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasWork "Photoelectric effect theory" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knownFor "Photoelectric effect" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1905"^^xsd:gYear .

# %% [raw]
# {"cell": 62, "stmt_key": "2_3", "chunk_num": 2, "stmt_idx": 3, "type": "rdf", "cid": "b6000c6ca8eb77b148844f8bc926901a0c53071fc52363c159d8094e268fc7b5", "from_cid": "c68616c53b7f4727af62c9b8263b111c63a8dc3358ca99e0df81861ab5d79848"}

# %% [raw]
# # Statement [2.4]: In 1905, Albert Einstein explained Brownian motion in one of his four groundbreaking papers.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Researcher .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Ulm, Kingdom of Württemberg" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality schema:German .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathPlace "Princeton, New Jersey" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knownFor "Brownian motion" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Physicist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation "Princeton University" .

# %% [raw]
# {"cell": 64, "stmt_key": "2_4", "chunk_num": 2, "stmt_idx": 4, "type": "rdf", "cid": "07024f9d144f66bd58e6920cf8aa6bd09c74c0324bfa0780bda87872e05fbdba", "from_cid": "0c81644710a0ad4f6cf8a86df050fdf25e6be1a919aef944c44e573118f42f32"}

# %% [raw]
# # Statement [2.5]: In 1905, Albert Einstein introduced his special theory of relativity in one of his four groundbreaking papers.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator <#special_theory_of_relativity> .
# <#special_theory_of_relativity> rdf:type schema:CreativeWork .
# <#special_theory_of_relativity> schema:datePublished "1905"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#special_theory_of_relativity> rdf:type schema:CreativeWork .
# <#special_theory_of_relativity> schema:datePublished "1905"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor <#special_theory_of_relativity> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#special_theory_of_relativity> rdf:type schema:CreativeWork .
# <#special_theory_of_relativity> schema:datePublished "1905"^^xsd:date .
# <#special_theory_of_relativity> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .

# %% [raw]
# {"cell": 66, "stmt_key": "2_5", "chunk_num": 2, "stmt_idx": 5, "type": "rdf", "cid": "e364f3a5e319ef05365dad9e3ca3f9d4da306acde198c68c79f7fbbd5af5bfa0", "from_cid": "913f0fb315cbd90ff49868d0a9d0f7610f95566168f3ae0bbe70d7384ffe8584"}

# %% [raw]
# # Statement [2.6]: In 1905, Albert Einstein demonstrated that if the special theory of relativity is correct, mass and energy are equivalent to each other.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "special theory of relativity" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "mass-energy equivalence" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "1905 demonstration" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "1905 demonstration of mass-energy equivalence" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "mass-energy equivalence" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "special theory of relativity" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:achievement "Demonstrated mass-energy equivalence in 1905" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:achievementDate "1905"^^xsd:gYear .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:achievementDescription "If the special theory of relativity is correct, mass and energy are equivalent to each other" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "1905 demonstration of mass-energy equivalence" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "mass-energy equivalence" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "special theory of relativity" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:achievement "Demonstrated mass-energy equivalence" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:achievementDate "1905"^^xsd:gYear .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:achievementDescription "If the special theory of relativity is correct, mass and energy are equivalent to each other" .

# %% [raw]
# {"cell": 68, "stmt_key": "2_6", "chunk_num": 2, "stmt_idx": 6, "type": "rdf", "cid": "8dbeea713167c2439b51dacf9dfd10e506343cbbef4d31f57e655b2905883d89", "from_cid": "f381edc1d82072cc74f0a5aa833313b734783db190c919ea52a588dcc6de96a6"}

# %% [raw]
# # Statement [2.7]: In 1915, Albert Einstein proposed a general theory of relativity.
# # Error: ValidationError: 1 validation error for emit_triples
# triples
#   Input should be a valid list [type

# %% [raw]
# {"cell": 70, "stmt_key": "2_7", "chunk_num": 2, "stmt_idx": 7, "type": "rdf", "cid": "dc3b5941292443f13550622031315cd589666186a77e15b735b25f250a630b3d", "from_cid": "5694ca4ce8df6fb1cfaf4534d3d38f1e9a226dd869fc8482e8940b5572c00e58"}

# %% [raw]
# # Statement [2.8]: In 1915, the general theory of relativity that Albert Einstein proposed extended his system of mechanics to incorporate gravitation.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#general_theory_of_relativity> rdf:type schema:CreativeWork .
# <#general_theory_of_relativity> schema:name "General theory of relativity" .
# <#general_theory_of_relativity> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#general_theory_of_relativity> schema:dateCreated "1915"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#general_theory_of_relativity> rdf:type schema:CreativeWork .
# <#general_theory_of_relativity> schema:name "General theory of relativity" .
# <#general_theory_of_relativity> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#general_theory_of_relativity> schema:dateCreated "1915"^^xsd:date .
# <#general_theory_of_relativity> schema:description "Extended his system of mechanics to incorporate gravitation" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#general_theory_of_relativity> rdf:type schema:CreativeWork .
# <#general_theory_of_relativity> schema:name "General theory of relativity" .
# <#general_theory_of_relativity> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#general_theory_of_relativity> schema:dateCreated "1915"^^xsd:date .
# <#general_theory_of_relativity> schema:about "system of mechanics" .
# <#general_theory_of_relativity> schema:hasPart "gravitation" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#general_theory_of_relativity> rdf:type schema:CreativeWork .
# <#general_theory_of_relativity> schema:name "General theory of relativity" .
# <#general_theory_of_relativity> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#general_theory_of_relativity> schema:dateCreated "1915"^^xsd:date .
# <#general_theory_of_relativity> schema:description "Extended his system of mechanics to incorporate gravitation" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#general_theory_of_relativity> rdf:type schema:CreativeWork .
# <#general_theory_of_relativity> schema:name "General theory of relativity" .
# <#general_theory_of_relativity> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#general_theory_of_relativity> schema:dateCreated "1915"^^xsd:date .
# <#general_theory_of_relativity> schema:comment "Extended his system of mechanics to incorporate gravitation" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#general_theory_of_relativity> rdf:type schema:CreativeWork .
# <#general_theory_of_relativity> schema:name "General theory of relativity" .
# <#general_theory_of_relativity> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#general_theory_of_relativity> schema:dateCreated "1915"^^xsd:date .
# <#general_theory_of_relativity> schema:description "Extended his system of mechanics to incorporate gravitation" .

# %% [raw]
# {"cell": 72, "stmt_key": "2_8", "chunk_num": 2, "stmt_idx": 8, "type": "rdf", "cid": "e5984a9b587746df00fc0df4c502ea5af4e848416a7bf8950fc6d01325915e9e", "from_cid": "214e4bb0808ccfb932a185a19ef9fb3af306de8c8d1febc0f49dc48ea367763f"}

# %% [raw]
# # Statement [2.9]: In 1916, Albert Einstein published a paper that laid out the implications of general relativity for the modeling of the structure and evolution of the universe as a whole.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#paper_1916> rdf:type schema:ScholarlyArticle .
# <#paper_1916> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#paper_1916> schema:datePublished "1916"^^xsd:gYear .
# <#paper_1916> schema:mentions "General relativity" .
# <#paper_1916> schema:discussionUrl "https://en.wikipedia.org/wiki/Albert_Einstein#Introduction" .
# <#paper_1916> schema:text "This paper laid out the implications of general relativity for the modeling of the structure and evolution of the universe as a whole." .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#publication_1916> rdf:type schema:ScholarlyArticle .
# <#publication_1916> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#publication_1916> schema:datePublished "1916"^^xsd:gYear .
# <#publication_1916> schema:about "General relativity" .
# <#publication_1916> schema:discussionUrl "https://en.wikipedia.org/wiki/Albert_Einstein#Introduction" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#paper_1916> rdf:type schema:ScholarlyArticle .
# <#paper_1916> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#paper_1916> schema:datePublished "1916"^^xsd:gYear .
# <#paper_1916> schema:about "General relativity" .
# <#paper_1916> schema:text "This paper laid out the implications of general relativity for the modeling of the structure and evolution of the universe as a whole." .

# %% [raw]
# {"cell": 74, "stmt_key": "2_9", "chunk_num": 2, "stmt_idx": 9, "type": "rdf", "cid": "52b49aecb4d63f4f0538b9d269e9d414e1a3260302971f420400d4f3705eb9cd", "from_cid": "adf7708c3ae9ffd5139a597f5fbb7e70224e95fd22c69468cae41a07b8e06a0b"}

# %% [raw]
# # Statement [2.10]: In 1916, the paper that Albert Einstein published introduced the cosmological constant.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <#paper_1916> rdf:type schema:Article .
# <#paper_1916> schema:datePublished "1916"^^xsd:date .
# <#paper_1916> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#paper_1916> schema:headline "On the Cosmological Problem" .
# <#paper_1916> schema:mentions "cosmological constant" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#paper_1916> rdf:type schema:Article .
# <#paper_1916> schema:datePublished "1916"^^xsd:date .
# <#paper_1916> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#paper_1916> schema:mentions "cosmological constant" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#paper_1916> rdf:type schema:Article .
# <#paper_1916> schema:datePublished "1916"^^xsd:date .
# <#paper_1916> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#paper_1916> schema:mentions "cosmological constant" .

# %% [raw]
# {"cell": 76, "stmt_key": "2_10", "chunk_num": 2, "stmt_idx": 10, "type": "rdf", "cid": "da64ca58f388180a4b8576141c7a80eabfd5605d8fe76bb47bc37903d34de1df", "from_cid": "63a4aaed4ec6dc292e83a162ceba6ca27bfebaf27aeca143585c8e7ecca96341"}

# %% [raw]
# # Statement [2.11]: In 1916, the paper that Albert Einstein published is regarded as the first step in the field of modern theoretical cosmology.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#work_1916> rdf:type schema:CreativeWork .
# <#work_1916> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#work_1916> schema:datePublished "1916"^^xsd:date .
# <#work_1916> schema:description "Regarded as the first step in the field of modern theoretical cosmology" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#work_1916> rdf:type schema:CreativeWork .
# <#work_1916> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#work_1916> schema:datePublished "1916"^^xsd:date .
# <#work_1916> schema:description "Regarded as the first step in the field of modern theoretical cosmology" .

# %% [raw]
# {"cell": 78, "stmt_key": "2_11", "chunk_num": 2, "stmt_idx": 11, "type": "rdf", "cid": "c6085096732d63c1f7eff7dc9e3a7316826ca346b295ccc7ef88be365d77c7cc", "from_cid": "4917d71074ce6efaf529471c179f9b78b1f6c364d29448ac989b420a9ab45168"}

# %% [raw]
# # Statement [2.12]: In 1917, Albert Einstein wrote a paper.
# # Error: ValidationError: 1 validation error for emit_triples
# triples
#   Input should be a valid list [type

# %% [raw]
# {"cell": 80, "stmt_key": "2_12", "chunk_num": 2, "stmt_idx": 12, "type": "rdf", "cid": "e35657c350db1aa8dcf676fac0fca6c95af9d012399f574d0b83dc985b5157e4", "from_cid": "10f4446826561ca794f73359eef299688f0c3bf55e3627c335c9635eddd22b20"}

# %% [raw]
# # Statement [2.13]: In 1917, the paper that Albert Einstein wrote introduced the concepts of spontaneous emission and stimulated emission.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "spontaneous emission" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "stimulated emission" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#paper_1917> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#paper_1917> rdf:type schema:CreativeWork .
# <https://en.wikipedia.org/wiki/Albert_Einstein#paper_1917> schema:datePublished "1917"^^xsd:gYear .
# <https://en.wikipedia.org/wiki/Albert_Einstein#paper_1917> schema:text "introduced the concepts of spontaneous emission and stimulated emission" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#paper_1917> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#paper_1917> rdf:type schema:CreativeWork .
# <https://en.wikipedia.org/wiki/Albert_Einstein#paper_1917> schema:datePublished "1917"^^xsd:gYear .
# <https://en.wikipedia.org/wiki/Albert_Einstein#paper_1917> schema:text "introduced the concepts of spontaneous emission and stimulated emission" .

# %% [raw]
# {"cell": 82, "stmt_key": "2_13", "chunk_num": 2, "stmt_idx": 13, "type": "rdf", "cid": "108075f4fa64b6b9a281d488340a14683a6d7124bfb9cc005d76842f55dd8d0d", "from_cid": "e5c0e94eca64f26e1255ba316f054db524e6c7535f3457ee6bf0e5944e90f33d"}

# %% [raw]
# # Statement [2.14]: In 1917, the concept of stimulated emission is the core mechanism behind the laser and maser.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:knows "stimulated emission" .
# "stimulated emission" schema:mechanismFor "laser" .
# "stimulated emission" rdf:type schema:Thing .
# "stimulated emission" schema:description "A scientific principle where photons stimulate emission of other photons with the same energy, frequency, phase, and direction" .
# "stimulated emission" schema:mechanismFor "laser" .
# "stimulated emission" schema:mechanismFor "maser" .
# "stimulated emission" schema:temporalCoverage "1917"^^xsd:integer .
# "stimulated emission" rdf:type "schema:ScientificConcept" .
# "stimulated emission" rdf:type schema:Thing .
# "stimulated emission" schema:isBasedOn "1917"^^xsd:integer .
# "stimulated emission" schema:hasPart "laser" .
# "stimulated emission" schema:hasPart "maser" .
# "stimulated emission" rdf:type schema:Thing .
# "stimulated emission" schema:mechanismFor "laser" .
# "stimulated emission" schema:mechanismFor "maser" .
# "stimulated emission" schema:temporalCoverage "1917"^^xsd:integer .
# "stimulated emission" schema:hasPart "laser" .
# "stimulated emission" rdf:type schema:Thing .
# "stimulated emission" schema:mechanismFor "laser" .
# "stimulated emission" schema:mechanismFor "maser" .
# "stimulated emission" schema:temporalCoverage "1917"^^xsd:integer .
# "stimulated emission" rdf:type schema:Thing .
# "stimulated emission" schema:description "The core mechanism behind laser and maser operation" .
# "stimulated emission" schema:temporalCoverage "1917"^^xsd:integer .
# "stimulated emission" schema:hasPart "laser" .
# "stimulated emission" rdf:type schema:Thing .
# "stimulated emission" schema:mechanismFor "laser" .
# "stimulated emission" schema:mechanismFor "maser" .
# "stimulated emission" schema:temporalCoverage "1917"^^xsd:integer .

# %% [raw]
# {"cell": 84, "stmt_key": "2_14", "chunk_num": 2, "stmt_idx": 14, "type": "rdf", "cid": "1f1372eb68355d4ed55690b57b9a90bbe15d26fd3217b591a2769f0b371cc085", "from_cid": "9096865aa9dbf07b2fd7045becbf979a5e8b1a6d3810688572cd4ed8b6a3af2b"}

# %% [raw]
# # Statement [2.15]: In 1917, the paper that Albert Einstein wrote contained information beneficial to developments in physics later on such as quantum electrodynamics and quantum optics.
# # Error: ValidationError: 1 validation error for emit_triples
# triples
#   Input should be a valid list [type

# %% [raw]
# {"cell": 86, "stmt_key": "2_15", "chunk_num": 2, "stmt_idx": 15, "type": "rdf", "cid": "31fa25ef827f1479b8646c8423c639dbe307bd52a4679790bd8bbae1a4e32a15", "from_cid": "7670a21dfd67860357287ef4cd1cea2960cb877b9a16c3f68dce976cb22d9d45"}

# %% [raw]
# # Statement [2.16]: During the middle part of his career, Albert Einstein made important contributions to statistical mechanics.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "statistical mechanics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "statistical mechanics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "statistical mechanics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "statistical mechanics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "statistical mechanics" .

# %% [raw]
# {"cell": 88, "stmt_key": "2_16", "chunk_num": 2, "stmt_idx": 16, "type": "rdf", "cid": "fcadb214114a94bfcdef54cff51ab0a1ca6305ac526093e398a27e7e4fe71484", "from_cid": "2462a14a78fcd12ba729ce612378affdbfbb56b0218bd240ed217ca132afee07"}

# %% [raw]
# # Statement [2.17]: During the middle part of his career, Albert Einstein made important contributions to quantum theory.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "quantum theory" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "quantum theory" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "quantum theory" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "quantum theory" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "physicist" .

# %% [raw]
# {"cell": 90, "stmt_key": "2_17", "chunk_num": 2, "stmt_idx": 17, "type": "rdf", "cid": "36e9ba59fae7d6cc63be57357e5461bf4ca23fe7121d407ec566b3b54cd0c1a6", "from_cid": "0dc59ed95f4666e62191b74abe1bccd2de0f4d55307a9a36acfb1a29706ee81a"}

# %% [raw]
# # Statement [2.18]: Especially notable during the middle part of his career was Albert Einstein's work on the quantum physics of radiation.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "quantum physics of radiation"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "quantum physics of radiation"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "quantum physics of radiation"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "quantum physics of radiation"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "quantum physics of radiation"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "quantum physics of radiation" .

# %% [raw]
# {"cell": 92, "stmt_key": "2_18", "chunk_num": 2, "stmt_idx": 18, "type": "rdf", "cid": "b199282b173c87e5dd0810340b38622da064b8463e7d5405e03e619fd7fe3757", "from_cid": "a3a51a4fb15b71a5adb42b2405aaed0ccdc0ecd163e7e28a055ec31a22f51958"}

# %% [raw]
# # Statement [2.19]: In his work on the quantum physics of radiation, Albert Einstein proposed that light consists of particles.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "quantum physics of radiation" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contribution "light consists of particles" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "quantum physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "quantum physics of radiation" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "quantum physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "quantum physics of radiation" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .

# %% [raw]
# {"cell": 94, "stmt_key": "2_19", "chunk_num": 2, "stmt_idx": 19, "type": "rdf", "cid": "cfca8344f8b79a13a113ec45af8d1fca670b6c7ec4d6436ef5304c699d35a1b7", "from_cid": "7424ab1983b635d10e67b0aa9cff1e9a5481e8d30daeb9b42deb03b6d7e1225c"}

# %% [raw]
# # Statement [2.20]: These particles that Albert Einstein proposed are subsequently called photons.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "photons" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "photons" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .

# %% [raw]
# {"cell": 96, "stmt_key": "2_20", "chunk_num": 2, "stmt_idx": 20, "type": "rdf", "cid": "f2bf4d37b3299f82cc828c63e83aca0b42c6a81173cbd0eed53357ea10f2e6bd", "from_cid": "0b46167b9ed8581abe327be994c6442a025ff2fb61cd8d76a010f0c733401427"}

# %% [raw]
# # Statement [2.21]: With physicist Satyendra Nath Bose, Albert Einstein laid the groundwork for Bose–Einstein statistics.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Researcher .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:colleagues <https://en.wikipedia.org/wiki/Satyendra_Nath_Bose#person_satyendra_nath_bose> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor <https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_statistics#work_bose_einstein_statistics> .

# %% [raw]
# {"cell": 98, "stmt_key": "2_21", "chunk_num": 2, "stmt_idx": 21, "type": "rdf", "cid": "96bca452d957c2a60756bca89c72498cbba02e464495956eaddbf03a4c419ca0", "from_cid": "3cdcff155ec77ba551701e5d19cc8d47d12a7b4786382c61f53e40f4504adf3b"}

# %% [raw]
# # Statement [2.22]: For much of the last phase of his academic life, Albert Einstein worked on two endeavors.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist"@en .

# %% [raw]
# {"cell": 100, "stmt_key": "2_22", "chunk_num": 2, "stmt_idx": 22, "type": "rdf", "cid": "b025e3276933bddb40fbaf312cc4038bac05eaf5fd4a54baac726bb334b520f9", "from_cid": "38771dc4e412974b90668a454c8024a6f6ffad87e7866ab9f5fe8cbe1e5ad031"}

# %% [raw]
# # Statement [2.23]: The first endeavor that Albert Einstein advocated against was quantum theory's introduction of fundamental randomness into science's picture of the world.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "quantum theory" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist"@en .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "quantum theory" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "quantum theory" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:mainEntityOfPage <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "quantum theory" .

# %% [raw]
# {"cell": 102, "stmt_key": "2_23", "chunk_num": 2, "stmt_idx": 23, "type": "rdf", "cid": "23376e68a05c5b0504867e6676e970d385ec6c0c996d4025a6679fc380ba86ce", "from_cid": "79ba848b54aa7e25998e37ab9fa590627c49c0c1b68fc8d4507222d71b613d12"}

# %% [raw]
# # Statement [2.24]: Albert Einstein objected to quantum theory's introduction of fundamental randomness by saying that "God does not play dice".
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "quantum theory" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasQuote <#quote_on_quantum_theory> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#quote_on_quantum_theory> rdf:type schema:Quotation .
# <#quote_on_quantum_theory> schema:text "God does not play dice" .
# <#quote_on_quantum_theory> schema:spokenByCharacter <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#quote_on_quantum_theory> rdf:type schema:Quotation .
# <#quote_on_quantum_theory> schema:text "God does not play dice" .
# <#quote_on_quantum_theory> schema:spokenByCharacter <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .

# %% [raw]
# {"cell": 104, "stmt_key": "2_24", "chunk_num": 2, "stmt_idx": 24, "type": "rdf", "cid": "145cf36584ab68a1e0dc0b15037e09d65672ffa446132831173d00dcbb9e0b30", "from_cid": "a4b7561bfa85556413fc2b1ea328543b79cb29f9c383ab93929b10dbb24fe219"}

# %% [raw]
# # Statement [2.25]: The second endeavor that Albert Einstein attempted was to devise a unified field theory.
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:hasOccupation "Scientist" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:workExample "Devise a unified field theory" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:action "attempted to devise a unified field theory" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:achievement "Devise a unified field theory" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:knownFor "Unified field theory" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:hasOccupation "Scientist" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:knownFor "Unified field theory" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:achievement "Attempted to devise a unified field theory" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:knowsAbout "Unified field theory" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:hasOccupation "Scientist" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:knowsAbout "Unified field theory" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:achievement "Attempted to devise unified field theory" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:contributor "Unified field theory research" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:hasOccupation "Scientist" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:action "Attempted to devise unified field theory" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:knownFor "Unified field theory" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:achievement "Attempted to devise unified field theory" .

# %% [raw]
# {"cell": 106, "stmt_key": "2_25", "chunk_num": 2, "stmt_idx": 25, "type": "rdf", "cid": "3f44d207e84717d3fac034e877ad4646de57cbb41ccd81530b1777a327a28f13", "from_cid": "9ec009f4da32da0639047b63299012bfa197e46eaeaab025a3968c7fdf8ef4cb"}

# %% [raw]
# # Statement [2.26]: The unified field theory that Albert Einstein attempted was based on generalizing his geometric theory of gravitation to include electromagnetism.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "unified field theory"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "geometric theory of gravitation"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "electromagnetism"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "unified field theory"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "geometric theory of gravitation"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "electromagnetism"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "unified field theory"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "geometric theory of gravitation"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "electromagnetism"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "unified field theory"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "geometric theory of gravitation"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "electromagnetism"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "unified field theory"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "geometric theory of gravitation"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "electromagnetism"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "unified field theory"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "geometric theory of gravitation"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "electromagnetism"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "unified field theory"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "geometric theory of gravitation"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "electromagnetism"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "unified field theory"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "unified field theory"^^xsd:string .

# %% [raw]
# {"cell": 108, "stmt_key": "2_26", "chunk_num": 2, "stmt_idx": 26, "type": "rdf", "cid": "6b4722fbf8a52cbcce4db20bfd02c6554dcb21a71f4d7831b96f05f46f6a75de", "from_cid": "8651775adc0f7b9771cb92cf9e701be612a855e88c946550de079381ffcb5550"}

# %% [raw]
# # Statement [2.27]: As a result of his unsuccessful attempts, Albert Einstein became increasingly isolated from mainstream modern physics.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:relatedTo "mainstream modern physics" .

# %% [raw]
# {"cell": 110, "stmt_key": "2_27", "chunk_num": 2, "stmt_idx": 27, "type": "rdf", "cid": "93d9347fb86344bd2fc007a7ff336e2071710beefe75a0f599ecf6a3ad2e6859", "from_cid": "c03f6cd8780cad0a8bfeeb6cadad127ae1035de3d45387f18ef2cd72681fc103"}

# %% [raw]
# # Statement [3.1]: Albert Einstein was born in Ulm in the Kingdom of Württemberg in the German Empire on 14 March 1879
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Ulm" .

# %% [raw]
# {"cell": 112, "stmt_key": "3_1", "chunk_num": 3, "stmt_idx": 1, "type": "rdf", "cid": "c7462588b26074e12977e48598d1948a17bf99043627f2a54b0b36898d29f1e5", "from_cid": "32dbe8ce2834ada078b196643078785ad5c8d6d67d2952a9aca5bc780f3e98a4"}

# %% [raw]
# # Statement [3.2]: Hermann Einstein was a salesman and engineer
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_hermann_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_hermann_einstein> schema:hasOccupation "salesman" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_hermann_einstein> schema:hasOccupation "engineer" .

# %% [raw]
# {"cell": 114, "stmt_key": "3_2", "chunk_num": 3, "stmt_idx": 2, "type": "rdf", "cid": "d85ed8973e6afa13b9084fe35fea4d8229dc5c56ead649a880e6833badc76a2b", "from_cid": "01c7b0055d922c131345ca243232ef14adcfc2376e36626ce3d2f4e9feae9c4d"}

# %% [raw]
# # Statement [3.3]: Pauline Koch was the mother of Albert Einstein
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parent <"Pauline Koch"> .

# %% [raw]
# {"cell": 116, "stmt_key": "3_3", "chunk_num": 3, "stmt_idx": 3, "type": "rdf", "cid": "6de93e322ad94bec644283c117a9b4c37f57d47693f9dd75356f667cd112c45d", "from_cid": "df4ff1b2960bb6ae707df49eb34bc79e1ea7c4447f6f11388cd3b59b95e18c94"}

# %% [raw]
# # Statement [3.4]: In 1880, the family of Albert Einstein moved to Munich's borough of Ludwigsvorstadt-Isarvorstadt
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation "Munich's borough of Ludwigsvorstadt-Isarvorstadt" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1880"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation "Munich's borough of Ludwigsvorstadt-Isarvorstadt" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation "Munich's borough of Ludwigsvorstadt-Isarvorstadt"@en .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation "Munich's borough of Ludwigsvorstadt-Isarvorstadt"@en .

# %% [raw]
# {"cell": 118, "stmt_key": "3_4", "chunk_num": 3, "stmt_idx": 4, "type": "rdf", "cid": "6559a69e0c34dbb412bf6770ccd7a84963361af3794328fec0ba55185698b564", "from_cid": "d9fa8f4dd3bdb6d64366cf00e2d1757e3c6f67b287b8b475f5110361921c4ac7"}

# %% [raw]
# # Statement [3.5]: Elektrotechnische Fabrik J. Einstein & Cie was a company founded by Hermann Einstein and his uncle Jakob
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alternateName "Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Theoretical Physicist" .
# <https://en.wikipedia.org/wiki/Elektrotechnische_Fabrik_J._Einstein_&_Cie> rdf:type schema:Corporation .
# <https://en.wikipedia.org/wiki/Elektrotechnische_Fabrik_J._Einstein_&_Cie> schema:name "Elektrotechnische Fabrik J. Einstein & Cie" .
# <https://en.wikipedia.org/wiki/Hermann_Einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Hermann_Einstein> schema:name "Hermann Einstein" .
# <https://en.wikipedia.org/wiki/Jakob_Einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Jakob_Einstein> schema:name "Jakob Einstein" .
# <https://en.wikipedia.org/wiki/Elektrotechnische_Fabrik_J._Einstein_&_Cie> schema:founder <https://en.wikipedia.org/wiki/Hermann_Einstein> .
# <https://en.wikipedia.org/wiki/Elektrotechnische_Fabrik_J._Einstein_&_Cie> schema:founder <https://en.wikipedia.org/wiki/Jakob_Einstein> .
# <https://en.wikipedia.org/wiki/Hermann_Einstein> schema:relatedTo <https://en.wikipedia.org/wiki/Jakob_Einstein> .

# %% [raw]
# {"cell": 120, "stmt_key": "3_5", "chunk_num": 3, "stmt_idx": 5, "type": "rdf", "cid": "20b84d97b6bb802e51899f8835e5d07f55998708e02da53c9c1479d614efdce4", "from_cid": "1cbd1a7ad1ec6fa299279ae58ca69271baab2c9fc62500975d66ec08af443fde"}

# %% [raw]
# # Statement [3.6]: Elektrotechnische Fabrik J. Einstein & Cie manufactured electrical equipment based on direct current
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Organization .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Elektrotechnische Fabrik J. Einstein & Cie" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:description "A company that manufactured electrical equipment based on direct current" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Organization .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Elektrotechnische Fabrik J. Einstein & Cie" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:description "Company that manufactured electrical equipment based on direct current" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Organization .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Organization .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Organization .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Elektrotechnische Fabrik J. Einstein & Cie" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:description "Company that manufactured electrical equipment based on direct current" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Organization .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Elektrotechnische Fabrik J. Einstein & Cie" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:description "Company that manufactured electrical equipment based on direct current" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Organization .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Elektrotechnische Fabrik J. Einstein & Cie" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:description "Company that manufactured electrical equipment based on direct current" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Organization .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Elektrotechnische Fabrik J. Einstein & Cie" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:subjectOf "manufactured electrical equipment based on direct current" .

# %% [raw]
# {"cell": 122, "stmt_key": "3_6", "chunk_num": 3, "stmt_idx": 6, "type": "rdf", "cid": "0d5be722be4c11bfae03bf3e9b203769dcb69dd88661383cbbd223c02650293e", "from_cid": "5ecadb023addb9bceca9fffb2d408407d961c35586bcffc59488662c38eb4121"}

# %% [raw]
# # Statement [3.7]: Albert Einstein's parents were secular Ashkenazi Jews
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parents <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein_parent_1> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parents <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein_parent_1> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parents <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein_parent_2> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parents <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein_parent_1> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parents <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein_parent_1> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parents <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein_parent_2> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parents <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein_parent_1> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parents <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein_parent_1> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parents <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein_parent_2> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parents <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein_parent_1> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .

# %% [raw]
# {"cell": 124, "stmt_key": "3_7", "chunk_num": 3, "stmt_idx": 7, "type": "rdf", "cid": "9530489a0c6a484d294e5e7f41b297aa5f7aa03835e6a8fdf57b4295ff285370", "from_cid": "2e59b6e4089ccfe2e3c6d566e4abe2def2cdee1ad353d9e9e6211a70a3bcd0be"}

# %% [raw]
# # Statement [3.8]: Albert Einstein was slow to learn to talk when he was very young
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:additionalProperty "slow to learn to talk when young" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:description "Albert Einstein was slow to learn to talk when he was very young" .

# %% [raw]
# {"cell": 126, "stmt_key": "3_8", "chunk_num": 3, "stmt_idx": 8, "type": "rdf", "cid": "f23610bf4d343b45aacdf7cff3ca0ad5432d9d39eeb30958af8da45c17354dd3", "from_cid": "f840f5849314cbb99f811c01fb2c63d2ff4bafa4337a8d5d2449577254707c64"}

# %% [raw]
# # Statement [3.9]: Albert Einstein's parents worried that he had a learning disability when he was very young
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parent <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>_parent .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parent <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>_parent .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parent <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>_parent .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parent <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>_parent .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parent schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parent schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parent schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parent schema:Person .

# %% [raw]
# {"cell": 128, "stmt_key": "3_9", "chunk_num": 3, "stmt_idx": 9, "type": "rdf", "cid": "034bf66e9d25dfbc39a271aa3ca4322032116dd9a129c53215b977b5f1a29733", "from_cid": "1a04b2d91e1a34f6c530fb7f1d5da7324446fc2669bfbee9facf9a8632d22d73"}

# %% [raw]
# # Statement [3.10]: When Albert Einstein was five and sick in bed, his father brought him a compass
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#give_action> rdf:type schema:GiveAction .
# <#give_action> schema:sender <#father> .
# <#give_action> schema:recipient <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#give_action> schema:object <#compass> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "5"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:healthCondition "sick in bed" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#give_action> rdf:type schema:GiveAction .
# <#give_action> schema:sender <#father> .
# <#give_action> schema:recipient <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#give_action> schema:object <#compass> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parent <#father> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#give_action> rdf:type schema:GiveAction .
# <#give_action> schema:sender <#father> .
# <#give_action> schema:recipient <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#give_action> schema:object <#compass> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parent <#father> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#father> rdf:type schema:Person .
# <#compass> rdf:type schema:Thing .
# <#give_action> rdf:type schema:GiveAction .
# <#give_action> schema:sender <#father> .
# <#give_action> schema:recipient <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#give_action> schema:object <#compass> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parent <#father> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#father> rdf:type schema:Person .
# <#compass> rdf:type schema:Thing .
# <#give_action> rdf:type schema:GiveAction .
# <#give_action> schema:sender <#father> .
# <#give_action> schema:recipient <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#give_action> schema:object <#compass> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parent <#father> .

# %% [raw]
# {"cell": 130, "stmt_key": "3_10", "chunk_num": 3, "stmt_idx": 10, "type": "rdf", "cid": "e03e3dcbd12c2fc8b3548b02822b05746006a0a17db3e1efb9c69cb0f9a18a0c", "from_cid": "a194776db1f69c99d847abd59bc123807c53c521c208a0d64a908fee3d1701b6"}

# %% [raw]
# # Statement [3.11]: The compass sparked Albert Einstein's lifelong fascination with electromagnetism
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "Electromagnetism" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "Electromagnetism" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "Electromagnetism" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "Electromagnetism" .

# %% [raw]
# {"cell": 132, "stmt_key": "3_11", "chunk_num": 3, "stmt_idx": 11, "type": "rdf", "cid": "3ac0bdd4cf9adcdcc079ae17eeea9f10ae0bb828c90eb817808067877dea9c80", "from_cid": "a38b168f028da418acebe01b8b3247fdebabda06427076520dfbc5089747fe6d"}

# %% [raw]
# # Statement [3.12]: Albert Einstein realized that something deeply hidden had to be behind things
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "something deeply hidden had to be behind things" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "somthing deeply hidden had to be behind things" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "somthing deeply hidden had to be behind things" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "something deeply hidden had to be behind things" .

# %% [raw]
# {"cell": 134, "stmt_key": "3_12", "chunk_num": 3, "stmt_idx": 12, "type": "rdf", "cid": "1e4d22eb9ae5be9b70c4aa1776d4a44b81663ab272bad633c5cf1802c67a3048", "from_cid": "c8b3cd665413484f44c06eb43c6ec3bc6e7e93e3428badd0fdd56775944e9efc"}

# %% [raw]
# # Statement [3.13]: Albert Einstein attended St. Peter's Catholic elementary school in Munich from the age of five
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <#st_peters_catholic_school> .
# <#st_peters_catholic_school> rdf:type schema:School .
# <#st_peters_catholic_school> schema:address "Munich" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#st_peters_catholic_school> rdf:type schema:School .
# <#st_peters_catholic_school> schema:name "St. Peter's Catholic elementary school" .
# <#st_peters_catholic_school> schema:address "Munich" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <#st_peters_catholic_school> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#st_peters_catholic_school> rdf:type schema:School .
# <#st_peters_catholic_school> schema:name "St. Peter's Catholic elementary school" .
# <#st_peters_catholic_school> schema:address "Munich" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <#st_peters_catholic_school> .

# %% [raw]
# {"cell": 136, "stmt_key": "3_13", "chunk_num": 3, "stmt_idx": 13, "type": "rdf", "cid": "653733230f8695f4b343098041454146af584c8db40a32335e02ab43743e8a8d", "from_cid": "2b8b62aaa8842c46268762d1b89cadb12255d49e20deb451e0f256b0dfb59fb6"}

# %% [raw]
# # Statement [3.14]: Albert Einstein was transferred to the Luitpold Gymnasium when he was eight
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Luitpold_Gymnasium> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Luitpold_Gymnasium> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Luitpold_Gymnasium> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "8"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Luitpold_Gymnasium> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Luitpold_Gymnasium> .

# %% [raw]
# {"cell": 138, "stmt_key": "3_14", "chunk_num": 3, "stmt_idx": 14, "type": "rdf", "cid": "8a662a5448ef38b0b12ba38396753f3f0cdd7314dd0ec4d82c647a90d35e0cbd", "from_cid": "30d2582564da99bd25ee86cb2bd490adb53dce4ed5983c51af86a01d85b99bbc"}

# %% [raw]
# # Statement [3.15]: The Luitpold Gymnasium provided Albert Einstein with advanced primary and then secondary school education
# schema:Person rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Luitpold_Gymnasium> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Luitpold_Gymnasium> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Luitpold_Gymnasium> rdf:type schema:EducationalOrganization .

# %% [raw]
# {"cell": 140, "stmt_key": "3_15", "chunk_num": 3, "stmt_idx": 15, "type": "rdf", "cid": "b905aebed7cf5ca2fa71f97caa6b546bffd3ced013cb3b1a1db7090df19850cd", "from_cid": "9417b3d6d0ec4023735dff67d6fabbb506ded050d4e2aba27dc74f09d9f0477b"}

# %% [raw]
# # Statement [4.1]: In 1894, Hermann and Jakob's company tendered for a contract to install electric lighting in Munich.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#event_1894> rdf:type schema:Event .
# <#event_1894> schema:startDate "1894"^^xsd:date .
# <#event_1894> schema:name "Company tendering for contract" .
# <#event_1894> schema:description "Hermann and Jakob's company tendered for a contract to install electric lighting in Munich" .
# <#company_tender_event> rdf:type schema:Event .
# <#company_tender_event> schema:startDate "1894"^^xsd:date .
# <#company_tender_event> schema:description "Hermann and Jakob's company tendered for a contract to install electric lighting in Munich" .
# <#company_tender_event> schema:name "Company Tender Event" .
# <#company_tender_event> rdf:type schema:Event .
# <#company_tender_event> schema:startDate "1894"^^xsd:date .
# <#company_tender_event> schema:description "Hermann and Jakob's company tendered for a contract to install electric lighting in Munich" .
# <#event_1894> rdf:type schema:Event .
# <#event_1894> schema:startDate "1894"^^xsd:date .
# <#event_1894> schema:description "Hermann and Jakob's company tendered for a contract to install electric lighting in Munich" .

# %% [raw]
# {"cell": 142, "stmt_key": "4_1", "chunk_num": 4, "stmt_idx": 1, "type": "rdf", "cid": "3b8a7d16255bc92bca1e90d37964ee2433f6ca874227f9b64c85908a5a5d5ae8", "from_cid": "1ab980732013c4d5349bf6a2f2aca99317d45f2679cc541de645158da27eb1c3"}

# %% [raw]
# # Statement [4.2]: The company lacked the capital required to update their technology from direct current to alternating current.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Theoretical Physicist" .
# <#company> rdf:type schema:Organization .
# <#company> rdf:type schema:Corporation .
# <#company> rdf:type schema:Organization .
# <#company> schema:ownershipFundingInfo "Lacked capital for technology update" .
# <#company> rdf:type schema:Corporation .
# <#company> rdf:type schema:Organization .
# <#company> rdf:type schema:Organization .
# <#company> rdf:type schema:Corporation .

# %% [raw]
# {"cell": 144, "stmt_key": "4_2", "chunk_num": 4, "stmt_idx": 2, "type": "rdf", "cid": "6ba5355fc1aa0cf2a497f6279b2ab3a3d81a810ded70800922f5b47110e54047", "from_cid": "ff3e555e5c91426c623b72c551da74b8a2f061572894fecfe5ac422343e19ad0"}

# %% [raw]
# # Statement [4.3]: The failure of their bid forced them to sell their Munich factory.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .

# %% [raw]
# {"cell": 146, "stmt_key": "4_3", "chunk_num": 4, "stmt_idx": 3, "type": "rdf", "cid": "54dca32183d6678f215c375d09fb2b7cd0878fbbf20027b4915b7aafbb3d47af", "from_cid": "64a73236c464d949ca99c5ff085c1edbf0a9640d9d74dbf4f758c0585a5d74ec"}

# %% [raw]
# # Statement [4.4]: The Einstein family moved to Italy, first to Milan and then to Pavia.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:familyName "Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Germany" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:familyName "Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Germany" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "family moved to Italy, first to Milan and then to Pavia" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Germany" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# schema:Country rdf:type rdfs:Class .
# schema:Place rdf:type rdfs:Class .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:familyName "Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:familyName "Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:familyName "Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:familyName "Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Germany" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:familyName "Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:familyName "Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Germany" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:familyName "Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Germany" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:familyName "Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Germany" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:familyName "Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:familyName "Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Germany" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:familyName "Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .

# %% [raw]
# {"cell": 148, "stmt_key": "4_4", "chunk_num": 4, "stmt_idx": 4, "type": "rdf", "cid": "d1ffc382d247a2bf1879ff7dac85bc8cbac11c3519a417595aaecf1f6ad755ad", "from_cid": "2fcbff608a19450096756ed9c06289eef4c93bdc8df73b357da864e1c59a28c9"}

# %% [raw]
# # Statement [4.5]: The Einstein family settled in Palazzo Cornazzani in Pavia.
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:homeLocation "Palazzo Cornazzani in Pavia"^^xsd:string .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:homeLocation "Palazzo Cornazzani in Pavia"^^xsd:string .

# %% [raw]
# {"cell": 150, "stmt_key": "4_5", "chunk_num": 4, "stmt_idx": 5, "type": "rdf", "cid": "dbb0c6a51ef4e3a4d7d235b6e7bb9cd21a57dbdddfd86a0de0e1a711e6ea7a9c", "from_cid": "1c14dd748ce60d7842761f23380da1ee9e6c90a9572e03f438ad80c7bc0329c4"}

# %% [raw]
# # Statement [4.6]: Albert Einstein was fifteen years old in 1894.
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:birthDate "1879-03-14"^^xsd:date .

# %% [raw]
# {"cell": 152, "stmt_key": "4_6", "chunk_num": 4, "stmt_idx": 6, "type": "rdf", "cid": "69cbbf7c74e660cf708ed39a827a2c619baa7cd58cb6e85e18bb9a41452cd747", "from_cid": "5fa9804892f1dc6872d763a75dd9a4fbbc014431abfe79c858b622a7397c7214"}

# %% [raw]
# # Statement [4.7]: Albert Einstein stayed behind in Munich to finish his schooling.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:location "Munich"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:education "schooling"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:location "Munich"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:location "Munich"^^xsd:string .

# %% [raw]
# {"cell": 154, "stmt_key": "4_7", "chunk_num": 4, "stmt_idx": 7, "type": "rdf", "cid": "179c490559068ab45fbfef6ae147d89c8951c98d3be448a760ce54b2a886b998", "from_cid": "309b3accc3976d0228ff2903acadf3651cb0b83639ebaf6c52c754e602a06246"}

# %% [raw]
# # Statement [4.8]: Albert Einstein's father wanted him to study electrical engineering.
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:parent <#father> .
# <#father> rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:parent <#father> .
# <#father> rdf:type schema:Person .
# <#father> schema:seeks <#electrical_engineering_study> .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:parent <#father> .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:parent <#father> .
# <#father> rdf:type schema:Person .
# <#father> schema:seeks "study electrical engineering"^^xsd:string .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:parent <#father> .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:parent <#father> .
# <#father> rdf:type schema:Person .

# %% [raw]
# {"cell": 156, "stmt_key": "4_8", "chunk_num": 4, "stmt_idx": 8, "type": "rdf", "cid": "1bab8e0bfea5ac189c810b50df19660da2fd554ba82844db24e50b10a0525a20", "from_cid": "469d49528d45c4e96049be701922608b8454f8b0266b025e8afd0c3b9799785c"}

# %% [raw]
# # Statement [4.9]: Albert Einstein was a fractious pupil in Munich.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation "Munich" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Munich" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation "Munich" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Student" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation "Munich" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Student" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation "Munich" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Student" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Munich" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Student" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation "Munich" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Student" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Munich" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Student" .

# %% [raw]
# {"cell": 158, "stmt_key": "4_9", "chunk_num": 4, "stmt_idx": 9, "type": "rdf", "cid": "6b30dfb713ff9f7c4111a34d7c80d04c9250d3cafc6e31c5362ad05b6d897ca3", "from_cid": "72d71933e916f32b2b8f5e54bed2eab8e81069f484a72a05b044585d09aa297f"}

# %% [raw]
# # Statement [4.10]: The Gymnasium's regimen and teaching methods were not congenial to Albert Einstein.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#gymnasium> rdf:type schema:School .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#gymnasium> rdf:type schema:School .
# <#gymnasium> schema:name "Gymnasium" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#gymnasium> rdf:type schema:School .

# %% [raw]
# {"cell": 160, "stmt_key": "4_10", "chunk_num": 4, "stmt_idx": 10, "type": "rdf", "cid": "e209f3ff51a199bd9f507e1fc8009936c3fc66d9f8c2d45f0d79f461c802c4dc", "from_cid": "71f36b675e86ee41b9f4f0e48ae92468cb3eb7315da90643b11d4c26539ebd04"}

# %% [raw]
# # Statement [4.11]: Albert Einstein later wrote that the school's policy of strict rote learning was harmful to creativity.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:author "Albert Einstein later wrote that the school's policy of strict rote learning was harmful to creativity."^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:author "Albert Einstein later wrote that the school's policy of strict rote learning was harmful to creativity."^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:author "Albert Einstein later wrote that the school's policy of strict rote learning was harmful to creativity."^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:author "Albert Einstein later wrote that the school's policy of strict rote learning was harmful to creativity."^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:author "Albert Einstein later wrote that the school's policy of strict rote learning was harmful to creativity."^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:author "Albert Einstein later wrote that the school's policy of strict rote learning was harmful to creativity."^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:author "Albert Einstein later wrote that the school's policy of strict rote learning was harmful to creativity."^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:author "Albert Einstein later wrote that the school's policy of strict rote learning was harmful to creativity."^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:author "Albert Einstein later wrote that the school's policy of strict rote learning was harmful to creativity."^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:author "Albert Einstein later wrote that the school's policy of strict rote learning was harmful to creativity." .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .

# %% [raw]
# {"cell": 162, "stmt_key": "4_11", "chunk_num": 4, "stmt_idx": 11, "type": "rdf", "cid": "a9d0133967c1c8e51422d982bb3bfb01bd0d0e4ec56ad31a8f86643155d1f938", "from_cid": "5e2b302822014571d5771f0305f54ea6f03606bd82dcf61d397d1ff6c36358ca"}

# %% [raw]
# # Statement [4.12]: At the end of December 1894, a doctor's letter persuaded the Luitpold's authorities to release Albert Einstein from their care.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation <https://en.wikipedia.org/wiki/Luitpold's_authorities> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:identifier "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:additionalType "Person" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Ulm, Germany" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathPlace "Princeton, New Jersey, USA" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:identifier "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Doctor of Philosophy" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:mainEntityOfPage <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:additionalName "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Ulm, Germany" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathPlace "Princeton, New Jersey, USA" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "German" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "ETH Zurich" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:mainEntityOfPage <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:identifier "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "German" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "ETH Zurich" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 164, "stmt_key": "4_12", "chunk_num": 4, "stmt_idx": 12, "type": "rdf", "cid": "d625a567593892c5faaeac613464285f35c39a984a1269869d5882d12956aeb9", "from_cid": "b2b4e0bef4428902a7704d414f78b58278b204359124f4e3484a0efb122b3862"}

# %% [raw]
# # Statement [4.13]: Albert Einstein joined his family in Pavia in December 1894.
# # Error: ValidationError: 1 validation error for emit_triples
# triples
#   Input should be a valid list [type

# %% [raw]
# {"cell": 166, "stmt_key": "4_13", "chunk_num": 4, "stmt_idx": 13, "type": "rdf", "cid": "87f1d6c96edcb56e6ab4f29dec4d6134f1aed5534c675361e3eaea9a71d0e847", "from_cid": "ab02b05afe913589fe2d936652bc5ab0b417cc919694e2fa42f88e3aac8a385a"}

# %% [raw]
# # Statement [4.14]: While in Italy as a teenager, Albert Einstein wrote an essay entitled "On the Investigation of the State of the Ether in a Magnetic Field".
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator "On the Investigation of the State of the Ether in a Magnetic Field" .
# "On the Investigation of the State of the Ether in a Magnetic Field" rdf:type schema:Manuscript .
# "On the Investigation of the State of the Ether in a Magnetic Field" schema:headline "On the Investigation of the State of the Ether in a Magnetic Field" .
# "On the Investigation of the State of the Ether in a Magnetic Field" schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# "On the Investigation of the State of the Ether in a Magnetic Field" rdf:type schema:Manuscript .
# "On the Investigation of the State of the Ether in a Magnetic Field" schema:headline "On the Investigation of the State of the Ether in a Magnetic Field" .
# "On the Investigation of the State of the Ether in a Magnetic Field" schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCreativeWork "On the Investigation of the State of the Ether in a Magnetic Field" .
# "On the Investigation of the State of the Ether in a Magnetic Field" rdf:type schema:Manuscript .
# "On the Investigation of the State of the Ether in a Magnetic Field" schema:headline "On the Investigation of the State of the Ether in a Magnetic Field" .
# "On the Investigation of the State of the Ether in a Magnetic Field" schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# "On the Investigation of the State of the Ether in a Magnetic Field" rdf:type schema:Manuscript .
# "On the Investigation of the State of the Ether in a Magnetic Field" schema:headline "On the Investigation of the State of the Ether in a Magnetic Field" .
# "On the Investigation of the State of the Ether in a Magnetic Field" schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# "On the Investigation of the State of the Ether in a Magnetic Field" rdf:type schema:Manuscript .
# "On the Investigation of the State of the Ether in a Magnetic Field" schema:headline "On the Investigation of the State of the Ether in a Magnetic Field" .
# "On the Investigation of the State of the Ether in a Magnetic Field" schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# "On the Investigation of the State of the Ether in a Magnetic Field" rdf:type schema:Manuscript .
# "On the Investigation of the State of the Ether in a Magnetic Field" schema:headline "On the Investigation of the State of the Ether in a Magnetic Field" .
# "On the Investigation of the State of the Ether in a Magnetic Field" schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .

# %% [raw]
# {"cell": 168, "stmt_key": "4_14", "chunk_num": 4, "stmt_idx": 14, "type": "rdf", "cid": "af74a89957f4d42e868dea5839797d02dec18c845440e695de6ae22aa1c894ae", "from_cid": "17f901c5386972fb106f25309889b139ef6ae77a72e4629bf4ecdb9150d2bc48"}

# %% [raw]
# # Statement [5.1]: Albert Einstein excelled at physics and mathematics from an early age
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:skills "physics" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:skills "mathematics" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:skills "physics" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:skills "mathematics" .

# %% [raw]
# {"cell": 170, "stmt_key": "5_1", "chunk_num": 5, "stmt_idx": 1, "type": "rdf", "cid": "ce71eb011c054709bb6d3d4c215a9a164e380f17c3ebae1839c011ce06963d2b", "from_cid": "d2b9edee568582a20ea79228c73fe6fa155b3512ccaad9390af1756cf52e3efb"}

# %% [raw]
# # Statement [5.2]: Albert Einstein acquired the mathematical expertise normally only found in a child several years his senior
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:skills "mathematical expertise" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:skills "mathematical expertise" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "mathematics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:skills "mathematical expertise" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "mathematics" .

# %% [raw]
# {"cell": 172, "stmt_key": "5_2", "chunk_num": 5, "stmt_idx": 2, "type": "rdf", "cid": "e556f53e1f6d7ff67120bf03138cc801b857997c9ac2338b8c50f285fac656d4", "from_cid": "cfc1397d1a97659bbb8f35bc18a9965cf1854003607791a5634831d21fb26776"}

# %% [raw]
# # Statement [5.3]: Albert Einstein began teaching himself algebra when he was twelve years old
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "algebra" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "mathematics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "algebra" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "mathematics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "algebra" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "mathematics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "algebra" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "mathematics" .

# %% [raw]
# {"cell": 174, "stmt_key": "5_3", "chunk_num": 5, "stmt_idx": 3, "type": "rdf", "cid": "08a4b94462626a6ae1ae24fef745d6748d374f956e8a05dd56614ba49fa1df84", "from_cid": "5a4f4af4c71dbe9cde140013017e354061408bfa0e0e5f244ab10fa508e246f4"}

# %% [raw]
# # Statement [5.4]: Albert Einstein began teaching himself calculus when he was twelve years old
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:additionalType "learning"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:achievement "Began self-teaching calculus at age 12"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "Calculus" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:additionalType "EducationalAchievement"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:description "Begun self-teaching calculus at age 12"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:achievement "Begun self-teaching calculus at age 12"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "Calculus" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:description "Begun self-teaching calculus at age 12"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:achievement "Begun self-teaching calculus at age 12"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:achievement "Begun self-teaching calculus at age 12"^^xsd:string .

# %% [raw]
# {"cell": 176, "stmt_key": "5_4", "chunk_num": 5, "stmt_idx": 4, "type": "rdf", "cid": "f3965e95855ebc41700e970c8afb72bf73b8b807895d3c216c176f2ea03f7d62", "from_cid": "989ee4b09441acd51dc4a541644a327b6086d9ebdb71c3de5f2efabb175b4853"}

# %% [raw]
# # Statement [5.5]: Albert Einstein began teaching himself Euclidean geometry when he was twelve years old
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:studySubject "Euclidean geometry" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:age "12"^^xsd:integer .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:studySubject "Euclidean geometry" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:age "12"^^xsd:integer .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:studySubject "Euclidean geometry" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:age "12"^^xsd:integer .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:studySubject "Euclidean geometry" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:age "12"^^xsd:integer .

# %% [raw]
# {"cell": 178, "stmt_key": "5_5", "chunk_num": 5, "stmt_idx": 5, "type": "rdf", "cid": "53cfdf263678fdc9d41513e1e157b1a504a26d1a884e0347b696a1f699da7d70", "from_cid": "f8e8bd76bcb47ce45a2c7d55a03237b93e925fabdfe9f0ae1dbe14d8c31b196e"}

# %% [raw]
# # Statement [5.6]: Albert Einstein discovered an original proof of the Pythagorean theorem before his thirteenth birthday
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#discovery_action> rdf:type schema:Action .
# <#discovery_action> schema:agent <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#discovery_action> schema:result "Proof of the Pythagorean theorem" .
# <#discovery_action> schema:startDate "1892-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#proof_discovery> rdf:type schema:CreativeWork .
# <#proof_discovery> schema:name "Proof of the Pythagorean theorem" .
# <#proof_discovery> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#proof_discovery> schema:dateCreated "1892-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#childhood_discovery> rdf:type schema:CreativeWork .
# <#childhood_discovery> schema:name "Proof of the Pythagorean theorem" .
# <#childhood_discovery> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#childhood_discovery> schema:dateCreated "1892-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#discovery> rdf:type schema:CreativeWork .
# <#discovery> schema:name "Proof of the Pythagorean theorem" .
# <#discovery> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#discovery> schema:dateCreated "1892-03-14"^^xsd:date .

# %% [raw]
# {"cell": 180, "stmt_key": "5_6", "chunk_num": 5, "stmt_idx": 6, "type": "rdf", "cid": "e84fb700dc3276f26dcb22993ddc57fba691fce72acadcc55d1ba8f694d76c7a", "from_cid": "7bded7d0a7f410277a756b5a4913d9bb5ebdba2a4b32759a91d931bd1f95d942"}

# %% [raw]
# # Statement [5.7]: Max Talmud was a family tutor of Albert Einstein
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#max_talmud> rdf:type schema:Person .
# <#max_talmud> schema:name "Max Talmud" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <#max_talmud> .
# <#max_talmud> schema:knows <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#max_talmud> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#max_talmud> rdf:type schema:Person .
# <#max_talmud> schema:knows <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#max_talmud> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#max_talmud> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#max_talmud> schema:knows <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#max_talmud> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#max_talmud> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#max_talmud> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#max_talmud> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#max_talmud> schema:knows <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#max_talmud> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .

# %% [raw]
# {"cell": 182, "stmt_key": "5_7", "chunk_num": 5, "stmt_idx": 7, "type": "rdf", "cid": "34d6b844e8cb540d1ded14db2fcc32ff21a9176c33db562d0ce91c208bfe5bd3", "from_cid": "fde22efaadd01f6229ca9ba6784b4df05b09e988c81f353dd7167ec1e8995184"}

# %% [raw]
# # Statement [5.8]: Max Talmud said that only a short time after he had given the twelve year old Albert Einstein a geometry textbook, the boy had worked through the whole book
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "12"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "12"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "12"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "12"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "12"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "12"^^xsd:integer .

# %% [raw]
# {"cell": 184, "stmt_key": "5_8", "chunk_num": 5, "stmt_idx": 8, "type": "rdf", "cid": "f489aec3f0113d2a7e4a4ed8669f4d29138079ec328ebbc86b8d65bf38552b91", "from_cid": "32a3c19fac0b866417ce54f11c2f5ce17c2a1eea5ad206f5c49a9e4e15b5ed9c"}

# %% [raw]
# # Statement [5.9]: Max Talmud said that the twelve year old Albert Einstein devoted himself to higher mathematics after working through the geometry textbook
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "12"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "higher mathematics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "12"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "higher mathematics" .

# %% [raw]
# {"cell": 186, "stmt_key": "5_9", "chunk_num": 5, "stmt_idx": 9, "type": "rdf", "cid": "cea8fa7f3ff9eb0a8d443469e7fba4d19f2302812922883808c526bee4ab1d36", "from_cid": "75e48b9beb3e2035176007a1e695eb1573c88e49ccc5a3c4b9fa8ac25525cea5"}

# %% [raw]
# # Statement [5.10]: Max Talmud said that the flight of the mathematical genius of Albert Einstein was so high that Max Talmud could not follow
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knownFor "Mathematical genius" .
# <#max_talmud> rdf:type schema:Person .
# <#max_talmud> schema:name "Max Talmud" .
# <#statement_about_einstein> rdf:type schema:Text .
# <#statement_about_einstein> schema:description "The flight of the mathematical genius of Albert Einstein was so high that Max Talmud could not follow" .
# <#max_talmud> rdf:type schema:Person .
# <#max_talmud> schema:name "Max Talmud" .
# <#albert_einstein> rdf:type schema:Person .
# <#albert_einstein> schema:name "Albert Einstein" .
# <#statement> rdf:type schema:CreativeWork .
# <#statement> schema:description "The flight of the mathematical genius of Albert Einstein was so high that Max Talmud could not follow" .
# <#statement> schema:creator <#max_talmud> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#max_talmud> rdf:type schema:Person .
# <#max_talmud> schema:name "Max Talmud" .
# <#statement> rdf:type schema:CreativeWork .
# <#statement> schema:description "The flight of the mathematical genius of Albert Einstein was so high that Max Talmud could not follow" .
# <#statement> schema:creator <#max_talmud> .
# <#max_talmud> rdf:type schema:Person .
# <#max_talmud> schema:name "Max Talmud" .
# <#albert_einstein> rdf:type schema:Person .
# <#albert_einstein> schema:name "Albert Einstein" .
# <#statement> rdf:type schema:Quotation .
# <#statement> schema:text "The flight of the mathematical genius of Albert Einstein was so high that Max Talmud could not follow" .
# <#statement> schema:author <#max_talmud> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#max_talmud> rdf:type schema:Person .
# <#max_talmud> schema:name "Max Talmud" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#max_talmud> rdf:type schema:Person .
# <#max_talmud> schema:name "Max Talmud" .

# %% [raw]
# {"cell": 188, "stmt_key": "5_10", "chunk_num": 5, "stmt_idx": 10, "type": "rdf", "cid": "df49e1ae92c04d45a4f9e1f18691f5d0d2ec7988ed31e3b5ad81f0dd2f00bf8f", "from_cid": "3ad083b206187f8e6e3f57670ab3a5480d32449030de3c3f6388f2ff5fc0a55a"}

# %% [raw]
# # Statement [5.11]: Albert Einstein recorded that he had mastered integral and differential calculus while he was fourteen years old
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "integral and differential calculus" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:skills "integral and differential calculus" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "integral and differential calculus" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "integral and differential calculus" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:skills "integral and differential calculus" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "integral and differential calculus" .

# %% [raw]
# {"cell": 190, "stmt_key": "5_11", "chunk_num": 5, "stmt_idx": 11, "type": "rdf", "cid": "a18f9260c87fff41959c8b09c0a36295d42811e1aea03788e4f98e48bdd1fa5b", "from_cid": "580c73e4f53ba723d2dafd26df900b5c53ec58d901b24c6af2832bf13b9d120e"}

# %% [raw]
# # Statement [5.12]: Albert Einstein was confident that nature could be understood as a mathematical structure when he was twelve years old
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:description "Confident that nature could be understood as a mathematical structure at age 12" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:description "At age 12, Albert Einstein was confident that nature could be understood as a mathematical structure" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "mathematical structure of nature" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:description "At age 12, Albert Einstein was confident that nature could be understood as a mathematical structure" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:description "At age 12, Albert Einstein was confident that nature could be understood as a mathematical structure" .

# %% [raw]
# {"cell": 192, "stmt_key": "5_12", "chunk_num": 5, "stmt_idx": 12, "type": "rdf", "cid": "39a683c9186674a751b99ba8a102002420c5a16d0eeb238aebb6c25d5ea898d8", "from_cid": "aa185381cea67bac205eeeadd4498bc73bf606cec00b30c232805a12e63594d3"}

# %% [raw]
# # Statement [6.1]: At thirteen years old, Albert Einstein was introduced to Kant's Critique of Pure Reason by Talmud.
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:age "13"^^xsd:integer .
# <#kant_work> rdf:type schema:Book .
# <#kant_work> schema:name "Kant's Critique of Pure Reason" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:knows <#kant_work> .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# <#kant_work> rdf:type schema:Book .
# <#kant_work> schema:name "Kant's Critique of Pure Reason" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:knows <#kant_work> .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# <#kant_work> rdf:type schema:Book .
# <#kant_work> schema:name "Kant's Critique of Pure Reason" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:knows <#kant_work> .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# <#kant_work> rdf:type schema:Book .
# <#kant_work> schema:name "Kant's Critique of Pure Reason" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:knows <#kant_work> .

# %% [raw]
# {"cell": 194, "stmt_key": "6_1", "chunk_num": 6, "stmt_idx": 1, "type": "rdf", "cid": "e90db565f75bc99d72b671784e6cb8db3d37dbaa2909cd4b91d70812bd10d2f9", "from_cid": "76ff290284765576ef2c7d98da9d4f3cf51eead3727646f023f221290fd046f2"}

# %% [raw]
# # Statement [6.2]: At thirteen years old, Albert Einstein considered Kant to be his favorite philosopher.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "13"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "Philosophy" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "13"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "13"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "13"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "13"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "Philosophy" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "13"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "13"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "13"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "13"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "13"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "13"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .

# %% [raw]
# {"cell": 196, "stmt_key": "6_2", "chunk_num": 6, "stmt_idx": 2, "type": "rdf", "cid": "8b00bbc23608aaf292ef8dbbabe48ef64eb8e5e1b6de16b78c17eadc79368a21", "from_cid": "0a27f984e2ad43deaece6a20ab9d2d65ea6aaf3615173ba90d76cbfd1b9ba5a0"}

# %% [raw]
# # Statement [6.3]: At thirteen years old, Albert Einstein demonstrated understanding of Kant's works according to Talmud.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:lifeEvent "At thirteen years old, Albert Einstein demonstrated understanding of Kant's works according to Talmud" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:lifeEvent "Demonstrated understanding of Kant's works at age 13" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:lifeEvent "At thirteen years old, Albert Einstein demonstrated understanding of Kant's works" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:lifeEvent "Demonstrated understanding of Kant's works at age 13" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:lifeEvent "At thirteen years old, Albert Einstein demonstrated understanding of Kant's works" .

# %% [raw]
# {"cell": 198, "stmt_key": "6_3", "chunk_num": 6, "stmt_idx": 3, "type": "rdf", "cid": "da479aa51fe4ab363d9f69485394f5393349f772a5bc026c55a98555f1009195", "from_cid": "e588725f8916ab9b59031d60193a6813a07a850f4285e5465dddd20b4fa579b5"}

# %% [raw]
# # Statement [6.4]: In 1895, Albert Einstein was sixteen years old when he sat the entrance examination for the federal polytechnic school in Zurich, Switzerland.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "16"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "https://en.wikipedia.org/wiki/Federal_Polytechnic_School_of_Zurich" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "<https://en.wikipedia.org/wiki/Albert_Einstein#examination_1895>" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "education" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Federal Polytechnic School of Zurich" .

# %% [raw]
# {"cell": 200, "stmt_key": "6_4", "chunk_num": 6, "stmt_idx": 4, "type": "rdf", "cid": "816fd1e4063dd69535365271055159ee4a9acdee50ae78c5ba28fc343f5d0b7f", "from_cid": "f04766c1480f0821091b8e9d5f6590296b860e64465663d3e114808b8ad66500"}

# %% [raw]
# # Statement [6.5]: In 1895, Albert Einstein failed to reach the required standard in the general part of the entrance examination for the federal polytechnic school.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:achievement "Failed to reach required standard in the general part of the entrance examination for the federal polytechnic school in 1895" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasAchievement "Failed entrance examination for federal polytechnic school in 1895" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:achievement "Failed to reach required standard in the general part of the entrance examination for the federal polytechnic school" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:achievement "Failed to reach required standard in the general part of the entrance examination for the federal polytechnic school in 1895" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:achievement "Failed entrance examination for federal polytechnic school in 1895" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:achievement "Failed entrance examination for federal polytechnic school in 1895" .

# %% [raw]
# {"cell": 202, "stmt_key": "6_5", "chunk_num": 6, "stmt_idx": 5, "type": "rdf", "cid": "ae545fa86f5384ecec2f45d2aacaec044d2f527b33d14ae54cfd62678fc2473f", "from_cid": "ecc0b196f9630bfb40aa115482e77c3f765042b76a93e0893dd23b9056809c41"}

# %% [raw]
# # Statement [6.6]: In 1895, Albert Einstein performed with distinction in physics and mathematics in the entrance examination for the federal polytechnic school.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Federal Polytechnic School" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Distinction" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Mathematics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:dateIssued "1895"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Federal Polytechnic School" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:educationalRole "Examinee" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Distinction" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Mathematics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Federal Polytechnic School" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Distinction" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Mathematics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Federal Polytechnic School" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Distinction" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Mathematics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:dateIssued "1895"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Federal Polytechnic School" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Distinction" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Mathematics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:dateIssued "1895"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Federal Polytechnic School" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Distinction" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Mathematics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Federal Polytechnic School" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Distinction" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Mathematics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:dateIssued "1895"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Federal Polytechnic School" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Distinction" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Mathematics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .

# %% [raw]
# {"cell": 204, "stmt_key": "6_6", "chunk_num": 6, "stmt_idx": 6, "type": "rdf", "cid": "17ec5ba7880340be8b739f824f5c1286a003623a120fe1da23786af84265009e", "from_cid": "03a9c4692f794ab35bc2dff2f667a0d373cbaf4a07bd107f9ffaf1cd415d4e7d"}

# %% [raw]
# # Statement [6.7]: In 1895, the principal of the federal polytechnic school advised Albert Einstein to complete his secondary education at the Argovian cantonal school in Aarau, Switzerland.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 206, "stmt_key": "6_7", "chunk_num": 6, "stmt_idx": 7, "type": "rdf", "cid": "92d08388cd4d8806364f61f847a9ec63d863cf0742ce2ecf092449e4f4cdd971", "from_cid": "3aa8dccc3924948f26fe397159d87b2a3d26f019aa3fedb8f47072066d8604d1"}

# %% [raw]
# # Statement [6.8]: Albert Einstein graduated from the Argovian cantonal school in Aarau, Switzerland, in 1896.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <https://example.org/school_argovian_cantonal_school> .
# <https://example.org/school_argovian_cantonal_school> rdf:type schema:School .
# <https://example.org/school_argovian_cantonal_school> schema:name "Argovian cantonal school" .
# <https://example.org/school_argovian_cantonal_school> schema:location "Aarau, Switzerland" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential <https://example.org/credential_einstein_graduation> .
# <https://example.org/credential_einstein_graduation> rdf:type schema:EducationalOccupationalCredential .
# <https://example.org/credential_einstein_graduation> schema:credentialCategory "Graduation" .
# <https://example.org/credential_einstein_graduation> schema:dateCreated "1896"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Argovian_cantonal_school> .
# <https://en.wikipedia.org/wiki/Argovian_cantonal_school> rdf:type schema:School .
# <https://en.wikipedia.org/wiki/Argovian_cantonal_school> schema:name "Argovian cantonal school" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Graduation from Argovian cantonal school in Aarau, Switzerland in 1896" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Aarau, Switzerland" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Argovian_cantonal_school> .
# <https://en.wikipedia.org/wiki/Argovian_cantonal_school> rdf:type schema:School .
# <https://en.wikipedia.org/wiki/Argovian_cantonal_school> schema:name "Argovian cantonal school" .
# <https://en.wikipedia.org/wiki/Argovian_cantonal_school> schema:location "Aarau, Switzerland" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Graduation in 1896" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Argovian_cantonal_school> .
# <https://en.wikipedia.org/wiki/Argovian_cantonal_school> rdf:type schema:School .
# <https://en.wikipedia.org/wiki/Argovian_cantonal_school> schema:name "Argovian cantonal school" .
# <https://en.wikipedia.org/wiki/Argovian_cantonal_school> schema:location "Aarau, Switzerland" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Graduation in 1896" .

# %% [raw]
# {"cell": 208, "stmt_key": "6_8", "chunk_num": 6, "stmt_idx": 8, "type": "rdf", "cid": "1c2c0e6c9872f121d7f56dccc8dfede0e982aa01b5d96cb8c8cc56e1a3497eb3", "from_cid": "6570f7d4bcfdf8bc5d8d30103d9c31309646f9f54815c8f31ac8ff35bcac94d2"}

# %% [raw]
# # Statement [6.9]: While residing in Aarau, Switzerland, Albert Einstein lodged with the family of Jost Winteler.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation "Aarau, Switzerland" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .

# %% [raw]
# {"cell": 210, "stmt_key": "6_9", "chunk_num": 6, "stmt_idx": 9, "type": "rdf", "cid": "33ababe8ba863a58d722196bc45d372265f2750703885a96166fcbf3592cff69", "from_cid": "bd4d3a43c378bd18c8913222803601cb72c175d417a9e8d283ee06302b4641b9"}

# %% [raw]
# # Statement [6.10]: While residing in Aarau, Switzerland, Albert Einstein fell in love with Marie Winteler.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation <https://www.wikidata.org/wiki/Q15536> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://www.wikidata.org/wiki/Q123456> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation schema:City .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation schema:City .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse schema:Person .

# %% [raw]
# {"cell": 212, "stmt_key": "6_10", "chunk_num": 6, "stmt_idx": 10, "type": "rdf", "cid": "362127ce8d99d5fae11aa0197cbc22e5979eae82187f10108ee1c749a3b32892", "from_cid": "a3b163eedf119aed02f5569ef65da7c5fe0cf40482836dd38353d41b2b6fc187"}

# %% [raw]
# # Statement [6.11]: Maja Einstein married Paul Winteler.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Albert_Einstein#person_paul_winteler> .
# <#person_maja_einstein> rdf:type schema:Person .
# <#person_paul_winteler> rdf:type schema:Person .
# <#person_maja_einstein> schema:spouse <#person_paul_winteler> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Albert_Einstein#person_paul_winteler> .
# <#maja_einstein> rdf:type schema:Person .
# <#paul_winteler> rdf:type schema:Person .
# <#maja_einstein> schema:spouse <#paul_winteler> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_maja_einstein> schema:spouse <https://en.wikipedia.org/wiki/Albert_Einstein#person_paul_winteler> .
# <#maja_einstein> rdf:type schema:Person .
# <#paul_winteler> rdf:type schema:Person .
# <#maja_einstein> schema:spouse <#paul_winteler> .
# <#maja_einstein> schema:spouse <#paul_winteler> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_maja_einstein> schema:spouse <https://en.wikipedia.org/wiki/Albert_Einstein#person_paul_winteler> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_maja_einstein> schema:spouse <https://en.wikipedia.org/wiki/Albert_Einstein#person_paul_winteler> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Albert_Einstein#person_paul_winteler> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Albert_Einstein#person_paul_winteler> .
# <#maja_einstein> schema:spouse <#paul_winteler> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <#paul_winteler> .
# <#maja_einstein> schema:spouse <#paul_winteler> .

# %% [raw]
# {"cell": 214, "stmt_key": "6_11", "chunk_num": 6, "stmt_idx": 11, "type": "rdf", "cid": "87648574ddab14a2dfa8b1f6fbcbd6ef3f2f542310cab3db8f8885958a9f744e", "from_cid": "367ff044516700d306a920879fd7a7b62b2e3c8f916426a8a4650ff2d6f8fc29"}

# %% [raw]
# # Statement [7.1]: In January 1896, Albert Einstein renounced his citizenship of the German Kingdom of Württemberg.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "German Kingdom of Württemberg" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "German Kingdom of Württemberg" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "German Kingdom of Württemberg" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .

# %% [raw]
# {"cell": 216, "stmt_key": "7_1", "chunk_num": 7, "stmt_idx": 1, "type": "rdf", "cid": "9dae6161bb2149c78a40f6524d386b1824fad92a60610e06a041e6af24b00b50", "from_cid": "6592fee656e0324202282f4a47e419650c2a82e25f5d62d544c6a8aafe6601be"}

# %% [raw]
# # Statement [7.2]: Albert Einstein avoided conscription into military service by renouncing his citizenship in January 1896.
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:birthDate "1879-03-14"^^xsd:date .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .

# %% [raw]
# {"cell": 218, "stmt_key": "7_2", "chunk_num": 7, "stmt_idx": 2, "type": "rdf", "cid": "aa5fee07604aec5322f02f8039c7de73eb61de5390a2a90776e12a1b81fa7355", "from_cid": "a26b72e9bab9eab423825ef46863aa12410c38e9ee34fefac138de8622c65e65"}

# %% [raw]
# # Statement [7.3]: Albert Einstein received a Matura in September 1896.
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:hasCredential "Matura"^^xsd:string .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:educationalCredentialAwarded "Matura"^^xsd:string .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:hasCredential "Matura"^^xsd:string .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:hasCredential "Matura"^^xsd:string .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:hasCredential "Matura"^^xsd:string .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:hasCredential "Matura"^^xsd:string .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:hasCredential "Matura"^^xsd:string .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:hasCredential "Matura"^^xsd:string .

# %% [raw]
# {"cell": 220, "stmt_key": "7_3", "chunk_num": 7, "stmt_idx": 3, "type": "rdf", "cid": "bea440094acf65a3a2233bde5614816a1c26eb798634e0e1512542ec1d85deab", "from_cid": "2cfcf8972f6876d2e8197060d709aa7c562dcea25d32672404d6823dde6140b7"}

# %% [raw]
# # Statement [7.4]: Albert Einstein performed well across most of the curriculum and received a top grade of 6 for history, physics, algebra, geometry, and descriptive geometry.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:achievement "Performed well across most of the curriculum" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:achievement "Received top grade of 6 for history, physics, algebra, geometry, and descriptive geometry" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "School" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:achievement "Performed well across most of the curriculum" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Top grade of 6" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:achievement "Performed well across most of the curriculum" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:grade "6" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:subject "History" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:subject "Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:subject "Algebra" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:subject "Geometry" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:subject "Descriptive geometry" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:achievement "Performed well across most of the curriculum" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Top grade of 6" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:achievement "Performed well across most of the curriculum" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:grade "6" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:academicPerformance "Top grade in history, physics, algebra, geometry, and descriptive geometry" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:achievement "Performed well across most of the curriculum" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Top grade of 6" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:achievement "Performed well across most of the curriculum" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:academicPerformance "Received top grade of 6 for history, physics, algebra, geometry, and descriptive geometry" .

# %% [raw]
# {"cell": 222, "stmt_key": "7_4", "chunk_num": 7, "stmt_idx": 4, "type": "rdf", "cid": "d25cf70b7e9426708adcfbf5530ee9a2c32098e87f2c58b6a67eea7ae1aaa69b", "from_cid": "f79a7b3db6f1e896ef6472754fec64c9604fbdfdbaea89c4dde83ec74f09808d"}

# %% [raw]
# # Statement [7.5]: Albert Einstein enrolled in the four-year mathematics and physics teaching diploma program at the federal polytechnic school at age seventeen.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "17"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "17"^^xsd:integer .
# <#educational_program> rdf:type schema:EducationalOccupationalProgram .
# <#educational_program> schema:name "four-year mathematics and physics teaching diploma program" .
# <#institution> rdf:type schema:EducationalOrganization .
# <#institution> schema:name "federal polytechnic school" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <#institution> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:age "17"^^xsd:integer .
# <#educational_program> rdf:type schema:EducationalOccupationalProgram .
# <#educational_program> schema:name "four-year mathematics and physics teaching diploma program" .
# <#institution> rdf:type schema:EducationalOrganization .
# <#institution> schema:name "federal polytechnic school" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <#institution> .
# <#enrollment> rdf:type schema:ProgramMembership .
# <#enrollment> schema:member <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#enrollment> schema:program <#educational_program> .
# <#enrollment> schema:memberOf <#institution> .
# <#enrollment> schema:startDate "17"^^xsd:integer .

# %% [raw]
# {"cell": 224, "stmt_key": "7_5", "chunk_num": 7, "stmt_idx": 5, "type": "rdf", "cid": "df691879a2f8a4d25b504b79b983e2df29926d9c19e684b4aece1f05eeef283e", "from_cid": "317325e3736a80d872a635add324fb127a9d9bb653f80dfbcdf9d651babb70db"}

# %% [raw]
# # Statement [7.6]: Albert Einstein befriended Marcel Grossmann at the federal polytechnic school.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Marcel_Grossmann#person_marcel_grossmann> .
# <https://en.wikipedia.org/wiki/Marcel_Grossmann#person_marcel_grossmann> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Federal_Polytechnic_School#organization_federal_polytechnic_school> .
# <https://en.wikipedia.org/wiki/Federal_Polytechnic_School#organization_federal_polytechnic_school> rdf:type schema:EducationalOrganization .

# %% [raw]
# {"cell": 226, "stmt_key": "7_6", "chunk_num": 7, "stmt_idx": 6, "type": "rdf", "cid": "fccdb3add384a5d61902550bbbf15879ff68867fa9984f4acffad4a9a8e7d2ea", "from_cid": "9e32993941ec74f34bbf08674fb8a14c21f5537b0c27316684a10a14bd74ec79"}

# %% [raw]
# # Statement [7.7]: Marcel Grossmann helped Albert Einstein to get by despite his loose study habits at the federal polytechnic school.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Marcel_Grossmann> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Marcel_Grossmann> schema:knows <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Federal polytechnic school" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Marcel_Grossmann> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Marcel_Grossmann> schema:knows <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Federal polytechnic school" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:studyHabits "loose" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Marcel_Grossmann> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Marcel_Grossmann> schema:knows <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Federal polytechnic school" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:studyHabits "loose" .
# <https://en.wikipedia.org/wiki/Marcel_Grossmann> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Marcel_Grossmann> schema:knows <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Federal polytechnic school" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Marcel_Grossmann> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Federal polytechnic school" .
# <https://en.wikipedia.org/wiki/Marcel_Grossmann> schema:knows <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:studyHabits "loose" .

# %% [raw]
# {"cell": 228, "stmt_key": "7_7", "chunk_num": 7, "stmt_idx": 7, "type": "rdf", "cid": "981f877db1aa5aecaddc619f8a7c4937a78af089b3c4721cef67713119afddcd", "from_cid": "e0bacef470ec8af873a0429f73b6cf7ef5607927cd53b30446a0b24e8d2c34a4"}

# %% [raw]
# # Statement [7.8]: Marcel Grossmann helped Albert Einstein mathematically underpin his revolutionary insights into physics.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Marcel_Grossmann> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Marcel_Grossmann> schema:colleague <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Marcel_Grossmann> schema:collaboration "Marcel Grossmann helped Albert Einstein mathematically underpin his revolutionary insights into physics" .
# <https://en.wikipedia.org/wiki/Marcel_Grossmann> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Marcel_Grossmann> schema:colleague <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:colleague <https://en.wikipedia.org/wiki/Marcel_Grossmann> .

# %% [raw]
# {"cell": 230, "stmt_key": "7_8", "chunk_num": 7, "stmt_idx": 8, "type": "rdf", "cid": "d5591edf3c6a5bcd760ac11f9d70727bff84a361e071e4732726eb3de18f2ad3", "from_cid": "25e43c3a8b433165e1eafa17df89763543692ae2c2fec3d7b2b1d4e668c088f9"}

# %% [raw]
# # Statement [7.9]: Marie Winteler took up a teaching post in Olsberg, Switzerland.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation _:teaching_post .
# _:teaching_post rdf:type schema:Occupation .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:workLocation _:olsberg_location .
# _:olsberg_location rdf:type schema:Place .
# _:olsberg_location schema:name "Olsberg, Switzerland" .
# _:marie_winteler rdf:type schema:Person .
# _:marie_winteler schema:hasOccupation _:teaching_post .
# _:teaching_post rdf:type schema:Occupation .
# _:teaching_post schema:name "Teaching post" .
# _:marie_winteler schema:workLocation _:olsberg_location .
# _:olsberg_location rdf:type schema:Place .
# _:olsberg_location schema:name "Olsberg, Switzerland" .
# _:marie_winteler rdf:type schema:Person .
# _:marie_winteler schema:hasOccupation _:teaching_post .
# _:teaching_post rdf:type schema:Occupation .
# _:teaching_post schema:name "Teaching post" .
# _:marie_winteler schema:workLocation _:olsberg_location .
# _:olsberg_location rdf:type schema:Place .
# _:olsberg_location schema:name "Olsberg, Switzerland" .
# _:marie_winteler rdf:type schema:Person .
# _:marie_winteler schema:hasOccupation _:occupation .
# _:occupation rdf:type schema:Occupation .
# _:occupation schema:name "Teacher" .
# _:marie_winteler schema:workLocation _:olsberg_location .
# _:olsberg_location rdf:type schema:Place .
# _:olsberg_location schema:name "Olsberg, Switzerland" .
# _:person rdf:type schema:Person .
# _:person schema:name "Marie Winteler" .
# _:person schema:hasOccupation _:occupation .
# _:occupation rdf:type schema:Occupation .
# _:occupation schema:name "Teacher" .
# _:person schema:workLocation _:location .
# _:location rdf:type schema:Place .
# _:location schema:name "Olsberg, Switzerland" .
# _:person rdf:type schema:Person .
# _:person schema:name "Marie Winteler" .
# _:person schema:hasOccupation _:occupation .
# _:occupation rdf:type schema:Occupation .
# _:occupation schema:name "Teacher" .
# _:person schema:workLocation _:location .
# _:location rdf:type schema:Place .
# _:location schema:name "Olsberg, Switzerland" .
# _:marie_winteler rdf:type schema:Person .
# _:marie_winteler schema:hasOccupation _:teaching_post .
# _:teaching_post rdf:type schema:Occupation .
# _:marie_winteler schema:workLocation _:olsberg .
# _:olsberg rdf:type schema:Place .
# _:olsberg schema:name "Olsberg, Switzerland" .
# _:teaching_post schema:name "Teaching post" .

# %% [raw]
# {"cell": 232, "stmt_key": "7_9", "chunk_num": 7, "stmt_idx": 9, "type": "rdf", "cid": "0abd50fd6cc9bcf9fe2db44697204c9b0360ccf816f9bba8983212397fecab5d", "from_cid": "e36d7ac43109ce78cfc4088c3efce1219276153f280dcf47712cce39d24018ed"}

# %% [raw]
# # Statement [7.10]: Marie Winteler was a year older than Albert Einstein.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:relatedTo <https://en.wikipedia.org/wiki/Marie_Winteler> .
# <https://en.wikipedia.org/wiki/Marie_Winteler> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Marie_Winteler> schema:name "Marie Winteler" .
# <https://en.wikipedia.org/wiki/Marie_Winteler> schema:relatedTo <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Marie_Winteler> schema:ageDifference "1 year" .
# <https://en.wikipedia.org/wiki/Marie_Winteler> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Marie_Winteler> schema:name "Marie Winteler" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Marie_Winteler> schema:relatedTo <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .

# %% [raw]
# {"cell": 234, "stmt_key": "7_10", "chunk_num": 7, "stmt_idx": 10, "type": "rdf", "cid": "4d3f65b4833427eaf8c4b013a83042e6a00aa843463e7e6090c5944b8fb607c7", "from_cid": "5a03ddf00a4822ffb6403f16c3abe6415fb458f26727e229c28daa9dc667af04"}

# %% [raw]
# # Statement [7.11]: The five other polytechnic school freshmen following the same course as Albert Einstein included just one woman.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#polytechnic_freshmen_group> rdf:type schema:EducationalAudience .
# <#polytechnic_freshmen_group> schema:educationalRole "student" .
# <#polytechnic_freshmen_group> schema:description "Five other polytechnic school freshmen following the same course as Albert Einstein" .
# <#polytechnic_freshmen_group> schema:member <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#polytechnic_freshmen_group> schema:member <#student1> .
# <#polytechnic_freshmen_group> schema:member <#student2> .
# <#polytechnic_freshmen_group> schema:member <#student3> .
# <#polytechnic_freshmen_group> schema:member <#student4> .
# <#polytechnic_freshmen_group> schema:member <#student5> .
# <#student1> rdf:type schema:Person .
# <#student2> rdf:type schema:Person .
# <#student3> rdf:type schema:Person .
# <#student4> rdf:type schema:Person .
# <#student5> rdf:type schema:Person .
# <#student1> schema:gender "Male" .
# <#student2> schema:gender "Male" .
# <#student3> schema:gender "Male" .
# <#student4> schema:gender "Male" .
# <#student5> schema:gender "Female" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#course_group> rdf:type schema:EducationalAudience .
# <#course_group> schema:description "Five other polytechnic school freshmen following the same course as Albert Einstein" .
# <#course_group> schema:member <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#course_group> schema:numberOfMembers "5" .
# <#course_group> schema:educationalRole "student" .
# <#course_group> schema:description "Five other polytechnic school freshmen following the same course as Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#freshmen_group> rdf:type schema:EducationalAudience .
# <#freshmen_group> schema:description "Five other polytechnic school freshmen following the same course as Albert Einstein" .
# <#freshmen_group> schema:educationalRole "student" .
# <#freshmen_group> schema:numberOfMembers "5" .
# <#freshmen_group> schema:description "Five other polytechnic school freshmen following the same course as Albert Einstein, including just one woman" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#course_freshmen> rdf:type schema:EducationalAudience .
# <#course_freshmen> schema:description "Five other polytechnic school freshmen following the same course as Albert Einstein" .
# <#course_freshmen> schema:educationalRole "student" .
# <#course_freshmen> schema:numberOfMembers "5" .
# <#course_freshmen> schema:description "Five other polytechnic school freshmen following the same course as Albert Einstein, including just one woman" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#course_freshmen> rdf:type schema:EducationalAudience .
# <#course_freshmen> schema:description "Five other polytechnic school freshmen following the same course as Albert Einstein, including just one woman" .
# <#course_freshmen> schema:educationalRole "student" .
# <#course_freshmen> schema:numberOfMembers "5" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#freshmen_group> rdf:type schema:EducationalAudience .
# <#freshmen_group> schema:description "Five other polytechnic school freshmen following the same course as Albert Einstein" .
# <#freshmen_group> schema:educationalRole "student" .
# <#freshmen_group> schema:numberOfMembers "5" .
# <#freshmen_group> schema:description "Five other polytechnic school freshmen following the same course as Albert Einstein, including just one woman" .

# %% [raw]
# {"cell": 236, "stmt_key": "7_11", "chunk_num": 7, "stmt_idx": 11, "type": "rdf", "cid": "3b353cb271900367d0691d58042f4584f149dca077c2a75e9b3c8c079a775507", "from_cid": "be8f31d3dabdd75578a2c19646c14ca86d02c78dc9681b8b7d08136fd34c2682"}

# %% [raw]
# # Statement [7.12]: The woman among the five other polytechnic school freshmen was a twenty-year-old Serbian named Mileva Marić.
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:name "Albert Einstein" .
# <#mileva_marić> rdf:type schema:Person .
# <#mileva_marić> schema:name "Mileva Marić" .
# <#mileva_marić> schema:nationality schema:Country .
# <#mileva_marić> schema:birthDate "1900-01-01"^^xsd:date .
# <#mileva_marić> schema:affiliation <https://example.org/polytechnic_school> .
# <#mileva_marić> rdf:type schema:Person .
# <#mileva_marić> schema:name "Mileva Marić" .
# <#mileva_marić> schema:nationality "Serbia" .
# <#mileva_marić> schema:birthDate "1900-01-01"^^xsd:date .
# <#mileva_marić> schema:affiliation "polytechnic school" .
# <#mileva_marić> schema:alumniOf "polytechnic school" .
# <#mileva_marić> rdf:type schema:Person .
# <#mileva_marić> schema:name "Mileva Marić" .
# <#mileva_marić> schema:nationality "Serbia" .
# <#mileva_marić> schema:birthDate "1900-01-01"^^xsd:date .
# <#mileva_marić> schema:affiliation "polytechnic school" .
# <#mileva_marić> rdf:type schema:Person .
# <#mileva_marić> schema:name "Mileva Marić" .
# <#mileva_marić> schema:nationality "Serbia" .
# <#mileva_marić> schema:birthDate "1900-01-01"^^xsd:date .
# <#mileva_marić> schema:affiliation "polytechnic school" .
# <#mileva_marić> rdf:type schema:Person .
# <#mileva_marić> schema:name "Mileva Marić" .
# <#mileva_marić> schema:nationality "Serbia" .
# <#mileva_marić> schema:birthDate "1900-01-01"^^xsd:date .
# <#mileva_marić> schema:affiliation "polytechnic school" .
# <#mileva_marić> rdf:type schema:Person .
# <#mileva_marić> schema:name "Mileva Marić" .
# <#mileva_marić> schema:nationality "Serbia" .
# <#mileva_marić> schema:affiliation "polytechnic school" .
# <#mileva_marić> schema:birthDate "1900-01-01"^^xsd:date .

# %% [raw]
# {"cell": 238, "stmt_key": "7_12", "chunk_num": 7, "stmt_idx": 12, "type": "rdf", "cid": "3df34a9cc93d2b15c3ddd159f7960f854d3ccb811c4ad4717a70c2a073735039", "from_cid": "be8a5f976e2529f1cff3529ce08ae30ccc3b8b3e55663e823d5d094913dd5af8"}

# %% [raw]
# # Statement [7.13]: Albert Einstein and Mileva Marić spent many hours discussing their shared interests and learning about topics in physics.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Mileva_Marić#person_mileva_maric> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "physics" .
# <https://en.wikipedia.org/wiki/Mileva_Marić#person_mileva_maric> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Mileva_Marić#person_mileva_maric> schema:knows <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Mileva_Marić#person_mileva_maric> schema:knowsAbout "physics" .

# %% [raw]
# {"cell": 240, "stmt_key": "7_13", "chunk_num": 7, "stmt_idx": 13, "type": "rdf", "cid": "9f364366c8058db9cffa2ecbaf451db1d9bdf940be34b85331dceb5e9de00c5d", "from_cid": "23cf02f6dded4fed4c1d8c3036bcdf2440a48098e050c98840ea05aaf34b77bf"}

# %% [raw]
# # Statement [7.14]: Albert Einstein wrote letters to Mileva Marić confessing that exploring science with her was more enjoyable than reading a textbook in solitude.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Mileva_Marić#person_mileva_marić> .
# <https://en.wikipedia.org/wiki/Mileva_Marić#person_mileva_marić> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Mileva_Marić#person_mileva_marić> schema:name "Mileva Marić" .
# <#letter_action> rdf:type schema:WriteAction .
# <#letter_action> schema:agent <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#letter_action> schema:recipient <https://en.wikipedia.org/wiki/Mileva_Marić#person_mileva_marić> .
# <#letter_action> schema:text "exploring science with her was more enjoyable than reading a textbook in solitude" .

# %% [raw]
# {"cell": 242, "stmt_key": "7_14", "chunk_num": 7, "stmt_idx": 14, "type": "rdf", "cid": "2504dc5c638d797b5e28bec86ed576500ef46ab60506ec6f9dce16332f9e314a", "from_cid": "e7e23dc8c83b105ec038bfc75fd06b1b92992c1df7eb0719a52f4924fe0b9a88"}

# %% [raw]
# # Statement [7.15]: Albert Einstein and Mileva Marić became friends and then lovers.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87#person_mileva_mari%C4%87> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87#person_mileva_mari%C4%87> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Mileva_Marić#person_mileva_marić> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Mileva_Marić#person_mileva_marić> .

# %% [raw]
# {"cell": 244, "stmt_key": "7_15", "chunk_num": 7, "stmt_idx": 15, "type": "rdf", "cid": "1ef43ef0654fd2e11afbe76b44e5e2292881a7f4333dab7f63b08f3f906e5e64", "from_cid": "3c951f500d7fe6a2d2d6a1952c337fa7060a5bb8d95e4f183f99ee235fde81ee"}

# %% [raw]
# # Statement [7.16]: Historians of physics are divided on the question of the extent to which Mileva Marić contributed to the insights of Albert Einstein's annus mirabilis publications.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Physicist" .
# schema:Person rdf:type rdfs:Class .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Physicist" .
# schema:Person rdf:type rdfs:Class .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "Annus mirabilis publications" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator "Annus mirabilis publications" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Physicist" .
# <https://en.wikipedia.org/wiki/Mileva_Marić> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Mileva_Marić> schema:name "Mileva Marić" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "Annus mirabilis publications" .
# "Annus mirabilis publications" rdf:type schema:ScholarlyArticle .
# "Annus mirabilis publications" schema:name "Annus mirabilis publications" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Mileva_Marić> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Mileva_Marić> schema:name "Mileva Marić" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator "Annus mirabilis publications" .
# "Annus mirabilis publications" rdf:type schema:ScholarlyArticle .
# "Annus mirabilis publications" schema:name "Annus mirabilis publications" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "Mileva Marić" .
# "Historians of physics" rdf:type schema:Person .
# "Historians of physics" schema:hasOccupation "Historian" .
# "Historians of physics" schema:disagree "extent of Mileva Marić's contribution" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Mileva_Marić> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Mileva_Marić> schema:name "Mileva Marić" .
# "Annus mirabilis publications" rdf:type schema:ScholarlyArticle .
# "Annus mirabilis publications" schema:name "Annus mirabilis publications" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator "Annus mirabilis publications" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "Mileva Marić" .
# "Historians of physics" rdf:type schema:Person .
# "Historians of physics" schema:hasOccupation "Historian" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Mileva_Marić> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Mileva_Marić> schema:name "Mileva Marić" .
# "Annus mirabilis publications" rdf:type schema:ScholarlyArticle .
# "Annus mirabilis publications" schema:name "Annus mirabilis publications" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator "Annus mirabilis publications" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "Mileva Marić" .
# "Historians of physics" rdf:type schema:Person .
# "Historians of physics" schema:hasOccupation "Historian" .
# "Historians of physics" schema:disagree "extent of Mileva Marić's contribution" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Mileva_Marić> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Mileva_Marić> schema:name "Mileva Marić" .
# "Annus mirabilis publications" rdf:type schema:ScholarlyArticle .
# "Annus mirabilis publications" schema:name "Annus mirabilis publications" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator "Annus mirabilis publications" .
# "Historians of physics" rdf:type schema:Person .
# "Historians of physics" schema:hasOccupation "Historian" .
# "Historians of physics" schema:hasDisagreement "extent of Mileva Marić's contribution" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Mileva_Marić> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Mileva_Marić> schema:name "Mileva Marić" .
# "Annus mirabilis publications" rdf:type schema:ScholarlyArticle .
# "Annus mirabilis publications" schema:name "Annus mirabilis publications" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator "Annus mirabilis publications" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "Mileva Marić" .
# "Historians of physics" rdf:type schema:Person .
# "Historians of physics" schema:hasOccupation "Historian" .
# "Historians of physics" schema:disagrees "extent of Mileva Marić's contribution" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Mileva_Marić> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Mileva_Marić> schema:name "Mileva Marić" .
# "Annus mirabilis publications" rdf:type schema:ScholarlyArticle .
# "Annus mirabilis publications" schema:name "Annus mirabilis publications" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator "Annus mirabilis publications" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "Mileva Marić" .
# "Historians of physics" rdf:type schema:Person .
# "Historians of physics" schema:hasOccupation "Historian" .
# "Historians of physics" schema:disagrees "extent of Mileva Marić's contribution" .

# %% [raw]
# {"cell": 246, "stmt_key": "7_16", "chunk_num": 7, "stmt_idx": 16, "type": "rdf", "cid": "f15557681c324c39354d99ce01106ffe402933ab3712bdcba53d137b92a92a47", "from_cid": "944e42afb53fa6219aed33c880517a3adca6a2bad2091fb2040b7bf8ef6db62c"}

# %% [raw]
# # Statement [7.17]: There is at least some evidence that Albert Einstein was influenced by Mileva Marić's scientific ideas.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Mileva_Marić> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Mileva_Marić> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Mileva_Marić> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Mileva_Marić> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Mileva_Marić> .

# %% [raw]
# {"cell": 248, "stmt_key": "7_17", "chunk_num": 7, "stmt_idx": 17, "type": "rdf", "cid": "4411cb9499f0d19bc14bfc693da3dc0d36ca01effb59a2d9885b065a96324b41", "from_cid": "145b3542b9b0b25d112085c83fbdbea4839b2f9b35952b08e0d98cc130a6b66c"}

# %% [raw]
# # Statement [7.18]: Some scholars doubt whether Mileva Marić's impact on Albert Einstein's thought was of any great significance.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Mileva_Marić> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:relatedTo <https://en.wikipedia.org/wiki/Mileva_Marić> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Mileva_Marić> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:relatedTo <https://en.wikipedia.org/wiki/Mileva_Marić> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Mileva_Marić> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:relatedTo <https://en.wikipedia.org/wiki/Mileva_Marić> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Mileva_Marić> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:relatedTo <https://en.wikipedia.org/wiki/Mileva_Marić> .

# %% [raw]
# {"cell": 250, "stmt_key": "7_18", "chunk_num": 7, "stmt_idx": 18, "type": "rdf", "cid": "e70ef07c09419df1eb526c011701895890d8d7a88c994ab3ba899e7be6cda544", "from_cid": "e55d81c73d01366b34594cbba19431a37353bbf9f1d914481cbe7e2a957d94b0"}

# %% [raw]
# # Statement [8.1]: Albert Einstein correspondence with Marić revealed that in early 1902, while Marić was visiting her parents in Novi Sad, Marić gave birth to a daughter named Lieserl.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Mari%C4%87#person_maric> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Mari%C4%87#person_maric> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Mari%C4%87#person_maric> schema:name "Marić" .
# <https://en.wikipedia.org/wiki/Lieserl_Einstein#person_lieserl> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Lieserl_Einstein#person_lieserl> schema:name "Lieserl" .
# <https://en.wikipedia.org/wiki/Lieserl_Einstein#person_lieserl> schema:parent <https://en.wikipedia.org/wiki/Mari%C4%87#person_maric> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:correspondence <https://en.wikipedia.org/wiki/Einstein-Mari%C4%87_correspondence#document_correspondence> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Mari%C4%87#person_maric> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Mari%C4%87#person_maric> schema:name "Marić" .
# <https://en.wikipedia.org/wiki/Lieserl_Einstein#person_lieserl> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Lieserl_Einstein#person_lieserl> schema:name "Lieserl" .
# <https://en.wikipedia.org/wiki/Lieserl_Einstein#person_lieserl> schema:parent <https://en.wikipedia.org/wiki/Mari%C4%87#person_maric> .
# <https://en.wikipedia.org/wiki/Mari%C4%87#person_maric> schema:birthDate "1890-07-23"^^xsd:date .
# <https://en.wikipedia.org/wiki/Lieserl_Einstein#person_lieserl> schema:birthDate "1902-01-01"^^xsd:date .
# <https://en.wikipedia.org/wiki/Lieserl_Einstein#person_lieserl> schema:birthPlace "Novi Sad" .
# <https://en.wikipedia.org/wiki/Einstein-Mari%C4%87_correspondence#document_correspondence> rdf:type schema:Document .
# <https://en.wikipedia.org/wiki/Einstein-Mari%C4%87_correspondence#document_correspondence> schema:about <https://en.wikipedia.org/wiki/Lieserl_Einstein#person_lieserl> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Mari%C4%87#person_maric> .
# <https://en.wikipedia.org/wiki/Einstein-Mari%C4%87_correspondence#document_correspondence> schema:text "Albert Einstein correspondence with Marić revealed that in early 1902, while Marić was visiting her parents in Novi Sad, Marić gave birth to a daughter named Lieserl." .

# %% [raw]
# {"cell": 252, "stmt_key": "8_1", "chunk_num": 8, "stmt_idx": 1, "type": "rdf", "cid": "d84dacc43f36ac309eae55662278316d376b943f187dd20327ebf34b8aa203a1", "from_cid": "c7ba5a7980a3e2846961f4aeaaea1774b2f0d96008f77b00cc9589b50a7e4c65"}

# %% [raw]
# # Statement [8.2]: When Marić returned to Switzerland in early 1902, she was without the child named Lieserl whose fate is uncertain.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:children <#child_lieserl> .
# <#child_lieserl> rdf:type schema:Person .
# <#child_lieserl> schema:name "Lieserl" .
# <#child_lieserl> schema:description "Fate is uncertain" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:children <#child_lieserl> .
# <#child_lieserl> rdf:type schema:Person .
# <#child_lieserl> schema:name "Lieserl" .
# <#child_lieserl> schema:description "Fate is uncertain" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#person_maric> rdf:type schema:Person .
# <#person_maric> schema:children <#child_lieserl> .
# <#child_lieserl> rdf:type schema:Person .
# <#child_lieserl> schema:name "Lieserl" .
# <#child_lieserl> schema:description "Fate is uncertain" .
# <#person_maric> rdf:type schema:Person .
# <#person_maric> rdf:type schema:Person .
# <#child_lieserl> rdf:type schema:Person .
# <#child_lieserl> schema:name "Lieserl" .
# <#child_lieserl> schema:description "Fate is uncertain" .
# <#person_maric> schema:children <#child_lieserl> .
# <#person_maric> rdf:type schema:Person .
# <#child_lieserl> rdf:type schema:Person .
# <#child_lieserl> schema:name "Lieserl" .
# <#child_lieserl> schema:description "Fate is uncertain" .
# <#person_maric> schema:children <#child_lieserl> .
# <#person_maric> rdf:type schema:Person .
# <#child_lieserl> rdf:type schema:Person .
# <#child_lieserl> schema:name "Lieserl" .
# <#child_lieserl> schema:description "Fate is uncertain" .
# <#person_maric> schema:children <#child_lieserl> .
# <#person_maric> rdf:type schema:Person .
# <#person_maric> rdf:type schema:Person .
# <#child_lieserl> rdf:type schema:Person .
# <#child_lieserl> schema:name "Lieserl" .
# <#child_lieserl> schema:description "Fate is uncertain" .
# <#person_maric> schema:children <#child_lieserl> .
# <#person_maric> rdf:type schema:Person .
# <#child_lieserl> rdf:type schema:Person .
# <#child_lieserl> schema:name "Lieserl" .
# <#child_lieserl> schema:description "Fate is uncertain" .
# <#person_maric> schema:children <#child_lieserl> .

# %% [raw]
# {"cell": 254, "stmt_key": "8_2", "chunk_num": 8, "stmt_idx": 2, "type": "rdf", "cid": "82f72ce1580ca95d72075edfe27b11e525f8fc0c198618af5111e3bca120d70d", "from_cid": "3630c675520a4656942485a96d1b534b22d51b767dfe7d43385eb8d5482bb618"}

# %% [raw]
# # Statement [8.3]: A letter of Albert Einstein's that he wrote in September 1903 suggests that the daughter named Lieserl was either given up for adoption or died of scarlet fever in infancy.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#letter_1903> rdf:type schema:Message .
# <#letter_1903> schema:author <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#letter_1903> schema:dateSent "1903-09"^^xsd:date .
# <#lieserl> rdf:type schema:Person .
# <#lieserl> schema:name "Lieserl" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:children <#lieserl> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#letter_1903> rdf:type schema:Message .
# <#letter_1903> schema:author <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#letter_1903> schema:dateSent "1903-09"^^xsd:date .
# <#lieserl> rdf:type schema:Person .
# <#lieserl> schema:name "Lieserl" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:children <#lieserl> .
# <#lieserl> schema:deathDate "1902-1903"^^xsd:date .
# <#lieserl> schema:deathPlace "Infancy" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#letter_1903> rdf:type schema:Message .
# <#letter_1903> schema:author <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#letter_1903> schema:dateSent "1903-09"^^xsd:date .
# <#lieserl> rdf:type schema:Person .
# <#lieserl> schema:name "Lieserl" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:children <#lieserl> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#letter_1903> rdf:type schema:Message .
# <#letter_1903> schema:author <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#letter_1903> schema:dateSent "1903-09"^^xsd:date .
# <#lieserl> rdf:type schema:Person .
# <#lieserl> schema:name "Lieserl" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:children <#lieserl> .

# %% [raw]
# {"cell": 256, "stmt_key": "8_3", "chunk_num": 8, "stmt_idx": 3, "type": "rdf", "cid": "81bebf0116227d57b19bc8c7d25439d2a93e37ce34ec81c9413c152704f02d33", "from_cid": "bf463ca1ece31bd702594eb56276852192ade0f1aa7ab074d18457542a87ff02"}

# %% [raw]
# # Statement [8.4]: Albert Einstein and Marić married in January 1903.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Mari%C4%87> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Mari%C4%87> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Mari%C4%87> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Mari%C4%87> .

# %% [raw]
# {"cell": 258, "stmt_key": "8_4", "chunk_num": 8, "stmt_idx": 4, "type": "rdf", "cid": "8a5659ea8c35c138f75bbc0f98dd1abf0b3d1f3af6bf148fed4b28da2a3666e3", "from_cid": "cc0ae5f0e77319ba918c24f9af7d4fbe37984a22a70d58111bbffc3349546a51"}

# %% [raw]
# # Statement [8.5]: In May 1904, Albert Einstein and Marić's son named Hans Albert was born in Bern, Switzerland.
# # Error: ValidationError: 1 validation error for emit_triples
# triples
#   Input should be a valid list [type

# %% [raw]
# {"cell": 260, "stmt_key": "8_5", "chunk_num": 8, "stmt_idx": 5, "type": "rdf", "cid": "e0c8c7f107bc1ff4e7fc42c1d5e3bd39bebae969ce8b6e1addb8f71e21d4e54d", "from_cid": "4079057358e646f3f5bb3bbdca4006a9e0e43cc197f131094300b8aeb250bbba"}

# %% [raw]
# # Statement [8.6]: Their son named Eduard was born in Zurich in July 1910.
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:children <#child_eduard> .
# <#child_eduard> rdf:type schema:Person .
# <#child_eduard> schema:name "Eduard" .
# <#child_eduard> schema:birthDate "1910-07"^^xsd:date .
# <#child_eduard> schema:birthPlace "Zurich"^^xsd:string .
# <#child_eduard> rdf:type schema:Person .
# <#child_eduard> schema:name "Eduard" .
# <#child_eduard> schema:birthDate "1910-07"^^xsd:date .
# <#child_eduard> schema:birthPlace "Zurich" .
# <#child_eduard> schema:parent https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .
# <#child_eduard> rdf:type schema:Person .
# <#child_eduard> schema:name "Eduard" .
# <#child_eduard> schema:birthDate "1910-07"^^xsd:date .
# <#child_eduard> schema:birthPlace <#place_zurich> .
# <#place_zurich> rdf:type schema:City .
# <#place_zurich> schema:name "Zurich" .
# <#child_eduard> schema:parent https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .
# <#child_eduard> rdf:type schema:Person .
# <#child_eduard> schema:name "Eduard" .
# <#child_eduard> schema:birthDate "1910-07"^^xsd:date .
# <#child_eduard> schema:birthPlace "Zurich" .
# <#child_eduard> schema:parent https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .
# <#child_eduard> rdf:type schema:Person .
# <#child_eduard> rdf:type schema:Person .
# <#child_eduard> schema:name "Eduard" .
# <#child_eduard> schema:birthDate "1910-07"^^xsd:date .
# <#child_eduard> schema:birthPlace "Zurich" .
# <#child_eduard> schema:parent https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .

# %% [raw]
# {"cell": 262, "stmt_key": "8_6", "chunk_num": 8, "stmt_idx": 6, "type": "rdf", "cid": "ea6950c29f79254655cfa27cce831baa7e629c693efd26064440d37f365d7209", "from_cid": "3fbdba1df29dfca5eb447f1279329bbd10a2d9cc4d42e2eebb1dae17e1619242"}

# %% [raw]
# # Statement [8.7]: In letters that Albert Einstein wrote to Marie Winteler in the months before Eduard's arrival, Albert Einstein described his love for his wife as "misguided".
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Marie_Winteler> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Marie_Winteler> schema:name "Marie Winteler" .
# <#letter_to_marie> rdf:type schema:Message .
# <#letter_to_marie> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#letter_to_marie> schema:recipient <https://en.wikipedia.org/wiki/Marie_Winteler> .
# <#letter_to_marie> schema:text "misguided" .
# <#letter_to_marie> schema:description "Letter from Albert Einstein to Marie Winteler describing his love for his wife" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Marie_Winteler> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Marie_Winteler> schema:name "Marie Winteler" .
# <#letter_to_marie> rdf:type schema:Message .
# <#letter_to_marie> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#letter_to_marie> schema:recipient <https://en.wikipedia.org/wiki/Marie_Winteler> .
# <#letter_to_marie> schema:text "misguided" .
# <#letter_to_marie> schema:description "Letter from Albert Einstein to Marie Winteler describing his love for his wife" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Marie_Winteler> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Marie_Winteler> schema:name "Marie Winteler" .
# <#letter_to_marie> rdf:type schema:Message .
# <#letter_to_marie> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#letter_to_marie> schema:recipient <https://en.wikipedia.org/wiki/Marie_Winteler> .
# <#letter_to_marie> schema:text "misguided" .
# <#letter_to_marie> schema:description "Letter from Albert Einstein to Marie Winteler describing his love for his wife" .
# <#letter_to_marie> schema:text "misguided" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Marie_Winteler> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Marie_Winteler> schema:name "Marie Winteler" .
# <#letter_to_marie> rdf:type schema:Message .
# <#letter_to_marie> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#letter_to_marie> schema:recipient <https://en.wikipedia.org/wiki/Marie_Winteler> .
# <#letter_to_marie> schema:text "misguided" .
# <#letter_to_marie> schema:description "Letter from Albert Einstein to Marie Winteler describing his love for his wife" .
# <#letter_to_marie> schema:text \""misguided\"" .
# <#letter_to_marie> schema:text "misguided" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Marie_Winteler> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Marie_Winteler> schema:name "Marie Winteler" .
# <#letter_to_marie> rdf:type schema:Message .
# <#letter_to_marie> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#letter_to_marie> schema:recipient <https://en.wikipedia.org/wiki/Marie_Winteler> .
# <#letter_to_marie> schema:text "misguided" .
# <#letter_to_marie> schema:description "Letter from Albert Einstein to Marie Winteler describing his love for his wife" .

# %% [raw]
# {"cell": 264, "stmt_key": "8_7", "chunk_num": 8, "stmt_idx": 7, "type": "rdf", "cid": "d1ba5c5a1c1b1a5ba6b7ef9d2c23650257f875b774a97aee2827afb4f49d330d", "from_cid": "053addb14fcca5ce3380547553e5703082564256ab38463d00f29d72694aeb1a"}

# %% [raw]
# # Statement [8.8]: In letters that Albert Einstein wrote to Marie Winteler in the months before Eduard's arrival, Albert Einstein mourned the "missed life" that he imagined he would have enjoyed if he had married Marie Winteler instead.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Marie_Winteler> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Countess_Elsa_Knecht> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Elisabeth_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:children <https://en.wikipedia.org/wiki/Eduard_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Elisabeth_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator "<https://en.wikipedia.org/wiki/Albert_Einstein#letter_to_marie_winteler>" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#letter_to_marie_winteler> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letter_to_marie_winteler> rdf:type schema:Message .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letter_to_marie_winteler> schema:text "In letters that Albert Einstein wrote to Marie Winteler in the months before Eduard's arrival, Albert Einstein mourned the \"missed life\" that he imagined he would have enjoyed if he had married Marie Winteler instead." .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Elisabeth_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:children <https://en.wikipedia.org/wiki/Eduard_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator "<https://en.wikipedia.org/wiki/Albert_Einstein#letter_to_marie_winteler>" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letter_to_marie_winteler> rdf:type schema:Message .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letter_to_marie_winteler> schema:text \""In letters that Albert Einstein wrote to Marie Winteler in the months before Eduard's arrival, Albert Einstein mourned the \\\"missed life\\\" that he imagined he would have enjoyed if he had married Marie Winteler instead.\"\" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Elisabeth_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:children <https://en.wikipedia.org/wiki/Eduard_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letter_to_marie_winteler> rdf:type schema:Message .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letter_to_marie_winteler> rdf:type schema:Message .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letter_to_marie_winteler> schema:author <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letter_to_marie_winteler> schema:text "In letters that Albert Einstein wrote to Marie Winteler in the months before Eduard's arrival, Albert Einstein mourned the \"missed life\" that he imagined he would have enjoyed if he had married Marie Winteler instead." .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letter_to_marie_winteler> rdf:type schema:Message .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letter_to_marie_winteler> schema:author <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letter_to_marie_winteler> schema:text "In letters that Albert Einstein wrote to Marie Winteler in the months before Eduard's arrival, Albert Einstein mourned the \"missed life\" that he imagined he would have enjoyed if he had married Marie Winteler instead." .

# %% [raw]
# {"cell": 266, "stmt_key": "8_8", "chunk_num": 8, "stmt_idx": 8, "type": "rdf", "cid": "dd623c916d35071383c839d56b1485c235a3d874c444d85df9bcad2b6fa3c32b", "from_cid": "5f3b9102dd392ded4cde3fa8d81bd59ae8425e3abc71ff03b6311eba753c1b30"}

# %% [raw]
# # Statement [8.9]: In 1912, Albert Einstein entered into a relationship with Elsa Löwenthal.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Elsa_Löwenthal#person_elsa_loewenthal> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Elsa_Löwenthal#person_elsa_loewenthal> .

# %% [raw]
# {"cell": 268, "stmt_key": "8_9", "chunk_num": 8, "stmt_idx": 9, "type": "rdf", "cid": "9e394786f03a8ca0197d6ca857d672febdbdcfd1cb36e04aedaee15b70c6e6ce", "from_cid": "a314167418a7a094f146857f13f0307224447c9a37bec997e92d77552d12c753"}

# %% [raw]
# # Statement [8.10]: Elsa Löwenthal was both first cousin of Albert Einstein on his mother's side and second cousin of Albert Einstein on his father's side.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:relatedTo <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> .
# <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> schema:relatedTo <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> schema:relatedTo <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> schema:relationshipType "First cousin" .
# <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> schema:relationshipSide "Mother's side" .
# <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> schema:relatedTo <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> schema:relationshipType "Second cousin" .
# <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> schema:relationshipSide "Father's side" .
# <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> schema:relatedTo <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:relatedTo <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> .
# <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> schema:relatedTo <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:relatedTo <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> .

# %% [raw]
# {"cell": 270, "stmt_key": "8_10", "chunk_num": 8, "stmt_idx": 10, "type": "rdf", "cid": "aa3c5f94c2dd521c86b6fffbe2e5928cab9a8d8696ddefa053d24fd311460b59", "from_cid": "397cc567efe213155e04f37efcba4be01d5ea3ce28ebcca9e97a1cc699a5d40f"}

# %% [raw]
# # Statement [8.11]: When Marić learned of Albert Einstein's infidelity soon after Marić moved to Berlin with him in April 1914, Marić returned to Zurich.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <#person_maric> .
# <#person_maric> rdf:type schema:Person .
# <#person_maric> schema:knowsAbout "infidelity" .
# <#person_maric> schema:knowsAbout "Albert Einstein's infidelity" .
# <#person_maric> schema:knowsAbout "Albert Einstein's infidelity" .
# <#person_maric> schema:knowsAbout "infidelity" .
# <#person_maric> schema:birthPlace "Zurich" .
# <#person_maric> schema:deathDate "1935-04-12"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <#person_maric> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#person_maric> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <#person_maric> .
# <#person_maric> schema:knowsAbout "Albert Einstein's infidelity" .
# <#person_maric> schema:birthPlace "Zurich" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#person_maric> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <#person_maric> .
# <#person_maric> schema:knowsAbout "Albert Einstein's infidelity" .

# %% [raw]
# {"cell": 272, "stmt_key": "8_11", "chunk_num": 8, "stmt_idx": 11, "type": "rdf", "cid": "ad36c5ddbef8d0ce7197aeeb38210ad7f5aacabbb2fac0fc696065d63f392d4a", "from_cid": "6c4801da80e57135bd29bf84b1566a4d3c0f6f7fa1b8af0dba2fb554facd515b"}

# %% [raw]
# # Statement [8.12]: When Marić learned of Albert Einstein's infidelity soon after Marić moved to Berlin with him in April 1914, Marić took Hans Albert and Eduard with her.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Mari%C4%87> .
# <https://en.wikipedia.org/wiki/Mari%C4%87> schema:spouse <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Mari%C4%87> schema:children <https://en.wikipedia.org/wiki/Hans_Albert> .
# <https://en.wikipedia.org/wiki/Mari%C4%87> schema:children <https://en.wikipedia.org/wiki/Eduard_Einstein> .
# <https://en.wikipedia.org/wiki/Hans_Albert> schema:parent <https://en.wikipedia.org/wiki/Mari%C4%87> .
# <https://en.wikipedia.org/wiki/Eduard_Einstein> schema:parent <https://en.wikipedia.org/wiki/Mari%C4%87> .
# <https://en.wikipedia.org/wiki/Mari%C4%87> schema:homeLocation "Berlin"^^xsd:string .
# <https://en.wikipedia.org/wiki/Mari%C4%87> schema:birthDate "1914-04-01"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Mari%C4%87> .
# <https://en.wikipedia.org/wiki/Mari%C4%87> schema:spouse <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Mari%C4%87> schema:children <https://en.wikipedia.org/wiki/Hans_Albert> .
# <https://en.wikipedia.org/wiki/Mari%C4%87> schema:children <https://en.wikipedia.org/wiki/Eduard_Einstein> .
# <https://en.wikipedia.org/wiki/Hans_Albert> schema:parent <https://en.wikipedia.org/wiki/Mari%C4%87> .
# <https://en.wikipedia.org/wiki/Eduard_Einstein> schema:parent <https://en.wikipedia.org/wiki/Mari%C4%87> .
# <https://en.wikipedia.org/wiki/Mari%C4%87> schema:homeLocation "Berlin"^^xsd:string .

# %% [raw]
# {"cell": 274, "stmt_key": "8_12", "chunk_num": 8, "stmt_idx": 12, "type": "rdf", "cid": "fedd6ce9fbeddb6655d6893e8d590a4af935b841452f838ca935f16061a16008", "from_cid": "f95255c26868b80f17a2d774abfc0bc93c6143c3b539f73115ba130b5572009c"}

# %% [raw]
# # Statement [8.13]: Albert Einstein and Marić were granted a divorce on 14 February 1919 on the grounds of having lived apart for five years.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Marić> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:dissolutionDate "1919-02-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Marić> schema:dissolutionDate "1919-02-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Marić> .
# <https://en.wikipedia.org/wiki/Marić> schema:spouse <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:dissolutionDate "1919-02-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Marić> .
# <https://en.wikipedia.org/wiki/Marić> schema:spouse <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "Albert Einstein was divorced from Marić on 14 February 1919"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Marić> .
# <https://en.wikipedia.org/wiki/Marić> schema:spouse <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .

# %% [raw]
# {"cell": 276, "stmt_key": "8_13", "chunk_num": 8, "stmt_idx": 13, "type": "rdf", "cid": "cc833ae0b2406703df132860a2f63c872501ef2c6cc6393d802336cf564157c5", "from_cid": "c5a30c62efb2dc0ac71434d0c7ae9632f6bea918d2df576e4740c7bb1c9e5148"}

# %% [raw]
# # Statement [8.14]: As part of the divorce settlement, Albert Einstein agreed that if Albert Einstein were to win a Nobel Prize, Albert Einstein would give the money that Albert Einstein received to Marić.
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:spouse https://en.wikipedia.org/wiki/Mileva_Mari%C4%87 .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:award "Nobel Prize" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:award "Nobel Prize in Physics" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:spouse https://en.wikipedia.org/wiki/Mileva_Mari%C4%87 .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:award "Nobel Prize" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:award "Nobel Prize in Physics" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:spouse https://en.wikipedia.org/wiki/Mileva_Mari%C4%87 .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:award "Nobel Prize" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:award "Nobel Prize in Physics" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:spouse https://en.wikipedia.org/wiki/Mileva_Mari%C4%87 .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:award "Nobel Prize" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:award "Nobel Prize in Physics" .

# %% [raw]
# {"cell": 278, "stmt_key": "8_14", "chunk_num": 8, "stmt_idx": 14, "type": "rdf", "cid": "1cac51a82fec737a4abe52b54b08afaaf2162a6f8ea7316314c71a28c465e182", "from_cid": "0a3691c10070a8c87cb75a2275e8edb1a2f0bcfad7fc9916d3f35553c9e69d55"}

# %% [raw]
# # Statement [8.15]: Albert Einstein won the Nobel Prize in 1921.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Nobel Prize" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Nobel Prize in Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "1921" .

# %% [raw]
# {"cell": 280, "stmt_key": "8_15", "chunk_num": 8, "stmt_idx": 15, "type": "rdf", "cid": "12f660d5f8b05143dda55aa52a10835d0a6853099ce30864b4cff343b544ee91", "from_cid": "0828ace3654c9257f308aa519e957449932e4410a8b1a7ec9a6c032d701812a7"}

# %% [raw]
# # Statement [8.16]: Albert Einstein married Elsa Löwenthal in 1919.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://example.org#elsa_loewenthal> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://example.org#elsa_loewenthal> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:description "Married Elsa Löwenthal in 1919" .

# %% [raw]
# {"cell": 282, "stmt_key": "8_16", "chunk_num": 8, "stmt_idx": 16, "type": "rdf", "cid": "e06202ed46fb272f67384b07611c13a0db9b7ff351e340f7a134d99cf0dd50fb", "from_cid": "52772f3112a35a5e9a8f78e7c09a12925aa473e13f4e532f8f48bc63c32a9915"}

# %% [raw]
# # Statement [8.17]: In 1923, Albert Einstein began a relationship with a secretary named Betty Neumann.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "Betty Neumann" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasSpouse "Betty Neumann" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasPartner "Betty Neumann" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasRelationship "Betty Neumann" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "Betty Neumann" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasPartner "Betty Neumann" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .

# %% [raw]
# {"cell": 284, "stmt_key": "8_17", "chunk_num": 8, "stmt_idx": 17, "type": "rdf", "cid": "75476148d722e851a86fef32e4e21cf355bacade0a278e6574858cc22a2b938a", "from_cid": "bf89f4b7a2241683a550f6f296765b0f44d925a750cd52ef617195186e2d4561"}

# %% [raw]
# # Statement [8.18]: Betty Neumann was the niece of Albert Einstein's close friend named Hans Mühsam.
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:relatedTo _:hans_muhsam .
# _:hans_muhsam rdf:type schema:Person .
# _:hans_muhsam schema:name "Hans Mühsam" .
# _:hans_muhsam schema:relatedTo _:betty_neumann .
# _:betty_neumann rdf:type schema:Person .
# _:betty_neumann schema:name "Betty Neumann" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:relatedTo _:hans_muhsam .
# _:hans_muhsam rdf:type schema:Person .
# _:hans_muhsam schema:name "Hans Mühsam" .
# _:hans_muhsam schema:relatedTo _:betty_neumann .
# _:betty_neumann rdf:type schema:Person .
# _:betty_neumann schema:name "Betty Neumann" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:relatedTo _:hans_muhsam .
# _:hans_muhsam rdf:type schema:Person .
# _:hans_muhsam schema:name "Hans Mühsam" .
# _:hans_muhsam schema:relatedTo _:betty_neumann .
# _:betty_neumann rdf:type schema:Person .
# _:betty_neumann schema:name "Betty Neumann" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:relatedTo _:hans_muhsam .
# _:hans_muhsam rdf:type schema:Person .
# _:hans_muhsam schema:name "Hans Mühsam" .
# _:hans_muhsam schema:relatedTo _:betty_neumann .
# _:betty_neumann rdf:type schema:Person .
# _:betty_neumann schema:name "Betty Neumann" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:relatedTo _:hans_muhsam .
# _:hans_muhsam rdf:type schema:Person .
# _:hans_muhsam schema:name "Hans Mühsam" .
# _:hans_muhsam schema:relatedTo _:betty_neumann .
# _:betty_neumann rdf:type schema:Person .
# _:betty_neumann schema:name "Betty Neumann" .

# %% [raw]
# {"cell": 286, "stmt_key": "8_18", "chunk_num": 8, "stmt_idx": 18, "type": "rdf", "cid": "c71045cf43a5a574e5d47e190a24635390c8f4407b7a19c6d659325da82d5992", "from_cid": "47baa85c0113c1c4b8e8ba66cdfd6a15bd82237f98b848eabf5f5ef225b244e2"}

# %% [raw]
# # Statement [8.19]: Elsa Löwenthal remained loyal to Albert Einstein.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://www.wikidata.org/wiki/Q1042759> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://www.wikidata.org/wiki/Q1042759> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://www.wikidata.org/wiki/Q1042759> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://www.wikidata.org/wiki/Q1042759> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://www.wikidata.org/wiki/Q1042759> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://www.wikidata.org/wiki/Q1042759> rdf:type schema:Person .

# %% [raw]
# {"cell": 288, "stmt_key": "8_19", "chunk_num": 8, "stmt_idx": 19, "type": "rdf", "cid": "bd0b4d9baf26e4f52e0182eb8181f5e689c85c0e5662c1d7b5c2f8290d9a4888", "from_cid": "2c3a7b1cf1ddefc4985ff4ed1502406b9045eb44c0358666d44569d623080d4c"}

# %% [raw]
# # Statement [8.20]: Elsa Löwenthal accompanied Albert Einstein when Albert Einstein emigrated to the United States in 1933.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Ulm, Germany" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathPlace "Princeton, New Jersey" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "German" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Ulm, Germany" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Ulm, Germany" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathPlace "Princeton, New Jersey" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "German" .
# <https://en.wikipedia.org/wiki/Elsa_Löwenthal> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Elsa_Löwenthal> schema:name "Elsa Löwenthal" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Ulm, Germany" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathPlace "Princeton, New Jersey" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "German" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation "Princeton, New Jersey" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Ulm, Germany" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathPlace "Princeton, New Jersey" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "German" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Elsa_Löwenthal> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Elsa_Löwenthal> schema:name "Elsa Löwenthal" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation "Princeton, New Jersey" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation "Princeton, New Jersey" .

# %% [raw]
# {"cell": 290, "stmt_key": "8_20", "chunk_num": 8, "stmt_idx": 20, "type": "rdf", "cid": "7faf64d96180093215bfc85cbb77f6ad7941603c583181e1ca34085173d0458c", "from_cid": "3bde3b36de654cc5e4f13bcb8f03b83b2be0deefe0b1dfb43ee24e27910dee54"}

# %% [raw]
# # Statement [8.21]: In 1935, Elsa Löwenthal was diagnosed with heart and kidney problems.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:healthCondition "heart and kidney problems" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Elsa Löwenthal" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:healthCondition "heart and kidney problems" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Elsa Löwenthal" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:healthCondition "heart and kidney problems" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:healthCondition "heart and kidney problems" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:healthCondition "heart and kidney problems" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Elsa Löwenthal" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:healthCondition "heart and kidney problems" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:healthCondition "heart and kidney problems" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:healthCondition "heart and kidney problems" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:healthCondition "heart and kidney problems" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:healthCondition "heart and kidney problems" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:healthCondition "heart and kidney problems" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:healthCondition "heart and kidney problems" .

# %% [raw]
# {"cell": 292, "stmt_key": "8_21", "chunk_num": 8, "stmt_idx": 21, "type": "rdf", "cid": "e572a3257820a2dad615d31a7e7b211da2a70d33bfdd6014f1fdc6920fbf8198", "from_cid": "6844a6523556ed82b6772146b080159bfeda15f677905ab1f1169a13e18f8b7f"}

# %% [raw]
# # Statement [8.22]: Elsa Löwenthal died in December 1936.
# # Error: ValidationError: 1 validation error for emit_triples
# triples
#   Input should be a valid list [type

# %% [raw]
# {"cell": 294, "stmt_key": "8_22", "chunk_num": 8, "stmt_idx": 22, "type": "rdf", "cid": "724d4e782782fd2e28af6540b1e4b5ee96e979e2b05aa6138bfd0fd04fbb6b37", "from_cid": "9b7e6b57d1e32493da3c510a490e4e99ae9bea281de76a74d52e5996da435f2a"}

# %% [raw]
# # Statement [9.1]: Hebrew University of Jerusalem released a volume of letters by Albert Einstein in 2006.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Hebrew_University_of_Jerusalem> rdf:type schema:CollegeOrUniversity .
# <https://en.wikipedia.org/wiki/Hebrew_University_of_Jerusalem> schema:name "Hebrew University of Jerusalem" .
# <#volume_of_letters> rdf:type schema:Collection .
# <#volume_of_letters> schema:name "Volume of letters by Albert Einstein" .
# <#volume_of_letters> schema:releasedEvent <#release_event> .
# <#release_event> rdf:type schema:PublicationEvent .
# <#release_event> schema:publishedBy <https://en.wikipedia.org/wiki/Hebrew_University_of_Jerusalem> .
# <#release_event> schema:startDate "2006"^^xsd:date .
# <#volume_of_letters> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .

# %% [raw]
# {"cell": 296, "stmt_key": "9_1", "chunk_num": 9, "stmt_idx": 1, "type": "rdf", "cid": "e0168d7d80c9393a9f7b1e7feed9ddd09b07c6f91980fd6ccf1e7d16145dfd99", "from_cid": "cc655848928689d7538969db1cb4e11f351d60bfd35ba133eac9b1aea7e4cd20"}

# %% [raw]
# # Statement [9.2]: The volume of letters added information about women with whom Albert Einstein was romantically involved.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasPart <https://en.wikipedia.org/wiki/Albert_Einstein#letters_volume> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letters_volume> rdf:type schema:DigitalDocument .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letters_volume> schema:name "Volume of Letters" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letters_volume> schema:hasPart <https://en.wikipedia.org/wiki/Albert_Einstein#letters_content> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letters_content> rdf:type schema:CreativeWork .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letters_content> schema:description "Information about women with whom Albert Einstein was romantically involved" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letters_volume> rdf:type schema:DigitalDocument .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letters_volume> rdf:type schema:DigitalDocument .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letters_volume> schema:hasPart <https://en.wikipedia.org/wiki/Albert_Einstein#letters_content> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letters_content> rdf:type schema:CreativeWork .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letters_content> schema:description "Information about women with whom Albert Einstein was romantically involved" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letters_volume> rdf:type schema:DigitalDocument .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letters_volume> schema:hasPart <https://en.wikipedia.org/wiki/Albert_Einstein#letters_content> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letters_volume> rdf:type schema:DigitalDocument .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letters_volume> schema:name "Volume of Letters" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letters_content> rdf:type schema:CreativeWork .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letters_content> schema:description "Information about women with whom Albert Einstein was romantically involved" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letters_volume> rdf:type schema:DigitalDocument .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letters_volume> rdf:type schema:DigitalDocument .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letters_volume> schema:description "Contains information about women with whom Albert Einstein was romantically involved" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letters_volume> rdf:type schema:DigitalDocument .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letters_volume> rdf:type schema:DigitalDocument .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letters_volume> rdf:type schema:DigitalDocument .
# <https://en.wikipedia.org/wiki/Albert_Einstein#letters_volume> schema:description "Contains information about women with whom Albert Einstein was romantically involved" .

# %% [raw]
# {"cell": 298, "stmt_key": "9_2", "chunk_num": 9, "stmt_idx": 2, "type": "rdf", "cid": "02f36e965ea634efd834dfeb7b29b8bd18f925ea3d6fa688e26fd873b8709c11", "from_cid": "d5f675ab2dde170f2f794d3e3ef1a0cc8ddd95543f8befa93c1fcbd85b6fb9dd"}

# %% [raw]
# # Statement [9.3]: Margarete Lebach was a married Austrian woman with whom Albert Einstein was romantically involved.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Margarete_Lebach> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Margarete_Lebach> schema:nationality <https://en.wikipedia.org/wiki/Austria> .
# <https://en.wikipedia.org/wiki/Margarete_Lebach> schema:relatedTo <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .

# %% [raw]
# {"cell": 300, "stmt_key": "9_3", "chunk_num": 9, "stmt_idx": 3, "type": "rdf", "cid": "621e75dd43730e2d7b98025ccd98ceb7b43fd2918ac9101116ce0c6dd8903d9f", "from_cid": "558f55a57afee5d8d51b641f2d17b07d2e2f1678619b5497e674058b3c954d53"}

# %% [raw]
# # Statement [9.4]: Estella Katzenellenbogen was a rich owner of a florist business with whom Albert Einstein was romantically involved.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#person_estella> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#person_estella> schema:name "Estella Katzenellenbogen" .
# <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#business_florist> rdf:type schema:Florist .
# <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#business_florist> schema:name "Florist Business" .
# <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#person_estella> schema:owns <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#business_florist> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#person_estella> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#person_estella> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#person_estella> schema:name "Estella Katzenellenbogen" .
# <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#business_florist> rdf:type schema:Florist .
# <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#business_florist> schema:name "Florist Business" .
# <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#person_estella> schema:owns <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#business_florist> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#person_estella> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#person_estella> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#person_estella> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#person_estella> schema:owns <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#business_florist> .
# <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#business_florist> rdf:type schema:Florist .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#person_estella> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#person_estella> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#person_estella> schema:owns <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#business_florist> .
# <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#business_florist> rdf:type schema:Florist .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Estella_Katzenellenbogen#person_estella> .

# %% [raw]
# {"cell": 302, "stmt_key": "9_4", "chunk_num": 9, "stmt_idx": 4, "type": "rdf", "cid": "c8a95694df825a16f0dae2f71efd4d3d4501e0e1850e100c50fc5014811fa1d4", "from_cid": "b56b2645baa0dcf152f061499deda6cb86dfd2c8aedd06e11f647d3b0bf13c7e"}

# %% [raw]
# # Statement [9.5]: Toni Mendel was a wealthy Jewish widow with whom Albert Einstein was romantically involved.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Toni_Mendel> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Toni_Mendel> .
# <https://en.wikipedia.org/wiki/Toni_Mendel> schema:additionalType "wealthy" .
# <https://en.wikipedia.org/wiki/Toni_Mendel> schema:additionalType "Jewish" .
# <https://en.wikipedia.org/wiki/Toni_Mendel> schema:additionalType "widow" .
# <https://en.wikipedia.org/wiki/Toni_Mendel> schema:jobTitle "widow" .
# <https://en.wikipedia.org/wiki/Toni_Mendel> schema:additionalType "Jewish" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Toni_Mendel> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Toni_Mendel> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Toni_Mendel> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Toni_Mendel> .

# %% [raw]
# {"cell": 304, "stmt_key": "9_5", "chunk_num": 9, "stmt_idx": 5, "type": "rdf", "cid": "47f8ef9bd54e69e3a5635f7e74988373b2e8208f8630351a5d0670ffb05dae64", "from_cid": "77ca836e3fa45e4cae5cacafec1e86c200cf036304a37966cc599ede8974d440"}

# %% [raw]
# # Statement [9.6]: Ethel Michanowski was a Berlin socialite with whom Albert Einstein spent time and from whom he accepted gifts while married to Löwenthal.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Löwenthal> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Löwenthal> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:relatedTo <https://en.wikipedia.org/wiki/Ethel_Michanowski> .
# <https://en.wikipedia.org/wiki/Ethel_Michanowski> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Löwenthal> .
# <https://en.wikipedia.org/wiki/Ethel_Michanowski> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Ethel_Michanowski> schema:relatedTo <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Löwenthal> .
# <https://en.wikipedia.org/wiki/Ethel_Michanowski> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:relatedTo <https://en.wikipedia.org/wiki/Ethel_Michanowski> .

# %% [raw]
# {"cell": 306, "stmt_key": "9_6", "chunk_num": 9, "stmt_idx": 6, "type": "rdf", "cid": "a19502892f859627cee6066c72e879a18da6fdd283fa24f6a5568ee0fce2600a", "from_cid": "0a78591ede101eba44d5d3210276b56f745cc9bad077524bf8031f3f5d7739e1"}

# %% [raw]
# # Statement [9.7]: After being widowed, Albert Einstein was briefly in a relationship with Margarita Konenkova.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <#margarita_konenkova> .
# <#margarita_konenkova> rdf:type schema:Person .
# <#margarita_konenkova> schema:name "Margarita Konenkova" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#margarita_konenkova> rdf:type schema:Person .
# <#margarita_konenkova> schema:name "Margarita Konenkova" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <#margarita_konenkova> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#margarita_konenkova> rdf:type schema:Person .
# <#margarita_konenkova> schema:name "Margarita Konenkova" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <#margarita_konenkova> .

# %% [raw]
# {"cell": 308, "stmt_key": "9_7", "chunk_num": 9, "stmt_idx": 7, "type": "rdf", "cid": "98da946ce142d59625174176b89d7e2e0e2dd2faa5aac9fb2107f8375b3f03b6", "from_cid": "acc612a17cb0641129e2de6b1dde36e6344bba2444cdb7ddf34198ca8c4841f0"}

# %% [raw]
# # Statement [9.8]: Margarita Konenkova was thought by some to be a Russian spy.
# <https://en.wikipedia.org/wiki/Margarita_Konenkova> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Margarita_Konenkova> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Margarita_Konenkova> schema:jobTitle "Russian spy"@en .
# <https://en.wikipedia.org/wiki/Margarita_Konenkova> schema:jobTitle "Russian spy"@en .
# <https://en.wikipedia.org/wiki/Margarita_Konenkova> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Margarita_Konenkova> schema:jobTitle "Russian spy"@en .

# %% [raw]
# {"cell": 310, "stmt_key": "9_8", "chunk_num": 9, "stmt_idx": 8, "type": "rdf", "cid": "2c0a356cb5963ddafd45b28fc23ae4cd0debe6894adc81359ffc89dd7faede0b", "from_cid": "af636b46388f29e209b0813e236d886383beae51975f06141f448008affdf0f5"}

# %% [raw]
# # Statement [9.9]: Sergei Konenkov was the husband of Margarita Konenkova.
# <https://en.wikipedia.org/wiki/Sergei_Konenkov> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Margarita_Konenkova> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Sergei_Konenkov> schema:spouse <https://en.wikipedia.org/wiki/Margarita_Konenkova> .
# <https://en.wikipedia.org/wiki/Margarita_Konenkova> schema:spouse <https://en.wikipedia.org/wiki/Sergei_Konenkov> .

# %% [raw]
# {"cell": 312, "stmt_key": "9_9", "chunk_num": 9, "stmt_idx": 9, "type": "rdf", "cid": "fb9234e29a023c55487c9601b60e851aea0e61b7dbe08bd9ad2b19f4ef62ea64", "from_cid": "cff251e9d4040bc56b6a9e988dd7661d0a701bb4ff2f3b92fa3edfe5c7b42c79"}

# %% [raw]
# # Statement [9.10]: Sergei Konenkov was a Russian sculptor.
# <https://en.wikipedia.org/wiki/Sergei_Konenkov> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Sergei_Konenkov> schema:nationality schema:Country .
# <https://en.wikipedia.org/wiki/Sergei_Konenkov> schema:hasOccupation "sculptor" .
# <https://en.wikipedia.org/wiki/Sergei_Konenkov> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Sergei_Konenkov> schema:nationality <https://en.wikipedia.org/wiki/Russia> .
# <https://en.wikipedia.org/wiki/Sergei_Konenkov> schema:hasOccupation "sculptor" .
# <https://en.wikipedia.org/wiki/Sergei_Konenkov> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Sergei_Konenkov> schema:nationality "Russia"@en .
# <https://en.wikipedia.org/wiki/Sergei_Konenkov> schema:hasOccupation "sculptor" .
# <https://en.wikipedia.org/wiki/Sergei_Konenkov> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Sergei_Konenkov> schema:nationality <https://www.wikidata.org/entity/Q159> .
# schema:Person schema:hasOccupation "sculptor" .
# <https://en.wikipedia.org/wiki/Sergei_Konenkov> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Sergei_Konenkov> schema:nationality <https://www.wikidata.org/entity/Q159> .
# <https://en.wikipedia.org/wiki/Sergei_Konenkov> schema:hasOccupation "sculptor" .
# <https://en.wikipedia.org/wiki/Sergei_Konenkov> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Sergei_Konenkov> schema:nationality "Russian"@en .
# <https://en.wikipedia.org/wiki/Sergei_Konenkov> schema:hasOccupation "sculptor" .
# <https://en.wikipedia.org/wiki/Sergei_Konenkov> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Sergei_Konenkov> schema:nationality "Russian"@en .
# <https://en.wikipedia.org/wiki/Sergei_Konenkov> schema:hasOccupation "sculptor" .

# %% [raw]
# {"cell": 314, "stmt_key": "9_10", "chunk_num": 9, "stmt_idx": 10, "type": "rdf", "cid": "c0af24b601d43a2bd09090a030678acd6db9adc52f109a46f993ef214fa65bd9", "from_cid": "228074177e363dd049cf074c0be60eec87598a41f956c785bdb6fa3cbca040a2"}

# %% [raw]
# # Statement [9.11]: Sergei Konenkov created the bronze bust of Albert Einstein at the Institute for Advanced Study at Princeton.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alternateName "Sergei Konenkov" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator <https://en.wikipedia.org/wiki/Sergei_Konenkov> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:material "bronze" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:location "Institute for Advanced Study at Princeton" .
# <#bust_einstein> rdf:type schema:Sculpture .
# <#bust_einstein> schema:creator <https://en.wikipedia.org/wiki/Sergei_Konenkov> .
# <#bust_einstein> schema:material "bronze" .
# <#bust_einstein> schema:contentLocation "Institute for Advanced Study at Princeton" .
# <#bust_einstein> schema:subjectOf <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#einstein_bust> rdf:type schema:Sculpture .
# <#einstein_bust> schema:name "Bronze bust of Albert Einstein" .
# <#einstein_bust> schema:creator <https://en.wikipedia.org/wiki/Sergei_Konenkov> .
# <#einstein_bust> schema:material "bronze" .
# <#einstein_bust> schema:contentLocation "Institute for Advanced Study at Princeton" .
# <#einstein_bust> rdf:type schema:Sculpture .
# <#einstein_bust> schema:creator <https://en.wikipedia.org/wiki/Sergei_Konenkov> .
# <#einstein_bust> schema:material "bronze" .
# <#einstein_bust> schema:contentLocation "Institute for Advanced Study at Princeton" .
# <#einstein_bust> schema:subjectOf <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .

# %% [raw]
# {"cell": 316, "stmt_key": "9_11", "chunk_num": 9, "stmt_idx": 11, "type": "rdf", "cid": "f54eaa8d97bd4c5455b35852654b2720dc57bda85793593341bd882935a8746f", "from_cid": "53106ebb893148983c9c25e0b2e2a33c2727e333bdf17de75a2a7a15bf0a0e20"}

# %% [raw]
# # Statement [9.12]: Albert Einstein's son Eduard experienced an episode of acute mental illness at about the age of twenty.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:children <#person_eduard> .
# <#person_eduard> rdf:type schema:Person .
# <#person_eduard> schema:healthCondition <#mental_illness_condition> .
# <#mental_illness_condition> rdf:type schema:MedicalCondition .
# <#mental_illness_condition> schema:name "Acute mental illness" .
# <#person_eduard> schema:age "20"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:children <#person_eduard> .
# <#person_eduard> rdf:type schema:Person .
# <#person_eduard> schema:healthCondition <#mental_illness_condition> .
# <#mental_illness_condition> rdf:type schema:MedicalCondition .
# <#mental_illness_condition> schema:name "Acute mental illness" .

# %% [raw]
# {"cell": 318, "stmt_key": "9_12", "chunk_num": 9, "stmt_idx": 12, "type": "rdf", "cid": "afab1cc4bfc4be729e860732d5720c95477b2326bd9adde8ce6a290824e21629", "from_cid": "707e1f3423a0993c56d7d7840cf1c01bbe0beb935768bab706ace0d1f4a84aa9"}

# %% [raw]
# # Statement [9.13]: Albert Einstein's son Eduard was diagnosed with schizophrenia.
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:children <https://en.wikipedia.org/wiki/Eduard_Einstein#person_eduard_einstein> .
# <https://en.wikipedia.org/wiki/Eduard_Einstein#person_eduard_einstein> schema:medicalCondition "schizophrenia" .

# %% [raw]
# {"cell": 320, "stmt_key": "9_13", "chunk_num": 9, "stmt_idx": 13, "type": "rdf", "cid": "735166fcc5e34f9bba82d4822bd04782e73955526dcd74492fd4ae3717804a9c", "from_cid": "d7b2f7341e1e448108ec27e966951f07ae0f02e4879136a0a5d07686640e9208"}

# %% [raw]
# # Statement [9.14]: Albert Einstein's son Eduard spent the remainder of his life either in the care of his mother or in temporary confinement in an asylum.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:children <#eduard_einstein> .
# <#eduard_einstein> rdf:type schema:Person .
# <#eduard_einstein> schema:description "spent the remainder of his life either in the care of his mother or in temporary confinement in an asylum" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:children <#eduard_einstein> .
# <#eduard_einstein> rdf:type schema:Person .
# <#eduard_einstein> schema:description "spent the remainder of his life either in the care of his mother or in temporary confinement in an asylum" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:children <#eduard_einstein> .
# <#eduard_einstein> rdf:type schema:Person .
# <#eduard_einstein> schema:description "spent the remainder of his life either in the care of his mother or in temporary confinement in an asylum" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:children <#eduard_einstein> .
# <#eduard_einstein> rdf:type schema:Person .
# <#eduard_einstein> schema:description "spent the remainder of his life either in the care of his mother or in temporary confinement in an asylum" .

# %% [raw]
# {"cell": 322, "stmt_key": "9_14", "chunk_num": 9, "stmt_idx": 14, "type": "rdf", "cid": "b8254c963d08281ff4d3451027a010af7342bfd682b0c43a819f11c79fdf8e31", "from_cid": "05371589600112b9bc61b5289967afc8bc1a808f54fcbbb1ff2311ba10233cdc"}

# %% [raw]
# # Statement [9.15]: After the death of Albert Einstein's mother, Albert Einstein's son Eduard was committed permanently to Burghölzli.
# # Error: ValidationError: 1 validation error for emit_triples
# triples
#   Input should be a valid list [type

# %% [raw]
# {"cell": 324, "stmt_key": "9_15", "chunk_num": 9, "stmt_idx": 15, "type": "rdf", "cid": "e680913918b3292beb2b6b33b90bde01537feb93a9adb802dc57a8dc76d8ec57", "from_cid": "1535571c15482b0c8ed9d78c4f52cbb7beced1096259a1c6e415f93f19f9c668"}

# %% [raw]
# # Statement [9.16]: Burghölzli was the Psychiatric University Hospital in Zurich.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Burghölzli> rdf:type schema:Hospital .
# <https://en.wikipedia.org/wiki/Burghölzli> schema:name "Burghölzli" .
# <https://en.wikipedia.org/wiki/Burghölzli> schema:additionalType "Psychiatric University Hospital" .
# <https://en.wikipedia.org/wiki/Burghölzli> schema:location "Zurich" .

# %% [raw]
# {"cell": 326, "stmt_key": "9_16", "chunk_num": 9, "stmt_idx": 16, "type": "rdf", "cid": "6741de7af67411ff7387ff4a6d8b773e46f82de9ef6e990fa0cd2f7d283cc920", "from_cid": "e0340195f8b9faa74ac44da966519dc1fcfa2084030d1bb7c3994533a4f19f46"}

# %% [raw]
# # Statement [10.1]: Albert Einstein graduated from the federal polytechnic school in 1900 and was duly certified as competent to teach mathematics and physics.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Bachelor's degree in physics and mathematics"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Federal Polytechnic School"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Teaching certification in mathematics and physics"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Federal Polytechnic School"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential <#credential_1> .
# <#credential_1> rdf:type schema:EducationalOccupationalCredential .
# <#credential_1> schema:credentialCategory "Bachelor's degree"^^xsd:string .
# <#credential_1> schema:educationalCredentialAwarded "Bachelor's degree in physics and mathematics"^^xsd:string .
# <#credential_1> schema:dateCreated "1900"^^xsd:gYear .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Federal Polytechnic School"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential <#teaching_certification> .
# <#teaching_certification> rdf:type schema:EducationalOccupationalCredential .
# <#teaching_certification> schema:credentialCategory "Teaching certification"^^xsd:string .
# <#teaching_certification> schema:educationalCredentialAwarded "Competency to teach mathematics and physics"^^xsd:string .
# <#teaching_certification> schema:dateCreated "1900"^^xsd:gYear .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Federal Polytechnic School"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential <#degree_1900> .
# <#degree_1900> rdf:type schema:EducationalOccupationalCredential .
# <#degree_1900> schema:credentialCategory "Bachelor's degree"^^xsd:string .
# <#degree_1900> schema:educationalCredentialAwarded "Bachelor's degree in physics and mathematics"^^xsd:string .
# <#degree_1900> schema:dateCreated "1900"^^xsd:gYear .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Federal Polytechnic School" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Bachelor's degree in physics and mathematics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Teaching certification in mathematics and physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "1900" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Federal Polytechnic School" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Bachelor's degree in physics and mathematics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Federal Polytechnic School" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Bachelor's degree in physics and mathematics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Teaching certification in mathematics and physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "1900"^^xsd:gYear .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Federal Polytechnic School" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Bachelor's degree in physics and mathematics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Teaching certification in mathematics and physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "1900"^^xsd:gYear .

# %% [raw]
# {"cell": 328, "stmt_key": "10_1", "chunk_num": 10, "stmt_idx": 1, "type": "rdf", "cid": "d0e6ca792b2c410358726c2c3c89db8e6ba37c123d628a924f1c0c0870b38d6e", "from_cid": "91cbd9492600ef42954fc1b1acf8f82ec9d68cb5abf1c577597df0bf2899716a"}

# %% [raw]
# # Statement [10.2]: Albert Einstein successfully acquired Swiss citizenship in February 1901.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality schema:Switzerland .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality schema:Switzerland .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .

# %% [raw]
# {"cell": 330, "stmt_key": "10_2", "chunk_num": 10, "stmt_idx": 2, "type": "rdf", "cid": "81753816062973da7c6482d6b5a7e831da75ebad5a1a73d248ec8deb69370521", "from_cid": "668d1073bf372bf6dc795f729214c460f580913eaaa9f7ad124fbf2097cccdf0"}

# %% [raw]
# # Statement [10.3]: Swiss authorities deemed Albert Einstein medically unfit for military service.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:healthCondition "medically unfit for military service"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:healthCondition "medically unfit for military service"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:additionalType "MilitaryServiceFitnessDetermination"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:healthCondition "medically unfit for military service"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:healthCondition "medically unfit for military service"^^xsd:string .

# %% [raw]
# {"cell": 332, "stmt_key": "10_3", "chunk_num": 10, "stmt_idx": 3, "type": "rdf", "cid": "a74f034d0c267ae5995e6324b8b7f8803d59cf7ec96d699b2d403ca2a1bbd396", "from_cid": "689ce93890076d7dc5ed3c4bd6ef5a625ec235f8bb8bb1485ce7291e3f2e06e6"}

# %% [raw]
# # Statement [10.4]: Swiss schools did not offer Albert Einstein a teaching position despite his two years of applying for one.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Teaching position" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Teacher" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Teacher" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Teacher" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation schema:Occupation .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Teacher" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Teacher" .

# %% [raw]
# {"cell": 334, "stmt_key": "10_4", "chunk_num": 10, "stmt_idx": 4, "type": "rdf", "cid": "4c2b80866e17158742b6d721e1e7c6d5fa4e38cbf06769158e10279c71abfd79", "from_cid": "91318821cd7a46c95f75f6e9ecffca61369f5f6e3478eea4fa4079312cc168ff"}

# %% [raw]
# # Statement [10.5]: Marcel Grossmann's father helped Albert Einstein secure a post in Bern at the Swiss Patent Office as an assistant examiner – level III.
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:parent https://en.wikipedia.org/wiki/Marcel_Grossmann#person_marcel_grossmann_father .
# https://en.wikipedia.org/wiki/Marcel_Grossmann#person_marcel_grossmann_father schema:knows https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:worksFor https://en.wikipedia.org/wiki/Swiss_Patent_Office#organization_swiss_patent_office .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:parent https://en.wikipedia.org/wiki/Marcel_Grossmann#person_marcel_grossmann_father .
# https://en.wikipedia.org/wiki/Marcel_Grossmann#person_marcel_grossmann_father schema:knows https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:worksFor https://en.wikipedia.org/wiki/Swiss_Patent_Office#organization_swiss_patent_office .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:worksFor https://en.wikipedia.org/wiki/Swiss_Patent_Office#organization_swiss_patent_office .
# https://en.wikipedia.org/wiki/Marcel_Grossmann#person_marcel_grossmann_father schema:knows https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .
# https://en.wikipedia.org/wiki/Marcel_Grossmann#person_marcel_grossmann_father schema:employee https://en.wikipedia.org/wiki/Swiss_Patent_Office#organization_swiss_patent_office .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:worksFor https://en.wikipedia.org/wiki/Swiss_Patent_Office#organization_swiss_patent_office .
# https://en.wikipedia.org/wiki/Marcel_Grossmann#person_marcel_grossmann_father schema:knows https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:worksFor https://en.wikipedia.org/wiki/Swiss_Patent_Office#organization_swiss_patent_office .
# https://en.wikipedia.org/wiki/Marcel_Grossmann#person_marcel_grossmann_father schema:knows https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:worksFor https://en.wikipedia.org/wiki/Swiss_Patent_Office#organization_swiss_patent_office .
# https://en.wikipedia.org/wiki/Marcel_Grossmann#person_marcel_grossmann_father schema:knows https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:worksFor https://en.wikipedia.org/wiki/Swiss_Patent_Office#organization_swiss_patent_office .
# https://en.wikipedia.org/wiki/Marcel_Grossmann#person_marcel_grossmann_father schema:knows https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .

# %% [raw]
# {"cell": 336, "stmt_key": "10_5", "chunk_num": 10, "stmt_idx": 5, "type": "rdf", "cid": "fa2d8b23fb3c5493877e208e1de830d26c6ab44e0ee1c16b4686a690af2c4d35", "from_cid": "2cb275356fa395006ad9773d5c212b357a1951fd65b6c79eb2515624f72c9b2f"}

# %% [raw]
# # Statement [10.6]: Patent applications that landed on Albert Einstein's desk for evaluation included ideas for a gravel sorter and an electric typewriter.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <https://en.wikipedia.org/wiki/Swiss_Patent_Office> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Patent examiner" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor "Swiss Patent Office" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Patent examiner" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor "Swiss Patent Office" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Patent examiner" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor "Swiss Patent Office" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Patent examiner" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor "Swiss Patent Office" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor "Swiss Patent Office" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Patent examiner" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor "Swiss Patent Office" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Patent examiner" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor "Swiss Patent Office" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Patent examiner" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .

# %% [raw]
# {"cell": 338, "stmt_key": "10_6", "chunk_num": 10, "stmt_idx": 6, "type": "rdf", "cid": "243f9604d4923a020af99dad9ac673645af03c76a2b2cb0af2416d98f2a14fbb", "from_cid": "a89dba8d5f7aafce6f86f21b3284d1de66ef43457393ef00e36c964c0a1ceea7"}

# %% [raw]
# # Statement [10.7]: Albert Einstein's employers were pleased with his work at the Swiss Patent Office and made his position permanent in 1903.
# # Error: ValidationError: 1 validation error for emit_triples
# triples
#   Input should be a valid list [type

# %% [raw]
# {"cell": 340, "stmt_key": "10_7", "chunk_num": 10, "stmt_idx": 7, "type": "rdf", "cid": "a1b28663c8c15881673e20aea167cf68c98561cbf58f3c321a9406d969faf8df", "from_cid": "f6877d5b62a80ae8e156573fc4f239c8ac3fdd92f2aabe1d82e817287a9c29ac"}

# %% [raw]
# # Statement [10.8]: Albert Einstein's employers did not think that he should be promoted until he had fully mastered machine technology.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Patent Office Clerk" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <https://en.wikipedia.org/wiki/Swiss_Patent_Office> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <https://en.wikipedia.org/wiki/Swiss_Patent_Office> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Patent Office Clerk" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:description "Employers at the Swiss Patent Office did not think he should be promoted until he had fully mastered machine technology" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <https://en.wikipedia.org/wiki/Swiss_Patent_Office> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Patent Office Clerk" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:additionalType "Former employee of Swiss Patent Office" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <https://en.wikipedia.org/wiki/Swiss_Patent_Office> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:description "Employers at the Swiss Patent Office did not think he should be promoted until he had fully mastered machine technology" .

# %% [raw]
# {"cell": 342, "stmt_key": "10_8", "chunk_num": 10, "stmt_idx": 8, "type": "rdf", "cid": "e994a4d204b467d86a53b8e8b250cb5517d032e9d08332585068224c970f536c", "from_cid": "7e3c73920945e0c415efdab9be7957dc09b7213bc2e05684bfcbb99724a69860"}

# %% [raw]
# # Statement [10.9]: Albert Einstein arrived at his revolutionary ideas about space, time and light through thought experiments about the transmission of signals and the synchronization of clocks.
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:creator "revolutionary ideas about space, time and light" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:actionProcess "thought experiments about the transmission of signals and the synchronization of clocks" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:creator "revolutionary ideas about space, time and light" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:action "thought experiments about the transmission of signals and the synchronization of clocks" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:hasOccupation "Scientist" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:knowsAbout "space" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:knowsAbout "time" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:knowsAbout "light" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:creativeWork "revolutionary ideas about space, time and light" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:creator "revolutionary ideas about space, time and light" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:hasCreativeWork "revolutionary ideas about space, time and light" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:methodOfDiscovery "thought experiments about the transmission of signals and the synchronization of clocks" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:knowsAbout "space" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:knowsAbout "time" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:knowsAbout "light" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:hasCredential "revolutionary ideas about space, time and light" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:mainEntityOfPage "https://en.wikipedia.org/wiki/Albert_Einstein" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:knowsAbout "space" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:knowsAbout "time" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:knowsAbout "light" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:hasCredential "revolutionary ideas about space, time and light" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:action "thought experiments about the transmission of signals and the synchronization of clocks" .

# %% [raw]
# {"cell": 344, "stmt_key": "10_9", "chunk_num": 10, "stmt_idx": 9, "type": "rdf", "cid": "545a471ce2b8ad882a0c0aa679f3568c7c884a244889710945916d763b961d90", "from_cid": "5ea0ba8600b8dcde431618cc0fb40207e94b4194a16325422bc20aef52deff39"}

# %% [raw]
# # Statement [10.10]: Albert Einstein formed a group with friends in Bern in 1902 that held regular meetings to discuss science and philosophy.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 346, "stmt_key": "10_10", "chunk_num": 10, "stmt_idx": 10, "type": "rdf", "cid": "2ef8bfcdad5ab36e489664211afbd6034f809b283b632f92a6e42caae3520a6e", "from_cid": "d134be333d2335800e39386d08b7833a4ef7454d972704f81863c1ad0868ec85"}

# %% [raw]
# # Statement [10.11]: The name chosen for the group formed by Albert Einstein and his friends was the Olympia Academy.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation <#olympia_academy> .
# <#olympia_academy> rdf:type schema:Organization .
# <#olympia_academy> schema:legalName "Olympia Academy" .

# %% [raw]
# {"cell": 348, "stmt_key": "10_11", "chunk_num": 10, "stmt_idx": 11, "type": "rdf", "cid": "3bd6ffaf1a601945b3d2de3fa9e2d2c557a97e2d1b205f238cb122e018d10d66", "from_cid": "634fccf00e9b69be818580afa337f26f3269c5eeccf50fb0a5430d2d44a45f62"}

# %% [raw]
# # Statement [10.12]: The Olympia Academy was an ironic comment upon its far from Olympian status.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Olympia_Academy> rdf:type schema:Organization .
# <https://en.wikipedia.org/wiki/Olympia_Academy> schema:name "The Olympia Academy" .
# <https://en.wikipedia.org/wiki/Olympia_Academy> rdf:type schema:Organization .
# <https://en.wikipedia.org/wiki/Olympia_Academy> schema:name "The Olympia Academy" .
# <https://en.wikipedia.org/wiki/Olympia_Academy> rdf:type schema:Organization .
# <https://en.wikipedia.org/wiki/Olympia_Academy> schema:name "The Olympia Academy" .

# %% [raw]
# {"cell": 350, "stmt_key": "10_12", "chunk_num": 10, "stmt_idx": 12, "type": "rdf", "cid": "1dceca0340f783074c406e22e1142e06a137bd03e4ef149951e9e62ea410da6f", "from_cid": "a1f0b3cb38b9cf804a30233cde162c804b79b6928538117b0a20e7b23f97f237"}

# %% [raw]
# # Statement [10.13]: Marić sometimes participated in the meetings of the Olympia Academy by careful listening.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows " marić" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasSpouse " marić" .
# "marić" rdf:type schema:Person .
# "marić" schema:memberOf "Olympia Academy" .
# "marić" schema:participantIn "Olympia Academy meetings" .
# "marić" rdf:type schema:Person .
# "marić" schema:member "Olympia Academy" .
# "marić" rdf:type schema:Person .
# "marić" schema:memberOf "Olympia Academy" .
# marić rdf:type schema:Person .
# marić schema:memberOf Olympia Academy .
# Olympia Academy rdf:type schema:Organization .
# "marić" rdf:type schema:Person .
# "marić" schema:attendee "Olympia Academy meetings" .
# "marić" schema:participant "Olympia Academy meetings" .
# "marić" schema:member "Olympia Academy" .
# marić rdf:type schema:Person .
# marić schema:member Olympia Academy .
# Olympia Academy rdf:type schema:Organization .
# Olympia Academy schema:name "Olympia Academy" .
# "marić" rdf:type schema:Person .
# marić rdf:type schema:Person .
# marić schema:member Olympia Academy .
# Olympia Academy rdf:type schema:Organization .
# Olympia Academy schema:name "Olympia Academy" .
# "marić" schema:participant "Olympia Academy meetings" .
# marić rdf:type schema:Person .
# marić schema:participant Olympia Academy meetings .
# Olympia Academy meetings rdf:type schema:Event .
# Olympia Academy meetings schema:name "Olympia Academy meetings" .
# "marić" schema:attendee "Olympia Academy" .
# "marić" rdf:type schema:Person .
# "marić" schema:member "Olympia Academy" .
# marić rdf:type schema:Person .
# marić schema:member Olympia Academy .
# Olympia Academy rdf:type schema:Organization .
# "marić" schema:participantIn "Olympia Academy meetings" .

# %% [raw]
# {"cell": 352, "stmt_key": "10_13", "chunk_num": 10, "stmt_idx": 13, "type": "rdf", "cid": "03f114a3657fb3a1496b63f6a285dfc60971ce98e5e344459a81c588225d3b1d", "from_cid": "d5441f08f0ce206cc6d926d26c38276aff5bcfbacb3ac179a34835bba9473435"}

# %% [raw]
# # Statement [10.14]: The thinkers whose works were reflected upon by Albert Einstein and his friends included Henri Poincaré, Ernst Mach, and David Hume.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Henri_Poincar%C3%A9> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Henri_Poincar%C3%A9> schema:name "Henri Poincaré" .
# <https://en.wikipedia.org/wiki/Ernst_Mach> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Ernst_Mach> schema:name "Ernst Mach" .
# <https://en.wikipedia.org/wiki/David_Hume> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/David_Hume> schema:name "David Hume" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Henri_Poincar%C3%A9> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Ernst_Mach> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/David_Hume> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Henri_Poincar%C3%A9> .

# %% [raw]
# {"cell": 354, "stmt_key": "10_14", "chunk_num": 10, "stmt_idx": 14, "type": "rdf", "cid": "6d35eb61acb69335fd27dd9ef13005a365b93df83ffa288b75a4f36d350dc0bc", "from_cid": "2644f77da94d31ddbe5b88a5593cfc26a4504937266a1fcb75c0aee9e6387401"}

# %% [raw]
# # Statement [10.15]: Henri Poincaré, Ernst Mach, and David Hume significantly influenced Albert Einstein's own subsequent ideas and beliefs.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Henri_Poincar%C3%A9#person_henri_poincare> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Ernst_Mach#person_ernst_mach> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/David_Hume#person_david_hume> .
# <https://en.wikipedia.org/wiki/Henri_Poincar%C3%A9#person_henri_poincare> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Ernst_Mach#person_ernst_mach> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/David_Hume#person_david_hume> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Henri_Poincar%C3%A9#person_henri_poincare> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Ernst_Mach#person_ernst_mach> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/David_Hume#person_david_hume> .
# <https://en.wikipedia.org/wiki/Henri_Poincar%C3%A9#person_henri_poincare> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Ernst_Mach#person_ernst_mach> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/David_Hume#person_david_hume> rdf:type schema:Person .

# %% [raw]
# {"cell": 356, "stmt_key": "10_15", "chunk_num": 10, "stmt_idx": 15, "type": "rdf", "cid": "cf995517bcaab69c9d362e99a4a480383b1fedc91787051a0b0c44d9dcda469c", "from_cid": "0bb7a377302bc55b53033344d1499aed9fe4fef6bf47d70bbed2b576f9b603d9"}

# %% [raw]
# # Statement [11.1]: Albert Einstein published his first paper titled "Folgerungen aus den Capillaritätserscheinungen" in the journal Annalen der Physik in 1901.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Physicist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:author <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#paper_folgerungen> rdf:type schema:ScholarlyArticle .
# <#paper_folgerungen> schema:name "Folgerungen aus den Capillaritätserscheinungen" .
# <#paper_folgerungen> schema:datePublished "1901"^^xsd:date .
# <#paper_folgerungen> schema:author <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#paper_folgerungen> schema:publication <#journal_annalen_der_physik> .
# <#journal_annalen_der_physik> rdf:type schema:PublicationIssue .
# <#journal_annalen_der_physik> schema:name "Annalen der Physik" .
# <#einstein> rdf:type schema:Person .
# <#einstein> schema:name "Albert Einstein" .
# <#paper> rdf:type schema:ScholarlyArticle .
# <#paper> schema:name "Folgerungen aus den Capillaritätserscheinungen" .
# <#paper> schema:datePublished "1901"^^xsd:date .
# <#paper> schema:author <#einstein> .
# <#journal> rdf:type schema:PublicationIssue .
# <#journal> schema:name "Annalen der Physik" .
# <#paper> schema:publication <#journal> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#first_paper> rdf:type schema:ScholarlyArticle .
# <#first_paper> schema:name "Folgerungen aus den Capillaritätserscheinungen" .
# <#first_paper> schema:datePublished "1901"^^xsd:date .
# <#first_paper> schema:author <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#journal> rdf:type schema:PublicationIssue .
# <#journal> schema:name "Annalen der Physik" .
# <#first_paper> schema:publication <#journal> .

# %% [raw]
# {"cell": 358, "stmt_key": "11_1", "chunk_num": 11, "stmt_idx": 1, "type": "rdf", "cid": "56c87ed763efe1906982f6d4bd60a7c58d5a546a2df3a422ed6ad4c7ce233563", "from_cid": "b465eacf1c994c1bb7f22b9a0a4ba9eeb62d04594527240bcf32cde625c85dcb"}

# %% [raw]
# # Statement [11.2]: Albert Einstein proposed a model of intermolecular attraction in his first paper that he later disavowed as worthless.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator <#first_paper> .
# <#first_paper> rdf:type schema:CreativeWork .
# <#first_paper> schema:text "intermolecular attraction model" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:description "later disavowed as worthless" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#first_paper> rdf:type schema:CreativeWork .
# <#first_paper> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#first_paper> schema:text "model of intermolecular attraction" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:description "proposed first paper that he later disavowed as worthless" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#first_paper> rdf:type schema:CreativeWork .
# <#first_paper> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#first_paper> schema:description "model of intermolecular attraction" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "proposed first paper that he later disavowed as worthless" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#first_paper> rdf:type schema:CreativeWork .
# <#first_paper> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#first_paper> schema:name "First Scientific Paper" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Proposed model of intermolecular attraction in first paper that he later disavowed as worthless" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#first_paper> rdf:type schema:CreativeWork .
# <#first_paper> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#first_paper> schema:description "model of intermolecular attraction" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:mainEntityOfPage "Albert Einstein proposed a model of intermolecular attraction in his first paper that he later disavowed as worthless" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#first_paper> rdf:type schema:CreativeWork .
# <#first_paper> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#first_paper> schema:text "model of intermolecular attraction" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:description "proposed first paper that he later disavowed as worthless" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#first_paper> rdf:type schema:CreativeWork .
# <#first_paper> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#first_paper> schema:name "First Scientific Paper" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Proposed model of intermolecular attraction in first paper that he later disavowed as worthless" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#first_paper> rdf:type schema:CreativeWork .
# <#first_paper> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#first_paper> schema:description "model of intermolecular attraction" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:description "proposed first scientific paper that he later disavowed as worthless" .

# %% [raw]
# {"cell": 360, "stmt_key": "11_2", "chunk_num": 11, "stmt_idx": 2, "type": "rdf", "cid": "bcc632f3a9209244db7e910452ab6238f0c834ccca1a209454a9010a052dd8cb", "from_cid": "0301cc7549cb8b154af2f4cff4c85c8ce1de74164ed2970b7e4bae74d3c2fb0a"}

# %% [raw]
# # Statement [11.3]: Albert Einstein completed his 24-page doctoral dissertation titled "Eine neue Bestimmung der Moleküldimensionen" on 30 April 1905.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential <#thesis_einstein_1905> .
# <#thesis_einstein_1905> rdf:type schema:Thesis .
# <#thesis_einstein_1905> schema:name "Eine neue Bestimmung der Moleküldimensionen" .
# <#thesis_einstein_1905> schema:author <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#thesis_einstein_1905> schema:datePublished "1905-04-30"^^xsd:date .

# %% [raw]
# {"cell": 362, "stmt_key": "11_3", "chunk_num": 11, "stmt_idx": 3, "type": "rdf", "cid": "76167307f092f6fa14d3f1653c333e46cf8f76030544d99c6b4847a4b158e943", "from_cid": "ef716cd9134386ca9a4a4664b01505ae632a7f038cf4258a347f35d523e607f8"}

# %% [raw]
# # Statement [11.4]: Albert Einstein's doctoral dissertation was dedicated to his friend Marcel Grossmann.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_marcel_grossmann> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_marcel_grossmann> schema:name "Marcel Grossmann" .
# <#dissertation> rdf:type schema:Thesis .
# <#dissertation> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#dissertation> schema:contributor <https://en.wikipedia.org/wiki/Albert_Einstein#person_marcel_grossmann> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_marcel_grossmann> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_marcel_grossmann> schema:name "Marcel Grossmann" .
# <#dissertation> rdf:type schema:Thesis .
# <#dissertation> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#dissertation> schema:contributor <https://en.wikipedia.org/wiki/Albert_Einstein#person_marcel_grossmann> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_marcel_grossmann> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_marcel_grossmann> schema:name "Marcel Grossmann" .
# <#dissertation> rdf:type schema:Thesis .
# <#dissertation> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#dissertation> schema:contributor <https://en.wikipedia.org/wiki/Albert_Einstein#person_marcel_grossmann> .

# %% [raw]
# {"cell": 364, "stmt_key": "11_4", "chunk_num": 11, "stmt_idx": 4, "type": "rdf", "cid": "aea9557f32b354f784c339f6ffc8a9f9513584de4714c8d821aeb29007ca9ee1", "from_cid": "882643dcbfa7b69277bcd64d7e1f5a7995b357d77d2c97f88ee71ef4d892459c"}

# %% [raw]
# # Statement [11.5]: Professor Alfred Kleiner approved Albert Einstein's doctoral dissertation three months after its completion.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential <#thesis_einstein_dissertation> .
# <#thesis_einstein_dissertation> rdf:type schema:Thesis .
# <#thesis_einstein_dissertation> schema:name "Albert Einstein's Doctoral Dissertation" .
# <#thesis_einstein_dissertation> schema:about "Physics" .
# <#thesis_einstein_dissertation> schema:dateCreated "1905"^^xsd:gYear .
# <#professor_kleiner> rdf:type schema:Person .
# <#professor_kleiner> schema:name "Professor Alfred Kleiner" .
# <#thesis_einstein_dissertation> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#thesis_einstein_dissertation> schema:hasPart <#approval_action> .
# <#approval_action> rdf:type schema:EndorseAction .
# <#approval_action> schema:agent <#professor_kleiner> .
# <#approval_action> schema:object <#thesis_einstein_dissertation> .
# <#approval_action> schema:startDate "1905-04-01"^^xsd:date .
# <#approval_action> schema:endDate "1905-06-01"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#thesis_einstein_dissertation> rdf:type schema:Thesis .
# <#thesis_einstein_dissertation> schema:name "Albert Einstein's Doctoral Dissertation" .
# <#thesis_einstein_dissertation> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#professor_kleiner> rdf:type schema:Person .
# <#professor_kleiner> schema:name "Professor Alfred Kleiner" .
# <#approval_action> rdf:type schema:EndorseAction .
# <#approval_action> schema:agent <#professor_kleiner> .
# <#approval_action> schema:object <#thesis_einstein_dissertation> .
# <#approval_action> schema:startTime "1905-06-01"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#thesis_einstein_dissertation> rdf:type schema:Thesis .
# <#thesis_einstein_dissertation> schema:name "Albert Einstein's Doctoral Dissertation" .
# <#thesis_einstein_dissertation> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#professor_kleiner> rdf:type schema:Person .
# <#professor_kleiner> schema:name "Professor Alfred Kleiner" .
# <#approval_action> rdf:type schema:EndorseAction .
# <#approval_action> schema:agent <#professor_kleiner> .
# <#approval_action> schema:object <#thesis_einstein_dissertation> .
# <#approval_action> schema:startTime "1905-06-01"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#thesis_einstein_dissertation> rdf:type schema:Thesis .
# <#thesis_einstein_dissertation> schema:name "Albert Einstein's Doctoral Dissertation" .
# <#thesis_einstein_dissertation> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#professor_kleiner> rdf:type schema:Person .
# <#professor_kleiner> schema:name "Professor Alfred Kleiner" .
# <#approval_action> rdf:type schema:EndorseAction .
# <#approval_action> schema:agent <#professor_kleiner> .
# <#approval_action> schema:object <#thesis_einstein_dissertation> .
# <#approval_action> schema:startTime "1905-06-01"^^xsd:date .

# %% [raw]
# {"cell": 366, "stmt_key": "11_5", "chunk_num": 11, "stmt_idx": 5, "type": "rdf", "cid": "9971c1340faed9b49b2d5a3e9abc074b0ad1d21bbf387ee5416d8005f337a3d1", "from_cid": "754e7df3b171e47d3f6d38b1a48d88c060f4ffaccfff1b5f28d904b60c10c4ca"}

# %% [raw]
# # Statement [11.6]: Albert Einstein was formally awarded his PhD on 15 January 1906.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential <#phd_credential> .
# <#phd_credential> rdf:type schema:EducationalOccupationalCredential .
# <#phd_credential> schema:educationalCredentialAwarded "Doctor of Philosophy" .
# <#phd_credential> schema:datePublished "1906-01-15"^^xsd:date .

# %% [raw]
# {"cell": 368, "stmt_key": "11_6", "chunk_num": 11, "stmt_idx": 6, "type": "rdf", "cid": "dde93d12b959b44445b79683735f5a6cf9e5c711471d82898ac435bd34c90437", "from_cid": "48684763c1ebecf63552e63782a37d316c8854c86c54d74cd5c8eb675c7bc14b"}

# %% [raw]
# # Statement [11.7]: In 1905, Albert Einstein completed four other pieces of work including papers on the photoelectric effect, Brownian motion, special theory of relativity, and the equivalence of mass and energy.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator "Photoelectric effect paper" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator "Brownian motion paper" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator "Special theory of relativity paper" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator "Equivalence of mass and energy paper" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:dateCreated "1905"^^xsd:gYear .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator "Photoelectric effect paper" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator "Brownian motion paper" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator "Special theory of relativity paper" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator "Equivalence of mass and energy paper" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:dateCreated "1905"^^xsd:gYear .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator <https://en.wikipedia.org/wiki/Photoelectric_effect#paper> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator <https://en.wikipedia.org/wiki/Brownian_motion#paper> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator <https://en.wikipedia.org/wiki/Special_relativity#paper> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator <https://en.wikipedia.org/wiki/Mass-energy_equivalence#paper> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:dateCreated "1905"^^xsd:gYear .

# %% [raw]
# {"cell": 370, "stmt_key": "11_7", "chunk_num": 11, "stmt_idx": 7, "type": "rdf", "cid": "c45655c02b271f840ad3df62ded0f74d5efb6b5202bd6af0de6fea75d20fe9ca", "from_cid": "c3b2d7db01677f9fa3f32b25ed65c0ec3f63b0998b07bd77e9d6e1c95c0ca96a"}

# %% [raw]
# # Statement [11.8]: The year 1905 is celebrated as an annus mirabilis for physics due to Albert Einstein's four famous papers published that year.
# # Error: ValidationError: 1 validation error for emit_triples
# triples
#   Input should be a valid list [type

# %% [raw]
# {"cell": 372, "stmt_key": "11_8", "chunk_num": 11, "stmt_idx": 8, "type": "rdf", "cid": "c8d2dcd215541c20f3ed0bfcd34a34ec312209990a43f26ff34989ed7fbd6b64", "from_cid": "6a6f6f175fb4a7db1c5697104296262cbd06355a16899b598ff0a23aa4664e89"}

# %% [raw]
# # Statement [11.9]: Albert Einstein's publications in 1905 deeply impressed his contemporaries.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:publishes "<https://en.wikipedia.org/wiki/Albert_Einstein#work_1905>" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#work_1905> rdf:type schema:Article .
# <https://en.wikipedia.org/wiki/Albert_Einstein#work_1905> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#work_1905> schema:datePublished "1905"^^xsd:gYear .
# <https://en.wikipedia.org/wiki/Albert_Einstein#work_1905> schema:headline "Einstein's 1905 Publications" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#work_1905>" schema:impact "Deeply impressed contemporaries" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#work_1905> rdf:type schema:Article .
# <https://en.wikipedia.org/wiki/Albert_Einstein#work_1905> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#work_1905> schema:datePublished "1905"^^xsd:gYear .

# %% [raw]
# {"cell": 374, "stmt_key": "11_9", "chunk_num": 11, "stmt_idx": 9, "type": "rdf", "cid": "cd60eab5c24c4a56638f659851f18b668e10028d831c9a805af2d0fd35777c0a", "from_cid": "de57c26af6270d660de72bc8d308b18d13a811cee745ca86f7a8d5664ac980f0"}

# %% [raw]
# # Statement [11.10]: Albert Einstein secured a junior teaching position at the University of Bern in 1908.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation <#role_university_bern> .
# <#role_university_bern> rdf:type schema:Role .
# <#role_university_bern> schema:roleName "Junior Teaching Position" .
# <#role_university_bern> schema:organization <#university_berlin> .
# <#university_berlin> rdf:type schema:CollegeOrUniversity .
# <#university_berlin> schema:name "University of Bern" .
# <#role_university_bern> schema:startDate "1908"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Junior Teaching Position" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <#university_berlin> .
# <#university_berlin> rdf:type schema:CollegeOrUniversity .
# <#university_berlin> schema:name "University of Bern" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:startDate "1908"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#role_einstein_bern> rdf:type schema:Role .
# <#role_einstein_bern> schema:roleName "Junior Teaching Position" .
# <#role_einstein_bern> schema:organization <#university_berlin> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation <#role_einstein_bern> .
# <#university_berlin> rdf:type schema:CollegeOrUniversity .
# <#university_berlin> schema:name "University of Bern" .
# <#role_einstein_bern> schema:startDate "1908"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Junior Teaching Position" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <#university_berlin> .
# <#university_berlin> rdf:type schema:CollegeOrUniversity .
# <#university_berlin> schema:name "University of Bern" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:startDate "1908"^^xsd:date .

# %% [raw]
# {"cell": 376, "stmt_key": "11_10", "chunk_num": 11, "stmt_idx": 10, "type": "rdf", "cid": "cbc691cc1de8564bcd929364e99417605e7e68c47b72f64d3856b4b0bbefc725", "from_cid": "33c7962a37208e931628c5dd25ffb61d95e0b7b848531c61be95d4d604dd91b0"}

# %% [raw]
# # Statement [11.11]: Albert Einstein gave a lecture on relativistic electrodynamics at the University of Zurich in 1909.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation "University of Zurich" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation "University of Zurich" .
# <#lecture_event> rdf:type schema:EducationEvent .
# <#lecture_event> schema:startDate "1909"^^xsd:date .
# <#lecture_event> schema:location "University of Zurich" .
# <#lecture_event> schema:performer <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#lecture_event> rdf:type schema:EducationEvent .
# <#lecture_event> schema:name "Lecture on relativistic electrodynamics" .
# <#lecture_event> schema:startDate "1909"^^xsd:date .
# <#lecture_event> schema:location "University of Zurich" .
# <#lecture_event> schema:performer <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#lecture_event> rdf:type schema:EducationEvent .
# <#lecture_event> schema:name "Lecture on relativistic electrodynamics" .
# <#lecture_event> schema:startDate "1909"^^xsd:date .
# <#lecture_event> schema:location "University of Zurich" .
# <#lecture_event> schema:performer <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .

# %% [raw]
# {"cell": 378, "stmt_key": "11_11", "chunk_num": 11, "stmt_idx": 11, "type": "rdf", "cid": "4336e1214da580ec0d55ae3fa1c112b3aa0671754b1660e46e921880959dcb97", "from_cid": "20ce62a3770e91cebbe3b671f3c57d04431479224ec8badf5a3f9a15f6680445"}

# %% [raw]
# # Statement [11.12]: Alfred Kleiner admired Albert Einstein's lecture on relativistic electrodynamics at the University of Zurich in 1909.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <#person_alfred_kleiner> .
# <#person_alfred_kleiner> rdf:type schema:Person .
# <#person_alfred_kleiner> schema:name "Alfred Kleiner" .
# <#lecture_event> rdf:type schema:EducationEvent .
# <#lecture_event> schema:startDate "1909"^^xsd:date .
# <#lecture_event> schema:location "University of Zurich" .
# <#lecture_event> schema:about "relativistic electrodynamics" .
# <#lecture_event> schema:performer <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#person_alfred_kleiner> schema:attendee <#lecture_event> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#person_alfred_kleiner> rdf:type schema:Person .
# <#person_alfred_kleiner> schema:name "Alfred Kleiner" .
# <#lecture_event> rdf:type schema:EducationEvent .
# <#lecture_event> schema:startDate "1909"^^xsd:date .
# <#lecture_event> schema:location "University of Zurich" .
# <#lecture_event> schema:about "relativistic electrodynamics" .
# <#lecture_event> schema:performer <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#person_alfred_kleiner> schema:attendee <#lecture_event> .
# <#person_alfred_kleiner> schema:knows <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#person_alfred_kleiner> rdf:type schema:Person .
# <#person_alfred_kleiner> schema:name "Alfred Kleiner" .
# <#lecture_event> rdf:type schema:EducationEvent .
# <#lecture_event> schema:startDate "1909"^^xsd:date .
# <#lecture_event> schema:location "University of Zurich" .
# <#lecture_event> schema:about "relativistic electrodynamics" .
# <#lecture_event> schema:performer <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#person_alfred_kleiner> schema:attendee <#lecture_event> .
# <#person_alfred_kleiner> schema:knows <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <#person_alfred_kleiner> rdf:type schema:Person .
# <#person_alfred_kleiner> schema:name "Alfred Kleiner" .
# <#lecture_event> rdf:type schema:EducationEvent .
# <#lecture_event> schema:startDate "1909"^^xsd:date .
# <#lecture_event> schema:location "University of Zurich" .
# <#lecture_event> schema:about "relativistic electrodynamics" .
# <#lecture_event> schema:performer <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#person_alfred_kleiner> schema:attendee <#lecture_event> .
# <#person_alfred_kleiner> schema:knows <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .

# %% [raw]
# {"cell": 380, "stmt_key": "11_12", "chunk_num": 11, "stmt_idx": 12, "type": "rdf", "cid": "a5e81bceaff6d1beac8da865688c57beef6263ab7448e21e62944f239492986b", "from_cid": "aacec090b2c5f96f750904bc9017ae70bb879ec81474091dd61b1c5e18df0ea1"}

# %% [raw]
# # Statement [11.13]: In 1909, the University of Zurich offered Albert Einstein a newly created professorship.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <https://www.wikidata.org/wiki/Q167392> .
# <https://www.wikidata.org/wiki/Q167392> rdf:type schema:CollegeOrUniversity .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Professor" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation <https://schema.org/Researcher> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://www.wikidata.org/wiki/Q167392> rdf:type schema:CollegeOrUniversity .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Professor" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <https://www.wikidata.org/wiki/Q167392> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# https://www.wikidata.org/wiki/Q167392 rdf:type schema:CollegeOrUniversity .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor https://www.wikidata.org/wiki/Q167392 .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Professor" .

# %% [raw]
# {"cell": 382, "stmt_key": "11_13", "chunk_num": 11, "stmt_idx": 13, "type": "rdf", "cid": "18a29cbd10c20908ec9b9e5bdf9c546259f0c84a338730f1cbac6901719f0482", "from_cid": "3639723bacca83d854a12894a16568bc70d297669d365090a137dbf5c6361dce"}

# %% [raw]
# # Statement [11.14]: Albert Einstein was promoted to a full professorship in April 1911.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation <#professor_role> .
# <#professor_role> rdf:type schema:Role .
# <#professor_role> schema:roleName "Full Professor" .
# <#professor_role> schema:startDate "1911-04-01"^^xsd:date .

# %% [raw]
# {"cell": 384, "stmt_key": "11_14", "chunk_num": 11, "stmt_idx": 14, "type": "rdf", "cid": "fde536b697980a8ffa9a81ca93ff9bf596338393381291b4fe039fadcd71171e", "from_cid": "96050b78f23e89ce09e1c27cc30d9995ea3ba4960f4c03017b1afcd03389347d"}

# %% [raw]
# # Statement [11.15]: Albert Einstein took up a chair at the German Charles-Ferdinand University in Prague in April 1911.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor "Charles-Ferdinand University in Prague" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobStartDate "1911-04"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor "Charles-Ferdinand University in Prague" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobStartDate "1911-04"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor "Charles-Ferdinand University in Prague" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobStartDate "1911-04"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor "Charles-Ferdinand University in Prague" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobStartDate "1911-04"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor "Charles-Ferdinand University in Prague" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobStartDate "1911-04"^^xsd:date .

# %% [raw]
# {"cell": 386, "stmt_key": "11_15", "chunk_num": 11, "stmt_idx": 15, "type": "rdf", "cid": "8c3c5cbaf7b66a9719bc4ff68fb4d1fd8b15729a6fcb27b07cb732bac83d17c3", "from_cid": "cc5496ebda105cdad3f4794adb4363966dbe24545235fbec4241258e6375f51f"}

# %% [raw]
# # Statement [11.16]: Albert Einstein had to become an Austrian citizen of the Austro-Hungarian Empire due to his move to Prague.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "Austrian" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation "Prague" .

# %% [raw]
# {"cell": 388, "stmt_key": "11_16", "chunk_num": 11, "stmt_idx": 16, "type": "rdf", "cid": "dc5b544d2a26d06c2341a33e08b588ae193ff9652f61393729ba45cd660a372e", "from_cid": "a236c6ec6b9dea71c4e5c2e4783de7a26ec6d740d7a991918d475fe016345923"}

# %% [raw]
# # Statement [11.17]: Albert Einstein produced eleven research papers during his time in Prague.
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:workLocation "Prague" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:author <#research_paper_1> .
# <#research_paper_1> rdf:type schema:ScholarlyArticle .
# <#research_paper_1> schema:author https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:author <#research_paper_2> .
# <#research_paper_2> rdf:type schema:ScholarlyArticle .
# <#research_paper_2> schema:author https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:author <#research_paper_3> .
# <#research_paper_3> rdf:type schema:ScholarlyArticle .
# <#research_paper_3> schema:author https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:author <#research_paper_4> .
# <#research_paper_4> rdf:type schema:ScholarlyArticle .
# <#research_paper_4> schema:author https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:author <#research_paper_5> .
# <#research_paper_5> rdf:type schema:ScholarlyArticle .
# <#research_paper_5> schema:author https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:author <#research_paper_6> .
# <#research_paper_6> rdf:type schema:ScholarlyArticle .
# <#research_paper_6> schema:author https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:author <#research_paper_7> .
# <#research_paper_7> rdf:type schema:ScholarlyArticle .
# <#research_paper_7> schema:author https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:author <#research_paper_8> .
# <#research_paper_8> rdf:type schema:ScholarlyArticle .
# <#research_paper_8> schema:author https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:author <#research_paper_9> .
# <#research_paper_9> rdf:type schema:ScholarlyArticle .
# <#research_paper_9> schema:author https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:author <#research_paper_10> .
# <#research_paper_10> rdf:type schema:ScholarlyArticle .
# <#research_paper_10> schema:author https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:author <#research_paper_11> .
# <#research_paper_11> rdf:type schema:ScholarlyArticle .
# <#research_paper_11> schema:author https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:workLocation "Prague" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:workLocation "Prague" .

# %% [raw]
# {"cell": 390, "stmt_key": "11_17", "chunk_num": 11, "stmt_idx": 17, "type": "rdf", "cid": "d395e26aa59428661f2b3764ff2d254dd82da3c85fc2397e3a38a61aa09fc377", "from_cid": "93bff87a781f16c514d01da20b370f6fa86b537f8b5b52d64b084bf810b64933"}

# %% [raw]
# # Statement [12.1]: Albert Einstein attended the first Solvay Conference on Physics from 30 October to 3 November 1911.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:attendee <https://en.wikipedia.org/wiki/Solvay_Conference#first_conference> .
# <https://en.wikipedia.org/wiki/Solvay_Conference#first_conference> rdf:type schema:ConferenceEvent .
# <https://en.wikipedia.org/wiki/Solvay_Conference#first_conference> schema:startDate "1911-10-30"^^xsd:date .
# <https://en.wikipedia.org/wiki/Solvay_Conference#first_conference> schema:endDate "1911-11-03"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:attendee <https://en.wikipedia.org/wiki/Solvay_Conference#first_conference> .
# <https://en.wikipedia.org/wiki/Solvay_Conference#first_conference> rdf:type schema:ConferenceEvent .
# <https://en.wikipedia.org/wiki/Solvay_Conference#first_conference> schema:startDate "1911-10-30"^^xsd:date .
# <https://en.wikipedia.org/wiki/Solvay_Conference#first_conference> schema:endDate "1911-11-03"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Solvay_Conference#first_conference> rdf:type schema:ConferenceEvent .
# <https://en.wikipedia.org/wiki/Solvay_Conference#first_conference> schema:startDate "1911-10-30"^^xsd:date .
# <https://en.wikipedia.org/wiki/Solvay_Conference#first_conference> schema:endDate "1911-11-03"^^xsd:date .
# <https://en.wikipedia.org/wiki/Solvay_Conference#first_conference> schema:attendee <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .

# %% [raw]
# {"cell": 392, "stmt_key": "12_1", "chunk_num": 12, "stmt_idx": 1, "type": "rdf", "cid": "6ee4d1e5bfc2eec88acf8a63fa61e6196a356472370c11b6e1423e94cd61c8b8", "from_cid": "3b65b737724f05c5e6ff88dae25554ae1a920d2ec2d676173d0bba74e5c454ae"}

# %% [raw]
# # Statement [12.2]: In July 1912, Albert Einstein returned to the ETH Zurich to take up a chair in theoretical physics.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <https://en.wikipedia.org/wiki/ETH_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Chair in theoretical physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobStartDate "1912-07-01"^^xsd:date .
# <https://en.wikipedia.org/wiki/ETH_Zurich> rdf:type schema:CollegeOrUniversity .

# %% [raw]
# {"cell": 394, "stmt_key": "12_2", "chunk_num": 12, "stmt_idx": 2, "type": "rdf", "cid": "3f95d417bd60789112f7a0dbfe95d338e039dbb9a578699f955717fb44f2d2b3", "from_cid": "ba9672b4c9d753931ae672164f26922fe1954ed3083ace8864fcc7a78527255c"}

# %% [raw]
# # Statement [12.3]: Albert Einstein's teaching activities at the ETH Zurich centered on thermodynamics and analytical mechanics.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation <#teaching_role> .
# <#teaching_role> rdf:type schema:Occupation .
# <#teaching_role> schema:occupationLocation "ETH Zurich" .
# <#teaching_role> schema:description "Teaching activities centered on thermodynamics and analytical mechanics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation <#academic_position> .
# <#academic_position> rdf:type schema:Occupation .
# <#academic_position> schema:name "Professor at ETH Zurich" .
# <#academic_position> schema:occupationLocation "ETH Zurich" .
# <#academic_position> schema:teaches "thermodynamics" .
# <#academic_position> schema:teaches "analytical mechanics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation <#professor_role> .
# <#professor_role> rdf:type schema:Occupation .
# <#professor_role> schema:name "Professor at ETH Zurich" .
# <#professor_role> schema:occupationLocation "ETH Zurich" .
# <#professor_role> schema:description "Teaching activities centered on thermodynamics and analytical mechanics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .

# %% [raw]
# {"cell": 396, "stmt_key": "12_3", "chunk_num": 12, "stmt_idx": 3, "type": "rdf", "cid": "e53d8f4ebe10ce986aafc67f1a50bceb1ce0a70d1cdf72e839a02c60fb6d2663", "from_cid": "d52074b41a2eac3ac4fa7a64c9b94e0bd2f92fd0673f28204e88413454ba9268"}

# %% [raw]
# # Statement [12.4]: Albert Einstein's research interests at the ETH Zurich included the molecular theory of heat, continuum mechanics, and the development of a relativistic theory of gravitation.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation <https://dbpedia.org/resource/ETH_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "molecular theory of heat" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "continuum mechanics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "relativistic theory of gravitation" .

# %% [raw]
# {"cell": 398, "stmt_key": "12_4", "chunk_num": 12, "stmt_idx": 4, "type": "rdf", "cid": "f0974b4a69c7f62812d0fb40984db2dd8935948db0c5c9696e2db294de3bdb54", "from_cid": "969d84f1da9dbeace53f31392358b2450d3637b305dc357dfb4a8540dd1a068e"}

# %% [raw]
# # Statement [12.5]: Marcel Grossmann assisted Albert Einstein in his work on the development of a relativistic theory of gravitation.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Marcel_Grossmann#person_marcel_grossmann> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Marcel_Grossmann#person_marcel_grossmann> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Marcel_Grossmann#person_marcel_grossmann> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows <https://en.wikipedia.org/wiki/Marcel_Grossmann#person_marcel_grossmann> .

# %% [raw]
# {"cell": 400, "stmt_key": "12_5", "chunk_num": 12, "stmt_idx": 5, "type": "rdf", "cid": "7b856b7b79b23506a06771d68a89c1b775a7c59660fccb5213bca2610dfc39a7", "from_cid": "a4c11824cfcd21166bda475a67be00e18950f5461a85045680fad0af046596e1"}

# %% [raw]
# # Statement [12.6]: In the spring of 1913, Max Planck and Walther Nernst called upon Albert Einstein in Zurich.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Max_Planck#person_max_planck> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Max_Planck#person_max_planck> schema:name "Max Planck" .
# <https://en.wikipedia.org/wiki/Walther_Nernst#person_walther_nernst> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Walther_Nernst#person_walther_nernst> schema:name "Walther Nernst" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Max_Planck#person_max_planck> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Walther_Nernst#person_walther_nernst> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Max_Planck#person_max_planck> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Walther_Nernst#person_walther_nernst> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Physicist"@en .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Max_Planck#person_max_planck> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Walther_Nernst#person_walther_nernst> rdf:type schema:Person .

# %% [raw]
# {"cell": 402, "stmt_key": "12_6", "chunk_num": 12, "stmt_idx": 6, "type": "rdf", "cid": "c753bba0e9a07beccb78e15102206aa38e31ff34212a8b12f829c1705deed3d6", "from_cid": "67ec4d0cd545b5146848b925736aac5f4477742a27009aa35a71804e45cdda4f"}

# %% [raw]
# # Statement [12.7]: Max Planck and Walther Nernst hoped to persuade Albert Einstein to relocate to Berlin.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Max_Planck> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Walther_Nernst> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Max_Planck> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Walther_Nernst> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Max_Planck> schema:potentialAction <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Walther_Nernst> schema:potentialAction <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Max_Planck> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Walther_Nernst> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Max_Planck> schema:potentialAction <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Walther_Nernst> schema:potentialAction <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Max_Planck> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Walther_Nernst> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Max_Planck> schema:potentialAction <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Walther_Nernst> schema:potentialAction <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:potentialAction <https://en.wikipedia.org/wiki/Max_Planck> .
# <https://en.wikipedia.org/wiki/Max_Planck> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Walther_Nernst> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Max_Planck> schema:potentialAction <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <https://en.wikipedia.org/wiki/Walther_Nernst> schema:potentialAction <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .

# %% [raw]
# {"cell": 404, "stmt_key": "12_7", "chunk_num": 12, "stmt_idx": 7, "type": "rdf", "cid": "79985b2b6ec322533831f254e500af79d00f4432c82a4e01a1f776b66c0f9c21", "from_cid": "2b6b8d894ffef70dd623712199d0ec36ccffa584dfcf32a3f81b13f1aa02677f"}

# %% [raw]
# # Statement [12.8]: Max Planck and Walther Nernst offered Albert Einstein membership of the Prussian Academy of Sciences.
# # Error: ValidationError: 1 validation error for emit_triples
# triples
#   Input should be a valid list [type

# %% [raw]
# {"cell": 406, "stmt_key": "12_8", "chunk_num": 12, "stmt_idx": 8, "type": "rdf", "cid": "3e157f847a90be32b63a797810e07f98217a7e19ef65f2b732b8a3ca845ec0c6", "from_cid": "8b6fb47044aaacf09b4a0f680f0c1baadeef268d7f31ae9588298c1f820ff929"}

# %% [raw]
# # Statement [12.9]: Max Planck and Walther Nernst offered Albert Einstein the directorship of the planned Kaiser Wilhelm Institute for Physics.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Theoretical Physicist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor "Princeton University" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "ETH Zurich" .
# <#offer_directorship> rdf:type schema:Offer .
# <#offer_directorship> schema:offeredBy <https://en.wikipedia.org/wiki/Max_Planck#person_max_planck> .
# <#offer_directorship> schema:offeredBy <https://en.wikipedia.org/wiki/Walther_Nernst#person_walther_nernst> .
# <#offer_directorship> schema:acceptedOffer <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#offer_directorship> rdf:type schema:Offer .
# <#offer_directorship> schema:offeredBy <https://en.wikipedia.org/wiki/Max_Planck#person_max_planck> .
# <#offer_directorship> schema:offeredBy <https://en.wikipedia.org/wiki/Walther_Nernst#person_walther_nernst> .
# <#offer_directorship> schema:acceptedOffer <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> .
# <#offer_directorship> schema:description "Directorship of the planned Kaiser Wilhelm Institute for Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Max_Planck#person_max_planck> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Walther_Nernst#person_walther_nernst> rdf:type schema:Person .

# %% [raw]
# {"cell": 408, "stmt_key": "12_9", "chunk_num": 12, "stmt_idx": 9, "type": "rdf", "cid": "ddc70309766979138bf39e507aacc9b1e44280aa375ce55676e6108f39059f54", "from_cid": "f55a8db5779795c8a66d005eede193b553071a3d5c81d7c4e3f691b3ea42f7ff"}

# %% [raw]
# # Statement [12.10]: Max Planck and Walther Nernst offered Albert Einstein a chair at the Humboldt University of Berlin.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation <https://www.wikidata.org/wiki/Q152070> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://www.wikidata.org/wiki/Q152070> rdf:type schema:CollegeOrUniversity .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation <https://www.wikidata.org/wiki/Q152070> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://www.wikidata.org/wiki/Q152070> rdf:type schema:CollegeOrUniversity .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation <https://www.wikidata.org/wiki/Q152070> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <https://www.wikidata.org/wiki/Q152070> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation <https://www.wikidata.org/wiki/Q152070> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://www.wikidata.org/wiki/Q152070> rdf:type schema:CollegeOrUniversity .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation <https://www.wikidata.org/wiki/Q152070> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <https://www.wikidata.org/wiki/Q152070> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation <https://www.wikidata.org/wiki/Q152070> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://www.wikidata.org/wiki/Q152070> rdf:type schema:CollegeOrUniversity .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation <https://www.wikidata.org/wiki/Q152070> .

# %% [raw]
# {"cell": 410, "stmt_key": "12_10", "chunk_num": 12, "stmt_idx": 10, "type": "rdf", "cid": "af3435c5189a7af0cc56ad6af985858bbbd7495b88cbed62a40f25aa7390084e", "from_cid": "d3fa7cfbb652db274aa463632a280ce58ea09a7021913bf030ae911d0619bb43"}

# %% [raw]
# # Statement [12.11]: Albert Einstein joined the Prussian Academy of Sciences on 24 July 1913.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> .
# <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> rdf:type schema:ResearchOrganization .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> .
# <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> rdf:type schema:ResearchOrganization .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .

# %% [raw]
# {"cell": 412, "stmt_key": "12_11", "chunk_num": 12, "stmt_idx": 11, "type": "rdf", "cid": "852c50209f2e56fa4157500b514cc0223519d819dc61058c546cd797f71af7c7", "from_cid": "94d457baa4895b2aeb572c342db67854339cf74d9db0bd6abf887075659a1ef1"}

# %% [raw]
# # Statement [12.12]: Albert Einstein moved into an apartment in the Berlin district of Dahlem on 1 April 1914.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation "Berlin district of Dahlem" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation "Berlin district of Dahlem" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation "Berlin district of Dahlem" .

# %% [raw]
# {"cell": 414, "stmt_key": "12_12", "chunk_num": 12, "stmt_idx": 12, "type": "rdf", "cid": "fb2df08c521cfd619e3af84b8d6ee16d3e28bc41b8881f6382a30120c49fd72d", "from_cid": "995ed53a0632f74f45d8e28b52d39f98f6b7178215210d426d7067c365b3eb99"}

# %% [raw]
# # Statement [12.13]: Albert Einstein was installed in his Humboldt University position shortly after moving to Berlin.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Researcher .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> .
# <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> rdf:type schema:CollegeOrUniversity .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation <https://en.wikipedia.org/wiki/Berlin> .

# %% [raw]
# {"cell": 416, "stmt_key": "12_13", "chunk_num": 12, "stmt_idx": 13, "type": "rdf", "cid": "4b706c45921c560a4e810f5983b4906225d66d31ef9d05e8984af9937edb1c9e", "from_cid": "3ec9592899fb08f7d47ef6162dba1d0be1ae37ccbdee83810ab42de396e8ca22"}

# %% [raw]
# # Statement [12.14]: Elsa Löwenthal was the latest girlfriend of Albert Einstein.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Elsa_Loewenthal> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Elsa_Loewenthal> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Elsa_Loewenthal> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:spouse <https://en.wikipedia.org/wiki/Elsa_Loewenthal> .

# %% [raw]
# {"cell": 418, "stmt_key": "12_14", "chunk_num": 12, "stmt_idx": 14, "type": "rdf", "cid": "4af9c6e348b073c38f4f572907d726c1d7544296a41d215ee339817b5dda384c", "from_cid": "6c8a5bfa176f9537036b5b79fcf8d8f44a2862d0aa7fec58f313bb3fa9f2cf7c"}

# %% [raw]
# # Statement [12.15]: Elsa Löwenthal lived in Berlin.
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein schema:homeLocation <https://www.wikidata.org/entity/Q64> .
# <#elsa_loewenthal> rdf:type schema:Person .
# <#elsa_loewenthal> schema:homeLocation <https://www.wikidata.org/entity/Q64> .
# <https://www.wikidata.org/entity/Q64> rdf:type schema:City .
# <#elsa_loewenthal> rdf:type schema:Person .
# <#elsa_loewenthal> schema:homeLocation <https://www.wikidata.org/entity/Q64> .
# <https://www.wikidata.org/entity/Q64> rdf:type schema:City .
# <#elsa_loewenthal> rdf:type schema:Person .
# <#elsa_loewenthal> schema:homeLocation <https://www.wikidata.org/entity/Q64> .
# <https://www.wikidata.org/entity/Q64> rdf:type schema:City .
# <#elsa_loewenthal> rdf:type schema:Person .
# <#elsa_loewenthal> schema:homeLocation <https://www.wikidata.org/entity/Q64> .
# <https://www.wikidata.org/entity/Q64> rdf:type schema:City .
# <#elsa_loewenthal> rdf:type schema:Person .
# <#elsa_loewenthal> schema:homeLocation <https://www.wikidata.org/entity/Q64> .
# <https://www.wikidata.org/entity/Q64> rdf:type schema:City .

# %% [raw]
# {"cell": 420, "stmt_key": "12_15", "chunk_num": 12, "stmt_idx": 15, "type": "rdf", "cid": "786b934ff3ff9ec017976334f60b10b22ef5151a8055c54e9725e5f2998c80e5", "from_cid": "57c6384c38461adeb541aafe4ea7a8f4599f82f9b1ac44095a12a16d7ceb0808"}

# %% [raw]
# # Statement [13.1]: The First World War began in July 1914.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/First_World_War> rdf:type schema:Event .
# <https://en.wikipedia.org/wiki/First_World_War> schema:startDate "1914-07-01"^^xsd:date .
# <https://en.wikipedia.org/wiki/First_World_War> rdf:type schema:Event .
# <https://en.wikipedia.org/wiki/First_World_War> schema:startDate "1914-07-01"^^xsd:date .

# %% [raw]
# {"cell": 422, "stmt_key": "13_1", "chunk_num": 13, "stmt_idx": 1, "type": "rdf", "cid": "49137797899128455c4cab95c7e9d2e49698ae15b1a6982645eff40073f408c7", "from_cid": "41b2097adaf0c44bda5982c791e4d9ae10e7ffdd8f71f38118746a58ea71c547"}

# %% [raw]
# # Statement [13.2]: Albert Einstein experienced gradual estrangement from his nation of birth following the outbreak of the First World War.
# # Error: ValidationError: 1 validation error for emit_triples
# triples
#   Input should be a valid list [type

# %% [raw]
# {"cell": 424, "stmt_key": "13_2", "chunk_num": 13, "stmt_idx": 2, "type": "rdf", "cid": "048a370e56db2022efbfe05cbd64b97a2ebb86519868e8500ab90c38af9d9767", "from_cid": "4965459766047af3bcc6073774fc31455ed6ee35b18fb89b885e9ec392f9f5ea"}

# %% [raw]
# # Statement [13.3]: The "Manifesto of the Ninety-Three" was published in October 1914.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <#manifesto_ninety_three> rdf:type schema:Statement .
# <#manifesto_ninety_three> schema:name "The Manifesto of the Ninety-Three" .
# <#manifesto_ninety_three> schema:datePublished "1914-10-01"^^xsd:date .
# <#manifesto_ninety_three> rdf:type schema:Statement .
# <#manifesto_ninety_three> schema:name "The Manifesto of the Ninety-Three" .
# <#manifesto_ninety_three> schema:datePublished "1914-10-01"^^xsd:date .
# <#manifesto_ninety_three> rdf:type schema:Statement .
# <#manifesto_ninety_three> schema:name "The Manifesto of the Ninety-Three" .
# <#manifesto_ninety_three> schema:datePublished "1914-10-01"^^xsd:date .

# %% [raw]
# {"cell": 426, "stmt_key": "13_3", "chunk_num": 13, "stmt_idx": 3, "type": "rdf", "cid": "5fcd60d1ed1047464dd66e102651b15290117c76dd899140f25ed87762fb0fb1", "from_cid": "3d80f8a46e69751880bf3f94ef58a001a40f3df125a2361db5a649635298f566"}

# %% [raw]
# # Statement [13.4]: The "Manifesto of the Ninety-Three" was signed by a host of prominent German thinkers.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "German" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "German" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "German" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "German" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .

# %% [raw]
# {"cell": 428, "stmt_key": "13_4", "chunk_num": 13, "stmt_idx": 4, "type": "rdf", "cid": "39253543858772585fc80e3b860a7bc0546944b1b5d9cb9e96dafd42ed987926", "from_cid": "7bfaae9f3162ed060cae0e50425a27e3a2964d15b6d6ad790fe2937a37f9cbe6"}

# %% [raw]
# # Statement [13.5]: The "Manifesto of the Ninety-Three" justified Germany's belligerence.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knownFor "Theoretical physicist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "German" .
# <https://en.wikipedia.org/wiki/Manifesto_of_the_Ninety-Three> rdf:type schema:CreativeWork .
# <https://en.wikipedia.org/wiki/Manifesto_of_the_Ninety-Three> schema:name "The Manifesto of the Ninety-Three" .
# <https://en.wikipedia.org/wiki/Manifesto_of_the_Ninety-Three> schema:mentions "Germany's belligerence" .
# <https://en.wikipedia.org/wiki/Manifesto_of_the_Ninety-Three> rdf:type schema:CreativeWork .
# <https://en.wikipedia.org/wiki/Manifesto_of_the_Ninety-Three> schema:name "The Manifesto of the Ninety-Three" .
# <https://en.wikipedia.org/wiki/Manifesto_of_the_Ninety-Three> schema:hasPart "Germany's belligerence" .
# <https://en.wikipedia.org/wiki/Manifesto_of_the_Ninety-Three> schema:description "Justified Germany's belligerence" .
# <https://en.wikipedia.org/wiki/Manifesto_of_the_Ninety-Three> schema:about "Germany's belligerence" .
# <https://en.wikipedia.org/wiki/Manifesto_of_the_Ninety-Three> rdf:type schema:CreativeWork .
# <https://en.wikipedia.org/wiki/Manifesto_of_the_Ninety-Three> schema:name "The Manifesto of the Ninety-Three" .
# <https://en.wikipedia.org/wiki/Manifesto_of_the_Ninety-Three> schema:mainEntityOfPage "https://en.wikipedia.org/wiki/Manifesto_of_the_Ninety-Three" .
# <https://en.wikipedia.org/wiki/Manifesto_of_the_Ninety-Three> schema:contentRating "Supported Germany's belligerence" .
# <https://en.wikipedia.org/wiki/Manifesto_of_the_Ninety-Three> rdf:type schema:CreativeWork .
# <https://en.wikipedia.org/wiki/Manifesto_of_the_Ninety-Three> rdf:type schema:CreativeWork .
# <https://en.wikipedia.org/wiki/Manifesto_of_the_Ninety-Three> schema:name "The Manifesto of the Ninety-Three" .
# <https://en.wikipedia.org/wiki/Manifesto_of_the_Ninety-Three> schema:description "Justified Germany's belligerence" .

# %% [raw]
# {"cell": 430, "stmt_key": "13_5", "chunk_num": 13, "stmt_idx": 5, "type": "rdf", "cid": "306fd00137138353bfa5bb94e5af3efb14585524eaef540aeed70f1ad525c3b0", "from_cid": "53af5563c1eff19dec0d3d87cfcf91b8f6fae78e58f427ac9a3ccf09d01a7d32"}

# %% [raw]
# # Statement [13.6]: Albert Einstein signed the alternative, irenic "Manifesto to the Europeans" instead of the "Manifesto of the Ninety-Three."
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:signed "Manifesto to the Europeans" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:signed "Manifesto of the Ninety-Three" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:author "Manifesto to the Europeans" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:author "Manifesto of the Ninety-Three" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator "Manifesto to the Europeans" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:creator "Manifesto of the Ninety-Three" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:author "Manifesto to the Europeans" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:author "Manifesto of the Ninety-Three" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# "Manifesto to the Europeans" rdf:type schema:CreativeWork .
# "Manifesto of the Ninety-Three" rdf:type schema:CreativeWork .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# "Manifesto to the Europeans" rdf:type schema:CreativeWork .
# "Manifesto of the Ninety-Three" rdf:type schema:CreativeWork .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# "Manifesto to the Europeans" rdf:type schema:CreativeWork .
# "Manifesto of the Ninety-Three" rdf:type schema:CreativeWork .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# "Manifesto to the Europeans" rdf:type schema:CreativeWork .
# "Manifesto of the Ninety-Three" rdf:type schema:CreativeWork .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "Manifesto to the Europeans" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "Manifesto of the Ninety-Three" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# "Manifesto to the Europeans" rdf:type schema:CreativeWork .
# "Manifesto of the Ninety-Three" rdf:type schema:CreativeWork .

# %% [raw]
# {"cell": 432, "stmt_key": "13_6", "chunk_num": 13, "stmt_idx": 6, "type": "rdf", "cid": "8e7d7b83be77573bfd9f814d1d08a9190aa196be02708e31261eda1e182033ca", "from_cid": "0d8f8046fc40125b5d3d7379d1fe9165ac0b80297ca53b55e5ebcc8393fa634f"}

# %% [raw]
# # Statement [13.7]: Albert Einstein was elected president of the German Physical Society in 1916.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "president of the German Physical Society" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "president of the German Physical Society" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "president of the German Physical Society"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "president of the German Physical Society" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "president of the German Physical Society" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "president of the German Physical Society" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "president of the German Physical Society"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "president of the German Physical Society" .

# %% [raw]
# {"cell": 434, "stmt_key": "13_7", "chunk_num": 13, "stmt_idx": 7, "type": "rdf", "cid": "327a59133d10f4ab3ac0d00aa488f58e226ea2d754d6a475decf757cf0a59e68", "from_cid": "9aa53c5c5dd6659d19b6b9cd0bff0a59f82f4aeafd0320b052066b63032fd746"}

# %% [raw]
# # Statement [13.8]: The Kaiser Wilhelm Institute for Physics opened its doors in 1917.
# # Error: ValidationError: 1 validation error for emit_triples
# triples
#   Input should be a valid list [type

# %% [raw]
# {"cell": 436, "stmt_key": "13_8", "chunk_num": 13, "stmt_idx": 8, "type": "rdf", "cid": "0148c2694c2e157e0db77b2cbb4aa20002adcbe9c15f5384ec6e4dc6f4f4efd8", "from_cid": "6fa8cf7e220f49f4d31caccec0f4163367e1f6d8f124338ad75ebd8420e1b149"}

# %% [raw]
# # Statement [13.9]: The foundation of the Kaiser Wilhelm Institute for Physics was delayed because of the First World War.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute_for_Physics> rdf:type schema:ResearchOrganization .
# <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute_for_Physics> schema:name "Kaiser Wilhelm Institute for Physics" .
# <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute_for_Physics> schema:foundingDate "1917-01-01"^^xsd:date .
# <https://en.wikipedia.org/wiki/First_World_War> rdf:type schema:Event .
# <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute_for_Physics> rdf:type schema:ResearchOrganization .
# <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute_for_Physics> schema:name "Kaiser Wilhelm Institute for Physics" .
# <https://en.wikipedia.org/wiki/First_World_War> rdf:type schema:Event .
# <https://en.wikipedia.org/wiki/First_World_War> schema:name "World War I" .
# <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute_for_Physics> schema:foundingDate "1917-01-01"^^xsd:date .
# <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute_for_Physics> rdf:type schema:ResearchOrganization .
# <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute_for_Physics> schema:name "Kaiser Wilhelm Institute for Physics" .
# <https://en.wikipedia.org/wiki/First_World_War> rdf:type schema:Event .
# <https://en.wikipedia.org/wiki/First_World_War> schema:name "World War I" .
# <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute_for_Physics> schema:foundingDate "1917-01-01"^^xsd:date .

# %% [raw]
# {"cell": 438, "stmt_key": "13_9", "chunk_num": 13, "stmt_idx": 9, "type": "rdf", "cid": "ecc8544cf533658e755af9a366e57d47ca4eb4f7919f79afcc11d9539c0dc0b1", "from_cid": "9aef0c9e5c75c8e02bb01cedfc12f2f30ddf8bb771fb3094268a2c15676ee4d0"}

# %% [raw]
# # Statement [13.10]: Albert Einstein was appointed the first director of the Kaiser Wilhelm Institute for Physics.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Director of Kaiser Wilhelm Institute for Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Director of Kaiser Wilhelm Institute for Physics" .

# %% [raw]
# {"cell": 440, "stmt_key": "13_10", "chunk_num": 13, "stmt_idx": 10, "type": "rdf", "cid": "4159e8f6386362bf79d2001fe2b515b1c5a17f6f65f3a820060853cde19b13d2", "from_cid": "e0a87ecbd92f1dd82cb2690ecaa3c0261d78f237f0e079207d945b2b5e8da3dd"}

# %% [raw]
# # Statement [13.11]: Planck and Nernst had promised Albert Einstein the position of director at the Kaiser Wilhelm Institute for Physics.
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# <#person_planck> rdf:type schema:Person .
# <#person_nernst> rdf:type schema:Person .
# <#institution_kaiser_wilhelm> rdf:type schema:Organization .
# <#person_planck> schema:worksFor <#institution_kaiser_wilhelm> .
# <#person_nernst> schema:worksFor <#institution_kaiser_wilhelm> .
# <#person_planck> schema:makesOffer <#offer_director_position> .
# <#person_nernst> schema:makesOffer <#offer_director_position> .
# <#offer_director_position> rdf:type schema:Offer .
# <#offer_director_position> schema:acceptedBy https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .
# <#offer_director_position> schema:jobTitle "Director" .
# <#offer_director_position> schema:offeredBy <#person_planck> .
# <#offer_director_position> schema:offeredBy <#person_nernst> .
# <#institution_kaiser_wilhelm> schema:name "Kaiser Wilhelm Institute for Physics" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# <#person_planck> rdf:type schema:Person .
# <#person_nernst> rdf:type schema:Person .
# <#institution_kaiser_wilhelm> rdf:type schema:Organization .
# <#person_planck> schema:worksFor <#institution_kaiser_wilhelm> .
# <#person_nernst> schema:worksFor <#institution_kaiser_wilhelm> .
# <#person_planck> schema:makesOffer <#offer_director_position> .
# <#person_nernst> schema:makesOffer <#offer_director_position> .
# <#offer_director_position> rdf:type schema:Offer .
# <#offer_director_position> schema:acceptedBy https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .
# <#offer_director_position> schema:jobTitle "Director" .
# <#offer_director_position> schema:offeredBy <#person_planck> .
# <#offer_director_position> schema:offeredBy <#person_nernst> .
# <#institution_kaiser_wilhelm> schema:name "Kaiser Wilhelm Institute for Physics" .
# https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein rdf:type schema:Person .
# <#person_planck> rdf:type schema:Person .
# <#person_nernst> rdf:type schema:Person .
# <#institution_kaiser_wilhelm> rdf:type schema:Organization .
# <#person_planck> schema:worksFor <#institution_kaiser_wilhelm> .
# <#person_nernst> schema:worksFor <#institution_kaiser_wilhelm> .
# <#person_planck> schema:makesOffer <#offer_director_position> .
# <#person_nernst> schema:makesOffer <#offer_director_position> .
# <#offer_director_position> rdf:type schema:Offer .
# <#offer_director_position> schema:acceptedBy https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein .
# <#offer_director_position> schema:jobTitle "Director" .
# <#offer_director_position> schema:offeredBy <#person_planck> .
# <#offer_director_position> schema:offeredBy <#person_nernst> .
# <#institution_kaiser_wilhelm> schema:name "Kaiser Wilhelm Institute for Physics" .

# %% [raw]
# {"cell": 442, "stmt_key": "13_11", "chunk_num": 13, "stmt_idx": 11, "type": "rdf", "cid": "c459fef8f0074c7582a2d49c07f676717a3f92b3e015e845809170da4fa6036e", "from_cid": "9e631141bd370faf5385d336f67733d1fe6a533d7bf91e423e3d6608ef571794"}

# %% [raw]
# # Statement [13.12]: Albert Einstein was elected a Foreign Member of the Royal Netherlands Academy of Arts and Sciences in 1920.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:memberOf "Royal Netherlands Academy of Arts and Sciences" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:member "Royal Netherlands Academy of Arts and Sciences" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Foreign Member" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:memberOf "Royal Netherlands Academy of Arts and Sciences" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Foreign Member" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "1920" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:memberOf "Royal Netherlands Academy of Arts and Sciences" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Foreign Member" .

# %% [raw]
# {"cell": 444, "stmt_key": "13_12", "chunk_num": 13, "stmt_idx": 12, "type": "rdf", "cid": "05abc04805a993cb2e5c27425d88757a9006f16adb46b40165c789e44d23f941", "from_cid": "26a189e5cf992cf1ff15f3caa619528de6508e4eedcad45a9038aac76eef3d9e"}

# %% [raw]
# # Statement [13.13]: Albert Einstein was elected a Foreign Member of the Royal Society in 1921.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:memberOf <https://www.wikidata.org/wiki/Q1265398> .
# <https://www.wikidata.org/wiki/Q1265398> rdf:type schema:Organization .
# <https://www.wikidata.org/wiki/Q1265398> schema:name "Royal Society" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:member <https://www.wikidata.org/wiki/Q1265398> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:member "Foreign Member" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:memberOf <https://www.wikidata.org/wiki/Q1265398> .
# <https://www.wikidata.org/wiki/Q1265398> rdf:type schema:Organization .
# <https://www.wikidata.org/wiki/Q1265398> schema:name "Royal Society" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:member <https://www.wikidata.org/wiki/Q1265398> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:member "Foreign Member" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:memberOf <https://www.wikidata.org/wiki/Q1265398> .
# <https://www.wikidata.org/wiki/Q1265398> rdf:type schema:Organization .
# <https://www.wikidata.org/wiki/Q1265398> schema:name "Royal Society" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:member <https://www.wikidata.org/wiki/Q1265398> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:member "Foreign Member" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:memberOf <https://www.wikidata.org/wiki/Q1265398> .
# <https://www.wikidata.org/wiki/Q1265398> rdf:type schema:Organization .
# <https://www.wikidata.org/wiki/Q1265398> schema:name "Royal Society" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Foreign Member of the Royal Society" .

# %% [raw]
# {"cell": 446, "stmt_key": "13_13", "chunk_num": 13, "stmt_idx": 13, "type": "rdf", "cid": "d2a646723878d175d6387e6d55cb93612a9dbd0d86c5d314778cd6debf3ced94", "from_cid": "fcfec5660b6e5fa828094eea6faac8c0e6192a30ff2945ce6134aed7bab197fe"}

# %% [raw]
# # Statement [13.14]: Albert Einstein was awarded the 1921 Nobel Prize in Physics in 1922.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "1921 Nobel Prize in Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "1922" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "1921 Nobel Prize in Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "1922" .

# %% [raw]
# {"cell": 448, "stmt_key": "13_14", "chunk_num": 13, "stmt_idx": 14, "type": "rdf", "cid": "5be34addbb0fe3a3e83db90f64b11f2beac7fc7631aabab5ee814e5a06ea66e9", "from_cid": "d1aa503a2b19fa7f3aa654daa64df8a27c2234d2a04f9130617e55fb71b3f234"}

# %% [raw]
# # Statement [13.15]: The Nobel Prize in Physics was awarded to Albert Einstein "for his services to Theoretical Physics, and especially for his discovery of the law of the photoelectric effect."
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "The Nobel Prize in Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "for his services to Theoretical Physics, and especially for his discovery of the law of the photoelectric effect." .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "The Nobel Prize in Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "The Nobel Prize in Physics for his services to Theoretical Physics, and especially for his discovery of the law of the photoelectric effect" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "The Nobel Prize in Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "for his services to Theoretical Physics, and especially for his discovery of the law of the photoelectric effect." .

# %% [raw]
# {"cell": 450, "stmt_key": "13_15", "chunk_num": 13, "stmt_idx": 15, "type": "rdf", "cid": "8e8fc9d0598610cb39fc8be627de206ec681cb00b06cc494340b22193ca4962a", "from_cid": "ec34d1c2c0b51fdbdb732895d60283403bc4f657e1a15fe24a27a2875d88c020"}

# %% [raw]
# # Statement [13.16]: Some physicists regarded the general theory of relativity skeptically in 1922.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Physicist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:ScientificTheory .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Physicist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Physicist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Physicist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Scientist .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "General theory of relativity" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein"@en .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasWork "General theory of relativity" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "General theory of relativity" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor "Princeton University" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "General theory of relativity" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation "Princeton University" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Germany" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "German" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "ETH Zurich" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Doctorate in Physics" .

# %% [raw]
# {"cell": 452, "stmt_key": "13_16", "chunk_num": 13, "stmt_idx": 16, "type": "rdf", "cid": "a6a79b2589a3ae500af13ac2ef373d6e70e1216adcc028d60fad099a76030c9f", "from_cid": "452df940b913642c2be0ae3d7e2471dc48621743a6a306d28b7f03effd51e0da"}

# %% [raw]
# # Statement [13.17]: The Nobel citation displayed doubt about Einstein's work on photoelectricity.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Nobel Prize" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Nobel Prize in Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Nobel Prize in Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Nobel Prize" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Nobel Prize in Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Nobel Prize" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Nobel Prize in Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Nobel Prize" .

# %% [raw]
# {"cell": 454, "stmt_key": "13_17", "chunk_num": 13, "stmt_idx": 17, "type": "rdf", "cid": "64b4067b06b85de90ffa06a709c9a0371b62080d044a0921dea1681985954715", "from_cid": "d3575b037bb9c935ddef9b4895b6c5f6f3d4958919d70525cb7361fb4df3367e"}

# %% [raw]
# # Statement [13.18]: The Nobel citation did not assent to Einstein's notion of the particulate nature of light.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Nobel Prize" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Nobel Prize" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "particulate nature of light" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Nobel Prize" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Nobel Prize" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "particulate nature of light" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Nobel Prize" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "particulate nature of light" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Nobel Prize" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "particulate nature of light" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Nobel Prize" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "particulate nature of light" .

# %% [raw]
# {"cell": 456, "stmt_key": "13_18", "chunk_num": 13, "stmt_idx": 18, "type": "rdf", "cid": "4232fb359c529b36c15e397650c5b85e630134cfa038acbc7649ea6b95040a94", "from_cid": "32fb5512c48a1a432264c2a6563af35ac4b3def04a8de4f208283e5005f4bb84"}

# %% [raw]
# # Statement [13.19]: S. N. Bose derived the Planck spectrum in 1924.
# <https://en.wikipedia.org/wiki/S._N._Bose#person_s_n_bose> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/S._N._Bose#person_s_n_bose> schema:name "S. N. Bose" .
# <https://en.wikipedia.org/wiki/Planck_spectrum> rdf:type schema:CreativeWork .
# <https://en.wikipedia.org/wiki/Planck_spectrum> schema:name "Planck spectrum" .
# <https://en.wikipedia.org/wiki/S._N._Bose#person_s_n_bose> schema:hasCredential "Scientist" .
# <https://en.wikipedia.org/wiki/S._N._Bose#person_s_n_bose> schema:contributedTo <https://en.wikipedia.org/wiki/Planck_spectrum> .
# <https://en.wikipedia.org/wiki/Planck_spectrum> schema:dateCreated "1924"^^xsd:gYear .
# <https://en.wikipedia.org/wiki/S._N._Bose#person_s_n_bose> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/S._N._Bose#person_s_n_bose> schema:name "S. N. Bose" .
# <https://en.wikipedia.org/wiki/Planck_spectrum> rdf:type schema:CreativeWork .
# <https://en.wikipedia.org/wiki/Planck_spectrum> schema:name "Planck spectrum" .
# <https://en.wikipedia.org/wiki/S._N._Bose#person_s_n_bose> schema:knows <https://en.wikipedia.org/wiki/Planck_spectrum> .
# <https://en.wikipedia.org/wiki/S._N._Bose#person_s_n_bose> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/S._N._Bose#person_s_n_bose> schema:name "S. N. Bose" .
# <https://en.wikipedia.org/wiki/Planck_spectrum> rdf:type schema:CreativeWork .
# <https://en.wikipedia.org/wiki/Planck_spectrum> schema:name "Planck spectrum" .
# <https://en.wikipedia.org/wiki/S._N._Bose#person_s_n_bose> schema:hasOccupation schema:Researcher .
# <https://en.wikipedia.org/wiki/S._N._Bose#person_s_n_bose> schema:contributedTo <https://en.wikipedia.org/wiki/Planck_spectrum> .
# <https://en.wikipedia.org/wiki/Planck_spectrum> schema:dateCreated "1924"^^xsd:gYear .

# %% [raw]
# {"cell": 458, "stmt_key": "13_19", "chunk_num": 13, "stmt_idx": 19, "type": "rdf", "cid": "b676deec74715c73e52e9418bd3963dcaf85f613325e3362432810e40db33c92", "from_cid": "292f775f52adcaffae4b4eb07138019d69675a8a0203a9b1ca3e6e6654ed96b5"}

# %% [raw]
# # Statement [13.20]: The derivation of the Planck spectrum by S. N. Bose won over the entire scientific community to Einstein's notion of the particulate nature of light.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "particulate nature of light" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knownFor "Particulate nature of light" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "Particulate nature of light" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "particulate nature of light" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Physicist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knows "particulate nature of light" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contribution "Particulate nature of light" .

# %% [raw]
# {"cell": 460, "stmt_key": "13_20", "chunk_num": 13, "stmt_idx": 20, "type": "rdf", "cid": "5e15f2c6456f0308a28082f186cb8fa8c55d1cbceba608f770c298be1d8ee0ce", "from_cid": "dac5c970fb4c3f4583ba69b136c20decf1e1e6448561478338c0f66a3ec71ec4"}
