# %% [markdown]
# # RDF Triples: Albert Einstein
#
# ## Provenance
#
# ```yaml
# source_url: https://en.wikipedia.org/wiki/Albert_Einstein
# article_title: Albert Einstein
# license: CC BY-SA 4.0
# license_url: https://creativecommons.org/licenses/by-sa/4.0/
# source_notebook: facts.ipynb
# generated_by: wiki_to_kg_pipeline.ipynb
# generated_at: 2025-12-19T07:47:40.340827
# llm_provider: lm_studio
# llm_model: qwen/qwen3-coder-30b
# llm_temperature: 1
# rdf_format: Turtle
# ```
#
# ## RDF Prefixes
#
# ```turtle
# @prefix schema: <https://schema.org/> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix wiki3: <https://wiki3.ai/vocab/> .
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix repro: <https://w3id.org/reproduceme#> .
# @prefix pplan: <http://purl.org/net/p-plan#> .
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @base <https://en.wikipedia.org/wiki/Albert_Einstein> .
#
# ```
#
# ## Processing Instructions
#
# This notebook contains RDF triples in Turtle format, one cell per source statement.
# Each content cell is followed by a signature cell with CID provenance.
#
# To regenerate a specific cell: delete both the content cell and its signature, then re-run the pipeline.
#
# ## Prompt Template
#
# ```
# You are an expert at converting factual statements to RDF triples in Turtle format.
#
# Convert the following factual statements to RDF using schema.org vocabulary where possible.
#
# Source: {source_url}
# Section: {breadcrumb}
#
# Use these prefixes:
# {prefixes}
#
# Entity registry (use these URIs):
# {entity_registry}
#
# Guidelines:
# - Use schema.org properties (schema:birthDate, schema:birthPlace, schema:worksFor, etc.)
# - For relationships not in schema.org, use wiki3: prefix
# - Include rdfs:label for entities
# - Use xsd datatypes for dates and numbers
# - Entity URIs should use the source URL as base with fragment identifiers
#
# ---
# {facts}
# ---
#
# Generate Turtle RDF:
#
# ```

# %% [raw]
# {
#   "source_url": "https://en.wikipedia.org/wiki/Albert_Einstein",
#   "entities": {
#     "albert_einstein": {
#       "id": "person_albert_einstein",
#       "uri": "https://en.wikipedia.org/wiki/Albert_Einstein",
#       "label": "Albert Einstein",
#       "type": "Person",
#       "descriptions": [
#         "Subject of Wikipedia article: Albert Einstein"
#       ],
#       "source_chunks": [],
#       "aliases": [
#         "Einstein"
#       ],
#       "wikidata_id": "Q937"
#     },
#     "ulm": {
#       "id": "thing_ulm",
#       "uri": "https://en.wikipedia.org/wiki/Ulm",
#       "label": "Ulm",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Ulm"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "kingdom_of_w_rttemberg": {
#       "id": "thing_kingdom_of_w_rttemberg",
#       "uri": "https://en.wikipedia.org/wiki/Kingdom_of_W%C3%BCrttemberg",
#       "label": "Kingdom of W\u00fcrttemberg",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Kingdom of W\u00fcrttemberg"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "german_empire": {
#       "id": "thing_german_empire",
#       "uri": "https://en.wikipedia.org/wiki/German_Empire",
#       "label": "German Empire",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: German Empire"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "princeton_new_jersey": {
#       "id": "thing_princeton_new_jersey",
#       "uri": "https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey",
#       "label": "Princeton, New Jersey",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Princeton, New Jersey"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "lieserl": {
#       "id": "thing_lieserl",
#       "uri": "https://en.wikipedia.org/wiki/Lieserl_Einstein",
#       "label": "Lieserl",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Lieserl"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "hans_albert": {
#       "id": "thing_hans_albert",
#       "uri": "https://en.wikipedia.org/wiki/Hans_Albert_Einstein",
#       "label": "Hans Albert",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Hans Albert"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "eduard_tete": {
#       "id": "thing_eduard_tete",
#       "uri": "https://en.wikipedia.org/wiki/Einstein_family",
#       "label": "Eduard \"Tete\"",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Eduard \"Tete\""
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "einstein": {
#       "id": "thing_einstein",
#       "uri": "https://en.wikipedia.org/wiki/Einstein_family",
#       "label": "Einstein",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Einstein"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "mileva_mari": {
#       "id": "thing_mileva_mari",
#       "uri": "https://en.wikipedia.org/wiki/Mileva_Mari%C4%87",
#       "label": "Mileva Mari\u0107",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Mileva Mari\u0107"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "elsa_l_wenthal": {
#       "id": "thing_elsa_l_wenthal",
#       "uri": "https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal",
#       "label": "Elsa L\u00f6wenthal",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Elsa L\u00f6wenthal"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "stateless": {
#       "id": "thing_stateless",
#       "uri": "https://en.wikipedia.org/wiki/Statelessness",
#       "label": "Stateless",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Stateless"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "switzerland": {
#       "id": "thing_switzerland",
#       "uri": "https://en.wikipedia.org/wiki/Switzerland",
#       "label": "Switzerland",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Switzerland"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "kingdom_of_prussia": {
#       "id": "thing_kingdom_of_prussia",
#       "uri": "https://en.wikipedia.org/wiki/Kingdom_of_Prussia",
#       "label": "Kingdom of Prussia",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Kingdom of Prussia"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "free_state_of_prussia": {
#       "id": "thing_free_state_of_prussia",
#       "uri": "https://en.wikipedia.org/wiki/Free_State_of_Prussia",
#       "label": "Free State of Prussia",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Free State of Prussia"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "weimar_republic": {
#       "id": "thing_weimar_republic",
#       "uri": "https://en.wikipedia.org/wiki/Weimar_Republic",
#       "label": "Weimar Republic",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Weimar Republic"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "united_states": {
#       "id": "thing_united_states",
#       "uri": "https://en.wikipedia.org/wiki/Citizenship_of_the_United_States",
#       "label": "United States",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: United States"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "physics": {
#       "id": "thing_physics",
#       "uri": "https://en.wikipedia.org/wiki/Physics",
#       "label": "Physics",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Physics"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "university_of_bern": {
#       "id": "thing_university_of_bern",
#       "uri": "https://en.wikipedia.org/wiki/University_of_Bern",
#       "label": "University of Bern",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: University of Bern"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "university_of_zurich": {
#       "id": "thing_university_of_zurich",
#       "uri": "https://en.wikipedia.org/wiki/University_of_Zurich",
#       "label": "University of Zurich",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: University of Zurich"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "charles_university_in_prague": {
#       "id": "thing_charles_university_in_prague",
#       "uri": "https://en.wikipedia.org/wiki/Charles_University_in_Prague",
#       "label": "Charles University in Prague",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Charles University in Prague"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "eth_zurich": {
#       "id": "thing_eth_zurich",
#       "uri": "https://en.wikipedia.org/wiki/ETH_Zurich",
#       "label": "ETH Zurich",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: ETH Zurich"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "prussian_academy_of_sciences": {
#       "id": "thing_prussian_academy_of_sciences",
#       "uri": "https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences",
#       "label": "Prussian Academy of Sciences",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Prussian Academy of Sciences"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "humboldt_university_of_berlin": {
#       "id": "thing_humboldt_university_of_berlin",
#       "uri": "https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin",
#       "label": "Humboldt University of Berlin",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Humboldt University of Berlin"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "kaiser_wilhelm_institute": {
#       "id": "thing_kaiser_wilhelm_institute",
#       "uri": "https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute",
#       "label": "Kaiser Wilhelm Institute",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Kaiser Wilhelm Institute"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "german_physical_society": {
#       "id": "thing_german_physical_society",
#       "uri": "https://en.wikipedia.org/wiki/German_Physical_Society",
#       "label": "German Physical Society",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: German Physical Society"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "institute_for_advanced_study": {
#       "id": "thing_institute_for_advanced_study",
#       "uri": "https://en.wikipedia.org/wiki/Institute_for_Advanced_Study",
#       "label": "Institute for Advanced Study",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Institute for Advanced Study"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "swiss_federal_polytechnic_school": {
#       "id": "thing_swiss_federal_polytechnic_school",
#       "uri": "https://en.wikipedia.org/wiki/ETH_Zurich",
#       "label": "Swiss Federal Polytechnic School",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Swiss Federal Polytechnic School"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "phd": {
#       "id": "thing_phd",
#       "uri": "https://en.wikipedia.org/wiki/PhD",
#       "label": "PhD",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: PhD"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "alfred_kleiner": {
#       "id": "thing_alfred_kleiner",
#       "uri": "https://en.wikipedia.org/wiki/Alfred_Kleiner",
#       "label": "Alfred Kleiner",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Alfred Kleiner"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "heinrich_friedrich_weber": {
#       "id": "thing_heinrich_friedrich_weber",
#       "uri": "https://en.wikipedia.org/wiki/Heinrich_Friedrich_Weber",
#       "label": "Heinrich Friedrich Weber",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Heinrich Friedrich Weber"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "general_relativity": {
#       "id": "thing_general_relativity",
#       "uri": "https://en.wikipedia.org/wiki/General_relativity",
#       "label": "General relativity",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: General relativity"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "special_relativity": {
#       "id": "thing_special_relativity",
#       "uri": "https://en.wikipedia.org/wiki/Special_relativity",
#       "label": "Special relativity",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Special relativity"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "photoelectric_effect": {
#       "id": "thing_photoelectric_effect",
#       "uri": "https://en.wikipedia.org/wiki/Photoelectric_effect",
#       "label": "Photoelectric effect",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Photoelectric effect"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "e_mc_sup_2_sup_mass_energy_equivalence": {
#       "id": "thing_e_mc_sup_2_sup_mass_energy_equivalence",
#       "uri": "https://en.wikipedia.org/wiki/Mass%E2%80%93energy_equivalence",
#       "label": "''E''=''mc''<sup>2</sup> (mass\u2013energy equivalence)",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: ''E''=''mc''<sup>2</sup> (mass\u2013energy equivalence)"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "e_hf_planck_einstein_relation": {
#       "id": "thing_e_hf_planck_einstein_relation",
#       "uri": "https://en.wikipedia.org/wiki/Planck%E2%80%93Einstein_relation",
#       "label": "''E''=''hf'' (Planck\u2013Einstein relation)",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: ''E''=''hf'' (Planck\u2013Einstein relation)"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "theory_of_brownian_motion": {
#       "id": "thing_theory_of_brownian_motion",
#       "uri": "https://en.wikipedia.org/wiki/Brownian_motion",
#       "label": "Theory of Brownian motion",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Theory of Brownian motion"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "einstein_field_equations": {
#       "id": "thing_einstein_field_equations",
#       "uri": "https://en.wikipedia.org/wiki/Einstein_field_equations",
#       "label": "Einstein field equations",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Einstein field equations"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "bose_einstein_statistics": {
#       "id": "thing_bose_einstein_statistics",
#       "uri": "https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_statistics",
#       "label": "Bose\u2013Einstein statistics",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Bose\u2013Einstein statistics"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "bose_einstein_condensate": {
#       "id": "thing_bose_einstein_condensate",
#       "uri": "https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_condensate",
#       "label": "Bose\u2013Einstein condensate",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Bose\u2013Einstein condensate"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "gravitational_wave": {
#       "id": "thing_gravitational_wave",
#       "uri": "https://en.wikipedia.org/wiki/Gravitational_wave",
#       "label": "Gravitational wave",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Gravitational wave"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "cosmological_constant": {
#       "id": "thing_cosmological_constant",
#       "uri": "https://en.wikipedia.org/wiki/Cosmological_constant",
#       "label": "Cosmological constant",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Cosmological constant"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "unified_field_theory": {
#       "id": "thing_unified_field_theory",
#       "uri": "https://en.wikipedia.org/wiki/Unified_field_theory",
#       "label": "Unified field theory",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Unified field theory"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "epr_paradox": {
#       "id": "thing_epr_paradox",
#       "uri": "https://en.wikipedia.org/wiki/EPR_paradox",
#       "label": "EPR paradox",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: EPR paradox"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "ensemble_interpretation": {
#       "id": "thing_ensemble_interpretation",
#       "uri": "https://en.wikipedia.org/wiki/Ensemble_interpretation",
#       "label": "Ensemble interpretation",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Ensemble interpretation"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "list_of_other_concepts": {
#       "id": "thing_list_of_other_concepts",
#       "uri": "https://en.wikipedia.org/wiki/List_of_things_named_after_Albert_Einstein",
#       "label": "List of other concepts",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: List of other concepts"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "barnard_medal_for_meritorious_service_to_science": {
#       "id": "thing_barnard_medal_for_meritorious_service_to_science",
#       "uri": "https://en.wikipedia.org/wiki/Barnard_Medal_for_Meritorious_Service_to_Science",
#       "label": "Barnard Medal for Meritorious Service to Science",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Barnard Medal for Meritorious Service to Science"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "nobel_prize_in_physics": {
#       "id": "thing_nobel_prize_in_physics",
#       "uri": "https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics",
#       "label": "Nobel Prize in Physics",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Nobel Prize in Physics"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "matteucci_medal": {
#       "id": "thing_matteucci_medal",
#       "uri": "https://en.wikipedia.org/wiki/Matteucci_Medal",
#       "label": "Matteucci Medal",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Matteucci Medal"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "formemrs": {
#       "id": "thing_formemrs",
#       "uri": "https://en.wikipedia.org/wiki/List_of_fellows_of_the_Royal_Society_elected_in_1921",
#       "label": "ForMemRS",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: ForMemRS"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "copley_medal": {
#       "id": "thing_copley_medal",
#       "uri": "https://en.wikipedia.org/wiki/Copley_Medal",
#       "label": "Copley Medal",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Copley Medal"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     }
#   },
#   "aliases": {
#     "einstein": "albert_einstein"
#   }
# }

# %% [raw]
# # Statement [1.1]: [Albert Einstein](/wiki/Albert_Einstein) was born on 14 March 1879.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/birthDate "1879-03-14"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiblwlymbl6coy63hveizhqaq6emnjm4qufhkdodzvpuu6aypkrcru",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiblwlymbl6coy63hveizhqaq6emnjm4qufhkdodzvpuu6aypkrcru",
#   "prov:label": "rdf:1_1",
#   "_cell": 2,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiazipa5t2o64vc2ckcsdd4w6e777giy7qp2zobg6dkbeutvmevxaq"
#   },
#   "_stmt_key": "1_1",
#   "_chunk_num": 1,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [1.2]: [Albert Einstein](/wiki/Albert_Einstein) was born in [Ulm](/wiki/Ulm).
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/birthPlace https://en.wikipedia.org/wiki/Ulm .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidbrdk3u72t4yax475op7avnaniywp75cfhwi3eisekxxna5aul2u",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidbrdk3u72t4yax475op7avnaniywp75cfhwi3eisekxxna5aul2u",
#   "prov:label": "rdf:1_2",
#   "_cell": 4,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiau7no73cwq424hhiyt45jj5opq2sv7djwqiumy2t4qk6z53ev43a"
#   },
#   "_stmt_key": "1_2",
#   "_chunk_num": 1,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [1.3]: [Ulm](/wiki/Ulm) was part of the [Kingdom of Württemberg](/wiki/Kingdom_of_W%C3%BCrttemberg) in 1879.
# https://en.wikipedia.org/wiki/Ulm https://schema.org/containedInPlace https://en.wikipedia.org/wiki/Kingdom_of_Württemberg .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreif3obud2ypdkq6gngnvk5kt6blluqozeja43j5fx7pyeg53esh42e",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreif3obud2ypdkq6gngnvk5kt6blluqozeja43j5fx7pyeg53esh42e",
#   "prov:label": "rdf:1_3",
#   "_cell": 6,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieuqw7ig4lrd4a2gwprtoxpdg42hkthjfl2yzd5sxemqhac7vwtky"
#   },
#   "_stmt_key": "1_3",
#   "_chunk_num": 1,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [1.4]: [Kingdom of Württemberg](/wiki/Kingdom_of_W%C3%BCrttemberg) was part of the [German Empire](/wiki/German_Empire) in 1879.
# https://en.wikipedia.org/wiki/Kingdom_of_Württemberg https://schema.org/containedInPlace https://en.wikipedia.org/wiki/German_Empire .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifdmec2sdgozqiyalu63szrvz3v4heryuxnbei6ugt6y54sw4hiya",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifdmec2sdgozqiyalu63szrvz3v4heryuxnbei6ugt6y54sw4hiya",
#   "prov:label": "rdf:1_4",
#   "_cell": 8,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiexjczrokij73nscv3l7ql4pvdajad7j7tiihajfkoncdtfvhdz7m"
#   },
#   "_stmt_key": "1_4",
#   "_chunk_num": 1,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [1.5]: [Albert Einstein](/wiki/Albert_Einstein) died on 18 April 1955.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic2aivijdbuyuuqf3bdrfilgjo57whocetpx57qqg673v4d5swvha",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic2aivijdbuyuuqf3bdrfilgjo57whocetpx57qqg673v4d5swvha",
#   "prov:label": "rdf:1_5",
#   "_cell": 10,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidvirzqgvtd4hdgwas4svphoo5x2sjxtb2fx3alguyqqeu5cixh74"
#   },
#   "_stmt_key": "1_5",
#   "_chunk_num": 1,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [1.6]: [Albert Einstein](/wiki/Albert_Einstein) died in [Princeton, New Jersey](/wiki/Princeton%2C_New_Jersey).
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/deathPlace https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifsj7mx3olhv4he6ti2sq62il6btduu7ocinjfxjpkpdl6dcodzcy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifsj7mx3olhv4he6ti2sq62il6btduu7ocinjfxjpkpdl6dcodzcy",
#   "prov:label": "rdf:1_6",
#   "_cell": 12,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidk667javbq3mkzsfuzstlsvi2cfatpvw54qn2yluoqqn4onnr4oy"
#   },
#   "_stmt_key": "1_6",
#   "_chunk_num": 1,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [1.7]: [Princeton, New Jersey](/wiki/Princeton%2C_New_Jersey) is located in the U.S.
# https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey https://schema.org/containedInPlace https://en.wikipedia.org/wiki/United_States .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieffoyklzfokldx6al3x5q7kcx7dpafoklr6ss4mvjq2fgzof4gya",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieffoyklzfokldx6al3x5q7kcx7dpafoklr6ss4mvjq2fgzof4gya",
#   "prov:label": "rdf:1_7",
#   "_cell": 14,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifly53udoithlcme3onyu7o6sjpyiw6x5miegdevjzfplfakhidg4"
#   },
#   "_stmt_key": "1_7",
#   "_chunk_num": 1,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [1.8]: [Albert Einstein](/wiki/Albert_Einstein) had children named [Lieserl](/wiki/Lieserl_Einstein), [Hans Albert](/wiki/Hans_Albert_Einstein), and [Eduard "Tete"](/wiki/Einstein_family).
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/children https://en.wikipedia.org/wiki/Lieserl_Einstein .
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/children https://en.wikipedia.org/wiki/Hans_Albert_Einstein .
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/children https://en.wikipedia.org/wiki/Einstein_family .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibv673thviyi6nms7ghleugbee42aithlo7zs5r7xrywpvglpo5tu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibv673thviyi6nms7ghleugbee42aithlo7zs5r7xrywpvglpo5tu",
#   "prov:label": "rdf:1_8",
#   "_cell": 16,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib6awwfpi4dummayaaoeybviodmjffq6rtels2hgjxyv6m6xa54mq"
#   },
#   "_stmt_key": "1_8",
#   "_chunk_num": 1,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [1.9]: [Albert Einstein](/wiki/Albert_Einstein) was a member of the [Einstein](/wiki/Einstein_family) family.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/familyName "Einstein" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieoswyyde6nmyoaadlskuilqfr2shnwtlnlotomgwibetfcupt6zy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieoswyyde6nmyoaadlskuilqfr2shnwtlnlotomgwibetfcupt6zy",
#   "prov:label": "rdf:1_9",
#   "_cell": 18,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihxembw7hqhg7cnns4zf3beh2ei2xahagqfxbz2vwyvn5vzv6mjae"
#   },
#   "_stmt_key": "1_9",
#   "_chunk_num": 1,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [1.10]: [Albert Einstein](/wiki/Albert_Einstein) held citizenship in the [Kingdom of Württemberg](/wiki/Kingdom_of_W%C3%BCrttemberg) until 1896.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/nationality https://en.wikipedia.org/wiki/Kingdom_of_Württemberg .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic25wqjrjxppue6f6tgmw5vauua6dghbuzgdjc7j7pliip2hyhquq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic25wqjrjxppue6f6tgmw5vauua6dghbuzgdjc7j7pliip2hyhquq",
#   "prov:label": "rdf:1_10",
#   "_cell": 20,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifuz6yqh35prrdikwq4uf7s27s3xbsuy26tiasltslxxnz6hj2kom"
#   },
#   "_stmt_key": "1_10",
#   "_chunk_num": 1,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [1.11]: [Albert Einstein](/wiki/Albert_Einstein) was stateless from 1896 to 1901.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/nationality https://en.wikipedia.org/wiki/Statelessness .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifh3pwbzadcnhue5ubvmmfrvmlcklge5b7zmlgv7tokqkd37253hy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifh3pwbzadcnhue5ubvmmfrvmlcklge5b7zmlgv7tokqkd37253hy",
#   "prov:label": "rdf:1_11",
#   "_cell": 22,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiciy7ragz5ltuoxscmmtkqeeza2g252h53i5kamsm74kxli2s6bqm"
#   },
#   "_stmt_key": "1_11",
#   "_chunk_num": 1,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [1.12]: [Albert Einstein](/wiki/Albert_Einstein) held citizenship in [Switzerland](/wiki/Switzerland) from 1901 to 1955.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/nationality https://en.wikipedia.org/wiki/Switzerland .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihqc3mv5olzrcx3cexltngkk5qhbmfqcjkoicniphqkrsrbbspgy4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihqc3mv5olzrcx3cexltngkk5qhbmfqcjkoicniphqkrsrbbspgy4",
#   "prov:label": "rdf:1_12",
#   "_cell": 24,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib2nmb3gssp2pivcgvfbaufezr2cn5hbs5lq35alutemaj3qcykjm"
#   },
#   "_stmt_key": "1_12",
#   "_chunk_num": 1,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [1.13]: [Albert Einstein](/wiki/Albert_Einstein) held citizenship in the [Kingdom of Prussia](/wiki/Kingdom_of_Prussia) from 1914 to 1918.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/nationality https://en.wikipedia.org/wiki/Kingdom_of_Prussia .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreih2lcxhydsgrug2nxmsofh3bxpd3r4tewqfujv5vz6wunxjhjohpa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreih2lcxhydsgrug2nxmsofh3bxpd3r4tewqfujv5vz6wunxjhjohpa",
#   "prov:label": "rdf:1_13",
#   "_cell": 26,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreienrdehun4qxy3f44kbwnf3zftfnft4r3j4wd5bhexlkgtfc74iny"
#   },
#   "_stmt_key": "1_13",
#   "_chunk_num": 1,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [1.14]: [Albert Einstein](/wiki/Albert_Einstein) held citizenship in the [Free State of Prussia](/wiki/Free_State_of_Prussia) during the [Weimar Republic](/wiki/Weimar_Republic) from 1918 to 1933.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/nationality https://en.wikipedia.org/wiki/Free_State_of_Prussia .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiduzv5g5i4g4d4eupn66grw7s5trknoi37ayjbsn5wwvjrnleeclq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiduzv5g5i4g4d4eupn66grw7s5trknoi37ayjbsn5wwvjrnleeclq",
#   "prov:label": "rdf:1_14",
#   "_cell": 28,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigdp2tugtvhdc43xiejvilkdnsju5oremx4lfokugcnssirxsuene"
#   },
#   "_stmt_key": "1_14",
#   "_chunk_num": 1,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [1.15]: [Albert Einstein](/wiki/Albert_Einstein) held citizenship in the [United States](/wiki/Citizenship_of_the_United_States) from 1940 to 1955.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/nationality https://en.wikipedia.org/wiki/Citizenship_of_the_United_States .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiexictu2m4bqw6nho5f4dwo54iuvvds2dttajn3pf4htiiihjiyz4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiexictu2m4bqw6nho5f4dwo54iuvvds2dttajn3pf4htiiihjiyz4",
#   "prov:label": "rdf:1_15",
#   "_cell": 30,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreic23253sveexcmmjogwfix3v4g5m5ojqxngls4pqa6x66oumrg2xy"
#   },
#   "_stmt_key": "1_15",
#   "_chunk_num": 1,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [1.16]: [Albert Einstein](/wiki/Albert_Einstein) worked at the [University of Bern](/wiki/University_of_Bern) from 1908 to 1909.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/worksFor https://en.wikipedia.org/wiki/University_of_Bern .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreib7fimarwnefp6ucx7a3wwhj42ga5egjbb3t57vs5s6w4eb2wswc4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreib7fimarwnefp6ucx7a3wwhj42ga5egjbb3t57vs5s6w4eb2wswc4",
#   "prov:label": "rdf:1_16",
#   "_cell": 32,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreievsu6eosthqzmazj4sfknkarbsvijrqgzdanpsx3lkarrr242ewe"
#   },
#   "_stmt_key": "1_16",
#   "_chunk_num": 1,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [1.17]: [Albert Einstein](/wiki/Albert_Einstein) worked at the [University of Zurich](/wiki/University_of_Zurich) from 1909 to 1911.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/worksFor https://en.wikipedia.org/wiki/University_of_Zurich .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiabjmjtdg7pm3ctcjp4yvsiu3v4dyr5slqrlzqjouk4kdkp4k25ga",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiabjmjtdg7pm3ctcjp4yvsiu3v4dyr5slqrlzqjouk4kdkp4k25ga",
#   "prov:label": "rdf:1_17",
#   "_cell": 34,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibd6sh22uermut67lsw6s6jadpbxqiexjzydw5epocy7bmubz5wvm"
#   },
#   "_stmt_key": "1_17",
#   "_chunk_num": 1,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [1.18]: [Albert Einstein](/wiki/Albert_Einstein) worked at the [Charles University in Prague](/wiki/Charles_University_in_Prague) from 1911 to 1912.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/worksFor https://en.wikipedia.org/wiki/Charles_University_in_Prague .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreichf52ht5tgw2ihzbz5ppldoiwzsrdchkqxxha3p4o3vkxn22bwwq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreichf52ht5tgw2ihzbz5ppldoiwzsrdchkqxxha3p4o3vkxn22bwwq",
#   "prov:label": "rdf:1_18",
#   "_cell": 36,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaugnblj22tuzxd6s3eovwvmfmpbnjmjtzls6gv6dfrysjjvhrybi"
#   },
#   "_stmt_key": "1_18",
#   "_chunk_num": 1,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [1.19]: [Albert Einstein](/wiki/Albert_Einstein) worked at the [ETH Zurich](/wiki/ETH_Zurich) from 1912 to 1914.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/worksFor https://en.wikipedia.org/wiki/ETH_Zurich .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic42bdocmskh6xoljwdglsi5b64v4tnbo454vw4rro7akksmqd23y",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic42bdocmskh6xoljwdglsi5b64v4tnbo454vw4rro7akksmqd23y",
#   "prov:label": "rdf:1_19",
#   "_cell": 38,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreie7ijfd6tvojhdhwrbmtg2rkomifdmggoopwdtzkv3mfl6rx2cxsy"
#   },
#   "_stmt_key": "1_19",
#   "_chunk_num": 1,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Statement [1.20]: [Albert Einstein](/wiki/Albert_Einstein) worked at the [Prussian Academy of Sciences](/wiki/Prussian_Academy_of_Sciences) from 1914 to 1933.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/worksFor https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibbznmt7bnf4d3u3gx4vxqpfb6lv6zb3wxxjoaj2qmi62gd5vumfu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibbznmt7bnf4d3u3gx4vxqpfb6lv6zb3wxxjoaj2qmi62gd5vumfu",
#   "prov:label": "rdf:1_20",
#   "_cell": 40,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieuzhirqwnwqt6uxodkadpb4ui6ppxqxpuil45kvjgce2htor2x2m"
#   },
#   "_stmt_key": "1_20",
#   "_chunk_num": 1,
#   "_stmt_idx": 20
# }

# %% [raw]
# # Statement [1.21]: [Albert Einstein](/wiki/Albert_Einstein) worked at the [Humboldt University of Berlin](/wiki/Humboldt_University_of_Berlin) from 1914 to 1933.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/worksFor https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieokloy3haaept5pzbwxfhdqvimbihihrhhaw3lvqrvjugnjkhxgy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieokloy3haaept5pzbwxfhdqvimbihihrhhaw3lvqrvjugnjkhxgy",
#   "prov:label": "rdf:1_21",
#   "_cell": 42,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid5ueqjvtimgxqwov25wtne4mpl7gxqtv723drcsa4k2mvpizuj3m"
#   },
#   "_stmt_key": "1_21",
#   "_chunk_num": 1,
#   "_stmt_idx": 21
# }

# %% [raw]
# # Statement [1.22]: [Albert Einstein](/wiki/Albert_Einstein) was director of the [Kaiser Wilhelm Institute](/wiki/Kaiser_Wilhelm_Institute) from 1917 to 1933.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/worksFor https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicab33ymbl2urdtnfhfcfto7567kbb6dmuhq6wnmmzqyr5esq55di",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicab33ymbl2urdtnfhfcfto7567kbb6dmuhq6wnmmzqyr5esq55di",
#   "prov:label": "rdf:1_22",
#   "_cell": 44,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia3bor2octlztb4os2ufesjewu64v65wpn5vsyeiiocsxuigwjdba"
#   },
#   "_stmt_key": "1_22",
#   "_chunk_num": 1,
#   "_stmt_idx": 22
# }

# %% [raw]
# # Statement [1.23]: [Albert Einstein](/wiki/Albert_Einstein) was president of the [German Physical Society](/wiki/German_Physical_Society) from 1916 to 1918.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/worksFor https://en.wikipedia.org/wiki/German_Physical_Society .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigim4xf53jlnolxbfxko7qmre3cxi5skhkjt47cgbjekqajo5awtu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigim4xf53jlnolxbfxko7qmre3cxi5skhkjt47cgbjekqajo5awtu",
#   "prov:label": "rdf:1_23",
#   "_cell": 46,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreics635ncl6bxd3zn6ijx3r2efwdj7zh5wxwc4hdvddurn4cnbr3aa"
#   },
#   "_stmt_key": "1_23",
#   "_chunk_num": 1,
#   "_stmt_idx": 23
# }

# %% [raw]
# # Statement [1.24]: [Albert Einstein](/wiki/Albert_Einstein) worked at the [Institute for Advanced Study](/wiki/Institute_for_Advanced_Study) from 1933 to 1955.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/worksFor https://en.wikipedia.org/wiki/Institute_for_Advanced_Study .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigr7olp6hqbgeeeheaqkuo6bwv2hmsyl5nybfyia4tgeoec6uoq6i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigr7olp6hqbgeeeheaqkuo6bwv2hmsyl5nybfyia4tgeoec6uoq6i",
#   "prov:label": "rdf:1_24",
#   "_cell": 48,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiezpofe4w54wfzsee2nzz6fjqlxej4bca5d7rqrftoqryv46j6e5e"
#   },
#   "_stmt_key": "1_24",
#   "_chunk_num": 1,
#   "_stmt_idx": 24
# }

# %% [raw]
# # Statement [1.25]: [Albert Einstein](/wiki/Albert_Einstein) studied at the [Swiss Federal Polytechnic School](/wiki/ETH_Zurich) and earned a teaching diploma in 1900.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/alumniOf https://en.wikipedia.org/wiki/ETH_Zurich .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiavccrpnij5c7eraxwtwfiiuj5fvdutbk3zr7pwi5qsxre5irnnea",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiavccrpnij5c7eraxwtwfiiuj5fvdutbk3zr7pwi5qsxre5irnnea",
#   "prov:label": "rdf:1_25",
#   "_cell": 50,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifgcbw7ymol2rue7b7k5imtvwd7agvj74k5tws265ovutkcuflsfq"
#   },
#   "_stmt_key": "1_25",
#   "_chunk_num": 1,
#   "_stmt_idx": 25
# }

# %% [raw]
# # Statement [1.26]: [Albert Einstein](/wiki/Albert_Einstein) studied at the [University of Zurich](/wiki/University_of_Zurich) and earned a [PhD](/wiki/PhD) in 1905.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/alumniOf https://en.wikipedia.org/wiki/University_of_Zurich .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiafsjnozrppotfm6ezj35gicy2imbs4bgtnyfgsrp2cnqsdrfpfzi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiafsjnozrppotfm6ezj35gicy2imbs4bgtnyfgsrp2cnqsdrfpfzi",
#   "prov:label": "rdf:1_26",
#   "_cell": 52,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidailn7tv6jmp6m2ttwats7s3xifftca4oix7gjnh3ilki67paixe"
#   },
#   "_stmt_key": "1_26",
#   "_chunk_num": 1,
#   "_stmt_idx": 26
# }

# %% [raw]
# # Statement [1.27]: [Albert Einstein](/wiki/Albert_Einstein)'s doctoral advisor was [Alfred Kleiner](/wiki/Alfred_Kleiner).
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/colleague https://en.wikipedia.org/wiki/Alfred_Kleiner .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaqyccsb3ndf5uptzyfpcv2jjemrhsh7nrmc2dmexydi25f2lzgua",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaqyccsb3ndf5uptzyfpcv2jjemrhsh7nrmc2dmexydi25f2lzgua",
#   "prov:label": "rdf:1_27",
#   "_cell": 54,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihpnwx2bbsrqmqnk3snspvjaylxtv7coq3kysdvns5jh3z32h4qgq"
#   },
#   "_stmt_key": "1_27",
#   "_chunk_num": 1,
#   "_stmt_idx": 27
# }

# %% [raw]
# # Statement [1.28]: [Albert Einstein](/wiki/Albert_Einstein) was a physicist.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/hasOccupation https://schema.org/Researcher .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaocjwwqau6gzzxmbchasjt2cdzn3qma5cprifagb2mei7ilhuep4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaocjwwqau6gzzxmbchasjt2cdzn3qma5cprifagb2mei7ilhuep4",
#   "prov:label": "rdf:1_28",
#   "_cell": 56,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigzlqmngwxellt5ygi2oseo74oyukj7hqpldshkx63dc2rpdlflu4"
#   },
#   "_stmt_key": "1_28",
#   "_chunk_num": 1,
#   "_stmt_idx": 28
# }

# %% [raw]
# # Statement [1.29]: [Albert Einstein](/wiki/Albert_Einstein) made significant contributions to the field of [Physics](/wiki/Physics).
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/knowsAbout https://en.wikipedia.org/wiki/Physics .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigpr5fdbwwdltpijshr4pe2jweiwwk2lqrsnrrlwa3347uf2vxh5m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigpr5fdbwwdltpijshr4pe2jweiwwk2lqrsnrrlwa3347uf2vxh5m",
#   "prov:label": "rdf:1_29",
#   "_cell": 58,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreig2zz723uk7qnpfsinin37rzhz4jr5utv4jeyfm6flptg3247nnce"
#   },
#   "_stmt_key": "1_29",
#   "_chunk_num": 1,
#   "_stmt_idx": 29
# }

# %% [raw]
# # Statement [2.1]: [Albert Einstein](/wiki/Albert_Einstein) was advised by [Alfred Kleiner](/wiki/Alfred_Kleiner) for his doctoral studies.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:advisor https://en.wikipedia.org/wiki/Alfred_Kleiner .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiedw5nqpxmldqlhbdiqjn5hok7g3rczrxmaz7u47pwrvp2xysukre",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiedw5nqpxmldqlhbdiqjn5hok7g3rczrxmaz7u47pwrvp2xysukre",
#   "prov:label": "rdf:2_1",
#   "_cell": 60,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihrvmlnmrrytxy5rouf2httae6uczl3f3olkhxniz2olv5sfas4ee"
#   },
#   "_stmt_key": "2_1",
#   "_chunk_num": 2,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [2.2]: [Albert Einstein](/wiki/Albert_Einstein) was advised by [Heinrich Friedrich Weber](/wiki/Heinrich_Friedrich_Weber) for his doctoral studies.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:advisor https://en.wikipedia.org/wiki/Heinrich_Friedrich_Weber .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihac5d5tkpjzlnpck57d4fs2m6lzxhboeqq23tlltnt7t7jqcnydm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihac5d5tkpjzlnpck57d4fs2m6lzxhboeqq23tlltnt7t7jqcnydm",
#   "prov:label": "rdf:2_2",
#   "_cell": 62,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifuylff6dqmgx4in6ms7r2jkqs6c2ytr7hixipzciirym3dihllla"
#   },
#   "_stmt_key": "2_2",
#   "_chunk_num": 2,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [2.3]: [Albert Einstein](/wiki/Albert_Einstein) wrote the thesis titled "Eine neue Bestimmung der Moleküldimensionen" in 1905.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:hasCredential https://en.wikipedia.org/wiki/PhD .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:thesis "Eine neue Bestimmung der Moleküldimensionen" .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:publicationDate "1905"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreif4voipbkcsdq7ykuvf7hsgftxcfr7zaiopifvpqmrndxaetyljyy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreif4voipbkcsdq7ykuvf7hsgftxcfr7zaiopifvpqmrndxaetyljyy",
#   "prov:label": "rdf:2_3",
#   "_cell": 64,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib4zaan56wm7eprs4p4jes4vdcrtz7qgprayq4l6tjyq56bszleai"
#   },
#   "_stmt_key": "2_3",
#   "_chunk_num": 2,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [2.4]: [Albert Einstein](/wiki/Albert_Einstein) is known for [General relativity](/wiki/General_relativity).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:knowsAbout https://en.wikipedia.org/wiki/General_relativity .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihgdpiwvfp5e7o7peib3srixtdrp4e4ehatwa4g3flumodjjhdxba",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihgdpiwvfp5e7o7peib3srixtdrp4e4ehatwa4g3flumodjjhdxba",
#   "prov:label": "rdf:2_4",
#   "_cell": 66,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicu3uak66xavhj7ne76tu2prpniqxpv73nmob7xxobqkvjftkwkgi"
#   },
#   "_stmt_key": "2_4",
#   "_chunk_num": 2,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [2.5]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Special relativity](/wiki/Special_relativity).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:knowsAbout https://en.wikipedia.org/wiki/Special_relativity .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihrs7ieekhqdiydlrslt6j6azqbjzjozcugmnqkuwrezwiy6iegfy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihrs7ieekhqdiydlrslt6j6azqbjzjozcugmnqkuwrezwiy6iegfy",
#   "prov:label": "rdf:2_5",
#   "_cell": 68,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiagxfrb22mjhekk6pyjkg4n4rqkw6nrc46ccf72puoooadjp3skre"
#   },
#   "_stmt_key": "2_5",
#   "_chunk_num": 2,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [2.6]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Photoelectric effect](/wiki/Photoelectric_effect).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:knowsAbout https://en.wikipedia.org/wiki/Photoelectric_effect .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifz6iogr37nbijh4tkr5oc3vm5ad6jpkvityhrvv5htnm64eqqefq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifz6iogr37nbijh4tkr5oc3vm5ad6jpkvityhrvv5htnm64eqqefq",
#   "prov:label": "rdf:2_6",
#   "_cell": 70,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifaxsyobkrqvmesrh2rtvc2ynjkdtdecuq5w742unnwyydvtcbudu"
#   },
#   "_stmt_key": "2_6",
#   "_chunk_num": 2,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [2.7]: [Albert Einstein](/wiki/Albert_Einstein) is known for [''E''=''mc''<sup>2</sup> (mass–energy equivalence)](/wiki/Mass%E2%80%93energy_equivalence).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:knowsAbout https://en.wikipedia.org/wiki/Mass%E2%80%93energy_equivalence .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibrgxl7jj6ylvexp5j7cnvoil72a2ndvv23rc3t5px22vc7nrzmk4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibrgxl7jj6ylvexp5j7cnvoil72a2ndvv23rc3t5px22vc7nrzmk4",
#   "prov:label": "rdf:2_7",
#   "_cell": 72,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicuagvycaq6pwvw6tilzqlemxepyqi2visziaoxx2pid6jbwpvx3a"
#   },
#   "_stmt_key": "2_7",
#   "_chunk_num": 2,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [2.8]: [Albert Einstein](/wiki/Albert_Einstein) is known for [''E''=''hf'' (Planck–Einstein relation)](/wiki/Planck%E2%80%93Einstein_relation).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:knowsAbout https://en.wikipedia.org/wiki/Planck%E2%80%93Einstein_relation .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiea2psb3od2o35c6r5aoxvdqpegnsb4ovvzh33bm2a2noscimqal4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiea2psb3od2o35c6r5aoxvdqpegnsb4ovvzh33bm2a2noscimqal4",
#   "prov:label": "rdf:2_8",
#   "_cell": 74,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiflyw2xzfu5mtm2kannkgqzwzzambi5nzv7pvt2gvx5a4oitngmn4"
#   },
#   "_stmt_key": "2_8",
#   "_chunk_num": 2,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [2.9]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Theory of Brownian motion](/wiki/Brownian_motion).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:knowsAbout https://en.wikipedia.org/wiki/Brownian_motion .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicverca654lyg4wumb7kfu2if6mk55efa7xfme6hzzq2wmpvsj5z4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicverca654lyg4wumb7kfu2if6mk55efa7xfme6hzzq2wmpvsj5z4",
#   "prov:label": "rdf:2_9",
#   "_cell": 76,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigcppcp6zphwdqruwi2nhleq4jp67bluezfla7jz7uls7mi3iij7q"
#   },
#   "_stmt_key": "2_9",
#   "_chunk_num": 2,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [2.10]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Einstein field equations](/wiki/Einstein_field_equations).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:knowsAbout https://en.wikipedia.org/wiki/Einstein_field_equations .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiczhrwkfrsvsn3ywkbsgebtoyt6sh3ujas3ztnvoqq54qcys2j55u",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiczhrwkfrsvsn3ywkbsgebtoyt6sh3ujas3ztnvoqq54qcys2j55u",
#   "prov:label": "rdf:2_10",
#   "_cell": 78,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifehzyxbzedtcfsyr676smhvjrymohsdvze3vcmntsjap6nc3sspa"
#   },
#   "_stmt_key": "2_10",
#   "_chunk_num": 2,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [2.11]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Bose–Einstein statistics](/wiki/Bose%E2%80%93Einstein_statistics).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:knowsAbout https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_statistics .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiajjljixjgaqwhwyr473cqvmcvqu4hupxdwcn7tpcmmp5nnfvv7ba",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiajjljixjgaqwhwyr473cqvmcvqu4hupxdwcn7tpcmmp5nnfvv7ba",
#   "prov:label": "rdf:2_11",
#   "_cell": 80,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaj5u7xholi3snu3cmehhfpj3h7uzdluba3npjpuy2f4hr7glaejm"
#   },
#   "_stmt_key": "2_11",
#   "_chunk_num": 2,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [2.12]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Bose–Einstein condensate](/wiki/Bose%E2%80%93Einstein_condensate).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:knowsAbout https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_condensate .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidu6ieo7aum7ihimuxnr424j7d32cqticnjh2qtniutf4zjerfauu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidu6ieo7aum7ihimuxnr424j7d32cqticnjh2qtniutf4zjerfauu",
#   "prov:label": "rdf:2_12",
#   "_cell": 82,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreielxmnpz766h4zqpovoax3cvnbxybajthd6gk3cn5cfaomlbrdqnq"
#   },
#   "_stmt_key": "2_12",
#   "_chunk_num": 2,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [2.13]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Gravitational wave](/wiki/Gravitational_wave).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:knowsAbout https://en.wikipedia.org/wiki/Gravitational_wave .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidcyc6vgvr33klbv2ggipujree5ogdq4rlmk45h52ncvez4bxwaa4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidcyc6vgvr33klbv2ggipujree5ogdq4rlmk45h52ncvez4bxwaa4",
#   "prov:label": "rdf:2_13",
#   "_cell": 84,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiatvzjbjzxzbtc2e7hg3gw752lexqmq2bnhebt4b2acu7eniv7k3i"
#   },
#   "_stmt_key": "2_13",
#   "_chunk_num": 2,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [2.14]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Cosmological constant](/wiki/Cosmological_constant).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:knowsAbout https://en.wikipedia.org/wiki/Cosmological_constant .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaa7hwjubgrqvkw5bau6djdy2bzuygwz7uiidbne6epz2infgntpu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaa7hwjubgrqvkw5bau6djdy2bzuygwz7uiidbne6epz2infgntpu",
#   "prov:label": "rdf:2_14",
#   "_cell": 86,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiezea3u4gvpuq7sys3cyhyfce6wpgrcn7scjxezhiwxt3s2ba6b2a"
#   },
#   "_stmt_key": "2_14",
#   "_chunk_num": 2,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [2.15]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Unified field theory](/wiki/Unified_field_theory).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:knowsAbout https://en.wikipedia.org/wiki/Unified_field_theory .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia7myk3dsmj2x2b4gkghlwxbitflhjafuofb7ill7zmhe4mha2b5m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia7myk3dsmj2x2b4gkghlwxbitflhjafuofb7ill7zmhe4mha2b5m",
#   "prov:label": "rdf:2_15",
#   "_cell": 88,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiewdffpjayuf5brypv5hwzf6f3tzg32sn3gvw3pg2kul4gt7v5vxu"
#   },
#   "_stmt_key": "2_15",
#   "_chunk_num": 2,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [2.16]: [Albert Einstein](/wiki/Albert_Einstein) is known for [EPR paradox](/wiki/EPR_paradox).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:knowsAbout https://en.wikipedia.org/wiki/EPR_paradox .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiagk7663czuayalskjxd2nfk6u6bjzy3znxh4bjql47pkjrbslmkm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiagk7663czuayalskjxd2nfk6u6bjzy3znxh4bjql47pkjrbslmkm",
#   "prov:label": "rdf:2_16",
#   "_cell": 90,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid6zg4j57b74owvy5phc3muafiv7qyqpovwdegyd5apabj2p7nqyq"
#   },
#   "_stmt_key": "2_16",
#   "_chunk_num": 2,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [2.17]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Ensemble interpretation](/wiki/Ensemble_interpretation).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:knowsAbout https://en.wikipedia.org/wiki/Ensemble_interpretation .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreietxya526xe7nbdwrgvq26r6oqfuuwb5ajr2zbmdhmszv2vrmdhxm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreietxya526xe7nbdwrgvq26r6oqfuuwb5ajr2zbmdhmszv2vrmdhxm",
#   "prov:label": "rdf:2_17",
#   "_cell": 92,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiev3ati7afcekanyr3mnmj2hrgtv4oj65ldi6mi4upv6ljkncq2am"
#   },
#   "_stmt_key": "2_17",
#   "_chunk_num": 2,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [2.18]: [Albert Einstein](/wiki/Albert_Einstein) is known for [List of other concepts](/wiki/List_of_things_named_after_Albert_Einstein).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:knowsAbout https://en.wikipedia.org/wiki/List_of_things_named_after_Albert_Einstein .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaq2nwt44an5ydnmr3riqw4rsd4zf63vpmjrmrfn6qxqh7ihbnp6i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaq2nwt44an5ydnmr3riqw4rsd4zf63vpmjrmrfn6qxqh7ihbnp6i",
#   "prov:label": "rdf:2_18",
#   "_cell": 94,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieoe2ctrubpli6cohaofoqihkujopnlee6w6sk5g2hgafelhfmkwi"
#   },
#   "_stmt_key": "2_18",
#   "_chunk_num": 2,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [2.19]: [Albert Einstein](/wiki/Albert_Einstein) received the [Barnard Medal for Meritorious Service to Science](/wiki/Barnard_Medal_for_Meritorious_Service_to_Science) in 1920.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:award https://en.wikipedia.org/wiki/Barnard_Medal_for_Meritorious_Service_to_Science .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:awardDate "1920"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidnmdyijxy6s3nshribcuglpoflq2hgatcczgly6wtrliz5rrhrie",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidnmdyijxy6s3nshribcuglpoflq2hgatcczgly6wtrliz5rrhrie",
#   "prov:label": "rdf:2_19",
#   "_cell": 96,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicgs3ugk6qnqjzrdto7glvclv5ker2r6xjbq3nm25qcgm7p6ds7qy"
#   },
#   "_stmt_key": "2_19",
#   "_chunk_num": 2,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Statement [2.20]: [Albert Einstein](/wiki/Albert_Einstein) received the [Nobel Prize in Physics](/wiki/Nobel_Prize_in_Physics) in 1921.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:award https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:awardDate "1921"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibypr25ivocgbhvvvo7vanoorueecrfhszenho2chqs3u44iyknm4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibypr25ivocgbhvvvo7vanoorueecrfhszenho2chqs3u44iyknm4",
#   "prov:label": "rdf:2_20",
#   "_cell": 98,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicafafidol4ikdvckqeads22s57rmdwibxyphori7zonbnjfr2wlq"
#   },
#   "_stmt_key": "2_20",
#   "_chunk_num": 2,
#   "_stmt_idx": 20
# }

# %% [raw]
# # Statement [2.21]: [Albert Einstein](/wiki/Albert_Einstein) received the [Matteucci Medal](/wiki/Matteucci_Medal) in 1921.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:award https://en.wikipedia.org/wiki/Matteucci_Medal .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:awardDate "1921"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigo62ytmcblevixbpultnlybkactfrwn5jytyhsmfiiba6lsrg4ca",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigo62ytmcblevixbpultnlybkactfrwn5jytyhsmfiiba6lsrg4ca",
#   "prov:label": "rdf:2_21",
#   "_cell": 100,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreic565x3sexx57x33sxa4cfjmmwowhpccap5sb6agavcnxvw7hyexm"
#   },
#   "_stmt_key": "2_21",
#   "_chunk_num": 2,
#   "_stmt_idx": 21
# }

# %% [raw]
# # Statement [2.22]: [Albert Einstein](/wiki/Albert_Einstein) received the [ForMemRS](/wiki/List_of_fellows_of_the_Royal_Society_elected_in_1921) in 1921.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:award https://en.wikipedia.org/wiki/List_of_fellows_of_the_Royal_Society_elected_in_1921 .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:awardDate "1921"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihgabcr42z4ng4nwqzm5bwve2vdpe63lpi4z2bupsvjbyjqdzxgia",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihgabcr42z4ng4nwqzm5bwve2vdpe63lpi4z2bupsvjbyjqdzxgia",
#   "prov:label": "rdf:2_22",
#   "_cell": 102,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaikeltogu4ptrnaphyg6pd24vlast476iit4kdktprph5nyxkvby"
#   },
#   "_stmt_key": "2_22",
#   "_chunk_num": 2,
#   "_stmt_idx": 22
# }

# %% [raw]
# # Statement [2.23]: [Albert Einstein](/wiki/Albert_Einstein) received the [Copley Medal](/wiki/Copley_Medal) in 1925.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:award https://en.wikipedia.org/wiki/Copley_Medal .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:awardDate "1925"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiewjvwstf3dri34l5olhrzabqgavrqfh5blbkcsbqsytvvvfi6gfe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiewjvwstf3dri34l5olhrzabqgavrqfh5blbkcsbqsytvvvfi6gfe",
#   "prov:label": "rdf:2_23",
#   "_cell": 104,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibi344loetra2smqz3pq5xnjeiro2zzuipli53q5fxmfquedi2vye"
#   },
#   "_stmt_key": "2_23",
#   "_chunk_num": 2,
#   "_stmt_idx": 23
# }

# %% [raw]
# # Statement [2.24]: [Albert Einstein](/wiki/Albert_Einstein) received the [Gold Medal of RAS](/wiki/Gold_Medal_of_the_Royal_Astronomical_Society) in 1926.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:award https://en.wikipedia.org/wiki/Gold_Medal_of_the_Royal_Astronomical_Society .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:awardDate "1926"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie64x2etjahhvxjpjb2vitacsmreu6bbyvhfsklxrnlgepw3orl54",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie64x2etjahhvxjpjb2vitacsmreu6bbyvhfsklxrnlgepw3orl54",
#   "prov:label": "rdf:2_24",
#   "_cell": 106,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreickqixxats5vv35tynfsznd7jafuvktv7ddbtzyeenmlrvrn2g27y"
#   },
#   "_stmt_key": "2_24",
#   "_chunk_num": 2,
#   "_stmt_idx": 24
# }

# %% [raw]
# # Statement [2.25]: [Albert Einstein](/wiki/Albert_Einstein) received the [Max Planck Medal](/wiki/Max_Planck_Medal) in 1929.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:award https://en.wikipedia.org/wiki/Max_Planck_Medal .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:awardDate "1929"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihv52fuhxw4y45w2x2xkzqpk5mza7wkvw52foojtvoxczccedxgay",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihv52fuhxw4y45w2x2xkzqpk5mza7wkvw52foojtvoxczccedxgay",
#   "prov:label": "rdf:2_25",
#   "_cell": 108,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiapimlwycvrdd2km4563v625ncoi3relezrqv64hk2u47k4pdoume"
#   },
#   "_stmt_key": "2_25",
#   "_chunk_num": 2,
#   "_stmt_idx": 25
# }

# %% [raw]
# # Statement [2.26]: [Albert Einstein](/wiki/Albert_Einstein) became a member of the [National Academy of Sciences](/wiki/Member_of_the_National_Academy_of_Sciences) in 1942.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:award https://en.wikipedia.org/wiki/Member_of_the_National_Academy_of_Sciences .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:awardDate "1942"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihcg5rpzgbvnjn7ourpfojnrvuxjnkivljrtto4q3pdx2t5gwlql4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihcg5rpzgbvnjn7ourpfojnrvuxjnkivljrtto4q3pdx2t5gwlql4",
#   "prov:label": "rdf:2_26",
#   "_cell": 110,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifiiaywlgjjhexhpqtpng6zfc4butvc7f3a7mtpl5djodnpmzndx4"
#   },
#   "_stmt_key": "2_26",
#   "_chunk_num": 2,
#   "_stmt_idx": 26
# }

# %% [raw]
# # Statement [2.27]: [Albert Einstein](/wiki/Albert_Einstein) was named [''Time'' Person of the Century](/wiki/Time_100%3A_The_Most_Important_People_of_the_Century) in 1999.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:award https://en.wikipedia.org/wiki/Time_100%3A_The_Most_Important_People_of_the_Century .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:awardDate "1999"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreif33h43ztoxp2el52ciwpywtu2odrcvt4voay3tzrcgskjl4wrmde",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreif33h43ztoxp2el52ciwpywtu2odrcvt4voay3tzrcgskjl4wrmde",
#   "prov:label": "rdf:2_27",
#   "_cell": 112,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigcxfm2qutcg5i6nchg2yvwxh7qaaq2d346pvzeydplelo6chsm4a"
#   },
#   "_stmt_key": "2_27",
#   "_chunk_num": 2,
#   "_stmt_idx": 27
# }

# %% [raw]
# # Statement [3.1]: [Albert Einstein](/wiki/Albert_Einstein) was born on 14 March 1879.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:birthDate "1879-03-14"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreih25ytinybvba2nbkwufbesd6ezoklvlchjkkhhtrsi43oc2v3wuy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreih25ytinybvba2nbkwufbesd6ezoklvlchjkkhhtrsi43oc2v3wuy",
#   "prov:label": "rdf:3_1",
#   "_cell": 114,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiazipa5t2o64vc2ckcsdd4w6e777giy7qp2zobg6dkbeutvmevxaq"
#   },
#   "_stmt_key": "3_1",
#   "_chunk_num": 3,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [3.2]: [Albert Einstein](/wiki/Albert_Einstein) was born in [Ulm](/wiki/Ulm).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:birthPlace <https://en.wikipedia.org/wiki/Ulm> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaebvavm2p2dagxwvbyben7pggiweiujrkugi5rjt444z7mt256ny",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaebvavm2p2dagxwvbyben7pggiweiujrkugi5rjt444z7mt256ny",
#   "prov:label": "rdf:3_2",
#   "_cell": 116,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiau7no73cwq424hhiyt45jj5opq2sv7djwqiumy2t4qk6z53ev43a"
#   },
#   "_stmt_key": "3_2",
#   "_chunk_num": 3,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [3.3]: [Albert Einstein](/wiki/Albert_Einstein) was a German-born [theoretical physicist](/wiki/theoretical_physicist).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasOccupation <https://en.wikipedia.org/wiki/theoretical_physicist> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifkrnaw2rcojssmuiouifd5xrppc647jljjw6b6nnmjypm2ky4l4m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifkrnaw2rcojssmuiouifd5xrppc647jljjw6b6nnmjypm2ky4l4m",
#   "prov:label": "rdf:3_3",
#   "_cell": 118,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihngs375qpx5bonfdil3mi45zkzntun2ztajcw5wm4ivkba5ymv4i"
#   },
#   "_stmt_key": "3_3",
#   "_chunk_num": 3,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [3.4]: [Albert Einstein](/wiki/Albert_Einstein) is best known for developing the [theory of relativity](/wiki/theory_of_relativity).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:contributor <https://en.wikipedia.org/wiki/theory_of_relativity> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiangwvezcw3of7etiaqvyhmnn6urjn6bjvfayl2vlg3jgd4ulx5me",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiangwvezcw3of7etiaqvyhmnn6urjn6bjvfayl2vlg3jgd4ulx5me",
#   "prov:label": "rdf:3_4",
#   "_cell": 120,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreif5hodzyh4kfxeqbpbxuzraxiqazpplf2z6uumj4t5e5wjwlmt2e4"
#   },
#   "_stmt_key": "3_4",
#   "_chunk_num": 3,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [3.5]: [Albert Einstein](/wiki/Albert_Einstein) made important contributions to [quantum theory](/wiki/Old_quantum_theory).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:contributor <https://en.wikipedia.org/wiki/Old_quantum_theory> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigejjn6j5rcjuk6oyvav7vxepy66ot2l5ro3hx4outrruzjpshio4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigejjn6j5rcjuk6oyvav7vxepy66ot2l5ro3hx4outrruzjpshio4",
#   "prov:label": "rdf:3_5",
#   "_cell": 122,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidd7abyxs2bfc3kzgfnyj5ezt3h2uhxgvknchh75bo5t253navkjm"
#   },
#   "_stmt_key": "3_5",
#   "_chunk_num": 3,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [3.6]: [Albert Einstein](/wiki/Albert_Einstein) made important contributions to [statistical mechanics](/wiki/statistical_mechanics).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:contributor <https://en.wikipedia.org/wiki/statistical_mechanics> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigzebjcriqnoenfzishfbgqb7wnztc3s32e4xemcx5ipltqaeozzy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigzebjcriqnoenfzishfbgqb7wnztc3s32e4xemcx5ipltqaeozzy",
#   "prov:label": "rdf:3_6",
#   "_cell": 124,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiey3exwniz3xoqmufns5g2yswbcoica2oltmvlmsueyx2nshzrtl4"
#   },
#   "_stmt_key": "3_6",
#   "_chunk_num": 3,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [3.7]: [Albert Einstein](/wiki/Albert_Einstein) made important contributions to quantum theory.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:contributor <https://en.wikipedia.org/wiki/quantum_theory> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreib2mfkv44k47kcdizstlzjaykvxsxm2s3zwsslfzd5xcl6i4gtg5u",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreib2mfkv44k47kcdizstlzjaykvxsxm2s3zwsslfzd5xcl6i4gtg5u",
#   "prov:label": "rdf:3_7",
#   "_cell": 126,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicnvikdqh5tz5ybfnbrdnuq72sn5lljh6tdnddxidubp4zjzcsf3e"
#   },
#   "_stmt_key": "3_7",
#   "_chunk_num": 3,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [3.8]: [Albert Einstein](/wiki/Albert_Einstein) worked on the quantum physics of [radiation](/wiki/radiation).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:contributor <https://en.wikipedia.org/wiki/radiation> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiek43rcj67tnhly6jq4jb2r5uksh7d42qbduyca6k2wuth65cxfa4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiek43rcj67tnhly6jq4jb2r5uksh7d42qbduyca6k2wuth65cxfa4",
#   "prov:label": "rdf:3_8",
#   "_cell": 128,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiggz43mehs5nxhs3hxepvqnssd3hxueic4kwbrhgmrg5hto4knfua"
#   },
#   "_stmt_key": "3_8",
#   "_chunk_num": 3,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [3.9]: Light consists of particles, subsequently called [photon](/wiki/photon)s.
# <https://en.wikipedia.org/wiki/photon> rdf:type <https://en.wikipedia.org/wiki/quantum_of_light> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic5xo3tlstglogyy2gnhnwxxyp2a6i333ul2aijennqqkig2m3b7e",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic5xo3tlstglogyy2gnhnwxxyp2a6i333ul2aijennqqkig2m3b7e",
#   "prov:label": "rdf:3_9",
#   "_cell": 130,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifuokvmgmj4pq4xupdf25ehv2357eety7kwznz25f6ousgrufossa"
#   },
#   "_stmt_key": "3_9",
#   "_chunk_num": 3,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [3.10]: [Albert Einstein](/wiki/Albert_Einstein) worked with physicist [Satyendra Nath Bose](/wiki/Satyendra_Nath_Bose).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:colleagues <https://en.wikipedia.org/wiki/Satyendra_Nath_Bose> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidday6pz25yzxjccf7zup6h4vcpw3tvwkrtcwvpqj7dir63q76lui",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidday6pz25yzxjccf7zup6h4vcpw3tvwkrtcwvpqj7dir63q76lui",
#   "prov:label": "rdf:3_10",
#   "_cell": 132,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicrb3fhy5pb4fbyrtqzpvfjmkbehmwgkg7h5ewvuakzrgfkfxlq64"
#   },
#   "_stmt_key": "3_10",
#   "_chunk_num": 3,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [3.11]: [Albert Einstein](/wiki/Albert_Einstein) and [Satyendra Nath Bose](/wiki/Satyendra_Nath_Bose) laid the groundwork for [Bose–Einstein statistics](/wiki/Bose%E2%80%93Einstein_statistics).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:contributor <https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_statistics> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia3wojrs5tkyte2foksahe3lxo7wqhek2hduyp4ojaxqlnd67r2fq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia3wojrs5tkyte2foksahe3lxo7wqhek2hduyp4ojaxqlnd67r2fq",
#   "prov:label": "rdf:3_11",
#   "_cell": 134,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibuaxa6hlavyisfc4qphdcw25l5cfymoyd47gau7ryzvcq6mevlgm"
#   },
#   "_stmt_key": "3_11",
#   "_chunk_num": 3,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [3.12]: [Albert Einstein](/wiki/Albert_Einstein) advocated against quantum theory's introduction of fundamental randomness into science's picture of the world.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:contributor <https://en.wikipedia.org/wiki/quantum_theory> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihw6kkcpivetr7dh7ql5373lzzn2kyyxzccijptxiejlmrigsk4gm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihw6kkcpivetr7dh7ql5373lzzn2kyyxzccijptxiejlmrigsk4gm",
#   "prov:label": "rdf:3_12",
#   "_cell": 136,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidqwkowshi463l62aucfnnupidtu43sd3cg2gf6r7oiilf2eariuq"
#   },
#   "_stmt_key": "3_12",
#   "_chunk_num": 3,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [3.13]: [Albert Einstein](/wiki/Albert_Einstein) objected that "God does not play dice".
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:quote "God does not play dice" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihznaq5ioubgmqhxyy3mmkvtypn3a7e6njubilegufhrms47jcyxy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihznaq5ioubgmqhxyy3mmkvtypn3a7e6njubilegufhrms47jcyxy",
#   "prov:label": "rdf:3_13",
#   "_cell": 138,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih2efafd45y3ynt3kytl5vkw47custqwybmfa75qhhr32y2xmqjs4"
#   },
#   "_stmt_key": "3_13",
#   "_chunk_num": 3,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [3.14]: [Albert Einstein](/wiki/Albert_Einstein) attempted to devise a [unified field theory](/wiki/unified_field_theory).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:contributor <https://en.wikipedia.org/wiki/unified_field_theory> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibic3bz6won43owvsyy2je3ojj5kykj4eyytxmyo4dvfyksxzwj2i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibic3bz6won43owvsyy2je3ojj5kykj4eyytxmyo4dvfyksxzwj2i",
#   "prov:label": "rdf:3_14",
#   "_cell": 140,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiejwtij5m6qtaqyon6ihi4bidnmwe2ruw627plwgdg73yrhivxu54"
#   },
#   "_stmt_key": "3_14",
#   "_chunk_num": 3,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [3.15]: [Albert Einstein](/wiki/Albert_Einstein) generalized his geometric theory of gravitation to include [electromagnetism](/wiki/electromagnetism).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:contributor <https://en.wikipedia.org/wiki/electromagnetism> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibzofzgnchb6vvw4bhdtxoxfnt3txgbfl47wcxo5zfvhqwtk32qoq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibzofzgnchb6vvw4bhdtxoxfnt3txgbfl47wcxo5zfvhqwtk32qoq",
#   "prov:label": "rdf:3_15",
#   "_cell": 142,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiadeb2lrrzjhfdcguzu5vuacykvxkgwxl3u2y2vzhfskftmmiwsfa"
#   },
#   "_stmt_key": "3_15",
#   "_chunk_num": 3,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [3.16]: [Albert Einstein](/wiki/Albert_Einstein) became increasingly isolated from mainstream [modern physics](/wiki/modern_physics).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:contributor <https://en.wikipedia.org/wiki/modern_physics> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihigkmw5kppjtztai3k5uoqnamkloz5hpi62cyxp7hucjgvvr6zoa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihigkmw5kppjtztai3k5uoqnamkloz5hpi62cyxp7hucjgvvr6zoa",
#   "prov:label": "rdf:3_16",
#   "_cell": 144,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidaocywva3vu5dd5x74hzhvlflbt3frcovkvpfregz3b5nc5ymuai"
#   },
#   "_stmt_key": "3_16",
#   "_chunk_num": 3,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [3.17]: [Albert Einstein](/wiki/Albert_Einstein) was five years old when he was sick in bed.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:lifeEvent <https://en.wikipedia.org/wiki/childhood_illness> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibnblqiwz4zjlittnnqstbma3cmi35xllpvjo5jo3ny2fspntwakm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibnblqiwz4zjlittnnqstbma3cmi35xllpvjo5jo3ny2fspntwakm",
#   "prov:label": "rdf:3_17",
#   "_cell": 146,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidnngi2krk5gdanrcmwt5wm27abiv2fwrbq3hcwmyx3uj3zm6jdcy"
#   },
#   "_stmt_key": "3_17",
#   "_chunk_num": 3,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [3.18]: [Albert Einstein](/wiki/Albert_Einstein)'s father brought him a [compass](/wiki/magnetic_compass) when he was five and sick in bed.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:lifeEvent <https://en.wikipedia.org/wiki/childhood_illness> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiadp5m6kck4nz7ew4zgd33xjq6vloulj5tisypgy33uwbtathsfqq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiadp5m6kck4nz7ew4zgd33xjq6vloulj5tisypgy33uwbtathsfqq",
#   "prov:label": "rdf:3_18",
#   "_cell": 148,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreie5d3iktqrir33e6gojkv4ydruegwb6cuy6ihn75fmctrtjcuyhaq"
#   },
#   "_stmt_key": "3_18",
#   "_chunk_num": 3,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [3.19]: [Albert Einstein](/wiki/Albert_Einstein) had a lifelong fascination with [electromagnetism](/wiki/electromagnetism).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:interest <https://en.wikipedia.org/wiki/electromagnetism> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreih4vdihcjswugs4x2rgsduvncwadu5waibzzja5nl22b4ve6e2bsa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreih4vdihcjswugs4x2rgsduvncwadu5waibzzja5nl22b4ve6e2bsa",
#   "prov:label": "rdf:3_19",
#   "_cell": 150,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidptdepou7jtsmlac36phak2jogchpwpm6dd5qtcgwe5d2f3j55b4"
#   },
#   "_stmt_key": "3_19",
#   "_chunk_num": 3,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Statement [3.20]: [Albert Einstein](/wiki/Albert_Einstein) realized that "Something deeply hidden had to be behind things."
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:quote "Something deeply hidden had to be behind things." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidrptifobtlw6u7cfnfmllmy5kttmeiclbu6f5iu5jsilvngacjfu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidrptifobtlw6u7cfnfmllmy5kttmeiclbu6f5iu5jsilvngacjfu",
#   "prov:label": "rdf:3_20",
#   "_cell": 152,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicrfu6q2js3ix6df4k3nbaxketdxrru6epfzwgabpovg2sarm2nze"
#   },
#   "_stmt_key": "3_20",
#   "_chunk_num": 3,
#   "_stmt_idx": 20
# }

# %% [raw]
# # Statement [3.21]: [Albert Einstein](/wiki/Albert_Einstein) attended St. Peter's [Catholic elementary school](/wiki/Catholic_school) in Munich.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Catholic_school> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigq65m3x2uqekxbvuku3pk4jjsf3p4ekupo7qwcuqve6f36k2k2pq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigq65m3x2uqekxbvuku3pk4jjsf3p4ekupo7qwcuqve6f36k2k2pq",
#   "prov:label": "rdf:3_21",
#   "_cell": 154,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifgbux2jpcevxgqym3d2u7wkkssboymcl6a4yhv42atdr2lpt2g64"
#   },
#   "_stmt_key": "3_21",
#   "_chunk_num": 3,
#   "_stmt_idx": 21
# }

# %% [raw]
# # Statement [3.22]: [Albert Einstein](/wiki/Albert_Einstein) attended St. Peter's [Catholic elementary school](/wiki/Catholic_school) from the age of five.
# # No triples emitted for this statement
# # Debug: 42 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:birthDate", "object_value": "\"1879-03-14\"^^xsd:date"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:birthPlace", "object_value": "<https://en.wikipedia.org/wiki/Ulm>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasOccupation", "object_value": "<https://en.wikipedia.org/wiki/theoretical_physicist>"}
# #   emit_triple: {"statement_id": 4, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:contributor", "object_value": "<https://en.wikipedia.org/wiki/theory_of_relativity>"}
# #   emit_triple: {"statement_id": 5, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:contributor", "object_value": "<https://en.wikipedia.org/wiki/Old_quantum_theory>"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiccohkhot3jarx7mfvu6klnxmjrdsvwh7r5gu2ncjjiawved4k5pe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiccohkhot3jarx7mfvu6klnxmjrdsvwh7r5gu2ncjjiawved4k5pe",
#   "prov:label": "rdf:3_22",
#   "_cell": 156,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifexybmrdjfuocg6kqoslhypb6olodr2o7jso2cnykh4xzffsncb4"
#   },
#   "_stmt_key": "3_22",
#   "_chunk_num": 3,
#   "_stmt_idx": 22
# }

# %% [raw]
# # Statement [3.23]: [Albert Einstein](/wiki/Albert_Einstein) was transferred to the [Luitpold Gymnasium](/wiki/Luitpold_Gymnasium) when he was eight.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Luitpold_Gymnasium> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihqwayrbva7fipq43nikinebocghk2kzlsgrxrk5id3czvifjvt4a",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihqwayrbva7fipq43nikinebocghk2kzlsgrxrk5id3czvifjvt4a",
#   "prov:label": "rdf:3_23",
#   "_cell": 158,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiczqzck4gw2qqwqmg5yluvt5cdvn4fm2nhmrstvzgtux5mxjose5e"
#   },
#   "_stmt_key": "3_23",
#   "_chunk_num": 3,
#   "_stmt_idx": 23
# }

# %% [raw]
# # Statement [3.24]: [Albert Einstein](/wiki/Albert_Einstein) received advanced primary and then secondary school education at the [Luitpold Gymnasium](/wiki/Luitpold_Gymnasium).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Luitpold_Gymnasium> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigoulvh5suvfxjkqkdl56ysdziyrwkisr6r6bi4budcme5cvjiziq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigoulvh5suvfxjkqkdl56ysdziyrwkisr6r6bi4budcme5cvjiziq",
#   "prov:label": "rdf:3_24",
#   "_cell": 160,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid5sdq23xbo3bdy5dyniebph3esdreuuecjqrpcgkjiel2niqqz2a"
#   },
#   "_stmt_key": "3_24",
#   "_chunk_num": 3,
#   "_stmt_idx": 24
# }

# %% [raw]
# # Statement [4.1]: In 1894, Hermann and Jakob's company tendered for a contract to install electric lighting in Munich.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:birthPlace <https://en.wikipedia.org/wiki/Ulm> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality <https://en.wikipedia.org/wiki/German_Empire> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:parent <https://en.wikipedia.org/wiki/Hermann_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:parent <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie4jgkmeck62blfjonzycofe2lli7lncwspfiujoc734irfukz45m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie4jgkmeck62blfjonzycofe2lli7lncwspfiujoc734irfukz45m",
#   "prov:label": "rdf:4_1",
#   "_cell": 162,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia2xgahgiatytktjg7wulzkzkmtc7kf6jtzzrkb3zsfcwg2e7vrym"
#   },
#   "_stmt_key": "4_1",
#   "_chunk_num": 4,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [4.2]: The company lacked the capital required to update their technology from direct current to alternating current.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Bern> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Charles_University_in_Prague> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/German_Physical_Society> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiardqjmfusuu5qk3zoxgwdviw7vxoyfauamkck2b7a7ps3kgsj26q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiardqjmfusuu5qk3zoxgwdviw7vxoyfauamkck2b7a7ps3kgsj26q",
#   "prov:label": "rdf:4_2",
#   "_cell": 164,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih7hzkv4xerijwgeo3syvi5u5fyulygcvzist7m7znmiiruhym22a"
#   },
#   "_stmt_key": "4_2",
#   "_chunk_num": 4,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [4.3]: [Albert Einstein](/wiki/Albert_Einstein) was fifteen years old in 1894.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:age "15"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:birthPlace <https://en.wikipedia.org/wiki/Ulm> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality <https://en.wikipedia.org/wiki/German_Empire> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:parent <https://en.wikipedia.org/wiki/Hermann_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:parent <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreif6gfwasolt22qw7rrwhyftacp4gaybr4cqkitzukfeycpixfecga",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreif6gfwasolt22qw7rrwhyftacp4gaybr4cqkitzukfeycpixfecga",
#   "prov:label": "rdf:4_3",
#   "_cell": 166,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibmfjzhyusujycp2rttprm773fmmbzqg6bt6rfbu2f3byfghayp6u"
#   },
#   "_stmt_key": "4_3",
#   "_chunk_num": 4,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [4.4]: [Albert Einstein](/wiki/Albert_Einstein) stayed behind in [Munich](/wiki/Munich) to finish his schooling.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:age "15"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:birthPlace <https://en.wikipedia.org/wiki/Ulm> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality <https://en.wikipedia.org/wiki/German_Empire> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:parent <https://en.wikipedia.org/wiki/Hermann_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:parent <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifrcv5y5mkbr6aujpmn76wh2e754jemja2tgvmeitclhbdkjlw7iy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifrcv5y5mkbr6aujpmn76wh2e754jemja2tgvmeitclhbdkjlw7iy",
#   "prov:label": "rdf:4_4",
#   "_cell": 168,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidlla7zhcvq7cbbg4tep2ve3teco6rmhqu3kn5zf6mo4suu7ej24q"
#   },
#   "_stmt_key": "4_4",
#   "_chunk_num": 4,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [4.5]: [Albert Einstein](/wiki/Albert_Einstein)'s father wanted him to study [electrical engineering](/wiki/electrical_engineering).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:studySubject <https://en.wikipedia.org/wiki/Electrical_engineering> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:age "15"^^xsd:integer .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:birthPlace <https://en.wikipedia.org/wiki/Ulm> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality <https://en.wikipedia.org/wiki/German_Empire> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibuq6esy635pj66f35vo4xlajv4ys3eswmobjahglzc64te2ivj34",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibuq6esy635pj66f35vo4xlajv4ys3eswmobjahglzc64te2ivj34",
#   "prov:label": "rdf:4_5",
#   "_cell": 170,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidur325vodflbu4ymgz5oqg3naimvse6ltl3b7igwrnknydv7tbhm"
#   },
#   "_stmt_key": "4_5",
#   "_chunk_num": 4,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [4.6]: [Albert Einstein](/wiki/Albert_Einstein) was a fractious pupil at the Gymnasium.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Bern> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Charles_University_in_Prague> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/German_Physical_Society> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihuwliaott7bvul3wjlxwb2zu7c65c4gnwpyzphfttulvih7lldpy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihuwliaott7bvul3wjlxwb2zu7c65c4gnwpyzphfttulvih7lldpy",
#   "prov:label": "rdf:4_6",
#   "_cell": 172,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibpzvlvy7pyvrot6wvemh7kabocfz2z32aucght4ksto6m5i66daq"
#   },
#   "_stmt_key": "4_6",
#   "_chunk_num": 4,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [4.7]: The Gymnasium's regimen and teaching methods were not congenial to [Albert Einstein](/wiki/Albert_Einstein).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:studySubject <https://en.wikipedia.org/wiki/Physics> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Bern> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Charles_University_in_Prague> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/German_Physical_Society> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihuxir35ztwmk5lftr53l5n4dewvznsog6yebgexx6xbg7peqlqpe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihuxir35ztwmk5lftr53l5n4dewvznsog6yebgexx6xbg7peqlqpe",
#   "prov:label": "rdf:4_7",
#   "_cell": 174,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihlafrqmustctzd25us2t3hadqsfh5ivjlzjxgszvlreillo4oo5y"
#   },
#   "_stmt_key": "4_7",
#   "_chunk_num": 4,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [4.8]: [Albert Einstein](/wiki/Albert_Einstein) later wrote that the school's policy of strict rote learning was harmful to creativity.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:studySubject <https://en.wikipedia.org/wiki/Physics> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Bern> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Charles_University_in_Prague> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/German_Physical_Society> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicxuerbdglqrvatmpdnxabciyxzlwvith7l7kog5tyrludxsttstq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicxuerbdglqrvatmpdnxabciyxzlwvith7l7kog5tyrludxsttstq",
#   "prov:label": "rdf:4_8",
#   "_cell": 176,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiehfg42votum3guyvunw3eja4cax6morzxb665gzbm3khhhfefbni"
#   },
#   "_stmt_key": "4_8",
#   "_chunk_num": 4,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [4.9]: At the end of December 1894, a doctor's letter persuaded the Luitpold's authorities to release [Albert Einstein](/wiki/Albert_Einstein) from their care.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Bern> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Charles_University_in_Prague> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/German_Physical_Society> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifsiskbix3w7l5pb52irr2fxk27ix4apa4uezlnusmgfohk6vr54q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifsiskbix3w7l5pb52irr2fxk27ix4apa4uezlnusmgfohk6vr54q",
#   "prov:label": "rdf:4_9",
#   "_cell": 178,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidzpxk3o6ewcf5vtbti6vua2pj7iwcd4lbjep5zturwywnikiuyim"
#   },
#   "_stmt_key": "4_9",
#   "_chunk_num": 4,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [4.10]: [Albert Einstein](/wiki/Albert_Einstein) joined his family in [Pavia](/wiki/Pavia).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Bern> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Charles_University_in_Prague> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/German_Physical_Society> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidfpgj4l3m3hs4qn7soig2jflnhxqjdkczuffoj7vpf6oopdh4yrq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidfpgj4l3m3hs4qn7soig2jflnhxqjdkczuffoj7vpf6oopdh4yrq",
#   "prov:label": "rdf:4_10",
#   "_cell": 180,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidobgtg66lzypdgpqjo2tpv5lejlbj3aytecnj6pblq7riz4f2o7u"
#   },
#   "_stmt_key": "4_10",
#   "_chunk_num": 4,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [4.11]: While in [Italy](/wiki/Italy) as a teenager, [Albert Einstein](/wiki/Albert_Einstein) wrote an essay entitled "On the Investigation of the State of the Ether in a Magnetic Field".
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:studySubject <https://en.wikipedia.org/wiki/Physics> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Bern> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Charles_University_in_Prague> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/German_Physical_Society> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiatdjyk6trslvltlokerog3cild5u4w2vwghbgnulbdmrq6l7q6ie",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiatdjyk6trslvltlokerog3cild5u4w2vwghbgnulbdmrq6l7q6ie",
#   "prov:label": "rdf:4_11",
#   "_cell": 182,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibdml4mo2is6lqrhoupb26cbpgzrvfcvml4k2pd73fpmuo6lva7w4"
#   },
#   "_stmt_key": "4_11",
#   "_chunk_num": 4,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [4.12]: [Max Talmud](/wiki/Max_Talmud) was a family tutor of [Albert Einstein](/wiki/Albert_Einstein).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Bern> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Charles_University_in_Prague> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/German_Physical_Society> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigemvje6lulyjgkat3fpmvzlhijyu7qmjr2i6hftw3b6wnzn5dfia",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigemvje6lulyjgkat3fpmvzlhijyu7qmjr2i6hftw3b6wnzn5dfia",
#   "prov:label": "rdf:4_12",
#   "_cell": 184,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihe2lgf7yyxsrstfviwos4h5baj3jjn4lkohgz2fmycb2dvqd3kpm"
#   },
#   "_stmt_key": "4_12",
#   "_chunk_num": 4,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [4.13]: [Max Talmud](/wiki/Max_Talmud) said that shortly after giving the twelve-year-old [Albert Einstein](/wiki/Albert_Einstein) a geometry textbook, the boy had worked through the whole book.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Bern> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Charles_University_in_Prague> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/German_Physical_Society> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicu5kne35aistqpt4xviiolxebydvh6obtwgedlyrqxy3moubxqs4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicu5kne35aistqpt4xviiolxebydvh6obtwgedlyrqxy3moubxqs4",
#   "prov:label": "rdf:4_13",
#   "_cell": 186,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifl6fzrxk3gjk7bi3gjhaxvltw6tqcdcn4ccv6z3ge2o67j7qptuq"
#   },
#   "_stmt_key": "4_13",
#   "_chunk_num": 4,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [4.14]: After working through the geometry textbook, [Albert Einstein](/wiki/Albert_Einstein) devoted himself to higher mathematics.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:studySubject <https://en.wikipedia.org/wiki/Physics> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Bern> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Charles_University_in_Prague> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/German_Physical_Society> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidc2cwmfzxdtoqd2rxaijhudiyzucu65prpwt33yjfejzospbffyi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidc2cwmfzxdtoqd2rxaijhudiyzucu65prpwt33yjfejzospbffyi",
#   "prov:label": "rdf:4_14",
#   "_cell": 188,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib6n6tacwumejibuivkqsemqndtyxxoa3awzh4k6x5xfrxbofnqd4"
#   },
#   "_stmt_key": "4_14",
#   "_chunk_num": 4,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [4.15]: [Max Talmud](/wiki/Max_Talmud) noted that the flight of [Albert Einstein](/wiki/Albert_Einstein)'s mathematical genius was so high that he could not follow.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:studySubject <https://en.wikipedia.org/wiki/Physics> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Bern> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Charles_University_in_Prague> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/German_Physical_Society> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibfc2ey4pybxe2ulfvfqwypaz7mgyatfiodxssjyt3yubdzai227i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibfc2ey4pybxe2ulfvfqwypaz7mgyatfiodxssjyt3yubdzai227i",
#   "prov:label": "rdf:4_15",
#   "_cell": 190,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreig3l3yz6opozjpqnctuylhkuueds2x5lv7jbt64xkq6zl4lt4ttai"
#   },
#   "_stmt_key": "4_15",
#   "_chunk_num": 4,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [4.16]: [Albert Einstein](/wiki/Albert_Einstein) recorded that he had mastered integral and differential calculus while still fourteen years old.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:studySubject <https://en.wikipedia.org/wiki/Physics> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Bern> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Charles_University_in_Prague> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/German_Physical_Society> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibgp3eshimbvitz63gsj2al5hc4jllfgmlrkjp5alp3sg2gi33p6e",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibgp3eshimbvitz63gsj2al5hc4jllfgmlrkjp5alp3sg2gi33p6e",
#   "prov:label": "rdf:4_16",
#   "_cell": 192,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiefrtp4mhgjdvd6wnnda3tza6oju7zxaevowb5mm7srm7raikttbu"
#   },
#   "_stmt_key": "4_16",
#   "_chunk_num": 4,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [4.17]: [Albert Einstein](/wiki/Albert_Einstein)'s love of algebra and geometry was so great that at twelve, he was already confident that nature could be understood as a mathematical structure.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:studySubject <https://en.wikipedia.org/wiki/Physics> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Bern> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Charles_University_in_Prague> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/German_Physical_Society> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia2dnkdf6qs3vd6km5zb2sd6zsqg4mvfi2jzipmvoven5fwyndlv4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia2dnkdf6qs3vd6km5zb2sd6zsqg4mvfi2jzipmvoven5fwyndlv4",
#   "prov:label": "rdf:4_17",
#   "_cell": 194,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihlcizpoqaxh3ggs3vwq2tnmjh65l4cv7inzjm6icoj2adymelzaq"
#   },
#   "_stmt_key": "4_17",
#   "_chunk_num": 4,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [5.1]: At thirteen, [Albert Einstein](/wiki/Albert_Einstein) was introduced to [Kant](/wiki/Kant)'s *[Critique of Pure Reason](/wiki/Critique_of_Pure_Reason)* by [Talmud](/wiki/Talmud).
# https://en.wikipedia.org/wiki/Albert_Einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Kant rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Critique_of_Pure_Reason rdf:type schema:Book .
# https://en.wikipedia.org/wiki/Talmud rdf:type schema:CreativeWork .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihxazccjocu67szbexnd3sbj2dbyqnbcfvmzqycsclmmijejvcb7e",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihxazccjocu67szbexnd3sbj2dbyqnbcfvmzqycsclmmijejvcb7e",
#   "prov:label": "rdf:5_1",
#   "_cell": 196,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreief7agjzgtjmclhfhlf5u4styfpvlnvmxwxwx4pjf5ovwdsgfbsc4"
#   },
#   "_stmt_key": "5_1",
#   "_chunk_num": 5,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [5.2]: At thirteen, [Albert Einstein](/wiki/Albert_Einstein) became interested in music and philosophy.
# https://en.wikipedia.org/wiki/Albert_Einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:interest "music" .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:interest "philosophy" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihffyah7wcyqwmr6fhlwi455jwqpow7lqmsl66ucr775kb66bpcrq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihffyah7wcyqwmr6fhlwi455jwqpow7lqmsl66ucr775kb66bpcrq",
#   "prov:label": "rdf:5_2",
#   "_cell": 198,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigc4wxtdfzmlpusoef5kitztmrcbuknwdmqfiyujbpirced46l4xq"
#   },
#   "_stmt_key": "5_2",
#   "_chunk_num": 5,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [5.3]: [Kant](/wiki/Kant) was a favorite philosopher of [Albert Einstein](/wiki/Albert_Einstein).
# https://en.wikipedia.org/wiki/Albert_Einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Kant rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:favoritePhilosopher https://en.wikipedia.org/wiki/Kant .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicjhr3un4rhxaatmphcvwv7uirp3xsexmpo547iqe34cjwiwltoda",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicjhr3un4rhxaatmphcvwv7uirp3xsexmpo547iqe34cjwiwltoda",
#   "prov:label": "rdf:5_3",
#   "_cell": 200,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicode2b4go6mj6putr66wiief6x64ypgogjhmprafcndhcsitgi5e"
#   },
#   "_stmt_key": "5_3",
#   "_chunk_num": 5,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [5.4]: According to [Talmud](/wiki/Talmud), at the age of thirteen, [Albert Einstein](/wiki/Albert_Einstein) found Kant's works clear despite their incomprehensibility to ordinary mortals.
# https://en.wikipedia.org/wiki/Albert_Einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Kant rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Critique_of_Pure_Reason rdf:type schema:Book .
# https://en.wikipedia.org/wiki/Talmud rdf:type schema:CreativeWork .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibnxdwf2z7ypqylbubpgbibhthrgy2wqmucfok6633yanxmzxa7ty",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibnxdwf2z7ypqylbubpgbibhthrgy2wqmucfok6633yanxmzxa7ty",
#   "prov:label": "rdf:5_4",
#   "_cell": 202,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreighaijj7rau7garyoodtrmtuqpcmopg4ckks54lbwya3vj3b25c5m"
#   },
#   "_stmt_key": "5_4",
#   "_chunk_num": 5,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [5.5]: In 1895, [Albert Einstein](/wiki/Albert_Einstein) was sixteen years old.
# https://en.wikipedia.org/wiki/Albert_Einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:age "16"^^xsd:integer .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiguwxmzioama3yw2pd2by3xqjhgvcy7frofs5mygyyhpaqkhjep7q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiguwxmzioama3yw2pd2by3xqjhgvcy7frofs5mygyyhpaqkhjep7q",
#   "prov:label": "rdf:5_5",
#   "_cell": 204,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreictf76rgw3l4powbjypihnjwiwb6i4dvlcxzlyu3g5pjvzo6kzaye"
#   },
#   "_stmt_key": "5_5",
#   "_chunk_num": 5,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [5.6]: In 1895, [Albert Einstein](/wiki/Albert_Einstein) sat the entrance examination for the [federal polytechnic school](/wiki/ETH_Zurich) in [Zurich](/wiki/Zurich), [Switzerland](/wiki/Switzerland).
# https://en.wikipedia.org/wiki/Albert_Einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/ETH_Zurich rdf:type schema:School .
# https://en.wikipedia.org/wiki/Zurich rdf:type schema:Place .
# https://en.wikipedia.org/wiki/Switzerland rdf:type schema:Place .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiebpyjcf4dmxwnjqoebe25gqbtdbepq4wewb5kle77dwimnjuzcou",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiebpyjcf4dmxwnjqoebe25gqbtdbepq4wewb5kle77dwimnjuzcou",
#   "prov:label": "rdf:5_6",
#   "_cell": 206,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigqy5skk67m7kfldqadxdxdeyjlgqm33hjfzfc4jzu6v77nnydxcy"
#   },
#   "_stmt_key": "5_6",
#   "_chunk_num": 5,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [5.7]: [Albert Einstein](/wiki/Albert_Einstein) failed to reach the required standard in the general part of the entrance examination.
# https://en.wikipedia.org/wiki/Albert_Einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/ETH_Zurich rdf:type schema:School .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieyjknd5rezl3yebuuv6s4x44nofhsf7zetoyxtrikm2jbxfc6evu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieyjknd5rezl3yebuuv6s4x44nofhsf7zetoyxtrikm2jbxfc6evu",
#   "prov:label": "rdf:5_7",
#   "_cell": 208,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieahkjpnlkc4aztvtlnstu2byyucdo4756whs4hq3ofvk3hhz6wfe"
#   },
#   "_stmt_key": "5_7",
#   "_chunk_num": 5,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [5.8]: [Albert Einstein](/wiki/Albert_Einstein) performed with distinction in physics and mathematics in the entrance examination.
# https://en.wikipedia.org/wiki/Albert_Einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/ETH_Zurich rdf:type schema:School .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie36kowv5rzzdmmm2hb7x4nyiinyi7sasj2ds44kbhwhcrctfruxu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie36kowv5rzzdmmm2hb7x4nyiinyi7sasj2ds44kbhwhcrctfruxu",
#   "prov:label": "rdf:5_8",
#   "_cell": 210,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreico7mbvjpvlg67jm6ulryqxmzz236hnvyrcirkz2nky5rxbf7g3n4"
#   },
#   "_stmt_key": "5_8",
#   "_chunk_num": 5,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [5.9]: On the advice of the principal of the [federal polytechnic school](/wiki/ETH_Zurich), [Albert Einstein](/wiki/Albert_Einstein) completed his secondary education at the [Argovian cantonal school](/wiki/Old_Cantonal_School_Aarau) in [Aarau](/wiki/Aarau), [Switzerland](/wiki/Switzerland).
# https://en.wikipedia.org/wiki/Albert_Einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/ETH_Zurich rdf:type schema:School .
# https://en.wikipedia.org/wiki/Old_Cantonal_School_Aarau rdf:type schema:School .
# https://en.wikipedia.org/wiki/Aarau rdf:type schema:Place .
# https://en.wikipedia.org/wiki/Switzerland rdf:type schema:Place .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieo5afzzxit5es5uzkjv6khuc4m5sem2c343zyyuss7gqjg774nhy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieo5afzzxit5es5uzkjv6khuc4m5sem2c343zyyuss7gqjg774nhy",
#   "prov:label": "rdf:5_9",
#   "_cell": 212,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifr25mjdxs7w27doyzfykn64lvmlnlh363etekueqp2tzmnxp3epe"
#   },
#   "_stmt_key": "5_9",
#   "_chunk_num": 5,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [5.10]: [Albert Einstein](/wiki/Albert_Einstein) graduated from the [Argovian cantonal school](/wiki/Old_Cantonal_School_Aarau) in 1896.
# https://en.wikipedia.org/wiki/Albert_Einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Old_Cantonal_School_Aarau rdf:type schema:School .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicp4b3l5vnzliriwc6uefaiavqqew4efjrhvv7owqpupgohrvun24",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicp4b3l5vnzliriwc6uefaiavqqew4efjrhvv7owqpupgohrvun24",
#   "prov:label": "rdf:5_10",
#   "_cell": 214,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreig4isjsfgaplev4on3csgpz5e5h6t7uuydifg6fdduye4yl55sp6i"
#   },
#   "_stmt_key": "5_10",
#   "_chunk_num": 5,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [5.11]: While lodging in [Aarau](/wiki/Aarau) with the family of [Jost Winteler](/wiki/Jost_Winteler), [Albert Einstein](/wiki/Albert_Einstein) fell in love with Winteler's daughter, [Marie](/wiki/Marie_Einstein).
# https://en.wikipedia.org/wiki/Albert_Einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Aarau rdf:type schema:Place .
# https://en.wikipedia.org/wiki/Jost_Winteler rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Marie_Einstein rdf:type schema:Person .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibvrsbyitwskqkkbmvjnzrubyeys4iyilrct3naxnrl4lednzd4j4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibvrsbyitwskqkkbmvjnzrubyeys4iyilrct3naxnrl4lednzd4j4",
#   "prov:label": "rdf:5_11",
#   "_cell": 216,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidb2codnmnsnn4czkdebhz2zmbi4zqkihusafnc44qngnkfdhuz5y"
#   },
#   "_stmt_key": "5_11",
#   "_chunk_num": 5,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [5.12]: [Albert Einstein](/wiki/Albert_Einstein)'s sister, [Maja](/wiki/Maja_Einstein), later married Winteler's son, [Paul](/wiki/Paul_Winteler).
# https://en.wikipedia.org/wiki/Maja_Einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Paul_Winteler rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Jost_Winteler rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Maja_Einstein schema:spouse https://en.wikipedia.org/wiki/Paul_Winteler .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiemrueo66paoyp2ypr3akkqn2nxwmykpytticybmp6zajsaz2nlgy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiemrueo66paoyp2ypr3akkqn2nxwmykpytticybmp6zajsaz2nlgy",
#   "prov:label": "rdf:5_12",
#   "_cell": 218,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibblgkx2eqastwm54satzxv6ij6fqrx4wqdb7nvk4zpb7yxlokczy"
#   },
#   "_stmt_key": "5_12",
#   "_chunk_num": 5,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [5.13]: The [federal polytechnic school](/wiki/ETH_Zurich) was later known as the Eidgenössische Technische Hochschule.
# https://en.wikipedia.org/wiki/ETH_Zurich rdf:type schema:School .
# https://en.wikipedia.org/wiki/Eidgenössische_Technische_Hochschule rdf:type schema:School .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibapapvifgzyexd6m55n4eygydfomcqol34uxnbt7cfiasmdc6bpa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibapapvifgzyexd6m55n4eygydfomcqol34uxnbt7cfiasmdc6bpa",
#   "prov:label": "rdf:5_13",
#   "_cell": 220,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigraarqjkini25kmmw7tnp6aspaawkqwhz2hlto54v63aepmsboj4"
#   },
#   "_stmt_key": "5_13",
#   "_chunk_num": 5,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [5.14]: [Aarau](/wiki/Aarau) is located in [Switzerland](/wiki/Switzerland).
# https://en.wikipedia.org/wiki/Aarau rdf:type schema:Place .
# https://en.wikipedia.org/wiki/Switzerland rdf:type schema:Place .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihfqe7a7bwzbwg2jhhq3dipno7rwc5elqvxv6dsykzoxycvyazdfq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihfqe7a7bwzbwg2jhhq3dipno7rwc5elqvxv6dsykzoxycvyazdfq",
#   "prov:label": "rdf:5_14",
#   "_cell": 222,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidflgfp2bevkqm6iddx7bqogzzi5g2wjkeh35i6cxcbbvjslkiu5u"
#   },
#   "_stmt_key": "5_14",
#   "_chunk_num": 5,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [5.15]: [Jost Winteler](/wiki/Jost_Winteler) was the father of [Marie](/wiki/Marie_Einstein).
# https://en.wikipedia.org/wiki/Jost_Winteler rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Marie_Einstein rdf:type schema:Person .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiepduyktknjjcbhcops4g7bnzigciphz5a3ibyq5p7kioelbewjiq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiepduyktknjjcbhcops4g7bnzigciphz5a3ibyq5p7kioelbewjiq",
#   "prov:label": "rdf:5_15",
#   "_cell": 224,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihh53huvhfg6tc4637hxwtu45wdh7nfbaupmde6vologkbebmclvu"
#   },
#   "_stmt_key": "5_15",
#   "_chunk_num": 5,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [5.16]: [Paul](/wiki/Paul_Winteler) was the son of [Jost Winteler](/wiki/Jost_Winteler).
# https://en.wikipedia.org/wiki/Jost_Winteler rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Paul_Winteler rdf:type schema:Person .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiby5wk7ukzyp4ce3h4ttctuq2vx7sdubm757xdo2tvjtxvgxzmwem",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiby5wk7ukzyp4ce3h4ttctuq2vx7sdubm757xdo2tvjtxvgxzmwem",
#   "prov:label": "rdf:5_16",
#   "_cell": 226,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid2bcuwkdgyuz3zt7ita73364ork676nvfe4or4gdel7eyczbzbji"
#   },
#   "_stmt_key": "5_16",
#   "_chunk_num": 5,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [5.17]: [Marie](/wiki/Marie_Einstein) was the daughter of [Jost Winteler](/wiki/Jost_Winteler).
# https://en.wikipedia.org/wiki/Jost_Winteler rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Marie_Einstein rdf:type schema:Person .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreih275xaouhwa32lrhrjn5zxkapbxi2hmnoe2tn5gl5x5kvcogs37u",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreih275xaouhwa32lrhrjn5zxkapbxi2hmnoe2tn5gl5x5kvcogs37u",
#   "prov:label": "rdf:5_17",
#   "_cell": 228,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiahvcsdzhetdksydzurwqk2owj7hvysp6vomafrrgv52gi27vpm64"
#   },
#   "_stmt_key": "5_17",
#   "_chunk_num": 5,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [5.18]: [Maja](/wiki/Maja_Einstein) was the sister of [Albert Einstein](/wiki/Albert_Einstein).
# https://en.wikipedia.org/wiki/Albert_Einstein rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Maja_Einstein rdf:type schema:Person .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigxq473b2cil3wpii7frnjxk3osekzmezl24dionvewncgugffzgq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigxq473b2cil3wpii7frnjxk3osekzmezl24dionvewncgugffzgq",
#   "prov:label": "rdf:5_18",
#   "_cell": 230,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreie344acopqzxai7e67dvj2pulexelrqnkyh6d4cclu46dsubqejmi"
#   },
#   "_stmt_key": "5_18",
#   "_chunk_num": 5,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [5.19]: The [Argovian cantonal school](/wiki/Old_Cantonal_School_Aarau) was a [*gymnasium*](/wiki/Gymnasium_%28school%29).
# https://en.wikipedia.org/wiki/Old_Cantonal_School_Aarau rdf:type schema:School .
# https://en.wikipedia.org/wiki/Gymnasium_%28school%29 rdf:type schema:School .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigwvnffmuv6aw7oazryphrnchx2e3dxshjbamlw34tns322a2fraq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigwvnffmuv6aw7oazryphrnchx2e3dxshjbamlw34tns322a2fraq",
#   "prov:label": "rdf:5_19",
#   "_cell": 232,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiborm2pzfnncizeqplwcik7ya5sus3njebe4gkxbfulzatabwgoqm"
#   },
#   "_stmt_key": "5_19",
#   "_chunk_num": 5,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Statement [5.20]: [Heinrich Friedrich Weber](/wiki/Heinrich_Friedrich_Weber) was associated with the [Argovian cantonal school](/wiki/Old_Cantonal_School_Aarau).
# https://en.wikipedia.org/wiki/Heinrich_Friedrich_Weber rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Old_Cantonal_School_Aarau rdf:type schema:School .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicbwktf7alptbcoiaajjz45kg6j7qajs4236orezmf7ciriz5cf7y",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicbwktf7alptbcoiaajjz45kg6j7qajs4236orezmf7ciriz5cf7y",
#   "prov:label": "rdf:5_20",
#   "_cell": 234,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreickcqovk2arocsaocj55ul4sjttxeq53zthli5w6vl6iuox6g67l4"
#   },
#   "_stmt_key": "5_20",
#   "_chunk_num": 5,
#   "_stmt_idx": 20
# }

# %% [raw]
# # Statement [5.21]: [Alfred Kleiner](/wiki/Alfred_Kleiner) was associated with the [Argovian cantonal school](/wiki/Old_Cantonal_School_Aarau).
# https://en.wikipedia.org/wiki/Alfred_Kleiner rdf:type schema:Person .
# https://en.wikipedia.org/wiki/Old_Cantonal_School_Aarau rdf:type schema:School .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicnau3y2lnnaol4ehxvhpuc2vt5kp6mpwg4l2tmon7fr2epnntl5q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicnau3y2lnnaol4ehxvhpuc2vt5kp6mpwg4l2tmon7fr2epnntl5q",
#   "prov:label": "rdf:5_21",
#   "_cell": 236,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieeu7i3qd6lyiengiddq6duya2t6zifobmqakm3tur2swwbldgvou"
#   },
#   "_stmt_key": "5_21",
#   "_chunk_num": 5,
#   "_stmt_idx": 21
# }

# %% [raw]
# # Chunk 6 Error: APITimeoutError: Request timed out.
# #
# # === FULL PROMPT SENT TO LLM ===
# #
# # SYSTEM PROMPT:
# # You are an expert at converting factual statements to RDF triples.
# #
# # The statements contain markdown links like [Entity Name](/wiki/Entity_Name) that provide Wikipedia URIs for entities.
# # Convert these to proper RDF URIs using: <https://en.wikipedia.org/wiki/Entity_Name>
# #
# # You have access to these tools:
# #
# # LOOKUP TOOLS (use first to find correct vocabulary):
# # - find_rdf_class: Find the best schema.org class/type for an entity
# # - find_rdf_property: Find the best predicate for a relationship
# #
# # OUTPUT TOOLS (use to emit your triples - MUST include statement_id):
# # - emit_triple: Output a single triple with statement_id
# # - emit_triples: Output multiple triples at once (more efficient)
# #
# # WORKFLOW:
# # 1. For each statement, extract entities from markdown links: [Label](/wiki/Path) → <https://en.wikipedia.org/wiki/Path>
# # 2. Use find_rdf_class and find_rdf_property to look up appropriate schema.org terms
# # 3. Use emit_triple or emit_triples to output RDF triples, INCLUDING the statement_id
# #
# # URI RULES:
# # - For entities with Wikipedia links like [Albert Einstein](/wiki/Albert_Einstein):
# #   Use: <https://en.wikipedia.org/wiki/Albert_Einstein>
# # - For entities in the Entity Registry: Use their provided URI
# # - For new entities not in either: Use fragment URIs like <#entity_name>
# # - NEVER invent Wikidata URIs (wd:Q...) unless explicitly provided
# #
# # IMPORTANT:
# # - Do NOT write Turtle syntax in your response - use the emit tools instead
# # - ALWAYS include the statement_id when emitting triples (e.g., "1", "2", "3")
# # - Use schema.org terms you looked up (e.g., schema:Person, schema:birthDate)
# # - For URIs, use angle brackets: <https://...> or fragment references: <#entity_id>
# # - For literals, use quotes with optional datatype: "value"^^xsd:date or "text"@en
# # - For prefixed terms as objects, just use the prefix: schema:Person
# # - Each statement is self-contained - extract all facts from each one
# #
# # HUMAN PROMPT:
# # Convert these factual statements to RDF triples.
# #
# # Source: https://en.wikipedia.org/wiki/Albert_Einstein
# # Section context: Albert Einstein > Life and career > Childhood, youth and education
# #
# # Entity Registry (use these URIs for known entities):
# # <https://en.wikipedia.org/wiki/Albert_Einstein> # Albert Einstein (Person) (Wikidata: Q937)
# # <https://en.wikipedia.org/wiki/Ulm> # Ulm (Thing)
# # <https://en.wikipedia.org/wiki/Kingdom_of_W%C3%BCrttemberg> # Kingdom of Württemberg (Thing)
# # <https://en.wikipedia.org/wiki/German_Empire> # German Empire (Thing)
# # <https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey> # Princeton, New Jersey (Thing)
# # <https://en.wikipedia.org/wiki/Lieserl_Einstein> # Lieserl (Thing)
# # <https://en.wikipedia.org/wiki/Hans_Albert_Einstein> # Hans Albert (Thing)
# # <https://en.wikipedia.org/wiki/Einstein_family> # Eduard "Tete" (Thing)
# # <https://en.wikipedia.org/wiki/Einstein_family> # Einstein (Thing)
# # <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> # Mileva Marić (Thing)
# # <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> # Elsa Löwenthal (Thing)
# # <https://en.wikipedia.org/wiki/Statelessness> # Stateless (Thing)
# # <https://en.wikipedia.org/wiki/Switzerland> # Switzerland (Thing)
# # <https://en.wikipedia.org/wiki/Kingdom_of_Prussia> # Kingdom of Prussia (Thing)
# # <https://en.wikipedia.org/wiki/Free_State_of_Prussia> # Free State of Prussia (Thing)
# # <https://en.wikipedia.org/wiki/Weimar_Republic> # Weimar Republic (Thing)
# # <https://en.wikipedia.org/wiki/Citizenship_of_the_United_States> # United States (Thing)
# # <https://en.wikipedia.org/wiki/Physics> # Physics (Thing)
# # <https://en.wikipedia.org/wiki/University_of_Bern> # University of Bern (Thing)
# # <https://en.wikipedia.org/wiki/University_of_Zurich> # University of Zurich (Thing)
# # <https://en.wikipedia.org/wiki/Charles_University_in_Prague> # Charles University in Prague (Thing)
# # <https://en.wikipedia.org/wiki/ETH_Zurich> # ETH Zurich (Thing)
# # <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> # Prussian Academy of Sciences (Thing)
# # <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> # Humboldt University of Berlin (Thing)
# # <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute> # Kaiser Wilhelm Institute (Thing)
# # <https://en.wikipedia.org/wiki/German_Physical_Society> # German Physical Society (Thing)
# # <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> # Institute for Advanced Study (Thing)
# # <https://en.wikipedia.org/wiki/ETH_Zurich> # Swiss Federal Polytechnic School (Thing)
# # <https://en.wikipedia.org/wiki/PhD> # PhD (Thing)
# # <https://en.wikipedia.org/wiki/Alfred_Kleiner> # Alfred Kleiner (Thing)
# # <https://en.wikipedia.org/wiki/Heinrich_Friedrich_Weber> # Heinrich Friedrich Weber (Thing)
# # <https://en.wikipedia.org/wiki/General_relativity> # General relativity (Thing)
# # <https://en.wikipedia.org/wiki/Special_relativity> # Special relativity (Thing)
# # <https://en.wikipedia.org/wiki/Photoelectric_effect> # Photoelectric effect (Thing)
# # <https://en.wikipedia.org/wiki/Mass%E2%80%93energy_equivalence> # ''E''=''mc''<sup>2</sup> (mass–energy equivalence) (Thing)
# # <https://en.wikipedia.org/wiki/Planck%E2%80%93Einstein_relation> # ''E''=''hf'' (Planck–Einstein relation) (Thing)
# # <https://en.wikipedia.org/wiki/Brownian_motion> # Theory of Brownian motion (Thing)
# # <https://en.wikipedia.org/wiki/Einstein_field_equations> # Einstein field equations (Thing)
# # <https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_statistics> # Bose–Einstein statistics (Thing)
# # <https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_condensate> # Bose–Einstein condensate (Thing)
# # <https://en.wikipedia.org/wiki/Gravitational_wave> # Gravitational wave (Thing)
# # <https://en.wikipedia.org/wiki/Cosmological_constant> # Cosmological constant (Thing)
# # <https://en.wikipedia.org/wiki/Unified_field_theory> # Unified field theory (Thing)
# # <https://en.wikipedia.org/wiki/EPR_paradox> # EPR paradox (Thing)
# # <https://en.wikipedia.org/wiki/Ensemble_interpretation> # Ensemble interpretation (Thing)
# # <https://en.wikipedia.org/wiki/List_of_things_named_after_Albert_Einstein> # List of other concepts (Thing)
# # <https://en.wikipedia.org/wiki/Barnard_Medal_for_Meritorious_Service_to_Science> # Barnard Medal for Meritorious Service to Science (Thing)
# # <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics> # Nobel Prize in Physics (Thing)
# # <https://en.wikipedia.org/wiki/Matteucci_Medal> # Matteucci Medal (Thing)
# # <https://en.wikipedia.org/wiki/List_of_fellows_of_the_Royal_Society_elected_in_1921> # ForMemRS (Thing)
# # <https://en.wikipedia.org/wiki/Copley_Medal> # Copley Medal (Thing)
# #
# # Statements to convert (each has a unique ID you must include when emitting triples):
# # [1] In January 1896, [Albert Einstein](/wiki/Albert_Einstein) renounced his [citizenship of the German Kingdom of Württemberg](/wiki/German_citizenship) in order to avoid [conscription into military service](/wiki/Conscription_in_Germany).
# # [2] The *[Matura](/wiki/Matura)* (graduation for the successful completion of higher secondary schooling), awarded to [Albert Einstein](/wiki/Albert_Einstein) in September 1896, acknowledged him to have performed well across most of the curriculum.
# # [3] [Albert Einstein](/wiki/Albert_Einstein) was awarded a [top grade of 6](/wiki/Grading_systems_by_country) for history, physics, algebra, geometry, and descriptive geometry.
# # [4] At seventeen, [Albert Einstein](/wiki/Albert_Einstein) enrolled in the four-year mathematics and physics teaching diploma program at the [Swiss Federal Polytechnic School](/wiki/ETH_Zurich).
# # [5] [Albert Einstein](/wiki/Albert_Einstein) befriended fellow student [Marcel Grossmann](/wiki/Marcel_Grossmann), who helped him to get by despite his loose study habits.
# # [6] [Marcel Grossmann](/wiki/Marcel_Grossmann) helped [Albert Einstein](/wiki/Albert_Einstein) to mathematically underpin his revolutionary insights into physics.
# # [7] [Marie Winteler](/wiki/Marie_Winteler) was a year older than [Albert Einstein](/wiki/Albert_Einstein).
# # [8] [Marie Winteler](/wiki/Marie_Winteler) took up a teaching post in [Olsberg](/wiki/Olsberg%2C_Aargau), Switzerland.
# # [9] The five other polytechnic school freshmen following the same course as [Albert Einstein](/wiki/Albert_Einstein) included just one woman.
# # [10] The one woman among the five polytechnic school freshmen was a twenty-year-old [Serbian](/wiki/Serbs).
# # [11] The one woman among the five polytechnic school freshmen was [Mileva Marić](/wiki/Mileva_Mari%C4%87).
# # [12] [Albert Einstein](/wiki/Albert_Einstein) and [Mileva Marić](/wiki/Mileva_Mari%C4%87) spent many hours discussing their shared interests and learning about topics in physics that the polytechnic school's lectures did not cover.
# # [13] In his letters to [Mileva Marić](/wiki/Mileva_Mari%C4%87), [Albert Einstein](/wiki/Albert_Einstein) confessed that exploring science with her by his side was much more enjoyable than reading a textbook in solitude.
# # [14] [Albert Einstein](/wiki/Albert_Einstein) and [Mileva Marić](/wiki/Mileva_Mari%C4%87) became not only friends but also lovers.
# # [15] Historians of physics are divided on the question of the extent to which [Mileva Marić](/wiki/Mileva_Mari%C4%87) contributed to the insights of [Albert Einstein](/wiki/Albert_Einstein)'s *annus mirabilis* publications.
# # [16] There is at least some evidence that [Albert Einstein](/wiki/Albert_Einstein) was influenced by [Mileva Marić](/wiki/Mileva_Mari%C4%87)'s scientific ideas.
# # [17] There are scholars who doubt whether [Mileva Marić](/wiki/Mileva_Mari%C4%87)'s impact on [Albert Einstein](/wiki/Albert_Einstein)'s thought was of any great significance at all.
# #
# # IMPORTANT: Statements contain markdown links like [Entity](/wiki/Path). Convert these to Wikipedia URIs:
# # [Albert Einstein](/wiki/Albert_Einstein) → <https://en.wikipedia.org/wiki/Albert_Einstein>
# #
# # For EACH statement:
# # 1. Extract entity URIs from markdown links
# # 2. Look up appropriate schema.org classes and properties
# # 3. Emit triples using emit_triple or emit_triples, ALWAYS including the statement_id
# #
# # Process all statements, then provide a brief summary.
# #
# # === END PROMPT ===

# %% [raw]
# # Statement [7.1]: [Albert Einstein](/wiki/Albert_Einstein) was born in [Ulm](/wiki/Ulm).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:birthPlace <https://en.wikipedia.org/wiki/Ulm> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:birthPlace <https://en.wikipedia.org/wiki/Ulm> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdf:type schema:Person .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihyypzu5zu3w63bvclfsgnmfyb7bk3nteuhwazhic2sxzjep3b5pa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihyypzu5zu3w63bvclfsgnmfyb7bk3nteuhwazhic2sxzjep3b5pa",
#   "prov:label": "rdf:7_1",
#   "_cell": 239,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiau7no73cwq424hhiyt45jj5opq2sv7djwqiumy2t4qk6z53ev43a"
#   },
#   "_stmt_key": "7_1",
#   "_chunk_num": 7,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [7.2]: When [Albert Einstein](/wiki/Albert_Einstein) was five years old, he was sick in bed.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:lifeEvent "2"^^xsd:string .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic4yx2r6hgsuie2lf3nxottevemhyhbsopsceol2qmmw76hzfhk2u",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic4yx2r6hgsuie2lf3nxottevemhyhbsopsceol2qmmw76hzfhk2u",
#   "prov:label": "rdf:7_2",
#   "_cell": 241,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibfy2nmukhk3y3sj5tmqputpkcra3oazk7zglg3j6jf5uuohk4vmi"
#   },
#   "_stmt_key": "7_2",
#   "_chunk_num": 7,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [7.3]: [Albert Einstein](/wiki/Albert_Einstein)'s father brought him a [compass](/wiki/magnetic_compass) when he was five and sick in bed.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:lifeEvent "3"^^xsd:string .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifneojiwttecifvlqu7o6uifurx4j2pi2czudttv32xghv7mvi3he",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifneojiwttecifvlqu7o6uifurx4j2pi2czudttv32xghv7mvi3he",
#   "prov:label": "rdf:7_3",
#   "_cell": 243,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreie5d3iktqrir33e6gojkv4ydruegwb6cuy6ihn75fmctrtjcuyhaq"
#   },
#   "_stmt_key": "7_3",
#   "_chunk_num": 7,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [7.4]: The compass sparked [Albert Einstein](/wiki/Albert_Einstein)'s lifelong fascination with [electromagnetism](/wiki/electromagnetism).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:lifeEvent "4"^^xsd:string .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihjpkhlwgyy3ak7takmrcs6nlf34hz6lceeuaauucdychme4zoonq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihjpkhlwgyy3ak7takmrcs6nlf34hz6lceeuaauucdychme4zoonq",
#   "prov:label": "rdf:7_4",
#   "_cell": 245,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieolnrbkyysda3mvopwi6vh5s6xi4z5qdiudvr4pby3v2nmhvxedu"
#   },
#   "_stmt_key": "7_4",
#   "_chunk_num": 7,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [7.5]: [Albert Einstein](/wiki/Albert_Einstein) realized that "Something deeply hidden had to be behind things."
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:lifeEvent "5"^^xsd:string .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigfww2zygwtmojhzvjx5iywjx474yhwb5w2snamrwswnygp24kauq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigfww2zygwtmojhzvjx5iywjx474yhwb5w2snamrwswnygp24kauq",
#   "prov:label": "rdf:7_5",
#   "_cell": 247,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicrfu6q2js3ix6df4k3nbaxketdxrru6epfzwgabpovg2sarm2nze"
#   },
#   "_stmt_key": "7_5",
#   "_chunk_num": 7,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [7.6]: [Albert Einstein](/wiki/Albert_Einstein) attended St. Peter's [Catholic elementary school](/wiki/Catholic_school) in Munich.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Catholic_school> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiavb2hgqtbgfhiedq4zkyel4mhwpkh6ka5e6jwtkkkaygbdx27yqi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiavb2hgqtbgfhiedq4zkyel4mhwpkh6ka5e6jwtkkkaygbdx27yqi",
#   "prov:label": "rdf:7_6",
#   "_cell": 249,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifgbux2jpcevxgqym3d2u7wkkssboymcl6a4yhv42atdr2lpt2g64"
#   },
#   "_stmt_key": "7_6",
#   "_chunk_num": 7,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [7.7]: [Albert Einstein](/wiki/Albert_Einstein) attended St. Peter's [Catholic elementary school](/wiki/Catholic_school) from the age of five.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Catholic_school> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicjpxomsjsqs3qnka2kzgdj6mydwaem54ltwknjbdhv4wfsiffvmi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicjpxomsjsqs3qnka2kzgdj6mydwaem54ltwknjbdhv4wfsiffvmi",
#   "prov:label": "rdf:7_7",
#   "_cell": 251,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifexybmrdjfuocg6kqoslhypb6olodr2o7jso2cnykh4xzffsncb4"
#   },
#   "_stmt_key": "7_7",
#   "_chunk_num": 7,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [7.8]: When [Albert Einstein](/wiki/Albert_Einstein) was eight years old, he was transferred to the [Luitpold Gymnasium](/wiki/Luitpold_Gymnasium).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Luitpold_Gymnasium> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifcdsdl3v4n5bysih2jp7ersn6jjnqnideijsrh4fixvcyd4jgspy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifcdsdl3v4n5bysih2jp7ersn6jjnqnideijsrh4fixvcyd4jgspy",
#   "prov:label": "rdf:7_8",
#   "_cell": 253,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicwnw2n23pjxe4ypihelsvdghyo7gfusywfut2uesclfo5m2uzqki"
#   },
#   "_stmt_key": "7_8",
#   "_chunk_num": 7,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [7.9]: [Albert Einstein](/wiki/Albert_Einstein) received advanced primary and then secondary school education at the [Luitpold Gymnasium](/wiki/Luitpold_Gymnasium).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Luitpold_Gymnasium> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidcwnituusx2kzgk45nbykjxrzxomve3rdklos5nig4f4pbdxgiwq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidcwnituusx2kzgk45nbykjxrzxomve3rdklos5nig4f4pbdxgiwq",
#   "prov:label": "rdf:7_9",
#   "_cell": 255,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid5sdq23xbo3bdy5dyniebph3esdreuuecjqrpcgkjiel2niqqz2a"
#   },
#   "_stmt_key": "7_9",
#   "_chunk_num": 7,
#   "_stmt_idx": 9
# }
