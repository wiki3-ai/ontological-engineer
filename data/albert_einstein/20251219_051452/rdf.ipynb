# %% [markdown]
# # RDF Triples: Albert Einstein
#
# ## Provenance
#
# ```yaml
# source_url: https://en.wikipedia.org/wiki/Albert_Einstein
# article_title: Albert Einstein
# license: CC BY-SA 4.0
# license_url: https://creativecommons.org/licenses/by-sa/4.0/
# source_notebook: facts.ipynb
# generated_by: wiki_to_kg_pipeline.ipynb
# generated_at: 2025-12-19T05:16:08.529979
# llm_provider: lm_studio
# llm_model: qwen/qwen3-coder-30b
# llm_temperature: 1
# rdf_format: Turtle
# ```
#
# ## RDF Prefixes
#
# ```turtle
# @prefix schema: <https://schema.org/> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix wiki3: <https://wiki3.ai/vocab/> .
# @base <https://en.wikipedia.org/wiki/Albert_Einstein> .
#
# ```
#
# ## Processing Instructions
#
# This notebook contains RDF triples in Turtle format, one cell per source statement.
# Each content cell is followed by a signature cell with CID provenance.
#
# To regenerate a specific cell: delete both the content cell and its signature, then re-run the pipeline.
#
# ## Prompt Template
#
# ```
# You are an expert at converting factual statements to RDF triples in Turtle format.
#
# Convert the following factual statements to RDF using schema.org vocabulary where possible.
#
# Source: {source_url}
# Section: {breadcrumb}
#
# Use these prefixes:
# {prefixes}
#
# Entity registry (use these URIs):
# {entity_registry}
#
# Guidelines:
# - Use schema.org properties (schema:birthDate, schema:birthPlace, schema:worksFor, etc.)
# - For relationships not in schema.org, use wiki3: prefix
# - Include rdfs:label for entities
# - Use xsd datatypes for dates and numbers
# - Entity URIs should use the source URL as base with fragment identifiers
#
# ---
# {facts}
# ---
#
# Generate Turtle RDF:
#
# ```

# %% [raw]
# {
#   "source_url": "https://en.wikipedia.org/wiki/Albert_Einstein",
#   "entities": {
#     "albert_einstein": {
#       "id": "person_albert_einstein",
#       "uri": "https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein",
#       "label": "Albert Einstein",
#       "type": "Person",
#       "descriptions": [
#         "Subject of Wikipedia article: Albert Einstein"
#       ],
#       "source_chunks": [],
#       "aliases": [
#         "Einstein"
#       ]
#     }
#   },
#   "aliases": {
#     "einstein": "albert_einstein"
#   }
# }

# %% [raw]
# # Statement [1.1]: Albert Einstein was a German-born theoretical physicist.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Theoretical physicist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality <https://www.wikidata.org/wiki/Q183> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Theoretical physicist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality <https://www.wikidata.org/wiki/Q183> .

# %% [raw]
# {"cell": 2, "stmt_key": "1_1", "chunk_num": 1, "stmt_idx": 1, "type": "rdf", "cid": "57cfbccf8ffefc1ba0ab0205bc6899d578330503d7cb2d45b8e4940536d7ad4f", "from_cid": "79ba89701100776971220da0a401e76270f4532db3b9deab8c0e88a0437b851d"}

# %% [raw]
# # Statement [1.2]: Albert Einstein developed the theory of relativity.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "theory of relativity" .

# %% [raw]
# {"cell": 4, "stmt_key": "1_2", "chunk_num": 1, "stmt_idx": 2, "type": "rdf", "cid": "a4c646a2423da81009d647e8701fc91b3f7b539978f0b07276de94c5f6439165", "from_cid": "5a542422fdf3bf263b00a36289863a73f58394c193434857daa58f74eb30dd44"}

# %% [raw]
# # Statement [1.3]: Albert Einstein made important contributions to quantum theory.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "quantum theory" .

# %% [raw]
# {"cell": 6, "stmt_key": "1_3", "chunk_num": 1, "stmt_idx": 3, "type": "rdf", "cid": "318f4100966c750abf37889221626fdb9068ca5b31cdb6a07f7e8e10581d0b71", "from_cid": "a7df5ee100428ecc2acdd4a608f0e0584ccab7ea59105f16a0789e1f3896bd84"}

# %% [raw]
# # Statement [1.4]: Albert Einstein's mass–energy equivalence formula E = mc2 arises from special relativity.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "mass–energy equivalence" .

# %% [raw]
# {"cell": 8, "stmt_key": "1_4", "chunk_num": 1, "stmt_idx": 4, "type": "rdf", "cid": "e30cf41e0bf2136b1257823a5873b4fbb7518903444cb89ca8f3265b249f1651", "from_cid": "2b43ae873d4591a9b62c93928968870e4cb97819df5ec51fda774d549577ab95"}

# %% [raw]
# # Statement [1.5]: Albert Einstein received the 1921 Nobel Prize in Physics.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "1921 Nobel Prize in Physics" .

# %% [raw]
# {"cell": 10, "stmt_key": "1_5", "chunk_num": 1, "stmt_idx": 5, "type": "rdf", "cid": "1583f2d4808eaa97196fad7dab48d83c43f67ca04055fa443a125782ec7aef78", "from_cid": "ba22410f26b37c84173b8dae0e295dfe3b7cd6a033f147acaaf0b8b8cf904984"}

# %% [raw]
# # Statement [1.6]: Albert Einstein was born on 14 March 1879.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .

# %% [raw]
# {"cell": 12, "stmt_key": "1_6", "chunk_num": 1, "stmt_idx": 6, "type": "rdf", "cid": "17efd930824fefffd68fe09b73e08df7d00f5ca5292d0dbb7a4447ed0f7176fc", "from_cid": "cbabea9601d0b563c2b511c733d1ebc9339a9346cf2e62049c93fbebafe949e6"}

# %% [raw]
# # Statement [1.7]: Albert Einstein died on 18 April 1955.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 14, "stmt_key": "1_7", "chunk_num": 1, "stmt_idx": 7, "type": "rdf", "cid": "f2dc96f616747a9ab5885a91fbe5aa7f6feb115aa7f44de37c663c8bec825165", "from_cid": "b0e67f805f2eff1d2efaec2c0d0484e2afa7c3b1f224f3fb1993127adcaaf4ac"}

# %% [raw]
# # Statement [1.8]: Albert Einstein was a subject of the Kingdom of Württemberg.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality <https://www.wikidata.org/wiki/Q1053827> .

# %% [raw]
# {"cell": 16, "stmt_key": "1_8", "chunk_num": 1, "stmt_idx": 8, "type": "rdf", "cid": "5883d10a84cdf5e6fb10507e0bca8178f2b76814421c45c4be6f8cee807e919f", "from_cid": "2854db29b44aa8c2fad35bb9ced1c0b374d60663ed2073d862f38c7efac779a4"}

# %% [raw]
# # Statement [1.9]: Albert Einstein moved to Switzerland in 1895.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:residence <https://www.wikidata.org/wiki/Q1742> .

# %% [raw]
# {"cell": 18, "stmt_key": "1_9", "chunk_num": 1, "stmt_idx": 9, "type": "rdf", "cid": "3ac382e16c31c49d139569d72711ab76fb931cf518cba42b7567bb748e9ab60b", "from_cid": "e6dd13f285db88000a302238e410c5798980ef6f28365ef24e50ea61c422cc1f"}

# %% [raw]
# # Statement [1.10]: Albert Einstein forsake his German citizenship in 1896.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality <https://www.wikidata.org/wiki/Q183> .

# %% [raw]
# {"cell": 20, "stmt_key": "1_10", "chunk_num": 1, "stmt_idx": 10, "type": "rdf", "cid": "d7581184663a4b73cdc224b9f03b8dae9757169369465b3193b34c55881ef989", "from_cid": "40152d387ad1eae8b528599d12e84b81868984e9aa931350719019d44c61a76b"}

# %% [raw]
# # Statement [1.11]: Albert Einstein enrolled in the mathematics and physics teaching diploma program at the Swiss federal polytechnic school in Zurich in 1897.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <https://www.wikidata.org/wiki/Q107563> .

# %% [raw]
# {"cell": 22, "stmt_key": "1_11", "chunk_num": 1, "stmt_idx": 11, "type": "rdf", "cid": "6d053771c3d81daaebe07eff94a84c4d7118661e68565794d5101797360c5088", "from_cid": "0409c73184920d8f1832598b79d2f1cc46bfbbe88c48a726c62f69220a2d56d3"}

# %% [raw]
# # Statement [1.12]: Albert Einstein graduated from the Swiss federal polytechnic school in Zurich in 1900.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <https://www.wikidata.org/wiki/Q107563> .

# %% [raw]
# {"cell": 24, "stmt_key": "1_12", "chunk_num": 1, "stmt_idx": 12, "type": "rdf", "cid": "61f7c9818c5ed380fe612eef51a056ad153fd861165c2b9f29e7e8df9ea429f6", "from_cid": "962dafb0bb954624e68d5421a3aea727531eb4da7fff1721b26bd8f0c0aef630"}

# %% [raw]
# # Statement [1.13]: Albert Einstein acquired Swiss citizenship in 1898.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality <https://www.wikidata.org/wiki/Q1742> .

# %% [raw]
# {"cell": 26, "stmt_key": "1_13", "chunk_num": 1, "stmt_idx": 13, "type": "rdf", "cid": "a9907f5b3d3db5e811d6c7fdfaa0c14357e6fa07285bcf1ef131a56237fc9433", "from_cid": "2d75bc8815c7dd177225c0c99e5fd073f8b583b60aaabec2f3af1aeebd4411bd"}

# %% [raw]
# # Statement [1.14]: Albert Einstein worked at the Swiss Patent Office in Bern.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <https://www.wikidata.org/wiki/Q152037> .

# %% [raw]
# {"cell": 28, "stmt_key": "1_14", "chunk_num": 1, "stmt_idx": 14, "type": "rdf", "cid": "13fffb832a5d9d3b5040f8f5e95e5fc763e1641ce3dfa24e1fa195e063b83a93", "from_cid": "1d1882ee24a5bfe147e8a6bad797b17541a7c15cd584ab6ec7197205800fce98"}

# %% [raw]
# # Statement [1.15]: Albert Einstein submitted a successful PhD dissertation to the University of Zurich in 1905.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "PhD" .

# %% [raw]
# {"cell": 30, "stmt_key": "1_15", "chunk_num": 1, "stmt_idx": 15, "type": "rdf", "cid": "cd9a98791fb5dc8f6de36c934010664e5df0fdc743946d98ae2aceaecdd289ab", "from_cid": "c95389c3206d9b257889549163faf02ad23086a96bd892ba35fc63501b3911de"}

# %% [raw]
# # Statement [1.16]: Albert Einstein moved to Berlin in 1914.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:residence <https://www.wikidata.org/wiki/Q1741> .

# %% [raw]
# {"cell": 32, "stmt_key": "1_16", "chunk_num": 1, "stmt_idx": 16, "type": "rdf", "cid": "7139e70db71b69915d3bc2580bfef1581069dd64ae83da955ffa23e90a8d9250", "from_cid": "39ddc4b533bcfd8dc14dfe0df9f40a1381b5c6ad91e603c8880243f5d2d73635"}

# %% [raw]
# # Statement [1.17]: Albert Einstein joined the Prussian Academy of Sciences in 1914.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:memberOf <https://www.wikidata.org/wiki/Q162705> .

# %% [raw]
# {"cell": 34, "stmt_key": "1_17", "chunk_num": 1, "stmt_idx": 17, "type": "rdf", "cid": "a5418e6e527fb178344cb82d473a06abf08dad6c9d4df0dc780678986befba9b", "from_cid": "31c9dd638470030ee5635805c7a4b847204a3e5cf363f35271450d02e74e7bbe"}

# %% [raw]
# # Statement [1.18]: Albert Einstein joined the Humboldt University of Berlin in 1914.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <https://www.wikidata.org/wiki/Q162705> .

# %% [raw]
# {"cell": 36, "stmt_key": "1_18", "chunk_num": 1, "stmt_idx": 18, "type": "rdf", "cid": "60272ad4d741d08ab5fdf5c356f3fd9ed4e582a661dbc7eb4e070bf1ec127477", "from_cid": "c0e2e677cd5d9ba6476f2d60315dcc6a9e444a766d6024ae17f8aa0d9a07cd47"}

# %% [raw]
# # Statement [1.19]: Albert Einstein became director of the Kaiser Wilhelm Institute for Physics in 1917.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor <https://www.wikidata.org/wiki/Q251924> .

# %% [raw]
# {"cell": 38, "stmt_key": "1_19", "chunk_num": 1, "stmt_idx": 19, "type": "rdf", "cid": "1dd8b209184d10a2a314e42ea431d4dadf01468b442b78d1f97e6d486413f35b", "from_cid": "b3797409272e0dc442a144b19eebee58b44806c1ba907f727b66340ee081a8f7"}

# %% [raw]
# # Statement [1.20]: Albert Einstein became a subject of the Kingdom of Prussia in 1914.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality <https://www.wikidata.org/wiki/Q183> .

# %% [raw]
# {"cell": 40, "stmt_key": "1_20", "chunk_num": 1, "stmt_idx": 20, "type": "rdf", "cid": "21bf0f799f977bec8be0219d1eff564bdbb2f06c11ae1e07a180fa55c123bdf9", "from_cid": "7a072cc16d27bf569714f137738b887f05c5324c95fd645b8210c40f64c4c8e3"}

# %% [raw]
# # Statement [1.21]: Adolf Hitler came to power in Germany in 1933.
# <https://www.wikidata.org/wiki/Q134870> schema:startDate "1933-01-01"^^xsd:date .

# %% [raw]
# {"cell": 42, "stmt_key": "1_21", "chunk_num": 1, "stmt_idx": 21, "type": "rdf", "cid": "e3ab9081ee0573c226d87a3441ccc7e140e15df0b77cfc5521868c743db602d3", "from_cid": "327c9e3d0fe188f5459b89ed3a262698267c91f99cf9e20d7450a112820badaf"}

# %% [raw]
# # Statement [1.22]: Albert Einstein was visiting the United States in 1933.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:residence <https://www.wikidata.org/wiki/Q1742> .

# %% [raw]
# {"cell": 44, "stmt_key": "1_22", "chunk_num": 1, "stmt_idx": 22, "type": "rdf", "cid": "d859ee2469c41edf90d7ce6663ca55eddef5d146b65625954fd3df64510f1b6f", "from_cid": "975a7140245ff451fb59c5a1ba8760915d48880d9451ec81f3b58765dd813d25"}

# %% [raw]
# # Statement [1.23]: Albert Einstein decided to remain in the United States in 1933.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:residence <https://www.wikidata.org/wiki/Q1742> .

# %% [raw]
# {"cell": 46, "stmt_key": "1_23", "chunk_num": 1, "stmt_idx": 23, "type": "rdf", "cid": "2feb83b4d857345d547bb72ef73b3ab779643c3ce0ba5d941cd951419aa2d66c", "from_cid": "81d420f2062e790719ed4d2c6b14b5fc6747a70a808baa89ce8df9d99e112a9c"}

# %% [raw]
# # Statement [1.24]: Albert Einstein was granted American citizenship in 1940.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality <https://www.wikidata.org/wiki/Q1742> .

# %% [raw]
# {"cell": 48, "stmt_key": "1_24", "chunk_num": 1, "stmt_idx": 24, "type": "rdf", "cid": "37944a8207efb9c4cc98bba0713857319bf4f3f0eb334502db2436bf00b2de1d", "from_cid": "20cdbe7d7f4b31ec70f00be952d6ab4553819258d741c22d7bf28d5750f79a0c"}

# %% [raw]
# # Statement [1.25]: Albert Einstein endorsed a letter to President Franklin D. Roosevelt in 1939.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Letter to President Franklin D. Roosevelt" .

# %% [raw]
# {"cell": 50, "stmt_key": "1_25", "chunk_num": 1, "stmt_idx": 25, "type": "rdf", "cid": "cf1aec61d4f95af77fa1afa336304dba53515aaf88226baa83d2205c8ad69fb1", "from_cid": "f35920481868d3d63a1f593d0c63829d140d3040018dd677100dfd6ead5dc536"}

# %% [raw]
# # Statement [1.26]: President Franklin D. Roosevelt was alerted to the potential German nuclear weapons program by Albert Einstein in 1939.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Alert to President Franklin D. Roosevelt" .

# %% [raw]
# {"cell": 52, "stmt_key": "1_26", "chunk_num": 1, "stmt_idx": 26, "type": "rdf", "cid": "8659f43db25a9161f5f8a648e4046b358511bcc0bd37c6a2b6043a87e7ffe156", "from_cid": "0215b53dfbaa68c601f564fe80d639e96876b0f66894af459f87759fdd0b5b2d"}

# %% [raw]
# # Statement [1.27]: Albert Einstein recommended that the United States begin nuclear weapons research in 1939.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasCredential "Recommendation for Nuclear Weapons Research" .

# %% [raw]
# {"cell": 54, "stmt_key": "1_27", "chunk_num": 1, "stmt_idx": 27, "type": "rdf", "cid": "92dadb466f5b09853a449391520add6ca81239d00f56de4b74e54e133f3dd761", "from_cid": "a01d7ab277f97391151796f3a4f0eaa77ad31bbbde9b4d3e9144a380bae02dc6"}

# %% [raw]
# # Statement [1.28]: The Manhattan Project was carried out as a result of Albert Einstein's recommendation in 1939.
# <https://www.wikidata.org/wiki/Q162705> schema:hasCredential "Manhattan Project" .

# %% [raw]
# {"cell": 56, "stmt_key": "1_28", "chunk_num": 1, "stmt_idx": 28, "type": "rdf", "cid": "9b4db7854df89e0d112316ae7fcc10869c845fdd57a98dbb3a9584cb66bfcbe3", "from_cid": "68122621b2933b8ff45902945044480235f6f9e24d35d5cc5162c7e12354a8ba"}

# %% [raw]
# # Statement [2.1]: In 1905, Albert Einstein published four groundbreaking papers.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 58, "stmt_key": "2_1", "chunk_num": 2, "stmt_idx": 1, "type": "rdf", "cid": "9cbc3c5abd3c994c4dddc316dbe24bbbbe51f0bef8097849774ef0935f684c18", "from_cid": "52aebc9b4189f97c550fcbbf3abcbcba988ec838d8839219d4deaa94731af088"}

# %% [raw]
# # Statement [2.2]: In 1905, the year 1905 is sometimes described as Albert Einstein's annus mirabilis.
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 60, "stmt_key": "2_2", "chunk_num": 2, "stmt_idx": 2, "type": "rdf", "cid": "b3bfe008db3b23e6db5446f4dfb9ccce1e96aca3cf9ef0601460b29e164d987d", "from_cid": "cccad7767947d604ff638b76c2f604f29691f342a6bf373ca969bdae4efbff79"}

# %% [raw]
# # Statement [2.3]: In 1905, Albert Einstein outlined a theory of the photoelectric effect in one of his four groundbreaking papers.
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 62, "stmt_key": "2_3", "chunk_num": 2, "stmt_idx": 3, "type": "rdf", "cid": "eeb090bbdff3dd11e58b6ec32933297a73a4c8f9316b6838c397ea37b6e34401", "from_cid": "c68616c53b7f4727af62c9b8263b111c63a8dc3358ca99e0df81861ab5d79848"}

# %% [raw]
# # Statement [2.4]: In 1905, Albert Einstein explained Brownian motion in one of his four groundbreaking papers.
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 64, "stmt_key": "2_4", "chunk_num": 2, "stmt_idx": 4, "type": "rdf", "cid": "f210dc7be2c9ec9cc924e527b286cfbf4e154ff0a3cb2ea3a92a5dbbfa23240d", "from_cid": "0c81644710a0ad4f6cf8a86df050fdf25e6be1a919aef944c44e573118f42f32"}

# %% [raw]
# # Statement [2.5]: In 1905, Albert Einstein introduced his special theory of relativity in one of his four groundbreaking papers.
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 66, "stmt_key": "2_5", "chunk_num": 2, "stmt_idx": 5, "type": "rdf", "cid": "ff0d1de229eae7657e0214676ce80c484932c6284a4a7210e9957158b83ff8a6", "from_cid": "913f0fb315cbd90ff49868d0a9d0f7610f95566168f3ae0bbe70d7384ffe8584"}

# %% [raw]
# # Statement [2.6]: In 1905, Albert Einstein demonstrated that if the special theory of relativity is correct, mass and energy are equivalent to each other in one of his four groundbreaking papers.
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 68, "stmt_key": "2_6", "chunk_num": 2, "stmt_idx": 6, "type": "rdf", "cid": "978b9f59ca659a5e6e88453a35d9df37c06a06374d47f9186da44fc4305d9643", "from_cid": "b8bad36ce7ec5c0cec623422aaa6a617903ddc718795082b1cd9cbb412eb6d12"}

# %% [raw]
# # Statement [2.7]: In 1915, Albert Einstein proposed a general theory of relativity.
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 70, "stmt_key": "2_7", "chunk_num": 2, "stmt_idx": 7, "type": "rdf", "cid": "b67aff70a47bc98e4d05ebfaa1e289608a8c1699cefcbb4afa34146aa87e7cab", "from_cid": "5694ca4ce8df6fb1cfaf4534d3d38f1e9a226dd869fc8482e8940b5572c00e58"}

# %% [raw]
# # Statement [2.8]: In 1915, the general theory of relativity proposed by Albert Einstein extended his system of mechanics to incorporate gravitation.
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 72, "stmt_key": "2_8", "chunk_num": 2, "stmt_idx": 8, "type": "rdf", "cid": "50dad59698da434f1ed665771fcd4b5aacf903cd84ff623dbbf93a84747097af", "from_cid": "17c401b1740150f00576f7138c4c1a4cc41ae0cd94de70c6ec87c1ca82530f3a"}

# %% [raw]
# # Statement [2.9]: In 1916, Albert Einstein published a paper that laid out the implications of general relativity for the modeling of the structure and evolution of the universe as a whole.
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 74, "stmt_key": "2_9", "chunk_num": 2, "stmt_idx": 9, "type": "rdf", "cid": "d38ca4aa8d7523b7ebfd970da492f8b43bc0aae5f70d3f5a5da1807bc0a28807", "from_cid": "adf7708c3ae9ffd5139a597f5fbb7e70224e95fd22c69468cae41a07b8e06a0b"}

# %% [raw]
# # Statement [2.10]: In 1916, the paper published by Albert Einstein introduced the cosmological constant.
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 76, "stmt_key": "2_10", "chunk_num": 2, "stmt_idx": 10, "type": "rdf", "cid": "da6e15888c66f90704d083c3a516144b4e280f654d3ab8792f721498441b4a14", "from_cid": "82c120ff291e4d91f34addd3a16dd7583dc1325bbfa0948afef033c04742a968"}

# %% [raw]
# # Statement [2.11]: In 1916, the paper published by Albert Einstein is regarded as the first step in the field of modern theoretical cosmology.
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 78, "stmt_key": "2_11", "chunk_num": 2, "stmt_idx": 11, "type": "rdf", "cid": "6893142ca0843d542d6eb33d80fcd8343270a80510429726117fe6d65f958140", "from_cid": "c01aa9a7daad7bfedd48329a762d176b730f49003b847e55379b62482f1f7ce3"}

# %% [raw]
# # Statement [2.12]: In 1917, Albert Einstein wrote a paper that introduced the concepts of spontaneous emission and stimulated emission.
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 80, "stmt_key": "2_12", "chunk_num": 2, "stmt_idx": 12, "type": "rdf", "cid": "4bed03690da255aadf545ca324fae401cf43c8ed71a57f1c89cad2ae6716f523", "from_cid": "c27cd85911d5354f37aec8cc9961f913f9eb20a3a2e2769ea3ec7530df20c000"}

# %% [raw]
# # Statement [2.13]: In 1917, the concept of stimulated emission introduced by Albert Einstein is the core mechanism behind the laser and maser.
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 82, "stmt_key": "2_13", "chunk_num": 2, "stmt_idx": 13, "type": "rdf", "cid": "3c821c0a2d9bbe40ef27fee196b554366d3e8e0838dcbe2af9715e65f19d1f4f", "from_cid": "e393c57c4adca99119a2b71b081b767ad040fca127ca9f0c8b7d7f3052e5c6f7"}

# %% [raw]
# # Statement [2.14]: In 1917, the paper written by Albert Einstein contained information beneficial to developments in physics later on such as quantum electrodynamics and quantum optics.
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 84, "stmt_key": "2_14", "chunk_num": 2, "stmt_idx": 14, "type": "rdf", "cid": "9ccabe845c93078836b6418f361f9ffbbc945f307461315483aad120ba510675", "from_cid": "4839a17f2ddc44928529a4e016f9ec8f40f98e6284470fec0c74849da799ddfb"}

# %% [raw]
# # Statement [2.15]: During the middle part of his career, Albert Einstein made important contributions to statistical mechanics.
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 86, "stmt_key": "2_15", "chunk_num": 2, "stmt_idx": 15, "type": "rdf", "cid": "b5d032846a0de6075af2a3db669554bbda3cdcefd86c9f49d9736661e32ca8fc", "from_cid": "2462a14a78fcd12ba729ce612378affdbfbb56b0218bd240ed217ca132afee07"}

# %% [raw]
# # Statement [2.16]: During the middle part of his career, Albert Einstein made important contributions to quantum theory.
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 88, "stmt_key": "2_16", "chunk_num": 2, "stmt_idx": 16, "type": "rdf", "cid": "f81d5b8eca43ed347c63861b79b48d1327f82caeb57cf4cf185e0a2f4619d028", "from_cid": "0dc59ed95f4666e62191b74abe1bccd2de0f4d55307a9a36acfb1a29706ee81a"}

# %% [raw]
# # Statement [2.17]: Especially notable during the middle part of his career was Albert Einstein's work on the quantum physics of radiation.
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 90, "stmt_key": "2_17", "chunk_num": 2, "stmt_idx": 17, "type": "rdf", "cid": "0ece394bd735888492e0ba71249ca66e650ba994d52be4290fb2832cf1eec61e", "from_cid": "a3a51a4fb15b71a5adb42b2405aaed0ccdc0ecd163e7e28a055ec31a22f51958"}

# %% [raw]
# # Statement [2.18]: In his work on the quantum physics of radiation, Albert Einstein stated that light consists of particles.
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 92, "stmt_key": "2_18", "chunk_num": 2, "stmt_idx": 18, "type": "rdf", "cid": "63a2d2b31c2957c9356a35790603e503dafa11f1513516251398b2aacb5d6a65", "from_cid": "e1832a01328fdb8dd6d4bf2c98501b84284e391c2544b6acdff33e64e5f6e574"}

# %% [raw]
# # Statement [2.19]: These particles subsequently called photons were part of Albert Einstein's work on the quantum physics of radiation.
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 94, "stmt_key": "2_19", "chunk_num": 2, "stmt_idx": 19, "type": "rdf", "cid": "326f762bd8ca98b925098d15d4d459c7ce3b968ac5ada3731d9b5f0c29c1e7ba", "from_cid": "1e52d1ffd842e7525af6b1a65a2195ecbf5f7146ab81b2a47cab98694d0b831a"}

# %% [raw]
# # Statement [2.20]: With physicist Satyendra Nath Bose, Albert Einstein laid the groundwork for Bose–Einstein statistics.
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 96, "stmt_key": "2_20", "chunk_num": 2, "stmt_idx": 20, "type": "rdf", "cid": "43207bbc06b0c0d64b65e795e2fa2919128e02c188aa6992b00f5885b056cbba", "from_cid": "3cdcff155ec77ba551701e5d19cc8d47d12a7b4786382c61f53e40f4504adf3b"}

# %% [raw]
# # Statement [2.21]: For much of the last phase of his academic life, Albert Einstein worked on two endeavors.
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 98, "stmt_key": "2_21", "chunk_num": 2, "stmt_idx": 21, "type": "rdf", "cid": "6e1e554f0a5ca951462b475f1772846e5766780adcd015237877b7301a8c84c3", "from_cid": "38771dc4e412974b90668a454c8024a6f6ffad87e7866ab9f5fe8cbe1e5ad031"}

# %% [raw]
# # Statement [2.22]: The first endeavor that Albert Einstein advocated against was quantum theory's introduction of fundamental randomness into science's picture of the world.
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 100, "stmt_key": "2_22", "chunk_num": 2, "stmt_idx": 22, "type": "rdf", "cid": "d4a6a1a3642646ec763cb49bee0688a1f9054a5425aeef48dd39d02cf6005e10", "from_cid": "79ba848b54aa7e25998e37ab9fa590627c49c0c1b68fc8d4507222d71b613d12"}

# %% [raw]
# # Statement [2.23]: Albert Einstein objected to quantum theory's introduction of fundamental randomness by stating that "God does not play dice".
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 102, "stmt_key": "2_23", "chunk_num": 2, "stmt_idx": 23, "type": "rdf", "cid": "715f039437ff81dbe28739994cbca4ccddd969fc55784329a0b551abca5e8d48", "from_cid": "c5f35ff6bdfc6db197970c5b3391987cb02b6d389acdce9812e5202a868dc0a3"}

# %% [raw]
# # Statement [2.24]: The second endeavor that Albert Einstein attempted was to devise a unified field theory.
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 104, "stmt_key": "2_24", "chunk_num": 2, "stmt_idx": 24, "type": "rdf", "cid": "a9786e3422742fa2d393f1904afd29ae3ecbaa6e587acd02515b023a7dbfa4de", "from_cid": "9ec009f4da32da0639047b63299012bfa197e46eaeaab025a3968c7fdf8ef4cb"}

# %% [raw]
# # Statement [2.25]: Albert Einstein's attempt to devise a unified field theory involved generalizing his geometric theory of gravitation to include electromagnetism.
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 106, "stmt_key": "2_25", "chunk_num": 2, "stmt_idx": 25, "type": "rdf", "cid": "392fa07e892bc0241a3d6f939afa16d343e343ba41582f1ddc9bac2d64e27fec", "from_cid": "cdaf1ffb3189f36c66f91e49b929d06c84fc61898961e7d7372a60dff38e5080"}

# %% [raw]
# # Statement [2.26]: As a result of his efforts, Albert Einstein became increasingly isolated from mainstream modern physics.
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:hasOccupation "scientist" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" rdf:type schema:Person .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:name "Albert Einstein" .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:birthDate "1879-03-14"^^xsd:date .
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 108, "stmt_key": "2_26", "chunk_num": 2, "stmt_idx": 26, "type": "rdf", "cid": "e1f1995c220494d89e7053ef786efb53eeda2f764ae3b468f010569431872a49", "from_cid": "41219624042ef6ac1198694d8f8dbe938ac750a4740a6f4708e1c838cda52618"}
