# %% [markdown]
# # RDF Triples: Albert Einstein
#
# ## Provenance
#
# ```yaml
# source_url: https://en.wikipedia.org/wiki/Albert_Einstein
# article_title: Albert Einstein
# license: CC BY-SA 4.0
# license_url: https://creativecommons.org/licenses/by-sa/4.0/
# source_notebook: facts.ipynb
# generated_by: wiki_to_kg_pipeline.ipynb
# generated_at: 2025-12-19T08:17:31.187713
# llm_provider: lm_studio
# llm_model: qwen/qwen3-coder-30b
# llm_temperature: 1
# rdf_format: Turtle
# ```
#
# ## RDF Prefixes
#
# ```turtle
# @prefix schema: <https://schema.org/> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix wiki3: <https://wiki3.ai/vocab/> .
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix repro: <https://w3id.org/reproduceme#> .
# @prefix pplan: <http://purl.org/net/p-plan#> .
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @base <https://en.wikipedia.org/wiki/Albert_Einstein> .
#
# ```
#
# ## Processing Instructions
#
# This notebook contains RDF triples in Turtle format, one cell per source statement.
# Each content cell is followed by a signature cell with CID provenance.
#
# To regenerate a specific cell: delete both the content cell and its signature, then re-run the pipeline.
#
# ## Prompt Template
#
# ```
# You are an expert at converting factual statements to RDF triples in Turtle format.
#
# Convert the following factual statements to RDF using schema.org vocabulary where possible.
#
# Source: {source_url}
# Section: {breadcrumb}
#
# Use these prefixes:
# {prefixes}
#
# Entity registry (use these URIs):
# {entity_registry}
#
# Guidelines:
# - Use schema.org properties (schema:birthDate, schema:birthPlace, schema:worksFor, etc.)
# - For relationships not in schema.org, use wiki3: prefix
# - Include rdfs:label for entities
# - Use xsd datatypes for dates and numbers
# - Entity URIs should use the source URL as base with fragment identifiers
#
# ---
# {facts}
# ---
#
# Generate Turtle RDF:
#
# ```

# %% [raw]
# {
#   "source_url": "https://en.wikipedia.org/wiki/Albert_Einstein",
#   "entities": {
#     "albert_einstein": {
#       "id": "person_albert_einstein",
#       "uri": "https://en.wikipedia.org/wiki/Albert_Einstein",
#       "label": "Albert Einstein",
#       "type": "Person",
#       "descriptions": [
#         "Subject of Wikipedia article: Albert Einstein"
#       ],
#       "source_chunks": [],
#       "aliases": [
#         "Einstein"
#       ],
#       "wikidata_id": "Q937"
#     },
#     "ulm": {
#       "id": "thing_ulm",
#       "uri": "https://en.wikipedia.org/wiki/Ulm",
#       "label": "Ulm",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Ulm"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "kingdom_of_w_rttemberg": {
#       "id": "thing_kingdom_of_w_rttemberg",
#       "uri": "https://en.wikipedia.org/wiki/Kingdom_of_W%C3%BCrttemberg",
#       "label": "Kingdom of W\u00fcrttemberg",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Kingdom of W\u00fcrttemberg"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "german_empire": {
#       "id": "thing_german_empire",
#       "uri": "https://en.wikipedia.org/wiki/German_Empire",
#       "label": "German Empire",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: German Empire"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "princeton_new_jersey": {
#       "id": "thing_princeton_new_jersey",
#       "uri": "https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey",
#       "label": "Princeton, New Jersey",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Princeton, New Jersey"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "lieserl": {
#       "id": "thing_lieserl",
#       "uri": "https://en.wikipedia.org/wiki/Lieserl_Einstein",
#       "label": "Lieserl",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Lieserl"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "hans_albert": {
#       "id": "thing_hans_albert",
#       "uri": "https://en.wikipedia.org/wiki/Hans_Albert_Einstein",
#       "label": "Hans Albert",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Hans Albert"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "eduard_tete": {
#       "id": "thing_eduard_tete",
#       "uri": "https://en.wikipedia.org/wiki/Einstein_family",
#       "label": "Eduard \"Tete\"",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Eduard \"Tete\""
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "einstein": {
#       "id": "thing_einstein",
#       "uri": "https://en.wikipedia.org/wiki/Einstein_family",
#       "label": "Einstein",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Einstein"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "mileva_mari": {
#       "id": "thing_mileva_mari",
#       "uri": "https://en.wikipedia.org/wiki/Mileva_Mari%C4%87",
#       "label": "Mileva Mari\u0107",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Mileva Mari\u0107"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "elsa_l_wenthal": {
#       "id": "thing_elsa_l_wenthal",
#       "uri": "https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal",
#       "label": "Elsa L\u00f6wenthal",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Elsa L\u00f6wenthal"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "stateless": {
#       "id": "thing_stateless",
#       "uri": "https://en.wikipedia.org/wiki/Statelessness",
#       "label": "Stateless",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Stateless"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "switzerland": {
#       "id": "thing_switzerland",
#       "uri": "https://en.wikipedia.org/wiki/Switzerland",
#       "label": "Switzerland",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Switzerland"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "kingdom_of_prussia": {
#       "id": "thing_kingdom_of_prussia",
#       "uri": "https://en.wikipedia.org/wiki/Kingdom_of_Prussia",
#       "label": "Kingdom of Prussia",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Kingdom of Prussia"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "free_state_of_prussia": {
#       "id": "thing_free_state_of_prussia",
#       "uri": "https://en.wikipedia.org/wiki/Free_State_of_Prussia",
#       "label": "Free State of Prussia",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Free State of Prussia"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "weimar_republic": {
#       "id": "thing_weimar_republic",
#       "uri": "https://en.wikipedia.org/wiki/Weimar_Republic",
#       "label": "Weimar Republic",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Weimar Republic"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "united_states": {
#       "id": "thing_united_states",
#       "uri": "https://en.wikipedia.org/wiki/Citizenship_of_the_United_States",
#       "label": "United States",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: United States"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "physics": {
#       "id": "thing_physics",
#       "uri": "https://en.wikipedia.org/wiki/Physics",
#       "label": "Physics",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Physics"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "university_of_bern": {
#       "id": "thing_university_of_bern",
#       "uri": "https://en.wikipedia.org/wiki/University_of_Bern",
#       "label": "University of Bern",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: University of Bern"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "university_of_zurich": {
#       "id": "thing_university_of_zurich",
#       "uri": "https://en.wikipedia.org/wiki/University_of_Zurich",
#       "label": "University of Zurich",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: University of Zurich"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "charles_university_in_prague": {
#       "id": "thing_charles_university_in_prague",
#       "uri": "https://en.wikipedia.org/wiki/Charles_University_in_Prague",
#       "label": "Charles University in Prague",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Charles University in Prague"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "eth_zurich": {
#       "id": "thing_eth_zurich",
#       "uri": "https://en.wikipedia.org/wiki/ETH_Zurich",
#       "label": "ETH Zurich",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: ETH Zurich"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "prussian_academy_of_sciences": {
#       "id": "thing_prussian_academy_of_sciences",
#       "uri": "https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences",
#       "label": "Prussian Academy of Sciences",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Prussian Academy of Sciences"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "humboldt_university_of_berlin": {
#       "id": "thing_humboldt_university_of_berlin",
#       "uri": "https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin",
#       "label": "Humboldt University of Berlin",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Humboldt University of Berlin"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "kaiser_wilhelm_institute": {
#       "id": "thing_kaiser_wilhelm_institute",
#       "uri": "https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute",
#       "label": "Kaiser Wilhelm Institute",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Kaiser Wilhelm Institute"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "german_physical_society": {
#       "id": "thing_german_physical_society",
#       "uri": "https://en.wikipedia.org/wiki/German_Physical_Society",
#       "label": "German Physical Society",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: German Physical Society"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "institute_for_advanced_study": {
#       "id": "thing_institute_for_advanced_study",
#       "uri": "https://en.wikipedia.org/wiki/Institute_for_Advanced_Study",
#       "label": "Institute for Advanced Study",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Institute for Advanced Study"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "swiss_federal_polytechnic_school": {
#       "id": "thing_swiss_federal_polytechnic_school",
#       "uri": "https://en.wikipedia.org/wiki/ETH_Zurich",
#       "label": "Swiss Federal Polytechnic School",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Swiss Federal Polytechnic School"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "phd": {
#       "id": "thing_phd",
#       "uri": "https://en.wikipedia.org/wiki/PhD",
#       "label": "PhD",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: PhD"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "alfred_kleiner": {
#       "id": "thing_alfred_kleiner",
#       "uri": "https://en.wikipedia.org/wiki/Alfred_Kleiner",
#       "label": "Alfred Kleiner",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Alfred Kleiner"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "heinrich_friedrich_weber": {
#       "id": "thing_heinrich_friedrich_weber",
#       "uri": "https://en.wikipedia.org/wiki/Heinrich_Friedrich_Weber",
#       "label": "Heinrich Friedrich Weber",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Heinrich Friedrich Weber"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "general_relativity": {
#       "id": "thing_general_relativity",
#       "uri": "https://en.wikipedia.org/wiki/General_relativity",
#       "label": "General relativity",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: General relativity"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "special_relativity": {
#       "id": "thing_special_relativity",
#       "uri": "https://en.wikipedia.org/wiki/Special_relativity",
#       "label": "Special relativity",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Special relativity"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "photoelectric_effect": {
#       "id": "thing_photoelectric_effect",
#       "uri": "https://en.wikipedia.org/wiki/Photoelectric_effect",
#       "label": "Photoelectric effect",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Photoelectric effect"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "e_mc_sup_2_sup_mass_energy_equivalence": {
#       "id": "thing_e_mc_sup_2_sup_mass_energy_equivalence",
#       "uri": "https://en.wikipedia.org/wiki/Mass%E2%80%93energy_equivalence",
#       "label": "''E''=''mc''<sup>2</sup> (mass\u2013energy equivalence)",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: ''E''=''mc''<sup>2</sup> (mass\u2013energy equivalence)"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "e_hf_planck_einstein_relation": {
#       "id": "thing_e_hf_planck_einstein_relation",
#       "uri": "https://en.wikipedia.org/wiki/Planck%E2%80%93Einstein_relation",
#       "label": "''E''=''hf'' (Planck\u2013Einstein relation)",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: ''E''=''hf'' (Planck\u2013Einstein relation)"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "theory_of_brownian_motion": {
#       "id": "thing_theory_of_brownian_motion",
#       "uri": "https://en.wikipedia.org/wiki/Brownian_motion",
#       "label": "Theory of Brownian motion",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Theory of Brownian motion"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "einstein_field_equations": {
#       "id": "thing_einstein_field_equations",
#       "uri": "https://en.wikipedia.org/wiki/Einstein_field_equations",
#       "label": "Einstein field equations",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Einstein field equations"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "bose_einstein_statistics": {
#       "id": "thing_bose_einstein_statistics",
#       "uri": "https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_statistics",
#       "label": "Bose\u2013Einstein statistics",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Bose\u2013Einstein statistics"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "bose_einstein_condensate": {
#       "id": "thing_bose_einstein_condensate",
#       "uri": "https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_condensate",
#       "label": "Bose\u2013Einstein condensate",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Bose\u2013Einstein condensate"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "gravitational_wave": {
#       "id": "thing_gravitational_wave",
#       "uri": "https://en.wikipedia.org/wiki/Gravitational_wave",
#       "label": "Gravitational wave",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Gravitational wave"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "cosmological_constant": {
#       "id": "thing_cosmological_constant",
#       "uri": "https://en.wikipedia.org/wiki/Cosmological_constant",
#       "label": "Cosmological constant",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Cosmological constant"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "unified_field_theory": {
#       "id": "thing_unified_field_theory",
#       "uri": "https://en.wikipedia.org/wiki/Unified_field_theory",
#       "label": "Unified field theory",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Unified field theory"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "epr_paradox": {
#       "id": "thing_epr_paradox",
#       "uri": "https://en.wikipedia.org/wiki/EPR_paradox",
#       "label": "EPR paradox",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: EPR paradox"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "ensemble_interpretation": {
#       "id": "thing_ensemble_interpretation",
#       "uri": "https://en.wikipedia.org/wiki/Ensemble_interpretation",
#       "label": "Ensemble interpretation",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Ensemble interpretation"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "list_of_other_concepts": {
#       "id": "thing_list_of_other_concepts",
#       "uri": "https://en.wikipedia.org/wiki/List_of_things_named_after_Albert_Einstein",
#       "label": "List of other concepts",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: List of other concepts"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "barnard_medal_for_meritorious_service_to_science": {
#       "id": "thing_barnard_medal_for_meritorious_service_to_science",
#       "uri": "https://en.wikipedia.org/wiki/Barnard_Medal_for_Meritorious_Service_to_Science",
#       "label": "Barnard Medal for Meritorious Service to Science",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Barnard Medal for Meritorious Service to Science"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "nobel_prize_in_physics": {
#       "id": "thing_nobel_prize_in_physics",
#       "uri": "https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics",
#       "label": "Nobel Prize in Physics",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Nobel Prize in Physics"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "matteucci_medal": {
#       "id": "thing_matteucci_medal",
#       "uri": "https://en.wikipedia.org/wiki/Matteucci_Medal",
#       "label": "Matteucci Medal",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Matteucci Medal"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "formemrs": {
#       "id": "thing_formemrs",
#       "uri": "https://en.wikipedia.org/wiki/List_of_fellows_of_the_Royal_Society_elected_in_1921",
#       "label": "ForMemRS",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: ForMemRS"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "copley_medal": {
#       "id": "thing_copley_medal",
#       "uri": "https://en.wikipedia.org/wiki/Copley_Medal",
#       "label": "Copley Medal",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Copley Medal"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     }
#   },
#   "aliases": {
#     "einstein": "albert_einstein"
#   }
# }

# %% [raw]
# # Statement [1.1]: [Albert Einstein](/wiki/Albert_Einstein) was born on 14 March 1879.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/birthDate "1879-03-14"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiblwlymbl6coy63hveizhqaq6emnjm4qufhkdodzvpuu6aypkrcru",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiblwlymbl6coy63hveizhqaq6emnjm4qufhkdodzvpuu6aypkrcru",
#   "prov:label": "rdf:1_1",
#   "_cell": 2,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiazipa5t2o64vc2ckcsdd4w6e777giy7qp2zobg6dkbeutvmevxaq"
#   },
#   "_stmt_key": "1_1",
#   "_chunk_num": 1,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [1.2]: [Albert Einstein](/wiki/Albert_Einstein) was born in [Ulm](/wiki/Ulm).
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/birthPlace https://en.wikipedia.org/wiki/Ulm .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidbrdk3u72t4yax475op7avnaniywp75cfhwi3eisekxxna5aul2u",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidbrdk3u72t4yax475op7avnaniywp75cfhwi3eisekxxna5aul2u",
#   "prov:label": "rdf:1_2",
#   "_cell": 4,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiau7no73cwq424hhiyt45jj5opq2sv7djwqiumy2t4qk6z53ev43a"
#   },
#   "_stmt_key": "1_2",
#   "_chunk_num": 1,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [1.3]: [Ulm](/wiki/Ulm) was part of the [Kingdom of Württemberg](/wiki/Kingdom_of_W%C3%BCrttemberg) in 1879.
# https://en.wikipedia.org/wiki/Ulm https://schema.org/isPartOf https://en.wikipedia.org/wiki/Kingdom_of_Württemberg .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidvd6n46am2e37bjvihhofwlm7ekuhmwpnxaduw4zl6txlmytifoa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidvd6n46am2e37bjvihhofwlm7ekuhmwpnxaduw4zl6txlmytifoa",
#   "prov:label": "rdf:1_3",
#   "_cell": 6,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieuqw7ig4lrd4a2gwprtoxpdg42hkthjfl2yzd5sxemqhac7vwtky"
#   },
#   "_stmt_key": "1_3",
#   "_chunk_num": 1,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [1.4]: [Kingdom of Württemberg](/wiki/Kingdom_of_W%C3%BCrttemberg) was part of the [German Empire](/wiki/German_Empire) in 1879.
# https://en.wikipedia.org/wiki/Kingdom_of_Württemberg https://schema.org/isPartOf https://en.wikipedia.org/wiki/German_Empire .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigiryukg6m2ceuh66zvzugzvpgeuyjfolgbqqxnzwyebue7aiotr4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigiryukg6m2ceuh66zvzugzvpgeuyjfolgbqqxnzwyebue7aiotr4",
#   "prov:label": "rdf:1_4",
#   "_cell": 8,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiexjczrokij73nscv3l7ql4pvdajad7j7tiihajfkoncdtfvhdz7m"
#   },
#   "_stmt_key": "1_4",
#   "_chunk_num": 1,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [1.5]: [Albert Einstein](/wiki/Albert_Einstein) died on 18 April 1955.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic2aivijdbuyuuqf3bdrfilgjo57whocetpx57qqg673v4d5swvha",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic2aivijdbuyuuqf3bdrfilgjo57whocetpx57qqg673v4d5swvha",
#   "prov:label": "rdf:1_5",
#   "_cell": 10,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidvirzqgvtd4hdgwas4svphoo5x2sjxtb2fx3alguyqqeu5cixh74"
#   },
#   "_stmt_key": "1_5",
#   "_chunk_num": 1,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [1.6]: [Albert Einstein](/wiki/Albert_Einstein) died in [Princeton, New Jersey](/wiki/Princeton%2C_New_Jersey).
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/deathPlace https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifsj7mx3olhv4he6ti2sq62il6btduu7ocinjfxjpkpdl6dcodzcy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifsj7mx3olhv4he6ti2sq62il6btduu7ocinjfxjpkpdl6dcodzcy",
#   "prov:label": "rdf:1_6",
#   "_cell": 12,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidk667javbq3mkzsfuzstlsvi2cfatpvw54qn2yluoqqn4onnr4oy"
#   },
#   "_stmt_key": "1_6",
#   "_chunk_num": 1,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [1.7]: [Princeton, New Jersey](/wiki/Princeton%2C_New_Jersey) is located in the U.S.
# https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey https://schema.org/isPartOf https://en.wikipedia.org/wiki/United_States .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigz2caqrgqmn5ul4kevso4y5i2kkt7yaakc2efxn6xpbhwuddlroq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigz2caqrgqmn5ul4kevso4y5i2kkt7yaakc2efxn6xpbhwuddlroq",
#   "prov:label": "rdf:1_7",
#   "_cell": 14,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifly53udoithlcme3onyu7o6sjpyiw6x5miegdevjzfplfakhidg4"
#   },
#   "_stmt_key": "1_7",
#   "_chunk_num": 1,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [1.8]: [Albert Einstein](/wiki/Albert_Einstein) had children named [Lieserl](/wiki/Lieserl_Einstein), [Hans Albert](/wiki/Hans_Albert_Einstein), and [Eduard "Tete"](/wiki/Einstein_family).
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/children https://en.wikipedia.org/wiki/Lieserl_Einstein .
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/children https://en.wikipedia.org/wiki/Hans_Albert_Einstein .
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/children https://en.wikipedia.org/wiki/Einstein_family .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibv673thviyi6nms7ghleugbee42aithlo7zs5r7xrywpvglpo5tu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibv673thviyi6nms7ghleugbee42aithlo7zs5r7xrywpvglpo5tu",
#   "prov:label": "rdf:1_8",
#   "_cell": 16,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib6awwfpi4dummayaaoeybviodmjffq6rtels2hgjxyv6m6xa54mq"
#   },
#   "_stmt_key": "1_8",
#   "_chunk_num": 1,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [1.9]: [Albert Einstein](/wiki/Albert_Einstein) was a member of the [Einstein](/wiki/Einstein_family) family.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/familyName "Einstein" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieoswyyde6nmyoaadlskuilqfr2shnwtlnlotomgwibetfcupt6zy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieoswyyde6nmyoaadlskuilqfr2shnwtlnlotomgwibetfcupt6zy",
#   "prov:label": "rdf:1_9",
#   "_cell": 18,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihxembw7hqhg7cnns4zf3beh2ei2xahagqfxbz2vwyvn5vzv6mjae"
#   },
#   "_stmt_key": "1_9",
#   "_chunk_num": 1,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [1.10]: [Albert Einstein](/wiki/Albert_Einstein) held citizenship in the [Kingdom of Württemberg](/wiki/Kingdom_of_W%C3%BCrttemberg) until 1896.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/nationality https://en.wikipedia.org/wiki/Kingdom_of_Württemberg .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic25wqjrjxppue6f6tgmw5vauua6dghbuzgdjc7j7pliip2hyhquq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic25wqjrjxppue6f6tgmw5vauua6dghbuzgdjc7j7pliip2hyhquq",
#   "prov:label": "rdf:1_10",
#   "_cell": 20,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifuz6yqh35prrdikwq4uf7s27s3xbsuy26tiasltslxxnz6hj2kom"
#   },
#   "_stmt_key": "1_10",
#   "_chunk_num": 1,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [1.11]: [Albert Einstein](/wiki/Albert_Einstein) was stateless from 1896 to 1901.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/nationality https://en.wikipedia.org/wiki/Statelessness .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifh3pwbzadcnhue5ubvmmfrvmlcklge5b7zmlgv7tokqkd37253hy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifh3pwbzadcnhue5ubvmmfrvmlcklge5b7zmlgv7tokqkd37253hy",
#   "prov:label": "rdf:1_11",
#   "_cell": 22,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiciy7ragz5ltuoxscmmtkqeeza2g252h53i5kamsm74kxli2s6bqm"
#   },
#   "_stmt_key": "1_11",
#   "_chunk_num": 1,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [1.12]: [Albert Einstein](/wiki/Albert_Einstein) held citizenship in [Switzerland](/wiki/Switzerland) from 1901 to 1955.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/nationality https://en.wikipedia.org/wiki/Switzerland .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihqc3mv5olzrcx3cexltngkk5qhbmfqcjkoicniphqkrsrbbspgy4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihqc3mv5olzrcx3cexltngkk5qhbmfqcjkoicniphqkrsrbbspgy4",
#   "prov:label": "rdf:1_12",
#   "_cell": 24,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib2nmb3gssp2pivcgvfbaufezr2cn5hbs5lq35alutemaj3qcykjm"
#   },
#   "_stmt_key": "1_12",
#   "_chunk_num": 1,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [1.13]: [Albert Einstein](/wiki/Albert_Einstein) held citizenship in the [Kingdom of Prussia](/wiki/Kingdom_of_Prussia) from 1914 to 1918.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/nationality https://en.wikipedia.org/wiki/Kingdom_of_Prussia .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreih2lcxhydsgrug2nxmsofh3bxpd3r4tewqfujv5vz6wunxjhjohpa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreih2lcxhydsgrug2nxmsofh3bxpd3r4tewqfujv5vz6wunxjhjohpa",
#   "prov:label": "rdf:1_13",
#   "_cell": 26,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreienrdehun4qxy3f44kbwnf3zftfnft4r3j4wd5bhexlkgtfc74iny"
#   },
#   "_stmt_key": "1_13",
#   "_chunk_num": 1,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [1.14]: [Albert Einstein](/wiki/Albert_Einstein) held citizenship in the [Free State of Prussia](/wiki/Free_State_of_Prussia) during the [Weimar Republic](/wiki/Weimar_Republic) from 1918 to 1933.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/nationality https://en.wikipedia.org/wiki/Free_State_of_Prussia .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiduzv5g5i4g4d4eupn66grw7s5trknoi37ayjbsn5wwvjrnleeclq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiduzv5g5i4g4d4eupn66grw7s5trknoi37ayjbsn5wwvjrnleeclq",
#   "prov:label": "rdf:1_14",
#   "_cell": 28,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigdp2tugtvhdc43xiejvilkdnsju5oremx4lfokugcnssirxsuene"
#   },
#   "_stmt_key": "1_14",
#   "_chunk_num": 1,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [1.15]: [Albert Einstein](/wiki/Albert_Einstein) held citizenship in the [United States](/wiki/Citizenship_of_the_United_States) from 1940 to 1955.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/nationality https://en.wikipedia.org/wiki/Citizenship_of_the_United_States .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiexictu2m4bqw6nho5f4dwo54iuvvds2dttajn3pf4htiiihjiyz4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiexictu2m4bqw6nho5f4dwo54iuvvds2dttajn3pf4htiiihjiyz4",
#   "prov:label": "rdf:1_15",
#   "_cell": 30,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreic23253sveexcmmjogwfix3v4g5m5ojqxngls4pqa6x66oumrg2xy"
#   },
#   "_stmt_key": "1_15",
#   "_chunk_num": 1,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [1.16]: [Albert Einstein](/wiki/Albert_Einstein) worked at the [University of Bern](/wiki/University_of_Bern) from 1908 to 1909.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/worksFor _:pos1 .
# _:pos1 rdf:type schema:OrganizationRole .
# _:pos1 schema:worksFor https://en.wikipedia.org/wiki/University_of_Bern .
# _:pos1 schema:startDate "1908"^^xsd:gYear .
# _:pos1 schema:endDate "1909"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibrulskdgs6gierdbrhnqclb6vlggf6agavm55wdxgnbe2zhx36bm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibrulskdgs6gierdbrhnqclb6vlggf6agavm55wdxgnbe2zhx36bm",
#   "prov:label": "rdf:1_16",
#   "_cell": 32,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreievsu6eosthqzmazj4sfknkarbsvijrqgzdanpsx3lkarrr242ewe"
#   },
#   "_stmt_key": "1_16",
#   "_chunk_num": 1,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [1.17]: [Albert Einstein](/wiki/Albert_Einstein) worked at the [University of Zurich](/wiki/University_of_Zurich) from 1909 to 1911.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/worksFor _:pos2 .
# _:pos2 rdf:type schema:OrganizationRole .
# _:pos2 schema:worksFor https://en.wikipedia.org/wiki/University_of_Zurich .
# _:pos2 schema:startDate "1909"^^xsd:gYear .
# _:pos2 schema:endDate "1911"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia3lidzycne4v2pfcvz7cxpfw5ekhglwbwmj2fzixhba6kp5swcxe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia3lidzycne4v2pfcvz7cxpfw5ekhglwbwmj2fzixhba6kp5swcxe",
#   "prov:label": "rdf:1_17",
#   "_cell": 34,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibd6sh22uermut67lsw6s6jadpbxqiexjzydw5epocy7bmubz5wvm"
#   },
#   "_stmt_key": "1_17",
#   "_chunk_num": 1,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [1.18]: [Albert Einstein](/wiki/Albert_Einstein) worked at the [Charles University in Prague](/wiki/Charles_University_in_Prague) from 1911 to 1912.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/worksFor _:pos3 .
# _:pos3 rdf:type schema:OrganizationRole .
# _:pos3 schema:worksFor https://en.wikipedia.org/wiki/Charles_University_in_Prague .
# _:pos3 schema:startDate "1911"^^xsd:gYear .
# _:pos3 schema:endDate "1912"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidto4ivvrglxnahwn2prmikpznekkns3xd54a4lvq3z3r3aezduvi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidto4ivvrglxnahwn2prmikpznekkns3xd54a4lvq3z3r3aezduvi",
#   "prov:label": "rdf:1_18",
#   "_cell": 36,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaugnblj22tuzxd6s3eovwvmfmpbnjmjtzls6gv6dfrysjjvhrybi"
#   },
#   "_stmt_key": "1_18",
#   "_chunk_num": 1,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [1.19]: [Albert Einstein](/wiki/Albert_Einstein) worked at the [ETH Zurich](/wiki/ETH_Zurich) from 1912 to 1914.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/worksFor _:pos4 .
# _:pos4 rdf:type schema:OrganizationRole .
# _:pos4 schema:worksFor https://en.wikipedia.org/wiki/ETH_Zurich .
# _:pos4 schema:startDate "1912"^^xsd:gYear .
# _:pos4 schema:endDate "1914"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreih6yyblatksl7jfufea75q7fvssbesybkryxzaxdfyfchn2pqoypa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreih6yyblatksl7jfufea75q7fvssbesybkryxzaxdfyfchn2pqoypa",
#   "prov:label": "rdf:1_19",
#   "_cell": 38,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreie7ijfd6tvojhdhwrbmtg2rkomifdmggoopwdtzkv3mfl6rx2cxsy"
#   },
#   "_stmt_key": "1_19",
#   "_chunk_num": 1,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Statement [1.20]: [Albert Einstein](/wiki/Albert_Einstein) worked at the [Prussian Academy of Sciences](/wiki/Prussian_Academy_of_Sciences) from 1914 to 1933.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/worksFor _:pos5 .
# _:pos5 rdf:type schema:OrganizationRole .
# _:pos5 schema:worksFor https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences .
# _:pos5 schema:startDate "1914"^^xsd:gYear .
# _:pos5 schema:endDate "1933"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigmhyo5iejenvg3ktvl7f6sujubgppwbkz2uzl7aorp3ahqae5oum",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigmhyo5iejenvg3ktvl7f6sujubgppwbkz2uzl7aorp3ahqae5oum",
#   "prov:label": "rdf:1_20",
#   "_cell": 40,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieuzhirqwnwqt6uxodkadpb4ui6ppxqxpuil45kvjgce2htor2x2m"
#   },
#   "_stmt_key": "1_20",
#   "_chunk_num": 1,
#   "_stmt_idx": 20
# }

# %% [raw]
# # Statement [1.21]: [Albert Einstein](/wiki/Albert_Einstein) worked at the [Humboldt University of Berlin](/wiki/Humboldt_University_of_Berlin) from 1914 to 1933.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/worksFor _:pos6 .
# _:pos6 rdf:type schema:OrganizationRole .
# _:pos6 schema:worksFor https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin .
# _:pos6 schema:startDate "1914"^^xsd:gYear .
# _:pos6 schema:endDate "1933"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibci7xljll4bqonvrvyaurlaxlb3maueiewanqncqks3qrqmunqp4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibci7xljll4bqonvrvyaurlaxlb3maueiewanqncqks3qrqmunqp4",
#   "prov:label": "rdf:1_21",
#   "_cell": 42,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid5ueqjvtimgxqwov25wtne4mpl7gxqtv723drcsa4k2mvpizuj3m"
#   },
#   "_stmt_key": "1_21",
#   "_chunk_num": 1,
#   "_stmt_idx": 21
# }

# %% [raw]
# # Statement [1.22]: [Albert Einstein](/wiki/Albert_Einstein) was director of the [Kaiser Wilhelm Institute](/wiki/Kaiser_Wilhelm_Institute) from 1917 to 1933.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/worksFor _:pos7 .
# _:pos7 rdf:type schema:OrganizationRole .
# _:pos7 schema:worksFor https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute .
# _:pos7 schema:startDate "1917"^^xsd:gYear .
# _:pos7 schema:endDate "1933"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieeqfc2hk35pjtzmfwkt474hrq2mju2djlq3sjnngxi37734zn6ia",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieeqfc2hk35pjtzmfwkt474hrq2mju2djlq3sjnngxi37734zn6ia",
#   "prov:label": "rdf:1_22",
#   "_cell": 44,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia3bor2octlztb4os2ufesjewu64v65wpn5vsyeiiocsxuigwjdba"
#   },
#   "_stmt_key": "1_22",
#   "_chunk_num": 1,
#   "_stmt_idx": 22
# }

# %% [raw]
# # Statement [1.23]: [Albert Einstein](/wiki/Albert_Einstein) was president of the [German Physical Society](/wiki/German_Physical_Society) from 1916 to 1918.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/worksFor _:pos8 .
# _:pos8 rdf:type schema:OrganizationRole .
# _:pos8 schema:worksFor https://en.wikipedia.org/wiki/German_Physical_Society .
# _:pos8 schema:startDate "1916"^^xsd:gYear .
# _:pos8 schema:endDate "1918"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaikbu2qzgktg4opsrqh6pjvufybmdnz2ennjfod6xr5vcan2ibya",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaikbu2qzgktg4opsrqh6pjvufybmdnz2ennjfod6xr5vcan2ibya",
#   "prov:label": "rdf:1_23",
#   "_cell": 46,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreics635ncl6bxd3zn6ijx3r2efwdj7zh5wxwc4hdvddurn4cnbr3aa"
#   },
#   "_stmt_key": "1_23",
#   "_chunk_num": 1,
#   "_stmt_idx": 23
# }

# %% [raw]
# # Statement [1.24]: [Albert Einstein](/wiki/Albert_Einstein) worked at the [Institute for Advanced Study](/wiki/Institute_for_Advanced_Study) from 1933 to 1955.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/worksFor _:pos9 .
# _:pos9 rdf:type schema:OrganizationRole .
# _:pos9 schema:worksFor https://en.wikipedia.org/wiki/Institute_for_Advanced_Study .
# _:pos9 schema:startDate "1933"^^xsd:gYear .
# _:pos9 schema:endDate "1955"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiegtlb4qqfihxnueglsm3htkblh7qbtlsufyikkm5oivozqaqgtme",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiegtlb4qqfihxnueglsm3htkblh7qbtlsufyikkm5oivozqaqgtme",
#   "prov:label": "rdf:1_24",
#   "_cell": 48,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiezpofe4w54wfzsee2nzz6fjqlxej4bca5d7rqrftoqryv46j6e5e"
#   },
#   "_stmt_key": "1_24",
#   "_chunk_num": 1,
#   "_stmt_idx": 24
# }

# %% [raw]
# # Statement [1.25]: [Albert Einstein](/wiki/Albert_Einstein) studied at the [Swiss Federal Polytechnic School](/wiki/ETH_Zurich) and earned a teaching diploma in 1900.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/alumniOf https://en.wikipedia.org/wiki/ETH_Zurich .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiavccrpnij5c7eraxwtwfiiuj5fvdutbk3zr7pwi5qsxre5irnnea",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiavccrpnij5c7eraxwtwfiiuj5fvdutbk3zr7pwi5qsxre5irnnea",
#   "prov:label": "rdf:1_25",
#   "_cell": 50,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifgcbw7ymol2rue7b7k5imtvwd7agvj74k5tws265ovutkcuflsfq"
#   },
#   "_stmt_key": "1_25",
#   "_chunk_num": 1,
#   "_stmt_idx": 25
# }

# %% [raw]
# # Statement [1.26]: [Albert Einstein](/wiki/Albert_Einstein) studied at the [University of Zurich](/wiki/University_of_Zurich) and earned a [PhD](/wiki/PhD) in 1905.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/alumniOf https://en.wikipedia.org/wiki/University_of_Zurich .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiafsjnozrppotfm6ezj35gicy2imbs4bgtnyfgsrp2cnqsdrfpfzi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiafsjnozrppotfm6ezj35gicy2imbs4bgtnyfgsrp2cnqsdrfpfzi",
#   "prov:label": "rdf:1_26",
#   "_cell": 52,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidailn7tv6jmp6m2ttwats7s3xifftca4oix7gjnh3ilki67paixe"
#   },
#   "_stmt_key": "1_26",
#   "_chunk_num": 1,
#   "_stmt_idx": 26
# }

# %% [raw]
# # Statement [1.27]: [Albert Einstein](/wiki/Albert_Einstein)'s doctoral advisor was [Alfred Kleiner](/wiki/Alfred_Kleiner).
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/advisor https://en.wikipedia.org/wiki/Alfred_Kleiner .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieyfocrt4tt5d4nc6v7f6mr5zyvwoktpbc3kgxjo7uksabkabg6b4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieyfocrt4tt5d4nc6v7f6mr5zyvwoktpbc3kgxjo7uksabkabg6b4",
#   "prov:label": "rdf:1_27",
#   "_cell": 54,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihpnwx2bbsrqmqnk3snspvjaylxtv7coq3kysdvns5jh3z32h4qgq"
#   },
#   "_stmt_key": "1_27",
#   "_chunk_num": 1,
#   "_stmt_idx": 27
# }

# %% [raw]
# # Statement [1.28]: [Albert Einstein](/wiki/Albert_Einstein) was a physicist.
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/jobTitle "Physicist" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiez7cqsheja3vsla4a6pszmpagnbmabduiod3j6waoh4iwxh5xqs4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiez7cqsheja3vsla4a6pszmpagnbmabduiod3j6waoh4iwxh5xqs4",
#   "prov:label": "rdf:1_28",
#   "_cell": 56,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigzlqmngwxellt5ygi2oseo74oyukj7hqpldshkx63dc2rpdlflu4"
#   },
#   "_stmt_key": "1_28",
#   "_chunk_num": 1,
#   "_stmt_idx": 28
# }

# %% [raw]
# # Statement [1.29]: [Albert Einstein](/wiki/Albert_Einstein) made significant contributions to the field of [Physics](/wiki/Physics).
# https://en.wikipedia.org/wiki/Albert_Einstein https://schema.org/knowsAbout https://en.wikipedia.org/wiki/Physics .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigpr5fdbwwdltpijshr4pe2jweiwwk2lqrsnrrlwa3347uf2vxh5m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigpr5fdbwwdltpijshr4pe2jweiwwk2lqrsnrrlwa3347uf2vxh5m",
#   "prov:label": "rdf:1_29",
#   "_cell": 58,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreig2zz723uk7qnpfsinin37rzhz4jr5utv4jeyfm6flptg3247nnce"
#   },
#   "_stmt_key": "1_29",
#   "_chunk_num": 1,
#   "_stmt_idx": 29
# }

# %% [raw]
# # Statement [2.1]: [Albert Einstein](/wiki/Albert_Einstein) was advised by [Alfred Kleiner](/wiki/Alfred_Kleiner) for his doctoral studies.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:advisor <https://en.wikipedia.org/wiki/Alfred_Kleiner> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreig6ufgzzqn4t67dretjjlr665azfxvkqarc2nxkir3pklxoygvp7i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreig6ufgzzqn4t67dretjjlr665azfxvkqarc2nxkir3pklxoygvp7i",
#   "prov:label": "rdf:2_1",
#   "_cell": 60,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihrvmlnmrrytxy5rouf2httae6uczl3f3olkhxniz2olv5sfas4ee"
#   },
#   "_stmt_key": "2_1",
#   "_chunk_num": 2,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [2.2]: [Albert Einstein](/wiki/Albert_Einstein) was advised by [Heinrich Friedrich Weber](/wiki/Heinrich_Friedrich_Weber) for his doctoral studies.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:advisor <https://en.wikipedia.org/wiki/Heinrich_Friedrich_Weber> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreih774d7scwxccfchqx6gzw625jqtl4sauf5u465go5xflairskrpm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreih774d7scwxccfchqx6gzw625jqtl4sauf5u465go5xflairskrpm",
#   "prov:label": "rdf:2_2",
#   "_cell": 62,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifuylff6dqmgx4in6ms7r2jkqs6c2ytr7hixipzciirym3dihllla"
#   },
#   "_stmt_key": "2_2",
#   "_chunk_num": 2,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [2.3]: [Albert Einstein](/wiki/Albert_Einstein) wrote the thesis titled "Eine neue Bestimmung der Moleküldimensionen" in 1905.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:thesis <#thesis_1905> .
# <#thesis_1905> rdf:type schema:Thesis .
# <#thesis_1905> schema:title "Eine neue Bestimmung der Moleküldimensionen" .
# <#thesis_1905> schema:datePublished "1905"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieixzvxlcgdymhjnte3bqgn6qclemh6p23xxrtuiz2s5t7x6bf4om",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieixzvxlcgdymhjnte3bqgn6qclemh6p23xxrtuiz2s5t7x6bf4om",
#   "prov:label": "rdf:2_3",
#   "_cell": 64,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib4zaan56wm7eprs4p4jes4vdcrtz7qgprayq4l6tjyq56bszleai"
#   },
#   "_stmt_key": "2_3",
#   "_chunk_num": 2,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [2.4]: [Albert Einstein](/wiki/Albert_Einstein) is known for [General relativity](/wiki/General_relativity).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/General_relativity> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieafwqu272guowvymg6xeu27y5vtigtncekmnubvip5eqcrbdtt6y",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieafwqu272guowvymg6xeu27y5vtigtncekmnubvip5eqcrbdtt6y",
#   "prov:label": "rdf:2_4",
#   "_cell": 66,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicu3uak66xavhj7ne76tu2prpniqxpv73nmob7xxobqkvjftkwkgi"
#   },
#   "_stmt_key": "2_4",
#   "_chunk_num": 2,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [2.5]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Special relativity](/wiki/Special_relativity).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Special_relativity> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie7pf7254tpns2ceog2mudg2bg2jxawwk3g4pfrqca3n4h4mswp7q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie7pf7254tpns2ceog2mudg2bg2jxawwk3g4pfrqca3n4h4mswp7q",
#   "prov:label": "rdf:2_5",
#   "_cell": 68,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiagxfrb22mjhekk6pyjkg4n4rqkw6nrc46ccf72puoooadjp3skre"
#   },
#   "_stmt_key": "2_5",
#   "_chunk_num": 2,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [2.6]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Photoelectric effect](/wiki/Photoelectric_effect).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Photoelectric_effect> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiacuk2zomhcfqhfvqez2omhvvem4z7jyjpxeu5aud66t3hspu4pne",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiacuk2zomhcfqhfvqez2omhvvem4z7jyjpxeu5aud66t3hspu4pne",
#   "prov:label": "rdf:2_6",
#   "_cell": 70,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifaxsyobkrqvmesrh2rtvc2ynjkdtdecuq5w742unnwyydvtcbudu"
#   },
#   "_stmt_key": "2_6",
#   "_chunk_num": 2,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [2.7]: [Albert Einstein](/wiki/Albert_Einstein) is known for [''E''=''mc''<sup>2</sup> (mass–energy equivalence)](/wiki/Mass%E2%80%93energy_equivalence).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Mass%E2%80%93energy_equivalence> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreib3da2hyjlgb3kuul3vsfympvjgqjleppe7u2kdmdwvfjgpeufupa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreib3da2hyjlgb3kuul3vsfympvjgqjleppe7u2kdmdwvfjgpeufupa",
#   "prov:label": "rdf:2_7",
#   "_cell": 72,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicuagvycaq6pwvw6tilzqlemxepyqi2visziaoxx2pid6jbwpvx3a"
#   },
#   "_stmt_key": "2_7",
#   "_chunk_num": 2,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [2.8]: [Albert Einstein](/wiki/Albert_Einstein) is known for [''E''=''hf'' (Planck–Einstein relation)](/wiki/Planck%E2%80%93Einstein_relation).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Planck%E2%80%93Einstein_relation> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiakfm6zlwpodsywzxqzue3lyke7fg6qb45qf6j44sc7tati7gifom",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiakfm6zlwpodsywzxqzue3lyke7fg6qb45qf6j44sc7tati7gifom",
#   "prov:label": "rdf:2_8",
#   "_cell": 74,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiflyw2xzfu5mtm2kannkgqzwzzambi5nzv7pvt2gvx5a4oitngmn4"
#   },
#   "_stmt_key": "2_8",
#   "_chunk_num": 2,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [2.9]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Theory of Brownian motion](/wiki/Brownian_motion).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Brownian_motion> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicifxxghmu6e24p7gtnqodfaj2x7bogblcccs4zeyzktycjuqtpm4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicifxxghmu6e24p7gtnqodfaj2x7bogblcccs4zeyzktycjuqtpm4",
#   "prov:label": "rdf:2_9",
#   "_cell": 76,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigcppcp6zphwdqruwi2nhleq4jp67bluezfla7jz7uls7mi3iij7q"
#   },
#   "_stmt_key": "2_9",
#   "_chunk_num": 2,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [2.10]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Einstein field equations](/wiki/Einstein_field_equations).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Einstein_field_equations> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaedzofeerwxb477qbqo2zdn6n4pm3yxywppvj7mrk4dtyner2z7q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaedzofeerwxb477qbqo2zdn6n4pm3yxywppvj7mrk4dtyner2z7q",
#   "prov:label": "rdf:2_10",
#   "_cell": 78,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifehzyxbzedtcfsyr676smhvjrymohsdvze3vcmntsjap6nc3sspa"
#   },
#   "_stmt_key": "2_10",
#   "_chunk_num": 2,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [2.11]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Bose–Einstein statistics](/wiki/Bose%E2%80%93Einstein_statistics).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_statistics> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic2eo2qysl6mlk2ullxy43ooszrxh4xcjbkknmfqwwxsd74heltii",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic2eo2qysl6mlk2ullxy43ooszrxh4xcjbkknmfqwwxsd74heltii",
#   "prov:label": "rdf:2_11",
#   "_cell": 80,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaj5u7xholi3snu3cmehhfpj3h7uzdluba3npjpuy2f4hr7glaejm"
#   },
#   "_stmt_key": "2_11",
#   "_chunk_num": 2,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [2.12]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Bose–Einstein condensate](/wiki/Bose%E2%80%93Einstein_condensate).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_condensate> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifb6x5w44qif2a5wuswert5c5ldjm7uzoi7d2e52eabe2hpf5h4ji",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifb6x5w44qif2a5wuswert5c5ldjm7uzoi7d2e52eabe2hpf5h4ji",
#   "prov:label": "rdf:2_12",
#   "_cell": 82,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreielxmnpz766h4zqpovoax3cvnbxybajthd6gk3cn5cfaomlbrdqnq"
#   },
#   "_stmt_key": "2_12",
#   "_chunk_num": 2,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [2.13]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Gravitational wave](/wiki/Gravitational_wave).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Gravitational_wave> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigmr7fumafuhdymkfctlrimbil5pxmpc3sku6nfpkp4zi67x2ntni",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigmr7fumafuhdymkfctlrimbil5pxmpc3sku6nfpkp4zi67x2ntni",
#   "prov:label": "rdf:2_13",
#   "_cell": 84,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiatvzjbjzxzbtc2e7hg3gw752lexqmq2bnhebt4b2acu7eniv7k3i"
#   },
#   "_stmt_key": "2_13",
#   "_chunk_num": 2,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [2.14]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Cosmological constant](/wiki/Cosmological_constant).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Cosmological_constant> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigj65o2oifznhr2wyybxznjfrcqxd3vnpzz7rjuaq2z4skukzupwm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigj65o2oifznhr2wyybxznjfrcqxd3vnpzz7rjuaq2z4skukzupwm",
#   "prov:label": "rdf:2_14",
#   "_cell": 86,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiezea3u4gvpuq7sys3cyhyfce6wpgrcn7scjxezhiwxt3s2ba6b2a"
#   },
#   "_stmt_key": "2_14",
#   "_chunk_num": 2,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [2.15]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Unified field theory](/wiki/Unified_field_theory).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Unified_field_theory> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidxzgkm73wt46aifaz24iny2e7ng5bgdhpzmutvi6mfpyyty4vemq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidxzgkm73wt46aifaz24iny2e7ng5bgdhpzmutvi6mfpyyty4vemq",
#   "prov:label": "rdf:2_15",
#   "_cell": 88,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiewdffpjayuf5brypv5hwzf6f3tzg32sn3gvw3pg2kul4gt7v5vxu"
#   },
#   "_stmt_key": "2_15",
#   "_chunk_num": 2,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [2.16]: [Albert Einstein](/wiki/Albert_Einstein) is known for [EPR paradox](/wiki/EPR_paradox).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/EPR_paradox> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidc652ibakaiiomo7ymjdobxzs3q6zw6q4conqjn673rhjyruf2sq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidc652ibakaiiomo7ymjdobxzs3q6zw6q4conqjn673rhjyruf2sq",
#   "prov:label": "rdf:2_16",
#   "_cell": 90,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid6zg4j57b74owvy5phc3muafiv7qyqpovwdegyd5apabj2p7nqyq"
#   },
#   "_stmt_key": "2_16",
#   "_chunk_num": 2,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [2.17]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Ensemble interpretation](/wiki/Ensemble_interpretation).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Ensemble_interpretation> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreien4cy6ur2hp7nfcrl63x24x2xifjfeysdlnuosgu2m6jhlfvi4im",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreien4cy6ur2hp7nfcrl63x24x2xifjfeysdlnuosgu2m6jhlfvi4im",
#   "prov:label": "rdf:2_17",
#   "_cell": 92,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiev3ati7afcekanyr3mnmj2hrgtv4oj65ldi6mi4upv6ljkncq2am"
#   },
#   "_stmt_key": "2_17",
#   "_chunk_num": 2,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [2.18]: [Albert Einstein](/wiki/Albert_Einstein) is known for [List of other concepts](/wiki/List_of_things_named_after_Albert_Einstein).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/List_of_things_named_after_Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihjv6btahsdtzzlfdh2tkr5ngrl6g7s7y4w6j53psqq7rrqgtesou",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihjv6btahsdtzzlfdh2tkr5ngrl6g7s7y4w6j53psqq7rrqgtesou",
#   "prov:label": "rdf:2_18",
#   "_cell": 94,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieoe2ctrubpli6cohaofoqihkujopnlee6w6sk5g2hgafelhfmkwi"
#   },
#   "_stmt_key": "2_18",
#   "_chunk_num": 2,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [2.19]: [Albert Einstein](/wiki/Albert_Einstein) received the [Barnard Medal for Meritorious Service to Science](/wiki/Barnard_Medal_for_Meritorious_Service_to_Science) in 1920.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award <https://en.wikipedia.org/wiki/Barnard_Medal_for_Meritorious_Service_to_Science> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award "1920"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiejmrreflblvhjqied5dyurl2mefcm7pr6ctj3p4u7bfzjm23qhvu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiejmrreflblvhjqied5dyurl2mefcm7pr6ctj3p4u7bfzjm23qhvu",
#   "prov:label": "rdf:2_19",
#   "_cell": 96,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicgs3ugk6qnqjzrdto7glvclv5ker2r6xjbq3nm25qcgm7p6ds7qy"
#   },
#   "_stmt_key": "2_19",
#   "_chunk_num": 2,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Statement [2.20]: [Albert Einstein](/wiki/Albert_Einstein) received the [Nobel Prize in Physics](/wiki/Nobel_Prize_in_Physics) in 1921.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award "1921"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaasgoudfgzot26ms7rv7l4s6o7s7lw4iylodlruidmpl2r66egga",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaasgoudfgzot26ms7rv7l4s6o7s7lw4iylodlruidmpl2r66egga",
#   "prov:label": "rdf:2_20",
#   "_cell": 98,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicafafidol4ikdvckqeads22s57rmdwibxyphori7zonbnjfr2wlq"
#   },
#   "_stmt_key": "2_20",
#   "_chunk_num": 2,
#   "_stmt_idx": 20
# }

# %% [raw]
# # Statement [2.21]: [Albert Einstein](/wiki/Albert_Einstein) received the [Matteucci Medal](/wiki/Matteucci_Medal) in 1921.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award <https://en.wikipedia.org/wiki/Matteucci_Medal> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award "1921"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiacywjhd7r3gx6oxfyx2oge2vhywsagp66ctnqrkgjuxyohwvzrwy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiacywjhd7r3gx6oxfyx2oge2vhywsagp66ctnqrkgjuxyohwvzrwy",
#   "prov:label": "rdf:2_21",
#   "_cell": 100,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreic565x3sexx57x33sxa4cfjmmwowhpccap5sb6agavcnxvw7hyexm"
#   },
#   "_stmt_key": "2_21",
#   "_chunk_num": 2,
#   "_stmt_idx": 21
# }

# %% [raw]
# # Statement [2.22]: [Albert Einstein](/wiki/Albert_Einstein) received the [ForMemRS](/wiki/List_of_fellows_of_the_Royal_Society_elected_in_1921) in 1921.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award <https://en.wikipedia.org/wiki/List_of_fellows_of_the_Royal_Society_elected_in_1921> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award "1921"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibzuimund7rz7zikdqxrp7227zxo2t4qkx3eqolttv6yl23adcwyi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibzuimund7rz7zikdqxrp7227zxo2t4qkx3eqolttv6yl23adcwyi",
#   "prov:label": "rdf:2_22",
#   "_cell": 102,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaikeltogu4ptrnaphyg6pd24vlast476iit4kdktprph5nyxkvby"
#   },
#   "_stmt_key": "2_22",
#   "_chunk_num": 2,
#   "_stmt_idx": 22
# }

# %% [raw]
# # Statement [2.23]: [Albert Einstein](/wiki/Albert_Einstein) received the [Copley Medal](/wiki/Copley_Medal) in 1925.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award <https://en.wikipedia.org/wiki/Copley_Medal> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award "1925"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifj6kipydhbvmsoz5o3q3k4sm6pu2zghp4qebnw3hdqwrktxteg7m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifj6kipydhbvmsoz5o3q3k4sm6pu2zghp4qebnw3hdqwrktxteg7m",
#   "prov:label": "rdf:2_23",
#   "_cell": 104,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibi344loetra2smqz3pq5xnjeiro2zzuipli53q5fxmfquedi2vye"
#   },
#   "_stmt_key": "2_23",
#   "_chunk_num": 2,
#   "_stmt_idx": 23
# }

# %% [raw]
# # Statement [2.24]: [Albert Einstein](/wiki/Albert_Einstein) received the [Gold Medal of RAS](/wiki/Gold_Medal_of_the_Royal_Astronomical_Society) in 1926.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award <https://en.wikipedia.org/wiki/Gold_Medal_of_the_Royal_Astronomical_Society> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award "1926"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibotvh4s7ma4mxlmhapgiommusj5efuost6dxs77sfotkzhizkbfe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibotvh4s7ma4mxlmhapgiommusj5efuost6dxs77sfotkzhizkbfe",
#   "prov:label": "rdf:2_24",
#   "_cell": 106,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreickqixxats5vv35tynfsznd7jafuvktv7ddbtzyeenmlrvrn2g27y"
#   },
#   "_stmt_key": "2_24",
#   "_chunk_num": 2,
#   "_stmt_idx": 24
# }

# %% [raw]
# # Statement [2.25]: [Albert Einstein](/wiki/Albert_Einstein) received the [Max Planck Medal](/wiki/Max_Planck_Medal) in 1929.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award <https://en.wikipedia.org/wiki/Max_Planck_Medal> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award "1929"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidd7637slkzbqu6uv2pxcwc55qzkmicb7qyaaglie53lykiy23jgm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidd7637slkzbqu6uv2pxcwc55qzkmicb7qyaaglie53lykiy23jgm",
#   "prov:label": "rdf:2_25",
#   "_cell": 108,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiapimlwycvrdd2km4563v625ncoi3relezrqv64hk2u47k4pdoume"
#   },
#   "_stmt_key": "2_25",
#   "_chunk_num": 2,
#   "_stmt_idx": 25
# }

# %% [raw]
# # Statement [2.26]: [Albert Einstein](/wiki/Albert_Einstein) became a member of the [National Academy of Sciences](/wiki/Member_of_the_National_Academy_of_Sciences) in 1942.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:member <https://en.wikipedia.org/wiki/Member_of_the_National_Academy_of_Sciences> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:member "1942"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihzkdjfdtmkgi74rnujf4y3klcay3ggovssomo4mzdolbk3c3evai",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihzkdjfdtmkgi74rnujf4y3klcay3ggovssomo4mzdolbk3c3evai",
#   "prov:label": "rdf:2_26",
#   "_cell": 110,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifiiaywlgjjhexhpqtpng6zfc4butvc7f3a7mtpl5djodnpmzndx4"
#   },
#   "_stmt_key": "2_26",
#   "_chunk_num": 2,
#   "_stmt_idx": 26
# }

# %% [raw]
# # Statement [2.27]: [Albert Einstein](/wiki/Albert_Einstein) was named [''Time'' Person of the Century](/wiki/Time_100%3A_The_Most_Important_People_of_the_Century) in 1999.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award <https://en.wikipedia.org/wiki/Time_100%3A_The_Most_Important_People_of_the_Century> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award "1999"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiciknlux5skblwk5xgodgkekbrbqsbgwcx2od4mrzbc2rhcl3kmy4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiciknlux5skblwk5xgodgkekbrbqsbgwcx2od4mrzbc2rhcl3kmy4",
#   "prov:label": "rdf:2_27",
#   "_cell": 112,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigcxfm2qutcg5i6nchg2yvwxh7qaaq2d346pvzeydplelo6chsm4a"
#   },
#   "_stmt_key": "2_27",
#   "_chunk_num": 2,
#   "_stmt_idx": 27
# }

# %% [raw]
# # Statement [3.1]: [Albert Einstein](/wiki/Albert_Einstein) was born on 14 March 1879.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:birthDate "1879-03-14"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreih25ytinybvba2nbkwufbesd6ezoklvlchjkkhhtrsi43oc2v3wuy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreih25ytinybvba2nbkwufbesd6ezoklvlchjkkhhtrsi43oc2v3wuy",
#   "prov:label": "rdf:3_1",
#   "_cell": 114,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiazipa5t2o64vc2ckcsdd4w6e777giy7qp2zobg6dkbeutvmevxaq"
#   },
#   "_stmt_key": "3_1",
#   "_chunk_num": 3,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [3.2]: [Albert Einstein](/wiki/Albert_Einstein) was born in [Ulm](/wiki/Ulm).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:birthPlace <https://en.wikipedia.org/wiki/Ulm> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaebvavm2p2dagxwvbyben7pggiweiujrkugi5rjt444z7mt256ny",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaebvavm2p2dagxwvbyben7pggiweiujrkugi5rjt444z7mt256ny",
#   "prov:label": "rdf:3_2",
#   "_cell": 116,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiau7no73cwq424hhiyt45jj5opq2sv7djwqiumy2t4qk6z53ev43a"
#   },
#   "_stmt_key": "3_2",
#   "_chunk_num": 3,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [3.3]: [Albert Einstein](/wiki/Albert_Einstein) was a German-born [theoretical physicist](/wiki/theoretical_physicist).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality <https://en.wikipedia.org/wiki/German_Empire> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasOccupation <https://en.wikipedia.org/wiki/Physics> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibr7p4dye5333b5bx2r4bcwavymexv6unj2c7vlg3z5tuuvf67tla",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibr7p4dye5333b5bx2r4bcwavymexv6unj2c7vlg3z5tuuvf67tla",
#   "prov:label": "rdf:3_3",
#   "_cell": 118,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihngs375qpx5bonfdil3mi45zkzntun2ztajcw5wm4ivkba5ymv4i"
#   },
#   "_stmt_key": "3_3",
#   "_chunk_num": 3,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [3.4]: [Albert Einstein](/wiki/Albert_Einstein) is best known for developing the [theory of relativity](/wiki/theory_of_relativity).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:mainEntityOfPage <https://en.wikipedia.org/wiki/General_relativity> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibnjhpqthgfb2xbg7jx3jelvm6u5va2m5lvboq7xd7obsbc4eizce",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibnjhpqthgfb2xbg7jx3jelvm6u5va2m5lvboq7xd7obsbc4eizce",
#   "prov:label": "rdf:3_4",
#   "_cell": 120,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreif5hodzyh4kfxeqbpbxuzraxiqazpplf2z6uumj4t5e5wjwlmt2e4"
#   },
#   "_stmt_key": "3_4",
#   "_chunk_num": 3,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [3.5]: [Albert Einstein](/wiki/Albert_Einstein) made important contributions to [quantum theory](/wiki/Old_quantum_theory).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:mainEntityOfPage <https://en.wikipedia.org/wiki/Photoelectric_effect> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieyvw6vof4m2rurinprqb73mtqmmnr5o6pd4gqx7ku4vzge5febdq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieyvw6vof4m2rurinprqb73mtqmmnr5o6pd4gqx7ku4vzge5febdq",
#   "prov:label": "rdf:3_5",
#   "_cell": 122,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidd7abyxs2bfc3kzgfnyj5ezt3h2uhxgvknchh75bo5t253navkjm"
#   },
#   "_stmt_key": "3_5",
#   "_chunk_num": 3,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [3.6]: [Albert Einstein](/wiki/Albert_Einstein) made important contributions to [statistical mechanics](/wiki/statistical_mechanics).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:mainEntityOfPage <https://en.wikipedia.org/wiki/Brownian_motion> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihhfe2qscpzik4of6ldvycrd24okwv2qkv574vugrg5mmnxmgy44q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihhfe2qscpzik4of6ldvycrd24okwv2qkv574vugrg5mmnxmgy44q",
#   "prov:label": "rdf:3_6",
#   "_cell": 124,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiey3exwniz3xoqmufns5g2yswbcoica2oltmvlmsueyx2nshzrtl4"
#   },
#   "_stmt_key": "3_6",
#   "_chunk_num": 3,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [3.7]: [Albert Einstein](/wiki/Albert_Einstein) made important contributions to quantum theory.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:mainEntityOfPage <https://en.wikipedia.org/wiki/Planck%E2%80%93Einstein_relation> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifnincylfgygssspt6uohfqzmbv2353oe4di5vfcj5ljpn6dziw6e",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifnincylfgygssspt6uohfqzmbv2353oe4di5vfcj5ljpn6dziw6e",
#   "prov:label": "rdf:3_7",
#   "_cell": 126,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicnvikdqh5tz5ybfnbrdnuq72sn5lljh6tdnddxidubp4zjzcsf3e"
#   },
#   "_stmt_key": "3_7",
#   "_chunk_num": 3,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [3.8]: [Albert Einstein](/wiki/Albert_Einstein) worked on the quantum physics of [radiation](/wiki/radiation).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:mainEntityOfPage <https://en.wikipedia.org/wiki/Photoelectric_effect> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiberrerakua7d5f24dgoj6csdowvvsqtg7vc63eucdq344xpskpey",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiberrerakua7d5f24dgoj6csdowvvsqtg7vc63eucdq344xpskpey",
#   "prov:label": "rdf:3_8",
#   "_cell": 128,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiggz43mehs5nxhs3hxepvqnssd3hxueic4kwbrhgmrg5hto4knfua"
#   },
#   "_stmt_key": "3_8",
#   "_chunk_num": 3,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [3.9]: Light consists of particles, subsequently called [photon](/wiki/photon)s.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:mainEntityOfPage <https://en.wikipedia.org/wiki/Photoelectric_effect> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigsyupf2qqsjckovzpoda7hg2lt4ewjlc7y4ihcrubr6t7yrklpqi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigsyupf2qqsjckovzpoda7hg2lt4ewjlc7y4ihcrubr6t7yrklpqi",
#   "prov:label": "rdf:3_9",
#   "_cell": 130,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifuokvmgmj4pq4xupdf25ehv2357eety7kwznz25f6ousgrufossa"
#   },
#   "_stmt_key": "3_9",
#   "_chunk_num": 3,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [3.10]: [Albert Einstein](/wiki/Albert_Einstein) worked with physicist [Satyendra Nath Bose](/wiki/Satyendra_Nath_Bose).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:colleagues <https://en.wikipedia.org/wiki/Satyendra_Nath_Bose> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidday6pz25yzxjccf7zup6h4vcpw3tvwkrtcwvpqj7dir63q76lui",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidday6pz25yzxjccf7zup6h4vcpw3tvwkrtcwvpqj7dir63q76lui",
#   "prov:label": "rdf:3_10",
#   "_cell": 132,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicrb3fhy5pb4fbyrtqzpvfjmkbehmwgkg7h5ewvuakzrgfkfxlq64"
#   },
#   "_stmt_key": "3_10",
#   "_chunk_num": 3,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [3.11]: [Albert Einstein](/wiki/Albert_Einstein) and [Satyendra Nath Bose](/wiki/Satyendra_Nath_Bose) laid the groundwork for [Bose–Einstein statistics](/wiki/Bose%E2%80%93Einstein_statistics).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:mainEntityOfPage <https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_statistics> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibwslf5oyfc53huvahgwwgvqc567feueigah2n25grrdug22ajpny",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibwslf5oyfc53huvahgwwgvqc567feueigah2n25grrdug22ajpny",
#   "prov:label": "rdf:3_11",
#   "_cell": 134,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibuaxa6hlavyisfc4qphdcw25l5cfymoyd47gau7ryzvcq6mevlgm"
#   },
#   "_stmt_key": "3_11",
#   "_chunk_num": 3,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [3.12]: [Albert Einstein](/wiki/Albert_Einstein) advocated against quantum theory's introduction of fundamental randomness into science's picture of the world.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:mainEntityOfPage <https://en.wikipedia.org/wiki/Ensemble_interpretation> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiasvaq65zppc4orh7n5imt5vaikpdhbsac2wmvz6qin6z6qxmlapq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiasvaq65zppc4orh7n5imt5vaikpdhbsac2wmvz6qin6z6qxmlapq",
#   "prov:label": "rdf:3_12",
#   "_cell": 136,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidqwkowshi463l62aucfnnupidtu43sd3cg2gf6r7oiilf2eariuq"
#   },
#   "_stmt_key": "3_12",
#   "_chunk_num": 3,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [3.13]: [Albert Einstein](/wiki/Albert_Einstein) objected that "God does not play dice".
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:mainEntityOfPage <https://en.wikipedia.org/wiki/Ensemble_interpretation> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidebk5jlwufe775djs7lhsszghonoikomlwlz5aylt3nl6mkxhl7u",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidebk5jlwufe775djs7lhsszghonoikomlwlz5aylt3nl6mkxhl7u",
#   "prov:label": "rdf:3_13",
#   "_cell": 138,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih2efafd45y3ynt3kytl5vkw47custqwybmfa75qhhr32y2xmqjs4"
#   },
#   "_stmt_key": "3_13",
#   "_chunk_num": 3,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [3.14]: [Albert Einstein](/wiki/Albert_Einstein) attempted to devise a [unified field theory](/wiki/unified_field_theory).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:mainEntityOfPage <https://en.wikipedia.org/wiki/Unified_field_theory> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifxdhapwipmkax72aojbmic2dz4bevynrdg65jeaviko373ubzlra",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifxdhapwipmkax72aojbmic2dz4bevynrdg65jeaviko373ubzlra",
#   "prov:label": "rdf:3_14",
#   "_cell": 140,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiejwtij5m6qtaqyon6ihi4bidnmwe2ruw627plwgdg73yrhivxu54"
#   },
#   "_stmt_key": "3_14",
#   "_chunk_num": 3,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [3.15]: [Albert Einstein](/wiki/Albert_Einstein) generalized his geometric theory of gravitation to include [electromagnetism](/wiki/electromagnetism).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:mainEntityOfPage <https://en.wikipedia.org/wiki/Einstein_field_equations> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibqr2agk7ldduklrsfapbevggiylnccqjhhplwt5jo5zq3jhrxx74",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibqr2agk7ldduklrsfapbevggiylnccqjhhplwt5jo5zq3jhrxx74",
#   "prov:label": "rdf:3_15",
#   "_cell": 142,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiadeb2lrrzjhfdcguzu5vuacykvxkgwxl3u2y2vzhfskftmmiwsfa"
#   },
#   "_stmt_key": "3_15",
#   "_chunk_num": 3,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [3.16]: [Albert Einstein](/wiki/Albert_Einstein) became increasingly isolated from mainstream [modern physics](/wiki/modern_physics).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:mainEntityOfPage <https://en.wikipedia.org/wiki/Modern_physics> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifkjwyp5ylqqndgdc4hljcaaxzvx5nvf2u4ue3z73z5pctln26vze",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifkjwyp5ylqqndgdc4hljcaaxzvx5nvf2u4ue3z73z5pctln26vze",
#   "prov:label": "rdf:3_16",
#   "_cell": 144,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidaocywva3vu5dd5x74hzhvlflbt3frcovkvpfregz3b5nc5ymuai"
#   },
#   "_stmt_key": "3_16",
#   "_chunk_num": 3,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [3.17]: [Albert Einstein](/wiki/Albert_Einstein) was five years old when he was sick in bed.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:lifeEvent <https://en.wikipedia.org/wiki/Brownian_motion> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreib5hfxlhr5wuwe3axzu2jlkb6qkzyhmsnfobeuowcu3p3ilzidaca",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreib5hfxlhr5wuwe3axzu2jlkb6qkzyhmsnfobeuowcu3p3ilzidaca",
#   "prov:label": "rdf:3_17",
#   "_cell": 146,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidnngi2krk5gdanrcmwt5wm27abiv2fwrbq3hcwmyx3uj3zm6jdcy"
#   },
#   "_stmt_key": "3_17",
#   "_chunk_num": 3,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [3.18]: [Albert Einstein](/wiki/Albert_Einstein)'s father brought him a [compass](/wiki/magnetic_compass) when he was five and sick in bed.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:mainEntityOfPage <https://en.wikipedia.org/wiki/Magnetic_compass> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreignbkx6hwhzewjoxvi6pfazbtdon2h2jze74eqbnebb6lif6rlfia",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreignbkx6hwhzewjoxvi6pfazbtdon2h2jze74eqbnebb6lif6rlfia",
#   "prov:label": "rdf:3_18",
#   "_cell": 148,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreie5d3iktqrir33e6gojkv4ydruegwb6cuy6ihn75fmctrtjcuyhaq"
#   },
#   "_stmt_key": "3_18",
#   "_chunk_num": 3,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [3.19]: [Albert Einstein](/wiki/Albert_Einstein) had a lifelong fascination with [electromagnetism](/wiki/electromagnetism).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:mainEntityOfPage <https://en.wikipedia.org/wiki/Electromagnetism> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiccapytvtghrptyqot5l53ex7wu7sgp5stvz7nviublb5yowresky",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiccapytvtghrptyqot5l53ex7wu7sgp5stvz7nviublb5yowresky",
#   "prov:label": "rdf:3_19",
#   "_cell": 150,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidptdepou7jtsmlac36phak2jogchpwpm6dd5qtcgwe5d2f3j55b4"
#   },
#   "_stmt_key": "3_19",
#   "_chunk_num": 3,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Statement [3.20]: [Albert Einstein](/wiki/Albert_Einstein) realized that "Something deeply hidden had to be behind things."
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:mainEntityOfPage <https://en.wikipedia.org/wiki/Photoelectric_effect> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibie5akyxexkef2p7hfl262bjpe2qmdkk2kosstvmv5msjb7ntn3q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibie5akyxexkef2p7hfl262bjpe2qmdkk2kosstvmv5msjb7ntn3q",
#   "prov:label": "rdf:3_20",
#   "_cell": 152,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicrfu6q2js3ix6df4k3nbaxketdxrru6epfzwgabpovg2sarm2nze"
#   },
#   "_stmt_key": "3_20",
#   "_chunk_num": 3,
#   "_stmt_idx": 20
# }

# %% [raw]
# # Statement [3.21]: [Albert Einstein](/wiki/Albert_Einstein) attended St. Peter's [Catholic elementary school](/wiki/Catholic_school) in Munich.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Catholic_school> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigq65m3x2uqekxbvuku3pk4jjsf3p4ekupo7qwcuqve6f36k2k2pq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigq65m3x2uqekxbvuku3pk4jjsf3p4ekupo7qwcuqve6f36k2k2pq",
#   "prov:label": "rdf:3_21",
#   "_cell": 154,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifgbux2jpcevxgqym3d2u7wkkssboymcl6a4yhv42atdr2lpt2g64"
#   },
#   "_stmt_key": "3_21",
#   "_chunk_num": 3,
#   "_stmt_idx": 21
# }

# %% [raw]
# # Statement [3.22]: [Albert Einstein](/wiki/Albert_Einstein) attended St. Peter's [Catholic elementary school](/wiki/Catholic_school) from the age of five.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Catholic_school> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibagesfzemytpys5hkoo32vq5bqizkoroyxxxi3yxn5gqx2zfs3eu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibagesfzemytpys5hkoo32vq5bqizkoroyxxxi3yxn5gqx2zfs3eu",
#   "prov:label": "rdf:3_22",
#   "_cell": 156,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifexybmrdjfuocg6kqoslhypb6olodr2o7jso2cnykh4xzffsncb4"
#   },
#   "_stmt_key": "3_22",
#   "_chunk_num": 3,
#   "_stmt_idx": 22
# }

# %% [raw]
# # Statement [3.23]: [Albert Einstein](/wiki/Albert_Einstein) was transferred to the [Luitpold Gymnasium](/wiki/Luitpold_Gymnasium) when he was eight.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Luitpold_Gymnasium> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihqwayrbva7fipq43nikinebocghk2kzlsgrxrk5id3czvifjvt4a",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihqwayrbva7fipq43nikinebocghk2kzlsgrxrk5id3czvifjvt4a",
#   "prov:label": "rdf:3_23",
#   "_cell": 158,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiczqzck4gw2qqwqmg5yluvt5cdvn4fm2nhmrstvzgtux5mxjose5e"
#   },
#   "_stmt_key": "3_23",
#   "_chunk_num": 3,
#   "_stmt_idx": 23
# }

# %% [raw]
# # Statement [3.24]: [Albert Einstein](/wiki/Albert_Einstein) received advanced primary and then secondary school education at the [Luitpold Gymnasium](/wiki/Luitpold_Gymnasium).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Luitpold_Gymnasium> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigoulvh5suvfxjkqkdl56ysdziyrwkisr6r6bi4budcme5cvjiziq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigoulvh5suvfxjkqkdl56ysdziyrwkisr6r6bi4budcme5cvjiziq",
#   "prov:label": "rdf:3_24",
#   "_cell": 160,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid5sdq23xbo3bdy5dyniebph3esdreuuecjqrpcgkjiel2niqqz2a"
#   },
#   "_stmt_key": "3_24",
#   "_chunk_num": 3,
#   "_stmt_idx": 24
# }
