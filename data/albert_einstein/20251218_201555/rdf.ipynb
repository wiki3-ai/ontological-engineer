# %% [markdown]
# # RDF Triples: Albert Einstein
#
# ## Provenance
#
# ```yaml
# source_url: https://en.wikipedia.org/wiki/Albert_Einstein
# article_title: Albert Einstein
# license: CC BY-SA 4.0
# license_url: https://creativecommons.org/licenses/by-sa/4.0/
# source_notebook: facts.ipynb
# generated_by: wiki_to_kg_pipeline.ipynb
# generated_at: 2025-12-18T20:15:57.098812
# llm_provider: lm_studio
# llm_model: qwen/qwen3-coder-30b
# llm_temperature: 1
# rdf_format: Turtle
# ```
#
# ## RDF Prefixes
#
# ```turtle
# @prefix schema: <https://schema.org/> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix wiki3: <https://wiki3.ai/vocab/> .
# @base <https://en.wikipedia.org/wiki/Albert_Einstein> .
#
# ```
#
# ## Processing Instructions
#
# This notebook contains RDF triples in Turtle format, one cell per source facts cell.
# Each content cell is followed by a signature cell with CID provenance.
#
# To regenerate a specific cell: delete both the content cell and its signature, then re-run the pipeline.
#
# ## Prompt Template
#
# ```
# You are an expert at converting factual statements to RDF triples in Turtle format.
#
# Convert the following factual statements to RDF using schema.org vocabulary where possible.
#
# Source: {source_url}
# Section: {breadcrumb}
#
# Use these prefixes:
# {prefixes}
#
# Entity registry (use these URIs):
# {entity_registry}
#
# Guidelines:
# - Use schema.org properties (schema:birthDate, schema:birthPlace, schema:worksFor, etc.)
# - For relationships not in schema.org, use wiki3: prefix
# - Include rdfs:label for entities
# - Use xsd datatypes for dates and numbers
# - Entity URIs should use the source URL as base with fragment identifiers
#
# ---
# {facts}
# ---
#
# Generate Turtle RDF:
#
# ```

# %% [raw]
# {
#   "source_url": "https://en.wikipedia.org/wiki/Albert_Einstein",
#   "entities": {
#     "albert_einstein": {
#       "id": "person_albert_einstein",
#       "uri": "https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein",
#       "label": "Albert Einstein",
#       "type": "Person",
#       "descriptions": [
#         "Subject of Wikipedia article: Albert Einstein"
#       ],
#       "source_chunks": [],
#       "aliases": [
#         "Einstein"
#       ]
#     }
#   },
#   "aliases": {
#     "einstein": "albert_einstein"
#   }
# }

# %% [raw]
# # Context: Albert Einstein > Introduction
# # Cell: 1 of 63
#
# # I've converted the factual statements about Albert Einstein into RDF triples using schema.org vocabulary. The key entities and relationships I captured include:
# #
# # 1. Basic biographical information (birth/death dates and place)
# # 2. Nationality changes (German to American)
# # 3. Professional roles and affiliations (theoretical physicist, various institutions)
#
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "German Empire" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "German" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Theoretical physicist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Nobel Prize in Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Swiss federal polytechnic school" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:workLocation "Swiss Patent Office" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:workLocation "Prussian Academy of Sciences" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:workLocation "Humboldt University of Berlin" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:workLocation "Kaiser Wilhelm Institute for Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:workLocation "Berlin" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "American" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Nobel Prize for his services to theoretical physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Nobel Prize for his discovery of the law of the photoelectric effect" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Swiss federal polytechnic school" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:workLocation "Swiss Patent Office" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:workLocation "Prussian Academy of Sciences" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:workLocation "Humboldt University of Berlin" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:workLocation "Kaiser Wilhelm Institute for Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:workLocation "Berlin" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "American" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Manhattan Project" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Theoretical physicist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Nobel Prize in Physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "German Empire" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:workLocation "Bern" .

# %% [raw]
# {"cell": 1, "type": "rdf", "cid": "9f81c7801b99d1e0603622cf1807a31f01c93550a264752afb40ffd5082802ca", "from_cid": "f35fcaeff0fd85ef2d8df201cfd075d136e3113d665dacc89f78782dd2f98d09"}

# %% [raw]
# # Context: Albert Einstein > Introduction
# # Cell: 2 of 63
#
# # I've converted the factual statements about Albert Einstein into RDF triples using schema.org vocabulary. The triples capture his key contributions, theories, papers, and affiliations.
# #
# # Key aspects covered:
# # - Basic personal information (birth/death dates)
# # - Professional roles and affiliations
#
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation schema:Researcher .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "Special theory of relativity" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "General theory of relativity" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "Bose-Einstein statistics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "Photoelectric effect" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "Brownian motion" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "Quantum physics of radiation" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "Mass-energy equivalence" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "Spontaneous emission and stimulated emission" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "Unified field theory" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "Statistical mechanics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "Quantum theory" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "Photon theory" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "Cosmological constant" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:contributor "Modern theoretical cosmology" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:colleague "https://en.wikipedia.org/wiki/Satyendra_Nath_Bose" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation "https://en.wikipedia.org/wiki/Princeton_University" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation "https://en.wikipedia.org/wiki/Institute_for_Advanced_Study" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation "https://en.wikipedia.org/wiki/Max_Planck_Institute" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation "https://en.wikipedia.org/wiki/University_of_Zurich" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation "https://en.wikipedia.org/wiki/ETH_Zurich" .

# %% [raw]
# {"cell": 2, "type": "rdf", "cid": "c454a587d67b195ccf187acc1a663e6f5516fa9b67fd69cd19dde98a63669616", "from_cid": "a07d222450f92250f5a4666ea59a012669061751c0dd516dad2935593a9f1963"}

# %% [raw]
# # Context: Albert Einstein > Life and career
# # Cell: 3 of 63
#
# # I've converted the factual statements about Albert Einstein into RDF triples using schema.org vocabulary. The conversion includes:
# #
# # 1. Basic biographical information (birth date, birth place)
# # 2. Family relationships (parents, uncle)
# # 3. Professional information (occupations of Hermann Einstein)
#
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Ulm" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parent <#person_hermann_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parent <#person_pauline_koch> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "German" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "St. Peter's Catholic elementary school" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Luitpold Gymnasium" .
# <#person_hermann_einstein> rdf:type schema:Person .
# <#person_hermann_einstein> schema:hasOccupation "salesman" .
# <#person_hermann_einstein> schema:hasOccupation "engineer" .
# <#organization_einstein_company> rdf:type schema:Organization .
# <#organization_einstein_company> schema:foundingDate "1880" .
# <#organization_einstein_company> schema:founder <#person_hermann_einstein> .
# <#organization_einstein_company> schema:founder <#person_jakob_einstein> .
# <#organization_einstein_company> schema:location "Munich" .
# <#person_hermann_einstein> schema:parent <#person_jakob_einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Kingdom of Württemberg" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "German Empire" .

# %% [raw]
# {"cell": 3, "type": "rdf", "cid": "ed983a88d64d15a02852f677532c9b391147a4605fdeb4fc11cc1f112f97a771", "from_cid": "14868673ddb40fffcc406c00a57ce5f24898609bc9bb8286b044b9c414c066a2"}

# %% [raw]
# # Context: Albert Einstein > Life and career > Childhood, youth and education
# # Cell: 4 of 63
#
# # I've converted the factual statements about Albert Einstein's early life and career into RDF triples using schema.org vocabulary. The triples capture key events including the company failure in Munich, the family's move to Italy, Einstein staying in Munich for school, and his essay writing while in Italy.
# #
# # I used the following key predicates:
# # - schema:lifeEvent to link Einstein to significant life occurrences
# # - schema:alumniOf to connect him with his educational institutions
#
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf <#school_gymnasium> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Ulm, Germany" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathPlace "Princeton, New Jersey, USA" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality schema:German .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation "Princeton, New Jersey, USA" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:lifeEvent "<#event_munich_failure>"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:lifeEvent "<#event_move_italy>"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:lifeEvent "<#event_stay_munich>"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:lifeEvent "<#event_essay_italy>"^^xsd:string .
# <#event_munich_failure> rdf:type schema:Event .
# <#event_munich_failure> schema:name "Company bid failure in Munich" .
# <#event_munich_failure> schema:description "Hermann and Jakob's company tendered for a contract to install electric lighting in Munich but was unsuccessful" .
# <#event_munich_failure> schema:startDate "1894"^^xsd:date .
# <#event_move_italy> rdf:type schema:Event .
# <#event_move_italy> schema:name "Move to Italy" .
# <#event_move_italy> schema:description "The Einstein family moved to Italy, first to Milan and then to Pavia" .
# <#event_move_italy> schema:startDate "1894"^^xsd:date .
# <#event_stay_munich> rdf:type schema:Event .
# <#event_stay_munich> schema:name "Stay in Munich" .
# <#event_stay_munich> schema:description "Einstein stayed behind in Munich to finish his schooling at the Gymnasium" .
# <#event_stay_munich> schema:startDate "1894"^^xsd:date .
# <#event_essay_italy> rdf:type schema:Event .
# <#event_essay_italy> schema:name "Essay on Ether in Magnetic Field" .
# <#event_essay_italy> schema:description "While in Italy as a teenager, Einstein wrote an essay entitled 'On the Investigation of the State of the Ether in a Magnetic Field'" .
# <#event_essay_italy> schema:startDate "1894"^^xsd:date .

# %% [raw]
# {"cell": 4, "type": "rdf", "cid": "18b8153ce0e00fb5052e94691b3871a98feb1a96740638a2524e3e199642a79e", "from_cid": "ac79491e5e81a420c1223b25485c6b6d4b80c9a86a0bc7b3b87c2beb1ccc07fc"}

# %% [raw]
# # Context: Albert Einstein > Life and career > Childhood, youth and education
# # Cell: 5 of 63
#
# # ## Summary
# #
# # I've converted the factual statements about Albert Einstein's early life and education into RDF triples using schema.org vocabulary. The key entities I represented include:
# #
# # 1. **Albert Einstein** as a Person with various skills and knowledge areas including physics, mathematics, algebra, calculus, geometry, and mathematical structures
#
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "physics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "mathematics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "algebra" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "calculus" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "Euclidean geometry" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "Pythagorean theorem" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "integral calculus" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "differential calculus" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:skills "algebra" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:skills "geometry" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:instructor <https://en.wikipedia.org/wiki/Max_Talmud> .
# <https://en.wikipedia.org/wiki/Max_Talmud> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Max_Talmud> schema:knowsAbout "geometry" .
# <https://en.wikipedia.org/wiki/Max_Talmud> schema:knowsAbout "mathematics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Ulm, Germany" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "German" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:skills "calculus" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:skills "higher mathematics" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:skills "mathematical structure" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "mathematical structure" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:skills "integral calculus" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:skills "differential calculus" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knowsAbout "mathematical genius" .

# %% [raw]
# {"cell": 5, "type": "rdf", "cid": "93c56e783805980ca88ddc81caebc07f92dd2a227c8ee5cc00163c3d081f5863", "from_cid": "5c9e7721fd8ad9adcbc2293079ce349e9f394ab73062e2dee6fc8aaffc655d1a"}
