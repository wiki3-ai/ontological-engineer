# %% [markdown]
# # Extracted Facts: Albert Einstein
#
# ## Provenance
#
# ```yaml
# source_notebook: chunks.ipynb
# source_url: https://en.wikipedia.org/wiki/Albert_Einstein
# article_title: Albert Einstein
# license: CC BY-SA 4.0
# license_url: https://creativecommons.org/licenses/by-sa/4.0/
# extraction_model: qwen/qwen3-coder-30b
# extraction_timestamp: 2025-12-19T06:41:58.166020
# total_chunks: 63
# generated_by: wiki_to_kg_pipeline.ipynb
# ```
#
# ## Processing Instructions
#
# This notebook contains factual statements extracted from source chunks.
# Each facts cell is followed by a signature cell with CID provenance linking back to its source chunk.
#
# To regenerate a specific cell: delete both the content cell and its signature, then re-run the pipeline.
#
# Structure:
# - **Context**: Section breadcrumb from source
# - **Chunk**: Position in sequence
# - **Facts**: Bulleted list of extracted factual statements

# %% [raw]
# {
#   "source_url": "https://en.wikipedia.org/wiki/Albert_Einstein",
#   "entities": {
#     "albert_einstein": {
#       "id": "person_albert_einstein",
#       "uri": "https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein",
#       "label": "Albert Einstein",
#       "type": "Person",
#       "descriptions": [
#         "Subject of Wikipedia article: Albert Einstein"
#       ],
#       "source_chunks": [],
#       "aliases": [
#         "Einstein"
#       ]
#     }
#   },
#   "aliases": {
#     "einstein": "albert_einstein"
#   }
# }

# %% [markdown]
# **Context:** Albert Einstein > Introduction
# **Chunk:** 1 of 63
#
# ---
#
# - Albert Einstein was a German-born theoretical physicist.
# - Albert Einstein developed the theory of relativity.
# - Albert Einstein made important contributions to quantum theory.
# - Albert Einstein's mass–energy equivalence formula E = mc2 arises from special relativity.
# - Albert Einstein received the 1921 Nobel Prize in Physics.
# - Albert Einstein was born on 14 March 1879.
# - Albert Einstein died on 18 April 1955.
# - Albert Einstein was a subject of the Kingdom of Württemberg.
# - Albert Einstein moved to Switzerland in 1895.
# - Albert Einstein forsaking his German citizenship in 1896.
# - Albert Einstein enrolled in the mathematics and physics teaching diploma program at the Swiss federal polytechnic school in Zurich in 1897.
# - Albert Einstein graduated from the Swiss federal polytechnic school in Zurich in 1900.
# - Albert Einstein acquired Swiss citizenship in 1901.
# - Albert Einstein worked at the Swiss Patent Office in Bern.
# - Albert Einstein submitted a successful PhD dissertation to the University of Zurich in 1905.
# - Albert Einstein moved to Berlin in 1914.
# - Albert Einstein joined the Prussian Academy of Sciences in 1914.
# - Albert Einstein joined the Humboldt University of Berlin in 1914.
# - Albert Einstein became director of the Kaiser Wilhelm Institute for Physics in 1917.
# - Albert Einstein became a subject of the Kingdom of Prussia in 1914.
# - Adolf Hitler came to power in Germany in 1933.
# - Albert Einstein was visiting the United States in 1933.
# - Albert Einstein was horrified by the Nazi persecution of his fellow Jews in 1933.
# - Albert Einstein decided to remain in the United States in 1933.
# - Albert Einstein was granted American citizenship in 1940.
# - Albert Einstein endorsed a letter to President Franklin D. Roosevelt in 1939.
# - President Franklin D. Roosevelt was alerted to the potential German nuclear weapons program in 1939.
# - Albert Einstein recommended that the United States begin similar research to the German nuclear weapons program in 1939.
# - The Manhattan Project was carried out as a result of Albert Einstein's recommendation in 1939.

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibyhrbzqdaqsz2lvpvaoenauadngqm3yvmd5qenxmafm7e5lqptbu",
#   "@type": [
#     "prov:Entity",
#     "repro:Data"
#   ],
#   "dcterms:identifier": "bafkreibyhrbzqdaqsz2lvpvaoenauadngqm3yvmd5qenxmafm7e5lqptbu",
#   "prov:label": "facts:1",
#   "_cell": 1,
#   "_type": "facts",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia2qair6n36lmezglslqlqf5zvfeiby4j2xgzzxqhmkyy45qncbuu"
#   }
# }
