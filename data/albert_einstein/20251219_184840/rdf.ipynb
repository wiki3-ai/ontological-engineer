# %% [markdown]
# # RDF Triples: Albert Einstein
#
# ## Provenance
#
# ```yaml
# source_url: https://en.wikipedia.org/wiki/Albert_Einstein
# article_title: Albert Einstein
# license: CC BY-SA 4.0
# license_url: https://creativecommons.org/licenses/by-sa/4.0/
# source_notebook: facts.ipynb
# generated_by: wiki_to_kg_pipeline.ipynb
# generated_at: 2025-12-19T18:48:41.272327
# llm_provider: lm_studio
# llm_model: qwen/qwen3-coder-30b
# llm_temperature: 1
# rdf_format: Turtle
# ```
#
# ## RDF Prefixes
#
# ```turtle
# @prefix schema: <https://schema.org/> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix wiki3: <https://wiki3.ai/vocab/> .
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix repro: <https://w3id.org/reproduceme#> .
# @prefix pplan: <http://purl.org/net/p-plan#> .
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @base <https://en.wikipedia.org/wiki/Albert_Einstein> .
#
# ```
#
# ## Processing Instructions
#
# This notebook contains RDF triples in Turtle format, one cell per source statement.
# Each content cell is followed by a signature cell with CID provenance.
#
# To regenerate a specific cell: delete both the content cell and its signature, then re-run the pipeline.
#
# ## Prompt Template
#
# ```
# You are an expert at converting factual statements to RDF triples in Turtle format.
#
# Convert the following factual statements to RDF using schema.org vocabulary where possible.
#
# Source: {source_url}
# Section: {breadcrumb}
#
# Use these prefixes:
# {prefixes}
#
# Entity registry (use these URIs):
# {entity_registry}
#
# Guidelines:
# - Use schema.org properties (schema:birthDate, schema:birthPlace, schema:worksFor, etc.)
# - For relationships not in schema.org, use wiki3: prefix
# - Include rdfs:label for entities
# - Use xsd datatypes for dates and numbers
# - Entity URIs should use the source URL as base with fragment identifiers
#
# ---
# {facts}
# ---
#
# Generate Turtle RDF:
#
# ```

# %% [raw]
# {
#   "source_url": "https://en.wikipedia.org/wiki/Albert_Einstein",
#   "entities": {
#     "albert_einstein": {
#       "id": "person_albert_einstein",
#       "uri": "https://en.wikipedia.org/wiki/Albert_Einstein",
#       "label": "Albert Einstein",
#       "type": "Person",
#       "descriptions": [
#         "Subject of Wikipedia article: Albert Einstein"
#       ],
#       "source_chunks": [],
#       "aliases": [
#         "Einstein"
#       ],
#       "wikidata_id": "Q937"
#     },
#     "ulm": {
#       "id": "thing_ulm",
#       "uri": "https://en.wikipedia.org/wiki/Ulm",
#       "label": "Ulm",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Ulm"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "kingdom_of_w_rttemberg": {
#       "id": "thing_kingdom_of_w_rttemberg",
#       "uri": "https://en.wikipedia.org/wiki/Kingdom_of_W%C3%BCrttemberg",
#       "label": "Kingdom of W\u00fcrttemberg",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Kingdom of W\u00fcrttemberg"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "german_empire": {
#       "id": "thing_german_empire",
#       "uri": "https://en.wikipedia.org/wiki/German_Empire",
#       "label": "German Empire",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: German Empire"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "princeton_new_jersey": {
#       "id": "thing_princeton_new_jersey",
#       "uri": "https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey",
#       "label": "Princeton, New Jersey",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Princeton, New Jersey"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "lieserl": {
#       "id": "thing_lieserl",
#       "uri": "https://en.wikipedia.org/wiki/Lieserl_Einstein",
#       "label": "Lieserl",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Lieserl"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "hans_albert": {
#       "id": "thing_hans_albert",
#       "uri": "https://en.wikipedia.org/wiki/Hans_Albert_Einstein",
#       "label": "Hans Albert",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Hans Albert"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "eduard_tete": {
#       "id": "thing_eduard_tete",
#       "uri": "https://en.wikipedia.org/wiki/Einstein_family",
#       "label": "Eduard \"Tete\"",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Eduard \"Tete\""
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "einstein": {
#       "id": "thing_einstein",
#       "uri": "https://en.wikipedia.org/wiki/Einstein_family",
#       "label": "Einstein",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Einstein"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "mileva_mari": {
#       "id": "thing_mileva_mari",
#       "uri": "https://en.wikipedia.org/wiki/Mileva_Mari%C4%87",
#       "label": "Mileva Mari\u0107",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Mileva Mari\u0107"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "elsa_l_wenthal": {
#       "id": "thing_elsa_l_wenthal",
#       "uri": "https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal",
#       "label": "Elsa L\u00f6wenthal",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Elsa L\u00f6wenthal"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "stateless": {
#       "id": "thing_stateless",
#       "uri": "https://en.wikipedia.org/wiki/Statelessness",
#       "label": "Stateless",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Stateless"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "switzerland": {
#       "id": "thing_switzerland",
#       "uri": "https://en.wikipedia.org/wiki/Switzerland",
#       "label": "Switzerland",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Switzerland"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "kingdom_of_prussia": {
#       "id": "thing_kingdom_of_prussia",
#       "uri": "https://en.wikipedia.org/wiki/Kingdom_of_Prussia",
#       "label": "Kingdom of Prussia",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Kingdom of Prussia"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "free_state_of_prussia": {
#       "id": "thing_free_state_of_prussia",
#       "uri": "https://en.wikipedia.org/wiki/Free_State_of_Prussia",
#       "label": "Free State of Prussia",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Free State of Prussia"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "weimar_republic": {
#       "id": "thing_weimar_republic",
#       "uri": "https://en.wikipedia.org/wiki/Weimar_Republic",
#       "label": "Weimar Republic",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Weimar Republic"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "united_states": {
#       "id": "thing_united_states",
#       "uri": "https://en.wikipedia.org/wiki/Citizenship_of_the_United_States",
#       "label": "United States",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: United States"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "physics": {
#       "id": "thing_physics",
#       "uri": "https://en.wikipedia.org/wiki/Physics",
#       "label": "Physics",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Physics"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "university_of_bern": {
#       "id": "thing_university_of_bern",
#       "uri": "https://en.wikipedia.org/wiki/University_of_Bern",
#       "label": "University of Bern",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: University of Bern"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "university_of_zurich": {
#       "id": "thing_university_of_zurich",
#       "uri": "https://en.wikipedia.org/wiki/University_of_Zurich",
#       "label": "University of Zurich",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: University of Zurich"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "charles_university_in_prague": {
#       "id": "thing_charles_university_in_prague",
#       "uri": "https://en.wikipedia.org/wiki/Charles_University_in_Prague",
#       "label": "Charles University in Prague",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Charles University in Prague"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "eth_zurich": {
#       "id": "thing_eth_zurich",
#       "uri": "https://en.wikipedia.org/wiki/ETH_Zurich",
#       "label": "ETH Zurich",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: ETH Zurich"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "prussian_academy_of_sciences": {
#       "id": "thing_prussian_academy_of_sciences",
#       "uri": "https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences",
#       "label": "Prussian Academy of Sciences",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Prussian Academy of Sciences"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "humboldt_university_of_berlin": {
#       "id": "thing_humboldt_university_of_berlin",
#       "uri": "https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin",
#       "label": "Humboldt University of Berlin",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Humboldt University of Berlin"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "kaiser_wilhelm_institute": {
#       "id": "thing_kaiser_wilhelm_institute",
#       "uri": "https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute",
#       "label": "Kaiser Wilhelm Institute",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Kaiser Wilhelm Institute"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "german_physical_society": {
#       "id": "thing_german_physical_society",
#       "uri": "https://en.wikipedia.org/wiki/German_Physical_Society",
#       "label": "German Physical Society",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: German Physical Society"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "institute_for_advanced_study": {
#       "id": "thing_institute_for_advanced_study",
#       "uri": "https://en.wikipedia.org/wiki/Institute_for_Advanced_Study",
#       "label": "Institute for Advanced Study",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Institute for Advanced Study"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "swiss_federal_polytechnic_school": {
#       "id": "thing_swiss_federal_polytechnic_school",
#       "uri": "https://en.wikipedia.org/wiki/ETH_Zurich",
#       "label": "Swiss Federal Polytechnic School",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Swiss Federal Polytechnic School"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "phd": {
#       "id": "thing_phd",
#       "uri": "https://en.wikipedia.org/wiki/PhD",
#       "label": "PhD",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: PhD"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "alfred_kleiner": {
#       "id": "thing_alfred_kleiner",
#       "uri": "https://en.wikipedia.org/wiki/Alfred_Kleiner",
#       "label": "Alfred Kleiner",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Alfred Kleiner"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "heinrich_friedrich_weber": {
#       "id": "thing_heinrich_friedrich_weber",
#       "uri": "https://en.wikipedia.org/wiki/Heinrich_Friedrich_Weber",
#       "label": "Heinrich Friedrich Weber",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Heinrich Friedrich Weber"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "general_relativity": {
#       "id": "thing_general_relativity",
#       "uri": "https://en.wikipedia.org/wiki/General_relativity",
#       "label": "General relativity",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: General relativity"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "special_relativity": {
#       "id": "thing_special_relativity",
#       "uri": "https://en.wikipedia.org/wiki/Special_relativity",
#       "label": "Special relativity",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Special relativity"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "photoelectric_effect": {
#       "id": "thing_photoelectric_effect",
#       "uri": "https://en.wikipedia.org/wiki/Photoelectric_effect",
#       "label": "Photoelectric effect",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Photoelectric effect"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "e_mc_sup_2_sup_mass_energy_equivalence": {
#       "id": "thing_e_mc_sup_2_sup_mass_energy_equivalence",
#       "uri": "https://en.wikipedia.org/wiki/Mass%E2%80%93energy_equivalence",
#       "label": "''E''=''mc''<sup>2</sup> (mass\u2013energy equivalence)",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: ''E''=''mc''<sup>2</sup> (mass\u2013energy equivalence)"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "e_hf_planck_einstein_relation": {
#       "id": "thing_e_hf_planck_einstein_relation",
#       "uri": "https://en.wikipedia.org/wiki/Planck%E2%80%93Einstein_relation",
#       "label": "''E''=''hf'' (Planck\u2013Einstein relation)",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: ''E''=''hf'' (Planck\u2013Einstein relation)"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "theory_of_brownian_motion": {
#       "id": "thing_theory_of_brownian_motion",
#       "uri": "https://en.wikipedia.org/wiki/Brownian_motion",
#       "label": "Theory of Brownian motion",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Theory of Brownian motion"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "einstein_field_equations": {
#       "id": "thing_einstein_field_equations",
#       "uri": "https://en.wikipedia.org/wiki/Einstein_field_equations",
#       "label": "Einstein field equations",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Einstein field equations"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "bose_einstein_statistics": {
#       "id": "thing_bose_einstein_statistics",
#       "uri": "https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_statistics",
#       "label": "Bose\u2013Einstein statistics",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Bose\u2013Einstein statistics"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "bose_einstein_condensate": {
#       "id": "thing_bose_einstein_condensate",
#       "uri": "https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_condensate",
#       "label": "Bose\u2013Einstein condensate",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Bose\u2013Einstein condensate"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "gravitational_wave": {
#       "id": "thing_gravitational_wave",
#       "uri": "https://en.wikipedia.org/wiki/Gravitational_wave",
#       "label": "Gravitational wave",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Gravitational wave"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "cosmological_constant": {
#       "id": "thing_cosmological_constant",
#       "uri": "https://en.wikipedia.org/wiki/Cosmological_constant",
#       "label": "Cosmological constant",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Cosmological constant"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "unified_field_theory": {
#       "id": "thing_unified_field_theory",
#       "uri": "https://en.wikipedia.org/wiki/Unified_field_theory",
#       "label": "Unified field theory",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Unified field theory"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "epr_paradox": {
#       "id": "thing_epr_paradox",
#       "uri": "https://en.wikipedia.org/wiki/EPR_paradox",
#       "label": "EPR paradox",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: EPR paradox"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "ensemble_interpretation": {
#       "id": "thing_ensemble_interpretation",
#       "uri": "https://en.wikipedia.org/wiki/Ensemble_interpretation",
#       "label": "Ensemble interpretation",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Ensemble interpretation"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "list_of_other_concepts": {
#       "id": "thing_list_of_other_concepts",
#       "uri": "https://en.wikipedia.org/wiki/List_of_things_named_after_Albert_Einstein",
#       "label": "List of other concepts",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: List of other concepts"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "barnard_medal_for_meritorious_service_to_science": {
#       "id": "thing_barnard_medal_for_meritorious_service_to_science",
#       "uri": "https://en.wikipedia.org/wiki/Barnard_Medal_for_Meritorious_Service_to_Science",
#       "label": "Barnard Medal for Meritorious Service to Science",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Barnard Medal for Meritorious Service to Science"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "nobel_prize_in_physics": {
#       "id": "thing_nobel_prize_in_physics",
#       "uri": "https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics",
#       "label": "Nobel Prize in Physics",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Nobel Prize in Physics"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "matteucci_medal": {
#       "id": "thing_matteucci_medal",
#       "uri": "https://en.wikipedia.org/wiki/Matteucci_Medal",
#       "label": "Matteucci Medal",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Matteucci Medal"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "formemrs": {
#       "id": "thing_formemrs",
#       "uri": "https://en.wikipedia.org/wiki/List_of_fellows_of_the_Royal_Society_elected_in_1921",
#       "label": "ForMemRS",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: ForMemRS"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     },
#     "copley_medal": {
#       "id": "thing_copley_medal",
#       "uri": "https://en.wikipedia.org/wiki/Copley_Medal",
#       "label": "Copley Medal",
#       "type": "Thing",
#       "descriptions": [
#         "Wikipedia entity: Copley Medal"
#       ],
#       "source_chunks": [],
#       "aliases": []
#     }
#   },
#   "aliases": {
#     "einstein": "albert_einstein"
#   }
# }

# %% [raw]
# # Statement [1.1]: [Albert Einstein](/wiki/Albert_Einstein) was born on 14 March 1879.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:birthDate "1879-03-14"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifz2hjyj5jr5lyfsdgqs26hdpjy5xfudw4etyaomrr2qpdgt2gq3i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifz2hjyj5jr5lyfsdgqs26hdpjy5xfudw4etyaomrr2qpdgt2gq3i",
#   "prov:label": "rdf:1_1",
#   "_cell": 2,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiazipa5t2o64vc2ckcsdd4w6e777giy7qp2zobg6dkbeutvmevxaq"
#   },
#   "_stmt_key": "1_1",
#   "_chunk_num": 1,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [1.2]: [Albert Einstein](/wiki/Albert_Einstein) was born in [Ulm](/wiki/Ulm).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:birthPlace https://en.wikipedia.org/wiki/Ulm .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibuphzaqrz54wdzpijuwvfepdyvwcvximjamddb2xayaexsn4nssu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibuphzaqrz54wdzpijuwvfepdyvwcvximjamddb2xayaexsn4nssu",
#   "prov:label": "rdf:1_2",
#   "_cell": 4,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiau7no73cwq424hhiyt45jj5opq2sv7djwqiumy2t4qk6z53ev43a"
#   },
#   "_stmt_key": "1_2",
#   "_chunk_num": 1,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [1.3]: [Ulm](/wiki/Ulm) was part of the [Kingdom of Württemberg](/wiki/Kingdom_of_Württemberg) in 1879.
# https://en.wikipedia.org/wiki/Ulm schema:containedInPlace https://en.wikipedia.org/wiki/Kingdom_of_W%C3%BCrttemberg .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihengsxefyxnzhot5g2hjv6h6pcllj77kzs2h5sxxqxcjqqhtxdbq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihengsxefyxnzhot5g2hjv6h6pcllj77kzs2h5sxxqxcjqqhtxdbq",
#   "prov:label": "rdf:1_3",
#   "_cell": 6,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiekxxsesgy4f4o5d6lukfyhept4y3qe6pz2jty3fwdsekxwbp5k54"
#   },
#   "_stmt_key": "1_3",
#   "_chunk_num": 1,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [1.4]: [Kingdom of Württemberg](/wiki/Kingdom_of_Württemberg) was part of the [German Empire](/wiki/German_Empire) in 1879.
# https://en.wikipedia.org/wiki/Kingdom_of_W%C3%BCrttemberg schema:containedInPlace https://en.wikipedia.org/wiki/German_Empire .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreierzywktpdpnpqcq5rrx3m5upqyobs2vqrz6nc3r5r4cxsabut3lu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreierzywktpdpnpqcq5rrx3m5upqyobs2vqrz6nc3r5r4cxsabut3lu",
#   "prov:label": "rdf:1_4",
#   "_cell": 8,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreievmklioubi6fcdsbleps4z4k3ngz3srereucko5s6blid7zrvh2y"
#   },
#   "_stmt_key": "1_4",
#   "_chunk_num": 1,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [1.5]: [Albert Einstein](/wiki/Albert_Einstein) died on 18 April 1955.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifr6dr4zfknuwx5fw6e3wf5xaio6dooeei7vpnqto2twfhv5q6xr4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifr6dr4zfknuwx5fw6e3wf5xaio6dooeei7vpnqto2twfhv5q6xr4",
#   "prov:label": "rdf:1_5",
#   "_cell": 10,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidvirzqgvtd4hdgwas4svphoo5x2sjxtb2fx3alguyqqeu5cixh74"
#   },
#   "_stmt_key": "1_5",
#   "_chunk_num": 1,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [1.6]: [Albert Einstein](/wiki/Albert_Einstein) died in [Princeton, New Jersey](/wiki/Princeton%2C_New_Jersey).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:deathPlace https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigpwdeihlnw636ftucpn6nu6pwju6rmzyksqfgqknomytz37neviu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigpwdeihlnw636ftucpn6nu6pwju6rmzyksqfgqknomytz37neviu",
#   "prov:label": "rdf:1_6",
#   "_cell": 12,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidk667javbq3mkzsfuzstlsvi2cfatpvw54qn2yluoqqn4onnr4oy"
#   },
#   "_stmt_key": "1_6",
#   "_chunk_num": 1,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [1.7]: [Princeton, New Jersey](/wiki/Princeton%2C_New_Jersey) is located in the U.S.
# https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey schema:containedInPlace https://en.wikipedia.org/wiki/United_States .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigfhufrzmkky4bfeqdrzogxck7a4v7aq6agyyoqcl4fkqk55jojw4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigfhufrzmkky4bfeqdrzogxck7a4v7aq6agyyoqcl4fkqk55jojw4",
#   "prov:label": "rdf:1_7",
#   "_cell": 14,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifly53udoithlcme3onyu7o6sjpyiw6x5miegdevjzfplfakhidg4"
#   },
#   "_stmt_key": "1_7",
#   "_chunk_num": 1,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [1.8]: [Albert Einstein](/wiki/Albert_Einstein) had children named [Lieserl](/wiki/Lieserl_Einstein), [Hans Albert](/wiki/Hans_Albert_Einstein), and [Eduard "Tete"](/wiki/Einstein_family).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:children https://en.wikipedia.org/wiki/Lieserl_Einstein .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:children https://en.wikipedia.org/wiki/Hans_Albert_Einstein .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:children https://en.wikipedia.org/wiki/Einstein_family .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiat4ixw4evxycnc765qntcvamcfzrnruyghvo2ktovo75kj4uv74m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiat4ixw4evxycnc765qntcvamcfzrnruyghvo2ktovo75kj4uv74m",
#   "prov:label": "rdf:1_8",
#   "_cell": 16,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib6awwfpi4dummayaaoeybviodmjffq6rtels2hgjxyv6m6xa54mq"
#   },
#   "_stmt_key": "1_8",
#   "_chunk_num": 1,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [1.9]: [Albert Einstein](/wiki/Albert_Einstein) belonged to the [Einstein](/wiki/Einstein_family) family.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:familyName "Einstein" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibctr6wurrpgrs6lrahu7es66sfuficd54rsjfyexsw2xx6oljpae",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibctr6wurrpgrs6lrahu7es66sfuficd54rsjfyexsw2xx6oljpae",
#   "prov:label": "rdf:1_9",
#   "_cell": 18,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidmdxtb52eojnfhebamm5newfycpfezdeo3rrqkiow3n66katfmce"
#   },
#   "_stmt_key": "1_9",
#   "_chunk_num": 1,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [1.10]: [Albert Einstein](/wiki/Albert_Einstein) held citizenship in the [Kingdom of Württemberg](/wiki/Kingdom_of_Württemberg) until 1896.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:nationality https://en.wikipedia.org/wiki/Kingdom_of_Württemberg .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:nationality _:s1_10_role1 .
# _:s1_10_role1 rdf:type schema:Role .
# _:s1_10_role1 schema:nationality https://en.wikipedia.org/wiki/Kingdom_of_Württemberg .
# _:s1_10_role1 schema:endDate "1896"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidqidm54vcajkcioy7prrxphjkixxj3xd4g6tv7mrsdz5djcr6wea",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidqidm54vcajkcioy7prrxphjkixxj3xd4g6tv7mrsdz5djcr6wea",
#   "prov:label": "rdf:1_10",
#   "_cell": 20,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreie2xgedzb35dme5kesutjruu3g5mutmptjgtmy624am5mpxjxhqjq"
#   },
#   "_stmt_key": "1_10",
#   "_chunk_num": 1,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [1.11]: [Albert Einstein](/wiki/Albert_Einstein) was stateless from 1896 to 1901.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:nationality https://en.wikipedia.org/wiki/Statelessness .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:nationality _:s1_11_role1 .
# _:s1_11_role1 rdf:type schema:Role .
# _:s1_11_role1 schema:nationality https://en.wikipedia.org/wiki/Statelessness .
# _:s1_11_role1 schema:startDate "1896"^^xsd:gYear .
# _:s1_11_role1 schema:endDate "1901"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibrog6u33kcmvrplkli2xjdvomcnjkwluqjs23jqqjvhbsoi3d2qm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibrog6u33kcmvrplkli2xjdvomcnjkwluqjs23jqqjvhbsoi3d2qm",
#   "prov:label": "rdf:1_11",
#   "_cell": 22,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiciy7ragz5ltuoxscmmtkqeeza2g252h53i5kamsm74kxli2s6bqm"
#   },
#   "_stmt_key": "1_11",
#   "_chunk_num": 1,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [1.12]: [Albert Einstein](/wiki/Albert_Einstein) held citizenship in [Switzerland](/wiki/Switzerland) from 1901 to 1955.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:nationality https://en.wikipedia.org/wiki/Switzerland .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:nationality _:s1_12_role1 .
# _:s1_12_role1 rdf:type schema:Role .
# _:s1_12_role1 schema:nationality https://en.wikipedia.org/wiki/Switzerland .
# _:s1_12_role1 schema:startDate "1901"^^xsd:gYear .
# _:s1_12_role1 schema:endDate "1955"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaceqwqhki52olehaqi7f2l2kgj3rct4evxsjfng63xg5hn3ul4sa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaceqwqhki52olehaqi7f2l2kgj3rct4evxsjfng63xg5hn3ul4sa",
#   "prov:label": "rdf:1_12",
#   "_cell": 24,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib2nmb3gssp2pivcgvfbaufezr2cn5hbs5lq35alutemaj3qcykjm"
#   },
#   "_stmt_key": "1_12",
#   "_chunk_num": 1,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [1.13]: [Albert Einstein](/wiki/Albert_Einstein) held citizenship in the [Kingdom of Prussia](/wiki/Kingdom_of_Prussia) from 1914 to 1918.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:nationality https://en.wikipedia.org/wiki/Kingdom_of_Prussia .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:nationality _:s1_13_role1 .
# _:s1_13_role1 rdf:type schema:Role .
# _:s1_13_role1 schema:nationality https://en.wikipedia.org/wiki/Kingdom_of_Prussia .
# _:s1_13_role1 schema:startDate "1914"^^xsd:gYear .
# _:s1_13_role1 schema:endDate "1918"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiffnhc7yrpwo6bxs7rkxueoml44ttrlxm4mk2cpaxiuuwy47jkrde",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiffnhc7yrpwo6bxs7rkxueoml44ttrlxm4mk2cpaxiuuwy47jkrde",
#   "prov:label": "rdf:1_13",
#   "_cell": 26,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreienrdehun4qxy3f44kbwnf3zftfnft4r3j4wd5bhexlkgtfc74iny"
#   },
#   "_stmt_key": "1_13",
#   "_chunk_num": 1,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [1.14]: [Albert Einstein](/wiki/Albert_Einstein) held citizenship in the [Free State of Prussia](/wiki/Free_State_of_Prussia) during the [Weimar Republic](/wiki/Weimar_Republic) from 1918 to 1933.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:nationality https://en.wikipedia.org/wiki/Free_State_of_Prussia .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:nationality _:s1_14_role1 .
# _:s1_14_role1 rdf:type schema:Role .
# _:s1_14_role1 schema:nationality https://en.wikipedia.org/wiki/Free_State_of_Prussia .
# _:s1_14_role1 schema:startDate "1918"^^xsd:gYear .
# _:s1_14_role1 schema:endDate "1933"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaghji5qcdt7xj7vwz4t3tu5yigaqzvvu4xcyhvjghfqbducxhlgy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaghji5qcdt7xj7vwz4t3tu5yigaqzvvu4xcyhvjghfqbducxhlgy",
#   "prov:label": "rdf:1_14",
#   "_cell": 28,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigdp2tugtvhdc43xiejvilkdnsju5oremx4lfokugcnssirxsuene"
#   },
#   "_stmt_key": "1_14",
#   "_chunk_num": 1,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [1.15]: [Albert Einstein](/wiki/Albert_Einstein) held citizenship in the [United States](/wiki/Citizenship_of_the_United_States) from 1940 to 1955.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:nationality https://en.wikipedia.org/wiki/Citizenship_of_the_United_States .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:nationality _:s1_15_role1 .
# _:s1_15_role1 rdf:type schema:Role .
# _:s1_15_role1 schema:nationality https://en.wikipedia.org/wiki/Citizenship_of_the_United_States .
# _:s1_15_role1 schema:startDate "1940"^^xsd:gYear .
# _:s1_15_role1 schema:endDate "1955"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiekcc5gakdmdvskqpe6lwtbe4unc5vj4nyufzsdd25ubr4a6w7u6m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiekcc5gakdmdvskqpe6lwtbe4unc5vj4nyufzsdd25ubr4a6w7u6m",
#   "prov:label": "rdf:1_15",
#   "_cell": 30,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreic23253sveexcmmjogwfix3v4g5m5ojqxngls4pqa6x66oumrg2xy"
#   },
#   "_stmt_key": "1_15",
#   "_chunk_num": 1,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [1.16]: [Albert Einstein](/wiki/Albert_Einstein) worked at the [University of Bern](/wiki/University_of_Bern) from 1908 to 1909.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:worksFor _:s1_16_role1 .
# _:s1_16_role1 rdf:type schema:OrganizationRole .
# _:s1_16_role1 schema:worksFor https://en.wikipedia.org/wiki/University_of_Bern .
# _:s1_16_role1 schema:startDate "1908"^^xsd:gYear .
# _:s1_16_role1 schema:endDate "1909"^^xsd:gYear .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:worksFor https://en.wikipedia.org/wiki/University_of_Bern .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiehvxlaancinybkirjhzta2b6q7ttgnx2f2rfavt5gejp3q4xxrje",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiehvxlaancinybkirjhzta2b6q7ttgnx2f2rfavt5gejp3q4xxrje",
#   "prov:label": "rdf:1_16",
#   "_cell": 32,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreievsu6eosthqzmazj4sfknkarbsvijrqgzdanpsx3lkarrr242ewe"
#   },
#   "_stmt_key": "1_16",
#   "_chunk_num": 1,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [1.17]: [Albert Einstein](/wiki/Albert_Einstein) worked at the [University of Zurich](/wiki/University_of_Zurich) from 1909 to 1911.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:worksFor _:s1_17_role1 .
# _:s1_17_role1 rdf:type schema:OrganizationRole .
# _:s1_17_role1 schema:worksFor https://en.wikipedia.org/wiki/University_of_Zurich .
# _:s1_17_role1 schema:startDate "1909"^^xsd:gYear .
# _:s1_17_role1 schema:endDate "1911"^^xsd:gYear .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:worksFor https://en.wikipedia.org/wiki/University_of_Zurich .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigngexvggbc4s33yqjponlxdrowbfkxkjddsoloeenl7iobnwfigy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigngexvggbc4s33yqjponlxdrowbfkxkjddsoloeenl7iobnwfigy",
#   "prov:label": "rdf:1_17",
#   "_cell": 34,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibd6sh22uermut67lsw6s6jadpbxqiexjzydw5epocy7bmubz5wvm"
#   },
#   "_stmt_key": "1_17",
#   "_chunk_num": 1,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [1.18]: [Albert Einstein](/wiki/Albert_Einstein) worked at [Charles University in Prague](/wiki/Charles_University_in_Prague) from 1911 to 1912.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:worksFor _:s1_18_role1 .
# _:s1_18_role1 rdf:type schema:OrganizationRole .
# _:s1_18_role1 schema:worksFor https://en.wikipedia.org/wiki/Charles_University_in_Prague .
# _:s1_18_role1 schema:startDate "1911"^^xsd:gYear .
# _:s1_18_role1 schema:endDate "1912"^^xsd:gYear .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:worksFor https://en.wikipedia.org/wiki/Charles_University_in_Prague .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiagw3272uwzweaj2fusw7w3bn3cjll64o6pulhmmkm4and76rxdce",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiagw3272uwzweaj2fusw7w3bn3cjll64o6pulhmmkm4and76rxdce",
#   "prov:label": "rdf:1_18",
#   "_cell": 36,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihuimevuiscy2zcqreugox72e7gg2nwa5wfmvnp2cicdv6cxtz74e"
#   },
#   "_stmt_key": "1_18",
#   "_chunk_num": 1,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [1.19]: [Albert Einstein](/wiki/Albert_Einstein) worked at [ETH Zurich](/wiki/ETH_Zurich) from 1912 to 1914.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:worksFor _:s1_19_role1 .
# _:s1_19_role1 rdf:type schema:OrganizationRole .
# _:s1_19_role1 schema:worksFor https://en.wikipedia.org/wiki/ETH_Zurich .
# _:s1_19_role1 schema:startDate "1912"^^xsd:gYear .
# _:s1_19_role1 schema:endDate "1914"^^xsd:gYear .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:worksFor https://en.wikipedia.org/wiki/ETH_Zurich .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifryf4qwqx622qstzcswiaopj47zmyasir2nkqayt6bzwqvfwtamy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifryf4qwqx622qstzcswiaopj47zmyasir2nkqayt6bzwqvfwtamy",
#   "prov:label": "rdf:1_19",
#   "_cell": 38,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreictx465nrqahngrzqabohwh2gkkrioznfbnzigcaniz5wwh7y2rvq"
#   },
#   "_stmt_key": "1_19",
#   "_chunk_num": 1,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Statement [1.20]: [Albert Einstein](/wiki/Albert_Einstein) worked at the [Prussian Academy of Sciences](/wiki/Prussian_Academy_of_Sciences) from 1914 to 1933.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:worksFor _:s1_20_role1 .
# _:s1_20_role1 rdf:type schema:OrganizationRole .
# _:s1_20_role1 schema:worksFor https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences .
# _:s1_20_role1 schema:startDate "1914"^^xsd:gYear .
# _:s1_20_role1 schema:endDate "1933"^^xsd:gYear .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:worksFor https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifvhaebxijchfysoq7onq5slezpj2m23dd57jx6rdznpnpmvjirly",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifvhaebxijchfysoq7onq5slezpj2m23dd57jx6rdznpnpmvjirly",
#   "prov:label": "rdf:1_20",
#   "_cell": 40,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieuzhirqwnwqt6uxodkadpb4ui6ppxqxpuil45kvjgce2htor2x2m"
#   },
#   "_stmt_key": "1_20",
#   "_chunk_num": 1,
#   "_stmt_idx": 20
# }

# %% [raw]
# # Statement [1.21]: [Albert Einstein](/wiki/Albert_Einstein) worked at the [Humboldt University of Berlin](/wiki/Humboldt_University_of_Berlin) from 1914 to 1933.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:worksFor _:s1_21_role1 .
# _:s1_21_role1 rdf:type schema:OrganizationRole .
# _:s1_21_role1 schema:worksFor https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin .
# _:s1_21_role1 schema:startDate "1914"^^xsd:gYear .
# _:s1_21_role1 schema:endDate "1933"^^xsd:gYear .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:worksFor https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifppvi6sdb77xtfc3vh4rz2inxy5oxi3yzmpw6x6jrd7wiqxb7n2a",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifppvi6sdb77xtfc3vh4rz2inxy5oxi3yzmpw6x6jrd7wiqxb7n2a",
#   "prov:label": "rdf:1_21",
#   "_cell": 42,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid5ueqjvtimgxqwov25wtne4mpl7gxqtv723drcsa4k2mvpizuj3m"
#   },
#   "_stmt_key": "1_21",
#   "_chunk_num": 1,
#   "_stmt_idx": 21
# }

# %% [raw]
# # Statement [1.22]: [Albert Einstein](/wiki/Albert_Einstein) was director of the [Kaiser Wilhelm Institute](/wiki/Kaiser_Wilhelm_Institute) from 1917 to 1933.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:worksFor _:s1_22_role1 .
# _:s1_22_role1 rdf:type schema:OrganizationRole .
# _:s1_22_role1 schema:worksFor https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute .
# _:s1_22_role1 schema:startDate "1917"^^xsd:gYear .
# _:s1_22_role1 schema:endDate "1933"^^xsd:gYear .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:worksFor https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiamut5uvlhtj7erejkzd2phcalic74hv2akzwycwlpcukhnk6kwei",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiamut5uvlhtj7erejkzd2phcalic74hv2akzwycwlpcukhnk6kwei",
#   "prov:label": "rdf:1_22",
#   "_cell": 44,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia3bor2octlztb4os2ufesjewu64v65wpn5vsyeiiocsxuigwjdba"
#   },
#   "_stmt_key": "1_22",
#   "_chunk_num": 1,
#   "_stmt_idx": 22
# }

# %% [raw]
# # Statement [1.23]: [Albert Einstein](/wiki/Albert_Einstein) was president of the [German Physical Society](/wiki/German_Physical_Society) from 1916 to 1918.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:worksFor _:s1_23_role1 .
# _:s1_23_role1 rdf:type schema:OrganizationRole .
# _:s1_23_role1 schema:worksFor https://en.wikipedia.org/wiki/German_Physical_Society .
# _:s1_23_role1 schema:startDate "1916"^^xsd:gYear .
# _:s1_23_role1 schema:endDate "1918"^^xsd:gYear .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:worksFor https://en.wikipedia.org/wiki/German_Physical_Society .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreib32pxpiq5cjiui2ddcb6ytme5icroxkseryrsmpzrgykhk4zuu7u",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreib32pxpiq5cjiui2ddcb6ytme5icroxkseryrsmpzrgykhk4zuu7u",
#   "prov:label": "rdf:1_23",
#   "_cell": 46,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreics635ncl6bxd3zn6ijx3r2efwdj7zh5wxwc4hdvddurn4cnbr3aa"
#   },
#   "_stmt_key": "1_23",
#   "_chunk_num": 1,
#   "_stmt_idx": 23
# }

# %% [raw]
# # Statement [1.24]: [Albert Einstein](/wiki/Albert_Einstein) worked at the [Institute for Advanced Study](/wiki/Institute_for_Advanced_Study) from 1933 to 1955.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:worksFor _:s1_24_role1 .
# _:s1_24_role1 rdf:type schema:OrganizationRole .
# _:s1_24_role1 schema:worksFor https://en.wikipedia.org/wiki/Institute_for_Advanced_Study .
# _:s1_24_role1 schema:startDate "1933"^^xsd:gYear .
# _:s1_24_role1 schema:endDate "1955"^^xsd:gYear .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:worksFor https://en.wikipedia.org/wiki/Institute_for_Advanced_Study .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreib3zwlpssyxva4hc2dyr7gd2grrmftdb3wr4j2ej6ae7w3a55fxna",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreib3zwlpssyxva4hc2dyr7gd2grrmftdb3wr4j2ej6ae7w3a55fxna",
#   "prov:label": "rdf:1_24",
#   "_cell": 48,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiezpofe4w54wfzsee2nzz6fjqlxej4bca5d7rqrftoqryv46j6e5e"
#   },
#   "_stmt_key": "1_24",
#   "_chunk_num": 1,
#   "_stmt_idx": 24
# }

# %% [raw]
# # Statement [1.25]: [Albert Einstein](/wiki/Albert_Einstein) studied at the [Swiss Federal Polytechnic School](/wiki/ETH_Zurich) and earned a teaching diploma in 1900.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:alumniOf https://en.wikipedia.org/wiki/ETH_Zurich .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreib5v5soimitsmti7a4ji56pxrnbmeycziy7hwmtrzl6ipr56jxpey",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreib5v5soimitsmti7a4ji56pxrnbmeycziy7hwmtrzl6ipr56jxpey",
#   "prov:label": "rdf:1_25",
#   "_cell": 50,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifgcbw7ymol2rue7b7k5imtvwd7agvj74k5tws265ovutkcuflsfq"
#   },
#   "_stmt_key": "1_25",
#   "_chunk_num": 1,
#   "_stmt_idx": 25
# }

# %% [raw]
# # Statement [1.26]: [Albert Einstein](/wiki/Albert_Einstein) earned a [PhD](/wiki/PhD) from the [University of Zurich](/wiki/University_of_Zurich) in 1905.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:hasCredential https://en.wikipedia.org/wiki/PhD .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:alumniOf _:s1_26_role1 .
# _:s1_26_role1 rdf:type schema:OrganizationRole .
# _:s1_26_role1 schema:alumniOf https://en.wikipedia.org/wiki/University_of_Zurich .
# _:s1_26_role1 schema:startDate "1905"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigbjtvkac7afh42566v5gg5hjm6clywudv24l4x6wcjhh3tkhjd5e",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigbjtvkac7afh42566v5gg5hjm6clywudv24l4x6wcjhh3tkhjd5e",
#   "prov:label": "rdf:1_26",
#   "_cell": 52,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreie233uvjmymv5xrx3gmnlluiqzcewf5zliylfbautpl2nzkvoklku"
#   },
#   "_stmt_key": "1_26",
#   "_chunk_num": 1,
#   "_stmt_idx": 26
# }

# %% [raw]
# # Statement [1.27]: [Alfred Kleiner](/wiki/Alfred_Kleiner) was the doctoral advisor of [Albert Einstein](/wiki/Albert_Einstein).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:hasOccupation https://en.wikipedia.org/wiki/Physics .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:hasOccupation _:s1_27_role1 .
# _:s1_27_role1 rdf:type schema:Role .
# _:s1_27_role1 schema:hasOccupation https://en.wikipedia.org/wiki/Physics .
# _:s1_27_role1 schema:startDate "1905"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic37h324fowmordrjgghrl657bos3ao5mu5wmzawuctqao4rvjyni",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic37h324fowmordrjgghrl657bos3ao5mu5wmzawuctqao4rvjyni",
#   "prov:label": "rdf:1_27",
#   "_cell": 54,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiacvmz52uvede5qzh6qrmfd7a4srd7xuzm3ooioh5noy37rsptiee"
#   },
#   "_stmt_key": "1_27",
#   "_chunk_num": 1,
#   "_stmt_idx": 27
# }

# %% [raw]
# # Statement [1.28]: [Albert Einstein](/wiki/Albert_Einstein) specialized in the field of [Physics](/wiki/Physics).
# https://en.wikipedia.org/wiki/Alfred_Kleiner schema:hasOccupation https://en.wikipedia.org/wiki/Physics .
# https://en.wikipedia.org/wiki/Alfred_Kleiner schema:hasOccupation _:s1_28_role1 .
# _:s1_28_role1 rdf:type schema:Role .
# _:s1_28_role1 schema:hasOccupation https://en.wikipedia.org/wiki/Physics .
# _:s1_28_role1 schema:startDate "1905"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiantuxghrl2lvhutwgdtwqa5vvvwud3ds5vhydndnyqpnih6svlz4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiantuxghrl2lvhutwgdtwqa5vvvwud3ds5vhydndnyqpnih6svlz4",
#   "prov:label": "rdf:1_28",
#   "_cell": 56,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid7lolwifjnblpdlx4kyljjoy2r4i3qpem5k5bcmdxrfht3zqrzbq"
#   },
#   "_stmt_key": "1_28",
#   "_chunk_num": 1,
#   "_stmt_idx": 28
# }

# %% [raw]
# # Statement [2.1]: [Albert Einstein](/wiki/Albert_Einstein) was advised by [Alfred Kleiner](/wiki/Alfred_Kleiner) for his doctoral studies.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasCredential <https://en.wikipedia.org/wiki/PhD> .
# _:s1_role1 rdf:type schema:Role .
# _:s1_role1 schema:advisor <https://en.wikipedia.org/wiki/Alfred_Kleiner> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award <https://en.wikipedia.org/wiki/Barnard_Medal_for_Meritorious_Service_to_Science> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award <https://en.wikipedia.org/wiki/List_of_fellows_of_the_Royal_Society_elected_in_1921> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award <https://en.wikipedia.org/wiki/Max_Planck_Medal> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/General_relativity> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Mass%E2%80%93energy_equivalence> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Einstein_field_equations> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Gravitational_wave> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/EPR_paradox> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Bern> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor <https://en.wikipedia.org/wiki/ETH_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality <https://en.wikipedia.org/wiki/Switzerland> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality <https://en.wikipedia.org/wiki/Weimar_Republic> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:birthPlace <https://en.wikipedia.org/wiki/Ulm> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:spouse <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:child <https://en.wikipedia.org/wiki/Hans_Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:jobTitle "Physicist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:homeLocation <https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasOccupation <https://en.wikipedia.org/wiki/Physics> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/ETH_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:memberOf <https://en.wikipedia.org/wiki/Member_of_the_National_Academy_of_Sciences> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor <https://en.wikipedia.org/wiki/University_of_Bern> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:advisor <https://en.wikipedia.org/wiki/Alfred_Kleiner> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:inSupportOf "Eine neue Bestimmung der Moleküldimensionen" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieowzmp24nc4m7kp3purdionl4etuqqycjavv2ycanbkmcqri5cae",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieowzmp24nc4m7kp3purdionl4etuqqycjavv2ycanbkmcqri5cae",
#   "prov:label": "rdf:2_1",
#   "_cell": 58,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihrvmlnmrrytxy5rouf2httae6uczl3f3olkhxniz2olv5sfas4ee"
#   },
#   "_stmt_key": "2_1",
#   "_chunk_num": 2,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [2.2]: [Albert Einstein](/wiki/Albert_Einstein) wrote the thesis titled "Eine neue Bestimmung der Moleküldimensionen" in 1905.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasCredential <https://en.wikipedia.org/wiki/PhD> .
# _:s2_role1 rdf:type schema:Role .
# _:s2_role1 schema:inSupportOf "Eine neue Bestimmung der Moleküldimensionen" .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award <https://en.wikipedia.org/wiki/Copley_Medal> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award <https://en.wikipedia.org/wiki/Member_of_the_National_Academy_of_Sciences> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Special_relativity> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Planck%E2%80%93Einstein_relation> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_statistics> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Cosmological_constant> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Ensemble_interpretation> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor <https://en.wikipedia.org/wiki/German_Physical_Society> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality <https://en.wikipedia.org/wiki/German_Empire> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality <https://en.wikipedia.org/wiki/Citizenship_of_the_United_States> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:birthPlace <https://en.wikipedia.org/wiki/Kingdom_of_W%C3%BCrttemberg> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:spouse <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:child <https://en.wikipedia.org/wiki/Einstein_family> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:jobTitle "Scientist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:homeLocation <https://en.wikipedia.org/wiki/Switzerland> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasOccupation <https://en.wikipedia.org/wiki/Science> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/German_Physical_Society> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:memberOf <https://en.wikipedia.org/wiki/List_of_fellows_of_the_Royal_Society_elected_in_1921> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor <https://en.wikipedia.org/wiki/ETH_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor <https://en.wikipedia.org/wiki/University_of_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:advisor <https://en.wikipedia.org/wiki/Heinrich_Friedrich_Weber> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:inSupportOf "Eine neue Bestimmung der Moleküldimensionen" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidbrlspgh5cdngnssy5iawzecc6fvlkby6bexabm42ani5hrefj6i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidbrlspgh5cdngnssy5iawzecc6fvlkby6bexabm42ani5hrefj6i",
#   "prov:label": "rdf:2_2",
#   "_cell": 60,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib4zaan56wm7eprs4p4jes4vdcrtz7qgprayq4l6tjyq56bszleai"
#   },
#   "_stmt_key": "2_2",
#   "_chunk_num": 2,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [2.3]: [Albert Einstein](/wiki/Albert_Einstein) was advised by [Heinrich Friedrich Weber](/wiki/Heinrich_Friedrich_Weber) during his academic career.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasCredential <https://en.wikipedia.org/wiki/PhD> .
# _:s3_role1 rdf:type schema:Role .
# _:s3_role1 schema:advisor <https://en.wikipedia.org/wiki/Heinrich_Friedrich_Weber> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award <https://en.wikipedia.org/wiki/Matteucci_Medal> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award <https://en.wikipedia.org/wiki/Gold_Medal_of_the_Royal_Astronomical_Society> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award <https://en.wikipedia.org/wiki/Time_100%3A_The_Most_Important_People_of_the_Century> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Photoelectric_effect> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Brownian_motion> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_condensate> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Unified_field_theory> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/List_of_things_named_after_Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Charles_University_in_Prague> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality <https://en.wikipedia.org/wiki/Free_State_of_Prussia> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality <https://en.wikipedia.org/wiki/Statelessness> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:birthPlace <https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:child <https://en.wikipedia.org/wiki/Lieserl_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:jobTitle "Researcher" .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:memberOf <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor <https://en.wikipedia.org/wiki/German_Physical_Society> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor <https://en.wikipedia.org/wiki/Charles_University_in_Prague> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:inSupportOf "Eine neue Bestimmung der Moleküldimensionen" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicy44miai46no6nd4t5okeylqofbpe6bjtsyat7qgs4v6pjd4fjgi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicy44miai46no6nd4t5okeylqofbpe6bjtsyat7qgs4v6pjd4fjgi",
#   "prov:label": "rdf:2_3",
#   "_cell": 62,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifmayo2uiq3ufqtnssg3c6sgrnbpwefo4xqdrdmj7fgpyepkfozfy"
#   },
#   "_stmt_key": "2_3",
#   "_chunk_num": 2,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [2.4]: [Albert Einstein](/wiki/Albert_Einstein) is known for [General relativity](/wiki/General_relativity).
# # No triples emitted for this statement
# # Debug: 438 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_role1", "predicate": "rdf:type", "object_value": "schema:Role"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_role1", "predicate": "rdf:type", "object_value": "schema:Role"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifcwvhkyjih77ah3m4nofkfoar6qoit3lqcuvdpy3hzd67xdjtppq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifcwvhkyjih77ah3m4nofkfoar6qoit3lqcuvdpy3hzd67xdjtppq",
#   "prov:label": "rdf:2_4",
#   "_cell": 64,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicu3uak66xavhj7ne76tu2prpniqxpv73nmob7xxobqkvjftkwkgi"
#   },
#   "_stmt_key": "2_4",
#   "_chunk_num": 2,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [2.5]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Special relativity](/wiki/Special_relativity).
# # No triples emitted for this statement
# # Debug: 438 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_role1", "predicate": "rdf:type", "object_value": "schema:Role"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_role1", "predicate": "rdf:type", "object_value": "schema:Role"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigavjnxz4q2mlnxxxgukdyeere52zqotibpqal3lqtrl3zs7t3jua",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigavjnxz4q2mlnxxxgukdyeere52zqotibpqal3lqtrl3zs7t3jua",
#   "prov:label": "rdf:2_5",
#   "_cell": 66,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiagxfrb22mjhekk6pyjkg4n4rqkw6nrc46ccf72puoooadjp3skre"
#   },
#   "_stmt_key": "2_5",
#   "_chunk_num": 2,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [2.6]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Photoelectric effect](/wiki/Photoelectric_effect).
# # No triples emitted for this statement
# # Debug: 438 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_role1", "predicate": "rdf:type", "object_value": "schema:Role"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_role1", "predicate": "rdf:type", "object_value": "schema:Role"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicn6gypbmwqgu2rc2nlowk6sizcpeiyk4x35jhri6k5adi6nrbjhm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicn6gypbmwqgu2rc2nlowk6sizcpeiyk4x35jhri6k5adi6nrbjhm",
#   "prov:label": "rdf:2_6",
#   "_cell": 68,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifaxsyobkrqvmesrh2rtvc2ynjkdtdecuq5w742unnwyydvtcbudu"
#   },
#   "_stmt_key": "2_6",
#   "_chunk_num": 2,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [2.7]: [Albert Einstein](/wiki/Albert_Einstein) is known for [''E''=''mc''<sup>2</sup> (mass–energy equivalence)](/wiki/Mass%E2%80%93energy_equivalence).
# # No triples emitted for this statement
# # Debug: 438 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_role1", "predicate": "rdf:type", "object_value": "schema:Role"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_role1", "predicate": "rdf:type", "object_value": "schema:Role"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibmghg4unmjcv2gptqtvekjggsiojcmasplztbk7qcsx5vizfiaqy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibmghg4unmjcv2gptqtvekjggsiojcmasplztbk7qcsx5vizfiaqy",
#   "prov:label": "rdf:2_7",
#   "_cell": 70,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicuagvycaq6pwvw6tilzqlemxepyqi2visziaoxx2pid6jbwpvx3a"
#   },
#   "_stmt_key": "2_7",
#   "_chunk_num": 2,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [2.8]: [Albert Einstein](/wiki/Albert_Einstein) is known for [''E''=''hf'' (Planck–Einstein relation)](/wiki/Planck%E2%80%93Einstein_relation).
# # No triples emitted for this statement
# # Debug: 438 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_role1", "predicate": "rdf:type", "object_value": "schema:Role"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_role1", "predicate": "rdf:type", "object_value": "schema:Role"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie5monco5naas3ywcohm76hh4536z4bbokbiaq2adneqg47wb65bu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie5monco5naas3ywcohm76hh4536z4bbokbiaq2adneqg47wb65bu",
#   "prov:label": "rdf:2_8",
#   "_cell": 72,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiflyw2xzfu5mtm2kannkgqzwzzambi5nzv7pvt2gvx5a4oitngmn4"
#   },
#   "_stmt_key": "2_8",
#   "_chunk_num": 2,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [2.9]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Theory of Brownian motion](/wiki/Brownian_motion).
# # No triples emitted for this statement
# # Debug: 438 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_role1", "predicate": "rdf:type", "object_value": "schema:Role"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_role1", "predicate": "rdf:type", "object_value": "schema:Role"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia26mjngpmtzcuq5z2y3qbveeyhls4b7thnkbgoe7bvxaosgo4one",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia26mjngpmtzcuq5z2y3qbveeyhls4b7thnkbgoe7bvxaosgo4one",
#   "prov:label": "rdf:2_9",
#   "_cell": 74,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigcppcp6zphwdqruwi2nhleq4jp67bluezfla7jz7uls7mi3iij7q"
#   },
#   "_stmt_key": "2_9",
#   "_chunk_num": 2,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [2.10]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Einstein field equations](/wiki/Einstein_field_equations).
# # No triples emitted for this statement
# # Debug: 438 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_role1", "predicate": "rdf:type", "object_value": "schema:Role"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_role1", "predicate": "rdf:type", "object_value": "schema:Role"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreib43dqus5qik4y4azo2ziiyx3usvhwsi7cthvmwxlakzi34qikyta",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreib43dqus5qik4y4azo2ziiyx3usvhwsi7cthvmwxlakzi34qikyta",
#   "prov:label": "rdf:2_10",
#   "_cell": 76,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifehzyxbzedtcfsyr676smhvjrymohsdvze3vcmntsjap6nc3sspa"
#   },
#   "_stmt_key": "2_10",
#   "_chunk_num": 2,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [2.11]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Bose–Einstein statistics](/wiki/Bose%E2%80%93Einstein_statistics).
# # No triples emitted for this statement
# # Debug: 438 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_role1", "predicate": "rdf:type", "object_value": "schema:Role"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_role1", "predicate": "rdf:type", "object_value": "schema:Role"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihzlfufrtwdnbjujbvv2ysuk3cqldncppgjeowshrfu33kj4cceie",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihzlfufrtwdnbjujbvv2ysuk3cqldncppgjeowshrfu33kj4cceie",
#   "prov:label": "rdf:2_11",
#   "_cell": 78,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaj5u7xholi3snu3cmehhfpj3h7uzdluba3npjpuy2f4hr7glaejm"
#   },
#   "_stmt_key": "2_11",
#   "_chunk_num": 2,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [2.12]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Bose–Einstein condensate](/wiki/Bose%E2%80%93Einstein_condensate).
# # No triples emitted for this statement
# # Debug: 438 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_role1", "predicate": "rdf:type", "object_value": "schema:Role"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_role1", "predicate": "rdf:type", "object_value": "schema:Role"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiervr5f7h6pnrx6dhoqi7b4favvbh7fdgivxc2ua66il6ud4f2wkq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiervr5f7h6pnrx6dhoqi7b4favvbh7fdgivxc2ua66il6ud4f2wkq",
#   "prov:label": "rdf:2_12",
#   "_cell": 80,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreielxmnpz766h4zqpovoax3cvnbxybajthd6gk3cn5cfaomlbrdqnq"
#   },
#   "_stmt_key": "2_12",
#   "_chunk_num": 2,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [2.13]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Gravitational wave](/wiki/Gravitational_wave).
# # No triples emitted for this statement
# # Debug: 438 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_role1", "predicate": "rdf:type", "object_value": "schema:Role"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_role1", "predicate": "rdf:type", "object_value": "schema:Role"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihpgdzdt6uzyfniqlnhoegqboyn2wtiremz6g3jmxgkf3fcl5hmau",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihpgdzdt6uzyfniqlnhoegqboyn2wtiremz6g3jmxgkf3fcl5hmau",
#   "prov:label": "rdf:2_13",
#   "_cell": 82,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiatvzjbjzxzbtc2e7hg3gw752lexqmq2bnhebt4b2acu7eniv7k3i"
#   },
#   "_stmt_key": "2_13",
#   "_chunk_num": 2,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [2.14]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Cosmological constant](/wiki/Cosmological_constant).
# # No triples emitted for this statement
# # Debug: 438 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_role1", "predicate": "rdf:type", "object_value": "schema:Role"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_role1", "predicate": "rdf:type", "object_value": "schema:Role"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifpnohspi2uqrsfm7kcccbqku6wdjc4isyd57kzccoahooyakalem",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifpnohspi2uqrsfm7kcccbqku6wdjc4isyd57kzccoahooyakalem",
#   "prov:label": "rdf:2_14",
#   "_cell": 84,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiezea3u4gvpuq7sys3cyhyfce6wpgrcn7scjxezhiwxt3s2ba6b2a"
#   },
#   "_stmt_key": "2_14",
#   "_chunk_num": 2,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [2.15]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Unified field theory](/wiki/Unified_field_theory).
# # No triples emitted for this statement
# # Debug: 438 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_role1", "predicate": "rdf:type", "object_value": "schema:Role"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_role1", "predicate": "rdf:type", "object_value": "schema:Role"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidrtqx6l6sw5aglmwvgjl6zycoevzk5gjidsvi2jwlo7ktb3ko3tu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidrtqx6l6sw5aglmwvgjl6zycoevzk5gjidsvi2jwlo7ktb3ko3tu",
#   "prov:label": "rdf:2_15",
#   "_cell": 86,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiewdffpjayuf5brypv5hwzf6f3tzg32sn3gvw3pg2kul4gt7v5vxu"
#   },
#   "_stmt_key": "2_15",
#   "_chunk_num": 2,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [2.16]: [Albert Einstein](/wiki/Albert_Einstein) is known for [EPR paradox](/wiki/EPR_paradox).
# # No triples emitted for this statement
# # Debug: 438 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_role1", "predicate": "rdf:type", "object_value": "schema:Role"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_role1", "predicate": "rdf:type", "object_value": "schema:Role"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreif4cashaaezbdiwpetixtesbwjkr4smyhekzi3pihmxfnu22czrma",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreif4cashaaezbdiwpetixtesbwjkr4smyhekzi3pihmxfnu22czrma",
#   "prov:label": "rdf:2_16",
#   "_cell": 88,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid6zg4j57b74owvy5phc3muafiv7qyqpovwdegyd5apabj2p7nqyq"
#   },
#   "_stmt_key": "2_16",
#   "_chunk_num": 2,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [2.17]: [Albert Einstein](/wiki/Albert_Einstein) is known for [Ensemble interpretation](/wiki/Ensemble_interpretation).
# # No triples emitted for this statement
# # Debug: 438 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_role1", "predicate": "rdf:type", "object_value": "schema:Role"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_role1", "predicate": "rdf:type", "object_value": "schema:Role"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia4slweyy2z4kwoihmhyqfuoa46mu4bgiwubhlt2tpb3cw4nh6oaa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia4slweyy2z4kwoihmhyqfuoa46mu4bgiwubhlt2tpb3cw4nh6oaa",
#   "prov:label": "rdf:2_17",
#   "_cell": 90,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiev3ati7afcekanyr3mnmj2hrgtv4oj65ldi6mi4upv6ljkncq2am"
#   },
#   "_stmt_key": "2_17",
#   "_chunk_num": 2,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [2.18]: [Albert Einstein](/wiki/Albert_Einstein) is known for [List of other concepts](/wiki/List_of_things_named_after_Albert_Einstein).
# # No triples emitted for this statement
# # Debug: 438 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_role1", "predicate": "rdf:type", "object_value": "schema:Role"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_role1", "predicate": "rdf:type", "object_value": "schema:Role"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiafsuqth6y4ofbpgqp2mabk6zbialwe2m2d63eog5vj333ucbd2l4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiafsuqth6y4ofbpgqp2mabk6zbialwe2m2d63eog5vj333ucbd2l4",
#   "prov:label": "rdf:2_18",
#   "_cell": 92,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieoe2ctrubpli6cohaofoqihkujopnlee6w6sk5g2hgafelhfmkwi"
#   },
#   "_stmt_key": "2_18",
#   "_chunk_num": 2,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [2.19]: [Albert Einstein](/wiki/Albert_Einstein) received the [Barnard Medal for Meritorious Service to Science](/wiki/Barnard_Medal_for_Meritorious_Service_to_Science) in 1920.
# # No triples emitted for this statement
# # Debug: 438 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_role1", "predicate": "rdf:type", "object_value": "schema:Role"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_role1", "predicate": "rdf:type", "object_value": "schema:Role"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreih7rmn244wcsztn6wpgn3a7wogrs5wd4ruektvbisissjpe7bkur4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreih7rmn244wcsztn6wpgn3a7wogrs5wd4ruektvbisissjpe7bkur4",
#   "prov:label": "rdf:2_19",
#   "_cell": 94,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicgs3ugk6qnqjzrdto7glvclv5ker2r6xjbq3nm25qcgm7p6ds7qy"
#   },
#   "_stmt_key": "2_19",
#   "_chunk_num": 2,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Statement [2.20]: [Albert Einstein](/wiki/Albert_Einstein) received the [Nobel Prize in Physics](/wiki/Nobel_Prize_in_Physics) in 1921.
# # No triples emitted for this statement
# # Debug: 438 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_role1", "predicate": "rdf:type", "object_value": "schema:Role"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_role1", "predicate": "rdf:type", "object_value": "schema:Role"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigykntu265l2wykwv2k222xivmvxsia2ycakmumej34v6nfgn3xty",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigykntu265l2wykwv2k222xivmvxsia2ycakmumej34v6nfgn3xty",
#   "prov:label": "rdf:2_20",
#   "_cell": 96,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicafafidol4ikdvckqeads22s57rmdwibxyphori7zonbnjfr2wlq"
#   },
#   "_stmt_key": "2_20",
#   "_chunk_num": 2,
#   "_stmt_idx": 20
# }

# %% [raw]
# # Statement [2.21]: [Albert Einstein](/wiki/Albert_Einstein) received the [Matteucci Medal](/wiki/Matteucci_Medal) in 1921.
# # No triples emitted for this statement
# # Debug: 438 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_role1", "predicate": "rdf:type", "object_value": "schema:Role"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_role1", "predicate": "rdf:type", "object_value": "schema:Role"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihoylj62wrnjevnuxqww3puhtpfqhhsst5jq6i5pmegqo7f26wtum",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihoylj62wrnjevnuxqww3puhtpfqhhsst5jq6i5pmegqo7f26wtum",
#   "prov:label": "rdf:2_21",
#   "_cell": 98,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreic565x3sexx57x33sxa4cfjmmwowhpccap5sb6agavcnxvw7hyexm"
#   },
#   "_stmt_key": "2_21",
#   "_chunk_num": 2,
#   "_stmt_idx": 21
# }

# %% [raw]
# # Statement [2.22]: [Albert Einstein](/wiki/Albert_Einstein) received [ForMemRS](/wiki/List_of_fellows_of_the_Royal_Society_elected_in_1921) in 1921.
# # No triples emitted for this statement
# # Debug: 438 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_role1", "predicate": "rdf:type", "object_value": "schema:Role"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_role1", "predicate": "rdf:type", "object_value": "schema:Role"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihwascempcavstaoh3zhgeugs7seltn2jy255suvd7wxpnrdczgoe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihwascempcavstaoh3zhgeugs7seltn2jy255suvd7wxpnrdczgoe",
#   "prov:label": "rdf:2_22",
#   "_cell": 100,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiespyl6bfkyelexbvbeaki6mhww5ih6at65vfaljgyd6vpknzffsq"
#   },
#   "_stmt_key": "2_22",
#   "_chunk_num": 2,
#   "_stmt_idx": 22
# }

# %% [raw]
# # Statement [2.23]: [Albert Einstein](/wiki/Albert_Einstein) received the [Copley Medal](/wiki/Copley_Medal) in 1925.
# # No triples emitted for this statement
# # Debug: 438 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_role1", "predicate": "rdf:type", "object_value": "schema:Role"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_role1", "predicate": "rdf:type", "object_value": "schema:Role"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie4vjnnwpuq7vlrwqbubjcmk7qgwywaemlplxyfx45t3v4ldtow34",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie4vjnnwpuq7vlrwqbubjcmk7qgwywaemlplxyfx45t3v4ldtow34",
#   "prov:label": "rdf:2_23",
#   "_cell": 102,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibi344loetra2smqz3pq5xnjeiro2zzuipli53q5fxmfquedi2vye"
#   },
#   "_stmt_key": "2_23",
#   "_chunk_num": 2,
#   "_stmt_idx": 23
# }

# %% [raw]
# # Statement [2.24]: [Albert Einstein](/wiki/Albert_Einstein) received the [Gold Medal of RAS](/wiki/Gold_Medal_of_the_Royal_Astronomical_Society) in 1926.
# # No triples emitted for this statement
# # Debug: 438 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_role1", "predicate": "rdf:type", "object_value": "schema:Role"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_role1", "predicate": "rdf:type", "object_value": "schema:Role"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidya4fnxwq7nk5tjejzqtw2bgzkjriwc4aghyfacp64z74dmhyegu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidya4fnxwq7nk5tjejzqtw2bgzkjriwc4aghyfacp64z74dmhyegu",
#   "prov:label": "rdf:2_24",
#   "_cell": 104,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreickqixxats5vv35tynfsznd7jafuvktv7ddbtzyeenmlrvrn2g27y"
#   },
#   "_stmt_key": "2_24",
#   "_chunk_num": 2,
#   "_stmt_idx": 24
# }

# %% [raw]
# # Statement [2.25]: [Albert Einstein](/wiki/Albert_Einstein) received the [Max Planck Medal](/wiki/Max_Planck_Medal) in 1929.
# # No triples emitted for this statement
# # Debug: 438 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_role1", "predicate": "rdf:type", "object_value": "schema:Role"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_role1", "predicate": "rdf:type", "object_value": "schema:Role"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigutbq45ns2zemhxwrmqt4olptc7v4n5uppktcvse7qmh3feqrv7m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigutbq45ns2zemhxwrmqt4olptc7v4n5uppktcvse7qmh3feqrv7m",
#   "prov:label": "rdf:2_25",
#   "_cell": 106,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiapimlwycvrdd2km4563v625ncoi3relezrqv64hk2u47k4pdoume"
#   },
#   "_stmt_key": "2_25",
#   "_chunk_num": 2,
#   "_stmt_idx": 25
# }

# %% [raw]
# # Statement [2.26]: [Albert Einstein](/wiki/Albert_Einstein) was elected a member of the [National Academy of Sciences](/wiki/Member_of_the_National_Academy_of_Sciences) in 1942.
# # No triples emitted for this statement
# # Debug: 438 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_role1", "predicate": "rdf:type", "object_value": "schema:Role"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_role1", "predicate": "rdf:type", "object_value": "schema:Role"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifdwe6ktsol4ax2c3u5iwizrmaisrancirnurzobnngiazcbdtq6m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifdwe6ktsol4ax2c3u5iwizrmaisrancirnurzobnngiazcbdtq6m",
#   "prov:label": "rdf:2_26",
#   "_cell": 108,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidejo4bfokb3cixme672toxmijsrypxrgo6vcxazmcfslr6axw5x4"
#   },
#   "_stmt_key": "2_26",
#   "_chunk_num": 2,
#   "_stmt_idx": 26
# }

# %% [raw]
# # Statement [2.27]: [Albert Einstein](/wiki/Albert_Einstein) was named [''Time'' Person of the Century](/wiki/Time_100%3A_The_Most_Important_People_of_the_Century) in 1999.
# # No triples emitted for this statement
# # Debug: 438 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:hasCredential", "object_value": "<https://en.wikipedia.org/wiki/PhD>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_role1", "predicate": "rdf:type", "object_value": "schema:Role"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_role1", "predicate": "rdf:type", "object_value": "schema:Role"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaidfpnh2dehhkw4n5senfzvrhklwifsmoq7okkdms3yht5xxqvda",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaidfpnh2dehhkw4n5senfzvrhklwifsmoq7okkdms3yht5xxqvda",
#   "prov:label": "rdf:2_27",
#   "_cell": 110,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigcxfm2qutcg5i6nchg2yvwxh7qaaq2d346pvzeydplelo6chsm4a"
#   },
#   "_stmt_key": "2_27",
#   "_chunk_num": 2,
#   "_stmt_idx": 27
# }

# %% [raw]
# # Chunk 3 Error: APITimeoutError: Request timed out.
# #
# # === FULL PROMPT SENT TO LLM ===
# #
# # SYSTEM PROMPT:
# # You are an expert at converting factual statements to RDF triples.
# #
# # The statements contain markdown links like [Entity Name](/wiki/Entity_Name) that provide Wikipedia URIs for entities.
# # Convert these to proper RDF URIs using: <https://en.wikipedia.org/wiki/Entity_Name>
# #
# # You have access to these tools:
# #
# # LOOKUP TOOLS (use first to find correct vocabulary):
# # - find_rdf_class: Find the best schema.org class/type for an entity
# # - find_rdf_property: Find the best predicate for a relationship
# #
# # OUTPUT TOOLS (use to emit your triples - MUST include statement_id):
# # - emit_triple: Output a single triple with statement_id
# # - emit_triples: Output multiple triples at once (more efficient)
# #
# # WORKFLOW:
# # 1. For each statement, identify what kind of fact it is (quote, employment, education, award, relationship, etc.)
# # 2. Use find_rdf_class and find_rdf_property with DESCRIPTIVE queries to find appropriate schema.org terms
# # 3. ONLY use schema matches with score >= 0.5. If no good match, skip or use rdfs:comment.
# # 4. Use emit_triple or emit_triples to output RDF triples, INCLUDING the statement_id
# #
# # QUERYING THE SCHEMA TOOLS:
# # Use descriptive natural language, not just keywords. Include:
# # - What the thing IS (for classes) or what relationship it represents (for properties)
# # - Context about domain/range when known
# #
# # GOOD QUERIES:
# # - find_rdf_class("a spoken or written quotation attributed to someone") → Quotation
# # - find_rdf_class("an organization that educates students like a university") → EducationalOrganization
# # - find_rdf_property("the text content of a quote", subject_type="Quotation") → text
# # - find_rdf_property("who said or authored a quotation", subject_type="Quotation") → creator, spokenByCharacter
# # - find_rdf_property("schools someone attended as a student", subject_type="Person") → alumniOf
# #
# # BAD QUERIES (too vague):
# # - find_rdf_class("quote") - missing context
# # - find_rdf_property("said") - doesn't explain the relationship
# # - find_rdf_property("school") - is it attended? works at? type of?
# #
# # URI RULES:
# # - For entities with Wikipedia links like [Albert Einstein](/wiki/Albert_Einstein):
# #   Use: <https://en.wikipedia.org/wiki/Albert_Einstein>
# # - For entities in the Entity Registry: Use their provided URI
# # - For new entities not in either: Use fragment URIs like <#entity_name>
# # - NEVER invent Wikidata URIs (wd:Q...) unless explicitly provided
# #
# # BLANK NODE NAMING:
# # Use the statement ID in blank node names to ensure uniqueness across chunks:
# #   - For statement [3.5], use: _:s3_5_role1, _:s3_5_role2, etc.
# #   - NOT just _:pos1, _:pos2 (these collide across statements)
# #
# # MODELING PATTERNS:
# #
# # 1. QUOTATIONS (when someone said/stated/objected something):
# #    Create a Quotation instance with text and attribution:
# #    _:s1_quote1 a schema:Quotation .
# #    _:s1_quote1 schema:text "The actual quote text" .
# #    _:s1_quote1 schema:creator <wiki:Person_Who_Said_It> .
# #
# # 2. TEMPORAL/QUALIFIED RELATIONSHIPS (dates on relationships):
# #    Use an intermediate Role node (schema.org Role pattern):
# #
# #    Example - Employment: "Einstein worked at University of Zurich from 1909 to 1911"
# #      <wiki:Albert_Einstein> schema:worksFor _:s1_role1 .
# #      _:s1_role1 a schema:OrganizationRole .
# #      _:s1_role1 schema:worksFor <wiki:University_of_Zurich> .
# #      _:s1_role1 schema:startDate "1909"^^xsd:gYear .
# #      _:s1_role1 schema:endDate "1911"^^xsd:gYear .
# #
# #    Example - Awards: "Einstein received the Nobel Prize in 1921"
# #      <wiki:Albert_Einstein> schema:award _:s2_award1 .
# #      _:s2_award1 a schema:Role .
# #      _:s2_award1 schema:award <wiki:Nobel_Prize_in_Physics> .
# #      _:s2_award1 schema:startDate "1921"^^xsd:gYear .
# #
# #    Example - Education: "Einstein attended University of Zurich from 1896 to 1900"
# #      <wiki:Albert_Einstein> schema:alumniOf _:s3_edu1 .
# #      _:s3_edu1 a schema:OrganizationRole .
# #      _:s3_edu1 schema:alumniOf <wiki:University_of_Zurich> .
# #      _:s3_edu1 schema:startDate "1896"^^xsd:gYear .
# #      _:s3_edu1 schema:endDate "1900"^^xsd:gYear .
# #
# # 3. SIMPLE FACTS (no dates/qualifiers needed):
# #    Direct triples without Role:
# #    <wiki:Einstein> schema:birthDate "1879-03-14"^^xsd:date .
# #    <wiki:Einstein> schema:birthPlace <wiki:Ulm> .
# #
# # WHAT NOT TO DO:
# # 1. DO NOT use schema:description for quotes, opinions, or narrative facts.
# #    schema:description is ONLY for describing what an entity IS, not what happened to it.
# #    WRONG: <Einstein> schema:description "God does not play dice" .
# #    RIGHT: Create a schema:Quotation with schema:text for the quote.
# #
# # 2. DO NOT emit unrelated triples when no good schema match exists.
# #    If a statement is about "being sick in bed", don't emit schema:birthDate.
# #    If no good match (score >= 0.5), either:
# #    - Skip the statement entirely
# #    - Use rdfs:comment to preserve the text: <Einstein> rdfs:comment "Statement text here" .
# #
# # 3. DO NOT conflate past and present states.
# #    "Einstein renounced his German citizenship in 1896" means he LOST it.
# #    Use endDate on a citizenship Role, not startDate.
# #
# # 4. DO NOT extract facts not stated in the statement.
# #    Only model what the specific statement says, not general knowledge about the subject.
# #
# # 5. DATES REQUIRE ROLE PATTERN - CRITICAL!
# #    If a statement mentions "from X to Y" or any year/date range, you MUST use the Role pattern.
# #    Simple triples like <Einstein> schema:worksFor <ETH> lose the temporal information.
# #
# #    Pattern: Subject → Role → Target + dates
# #    <Subject> schema:property _:role .
# #    _:role a schema:Role .           (or OrganizationRole for employment/membership)
# #    _:role schema:property <Target> .
# #    _:role schema:startDate "YYYY"^^xsd:gYear .
# #    _:role schema:endDate "YYYY"^^xsd:gYear .
# #
# # IMPORTANT:
# # - Do NOT write Turtle syntax in your response - use the emit tools instead
# # - ALWAYS include the statement_id when emitting triples
# # - Include statement_id in blank node names: _:s{{id}}_role1
# # - Only emit triples for facts that CAN be properly modeled in schema.org
# # - It is better to skip a statement than emit incorrect triples
# # - Statements with dates MUST use Role pattern (5+ triples, not 1)
# #
# # HUMAN PROMPT:
# # Convert these factual statements to RDF triples.
# #
# # Source: https://en.wikipedia.org/wiki/Albert_Einstein
# # Section context: Albert Einstein > Infobox: scientist
# #
# # Entity Registry (use these URIs for known entities):
# # <https://en.wikipedia.org/wiki/Albert_Einstein> # Albert Einstein (Person) (Wikidata: Q937)
# # <https://en.wikipedia.org/wiki/Ulm> # Ulm (Thing)
# # <https://en.wikipedia.org/wiki/Kingdom_of_W%C3%BCrttemberg> # Kingdom of Württemberg (Thing)
# # <https://en.wikipedia.org/wiki/German_Empire> # German Empire (Thing)
# # <https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey> # Princeton, New Jersey (Thing)
# # <https://en.wikipedia.org/wiki/Lieserl_Einstein> # Lieserl (Thing)
# # <https://en.wikipedia.org/wiki/Hans_Albert_Einstein> # Hans Albert (Thing)
# # <https://en.wikipedia.org/wiki/Einstein_family> # Eduard "Tete" (Thing)
# # <https://en.wikipedia.org/wiki/Einstein_family> # Einstein (Thing)
# # <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> # Mileva Marić (Thing)
# # <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> # Elsa Löwenthal (Thing)
# # <https://en.wikipedia.org/wiki/Statelessness> # Stateless (Thing)
# # <https://en.wikipedia.org/wiki/Switzerland> # Switzerland (Thing)
# # <https://en.wikipedia.org/wiki/Kingdom_of_Prussia> # Kingdom of Prussia (Thing)
# # <https://en.wikipedia.org/wiki/Free_State_of_Prussia> # Free State of Prussia (Thing)
# # <https://en.wikipedia.org/wiki/Weimar_Republic> # Weimar Republic (Thing)
# # <https://en.wikipedia.org/wiki/Citizenship_of_the_United_States> # United States (Thing)
# # <https://en.wikipedia.org/wiki/Physics> # Physics (Thing)
# # <https://en.wikipedia.org/wiki/University_of_Bern> # University of Bern (Thing)
# # <https://en.wikipedia.org/wiki/University_of_Zurich> # University of Zurich (Thing)
# # <https://en.wikipedia.org/wiki/Charles_University_in_Prague> # Charles University in Prague (Thing)
# # <https://en.wikipedia.org/wiki/ETH_Zurich> # ETH Zurich (Thing)
# # <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> # Prussian Academy of Sciences (Thing)
# # <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> # Humboldt University of Berlin (Thing)
# # <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute> # Kaiser Wilhelm Institute (Thing)
# # <https://en.wikipedia.org/wiki/German_Physical_Society> # German Physical Society (Thing)
# # <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> # Institute for Advanced Study (Thing)
# # <https://en.wikipedia.org/wiki/ETH_Zurich> # Swiss Federal Polytechnic School (Thing)
# # <https://en.wikipedia.org/wiki/PhD> # PhD (Thing)
# # <https://en.wikipedia.org/wiki/Alfred_Kleiner> # Alfred Kleiner (Thing)
# # <https://en.wikipedia.org/wiki/Heinrich_Friedrich_Weber> # Heinrich Friedrich Weber (Thing)
# # <https://en.wikipedia.org/wiki/General_relativity> # General relativity (Thing)
# # <https://en.wikipedia.org/wiki/Special_relativity> # Special relativity (Thing)
# # <https://en.wikipedia.org/wiki/Photoelectric_effect> # Photoelectric effect (Thing)
# # <https://en.wikipedia.org/wiki/Mass%E2%80%93energy_equivalence> # ''E''=''mc''<sup>2</sup> (mass–energy equivalence) (Thing)
# # <https://en.wikipedia.org/wiki/Planck%E2%80%93Einstein_relation> # ''E''=''hf'' (Planck–Einstein relation) (Thing)
# # <https://en.wikipedia.org/wiki/Brownian_motion> # Theory of Brownian motion (Thing)
# # <https://en.wikipedia.org/wiki/Einstein_field_equations> # Einstein field equations (Thing)
# # <https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_statistics> # Bose–Einstein statistics (Thing)
# # <https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_condensate> # Bose–Einstein condensate (Thing)
# # <https://en.wikipedia.org/wiki/Gravitational_wave> # Gravitational wave (Thing)
# # <https://en.wikipedia.org/wiki/Cosmological_constant> # Cosmological constant (Thing)
# # <https://en.wikipedia.org/wiki/Unified_field_theory> # Unified field theory (Thing)
# # <https://en.wikipedia.org/wiki/EPR_paradox> # EPR paradox (Thing)
# # <https://en.wikipedia.org/wiki/Ensemble_interpretation> # Ensemble interpretation (Thing)
# # <https://en.wikipedia.org/wiki/List_of_things_named_after_Albert_Einstein> # List of other concepts (Thing)
# # <https://en.wikipedia.org/wiki/Barnard_Medal_for_Meritorious_Service_to_Science> # Barnard Medal for Meritorious Service to Science (Thing)
# # <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics> # Nobel Prize in Physics (Thing)
# # <https://en.wikipedia.org/wiki/Matteucci_Medal> # Matteucci Medal (Thing)
# # <https://en.wikipedia.org/wiki/List_of_fellows_of_the_Royal_Society_elected_in_1921> # ForMemRS (Thing)
# # <https://en.wikipedia.org/wiki/Copley_Medal> # Copley Medal (Thing)
# #
# # Statements to convert (each has a unique ID like [3.5] - include this in blank node names):
# # [1] [Albert Einstein](/wiki/Albert_Einstein) was born on 14 March 1879.
# # [2] [Albert Einstein](/wiki/Albert_Einstein) was born in [Ulm](/wiki/Ulm).
# # [3] [Ulm](/wiki/Ulm) was part of the [Kingdom of Württemberg](/wiki/Kingdom_of_W%C3%BCrttemberg) in 1879.
# # [4] [Albert Einstein](/wiki/Albert_Einstein) was a [theoretical physicist](/wiki/theoretical_physicist).
# # [5] [Albert Einstein](/wiki/Albert_Einstein) is best known for developing the [theory of relativity](/wiki/theory_of_relativity).
# # [6] [Albert Einstein](/wiki/Albert_Einstein) made important contributions to [quantum theory](/wiki/Old_quantum_theory).
# # [7] [Albert Einstein](/wiki/Albert_Einstein) made important contributions to [statistical mechanics](/wiki/statistical_mechanics).
# # [8] [Albert Einstein](/wiki/Albert_Einstein) made important contributions to quantum physics of [radiation](/wiki/radiation).
# # [9] Light consists of particles called [photon](/wiki/photon)s according to Einstein's work.
# # [10] [Albert Einstein](/wiki/Albert_Einstein) worked with physicist [Satyendra Nath Bose](/wiki/Satyendra_Nath_Bose).
# # [11] [Albert Einstein](/wiki/Albert_Einstein) and [Satyendra Nath Bose](/wiki/Satyendra_Nath_Bose) laid the groundwork for [Bose–Einstein statistics](/wiki/Bose%E2%80%93Einstein_statistics).
# # [12] [Albert Einstein](/wiki/Albert_Einstein) advocated against quantum theory's introduction of fundamental randomness into science's picture of the world.
# # [13] [Albert Einstein](/wiki/Albert_Einstein) objected that "God does not play dice".
# # [14] [Albert Einstein](/wiki/Albert_Einstein) attempted to devise a [unified field theory](/wiki/unified_field_theory).
# # [15] [Albert Einstein](/wiki/Albert_Einstein) generalized his geometric theory of gravitation to include [electromagnetism](/wiki/electromagnetism).
# # [16] [Albert Einstein](/wiki/Albert_Einstein) became increasingly isolated from mainstream [modern physics](/wiki/modern_physics).
# # [17] [Albert Einstein](/wiki/Albert_Einstein) was five years old when he was sick in bed.
# # [18] [Albert Einstein](/wiki/Albert_Einstein)'s father brought him a [compass](/wiki/magnetic_compass) when he was five and sick in bed.
# # [19] [Albert Einstein](/wiki/Albert_Einstein) developed a lifelong fascination with [electromagnetism](/wiki/electromagnetism).
# # [20] [Albert Einstein](/wiki/Albert_Einstein) realized that "Something deeply hidden had to be behind things."
# # [21] [Albert Einstein](/wiki/Albert_Einstein) attended St. Peter's [Catholic elementary school](/wiki/Catholic_school) in Munich.
# # [22] [Albert Einstein](/wiki/Albert_Einstein) started attending St. Peter's [Catholic elementary school](/wiki/Catholic_school) in Munich at the age of five.
# # [23] [Albert Einstein](/wiki/Albert_Einstein) was transferred to the [Luitpold Gymnasium](/wiki/Luitpold_Gymnasium) when he was eight.
# # [24] [Albert Einstein](/wiki/Albert_Einstein) received advanced primary and secondary school education at the [Luitpold Gymnasium](/wiki/Luitpold_Gymnasium).
# #
# # CRITICAL RULES:
# #
# # 1. URI EXTRACTION: Convert markdown links to Wikipedia URIs:
# #    [Albert Einstein](/wiki/Albert_Einstein) → <https://en.wikipedia.org/wiki/Albert_Einstein>
# #
# # 2. BLANK NODE NAMING: Include statement ID to avoid collisions:
# #    For statement [3.5], use: _:s3_5_role1 (NOT just _:role1)
# #
# # 3. SCHEMA MATCHING: Only use matches with score >= 0.5.
# #    If no good match exists, either skip the statement or use rdfs:comment.
# #
# # 4. TEMPORAL RELATIONSHIPS - MANDATORY ROLE PATTERN:
# #    If a statement has dates like "from X to Y" or year ranges, you MUST use the Role pattern.
# #    A simple triple loses the temporal information - DO NOT emit just:
# #      <Einstein> schema:employee <ETH_Zurich> .  ← WRONG! Loses the dates!
# #
# #    CORRECT Role Pattern (REQUIRED for dated relationships):
# #    Statement: "Einstein worked at ETH Zurich from 1912 to 1914"
# #      <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor _:s1_21_role1 .
# #      _:s1_21_role1 a schema:OrganizationRole .
# #      _:s1_21_role1 schema:worksFor <https://en.wikipedia.org/wiki/ETH_Zurich> .
# #      _:s1_21_role1 schema:startDate "1912"^^xsd:gYear .
# #      _:s1_21_role1 schema:endDate "1914"^^xsd:gYear .
# #
# #    Statement: "Einstein was a citizen of Switzerland from 1901 to 1955"
# #      <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality _:s1_14_role1 .
# #      _:s1_14_role1 a schema:Role .
# #      _:s1_14_role1 schema:nationality <https://en.wikipedia.org/wiki/Switzerland> .
# #      _:s1_14_role1 schema:startDate "1901"^^xsd:gYear .
# #      _:s1_14_role1 schema:endDate "1955"^^xsd:gYear .
# #
# #    Use OrganizationRole for employment/membership, Role for citizenship/other.
# #
# # 5. DO NOT:
# #    - Use schema:description for quotes or narrative (only for entity descriptions)
# #    - Emit unrelated triples when no good match exists
# #    - Extract facts not stated in the statement
# #    - Emit simple triples when there are dates (MUST use Role pattern)
# #
# # Process each statement. If you cannot properly model it, skip it or use rdfs:comment.
# #
# # === END PROMPT ===

# %% [raw]
# # Statement [4.1]: In 1894, Hermann and Jakob's company tendered for a contract to install electric lighting in Munich.
# # No triples emitted for this statement
# # Debug: 595 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 3, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:birthDate", "object_value": "\"1879-03-14\"^^xsd:date"}
# #   emit_triple: {"statement_id": 3, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:birthPlace", "object_value": "https://en.wikipedia.org/wiki/Ulm"}
# #   emit_triple: {"statement_id": 4, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:alumniOf", "object_value": "https://en.wikipedia.org/wiki/University_of_Zurich"}
# #   emit_triple: {"statement_id": 5, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:alumniOf", "object_value": "https://en.wikipedia.org/wiki/ETH_Zurich"}
# #   emit_triple: {"statement_id": 12, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:alumniOf", "object_value": "https://en.wikipedia.org/wiki/University_of_Bern"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicnqgugltmx75wx7xsbloh2yc7k2lopa6tc4ozeinqzutchicajjq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicnqgugltmx75wx7xsbloh2yc7k2lopa6tc4ozeinqzutchicajjq",
#   "prov:label": "rdf:4_1",
#   "_cell": 113,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia2xgahgiatytktjg7wulzkzkmtc7kf6jtzzrkb3zsfcwg2e7vrym"
#   },
#   "_stmt_key": "4_1",
#   "_chunk_num": 4,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [4.2]: Hermann and Jakob's company lacked the capital required to update their technology from direct current to alternating current.
# # No triples emitted for this statement
# # Debug: 595 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 3, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:birthDate", "object_value": "\"1879-03-14\"^^xsd:date"}
# #   emit_triple: {"statement_id": 3, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:birthPlace", "object_value": "https://en.wikipedia.org/wiki/Ulm"}
# #   emit_triple: {"statement_id": 4, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:alumniOf", "object_value": "https://en.wikipedia.org/wiki/University_of_Zurich"}
# #   emit_triple: {"statement_id": 5, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:alumniOf", "object_value": "https://en.wikipedia.org/wiki/ETH_Zurich"}
# #   emit_triple: {"statement_id": 12, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:alumniOf", "object_value": "https://en.wikipedia.org/wiki/University_of_Bern"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreig24sw7vl7ctsmx4kasfnp5fhnwgxy6zuwtwdrhogsxgarvr6hj2u",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreig24sw7vl7ctsmx4kasfnp5fhnwgxy6zuwtwdrhogsxgarvr6hj2u",
#   "prov:label": "rdf:4_2",
#   "_cell": 115,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieqmokhbyqtysoclhbz3t3cidzrmieyeto5b6wcydcwpfevigjdce"
#   },
#   "_stmt_key": "4_2",
#   "_chunk_num": 4,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [4.3]: [Albert Einstein](/wiki/Albert_Einstein) was fifteen years old in 1894.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:birthDate "1879-03-14"^^xsd:date .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:birthPlace https://en.wikipedia.org/wiki/Ulm .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibrqcszif7nigvvns3lckobs6wepijixbye74beidyiy576eofz3u",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibrqcszif7nigvvns3lckobs6wepijixbye74beidyiy576eofz3u",
#   "prov:label": "rdf:4_3",
#   "_cell": 117,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibmfjzhyusujycp2rttprm773fmmbzqg6bt6rfbu2f3byfghayp6u"
#   },
#   "_stmt_key": "4_3",
#   "_chunk_num": 4,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [4.4]: [Albert Einstein](/wiki/Albert_Einstein) stayed behind in [Munich](/wiki/Munich) to finish his schooling in 1894.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:alumniOf https://en.wikipedia.org/wiki/University_of_Zurich .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicnavs4pynxsj654iir6khcl24s67y7vzveauh6luprqvylzjof2e",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicnavs4pynxsj654iir6khcl24s67y7vzveauh6luprqvylzjof2e",
#   "prov:label": "rdf:4_4",
#   "_cell": 119,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibjgfq4ctm7xtrc4y5nguboufnq2zmanzeptxbicctqlfk36r5nma"
#   },
#   "_stmt_key": "4_4",
#   "_chunk_num": 4,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [4.5]: [Albert Einstein](/wiki/Albert_Einstein)'s father wanted him to study [electrical engineering](/wiki/electrical_engineering).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:alumniOf https://en.wikipedia.org/wiki/ETH_Zurich .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaeefd2bbdq7ay4g622fiuws7kldywd4x7gb375rerh4zhppt5rlq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaeefd2bbdq7ay4g622fiuws7kldywd4x7gb375rerh4zhppt5rlq",
#   "prov:label": "rdf:4_5",
#   "_cell": 121,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidur325vodflbu4ymgz5oqg3naimvse6ltl3b7igwrnknydv7tbhm"
#   },
#   "_stmt_key": "4_5",
#   "_chunk_num": 4,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [4.6]: [Albert Einstein](/wiki/Albert_Einstein) was a fractious pupil in the Gymnasium.
# # No triples emitted for this statement
# # Debug: 595 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 3, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:birthDate", "object_value": "\"1879-03-14\"^^xsd:date"}
# #   emit_triple: {"statement_id": 3, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:birthPlace", "object_value": "https://en.wikipedia.org/wiki/Ulm"}
# #   emit_triple: {"statement_id": 4, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:alumniOf", "object_value": "https://en.wikipedia.org/wiki/University_of_Zurich"}
# #   emit_triple: {"statement_id": 5, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:alumniOf", "object_value": "https://en.wikipedia.org/wiki/ETH_Zurich"}
# #   emit_triple: {"statement_id": 12, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:alumniOf", "object_value": "https://en.wikipedia.org/wiki/University_of_Bern"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreif3m4vb6xw7xe7muy4ypoazj5funsejbhvv5uhm3i4zekozidlr7u",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreif3m4vb6xw7xe7muy4ypoazj5funsejbhvv5uhm3i4zekozidlr7u",
#   "prov:label": "rdf:4_6",
#   "_cell": 123,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidq3imtekf4nf3sh4it4vadnnyhq3t76ogdlwbeepblaeiu2it3oe"
#   },
#   "_stmt_key": "4_6",
#   "_chunk_num": 4,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [4.7]: The Gymnasium's regimen and teaching methods were not congenial to [Albert Einstein](/wiki/Albert_Einstein).
# # No triples emitted for this statement
# # Debug: 595 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 3, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:birthDate", "object_value": "\"1879-03-14\"^^xsd:date"}
# #   emit_triple: {"statement_id": 3, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:birthPlace", "object_value": "https://en.wikipedia.org/wiki/Ulm"}
# #   emit_triple: {"statement_id": 4, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:alumniOf", "object_value": "https://en.wikipedia.org/wiki/University_of_Zurich"}
# #   emit_triple: {"statement_id": 5, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:alumniOf", "object_value": "https://en.wikipedia.org/wiki/ETH_Zurich"}
# #   emit_triple: {"statement_id": 12, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:alumniOf", "object_value": "https://en.wikipedia.org/wiki/University_of_Bern"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibboja2t7zsxj6nd2adpvmchaxhakqqqns6djwcqoxaoyzrwaxmti",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibboja2t7zsxj6nd2adpvmchaxhakqqqns6djwcqoxaoyzrwaxmti",
#   "prov:label": "rdf:4_7",
#   "_cell": 125,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihlafrqmustctzd25us2t3hadqsfh5ivjlzjxgszvlreillo4oo5y"
#   },
#   "_stmt_key": "4_7",
#   "_chunk_num": 4,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [4.8]: [Albert Einstein](/wiki/Albert_Einstein) later wrote that the school's policy of strict [rote learning](/wiki/rote_learning) was harmful to creativity.
# # No triples emitted for this statement
# # Debug: 595 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 3, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:birthDate", "object_value": "\"1879-03-14\"^^xsd:date"}
# #   emit_triple: {"statement_id": 3, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:birthPlace", "object_value": "https://en.wikipedia.org/wiki/Ulm"}
# #   emit_triple: {"statement_id": 4, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:alumniOf", "object_value": "https://en.wikipedia.org/wiki/University_of_Zurich"}
# #   emit_triple: {"statement_id": 5, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:alumniOf", "object_value": "https://en.wikipedia.org/wiki/ETH_Zurich"}
# #   emit_triple: {"statement_id": 12, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:alumniOf", "object_value": "https://en.wikipedia.org/wiki/University_of_Bern"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreict5m72qwtlglwxazs6lbdy7jn3obeqgdiussty5ydvs4zotzvali",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreict5m72qwtlglwxazs6lbdy7jn3obeqgdiussty5ydvs4zotzvali",
#   "prov:label": "rdf:4_8",
#   "_cell": 127,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib3lyt6eol2wkwzjipif6wt7tv25vk6niky4cvb3ry42eawcaqhda"
#   },
#   "_stmt_key": "4_8",
#   "_chunk_num": 4,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [4.9]: At the end of December 1894, a doctor's letter persuaded the Luitpold's authorities to release [Albert Einstein](/wiki/Albert_Einstein) from its care.
# # No triples emitted for this statement
# # Debug: 595 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 3, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:birthDate", "object_value": "\"1879-03-14\"^^xsd:date"}
# #   emit_triple: {"statement_id": 3, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:birthPlace", "object_value": "https://en.wikipedia.org/wiki/Ulm"}
# #   emit_triple: {"statement_id": 4, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:alumniOf", "object_value": "https://en.wikipedia.org/wiki/University_of_Zurich"}
# #   emit_triple: {"statement_id": 5, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:alumniOf", "object_value": "https://en.wikipedia.org/wiki/ETH_Zurich"}
# #   emit_triple: {"statement_id": 12, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:alumniOf", "object_value": "https://en.wikipedia.org/wiki/University_of_Bern"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieozxnsljk5hx4xa7gw4zpapnd5rb5djnb37iyjidj4ppciow2w6m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieozxnsljk5hx4xa7gw4zpapnd5rb5djnb37iyjidj4ppciow2w6m",
#   "prov:label": "rdf:4_9",
#   "_cell": 129,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidfpuawxa73tbtlooxyas2wfmxfplo7dzcheor2rtcwlmytefzbdy"
#   },
#   "_stmt_key": "4_9",
#   "_chunk_num": 4,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [4.10]: [Albert Einstein](/wiki/Albert_Einstein) joined his family in [Pavia](/wiki/Pavia) at the end of December 1894.
# # No triples emitted for this statement
# # Debug: 595 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 3, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:birthDate", "object_value": "\"1879-03-14\"^^xsd:date"}
# #   emit_triple: {"statement_id": 3, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:birthPlace", "object_value": "https://en.wikipedia.org/wiki/Ulm"}
# #   emit_triple: {"statement_id": 4, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:alumniOf", "object_value": "https://en.wikipedia.org/wiki/University_of_Zurich"}
# #   emit_triple: {"statement_id": 5, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:alumniOf", "object_value": "https://en.wikipedia.org/wiki/ETH_Zurich"}
# #   emit_triple: {"statement_id": 12, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:alumniOf", "object_value": "https://en.wikipedia.org/wiki/University_of_Bern"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidkojx7lnqrrdrcfhuosn4illwc3tfkvxvaqlyhhly2hflwhdaxfy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidkojx7lnqrrdrcfhuosn4illwc3tfkvxvaqlyhhly2hflwhdaxfy",
#   "prov:label": "rdf:4_10",
#   "_cell": 131,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih5qnian6je6m65d6h2qfbkieh2kyanmspfw75l4ehztwtvbem3vm"
#   },
#   "_stmt_key": "4_10",
#   "_chunk_num": 4,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [4.11]: While in [Italy](/wiki/Italy) as a teenager, [Albert Einstein](/wiki/Albert_Einstein) wrote an essay entitled "On the Investigation of the State of the [Ether](/wiki/Aether_%28classical_element%29) in a Magnetic Field".
# # No triples emitted for this statement
# # Debug: 595 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 3, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:birthDate", "object_value": "\"1879-03-14\"^^xsd:date"}
# #   emit_triple: {"statement_id": 3, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:birthPlace", "object_value": "https://en.wikipedia.org/wiki/Ulm"}
# #   emit_triple: {"statement_id": 4, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:alumniOf", "object_value": "https://en.wikipedia.org/wiki/University_of_Zurich"}
# #   emit_triple: {"statement_id": 5, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:alumniOf", "object_value": "https://en.wikipedia.org/wiki/ETH_Zurich"}
# #   emit_triple: {"statement_id": 12, "subject": "https://en.wikipedia.org/wiki/Albert_Einstein", "predicate": "schema:alumniOf", "object_value": "https://en.wikipedia.org/wiki/University_of_Bern"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicothnfjzgc6lfujf6pko4dz2xhdakchj4ojxk2shuxfz3qd7a5wq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicothnfjzgc6lfujf6pko4dz2xhdakchj4ojxk2shuxfz3qd7a5wq",
#   "prov:label": "rdf:4_11",
#   "_cell": 133,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiarfnbfgapewlqz26sdkt7tml77tpptbhnnzwsg5q62n4w6zs2ksa"
#   },
#   "_stmt_key": "4_11",
#   "_chunk_num": 4,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [4.12]: [Max Talmud](/wiki/Max_Talmud) was a family tutor of [Albert Einstein](/wiki/Albert_Einstein).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:alumniOf https://en.wikipedia.org/wiki/University_of_Bern .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigbzhd3h6r7ydljet7wpcq5vam745cjznv6a3ju6zu3g77lkrpwxy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigbzhd3h6r7ydljet7wpcq5vam745cjznv6a3ju6zu3g77lkrpwxy",
#   "prov:label": "rdf:4_12",
#   "_cell": 135,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihe2lgf7yyxsrstfviwos4h5baj3jjn4lkohgz2fmycb2dvqd3kpm"
#   },
#   "_stmt_key": "4_12",
#   "_chunk_num": 4,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [4.13]: [Max Talmud](/wiki/Max_Talmud) said that shortly after giving the twelve-year-old [Albert Einstein](/wiki/Albert_Einstein) a geometry textbook, the boy had worked through the whole book.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:alumniOf https://en.wikipedia.org/wiki/Charles_University_in_Prague .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicrsdvyqa4dhngmchiqtwokuotpiji3pmerjegav7ietzkn7dq6qm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicrsdvyqa4dhngmchiqtwokuotpiji3pmerjegav7ietzkn7dq6qm",
#   "prov:label": "rdf:4_13",
#   "_cell": 137,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifl6fzrxk3gjk7bi3gjhaxvltw6tqcdcn4ccv6z3ge2o67j7qptuq"
#   },
#   "_stmt_key": "4_13",
#   "_chunk_num": 4,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [4.14]: After working through the geometry textbook, [Albert Einstein](/wiki/Albert_Einstein) devoted himself to higher mathematics.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:alumniOf https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreid4gg3eychnnt2w2tqi6v4tfmjokaly44a2ht4j7w2onfg2cirg2y",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreid4gg3eychnnt2w2tqi6v4tfmjokaly44a2ht4j7w2onfg2cirg2y",
#   "prov:label": "rdf:4_14",
#   "_cell": 139,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib6n6tacwumejibuivkqsemqndtyxxoa3awzh4k6x5xfrxbofnqd4"
#   },
#   "_stmt_key": "4_14",
#   "_chunk_num": 4,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [4.15]: [Albert Einstein](/wiki/Albert_Einstein) was able to follow the flight of his mathematical genius even when it soared high, according to [Max Talmud](/wiki/Max_Talmud).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:alumniOf https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidwts4w2zh5am2xf4b3xahpmyd65hzjjtnileekr3hxy5cfcgfie4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidwts4w2zh5am2xf4b3xahpmyd65hzjjtnileekr3hxy5cfcgfie4",
#   "prov:label": "rdf:4_15",
#   "_cell": 141,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihvfi3tho2zdbyonmwvyvbbx3vhe6bkog35oi3be357j3ppob7nda"
#   },
#   "_stmt_key": "4_15",
#   "_chunk_num": 4,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [4.16]: [Albert Einstein](/wiki/Albert_Einstein) mastered [integral](/wiki/integral) and [differential calculus](/wiki/differential_calculus) while he was fourteen years old.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:alumniOf https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihuhbhb3ebkz7cc2xgvncu46jzvpvzq3ryhmrnvzxqh7eppszaana",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihuhbhb3ebkz7cc2xgvncu46jzvpvzq3ryhmrnvzxqh7eppszaana",
#   "prov:label": "rdf:4_16",
#   "_cell": 143,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih7mjojqviz4o4fmoaeuyfrym3n43bcq3luh5cypjc6nw5xrgm6cu"
#   },
#   "_stmt_key": "4_16",
#   "_chunk_num": 4,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [4.17]: [Albert Einstein](/wiki/Albert_Einstein) had a great love of algebra and geometry at the age of twelve.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:alumniOf https://en.wikipedia.org/wiki/Institute_for_Advanced_Study .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihreyod4gfdmga42bzaipicbs4tk4fu73q5ga6wuq3lxno2vnjpcu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihreyod4gfdmga42bzaipicbs4tk4fu73q5ga6wuq3lxno2vnjpcu",
#   "prov:label": "rdf:4_17",
#   "_cell": 145,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiephrlzvy4uujm2d5ikrpekg6mb645q25utsohyu3pnw3e5yxtava"
#   },
#   "_stmt_key": "4_17",
#   "_chunk_num": 4,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [4.18]: At twelve years old, [Albert Einstein](/wiki/Albert_Einstein) was already confident that nature could be understood as a "mathematical structure".
# https://en.wikipedia.org/wiki/Albert_Einstein schema:nationality https://en.wikipedia.org/wiki/German_Empire .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreig74z3p7r7budmvjwkbfpwmvnixgsm7ragnmsydzmdlq2f6ovc2wi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreig74z3p7r7budmvjwkbfpwmvnixgsm7ragnmsydzmdlq2f6ovc2wi",
#   "prov:label": "rdf:4_18",
#   "_cell": 147,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreichbu2oun7kb4lesdovilh62vvtydrwe4zouxzr4davycrfobqltm"
#   },
#   "_stmt_key": "4_18",
#   "_chunk_num": 4,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [5.1]: At thirteen, [Albert Einstein](/wiki/Albert_Einstein) was introduced to [Kant](/wiki/Kant)'s *[Critique of Pure Reason](/wiki/Critique_of_Pure_Reason)* by [Talmud](/wiki/Talmud).
# _:s1_quote1 rdf:type schema:Quotation .
# _:s1_quote1 schema:text "Kant's Critique of Pure Reason" .
# _:s1_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidln2q7rqi3kxellllpbrff7ftqjq2nx4xnm66a4jjehymkfawta4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidln2q7rqi3kxellllpbrff7ftqjq2nx4xnm66a4jjehymkfawta4",
#   "prov:label": "rdf:5_1",
#   "_cell": 149,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreief7agjzgtjmclhfhlf5u4styfpvlnvmxwxwx4pjf5ovwdsgfbsc4"
#   },
#   "_stmt_key": "5_1",
#   "_chunk_num": 5,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [5.2]: At thirteen, [Albert Einstein](/wiki/Albert_Einstein) became interested in music and philosophy.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Music> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Philosophy> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiadlv2xuhemfwln6l3fo5bzxlypjciu5742efgdiuv72fy2jfl36m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiadlv2xuhemfwln6l3fo5bzxlypjciu5742efgdiuv72fy2jfl36m",
#   "prov:label": "rdf:5_2",
#   "_cell": 151,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigc4wxtdfzmlpusoef5kitztmrcbuknwdmqfiyujbpirced46l4xq"
#   },
#   "_stmt_key": "5_2",
#   "_chunk_num": 5,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [5.3]: [Kant](/wiki/Kant) was a favorite philosopher of [Albert Einstein](/wiki/Albert_Einstein).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Kant> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreih6unlpibufsadxgjygot3e446ay4pdzutd7lpemxbpaerohxf2y4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreih6unlpibufsadxgjygot3e446ay4pdzutd7lpemxbpaerohxf2y4",
#   "prov:label": "rdf:5_3",
#   "_cell": 153,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicode2b4go6mj6putr66wiief6x64ypgogjhmprafcndhcsitgi5e"
#   },
#   "_stmt_key": "5_3",
#   "_chunk_num": 5,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [5.4]: According to [Talmud](/wiki/Talmud), at the age of thirteen, [Albert Einstein](/wiki/Albert_Einstein) found Kant's works, which were incomprehensible to ordinary mortals, clear to him.
# _:s4_quote1 rdf:type schema:Quotation .
# _:s4_quote1 schema:text "Kant's works, which were incomprehensible to ordinary mortals, clear to him" .
# _:s4_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidpznc2hgfnh5fygrzisw7yhapspxz22375vrqyfwlffrfqqbw2ym",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidpznc2hgfnh5fygrzisw7yhapspxz22375vrqyfwlffrfqqbw2ym",
#   "prov:label": "rdf:5_4",
#   "_cell": 155,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifeurstnysisay33tya5slwpnend2liwvcdsj53j65a3bzcasbk2u"
#   },
#   "_stmt_key": "5_4",
#   "_chunk_num": 5,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [5.5]: In 1895, [Albert Einstein](/wiki/Albert_Einstein) was sixteen years old.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:birthDate "1879-03-14"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieaah3zwvnebovjta7lsjsiig3kze5ytd3r4v4ec4vja6sagog4fa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieaah3zwvnebovjta7lsjsiig3kze5ytd3r4v4ec4vja6sagog4fa",
#   "prov:label": "rdf:5_5",
#   "_cell": 157,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreictf76rgw3l4powbjypihnjwiwb6i4dvlcxzlyu3g5pjvzo6kzaye"
#   },
#   "_stmt_key": "5_5",
#   "_chunk_num": 5,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [5.6]: In 1895, [Albert Einstein](/wiki/Albert_Einstein) sat the entrance examination for the [federal polytechnic school](/wiki/ETH_Zurich) in [Zurich](/wiki/Zurich), [Switzerland](/wiki/Switzerland).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf _:s6_role1 .
# _:s6_role1 rdf:type schema:OrganizationRole .
# _:s6_role1 schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .
# _:s6_role1 schema:startDate "1895"^^xsd:gYear .
# _:s6_role1 schema:endDate "1896"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia2xbpsvz3mdzcez62mlz5lyvader447xgym5dlynd2xlpsemnnsu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia2xbpsvz3mdzcez62mlz5lyvader447xgym5dlynd2xlpsemnnsu",
#   "prov:label": "rdf:5_6",
#   "_cell": 159,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigqy5skk67m7kfldqadxdxdeyjlgqm33hjfzfc4jzu6v77nnydxcy"
#   },
#   "_stmt_key": "5_6",
#   "_chunk_num": 5,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [5.7]: [Albert Einstein](/wiki/Albert_Einstein) failed to reach the required standard in the general part of the test.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiezqi3otee3wkn74xwvso4l7wn4yshuq4pzqwy73uf3pgnlddbgza",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiezqi3otee3wkn74xwvso4l7wn4yshuq4pzqwy73uf3pgnlddbgza",
#   "prov:label": "rdf:5_7",
#   "_cell": 161,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifwirkn3brjfc2dkaf35a6rgzvpz2nrvzsl5flb763fuqmycniqiq"
#   },
#   "_stmt_key": "5_7",
#   "_chunk_num": 5,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [5.8]: [Albert Einstein](/wiki/Albert_Einstein) performed with distinction in physics and mathematics in the test.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaq7h3hve5hm3hvufblufubqvywsit2c5ae2d4ugwzyx2o7jk63qi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaq7h3hve5hm3hvufblufubqvywsit2c5ae2d4ugwzyx2o7jk63qi",
#   "prov:label": "rdf:5_8",
#   "_cell": 163,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibuampcrc4htm3oovex5uu7s6hg3bnoj6dtvmil527czu5x3ugvrq"
#   },
#   "_stmt_key": "5_8",
#   "_chunk_num": 5,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [5.9]: On the advice of the polytechnic's principal, [Albert Einstein](/wiki/Albert_Einstein) completed his secondary education at the [Argovian cantonal school](/wiki/Old_Cantonal_School_Aarau) in [Aarau](/wiki/Aarau), [Switzerland](/wiki/Switzerland).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Old_Cantonal_School_Aarau> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf _:s9_role1 .
# _:s9_role1 rdf:type schema:OrganizationRole .
# _:s9_role1 schema:alumniOf <https://en.wikipedia.org/wiki/Old_Cantonal_School_Aarau> .
# _:s9_role1 schema:startDate "1895"^^xsd:gYear .
# _:s9_role1 schema:endDate "1896"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidtxq2acnh4ktbc72g37ph4h25ktxb52idnmf3sxtbku5dnggdm7q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidtxq2acnh4ktbc72g37ph4h25ktxb52idnmf3sxtbku5dnggdm7q",
#   "prov:label": "rdf:5_9",
#   "_cell": 165,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia2cbyd67de4r3tmjbtxteymcm2ae5nl2i7fgjzetzkgmxwzqreyy"
#   },
#   "_stmt_key": "5_9",
#   "_chunk_num": 5,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [5.10]: [Albert Einstein](/wiki/Albert_Einstein) graduated from the [Argovian cantonal school](/wiki/Old_Cantonal_School_Aarau) in 1896.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/Old_Cantonal_School_Aarau> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiag6fjn2gyvimwa4h5zktq5ppygzrzgtrpgdp4q6zcxgpcogcgcym",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiag6fjn2gyvimwa4h5zktq5ppygzrzgtrpgdp4q6zcxgpcogcgcym",
#   "prov:label": "rdf:5_10",
#   "_cell": 167,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreig4isjsfgaplev4on3csgpz5e5h6t7uuydifg6fdduye4yl55sp6i"
#   },
#   "_stmt_key": "5_10",
#   "_chunk_num": 5,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [5.11]: While lodging in [Aarau](/wiki/Aarau) with the family of [Jost Winteler](/wiki/Jost_Winteler), [Albert Einstein](/wiki/Albert_Einstein) fell in love with Winteler's daughter, [Marie](/wiki/Marie_Einstein).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:spouse <https://en.wikipedia.org/wiki/Marie_Einstein> .
# <https://en.wikipedia.org/wiki/Marie_Einstein> schema:spouse <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiferkree3gijwkot54uuhpfiuytzujuflzqycbwhobppsatdjkvoa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiferkree3gijwkot54uuhpfiuytzujuflzqycbwhobppsatdjkvoa",
#   "prov:label": "rdf:5_11",
#   "_cell": 169,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidb2codnmnsnn4czkdebhz2zmbi4zqkihusafnc44qngnkfdhuz5y"
#   },
#   "_stmt_key": "5_11",
#   "_chunk_num": 5,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [5.12]: [Albert Einstein](/wiki/Albert_Einstein)'s sister, [Maja](/wiki/Maja_Einstein), later married Winteler's son, [Paul](/wiki/Paul_Winteler).
# <https://en.wikipedia.org/wiki/Maja_Einstein> schema:spouse <https://en.wikipedia.org/wiki/Paul_Winteler> .
# <https://en.wikipedia.org/wiki/Paul_Winteler> schema:spouse <https://en.wikipedia.org/wiki/Maja_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifhh7x2anoi2knuslh7unasxgvfdmjj3b7kpv43fdba4ywh53wv7m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifhh7x2anoi2knuslh7unasxgvfdmjj3b7kpv43fdba4ywh53wv7m",
#   "prov:label": "rdf:5_12",
#   "_cell": 171,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibblgkx2eqastwm54satzxv6ij6fqrx4wqdb7nvk4zpb7yxlokczy"
#   },
#   "_stmt_key": "5_12",
#   "_chunk_num": 5,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [5.13]: The [federal polytechnic school](/wiki/ETH_Zurich) in [Zurich](/wiki/Zurich), [Switzerland](/wiki/Switzerland), was later known as the Eidgenössische Technische Hochschule, ETH.
# <https://en.wikipedia.org/wiki/ETH_Zurich> schema:alternateName "Eidgenössische Technische Hochschule" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibr5poahatannirzedzre3e7bho5jnkmcz4fjete45sepqfptf4zu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibr5poahatannirzedzre3e7bho5jnkmcz4fjete45sepqfptf4zu",
#   "prov:label": "rdf:5_13",
#   "_cell": 173,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigufp6kpoh7lzsn3wzr2po3pceu4yvt7k2yxbhmlgcyzckzss422q"
#   },
#   "_stmt_key": "5_13",
#   "_chunk_num": 5,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [5.14]: The [Argovian cantonal school](/wiki/Old_Cantonal_School_Aarau) was a [*gymnasium*](/wiki/Gymnasium_%28school%29).
# <https://en.wikipedia.org/wiki/Old_Cantonal_School_Aarau> rdf:type schema:EducationalOrganization .
# <https://en.wikipedia.org/wiki/Old_Cantonal_School_Aarau> schema:alternateName "gymnasium" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreif3snlerivgb6mqt22zxphqnkgfutjjhakbijem2ebi6pkrcmw3yy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreif3snlerivgb6mqt22zxphqnkgfutjjhakbijem2ebi6pkrcmw3yy",
#   "prov:label": "rdf:5_14",
#   "_cell": 175,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiborm2pzfnncizeqplwcik7ya5sus3njebe4gkxbfulzatabwgoqm"
#   },
#   "_stmt_key": "5_14",
#   "_chunk_num": 5,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [5.15]: [Jost Winteler](/wiki/Jost_Winteler) was the father of [Marie](/wiki/Marie_Einstein).
# <https://en.wikipedia.org/wiki/Marie_Einstein> schema:parent <https://en.wikipedia.org/wiki/Jost_Winteler> .
# <https://en.wikipedia.org/wiki/Jost_Winteler> schema:child <https://en.wikipedia.org/wiki/Marie_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicrtyb5stze257zqj4rdizrisiiptoylxk7amwl3cmpyhbc4cdfwq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicrtyb5stze257zqj4rdizrisiiptoylxk7amwl3cmpyhbc4cdfwq",
#   "prov:label": "rdf:5_15",
#   "_cell": 177,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihh53huvhfg6tc4637hxwtu45wdh7nfbaupmde6vologkbebmclvu"
#   },
#   "_stmt_key": "5_15",
#   "_chunk_num": 5,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [5.16]: [Paul](/wiki/Paul_Winteler) was the son of [Jost Winteler](/wiki/Jost_Winteler).
# <https://en.wikipedia.org/wiki/Paul_Winteler> schema:parent <https://en.wikipedia.org/wiki/Jost_Winteler> .
# <https://en.wikipedia.org/wiki/Jost_Winteler> schema:child <https://en.wikipedia.org/wiki/Paul_Winteler> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiavmnrh4pp2kkrf6j6tag7oruxd5uunz4o34cu7hyjwl6zg3qycra",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiavmnrh4pp2kkrf6j6tag7oruxd5uunz4o34cu7hyjwl6zg3qycra",
#   "prov:label": "rdf:5_16",
#   "_cell": 179,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid2bcuwkdgyuz3zt7ita73364ork676nvfe4or4gdel7eyczbzbji"
#   },
#   "_stmt_key": "5_16",
#   "_chunk_num": 5,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [6.1]: In January 1896, [Albert Einstein](/wiki/Albert_Einstein) renounced his [citizenship of the German Kingdom of Württemberg](/wiki/German_citizenship) in order to avoid [conscription into military service](/wiki/Conscription_in_Germany).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality <https://en.wikipedia.org/wiki/Kingdom_of_W%C3%BCrttemberg> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigzitmzbq7rv37ik3rfifzlhbjq4sxymhuejnt45emwrt73ieilge",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigzitmzbq7rv37ik3rfifzlhbjq4sxymhuejnt45emwrt73ieilge",
#   "prov:label": "rdf:6_1",
#   "_cell": 181,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib6txn3uydtpgrfsy6ymnlet44ydj54shyrhbrx74njnax4jsiqfu"
#   },
#   "_stmt_key": "6_1",
#   "_chunk_num": 6,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [6.2]: The *[Matura](/wiki/Matura)* (graduation for the successful completion of higher secondary schooling), awarded to [Albert Einstein](/wiki/Albert_Einstein) in September 1896, acknowledged him to have performed well across most of the curriculum.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasCredential <https://en.wikipedia.org/wiki/Matura> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicrkqbnuz4dn3tktgicbcf5dhvdlo46kgffkb3k5fxs7cipsqqnpa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicrkqbnuz4dn3tktgicbcf5dhvdlo46kgffkb3k5fxs7cipsqqnpa",
#   "prov:label": "rdf:6_2",
#   "_cell": 183,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigy3fhof3erpmwsio3hhy67v3lcvcsbggmj5kkqv3zovhrmvoj6ta"
#   },
#   "_stmt_key": "6_2",
#   "_chunk_num": 6,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [6.3]: [Albert Einstein](/wiki/Albert_Einstein) was awarded a [top grade of 6](/wiki/Grading_systems_by_country) for history, physics, algebra, geometry, and descriptive geometry.
# <https://en.wikipedia.org/wiki/Matura> schema:educationalCredentialAwarded "6" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigppv62tzzocffhenohs7rhn5lqkn6jdt34y3ccxho5n2hscxhjde",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigppv62tzzocffhenohs7rhn5lqkn6jdt34y3ccxho5n2hscxhjde",
#   "prov:label": "rdf:6_3",
#   "_cell": 185,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreic6nrsd3p42xtyjpssogbqd7ckour4su3sp6h2kyoxagie63masoi"
#   },
#   "_stmt_key": "6_3",
#   "_chunk_num": 6,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [6.4]: At seventeen, [Albert Einstein](/wiki/Albert_Einstein) enrolled in the four-year mathematics and physics teaching diploma program at the [Swiss Federal Polytechnic School](/wiki/ETH_Zurich).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidkcy2gsrv4w7nv35pq2gouheu43shx6s4qfrpcfvcegnebyrtusa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidkcy2gsrv4w7nv35pq2gouheu43shx6s4qfrpcfvcegnebyrtusa",
#   "prov:label": "rdf:6_4",
#   "_cell": 187,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib2je3xhwcqyfg47254dowokrcdpjgxqjwfzoatpfcuqelavlcklm"
#   },
#   "_stmt_key": "6_4",
#   "_chunk_num": 6,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [6.5]: [Albert Einstein](/wiki/Albert_Einstein) befriended fellow student [Marcel Grossmann](/wiki/Marcel_Grossmann), who helped him to get by despite his loose study habits.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:colleagues <https://en.wikipedia.org/wiki/Marcel_Grossmann> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiagafbnzugtgtslnzujdrkh2exwxo2ldbf5raie3agyztcak573hu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiagafbnzugtgtslnzujdrkh2exwxo2ldbf5raie3agyztcak573hu",
#   "prov:label": "rdf:6_5",
#   "_cell": 189,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreif5tlvdpu5v3dnbbn2kkloeu6qcqzmpixaxwkwujuj2cdxq4vl3pi"
#   },
#   "_stmt_key": "6_5",
#   "_chunk_num": 6,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [6.6]: [Marcel Grossmann](/wiki/Marcel_Grossmann) helped [Albert Einstein](/wiki/Albert_Einstein) to mathematically underpin his revolutionary insights into physics.
# <https://en.wikipedia.org/wiki/Marcel_Grossmann> schema:colleagues <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigfr6el3m3imoqvwyaal2usupzzpr247ymnwzqmq7e4egunstauxu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigfr6el3m3imoqvwyaal2usupzzpr247ymnwzqmq7e4egunstauxu",
#   "prov:label": "rdf:6_6",
#   "_cell": 191,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihxncboocae5kgg2zkxewusds3sh3v7naby2mu5msxuju27wmji6e"
#   },
#   "_stmt_key": "6_6",
#   "_chunk_num": 6,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [6.7]: [Marie Winteler](/wiki/Marie_Winteler), a year older than [Albert Einstein](/wiki/Albert_Einstein), took up a teaching post in [Olsberg](/wiki/Olsberg%2C_Aargau), [Switzerland](/wiki/Switzerland).
# <https://en.wikipedia.org/wiki/Marie_Winteler> schema:alumniOf <https://en.wikipedia.org/wiki/Olsberg%2C_Aargau> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiftrxc3yyjtb3lfetudrpwa5katxalczrgodhz6f75tlr4dmm7ml4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiftrxc3yyjtb3lfetudrpwa5katxalczrgodhz6f75tlr4dmm7ml4",
#   "prov:label": "rdf:6_7",
#   "_cell": 193,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibgpzlqatus2zfrw6cq2miji6blyuncjnwjzgdiu5idkqgbizxpgm"
#   },
#   "_stmt_key": "6_7",
#   "_chunk_num": 6,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [6.8]: The five other polytechnic school freshmen following the same course as [Albert Einstein](/wiki/Albert_Einstein) included just one woman.
# <https://en.wikipedia.org/wiki/ETH_Zurich> schema:alumni <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiatkuuypvbu3yv5cl4flubfttowkuuybafikkhl52wsiqoo5j5zsi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiatkuuypvbu3yv5cl4flubfttowkuuybafikkhl52wsiqoo5j5zsi",
#   "prov:label": "rdf:6_8",
#   "_cell": 195,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiamb2b6pbbdgd4hthp5ak7dutlrfujhzv6uyd4ndoqrqozrprogla"
#   },
#   "_stmt_key": "6_8",
#   "_chunk_num": 6,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [6.9]: The woman among the five polytechnic school freshmen was a twenty-year-old [Serbian](/wiki/Serbs), [Mileva Marić](/wiki/Mileva_Mari%C4%87).
# <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigfrykgdrmncq63qfabibi5xtnqoimesmwchmz62m3q6mmiebpufy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigfrykgdrmncq63qfabibi5xtnqoimesmwchmz62m3q6mmiebpufy",
#   "prov:label": "rdf:6_9",
#   "_cell": 197,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibyvni6x7ajfovv3gur4jgfrdorgmutkfw3vwmljctlgo5mqe76f4"
#   },
#   "_stmt_key": "6_9",
#   "_chunk_num": 6,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [6.10]: [Albert Einstein](/wiki/Albert_Einstein) and [Mileva Marić](/wiki/Mileva_Mari%C4%87) spent many hours discussing their shared interests and learning about topics in physics that the polytechnic school's lectures did not cover.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:colleagues <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigvzn72qf7cu75jbtry7ihwyw7bs2ktyeg2mur2a34uvkox5azbgq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigvzn72qf7cu75jbtry7ihwyw7bs2ktyeg2mur2a34uvkox5azbgq",
#   "prov:label": "rdf:6_10",
#   "_cell": 199,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaag4lzrzy2x656edciyvzqbow3hcjqu45cnlfltwnqu4joccxwx4"
#   },
#   "_stmt_key": "6_10",
#   "_chunk_num": 6,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [6.11]: In his letters to [Mileva Marić](/wiki/Mileva_Mari%C4%87), [Albert Einstein](/wiki/Albert_Einstein) confessed that exploring science with her by his side was much more enjoyable than reading a textbook in solitude.
# <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> schema:colleagues <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidvhmayewpbvplo32agiy2olvtho4jgdloay3vpfzdvseexxk7eyq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidvhmayewpbvplo32agiy2olvtho4jgdloay3vpfzdvseexxk7eyq",
#   "prov:label": "rdf:6_11",
#   "_cell": 201,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiejue5oermegskcvxylyjkpq4g4laa4zkpslry6sp67w3nwycka4e"
#   },
#   "_stmt_key": "6_11",
#   "_chunk_num": 6,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [6.12]: [Albert Einstein](/wiki/Albert_Einstein) and [Mileva Marić](/wiki/Mileva_Mari%C4%87) became not only friends but also lovers.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:colleagues <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibhsyw2s4pmzgpg7dpfeluyp3m3t7d6b6dr6vh32l4bqsxlm4posu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibhsyw2s4pmzgpg7dpfeluyp3m3t7d6b6dr6vh32l4bqsxlm4posu",
#   "prov:label": "rdf:6_12",
#   "_cell": 203,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifzwj2dao5yc6umyqg3qfm2e6r3xppngywf3g4brk32ptwjplqnaq"
#   },
#   "_stmt_key": "6_12",
#   "_chunk_num": 6,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [6.13]: Historians of physics are divided on the question of the extent to which [Mileva Marić](/wiki/Mileva_Mari%C4%87) contributed to the insights of [Albert Einstein](/wiki/Albert_Einstein)'s *annus mirabilis* publications.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:colleagues <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibmnon3vaq7wsv7sqscstvh2lme66y5mfoa7nl5uiwwe5uc6cpxlu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibmnon3vaq7wsv7sqscstvh2lme66y5mfoa7nl5uiwwe5uc6cpxlu",
#   "prov:label": "rdf:6_13",
#   "_cell": 205,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiek7gtyz3xrgnee3tpzmpudmb7q6guzyoeeu2esauo2qemuhtbmeu"
#   },
#   "_stmt_key": "6_13",
#   "_chunk_num": 6,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [6.14]: There is at least some evidence that [Albert Einstein](/wiki/Albert_Einstein) was influenced by [Mileva Marić](/wiki/Mileva_Mari%C4%87)'s scientific ideas.
# <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> schema:colleagues <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreib2kdvp323a3hxai3cucn4khovvmadd4v7bi2kqxcqymupki5kzsu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreib2kdvp323a3hxai3cucn4khovvmadd4v7bi2kqxcqymupki5kzsu",
#   "prov:label": "rdf:6_14",
#   "_cell": 207,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifecf53xoa6ctyvptvbedfgjupbmohkqbmfrysn5ud67fesnefqui"
#   },
#   "_stmt_key": "6_14",
#   "_chunk_num": 6,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [6.15]: There are scholars who doubt whether [Mileva Marić](/wiki/Mileva_Mari%C4%87)'s impact on [Albert Einstein](/wiki/Albert_Einstein)'s thought was of any great significance at all.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:colleagues <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic7xfmpsnbyfebgvklfy47al3gltorsclrhmadll6gac7p4bam6rq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic7xfmpsnbyfebgvklfy47al3gltorsclrhmadll6gac7p4bam6rq",
#   "prov:label": "rdf:6_15",
#   "_cell": 209,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiakufiejvlwoht744tb4d26ph6t2dx3vielhptehywa5p2eu2ihba"
#   },
#   "_stmt_key": "6_15",
#   "_chunk_num": 6,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [7.1]: [Albert Einstein](/wiki/Albert_Einstein) was born in [Ulm](/wiki/Ulm).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:birthPlace <https://en.wikipedia.org/wiki/Ulm> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidsl6ihdyt27u5klzl3e7a23ruungs4hffef62qyr3tehpb3tauha",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidsl6ihdyt27u5klzl3e7a23ruungs4hffef62qyr3tehpb3tauha",
#   "prov:label": "rdf:7_1",
#   "_cell": 211,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiau7no73cwq424hhiyt45jj5opq2sv7djwqiumy2t4qk6z53ev43a"
#   },
#   "_stmt_key": "7_1",
#   "_chunk_num": 7,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [7.2]: When [Albert Einstein](/wiki/Albert_Einstein) was five years old, he was sick in bed.
# # No triples emitted for this statement
# # Debug: 10 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:birthPlace", "object_value": "<https://en.wikipedia.org/wiki/Ulm>"}
# #   emit_triple: {"statement_id": 5, "subject": "_:s5_quote1", "predicate": "rdf:type", "object_value": "schema:Quotation"}
# #   emit_triple: {"statement_id": 5, "subject": "_:s5_quote1", "predicate": "schema:text", "object_value": "\"Something deeply hidden had to be behind things.\""}
# #   emit_triple: {"statement_id": 5, "subject": "_:s5_quote1", "predicate": "schema:creator", "object_value": "<https://en.wikipedia.org/wiki/Albert_Einstein>"}
# #   emit_triple: {"statement_id": 6, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:alumniOf", "object_value": "_:s6_role1"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigtlj6fxatbbozwcxi2dpjbj4jc4accbo3efdhtb63bzsosjibzo4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigtlj6fxatbbozwcxi2dpjbj4jc4accbo3efdhtb63bzsosjibzo4",
#   "prov:label": "rdf:7_2",
#   "_cell": 213,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibfy2nmukhk3y3sj5tmqputpkcra3oazk7zglg3j6jf5uuohk4vmi"
#   },
#   "_stmt_key": "7_2",
#   "_chunk_num": 7,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [7.3]: [Albert Einstein](/wiki/Albert_Einstein)'s father brought him a [compass](/wiki/magnetic_compass) when he was five and sick in bed.
# # No triples emitted for this statement
# # Debug: 10 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:birthPlace", "object_value": "<https://en.wikipedia.org/wiki/Ulm>"}
# #   emit_triple: {"statement_id": 5, "subject": "_:s5_quote1", "predicate": "rdf:type", "object_value": "schema:Quotation"}
# #   emit_triple: {"statement_id": 5, "subject": "_:s5_quote1", "predicate": "schema:text", "object_value": "\"Something deeply hidden had to be behind things.\""}
# #   emit_triple: {"statement_id": 5, "subject": "_:s5_quote1", "predicate": "schema:creator", "object_value": "<https://en.wikipedia.org/wiki/Albert_Einstein>"}
# #   emit_triple: {"statement_id": 6, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:alumniOf", "object_value": "_:s6_role1"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie2shl5irhjvzqzdpuni5vo5anm5wottqq6lfgcjfnhzh4hzzevf4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie2shl5irhjvzqzdpuni5vo5anm5wottqq6lfgcjfnhzh4hzzevf4",
#   "prov:label": "rdf:7_3",
#   "_cell": 215,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreie5d3iktqrir33e6gojkv4ydruegwb6cuy6ihn75fmctrtjcuyhaq"
#   },
#   "_stmt_key": "7_3",
#   "_chunk_num": 7,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [7.4]: The compass sparked [Albert Einstein](/wiki/Albert_Einstein)'s lifelong fascination with [electromagnetism](/wiki/electromagnetism).
# # No triples emitted for this statement
# # Debug: 10 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:birthPlace", "object_value": "<https://en.wikipedia.org/wiki/Ulm>"}
# #   emit_triple: {"statement_id": 5, "subject": "_:s5_quote1", "predicate": "rdf:type", "object_value": "schema:Quotation"}
# #   emit_triple: {"statement_id": 5, "subject": "_:s5_quote1", "predicate": "schema:text", "object_value": "\"Something deeply hidden had to be behind things.\""}
# #   emit_triple: {"statement_id": 5, "subject": "_:s5_quote1", "predicate": "schema:creator", "object_value": "<https://en.wikipedia.org/wiki/Albert_Einstein>"}
# #   emit_triple: {"statement_id": 6, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:alumniOf", "object_value": "_:s6_role1"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic6o3pbgktbknljkc4kdnutisd7jpy6xqk3kyjto5sjp4afa25dnq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic6o3pbgktbknljkc4kdnutisd7jpy6xqk3kyjto5sjp4afa25dnq",
#   "prov:label": "rdf:7_4",
#   "_cell": 217,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieolnrbkyysda3mvopwi6vh5s6xi4z5qdiudvr4pby3v2nmhvxedu"
#   },
#   "_stmt_key": "7_4",
#   "_chunk_num": 7,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [7.5]: [Albert Einstein](/wiki/Albert_Einstein) realized that "Something deeply hidden had to be behind things."
# _:s5_quote1 rdf:type schema:Quotation .
# _:s5_quote1 schema:text "Something deeply hidden had to be behind things." .
# _:s5_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreica454zcvos5me7nmbovhjzwl63yyz64dq527ttuau5xmzpvqmata",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreica454zcvos5me7nmbovhjzwl63yyz64dq527ttuau5xmzpvqmata",
#   "prov:label": "rdf:7_5",
#   "_cell": 219,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicrfu6q2js3ix6df4k3nbaxketdxrru6epfzwgabpovg2sarm2nze"
#   },
#   "_stmt_key": "7_5",
#   "_chunk_num": 7,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [7.6]: [Albert Einstein](/wiki/Albert_Einstein) attended St. Peter's [Catholic elementary school](/wiki/Catholic_school) in Munich from the age of five.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf _:s6_role1 .
# _:s6_role1 rdf:type schema:OrganizationRole .
# _:s6_role1 schema:alumniOf <https://en.wikipedia.org/wiki/St._Peter's_Catholic_elementary_school> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihrjtqjmxwehirehnanckbhzvz6ymb2duyszvbnnbfsxwxk4bucv4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihrjtqjmxwehirehnanckbhzvz6ymb2duyszvbnnbfsxwxk4bucv4",
#   "prov:label": "rdf:7_6",
#   "_cell": 221,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib3tslssaefhnpzatsnsp7ljfiwq2a5usuvpyc65q4v5tthxs5jhm"
#   },
#   "_stmt_key": "7_6",
#   "_chunk_num": 7,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [7.7]: When [Albert Einstein](/wiki/Albert_Einstein) was eight years old, he was transferred to the [Luitpold Gymnasium](/wiki/Luitpold_Gymnasium).
# # No triples emitted for this statement
# # Debug: 10 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:birthPlace", "object_value": "<https://en.wikipedia.org/wiki/Ulm>"}
# #   emit_triple: {"statement_id": 5, "subject": "_:s5_quote1", "predicate": "rdf:type", "object_value": "schema:Quotation"}
# #   emit_triple: {"statement_id": 5, "subject": "_:s5_quote1", "predicate": "schema:text", "object_value": "\"Something deeply hidden had to be behind things.\""}
# #   emit_triple: {"statement_id": 5, "subject": "_:s5_quote1", "predicate": "schema:creator", "object_value": "<https://en.wikipedia.org/wiki/Albert_Einstein>"}
# #   emit_triple: {"statement_id": 6, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:alumniOf", "object_value": "_:s6_role1"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic2lromi4aitgaiv6y24xznfky5rukyc3fjveeo4zfdxhczepmmbu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic2lromi4aitgaiv6y24xznfky5rukyc3fjveeo4zfdxhczepmmbu",
#   "prov:label": "rdf:7_7",
#   "_cell": 223,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicwnw2n23pjxe4ypihelsvdghyo7gfusywfut2uesclfo5m2uzqki"
#   },
#   "_stmt_key": "7_7",
#   "_chunk_num": 7,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [7.8]: [Albert Einstein](/wiki/Albert_Einstein) received advanced primary and then secondary school education at the [Luitpold Gymnasium](/wiki/Luitpold_Gymnasium).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf _:s8_role1 .
# _:s8_role1 rdf:type schema:OrganizationRole .
# _:s8_role1 schema:alumniOf <https://en.wikipedia.org/wiki/Luitpold_Gymnasium> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic2saxii4xiulj4wa3w63my4tdadh7q6sm6wzoo7fcbthizhn2eny",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic2saxii4xiulj4wa3w63my4tdadh7q6sm6wzoo7fcbthizhn2eny",
#   "prov:label": "rdf:7_8",
#   "_cell": 225,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid5sdq23xbo3bdy5dyniebph3esdreuuecjqrpcgkjiel2niqqz2a"
#   },
#   "_stmt_key": "7_8",
#   "_chunk_num": 7,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Chunk 8 Error: APITimeoutError: Request timed out.
# #
# # === FULL PROMPT SENT TO LLM ===
# #
# # SYSTEM PROMPT:
# # You are an expert at converting factual statements to RDF triples.
# #
# # The statements contain markdown links like [Entity Name](/wiki/Entity_Name) that provide Wikipedia URIs for entities.
# # Convert these to proper RDF URIs using: <https://en.wikipedia.org/wiki/Entity_Name>
# #
# # You have access to these tools:
# #
# # LOOKUP TOOLS (use first to find correct vocabulary):
# # - find_rdf_class: Find the best schema.org class/type for an entity
# # - find_rdf_property: Find the best predicate for a relationship
# #
# # OUTPUT TOOLS (use to emit your triples - MUST include statement_id):
# # - emit_triple: Output a single triple with statement_id
# # - emit_triples: Output multiple triples at once (more efficient)
# #
# # WORKFLOW:
# # 1. For each statement, identify what kind of fact it is (quote, employment, education, award, relationship, etc.)
# # 2. Use find_rdf_class and find_rdf_property with DESCRIPTIVE queries to find appropriate schema.org terms
# # 3. ONLY use schema matches with score >= 0.5. If no good match, skip or use rdfs:comment.
# # 4. Use emit_triple or emit_triples to output RDF triples, INCLUDING the statement_id
# #
# # QUERYING THE SCHEMA TOOLS:
# # Use descriptive natural language, not just keywords. Include:
# # - What the thing IS (for classes) or what relationship it represents (for properties)
# # - Context about domain/range when known
# #
# # GOOD QUERIES:
# # - find_rdf_class("a spoken or written quotation attributed to someone") → Quotation
# # - find_rdf_class("an organization that educates students like a university") → EducationalOrganization
# # - find_rdf_property("the text content of a quote", subject_type="Quotation") → text
# # - find_rdf_property("who said or authored a quotation", subject_type="Quotation") → creator, spokenByCharacter
# # - find_rdf_property("schools someone attended as a student", subject_type="Person") → alumniOf
# #
# # BAD QUERIES (too vague):
# # - find_rdf_class("quote") - missing context
# # - find_rdf_property("said") - doesn't explain the relationship
# # - find_rdf_property("school") - is it attended? works at? type of?
# #
# # URI RULES:
# # - For entities with Wikipedia links like [Albert Einstein](/wiki/Albert_Einstein):
# #   Use: <https://en.wikipedia.org/wiki/Albert_Einstein>
# # - For entities in the Entity Registry: Use their provided URI
# # - For new entities not in either: Use fragment URIs like <#entity_name>
# # - NEVER invent Wikidata URIs (wd:Q...) unless explicitly provided
# #
# # BLANK NODE NAMING:
# # Use the statement ID in blank node names to ensure uniqueness across chunks:
# #   - For statement [3.5], use: _:s3_5_role1, _:s3_5_role2, etc.
# #   - NOT just _:pos1, _:pos2 (these collide across statements)
# #
# # MODELING PATTERNS:
# #
# # 1. QUOTATIONS (when someone said/stated/objected something):
# #    Create a Quotation instance with text and attribution:
# #    _:s1_quote1 a schema:Quotation .
# #    _:s1_quote1 schema:text "The actual quote text" .
# #    _:s1_quote1 schema:creator <wiki:Person_Who_Said_It> .
# #
# # 2. TEMPORAL/QUALIFIED RELATIONSHIPS (dates on relationships):
# #    Use an intermediate Role node (schema.org Role pattern):
# #
# #    Example - Employment: "Einstein worked at University of Zurich from 1909 to 1911"
# #      <wiki:Albert_Einstein> schema:worksFor _:s1_role1 .
# #      _:s1_role1 a schema:OrganizationRole .
# #      _:s1_role1 schema:worksFor <wiki:University_of_Zurich> .
# #      _:s1_role1 schema:startDate "1909"^^xsd:gYear .
# #      _:s1_role1 schema:endDate "1911"^^xsd:gYear .
# #
# #    Example - Awards: "Einstein received the Nobel Prize in 1921"
# #      <wiki:Albert_Einstein> schema:award _:s2_award1 .
# #      _:s2_award1 a schema:Role .
# #      _:s2_award1 schema:award <wiki:Nobel_Prize_in_Physics> .
# #      _:s2_award1 schema:startDate "1921"^^xsd:gYear .
# #
# #    Example - Education: "Einstein attended University of Zurich from 1896 to 1900"
# #      <wiki:Albert_Einstein> schema:alumniOf _:s3_edu1 .
# #      _:s3_edu1 a schema:OrganizationRole .
# #      _:s3_edu1 schema:alumniOf <wiki:University_of_Zurich> .
# #      _:s3_edu1 schema:startDate "1896"^^xsd:gYear .
# #      _:s3_edu1 schema:endDate "1900"^^xsd:gYear .
# #
# # 3. SIMPLE FACTS (no dates/qualifiers needed):
# #    Direct triples without Role:
# #    <wiki:Einstein> schema:birthDate "1879-03-14"^^xsd:date .
# #    <wiki:Einstein> schema:birthPlace <wiki:Ulm> .
# #
# # WHAT NOT TO DO:
# # 1. DO NOT use schema:description for quotes, opinions, or narrative facts.
# #    schema:description is ONLY for describing what an entity IS, not what happened to it.
# #    WRONG: <Einstein> schema:description "God does not play dice" .
# #    RIGHT: Create a schema:Quotation with schema:text for the quote.
# #
# # 2. DO NOT emit unrelated triples when no good schema match exists.
# #    If a statement is about "being sick in bed", don't emit schema:birthDate.
# #    If no good match (score >= 0.5), either:
# #    - Skip the statement entirely
# #    - Use rdfs:comment to preserve the text: <Einstein> rdfs:comment "Statement text here" .
# #
# # 3. DO NOT conflate past and present states.
# #    "Einstein renounced his German citizenship in 1896" means he LOST it.
# #    Use endDate on a citizenship Role, not startDate.
# #
# # 4. DO NOT extract facts not stated in the statement.
# #    Only model what the specific statement says, not general knowledge about the subject.
# #
# # 5. DATES REQUIRE ROLE PATTERN - CRITICAL!
# #    If a statement mentions "from X to Y" or any year/date range, you MUST use the Role pattern.
# #    Simple triples like <Einstein> schema:worksFor <ETH> lose the temporal information.
# #
# #    Pattern: Subject → Role → Target + dates
# #    <Subject> schema:property _:role .
# #    _:role a schema:Role .           (or OrganizationRole for employment/membership)
# #    _:role schema:property <Target> .
# #    _:role schema:startDate "YYYY"^^xsd:gYear .
# #    _:role schema:endDate "YYYY"^^xsd:gYear .
# #
# # IMPORTANT:
# # - Do NOT write Turtle syntax in your response - use the emit tools instead
# # - ALWAYS include the statement_id when emitting triples
# # - Include statement_id in blank node names: _:s{{id}}_role1
# # - Only emit triples for facts that CAN be properly modeled in schema.org
# # - It is better to skip a statement than emit incorrect triples
# # - Statements with dates MUST use Role pattern (5+ triples, not 1)
# #
# # HUMAN PROMPT:
# # Convert these factual statements to RDF triples.
# #
# # Source: https://en.wikipedia.org/wiki/Albert_Einstein
# # Section context: Albert Einstein > Life and career > Childhood, youth and education
# #
# # Entity Registry (use these URIs for known entities):
# # <https://en.wikipedia.org/wiki/Albert_Einstein> # Albert Einstein (Person) (Wikidata: Q937)
# # <https://en.wikipedia.org/wiki/Ulm> # Ulm (Thing)
# # <https://en.wikipedia.org/wiki/Kingdom_of_W%C3%BCrttemberg> # Kingdom of Württemberg (Thing)
# # <https://en.wikipedia.org/wiki/German_Empire> # German Empire (Thing)
# # <https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey> # Princeton, New Jersey (Thing)
# # <https://en.wikipedia.org/wiki/Lieserl_Einstein> # Lieserl (Thing)
# # <https://en.wikipedia.org/wiki/Hans_Albert_Einstein> # Hans Albert (Thing)
# # <https://en.wikipedia.org/wiki/Einstein_family> # Eduard "Tete" (Thing)
# # <https://en.wikipedia.org/wiki/Einstein_family> # Einstein (Thing)
# # <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> # Mileva Marić (Thing)
# # <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> # Elsa Löwenthal (Thing)
# # <https://en.wikipedia.org/wiki/Statelessness> # Stateless (Thing)
# # <https://en.wikipedia.org/wiki/Switzerland> # Switzerland (Thing)
# # <https://en.wikipedia.org/wiki/Kingdom_of_Prussia> # Kingdom of Prussia (Thing)
# # <https://en.wikipedia.org/wiki/Free_State_of_Prussia> # Free State of Prussia (Thing)
# # <https://en.wikipedia.org/wiki/Weimar_Republic> # Weimar Republic (Thing)
# # <https://en.wikipedia.org/wiki/Citizenship_of_the_United_States> # United States (Thing)
# # <https://en.wikipedia.org/wiki/Physics> # Physics (Thing)
# # <https://en.wikipedia.org/wiki/University_of_Bern> # University of Bern (Thing)
# # <https://en.wikipedia.org/wiki/University_of_Zurich> # University of Zurich (Thing)
# # <https://en.wikipedia.org/wiki/Charles_University_in_Prague> # Charles University in Prague (Thing)
# # <https://en.wikipedia.org/wiki/ETH_Zurich> # ETH Zurich (Thing)
# # <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> # Prussian Academy of Sciences (Thing)
# # <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> # Humboldt University of Berlin (Thing)
# # <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute> # Kaiser Wilhelm Institute (Thing)
# # <https://en.wikipedia.org/wiki/German_Physical_Society> # German Physical Society (Thing)
# # <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> # Institute for Advanced Study (Thing)
# # <https://en.wikipedia.org/wiki/ETH_Zurich> # Swiss Federal Polytechnic School (Thing)
# # <https://en.wikipedia.org/wiki/PhD> # PhD (Thing)
# # <https://en.wikipedia.org/wiki/Alfred_Kleiner> # Alfred Kleiner (Thing)
# # <https://en.wikipedia.org/wiki/Heinrich_Friedrich_Weber> # Heinrich Friedrich Weber (Thing)
# # <https://en.wikipedia.org/wiki/General_relativity> # General relativity (Thing)
# # <https://en.wikipedia.org/wiki/Special_relativity> # Special relativity (Thing)
# # <https://en.wikipedia.org/wiki/Photoelectric_effect> # Photoelectric effect (Thing)
# # <https://en.wikipedia.org/wiki/Mass%E2%80%93energy_equivalence> # ''E''=''mc''<sup>2</sup> (mass–energy equivalence) (Thing)
# # <https://en.wikipedia.org/wiki/Planck%E2%80%93Einstein_relation> # ''E''=''hf'' (Planck–Einstein relation) (Thing)
# # <https://en.wikipedia.org/wiki/Brownian_motion> # Theory of Brownian motion (Thing)
# # <https://en.wikipedia.org/wiki/Einstein_field_equations> # Einstein field equations (Thing)
# # <https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_statistics> # Bose–Einstein statistics (Thing)
# # <https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_condensate> # Bose–Einstein condensate (Thing)
# # <https://en.wikipedia.org/wiki/Gravitational_wave> # Gravitational wave (Thing)
# # <https://en.wikipedia.org/wiki/Cosmological_constant> # Cosmological constant (Thing)
# # <https://en.wikipedia.org/wiki/Unified_field_theory> # Unified field theory (Thing)
# # <https://en.wikipedia.org/wiki/EPR_paradox> # EPR paradox (Thing)
# # <https://en.wikipedia.org/wiki/Ensemble_interpretation> # Ensemble interpretation (Thing)
# # <https://en.wikipedia.org/wiki/List_of_things_named_after_Albert_Einstein> # List of other concepts (Thing)
# # <https://en.wikipedia.org/wiki/Barnard_Medal_for_Meritorious_Service_to_Science> # Barnard Medal for Meritorious Service to Science (Thing)
# # <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics> # Nobel Prize in Physics (Thing)
# # <https://en.wikipedia.org/wiki/Matteucci_Medal> # Matteucci Medal (Thing)
# # <https://en.wikipedia.org/wiki/List_of_fellows_of_the_Royal_Society_elected_in_1921> # ForMemRS (Thing)
# # <https://en.wikipedia.org/wiki/Copley_Medal> # Copley Medal (Thing)
# #
# # Statements to convert (each has a unique ID like [3.5] - include this in blank node names):
# # [1] In 1894, Hermann and Jakob's company tendered for a contract to install electric lighting in Munich.
# # [2] Hermann and Jakob's company lacked the capital required to update their technology from direct current to alternating current.
# # [3] [Albert Einstein](/wiki/Albert_Einstein) was fifteen years old in 1894.
# # [4] [Albert Einstein](/wiki/Albert_Einstein) stayed behind in [Munich](/wiki/Munich) to finish his schooling in 1894.
# # [5] [Albert Einstein](/wiki/Albert_Einstein)'s father wanted him to study [electrical engineering](/wiki/electrical_engineering).
# # [6] [Albert Einstein](/wiki/Albert_Einstein) was a fractious pupil at the Gymnasium.
# # [7] The Gymnasium's regimen and teaching methods were not congenial to [Albert Einstein](/wiki/Albert_Einstein).
# # [8] [Albert Einstein](/wiki/Albert_Einstein) later wrote that the school's policy of strict [rote learning](/wiki/rote_learning) was harmful to creativity.
# # [9] At the end of December 1894, a doctor's letter persuaded the Luitpold's authorities to release [Albert Einstein](/wiki/Albert_Einstein) from its care.
# # [10] [Albert Einstein](/wiki/Albert_Einstein) joined his family in [Pavia](/wiki/Pavia) at the end of December 1894.
# # [11] While in [Italy](/wiki/Italy) as a teenager, [Albert Einstein](/wiki/Albert_Einstein) wrote an essay entitled "On the Investigation of the State of the [Ether](/wiki/Aether_%28classical_element%29) in a Magnetic Field".
# # [12] [Max Talmud](/wiki/Max_Talmud) was a family tutor of [Albert Einstein](/wiki/Albert_Einstein).
# # [13] [Max Talmud](/wiki/Max_Talmud) said that after giving the twelve-year-old [Albert Einstein](/wiki/Albert_Einstein) a geometry textbook, the boy had worked through the whole book.
# # [14] After working through the geometry textbook, [Albert Einstein](/wiki/Albert_Einstein) devoted himself to higher mathematics.
# # [15] [Albert Einstein](/wiki/Albert_Einstein)'s mathematical genius was so advanced that [Max Talmud](/wiki/Max_Talmud) could not follow it.
# # [16] [Albert Einstein](/wiki/Albert_Einstein) mastered [integral](/wiki/integral) and [differential calculus](/wiki/differential_calculus) while he was fourteen years old.
# # [17] [Albert Einstein](/wiki/Albert_Einstein)'s love of algebra and geometry was so great that at twelve, he was already confident that nature could be understood as a "mathematical structure".
# #
# # CRITICAL RULES:
# #
# # 1. URI EXTRACTION: Convert markdown links to Wikipedia URIs:
# #    [Albert Einstein](/wiki/Albert_Einstein) → <https://en.wikipedia.org/wiki/Albert_Einstein>
# #
# # 2. BLANK NODE NAMING: Include statement ID to avoid collisions:
# #    For statement [3.5], use: _:s3_5_role1 (NOT just _:role1)
# #
# # 3. SCHEMA MATCHING: Only use matches with score >= 0.5.
# #    If no good match exists, either skip the statement or use rdfs:comment.
# #
# # 4. TEMPORAL RELATIONSHIPS - MANDATORY ROLE PATTERN:
# #    If a statement has dates like "from X to Y" or year ranges, you MUST use the Role pattern.
# #    A simple triple loses the temporal information - DO NOT emit just:
# #      <Einstein> schema:employee <ETH_Zurich> .  ← WRONG! Loses the dates!
# #
# #    CORRECT Role Pattern (REQUIRED for dated relationships):
# #    Statement: "Einstein worked at ETH Zurich from 1912 to 1914"
# #      <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor _:s1_21_role1 .
# #      _:s1_21_role1 a schema:OrganizationRole .
# #      _:s1_21_role1 schema:worksFor <https://en.wikipedia.org/wiki/ETH_Zurich> .
# #      _:s1_21_role1 schema:startDate "1912"^^xsd:gYear .
# #      _:s1_21_role1 schema:endDate "1914"^^xsd:gYear .
# #
# #    Statement: "Einstein was a citizen of Switzerland from 1901 to 1955"
# #      <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality _:s1_14_role1 .
# #      _:s1_14_role1 a schema:Role .
# #      _:s1_14_role1 schema:nationality <https://en.wikipedia.org/wiki/Switzerland> .
# #      _:s1_14_role1 schema:startDate "1901"^^xsd:gYear .
# #      _:s1_14_role1 schema:endDate "1955"^^xsd:gYear .
# #
# #    Use OrganizationRole for employment/membership, Role for citizenship/other.
# #
# # 5. DO NOT:
# #    - Use schema:description for quotes or narrative (only for entity descriptions)
# #    - Emit unrelated triples when no good match exists
# #    - Extract facts not stated in the statement
# #    - Emit simple triples when there are dates (MUST use Role pattern)
# #
# # Process each statement. If you cannot properly model it, skip it or use rdfs:comment.
# #
# # === END PROMPT ===

# %% [raw]
# # Chunk 9 Error: APITimeoutError: Request timed out.
# #
# # === FULL PROMPT SENT TO LLM ===
# #
# # SYSTEM PROMPT:
# # You are an expert at converting factual statements to RDF triples.
# #
# # The statements contain markdown links like [Entity Name](/wiki/Entity_Name) that provide Wikipedia URIs for entities.
# # Convert these to proper RDF URIs using: <https://en.wikipedia.org/wiki/Entity_Name>
# #
# # You have access to these tools:
# #
# # LOOKUP TOOLS (use first to find correct vocabulary):
# # - find_rdf_class: Find the best schema.org class/type for an entity
# # - find_rdf_property: Find the best predicate for a relationship
# #
# # OUTPUT TOOLS (use to emit your triples - MUST include statement_id):
# # - emit_triple: Output a single triple with statement_id
# # - emit_triples: Output multiple triples at once (more efficient)
# #
# # WORKFLOW:
# # 1. For each statement, identify what kind of fact it is (quote, employment, education, award, relationship, etc.)
# # 2. Use find_rdf_class and find_rdf_property with DESCRIPTIVE queries to find appropriate schema.org terms
# # 3. ONLY use schema matches with score >= 0.5. If no good match, skip or use rdfs:comment.
# # 4. Use emit_triple or emit_triples to output RDF triples, INCLUDING the statement_id
# #
# # QUERYING THE SCHEMA TOOLS:
# # Use descriptive natural language, not just keywords. Include:
# # - What the thing IS (for classes) or what relationship it represents (for properties)
# # - Context about domain/range when known
# #
# # GOOD QUERIES:
# # - find_rdf_class("a spoken or written quotation attributed to someone") → Quotation
# # - find_rdf_class("an organization that educates students like a university") → EducationalOrganization
# # - find_rdf_property("the text content of a quote", subject_type="Quotation") → text
# # - find_rdf_property("who said or authored a quotation", subject_type="Quotation") → creator, spokenByCharacter
# # - find_rdf_property("schools someone attended as a student", subject_type="Person") → alumniOf
# #
# # BAD QUERIES (too vague):
# # - find_rdf_class("quote") - missing context
# # - find_rdf_property("said") - doesn't explain the relationship
# # - find_rdf_property("school") - is it attended? works at? type of?
# #
# # URI RULES:
# # - For entities with Wikipedia links like [Albert Einstein](/wiki/Albert_Einstein):
# #   Use: <https://en.wikipedia.org/wiki/Albert_Einstein>
# # - For entities in the Entity Registry: Use their provided URI
# # - For new entities not in either: Use fragment URIs like <#entity_name>
# # - NEVER invent Wikidata URIs (wd:Q...) unless explicitly provided
# #
# # BLANK NODE NAMING:
# # Use the statement ID in blank node names to ensure uniqueness across chunks:
# #   - For statement [3.5], use: _:s3_5_role1, _:s3_5_role2, etc.
# #   - NOT just _:pos1, _:pos2 (these collide across statements)
# #
# # MODELING PATTERNS:
# #
# # 1. QUOTATIONS (when someone said/stated/objected something):
# #    Create a Quotation instance with text and attribution:
# #    _:s1_quote1 a schema:Quotation .
# #    _:s1_quote1 schema:text "The actual quote text" .
# #    _:s1_quote1 schema:creator <wiki:Person_Who_Said_It> .
# #
# # 2. TEMPORAL/QUALIFIED RELATIONSHIPS (dates on relationships):
# #    Use an intermediate Role node (schema.org Role pattern):
# #
# #    Example - Employment: "Einstein worked at University of Zurich from 1909 to 1911"
# #      <wiki:Albert_Einstein> schema:worksFor _:s1_role1 .
# #      _:s1_role1 a schema:OrganizationRole .
# #      _:s1_role1 schema:worksFor <wiki:University_of_Zurich> .
# #      _:s1_role1 schema:startDate "1909"^^xsd:gYear .
# #      _:s1_role1 schema:endDate "1911"^^xsd:gYear .
# #
# #    Example - Awards: "Einstein received the Nobel Prize in 1921"
# #      <wiki:Albert_Einstein> schema:award _:s2_award1 .
# #      _:s2_award1 a schema:Role .
# #      _:s2_award1 schema:award <wiki:Nobel_Prize_in_Physics> .
# #      _:s2_award1 schema:startDate "1921"^^xsd:gYear .
# #
# #    Example - Education: "Einstein attended University of Zurich from 1896 to 1900"
# #      <wiki:Albert_Einstein> schema:alumniOf _:s3_edu1 .
# #      _:s3_edu1 a schema:OrganizationRole .
# #      _:s3_edu1 schema:alumniOf <wiki:University_of_Zurich> .
# #      _:s3_edu1 schema:startDate "1896"^^xsd:gYear .
# #      _:s3_edu1 schema:endDate "1900"^^xsd:gYear .
# #
# # 3. SIMPLE FACTS (no dates/qualifiers needed):
# #    Direct triples without Role:
# #    <wiki:Einstein> schema:birthDate "1879-03-14"^^xsd:date .
# #    <wiki:Einstein> schema:birthPlace <wiki:Ulm> .
# #
# # WHAT NOT TO DO:
# # 1. DO NOT use schema:description for quotes, opinions, or narrative facts.
# #    schema:description is ONLY for describing what an entity IS, not what happened to it.
# #    WRONG: <Einstein> schema:description "God does not play dice" .
# #    RIGHT: Create a schema:Quotation with schema:text for the quote.
# #
# # 2. DO NOT emit unrelated triples when no good schema match exists.
# #    If a statement is about "being sick in bed", don't emit schema:birthDate.
# #    If no good match (score >= 0.5), either:
# #    - Skip the statement entirely
# #    - Use rdfs:comment to preserve the text: <Einstein> rdfs:comment "Statement text here" .
# #
# # 3. DO NOT conflate past and present states.
# #    "Einstein renounced his German citizenship in 1896" means he LOST it.
# #    Use endDate on a citizenship Role, not startDate.
# #
# # 4. DO NOT extract facts not stated in the statement.
# #    Only model what the specific statement says, not general knowledge about the subject.
# #
# # 5. DATES REQUIRE ROLE PATTERN - CRITICAL!
# #    If a statement mentions "from X to Y" or any year/date range, you MUST use the Role pattern.
# #    Simple triples like <Einstein> schema:worksFor <ETH> lose the temporal information.
# #
# #    Pattern: Subject → Role → Target + dates
# #    <Subject> schema:property _:role .
# #    _:role a schema:Role .           (or OrganizationRole for employment/membership)
# #    _:role schema:property <Target> .
# #    _:role schema:startDate "YYYY"^^xsd:gYear .
# #    _:role schema:endDate "YYYY"^^xsd:gYear .
# #
# # IMPORTANT:
# # - Do NOT write Turtle syntax in your response - use the emit tools instead
# # - ALWAYS include the statement_id when emitting triples
# # - Include statement_id in blank node names: _:s{{id}}_role1
# # - Only emit triples for facts that CAN be properly modeled in schema.org
# # - It is better to skip a statement than emit incorrect triples
# # - Statements with dates MUST use Role pattern (5+ triples, not 1)
# #
# # HUMAN PROMPT:
# # Convert these factual statements to RDF triples.
# #
# # Source: https://en.wikipedia.org/wiki/Albert_Einstein
# # Section context: Albert Einstein > Life and career > Childhood, youth and education
# #
# # Entity Registry (use these URIs for known entities):
# # <https://en.wikipedia.org/wiki/Albert_Einstein> # Albert Einstein (Person) (Wikidata: Q937)
# # <https://en.wikipedia.org/wiki/Ulm> # Ulm (Thing)
# # <https://en.wikipedia.org/wiki/Kingdom_of_W%C3%BCrttemberg> # Kingdom of Württemberg (Thing)
# # <https://en.wikipedia.org/wiki/German_Empire> # German Empire (Thing)
# # <https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey> # Princeton, New Jersey (Thing)
# # <https://en.wikipedia.org/wiki/Lieserl_Einstein> # Lieserl (Thing)
# # <https://en.wikipedia.org/wiki/Hans_Albert_Einstein> # Hans Albert (Thing)
# # <https://en.wikipedia.org/wiki/Einstein_family> # Eduard "Tete" (Thing)
# # <https://en.wikipedia.org/wiki/Einstein_family> # Einstein (Thing)
# # <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> # Mileva Marić (Thing)
# # <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> # Elsa Löwenthal (Thing)
# # <https://en.wikipedia.org/wiki/Statelessness> # Stateless (Thing)
# # <https://en.wikipedia.org/wiki/Switzerland> # Switzerland (Thing)
# # <https://en.wikipedia.org/wiki/Kingdom_of_Prussia> # Kingdom of Prussia (Thing)
# # <https://en.wikipedia.org/wiki/Free_State_of_Prussia> # Free State of Prussia (Thing)
# # <https://en.wikipedia.org/wiki/Weimar_Republic> # Weimar Republic (Thing)
# # <https://en.wikipedia.org/wiki/Citizenship_of_the_United_States> # United States (Thing)
# # <https://en.wikipedia.org/wiki/Physics> # Physics (Thing)
# # <https://en.wikipedia.org/wiki/University_of_Bern> # University of Bern (Thing)
# # <https://en.wikipedia.org/wiki/University_of_Zurich> # University of Zurich (Thing)
# # <https://en.wikipedia.org/wiki/Charles_University_in_Prague> # Charles University in Prague (Thing)
# # <https://en.wikipedia.org/wiki/ETH_Zurich> # ETH Zurich (Thing)
# # <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> # Prussian Academy of Sciences (Thing)
# # <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> # Humboldt University of Berlin (Thing)
# # <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute> # Kaiser Wilhelm Institute (Thing)
# # <https://en.wikipedia.org/wiki/German_Physical_Society> # German Physical Society (Thing)
# # <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> # Institute for Advanced Study (Thing)
# # <https://en.wikipedia.org/wiki/ETH_Zurich> # Swiss Federal Polytechnic School (Thing)
# # <https://en.wikipedia.org/wiki/PhD> # PhD (Thing)
# # <https://en.wikipedia.org/wiki/Alfred_Kleiner> # Alfred Kleiner (Thing)
# # <https://en.wikipedia.org/wiki/Heinrich_Friedrich_Weber> # Heinrich Friedrich Weber (Thing)
# # <https://en.wikipedia.org/wiki/General_relativity> # General relativity (Thing)
# # <https://en.wikipedia.org/wiki/Special_relativity> # Special relativity (Thing)
# # <https://en.wikipedia.org/wiki/Photoelectric_effect> # Photoelectric effect (Thing)
# # <https://en.wikipedia.org/wiki/Mass%E2%80%93energy_equivalence> # ''E''=''mc''<sup>2</sup> (mass–energy equivalence) (Thing)
# # <https://en.wikipedia.org/wiki/Planck%E2%80%93Einstein_relation> # ''E''=''hf'' (Planck–Einstein relation) (Thing)
# # <https://en.wikipedia.org/wiki/Brownian_motion> # Theory of Brownian motion (Thing)
# # <https://en.wikipedia.org/wiki/Einstein_field_equations> # Einstein field equations (Thing)
# # <https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_statistics> # Bose–Einstein statistics (Thing)
# # <https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_condensate> # Bose–Einstein condensate (Thing)
# # <https://en.wikipedia.org/wiki/Gravitational_wave> # Gravitational wave (Thing)
# # <https://en.wikipedia.org/wiki/Cosmological_constant> # Cosmological constant (Thing)
# # <https://en.wikipedia.org/wiki/Unified_field_theory> # Unified field theory (Thing)
# # <https://en.wikipedia.org/wiki/EPR_paradox> # EPR paradox (Thing)
# # <https://en.wikipedia.org/wiki/Ensemble_interpretation> # Ensemble interpretation (Thing)
# # <https://en.wikipedia.org/wiki/List_of_things_named_after_Albert_Einstein> # List of other concepts (Thing)
# # <https://en.wikipedia.org/wiki/Barnard_Medal_for_Meritorious_Service_to_Science> # Barnard Medal for Meritorious Service to Science (Thing)
# # <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics> # Nobel Prize in Physics (Thing)
# # <https://en.wikipedia.org/wiki/Matteucci_Medal> # Matteucci Medal (Thing)
# # <https://en.wikipedia.org/wiki/List_of_fellows_of_the_Royal_Society_elected_in_1921> # ForMemRS (Thing)
# # <https://en.wikipedia.org/wiki/Copley_Medal> # Copley Medal (Thing)
# #
# # Statements to convert (each has a unique ID like [3.5] - include this in blank node names):
# # [1] At thirteen, [Albert Einstein](/wiki/Albert_Einstein) was introduced to [Kant](/wiki/Kant)'s *[Critique of Pure Reason](/wiki/Critique_of_Pure_Reason)* by [Talmud](/wiki/Talmud).
# # [2] At thirteen, [Albert Einstein](/wiki/Albert_Einstein) was a child.
# # [3] [Albert Einstein](/wiki/Albert_Einstein) became interested in music and philosophy at thirteen.
# # [4] [Kant](/wiki/Kant)'s *[Critique of Pure Reason](/wiki/Critique_of_Pure_Reason)* became [Albert Einstein](/wiki/Albert_Einstein)'s favorite philosopher.
# # [5] According to [Talmud](/wiki/Talmud), [Albert Einstein](/wiki/Albert_Einstein) was thirteen years old when he understood Kant's works.
# # [6] In 1895, [Albert Einstein](/wiki/Albert_Einstein) was sixteen years old.
# # [7] In 1895, [Albert Einstein](/wiki/Albert_Einstein) sat the entrance examination for the [federal polytechnic school](/wiki/ETH_Zurich) in [Zurich](/wiki/Zurich), [Switzerland](/wiki/Switzerland).
# # [8] [Albert Einstein](/wiki/Albert_Einstein) failed to reach the required standard in the general part of the entrance examination.
# # [9] [Albert Einstein](/wiki/Albert_Einstein) performed with distinction in physics and mathematics in the entrance examination.
# # [10] On the advice of the polytechnic's principal, [Albert Einstein](/wiki/Albert_Einstein) completed his secondary education at the [Argovian cantonal school](/wiki/Old_Cantonal_School_Aarau) in [Aarau](/wiki/Aarau), [Switzerland](/wiki/Switzerland).
# # [11] [Albert Einstein](/wiki/Albert_Einstein) graduated from the [Argovian cantonal school](/wiki/Old_Cantonal_School_Aarau) in 1896.
# # [12] While lodging in [Aarau](/wiki/Aarau) with the family of [Jost Winteler](/wiki/Jost_Winteler), [Albert Einstein](/wiki/Albert_Einstein) fell in love with Winteler's daughter, [Marie](/wiki/Marie_Einstein).
# # [13] [Albert Einstein](/wiki/Albert_Einstein)'s sister was [Maja](/wiki/Maja_Einstein).
# # [14] [Maja](/wiki/Maja_Einstein) later married Winteler's son, [Paul](/wiki/Paul_Winteler).
# # [15] The [federal polytechnic school](/wiki/ETH_Zurich) was later known as the Eidgenössische Technische Hochschule.
# # [16] The [Argovian cantonal school](/wiki/Old_Cantonal_School_Aarau) was a [*gymnasium*](/wiki/Gymnasium_%28school%29).
# # [17] [Jost Winteler](/wiki/Jost_Winteler) was a resident of [Aarau](/wiki/Aarau).
# # [18] [Marie](/wiki/Marie_Einstein) was the daughter of [Jost Winteler](/wiki/Jost_Winteler).
# #
# # CRITICAL RULES:
# #
# # 1. URI EXTRACTION: Convert markdown links to Wikipedia URIs:
# #    [Albert Einstein](/wiki/Albert_Einstein) → <https://en.wikipedia.org/wiki/Albert_Einstein>
# #
# # 2. BLANK NODE NAMING: Include statement ID to avoid collisions:
# #    For statement [3.5], use: _:s3_5_role1 (NOT just _:role1)
# #
# # 3. SCHEMA MATCHING: Only use matches with score >= 0.5.
# #    If no good match exists, either skip the statement or use rdfs:comment.
# #
# # 4. TEMPORAL RELATIONSHIPS - MANDATORY ROLE PATTERN:
# #    If a statement has dates like "from X to Y" or year ranges, you MUST use the Role pattern.
# #    A simple triple loses the temporal information - DO NOT emit just:
# #      <Einstein> schema:employee <ETH_Zurich> .  ← WRONG! Loses the dates!
# #
# #    CORRECT Role Pattern (REQUIRED for dated relationships):
# #    Statement: "Einstein worked at ETH Zurich from 1912 to 1914"
# #      <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor _:s1_21_role1 .
# #      _:s1_21_role1 a schema:OrganizationRole .
# #      _:s1_21_role1 schema:worksFor <https://en.wikipedia.org/wiki/ETH_Zurich> .
# #      _:s1_21_role1 schema:startDate "1912"^^xsd:gYear .
# #      _:s1_21_role1 schema:endDate "1914"^^xsd:gYear .
# #
# #    Statement: "Einstein was a citizen of Switzerland from 1901 to 1955"
# #      <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality _:s1_14_role1 .
# #      _:s1_14_role1 a schema:Role .
# #      _:s1_14_role1 schema:nationality <https://en.wikipedia.org/wiki/Switzerland> .
# #      _:s1_14_role1 schema:startDate "1901"^^xsd:gYear .
# #      _:s1_14_role1 schema:endDate "1955"^^xsd:gYear .
# #
# #    Use OrganizationRole for employment/membership, Role for citizenship/other.
# #
# # 5. DO NOT:
# #    - Use schema:description for quotes or narrative (only for entity descriptions)
# #    - Emit unrelated triples when no good match exists
# #    - Extract facts not stated in the statement
# #    - Emit simple triples when there are dates (MUST use Role pattern)
# #
# # Process each statement. If you cannot properly model it, skip it or use rdfs:comment.
# #
# # === END PROMPT ===

# %% [raw]
# # Statement [10.1]: In January 1896, [Albert Einstein](/wiki/Albert_Einstein) renounced his [citizenship of the German Kingdom of Württemberg](/wiki/German_citizenship) in order to avoid [conscription into military service](/wiki/Conscription_in_Germany).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality <https://en.wikipedia.org/wiki/Kingdom_of_W%C3%BCrttemberg> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:unregisterAction <https://en.wikipedia.org/wiki/German_citizenship> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiez5q3fhpabkjuz5d4upuypmuzdyae75g4lzlm3y33xbysisyakue",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiez5q3fhpabkjuz5d4upuypmuzdyae75g4lzlm3y33xbysisyakue",
#   "prov:label": "rdf:10_1",
#   "_cell": 229,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib6txn3uydtpgrfsy6ymnlet44ydj54shyrhbrx74njnax4jsiqfu"
#   },
#   "_stmt_key": "10_1",
#   "_chunk_num": 10,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [10.2]: The *[Matura](/wiki/Matura)* awarded to [Albert Einstein](/wiki/Albert_Einstein) in September 1896 acknowledged him to have performed well across most of the curriculum.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Bern> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifi56j3nv3jmy7kudow637qu4sonwpzflrdbbkwuuqveuqqsrwtlu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifi56j3nv3jmy7kudow637qu4sonwpzflrdbbkwuuqveuqqsrwtlu",
#   "prov:label": "rdf:10_2",
#   "_cell": 231,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibpmtfi4bge2zouhhxbyodieq27ud2qobm33cvkkvt7gd5x7orfoi"
#   },
#   "_stmt_key": "10_2",
#   "_chunk_num": 10,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [10.3]: [Albert Einstein](/wiki/Albert_Einstein) received a [top grade of 6](/wiki/Grading_systems_by_country) for history, physics, algebra, geometry, and descriptive geometry in his *[Matura](/wiki/Matura)*.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:educationalCredentialAwarded <https://en.wikipedia.org/wiki/Matura> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihhuo3sj7qdbd2v6k2xwltju3zn2kfbz6redsn4srgfnur6re5qcm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihhuo3sj7qdbd2v6k2xwltju3zn2kfbz6redsn4srgfnur6re5qcm",
#   "prov:label": "rdf:10_3",
#   "_cell": 233,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaxevhmtehpunwfvgvz2axwexzdwnu4k2fkczjksbhzetaz5224w4"
#   },
#   "_stmt_key": "10_3",
#   "_chunk_num": 10,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [10.4]: At seventeen, [Albert Einstein](/wiki/Albert_Einstein) enrolled in the four-year mathematics and physics teaching diploma program at the [Swiss Federal Polytechnic School](/wiki/ETH_Zurich).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiblndshtsr45lirqf2njinbsevrkizpstg44hzlwxltf7d37srdkq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiblndshtsr45lirqf2njinbsevrkizpstg44hzlwxltf7d37srdkq",
#   "prov:label": "rdf:10_4",
#   "_cell": 235,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib2je3xhwcqyfg47254dowokrcdpjgxqjwfzoatpfcuqelavlcklm"
#   },
#   "_stmt_key": "10_4",
#   "_chunk_num": 10,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [10.5]: [Albert Einstein](/wiki/Albert_Einstein) befriended fellow student [Marcel Grossmann](/wiki/Marcel_Grossmann) at the [Swiss Federal Polytechnic School](/wiki/ETH_Zurich).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:colleague <https://en.wikipedia.org/wiki/Marcel_Grossmann> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibzx2xl2qkwrawr557gl4oe34i4pk2xotb65wkuwcec5qgu7hvjhm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibzx2xl2qkwrawr557gl4oe34i4pk2xotb65wkuwcec5qgu7hvjhm",
#   "prov:label": "rdf:10_5",
#   "_cell": 237,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigaixhzxka7lqngxy5dbdk6kzfwit3ojq2svrfymdyxrx4jdqkfmu"
#   },
#   "_stmt_key": "10_5",
#   "_chunk_num": 10,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [10.6]: [Marcel Grossmann](/wiki/Marcel_Grossmann) helped [Albert Einstein](/wiki/Albert_Einstein) get by at the [Swiss Federal Polytechnic School](/wiki/ETH_Zurich) despite his loose study habits.
# <https://en.wikipedia.org/wiki/Marcel_Grossmann> schema:colleague <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibchvfdkcp7oal6spq5euj554thkmvghzhqaua6jqz6umtcmt2rri",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibchvfdkcp7oal6spq5euj554thkmvghzhqaua6jqz6umtcmt2rri",
#   "prov:label": "rdf:10_6",
#   "_cell": 239,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiawhlegdbcigtumaj5inpuhfrd4tmaq24wzgxbz4fgdhrmwoc566u"
#   },
#   "_stmt_key": "10_6",
#   "_chunk_num": 10,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [10.7]: [Marcel Grossmann](/wiki/Marcel_Grossmann) later helped [Albert Einstein](/wiki/Albert_Einstein) mathematically underpin his revolutionary insights into physics.
# <https://en.wikipedia.org/wiki/Marcel_Grossmann> schema:colleague <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihzg7yxobdw4t6fc7rrmpgtkgmmqmf3nkzt5t6hzoffmqp7f2y4oa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihzg7yxobdw4t6fc7rrmpgtkgmmqmf3nkzt5t6hzoffmqp7f2y4oa",
#   "prov:label": "rdf:10_7",
#   "_cell": 241,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreie2wyw5edqkcfujiuwd2dqsq4elbckz4zed44zfj5aej7minrofxe"
#   },
#   "_stmt_key": "10_7",
#   "_chunk_num": 10,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [10.8]: Marie Winteler, a year older than [Albert Einstein](/wiki/Albert_Einstein), took up a teaching post in [Olsberg](/wiki/Olsberg%2C_Aargau), Switzerland.
# <https://en.wikipedia.org/wiki/Marie_Winteler> schema:alumniOf <https://en.wikipedia.org/wiki/University_of_Bern> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibudd24mkr4can2f6jjgrlvg6e4fhtqaiqmv7spfb3zpia466hj5e",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibudd24mkr4can2f6jjgrlvg6e4fhtqaiqmv7spfb3zpia466hj5e",
#   "prov:label": "rdf:10_8",
#   "_cell": 243,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicspjlwtm3vhunbdz4ldd4y5akgmkx4hzdlxgmkzqkboot6iarucm"
#   },
#   "_stmt_key": "10_8",
#   "_chunk_num": 10,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [10.9]: The five other polytechnic school freshmen following the same course as [Albert Einstein](/wiki/Albert_Einstein) included just one woman.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreig37gxla5qqrs6jxy42cqhqzhyp2gd7wh6xwamp3fj3becwfelu24",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreig37gxla5qqrs6jxy42cqhqzhyp2gd7wh6xwamp3fj3becwfelu24",
#   "prov:label": "rdf:10_9",
#   "_cell": 245,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiamb2b6pbbdgd4hthp5ak7dutlrfujhzv6uyd4ndoqrqozrprogla"
#   },
#   "_stmt_key": "10_9",
#   "_chunk_num": 10,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [10.10]: The one woman among the five polytechnic school freshmen was a twenty-year-old [Serbian](/wiki/Serbs), [Mileva Marić](/wiki/Mileva_Mari%C4%87).
# <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> schema:nationality <https://en.wikipedia.org/wiki/Serbia> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifgdhwcfhilxv75cvubyuynjto7qxhu6kfub52u63q7msuq6lgjku",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifgdhwcfhilxv75cvubyuynjto7qxhu6kfub52u63q7msuq6lgjku",
#   "prov:label": "rdf:10_10",
#   "_cell": 247,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih74qyf3do6soi6egohgwcsdlbshl4iqu6s4eaiu5kroycudvlxqm"
#   },
#   "_stmt_key": "10_10",
#   "_chunk_num": 10,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [10.11]: [Albert Einstein](/wiki/Albert_Einstein) and [Mileva Marić](/wiki/Mileva_Mari%C4%87) spent many hours discussing their shared interests and learning about topics in physics that the polytechnic school's lectures did not cover.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:colleague <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiedpwzpqbgrh5rzvqxoquhhg2vtg5xp62zyuifd6q2yig3cvzujbi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiedpwzpqbgrh5rzvqxoquhhg2vtg5xp62zyuifd6q2yig3cvzujbi",
#   "prov:label": "rdf:10_11",
#   "_cell": 249,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaag4lzrzy2x656edciyvzqbow3hcjqu45cnlfltwnqu4joccxwx4"
#   },
#   "_stmt_key": "10_11",
#   "_chunk_num": 10,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [10.12]: In his letters to [Mileva Marić](/wiki/Mileva_Mari%C4%87), [Albert Einstein](/wiki/Albert_Einstein) confessed that exploring science with her by his side was much more enjoyable than reading a textbook in solitude.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:colleague <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibiy3okheht4e6tlxbrxxdnpknercxwtebj2puhutxsnhnmekbzea",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibiy3okheht4e6tlxbrxxdnpknercxwtebj2puhutxsnhnmekbzea",
#   "prov:label": "rdf:10_12",
#   "_cell": 251,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiejue5oermegskcvxylyjkpq4g4laa4zkpslry6sp67w3nwycka4e"
#   },
#   "_stmt_key": "10_12",
#   "_chunk_num": 10,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [10.13]: [Albert Einstein](/wiki/Albert_Einstein) and [Mileva Marić](/wiki/Mileva_Mari%C4%87) became not only friends but also lovers.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:colleague <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidu7viiblgrdeojosdd4w6a6izbsdhtlgbqp2mi7v4efsvp5muui4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidu7viiblgrdeojosdd4w6a6izbsdhtlgbqp2mi7v4efsvp5muui4",
#   "prov:label": "rdf:10_13",
#   "_cell": 253,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifzwj2dao5yc6umyqg3qfm2e6r3xppngywf3g4brk32ptwjplqnaq"
#   },
#   "_stmt_key": "10_13",
#   "_chunk_num": 10,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [10.14]: Historians of physics are divided on the question of the extent to which [Mileva Marić](/wiki/Mileva_Mari%C4%87) contributed to the insights of [Albert Einstein](/wiki/Albert_Einstein)'s *annus mirabilis* publications.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:colleague <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibojboafucmat2rubjv62cvhwqfs56rgpmw2kxd4lzeoqnw4bsorm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibojboafucmat2rubjv62cvhwqfs56rgpmw2kxd4lzeoqnw4bsorm",
#   "prov:label": "rdf:10_14",
#   "_cell": 255,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiek7gtyz3xrgnee3tpzmpudmb7q6guzyoeeu2esauo2qemuhtbmeu"
#   },
#   "_stmt_key": "10_14",
#   "_chunk_num": 10,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [10.15]: There is at least some evidence that [Albert Einstein](/wiki/Albert_Einstein) was influenced by [Mileva Marić](/wiki/Mileva_Mari%C4%87)'s scientific ideas.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:colleague <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihjppvuohotbfrlpbvbic4oramb3uohrkyrfzdatoqne33o5cptdu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihjppvuohotbfrlpbvbic4oramb3uohrkyrfzdatoqne33o5cptdu",
#   "prov:label": "rdf:10_15",
#   "_cell": 257,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifecf53xoa6ctyvptvbedfgjupbmohkqbmfrysn5ud67fesnefqui"
#   },
#   "_stmt_key": "10_15",
#   "_chunk_num": 10,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [10.16]: There are scholars who doubt whether [Mileva Marić](/wiki/Mileva_Mari%C4%87)'s impact on [Albert Einstein](/wiki/Albert_Einstein)'s thought was of any great significance at all.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:colleague <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibnrwb3fawg54zqzvofunh7nki5ka5o7f4wboaxiq6hbgcuxfvneu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibnrwb3fawg54zqzvofunh7nki5ka5o7f4wboaxiq6hbgcuxfvneu",
#   "prov:label": "rdf:10_16",
#   "_cell": 259,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiakufiejvlwoht744tb4d26ph6t2dx3vielhptehywa5p2eu2ihba"
#   },
#   "_stmt_key": "10_16",
#   "_chunk_num": 10,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [11.1]: [Albert Einstein](/wiki/Albert_Einstein) had a daughter named [Lieserl](/wiki/Lieserl_Einstein) with [Mileva Marić](/wiki/Mileva_Mari%C4%87).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:children <https://en.wikipedia.org/wiki/Lieserl_Einstein> .
# <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> schema:children <https://en.wikipedia.org/wiki/Lieserl_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Albert Einstein had a daughter named Lieserl with Mileva Marić." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieaqexasgg2p5yqg2vghjpy7m5v4p3t7rylv3y2x6v75zbqrw63za",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieaqexasgg2p5yqg2vghjpy7m5v4p3t7rylv3y2x6v75zbqrw63za",
#   "prov:label": "rdf:11_1",
#   "_cell": 261,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidjhv2czpglc6r7krox44dnd5cmafa2sequjijch6n3tn447kdyii"
#   },
#   "_stmt_key": "11_1",
#   "_chunk_num": 11,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [11.2]: [Mileva Marić](/wiki/Mileva_Mari%C4%87) gave birth to [Lieserl](/wiki/Lieserl_Einstein) in [Novi Sad](/wiki/Novi_Sad) in early 1902.
# <https://en.wikipedia.org/wiki/Lieserl_Einstein> schema:birthDate "1902-01-01"^^xsd:date .
# <https://en.wikipedia.org/wiki/Lieserl_Einstein> schema:birthPlace <https://en.wikipedia.org/wiki/Novi_Sad> .
# <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> rdfs:comment "Mileva Marić gave birth to Lieserl in Novi Sad in early 1902." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigha5t72qmsaj74p5zsxvpqjb3ypgovc6fplvzal45iq7rqakc76a",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigha5t72qmsaj74p5zsxvpqjb3ypgovc6fplvzal45iq7rqakc76a",
#   "prov:label": "rdf:11_2",
#   "_cell": 263,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicxg7wqfg3xhrggczhoweu6urujobccxqgzhokspfjuyi77ocak3y"
#   },
#   "_stmt_key": "11_2",
#   "_chunk_num": 11,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [11.3]: [Lieserl](/wiki/Lieserl_Einstein) was not with [Mileva Marić](/wiki/Mileva_Mari%C4%87) when she returned to Switzerland.
# <https://en.wikipedia.org/wiki/Lieserl_Einstein> rdfs:comment "Lieserl was not with Mileva Marić when she returned to Switzerland." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiglf6kiywdbip4t3cqvv5qblnsmnzaxyxykm4rkv5e34vwjl62vwq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiglf6kiywdbip4t3cqvv5qblnsmnzaxyxykm4rkv5e34vwjl62vwq",
#   "prov:label": "rdf:11_3",
#   "_cell": 265,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaibo5hgoipp6wx5ztldsehyiipjj7mij7emcmjjpbkn5dtc7smh4"
#   },
#   "_stmt_key": "11_3",
#   "_chunk_num": 11,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [11.4]: The fate of [Lieserl](/wiki/Lieserl_Einstein) is uncertain.
# <https://en.wikipedia.org/wiki/Lieserl_Einstein> rdfs:comment "The fate of Lieserl is uncertain." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihbfp7h75whn6yfcwcd54wojrg477rsywv2wgwqb3jgnn3ujdqvdm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihbfp7h75whn6yfcwcd54wojrg477rsywv2wgwqb3jgnn3ujdqvdm",
#   "prov:label": "rdf:11_4",
#   "_cell": 267,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibhc7aame5b6mbuvwugbwwdudiqr3yrqvwxjykuvtjyx6infy7lgi"
#   },
#   "_stmt_key": "11_4",
#   "_chunk_num": 11,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [11.5]: A letter written by [Albert Einstein](/wiki/Albert_Einstein) in September 1903 suggests that [Lieserl](/wiki/Lieserl_Einstein) may have died of [scarlet fever](/wiki/scarlet_fever) or was given up for adoption.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "A letter written by Albert Einstein in September 1903 suggests that Lieserl may have died of scarlet fever or was given up for adoption." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicsh6vemr2fu3xqfpt6qv6m6yjlioxl46wbv5vhtfgmby66gbpa7a",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicsh6vemr2fu3xqfpt6qv6m6yjlioxl46wbv5vhtfgmby66gbpa7a",
#   "prov:label": "rdf:11_5",
#   "_cell": 269,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifhtiksgmeuaa4w546icosoisqki73gnf42fxstjzfafvdgrmcbiu"
#   },
#   "_stmt_key": "11_5",
#   "_chunk_num": 11,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [11.6]: In April 1914, [Mileva Marić](/wiki/Mileva_Mari%C4%87) returned to [Zurich](/wiki/Zurich), taking [Hans Albert](/wiki/Hans_Albert_Einstein) and [Eduard](/wiki/Einstein_family) with her after learning of [Albert Einstein](/wiki/Albert_Einstein)'s infidelity.
# <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> rdfs:comment "In April 1914, Mileva Marić returned to Zurich, taking Hans Albert and Eduard with her after learning of Albert Einstein's infidelity." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibbiwd4bmvxwdhkyhbc7m2dhind763gn66hh63drebhkbfjwclehi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibbiwd4bmvxwdhkyhbc7m2dhind763gn66hh63drebhkbfjwclehi",
#   "prov:label": "rdf:11_6",
#   "_cell": 271,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigs5dspvauwqevl5avsueannkfpb5myg4nzmzdvpsagupzmfjoxg4"
#   },
#   "_stmt_key": "11_6",
#   "_chunk_num": 11,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [11.7]: [Albert Einstein](/wiki/Albert_Einstein) married [Elsa Löwenthal](/wiki/Elsa_L%C3%B6wenthal) in 1919.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:spouse <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> .
# <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> schema:spouse <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifgbvczlghd4nsatqahpfs7cgbpaboeuxqhf4sojmdn557364qjwq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifgbvczlghd4nsatqahpfs7cgbpaboeuxqhf4sojmdn557364qjwq",
#   "prov:label": "rdf:11_7",
#   "_cell": 273,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicz6gjikby7sguqargqsnnjueolhbngokbwgcbwatlh262yatxm5a"
#   },
#   "_stmt_key": "11_7",
#   "_chunk_num": 11,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [11.8]: In 1923, [Albert Einstein](/wiki/Albert_Einstein) began a relationship with Betty Neumann.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "In 1923, Albert Einstein began a relationship with Betty Neumann." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibv2zztpwccfhf4zdcrh3xqbqsf4odjo4xnzzxrsw2hrumovue2dq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibv2zztpwccfhf4zdcrh3xqbqsf4odjo4xnzzxrsw2hrumovue2dq",
#   "prov:label": "rdf:11_8",
#   "_cell": 275,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigv2324rp5od6g6supuqbadxhchuy7ga7barvrslp72ssi7mphfny"
#   },
#   "_stmt_key": "11_8",
#   "_chunk_num": 11,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [11.9]: Betty Neumann was the niece of [Hans Mühsam](/wiki/Hans_M%C3%BChsam), a close friend of [Albert Einstein](/wiki/Albert_Einstein).
# <https://en.wikipedia.org/wiki/Betty_Neumann> rdfs:comment "Betty Neumann was the niece of Hans Mühsam, a close friend of Albert Einstein." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifx5uabw2whzzsmrb5p56moxg6aps3hkmfqetskgpfmio7zqkogi4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifx5uabw2whzzsmrb5p56moxg6aps3hkmfqetskgpfmio7zqkogi4",
#   "prov:label": "rdf:11_9",
#   "_cell": 277,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiekqilbreyh22m6nbznbjznqugjssx7w7t64ivwsylvtr6ps5m7ky"
#   },
#   "_stmt_key": "11_9",
#   "_chunk_num": 11,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [11.10]: [Elsa Löwenthal](/wiki/Elsa_L%C3%B6wenthal) remained loyal to [Albert Einstein](/wiki/Albert_Einstein).
# <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> rdfs:comment "Elsa Löwenthal remained loyal to Albert Einstein." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidmbz6xn7jkf4vlkvvyonvgbocjzoiuv3sl4qsqsgnhs5dpflnnpq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidmbz6xn7jkf4vlkvvyonvgbocjzoiuv3sl4qsqsgnhs5dpflnnpq",
#   "prov:label": "rdf:11_10",
#   "_cell": 279,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreictvwrou3egxygnqufzhcx2lhw6oxjhqlzrdndiru2trq5msa34sm"
#   },
#   "_stmt_key": "11_10",
#   "_chunk_num": 11,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [11.11]: In 1933, [Elsa Löwenthal](/wiki/Elsa_L%C3%B6wenthal) accompanied [Albert Einstein](/wiki/Albert_Einstein) when he emigrated to the [United States](/wiki/Citizenship_of_the_United_States).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality <https://en.wikipedia.org/wiki/Citizenship_of_the_United_States> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihgv5do2webhaw2xmenfcdb337liov6r6ou2b3spwz3hnr6wkii3e",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihgv5do2webhaw2xmenfcdb337liov6r6ou2b3spwz3hnr6wkii3e",
#   "prov:label": "rdf:11_11",
#   "_cell": 281,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibneiinajz6zjctrtjzjccdj6xqv4l7ysrly2ltnyl2ufs4cuihgm"
#   },
#   "_stmt_key": "11_11",
#   "_chunk_num": 11,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [11.12]: In 1935, [Elsa Löwenthal](/wiki/Elsa_L%C3%B6wenthal) was diagnosed with heart and kidney problems.
# <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> rdfs:comment "In 1935, Elsa Löwenthal was diagnosed with heart and kidney problems." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidwiccrfyufaukf23xnmbppmlipzsag4qhmpvl7sbdozykkpooiza",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidwiccrfyufaukf23xnmbppmlipzsag4qhmpvl7sbdozykkpooiza",
#   "prov:label": "rdf:11_12",
#   "_cell": 283,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreietijlszimqpo5ry234ddupe6v3vcabsokx2s5gxjn6j26eryz7qu"
#   },
#   "_stmt_key": "11_12",
#   "_chunk_num": 11,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [11.13]: [Elsa Löwenthal](/wiki/Elsa_L%C3%B6wenthal) died in December 1936.
# <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> schema:deathDate "1936-12-31"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigkfn2fh2cs36n5e6ot56py52j743amnx4zlu42yumyyiacnbmmdi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigkfn2fh2cs36n5e6ot56py52j743amnx4zlu42yumyyiacnbmmdi",
#   "prov:label": "rdf:11_13",
#   "_cell": 285,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihtwde4kyktim7impxtuaamnhl7pyp527jtm7wpou5jenvlgowimi"
#   },
#   "_stmt_key": "11_13",
#   "_chunk_num": 11,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [11.14]: As part of the divorce settlement, [Albert Einstein](/wiki/Albert_Einstein) agreed to give any Nobel Prize money he received to [Mileva Marić](/wiki/Mileva_Mari%C4%87).
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "As part of the divorce settlement, Albert Einstein agreed to give any Nobel Prize money he received to Mileva Marić." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreid3ze5qycur7jmnwn5aqim3i5x67a46o6vaxjaekd2zahnl2zubne",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreid3ze5qycur7jmnwn5aqim3i5x67a46o6vaxjaekd2zahnl2zubne",
#   "prov:label": "rdf:11_14",
#   "_cell": 287,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid3tdrnp4uf6hybz7oywipo23buyze3tlwwvsmoqkatzaxoe553zi"
#   },
#   "_stmt_key": "11_14",
#   "_chunk_num": 11,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [11.15]: [Albert Einstein](/wiki/Albert_Einstein) won the [Nobel Prize in Physics](/wiki/Nobel_Prize_in_Physics) two years after the divorce settlement.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics> .
# <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics> schema:recipient <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics> schema:startDate "1923"^^xsd:gYear .
# <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics> schema:endDate "1923"^^xsd:gYear .
# <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics> schema:award <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihilk6zcgraqobwgagktn5eshgqihtjwryv4hzbdv6k7xmlkl5zki",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihilk6zcgraqobwgagktn5eshgqihtjwryv4hzbdv6k7xmlkl5zki",
#   "prov:label": "rdf:11_15",
#   "_cell": 289,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifpdj56anxp7vvvs3fcndua4jfj5aquj23gfhf3fadeej6zzdqiny"
#   },
#   "_stmt_key": "11_15",
#   "_chunk_num": 11,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [12.1]: A volume of [Albert Einstein](/wiki/Albert_Einstein)'s letters released by the [Hebrew University of Jerusalem](/wiki/Hebrew_University_of_Jerusalem) in 2006 added some other women with whom he was romantically involved.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "A volume of Albert Einstein's letters released by the Hebrew University of Jerusalem in 2006 added some other women with whom he was romantically involved." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiem347elwxmfpqhb2eazaioospms2q2ipd4247wrx42owufzlhr6i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiem347elwxmfpqhb2eazaioospms2q2ipd4247wrx42owufzlhr6i",
#   "prov:label": "rdf:12_1",
#   "_cell": 291,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibivckayfqzhalmb4eclaqtqlxvkyt3ynhuqladitapkoxxh7ww7a"
#   },
#   "_stmt_key": "12_1",
#   "_chunk_num": 12,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [12.2]: Margarete Lebach was a married Austrian woman with whom [Albert Einstein](/wiki/Albert_Einstein) was romantically involved.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Margarete Lebach was a married Austrian woman with whom Albert Einstein was romantically involved." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigmfxt4tyl6gakeilzuhaex5vznrhdghwbhienzritu2msn6ebogy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigmfxt4tyl6gakeilzuhaex5vznrhdghwbhienzritu2msn6ebogy",
#   "prov:label": "rdf:12_2",
#   "_cell": 293,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid4gz2fmr5duhjr672o5owm6h2xgbvzerchvpq6fojd6bu7jedrry"
#   },
#   "_stmt_key": "12_2",
#   "_chunk_num": 12,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [12.3]: Estella Katzenellenbogen was the rich owner of a florist business with whom [Albert Einstein](/wiki/Albert_Einstein) was romantically involved.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Estella Katzenellenbogen was the rich owner of a florist business with whom Albert Einstein was romantically involved." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihdo5daj3hbjleyzop5ebky65456j75mlnhdqq3qodfwfuizaezzi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihdo5daj3hbjleyzop5ebky65456j75mlnhdqq3qodfwfuizaezzi",
#   "prov:label": "rdf:12_3",
#   "_cell": 295,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicb3cqan3skzgnbj5jtvxbccmihyxr4bcqgxvgn2oaaywwb7uoqzy"
#   },
#   "_stmt_key": "12_3",
#   "_chunk_num": 12,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [12.4]: Toni Mendel was a wealthy Jewish widow with whom [Albert Einstein](/wiki/Albert_Einstein) was romantically involved.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Toni Mendel was a wealthy Jewish widow with whom Albert Einstein was romantically involved." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidmofmp6gwfvdpawegzspbav6ax2xgrumkok66tn2wjnsnsseuu2a",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidmofmp6gwfvdpawegzspbav6ax2xgrumkok66tn2wjnsnsseuu2a",
#   "prov:label": "rdf:12_4",
#   "_cell": 297,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieth72v2ldn6ysq2rfhpdh6xrexelkg5aqllbi4obsb3shcmgbesu"
#   },
#   "_stmt_key": "12_4",
#   "_chunk_num": 12,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [12.5]: Ethel Michanowski was a Berlin socialite with whom [Albert Einstein](/wiki/Albert_Einstein) spent time and from whom he accepted gifts while married to [Elsa Löwenthal](/wiki/Elsa_L%C3%B6wenthal).
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Ethel Michanowski was a Berlin socialite with whom Albert Einstein spent time and from whom he accepted gifts while married to Elsa Löwenthal." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihwj74muz2sbxukfpemlco7nmm7uqfyp3clod7z37tact3kbyyqwe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihwj74muz2sbxukfpemlco7nmm7uqfyp3clod7z37tact3kbyyqwe",
#   "prov:label": "rdf:12_5",
#   "_cell": 299,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiezhhdblwxy5rnpeo2o4qgv5avdp66wc7q7hs5gyo57z5da3e2nd4"
#   },
#   "_stmt_key": "12_5",
#   "_chunk_num": 12,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [12.6]: After being widowed, [Albert Einstein](/wiki/Albert_Einstein) was briefly in a relationship with Margarita Konenkova.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "After being widowed, Albert Einstein was briefly in a relationship with Margarita Konenkova." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicvq6dbybemkomkbfifrbap5q3522vnmuyr5rsiwnkrji4dld2z2m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicvq6dbybemkomkbfifrbap5q3522vnmuyr5rsiwnkrji4dld2z2m",
#   "prov:label": "rdf:12_6",
#   "_cell": 301,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid6c42nhoeqgziebby4mqbllybucawlb2vmyec6ele6xzxhrakyji"
#   },
#   "_stmt_key": "12_6",
#   "_chunk_num": 12,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [12.7]: Margarita Konenkova was thought by some to be a Russian spy.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Margarita Konenkova was thought by some to be a Russian spy." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihcti4sqa6apyezc6e6it4orbx5rok6zp3tzgtdud3jd6vok633ny",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihcti4sqa6apyezc6e6it4orbx5rok6zp3tzgtdud3jd6vok633ny",
#   "prov:label": "rdf:12_7",
#   "_cell": 303,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifpmnvumoepfhratmebhyrw3cddqo7k4umxl4dbih2eqaek77pq6u"
#   },
#   "_stmt_key": "12_7",
#   "_chunk_num": 12,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [12.8]: Sergei Konenkov was the husband of Margarita Konenkova and a Russian sculptor.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Sergei Konenkov was the husband of Margarita Konenkova and a Russian sculptor." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifuuuhk7q3gsoitdlkwptmrxlrq2623fol5avtivoyg7twcst6fga",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifuuuhk7q3gsoitdlkwptmrxlrq2623fol5avtivoyg7twcst6fga",
#   "prov:label": "rdf:12_8",
#   "_cell": 305,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreif6byt5uunaxqjmazdkboxj6gigozq2ga2tojeun4poa7vbx4paqy"
#   },
#   "_stmt_key": "12_8",
#   "_chunk_num": 12,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [12.9]: Sergei Konenkov created the bronze bust of [Albert Einstein](/wiki/Albert_Einstein) at the [Institute for Advanced Study](/wiki/Institute_for_Advanced_Study) at [Princeton, New Jersey](/wiki/Princeton%2C_New_Jersey).
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Sergei Konenkov created the bronze bust of Albert Einstein at the Institute for Advanced Study at Princeton, New Jersey." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigfn6uz3hcxdazbukrijugqutmvbfwn6krdftj7pc5dw344bzkgj4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigfn6uz3hcxdazbukrijugqutmvbfwn6krdftj7pc5dw344bzkgj4",
#   "prov:label": "rdf:12_9",
#   "_cell": 307,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreic2dyrcc2ldmjj2dcs2xjavjiszkubxyy437nqg63xwofm2thnuyi"
#   },
#   "_stmt_key": "12_9",
#   "_chunk_num": 12,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [12.10]: Following an episode of acute mental illness at about the age of twenty, [Albert Einstein](/wiki/Albert_Einstein)'s son [Eduard "Tete"](/wiki/Einstein_family) was diagnosed with [schizophrenia](/wiki/schizophrenia).
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Following an episode of acute mental illness at about the age of twenty, Albert Einstein's son Eduard "Tete" was diagnosed with schizophrenia." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidyhdui7hy755j25ioa7was5rjorj6qism4x4iwcpo3p36amvxxii",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidyhdui7hy755j25ioa7was5rjorj6qism4x4iwcpo3p36amvxxii",
#   "prov:label": "rdf:12_10",
#   "_cell": 309,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidouqc3qu5kjpwzyjukysb5rrvgdnygugibsdkfmdb4sosdk6phoe"
#   },
#   "_stmt_key": "12_10",
#   "_chunk_num": 12,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [12.11]: [Eduard "Tete"](/wiki/Einstein_family) spent the remainder of his life either in the care of his mother [Albert Einstein](/wiki/Albert_Einstein) or in temporary confinement in an asylum.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Eduard "Tete" spent the remainder of his life either in the care of his mother Albert Einstein or in temporary confinement in an asylum." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigh6damxe5cz2ct7o6m6sge53yljoz67juak52hbcahzebz6tbkvm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigh6damxe5cz2ct7o6m6sge53yljoz67juak52hbcahzebz6tbkvm",
#   "prov:label": "rdf:12_11",
#   "_cell": 311,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidxnjxbnygjv75gcnczp4rbmaqiaefb367hqivliymzxzky7kzbp4"
#   },
#   "_stmt_key": "12_11",
#   "_chunk_num": 12,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [12.12]: After the death of [Albert Einstein](/wiki/Albert_Einstein), [Eduard "Tete"](/wiki/Einstein_family) was committed permanently to [Burghölzli](/wiki/Burgh%C3%B6lzli), the Psychiatric University Hospital in [Zurich](/wiki/Zurich).
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "After the death of Albert Einstein, Eduard "Tete" was committed permanently to Burghölzli, the Psychiatric University Hospital in Zurich." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreics64cgtodvvixwandfrlvxkpgqigpx2u4lhvm3oehc34gi2dc5sq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreics64cgtodvvixwandfrlvxkpgqigpx2u4lhvm3oehc34gi2dc5sq",
#   "prov:label": "rdf:12_12",
#   "_cell": 313,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreie3a5nzdmykbenke4svxdois73a5qvpiebepxxuqxgr4qf36pb5qm"
#   },
#   "_stmt_key": "12_12",
#   "_chunk_num": 12,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [13.1]: [Albert Einstein](/wiki/Albert_Einstein) graduated from the [Swiss Federal Polytechnic School](/wiki/ETH_Zurich) in 1900.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:alumniOf _:s1_role1 .
# _:s1_role1 rdf:type schema:OrganizationRole .
# _:s1_role1 schema:alumniOf <https://en.wikipedia.org/wiki/ETH_Zurich> .
# _:s1_role1 schema:startDate "1900"^^xsd:gYear .
# _:s1_role1 schema:endDate "1900"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreichtys6x77mzsrlmgx5rserzzoy25yb3ufukfklceym2tm5oqvbjq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreichtys6x77mzsrlmgx5rserzzoy25yb3ufukfklceym2tm5oqvbjq",
#   "prov:label": "rdf:13_1",
#   "_cell": 315,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidrmfhihk6kmemrfzlp2v2sxxeyn6udzmtvckx7pwdavamae3qrpm"
#   },
#   "_stmt_key": "13_1",
#   "_chunk_num": 13,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [13.2]: [Albert Einstein](/wiki/Albert_Einstein) was duly certified as competent to teach mathematics and physics.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasCredential <https://en.wikipedia.org/wiki/Physics> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasCredential _:s2_role1 .
# _:s2_role1 rdf:type schema:Role .
# _:s2_role1 schema:hasCredential <https://en.wikipedia.org/wiki/Physics> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifjmv2vvqgmvvwh3bqzdoqo3eb4tvyzyww2732kzatxtgcoaupeeu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifjmv2vvqgmvvwh3bqzdoqo3eb4tvyzyww2732kzatxtgcoaupeeu",
#   "prov:label": "rdf:13_2",
#   "_cell": 317,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibmvbwyilbcibzybmgvl3662kosov4zrunwxbnsiykl2koai6xcwy"
#   },
#   "_stmt_key": "13_2",
#   "_chunk_num": 13,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [13.3]: [Albert Einstein](/wiki/Albert_Einstein) acquired Swiss citizenship in February 1901.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality <https://en.wikipedia.org/wiki/Switzerland> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality _:s3_role1 .
# _:s3_role1 rdf:type schema:Role .
# _:s3_role1 schema:nationality <https://en.wikipedia.org/wiki/Switzerland> .
# _:s3_role1 schema:startDate "1901-02"^^xsd:gYearMonth .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicpqy3vkrskopvxypwiv6plsn5c5o2tomodm6rnhfxfolfogcynq4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicpqy3vkrskopvxypwiv6plsn5c5o2tomodm6rnhfxfolfogcynq4",
#   "prov:label": "rdf:13_3",
#   "_cell": 319,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiejflpowvqqq5miurt6r45art5lxkpomm4ugviowia3pwiec6vtxi"
#   },
#   "_stmt_key": "13_3",
#   "_chunk_num": 13,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [13.4]: The Swiss authorities deemed [Albert Einstein](/wiki/Albert_Einstein) medically unfit for military service.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "The Swiss authorities deemed Albert Einstein medically unfit for military service." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihrog6r7zcvgag5ins2gjwflsk7eerixwme2updto2p7de7whvs7y",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihrog6r7zcvgag5ins2gjwflsk7eerixwme2updto2p7de7whvs7y",
#   "prov:label": "rdf:13_4",
#   "_cell": 321,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigyn5wh4wz23xgpnsh45uufolyh6xo2gg7bs7fwzud6lwy37aolfy"
#   },
#   "_stmt_key": "13_4",
#   "_chunk_num": 13,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [13.5]: [Albert Einstein](/wiki/Albert_Einstein) did not receive a teaching position in Swiss schools despite applying for almost two years.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Albert Einstein did not receive a teaching position in Swiss schools despite applying for almost two years." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiflwekpv4a2q5a55zcotkwkkgsckdgpqnki243wwq2sj3npgvxesm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiflwekpv4a2q5a55zcotkwkkgsckdgpqnki243wwq2sj3npgvxesm",
#   "prov:label": "rdf:13_5",
#   "_cell": 323,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreief23zcmoyf6hnh5gi7wkgdonidsnsmn3gmnz6uxupooocuwaye7y"
#   },
#   "_stmt_key": "13_5",
#   "_chunk_num": 13,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [13.6]: [Albert Einstein](/wiki/Albert_Einstein) secured a post at the [Swiss Patent Office](/wiki/Swiss_Patent_Office) in [Bern](/wiki/Bern) with the help of [Marcel Grossmann](/wiki/Marcel_Grossmann)'s father.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor <https://en.wikipedia.org/wiki/Swiss_Patent_Office> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor _:s6_role1 .
# _:s6_role1 rdf:type schema:OrganizationRole .
# _:s6_role1 schema:worksFor <https://en.wikipedia.org/wiki/Swiss_Patent_Office> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihh37bt7lwytzgdymfyupoy6b5apb22w7pmesuaddt5s3hf7maela",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihh37bt7lwytzgdymfyupoy6b5apb22w7pmesuaddt5s3hf7maela",
#   "prov:label": "rdf:13_6",
#   "_cell": 325,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiepkwgjr7ndrmcv7f5mvfrvt5wuhmdsuqioy5cyoyu3whip5xi3ea"
#   },
#   "_stmt_key": "13_6",
#   "_chunk_num": 13,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [13.7]: [Albert Einstein](/wiki/Albert_Einstein) worked as an [assistant examiner – level III](/wiki/Patent_examiner) at the [Swiss Patent Office](/wiki/Swiss_Patent_Office).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:jobTitle "assistant examiner – level III" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreid4y7msqk6vnhl77j76liglfap3v5i6zwr55kskohrjrcr6viyr5u",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreid4y7msqk6vnhl77j76liglfap3v5i6zwr55kskohrjrcr6viyr5u",
#   "prov:label": "rdf:13_7",
#   "_cell": 327,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia7v4gwi2l3xkp45lhrlfudssqmluj4klnjm4bomeb22ixu2xa63y"
#   },
#   "_stmt_key": "13_7",
#   "_chunk_num": 13,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [13.8]: Patent applications evaluated by [Albert Einstein](/wiki/Albert_Einstein) included ideas for a gravel sorter and an electric typewriter.
# rdfs:comment rdfs:comment "Patent applications evaluated by Albert Einstein included ideas for a gravel sorter and an electric typewriter." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigwzq3o5s4paccxubjubrxcqgsrnk4lu4ykuyycadrodah5224jyi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigwzq3o5s4paccxubjubrxcqgsrnk4lu4ykuyycadrodah5224jyi",
#   "prov:label": "rdf:13_8",
#   "_cell": 329,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia3szwbnyxbwyp4jabm42wticekuowiuxyyo742iqzytwzvloadyu"
#   },
#   "_stmt_key": "13_8",
#   "_chunk_num": 13,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [13.9]: [Albert Einstein](/wiki/Albert_Einstein)'s employers were pleased with his work at the [Swiss Patent Office](/wiki/Swiss_Patent_Office).
# rdfs:comment rdfs:comment "Albert Einstein's employers were pleased with his work at the Swiss Patent Office." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidf5cxjhbqo74ke6x4lr2jmajilvdfhjmjk6vcnhzofc7ibaqftbe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidf5cxjhbqo74ke6x4lr2jmajilvdfhjmjk6vcnhzofc7ibaqftbe",
#   "prov:label": "rdf:13_9",
#   "_cell": 331,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigvicbzxbvrxcmgtbw2hp4xionkx66je2xkd3nrk3yg3fhamkeiye"
#   },
#   "_stmt_key": "13_9",
#   "_chunk_num": 13,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [13.10]: [Albert Einstein](/wiki/Albert_Einstein)'s position at the [Swiss Patent Office](/wiki/Swiss_Patent_Office) became permanent in 1903.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor _:s10_role1 .
# _:s10_role1 rdf:type schema:OrganizationRole .
# _:s10_role1 schema:worksFor <https://en.wikipedia.org/wiki/Swiss_Patent_Office> .
# _:s10_role1 schema:startDate "1903"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiafil36dz7wkol6tixqlwvfoqxpbzzhyefwq26ybuuw7tpkxc2lc4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiafil36dz7wkol6tixqlwvfoqxpbzzhyefwq26ybuuw7tpkxc2lc4",
#   "prov:label": "rdf:13_10",
#   "_cell": 333,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigzowc35tmk3mwiyo6fn66e44dm35krwdakgjuigolmt42msa43se"
#   },
#   "_stmt_key": "13_10",
#   "_chunk_num": 13,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [13.11]: [Albert Einstein](/wiki/Albert_Einstein) was not promoted until he had "fully mastered machine technology".
# rdfs:comment rdfs:comment "Albert Einstein was not promoted until he had 'fully mastered machine technology'." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihaokwuiiqwumgpmosd6ikczfajsu2ixz4eyvmkbyg3bph72rdtoa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihaokwuiiqwumgpmosd6ikczfajsu2ixz4eyvmkbyg3bph72rdtoa",
#   "prov:label": "rdf:13_11",
#   "_cell": 335,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreic7vysao7jabyn44gae7arqia3yomgmthqqapopyhrq5dpsfmts7a"
#   },
#   "_stmt_key": "13_11",
#   "_chunk_num": 13,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [13.12]: It is conceivable that [Albert Einstein](/wiki/Albert_Einstein)'s labors at the patent office had a bearing on his development of the special theory of relativity.
# rdfs:comment rdfs:comment "It is conceivable that Albert Einstein's labors at the patent office had a bearing on his development of the special theory of relativity." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreid5zyxljcoxlfg3jic7k47f3no7zmksb7esxo73xbb2mzrxr33sxe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreid5zyxljcoxlfg3jic7k47f3no7zmksb7esxo73xbb2mzrxr33sxe",
#   "prov:label": "rdf:13_12",
#   "_cell": 337,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib4g7c3o34jek2qfwkafgded2epgh3i27v32xfoqmpsj2fv56klqm"
#   },
#   "_stmt_key": "13_12",
#   "_chunk_num": 13,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [13.13]: [Albert Einstein](/wiki/Albert_Einstein) arrived at revolutionary ideas about space, time, and light through thought experiments.
# rdfs:comment rdfs:comment "Albert Einstein arrived at revolutionary ideas about space, time, and light through thought experiments." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifmtvfsko7ll3ytzazo2g3yxvy5yyy67uap25hxtmdjl7mo6edsb4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifmtvfsko7ll3ytzazo2g3yxvy5yyy67uap25hxtmdjl7mo6edsb4",
#   "prov:label": "rdf:13_13",
#   "_cell": 339,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicmzsqn73eqigaz6pwq7zidhxbdvc4677afjv2kda3tg6tw6c4z6i"
#   },
#   "_stmt_key": "13_13",
#   "_chunk_num": 13,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [13.14]: Thought experiments by [Albert Einstein](/wiki/Albert_Einstein) involved the transmission of signals and synchronization of clocks.
# rdfs:comment rdfs:comment "Thought experiments by Albert Einstein involved the transmission of signals and synchronization of clocks." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreig42hpx22lgzydsl3afbtzc2nni7xng2gf3ramjr5bzx4wr6rt6ai",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreig42hpx22lgzydsl3afbtzc2nni7xng2gf3ramjr5bzx4wr6rt6ai",
#   "prov:label": "rdf:13_14",
#   "_cell": 341,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib2fg7eleb3gh47ruv6iej5heep6ch4zwfqji6olmlrqahzzerfg4"
#   },
#   "_stmt_key": "13_14",
#   "_chunk_num": 13,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [13.15]: Matters related to signal transmission and clock synchronization also appeared in some inventions submitted for assessment at the [Swiss Patent Office](/wiki/Swiss_Patent_Office).
# rdfs:comment rdfs:comment "Matters related to signal transmission and clock synchronization also appeared in some inventions submitted for assessment at the Swiss Patent Office." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigrya3u7cdlmd2mfffisewl5esydvt7kx3n6jpleulerplvqdv2re",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigrya3u7cdlmd2mfffisewl5esydvt7kx3n6jpleulerplvqdv2re",
#   "prov:label": "rdf:13_15",
#   "_cell": 343,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifyqcmhwrpa5ua43bo7r6c2o7rokmt6hikvwmr4lrpmurvfquabwm"
#   },
#   "_stmt_key": "13_15",
#   "_chunk_num": 13,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [14.1]: In 1902, [Albert Einstein](/wiki/Albert_Einstein) formed a group with friends he had met in [Bern](/wiki/Bern) to hold regular meetings to discuss science and philosophy.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation <https://en.wikipedia.org/wiki/Bern> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:member <https://en.wikipedia.org/wiki/Olympia_Academy> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreid4umpei2fjx2waw7a2bxgg3vblqurcenkksgjw67rotv5szn3j7m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreid4umpei2fjx2waw7a2bxgg3vblqurcenkksgjw67rotv5szn3j7m",
#   "prov:label": "rdf:14_1",
#   "_cell": 345,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihredjrdpm544evjhoz7pa2smjyqheibzguv3fuxa2kv3mowtsk5q"
#   },
#   "_stmt_key": "14_1",
#   "_chunk_num": 14,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [14.2]: The group chose the name [Olympia Academy](/wiki/Olympia_Academy) for their club.
# <https://en.wikipedia.org/wiki/Olympia_Academy> schema:legalName "Olympia Academy" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreif4abat3zm4wsblm2tesw6rqhwledeqt7v5aonk24qnzvzjn7bo3q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreif4abat3zm4wsblm2tesw6rqhwledeqt7v5aonk24qnzvzjn7bo3q",
#   "prov:label": "rdf:14_2",
#   "_cell": 347,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiekcrwl3uzsaxcxdyritkdkam4gj4a4sw2dip2g4pha7nudqqfvve"
#   },
#   "_stmt_key": "14_2",
#   "_chunk_num": 14,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [14.3]: The name [Olympia Academy](/wiki/Olympia_Academy) was an ironic comment on its far from Olympian status.
# <https://en.wikipedia.org/wiki/Olympia_Academy> rdfs:comment "The name Olympia Academy was an ironic comment on its far from Olympian status." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifl6i2xi4ibgxqi7qweu3mwf2tnm5bda77ufmvp55vfxx3yopj4au",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifl6i2xi4ibgxqi7qweu3mwf2tnm5bda77ufmvp55vfxx3yopj4au",
#   "prov:label": "rdf:14_3",
#   "_cell": 349,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigzmgx2cogcnja4ckcyyvllurdujotua44fh3vwb6txyzl5akfouq"
#   },
#   "_stmt_key": "14_3",
#   "_chunk_num": 14,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [14.4]: Sometimes [Mileva Marić](/wiki/Mileva_Mari%C4%87) joined the meetings of the [Olympia Academy](/wiki/Olympia_Academy).
# <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> schema:member <https://en.wikipedia.org/wiki/Olympia_Academy> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiclc75fs2n3kidhn5ku7oimmo7u6ujb3pwn7k2t2breii53om5bxm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiclc75fs2n3kidhn5ku7oimmo7u6ujb3pwn7k2t2breii53om5bxm",
#   "prov:label": "rdf:14_4",
#   "_cell": 351,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidw6iro45y5kvssxkfrxb3i54j4kqgfewmnzjskjngkcsvtssi72u"
#   },
#   "_stmt_key": "14_4",
#   "_chunk_num": 14,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [14.5]: When [Mileva Marić](/wiki/Mileva_Mari%C4%87) participated in the meetings of the [Olympia Academy](/wiki/Olympia_Academy), she limited her participation to careful listening.
# <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> rdfs:comment "When Mileva Marić participated in the meetings of the Olympia Academy, she limited her participation to careful listening." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic47rjvppc3eigoc5wih4btzsfhfnaewaldu7tgxucq7upkpzq44e",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic47rjvppc3eigoc5wih4btzsfhfnaewaldu7tgxucq7upkpzq44e",
#   "prov:label": "rdf:14_5",
#   "_cell": 353,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreig4bpbk4kgbgsc7l7kbscwslsi2xqjrzwiyc7fs6liz5e6hz5owqi"
#   },
#   "_stmt_key": "14_5",
#   "_chunk_num": 14,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [14.6]: The thinkers whose works were reflected upon by the [Olympia Academy](/wiki/Olympia_Academy) included [Henri Poincaré](/wiki/Henri_Poincar%C3%A9).
# <https://en.wikipedia.org/wiki/Olympia_Academy> rdfs:comment "The thinkers whose works were reflected upon by the Olympia Academy included Henri Poincaré." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia37l5ltdcd2mvceumk7d34wmqowlseerr2t3mref7xm36hj2gumm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia37l5ltdcd2mvceumk7d34wmqowlseerr2t3mref7xm36hj2gumm",
#   "prov:label": "rdf:14_6",
#   "_cell": 355,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia53c3vnl6aiyvaglvmm62tmusntklwlgkxgik43zt3daq43gho3q"
#   },
#   "_stmt_key": "14_6",
#   "_chunk_num": 14,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [14.7]: The thinkers whose works were reflected upon by the [Olympia Academy](/wiki/Olympia_Academy) included [Ernst Mach](/wiki/Ernst_Mach).
# <https://en.wikipedia.org/wiki/Olympia_Academy> rdfs:comment "The thinkers whose works were reflected upon by the Olympia Academy included Ernst Mach." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidgw7uoxczlp52z7eryu4vdnnyrecvectopdukiyroewgrw4x2ez4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidgw7uoxczlp52z7eryu4vdnnyrecvectopdukiyroewgrw4x2ez4",
#   "prov:label": "rdf:14_7",
#   "_cell": 357,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigguj4tb4orhchnzxjksidlbnqjfpyjmsx2jbqxlnrccwxcuut3ja"
#   },
#   "_stmt_key": "14_7",
#   "_chunk_num": 14,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [14.8]: The thinkers whose works were reflected upon by the [Olympia Academy](/wiki/Olympia_Academy) included [David Hume](/wiki/David_Hume).
# <https://en.wikipedia.org/wiki/Olympia_Academy> rdfs:comment "The thinkers whose works were reflected upon by the Olympia Academy included David Hume." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihoxydhlj5l5ekbalexslsctutc7fmizhkpiecculutilvr2fyxdq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihoxydhlj5l5ekbalexslsctutc7fmizhkpiecculutilvr2fyxdq",
#   "prov:label": "rdf:14_8",
#   "_cell": 359,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidam5hg4ijx6btxzxzi3q5jg766f7dvxnsf4ibjxlhuo2bj32ezsa"
#   },
#   "_stmt_key": "14_8",
#   "_chunk_num": 14,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [14.9]: The works of [Henri Poincaré](/wiki/Henri_Poincar%C3%A9) significantly influenced [Albert Einstein](/wiki/Albert_Einstein)'s subsequent ideas and beliefs.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "The works of Henri Poincaré significantly influenced Albert Einstein's subsequent ideas and beliefs." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibbnzxecyrljxbzv47aevhvcrqu2erbahi54qtascfsio5mreggk4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibbnzxecyrljxbzv47aevhvcrqu2erbahi54qtascfsio5mreggk4",
#   "prov:label": "rdf:14_9",
#   "_cell": 361,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia6lgiapw36tbj7jn64zp4ia7lwjfeglzozhmd4hs67x3jhy5oco4"
#   },
#   "_stmt_key": "14_9",
#   "_chunk_num": 14,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [14.10]: The works of [Ernst Mach](/wiki/Ernst_Mach) significantly influenced [Albert Einstein](/wiki/Albert_Einstein)'s subsequent ideas and beliefs.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "The works of Ernst Mach significantly influenced Albert Einstein's subsequent ideas and beliefs." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifg4r43izrdfy6zudwoo6zv62mhhxtvobssddg2rk4yw3wexr2tfu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifg4r43izrdfy6zudwoo6zv62mhhxtvobssddg2rk4yw3wexr2tfu",
#   "prov:label": "rdf:14_10",
#   "_cell": 363,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih2l4xqauopd4xb7bt7s7ms62hpczwkrxbp5ets6pztanu4tcp57u"
#   },
#   "_stmt_key": "14_10",
#   "_chunk_num": 14,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [14.11]: The works of [David Hume](/wiki/David_Hume) significantly influenced [Albert Einstein](/wiki/Albert_Einstein)'s subsequent ideas and beliefs.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "The works of David Hume significantly influenced Albert Einstein's subsequent ideas and beliefs." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreid2ktgwdybij5unu7uqvrmr3oggzhz5t2wrwpnywbnz5xwnaihgfq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreid2ktgwdybij5unu7uqvrmr3oggzhz5t2wrwpnywbnz5xwnaihgfq",
#   "prov:label": "rdf:14_11",
#   "_cell": 365,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifr6ucim6dsgplk6xs6mgxvfadha3pq6dmujvczezfqkrc4uxt434"
#   },
#   "_stmt_key": "14_11",
#   "_chunk_num": 14,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [15.1]: [Albert Einstein](/wiki/Albert_Einstein) published his first paper titled ["Folgerungen aus den Capillaritätserscheinungen"](/wiki/List_of_scientific_publications_by_Albert_Einstein) in the journal *[Annalen der Physik](/wiki/Annalen_der_Physik)* in 1901.
# _:s1_paper1 rdf:type schema:ScholarlyArticle .
# _:s1_paper1 schema:text "Folgerungen aus den Capillaritätserscheinungen" .
# _:s1_paper1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s1_paper1 schema:datePublished "1901"^^xsd:gYear .
# _:s1_paper1 schema:publication _:s1_pub1 .
# _:s1_pub1 rdf:type schema:PublicationEvent .
# _:s1_pub1 schema:publishedOn <https://en.wikipedia.org/wiki/Annalen_der_Physik> .
# _:s1_paper1 schema:title "Folgerungen aus den Capillaritätserscheinungen" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifxnxdmv3bvcrc4pe7br5eslmaszv3zyhhllnv4vqlfeykiwcl6j4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifxnxdmv3bvcrc4pe7br5eslmaszv3zyhhllnv4vqlfeykiwcl6j4",
#   "prov:label": "rdf:15_1",
#   "_cell": 367,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaqmceeplr6szububhu2jprvddndf3gyo5h3lza7vgtaxhlymyxfa"
#   },
#   "_stmt_key": "15_1",
#   "_chunk_num": 15,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [15.2]: [Albert Einstein](/wiki/Albert_Einstein) proposed a model of intermolecular attraction in his first paper that he afterwards disavowed as worthless.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment Albert Einstein proposed a model of intermolecular attraction in his first paper that he afterwards disavowed as worthless. .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie7eh7brji6a3oaukjbnlsvrekywcihc7tca2tkw4lm56vntaj3hu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie7eh7brji6a3oaukjbnlsvrekywcihc7tca2tkw4lm56vntaj3hu",
#   "prov:label": "rdf:15_2",
#   "_cell": 369,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifw4x4djgvu7q3qoypsaykarmkkxxditfx3moquavryadgwcnnvba"
#   },
#   "_stmt_key": "15_2",
#   "_chunk_num": 15,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [15.3]: [Albert Einstein](/wiki/Albert_Einstein) completed his 24-page doctoral dissertation titled "Eine neue Bestimmung der Moleküldimensionen" on 30 April 1905.
# _:s3_dissertation1 rdf:type schema:Thesis .
# _:s3_dissertation1 schema:text "Eine neue Bestimmung der Moleküldimensionen" .
# _:s3_dissertation1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s3_dissertation1 schema:datePublished "1905-04-30"^^xsd:date .
# _:s3_dissertation1 schema:title "Eine neue Bestimmung der Moleküldimensionen" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieeqcnmxnxzl6zgq6ul4sjrt6hpcl2im6qc6v5odu5pc66y5pozci",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieeqcnmxnxzl6zgq6ul4sjrt6hpcl2im6qc6v5odu5pc66y5pozci",
#   "prov:label": "rdf:15_3",
#   "_cell": 371,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibrmnxu47qtm76p3gknught2jpfvklj2jksczkp5bkwo2jzvv6srq"
#   },
#   "_stmt_key": "15_3",
#   "_chunk_num": 15,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [15.4]: [Albert Einstein](/wiki/Albert_Einstein)'s doctoral dissertation was dedicated "Meinem Freunde Herr Dr. Marcel Grossmann gewidet" (to his friend Marcel Grossman).
# _:s4_dissertation1 schema:inSupportOf "Meinem Freunde Herr Dr. Marcel Grossmann gewidet" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaiys3idliedsujjlifme5gxtc5w2vwjkbxstacf7bm5fk7nedopi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaiys3idliedsujjlifme5gxtc5w2vwjkbxstacf7bm5fk7nedopi",
#   "prov:label": "rdf:15_4",
#   "_cell": 373,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiefx4ibopn3jqnpjnch2rv2ultvkvblbx6ewmd7enx4ss2s6iycgq"
#   },
#   "_stmt_key": "15_4",
#   "_chunk_num": 15,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [15.5]: [Albert Einstein](/wiki/Albert_Einstein)'s doctoral dissertation was approved by Professor [Alfred Kleiner](/wiki/Alfred_Kleiner) of the [University of Zurich](/wiki/University_of_Zurich) three months after completion.
# _:s5_dissertation1 schema:creator <https://en.wikipedia.org/wiki/Alfred_Kleiner> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigeqyboobrlcsohjj56mwq2n4amg33yvhipfhyeuriktxsrf44pr4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigeqyboobrlcsohjj56mwq2n4amg33yvhipfhyeuriktxsrf44pr4",
#   "prov:label": "rdf:15_5",
#   "_cell": 375,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihialtf4jqkwtudz24xzwaoufueyog3ss6ir54g74p6abfy7iklwa"
#   },
#   "_stmt_key": "15_5",
#   "_chunk_num": 15,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [15.6]: [Albert Einstein](/wiki/Albert_Einstein) was formally awarded his [PhD](/wiki/PhD) on 15 January 1906.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:educationalCredentialAwarded <https://en.wikipedia.org/wiki/PhD> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:datePublished "1906-01-15"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreietswwssnlcx6bhz7rxddly4fjshjd6r666xaphs2wi5qajtbnqsm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreietswwssnlcx6bhz7rxddly4fjshjd6r666xaphs2wi5qajtbnqsm",
#   "prov:label": "rdf:15_6",
#   "_cell": 377,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigulcoczm5k22siioyivbmh2agebnnbu3dsstg67pvhtytm5ctu44"
#   },
#   "_stmt_key": "15_6",
#   "_chunk_num": 15,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [15.7]: In 1905, [Albert Einstein](/wiki/Albert_Einstein) completed four other pieces of work including his famous papers on the [photoelectric effect](/wiki/Photoelectric_effect), [Brownian motion](/wiki/Brownian_motion), the [special theory of relativity](/wiki/Special_relativity), and the [equivalence of mass and energy](/wiki/Mass%E2%80%93energy_equivalence).
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment In 1905, Albert Einstein completed four other pieces of work including his famous papers on the photoelectric effect, Brownian motion, the special theory of relativity, and the equivalence of mass and energy. .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifqvck7dcico7pwhmon2cdwyvkjmnbb3y66ki54fzv2zznehdloem",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifqvck7dcico7pwhmon2cdwyvkjmnbb3y66ki54fzv2zznehdloem",
#   "prov:label": "rdf:15_7",
#   "_cell": 379,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiar2m3v7wkjzabp55m2uwdre6et37idx6cjkqoxj66kf3nsofhmci"
#   },
#   "_stmt_key": "15_7",
#   "_chunk_num": 15,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [15.8]: The year 1905 is celebrated as an *annus mirabilis* for physics due to [Albert Einstein](/wiki/Albert_Einstein)'s four major papers published that year.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment The year 1905 is celebrated as an annus mirabilis for physics due to Albert Einstein's four major papers published that year. .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidohjpcfvfzuxlmkm35y67tq6sklrgqplzpuy2nxm7glzcuztm73i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidohjpcfvfzuxlmkm35y67tq6sklrgqplzpuy2nxm7glzcuztm73i",
#   "prov:label": "rdf:15_8",
#   "_cell": 381,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifwg6rbomygj2i5dncqdat2u4qmfatld6weztnicwxvvqc5uw5aoq"
#   },
#   "_stmt_key": "15_8",
#   "_chunk_num": 15,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [15.9]: [Isaac Newton](/wiki/Isaac_Newton) experienced his greatest epiphanies during the miracle year of 1666.
# <https://en.wikipedia.org/wiki/Isaac_Newton> rdfs:comment Isaac Newton experienced his greatest epiphanies during the miracle year of 1666. .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifzduex7rumagibl23tlkh23gqr6xugachsegtljfhboask24wzre",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifzduex7rumagibl23tlkh23gqr6xugachsegtljfhboask24wzre",
#   "prov:label": "rdf:15_9",
#   "_cell": 383,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigk42t34qjzhrmiptsnkgllztulxgocmprlda5yowedpjml3zyfcq"
#   },
#   "_stmt_key": "15_9",
#   "_chunk_num": 15,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [15.10]: [Albert Einstein](/wiki/Albert_Einstein)'s publications in 1905 deeply impressed his contemporaries.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment Albert Einstein's publications in 1905 deeply impressed his contemporaries. .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia52hojimpm6bnkcvuz6l7tvhtwi5vfvre7vdfkk3zkxh5wbxeybm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia52hojimpm6bnkcvuz6l7tvhtwi5vfvre7vdfkk3zkxh5wbxeybm",
#   "prov:label": "rdf:15_10",
#   "_cell": 385,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih4vrne42nubw65ghactr3gdq2tg7lsgavieaf5nxewv7xgck5hpm"
#   },
#   "_stmt_key": "15_10",
#   "_chunk_num": 15,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [15.11]: In 1908, [Albert Einstein](/wiki/Albert_Einstein)'s sabbatical as a civil servant approached its end.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment In 1908, Albert Einstein's sabbatical as a civil servant approached its end. .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidcwynnumcyqsifu4kzmo7e64etbughyaugduxaaarlqxmjjpswcq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidcwynnumcyqsifu4kzmo7e64etbughyaugduxaaarlqxmjjpswcq",
#   "prov:label": "rdf:15_11",
#   "_cell": 387,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigc5t7tnxhh7ygjlt7z3hzcai3ftsc2k4xd4ncx7r5mf7w73gkhhi"
#   },
#   "_stmt_key": "15_11",
#   "_chunk_num": 15,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [15.12]: In 1908, [Albert Einstein](/wiki/Albert_Einstein) secured a junior teaching position at the [University of Bern](/wiki/University_of_Bern).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor _:s12_role1 .
# _:s12_role1 rdf:type schema:OrganizationRole .
# _:s12_role1 schema:worksFor <https://en.wikipedia.org/wiki/University_of_Bern> .
# _:s12_role1 schema:startDate "1908"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieotup5qrly7iyd7vrrg4ob4clluf7fxmvjg3ks6ghyfqkiv2kf2e",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieotup5qrly7iyd7vrrg4ob4clluf7fxmvjg3ks6ghyfqkiv2kf2e",
#   "prov:label": "rdf:15_12",
#   "_cell": 389,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih72n4ishthmg46yldbieccfac4qhxbflbddzroc74my7log2dlve"
#   },
#   "_stmt_key": "15_12",
#   "_chunk_num": 15,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [15.13]: In 1909, [Albert Einstein](/wiki/Albert_Einstein) gave a lecture on relativistic [electrodynamics](/wiki/Electrodynamics) at the [University of Zurich](/wiki/University_of_Zurich).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor _:s13_role1 .
# _:s13_role1 rdf:type schema:OrganizationRole .
# _:s13_role1 schema:worksFor <https://en.wikipedia.org/wiki/University_of_Zurich> .
# _:s13_role1 schema:startDate "1909"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaguwcy6r5qiczssnvaszt66utxyiz73fb53jdel73ejtc7lpecea",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaguwcy6r5qiczssnvaszt66utxyiz73fb53jdel73ejtc7lpecea",
#   "prov:label": "rdf:15_13",
#   "_cell": 391,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiehc74itdzg2nw36bymqryegvwsrehhyohewitikp5vkdqauwebzi"
#   },
#   "_stmt_key": "15_13",
#   "_chunk_num": 15,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [15.14]: [Albert Einstein](/wiki/Albert_Einstein)'s lecture on relativistic [electrodynamics](/wiki/Electrodynamics) was much admired by Professor [Alfred Kleiner](/wiki/Alfred_Kleiner).
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment Albert Einstein's lecture on relativistic electrodynamics was much admired by Professor Alfred Kleiner. .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieep5jcn3wns2ls5x4tl2pxddvkiyld4fwdclurk3mxzwtbprw3ba",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieep5jcn3wns2ls5x4tl2pxddvkiyld4fwdclurk3mxzwtbprw3ba",
#   "prov:label": "rdf:15_14",
#   "_cell": 393,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibjm4fln5yxiyuidog75h4f2rxgtnbnailtldtj5hmxddebes3nke"
#   },
#   "_stmt_key": "15_14",
#   "_chunk_num": 15,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [15.15]: In 1909, the [University of Zurich](/wiki/University_of_Zurich) lured [Albert Einstein](/wiki/Albert_Einstein) away from the [University of Bern](/wiki/University_of_Bern) with a newly created associate professorship.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor _:s15_role1 .
# _:s15_role1 rdf:type schema:OrganizationRole .
# _:s15_role1 schema:worksFor <https://en.wikipedia.org/wiki/University_of_Zurich> .
# _:s15_role1 schema:startDate "1909"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifzieqxad72jyzsr22opnj4s3j75mai3ldj5r3ap4b3zipah7nr3e",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifzieqxad72jyzsr22opnj4s3j75mai3ldj5r3ap4b3zipah7nr3e",
#   "prov:label": "rdf:15_15",
#   "_cell": 395,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifdge2o4jdv5jj4j64xhf4i6qzxwq2hw3bpwkutlslcpesnhliw2e"
#   },
#   "_stmt_key": "15_15",
#   "_chunk_num": 15,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [16.1]: From 30 October to 3 November 1911, [Albert Einstein](/wiki/Albert_Einstein) attended the first [Solvay Conference on Physics](/wiki/Solvay_Conference).
# _:s1_event1 rdf:type "https://schema.org/ConferenceEvent" .
# _:s1_event1 schema:startDate "1911-10-30"^^xsd:date .
# _:s1_event1 schema:endDate "1911-11-03"^^xsd:date .
# _:s1_event1 schema:name "Solvay Conference on Physics" .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:attendee _:s1_event1 .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreig77dyqsdssxoa42dn2m3ikno2tt4lrqupp4v4wzupreqwqowapya",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreig77dyqsdssxoa42dn2m3ikno2tt4lrqupp4v4wzupreqwqowapya",
#   "prov:label": "rdf:16_1",
#   "_cell": 397,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiayhj24yswlci42sgrngdiy3piiyshb7y5xwhaov7szqyusi6eoca"
#   },
#   "_stmt_key": "16_1",
#   "_chunk_num": 16,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [16.2]: In July 1912, [Albert Einstein](/wiki/Albert_Einstein) returned to his *alma mater*, the [ETH Zurich](/wiki/ETH_Zurich), to take up a chair in theoretical physics.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:worksFor _:s2_role1 .
# _:s2_role1 rdf:type "https://schema.org/OrganizationRole" .
# _:s2_role1 schema:worksFor "https://en.wikipedia.org/wiki/ETH_Zurich" .
# _:s2_role1 schema:startDate "1912"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreida3m3ppivy4ysa7n4gpoul753mzcdtehsz6fujxiknbtcka7occq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreida3m3ppivy4ysa7n4gpoul753mzcdtehsz6fujxiknbtcka7occq",
#   "prov:label": "rdf:16_2",
#   "_cell": 399,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiflw7j2fyvplfv4f2dzpicq76rmcjf7qo2vbbzem52kl34fpgtuea"
#   },
#   "_stmt_key": "16_2",
#   "_chunk_num": 16,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [16.3]: [Albert Einstein](/wiki/Albert_Einstein)'s teaching activities at the [ETH Zurich](/wiki/ETH_Zurich) centered on [thermodynamics](/wiki/thermodynamics) and analytical mechanics.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:teaches "https://en.wikipedia.org/wiki/thermodynamics" .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:teaches "https://en.wikipedia.org/wiki/analytical_mechanics" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifig765tvd3lu6e63wqrprjy5emvbxexxbh2j4gvffeatqqjcskim",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifig765tvd3lu6e63wqrprjy5emvbxexxbh2j4gvffeatqqjcskim",
#   "prov:label": "rdf:16_3",
#   "_cell": 401,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihkrbuxw56vod6beklvpjfveffflu6frkglx6hqgh6ctr7xb67usm"
#   },
#   "_stmt_key": "16_3",
#   "_chunk_num": 16,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [16.4]: [Albert Einstein](/wiki/Albert_Einstein)'s research interests at the [ETH Zurich](/wiki/ETH_Zurich) included the molecular theory of heat, [continuum mechanics](/wiki/continuum_mechanics), and the development of a relativistic theory of gravitation.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:researchInterests "https://en.wikipedia.org/wiki/molecular_theory_of_heat" .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:researchInterests "https://en.wikipedia.org/wiki/continuum_mechanics" .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:researchInterests "https://en.wikipedia.org/wiki/relativistic_theory_of_gravitation" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigajmivt7hpu32jme45bxxbopm5fdrzrenmulrehyezu2zkznrntu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigajmivt7hpu32jme45bxxbopm5fdrzrenmulrehyezu2zkznrntu",
#   "prov:label": "rdf:16_4",
#   "_cell": 403,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifrn3ngcsdkmu445du42nocve77pbcq4qz5ssv6zjjvoajpw5kdoq"
#   },
#   "_stmt_key": "16_4",
#   "_chunk_num": 16,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [16.5]: In his work on the relativistic theory of gravitation, [Albert Einstein](/wiki/Albert_Einstein) was assisted by his friend [Marcel Grossmann](/wiki/Marcel_Grossmann).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:colleague "https://en.wikipedia.org/wiki/Marcel_Grossmann" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigqerq7wuhdt7fkcbbbquk2bq5wlypsqn6mx3eioysjbvrmig2pcy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigqerq7wuhdt7fkcbbbquk2bq5wlypsqn6mx3eioysjbvrmig2pcy",
#   "prov:label": "rdf:16_5",
#   "_cell": 405,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiguqtcmqgklyxuaizbwhv3l6fw7zdujot5afcjhwgsnfqp3ygw7cq"
#   },
#   "_stmt_key": "16_5",
#   "_chunk_num": 16,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [16.6]: [Albert Einstein](/wiki/Albert_Einstein) moved into an apartment in the Berlin district of [Dahlem](/wiki/Dahlem_%28Berlin%29) on 1 April 1914.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:homeLocation "https://en.wikipedia.org/wiki/Dahlem_%28Berlin%29" .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:startDate "1914-04-01"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreienge2spbi67sgtfkel2ypel3r5osori42icadctxundadg5wrkva",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreienge2spbi67sgtfkel2ypel3r5osori42icadctxundadg5wrkva",
#   "prov:label": "rdf:16_6",
#   "_cell": 407,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihpdlph7jke3hrnkw3hvcilfqp7aquli3455fmnzhiowvkpi3esha"
#   },
#   "_stmt_key": "16_6",
#   "_chunk_num": 16,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [16.7]: Britain's closest equivalent of the Nobel award, the [Royal Society](/wiki/Royal_Society)'s [Copley Medal](/wiki/Copley_Medal), was not hung around [Albert Einstein](/wiki/Albert_Einstein)'s neck until 1925.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:award _:s7_role1 .
# _:s7_role1 rdf:type "https://schema.org/Role" .
# _:s7_role1 schema:award "https://en.wikipedia.org/wiki/Copley_Medal" .
# _:s7_role1 schema:startDate "1925"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidt4la6iwfvmjdywz6ljkq3etd23owcqmx6itnjaix7klyphfzb5a",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidt4la6iwfvmjdywz6ljkq3etd23owcqmx6itnjaix7klyphfzb5a",
#   "prov:label": "rdf:16_7",
#   "_cell": 409,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiec7gwp4v6f2yj5ud7ia5rpacdfzwgva4rdpidseul7wvzls3phbm"
#   },
#   "_stmt_key": "16_7",
#   "_chunk_num": 16,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [16.8]: [Albert Einstein](/wiki/Albert_Einstein) resigned from the [Prussian Academy of Sciences](/wiki/Prussian_Academy_of_Sciences) in March 1933.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:employee _:s8_role1 .
# _:s8_role1 rdf:type "https://schema.org/Role" .
# _:s8_role1 schema:employee "https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences" .
# _:s8_role1 schema:endDate "1933-03"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifvtswscpmbvz6oabi7thou4cxfyztoggdfcv5alj6btq6u5wmeem",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifvtswscpmbvz6oabi7thou4cxfyztoggdfcv5alj6btq6u5wmeem",
#   "prov:label": "rdf:16_8",
#   "_cell": 411,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaq7suibyjsqobwdxswfod4xdnos5l5iic3ihcei777qqei6ly7o4"
#   },
#   "_stmt_key": "16_8",
#   "_chunk_num": 16,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [16.9]: [Albert Einstein](/wiki/Albert_Einstein)'s accomplishments in Berlin included the completion of the general theory of relativity.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:accomplishment "https://en.wikipedia.org/wiki/General_relativity" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicar7awlkhyn6lr6llyyqxn7u6bkzjmssc6bpxnxylmejsxhlvyda",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicar7awlkhyn6lr6llyyqxn7u6bkzjmssc6bpxnxylmejsxhlvyda",
#   "prov:label": "rdf:16_9",
#   "_cell": 413,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiemmoruiuapyxzxvvjtcczxmiycpjw34texqfpremp5dxeiouubjy"
#   },
#   "_stmt_key": "16_9",
#   "_chunk_num": 16,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [16.10]: [Albert Einstein](/wiki/Albert_Einstein)'s accomplishments in Berlin included proving the [Einstein–de Haas effect](/wiki/Einstein%E2%80%93de_Haas_effect).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:accomplishment "https://en.wikipedia.org/wiki/Einstein%E2%80%93de_Haas_effect" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiggvhf2mlvnntm6b7ia5stmrxwqcgtycnzgrljxp6wxfw3beszbfy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiggvhf2mlvnntm6b7ia5stmrxwqcgtycnzgrljxp6wxfw3beszbfy",
#   "prov:label": "rdf:16_10",
#   "_cell": 415,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibwnbgmi5nhr5l2z35ln4fsfebw3pgoptudu2gikl27eg5pqllabe"
#   },
#   "_stmt_key": "16_10",
#   "_chunk_num": 16,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [16.11]: [Albert Einstein](/wiki/Albert_Einstein)'s accomplishments in Berlin included contributing to the quantum theory of radiation.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:accomplishment "https://en.wikipedia.org/wiki/quantum_theory_of_radiation" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigju3vdybuboe2ngtpjeegwt7sqsi7dnsra6ri4qorpkvorndxeuy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigju3vdybuboe2ngtpjeegwt7sqsi7dnsra6ri4qorpkvorndxeuy",
#   "prov:label": "rdf:16_11",
#   "_cell": 417,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiglqp7gyd3cceole3c43tgavwqnna57psuc4oqaxcs4ochcacoe2i"
#   },
#   "_stmt_key": "16_11",
#   "_chunk_num": 16,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [16.12]: [Albert Einstein](/wiki/Albert_Einstein)'s accomplishments in Berlin included the development of [Bose–Einstein statistics](/wiki/Bose%E2%80%93Einstein_statistics).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:accomplishment "https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_statistics" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicynp2i23cwkkz6pijstf5due5jxvhwitzw5pccjgkqy6z4lbuoem",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicynp2i23cwkkz6pijstf5due5jxvhwitzw5pccjgkqy6z4lbuoem",
#   "prov:label": "rdf:16_12",
#   "_cell": 419,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaga3xyvisiz76erwei2o3mgd3aovfg6hwneo7bl3njxuvsdnox5m"
#   },
#   "_stmt_key": "16_12",
#   "_chunk_num": 16,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [17.1]: [Albert Einstein](/wiki/Albert_Einstein) reached a milestone in 1907 on his journey from special relativity to a new idea of gravitation.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:knownFor "https://en.wikipedia.org/wiki/General_relativity" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiftpp2qhfhqg4zmhh4dhy3dbeuko7u64iul6a4vq6snxmvdtvmpeq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiftpp2qhfhqg4zmhh4dhy3dbeuko7u64iul6a4vq6snxmvdtvmpeq",
#   "prov:label": "rdf:17_1",
#   "_cell": 421,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicxjnl6x3pqszym76n2y6fqrd3saih6d4iphzvfh2dxdkzd4dncje"
#   },
#   "_stmt_key": "17_1",
#   "_chunk_num": 17,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [17.2]: In 1907, [Albert Einstein](/wiki/Albert_Einstein) formulated the [equivalence principle](/wiki/equivalence_principle).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:creator "https://en.wikipedia.org/wiki/Equivalence_principle" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiblfxkpetn3oijs5w5phwea3k4gc5a3rgujgiubuxmlh6hj5wyxdi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiblfxkpetn3oijs5w5phwea3k4gc5a3rgujgiubuxmlh6hj5wyxdi",
#   "prov:label": "rdf:17_2",
#   "_cell": 423,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicljeha23rasr535vnuq2qwwksmbl3y57i75xs7c24w34bepgl46i"
#   },
#   "_stmt_key": "17_2",
#   "_chunk_num": 17,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [17.3]: The [equivalence principle](/wiki/equivalence_principle) asserts that an observer in a box falling freely in a gravitational field would be unable to find any evidence that the field exists.
# "https://en.wikipedia.org/wiki/Equivalence_principle" schema:description "A principle stating that gravitational and inertial forces are equivalent" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiawrzz5bn2zl2iy535wy3j3nax57cvq7jhxpneeutypx6q56wikcm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiawrzz5bn2zl2iy535wy3j3nax57cvq7jhxpneeutypx6q56wikcm",
#   "prov:label": "rdf:17_3",
#   "_cell": 425,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaww3l7yamji7wtzajp7tvo4hxicnsqmvtcawoy2s3kpr7mblk6i4"
#   },
#   "_stmt_key": "17_3",
#   "_chunk_num": 17,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [17.4]: In 1911, [Albert Einstein](/wiki/Albert_Einstein) used the [equivalence principle](/wiki/equivalence_principle) to estimate the amount by which a ray of light from a distant star would be [bent](/wiki/Gravitational_lens) by the gravitational pull of the Sun.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:creator "https://en.wikipedia.org/wiki/Gravitational_lens" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigftlwwzbnaxltxfyeo5kfzgq7ik7xtzhyc63nkf6yvbti25koalq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigftlwwzbnaxltxfyeo5kfzgq7ik7xtzhyc63nkf6yvbti25koalq",
#   "prov:label": "rdf:17_4",
#   "_cell": 427,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibz7fmhku7fxntwt4r23gf2ft74a7iyu5zzryud75x33jyhkiruwe"
#   },
#   "_stmt_key": "17_4",
#   "_chunk_num": 17,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [17.5]: In 1911, [Albert Einstein](/wiki/Albert_Einstein) estimated the bending of light as it passed close to the Sun's [photosphere](/wiki/photosphere).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:creator "https://en.wikipedia.org/wiki/Photosphere" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieqglgnr5oa4yxaicsavexlb4cvi7lb6v2jhl535bjtu3ctncwjq4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieqglgnr5oa4yxaicsavexlb4cvi7lb6v2jhl535bjtu3ctncwjq4",
#   "prov:label": "rdf:17_5",
#   "_cell": 429,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieu3en2fy4vxlbyoovon7jsrkxwmlvh6buiz772zjufdo6ce3in44"
#   },
#   "_stmt_key": "17_5",
#   "_chunk_num": 17,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [17.6]: In 1913, [Albert Einstein](/wiki/Albert_Einstein) reworked his calculation of light bending.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:creator "https://en.wikipedia.org/wiki/Gravitational_lens" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreig4yze3s32jplfqvpot4bjnvvndcaenofqyck2yxel3psmayzt32y",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreig4yze3s32jplfqvpot4bjnvvndcaenofqyck2yxel3psmayzt32y",
#   "prov:label": "rdf:17_6",
#   "_cell": 431,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibpek4tjjjpvel5gaqejoz2ribihvf6x7xcvcr6q57zyllcngntee"
#   },
#   "_stmt_key": "17_6",
#   "_chunk_num": 17,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [17.7]: In 1913, [Albert Einstein](/wiki/Albert_Einstein) used the [Riemann curvature tensor](/wiki/Riemann_curvature_tensor) of a non-Euclidean four-dimensional [spacetime](/wiki/spacetime).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:creator "https://en.wikipedia.org/wiki/Riemann_curvature_tensor" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia4irjeqrs5l2a42crsduhjz6q3eduyd2vb4yxjxk4zt5yskcbjii",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia4irjeqrs5l2a42crsduhjz6q3eduyd2vb4yxjxk4zt5yskcbjii",
#   "prov:label": "rdf:17_7",
#   "_cell": 433,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibpnflgggiig7knnpvsy5bvddmxo6omekj5mwvbkgk4cfucizffaq"
#   },
#   "_stmt_key": "17_7",
#   "_chunk_num": 17,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [17.8]: By the fall of 1915, [Albert Einstein](/wiki/Albert_Einstein) completed his reimagining of the mathematics of gravitation in terms of Riemannian geometry.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:creator "https://en.wikipedia.org/wiki/General_relativity" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidvhg4zhyoyvo3dlu3wrhc5uuh5lvmyzpbybs5knpdza2gtkqpvy4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidvhg4zhyoyvo3dlu3wrhc5uuh5lvmyzpbybs5knpdza2gtkqpvy4",
#   "prov:label": "rdf:17_8",
#   "_cell": 435,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiazh5vwwbeh7f6fihpx4paadobxpwhtqbuzmaferxgcepr55ooc6i"
#   },
#   "_stmt_key": "17_8",
#   "_chunk_num": 17,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [17.9]: [Albert Einstein](/wiki/Albert_Einstein) applied his new theory of gravitation to the behavior of the Sun as a gravitational lens.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:creator "https://en.wikipedia.org/wiki/Gravitational_lens" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifgndv32aceslew73wtiwaoc5wpcxzd2c6rvsbvjelkdnjxr6m6xi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifgndv32aceslew73wtiwaoc5wpcxzd2c6rvsbvjelkdnjxr6m6xi",
#   "prov:label": "rdf:17_9",
#   "_cell": 437,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreig6jlmkykemxkg73rdxx626flzz7cvnrqeii6bzwzygrehzqgtaa4"
#   },
#   "_stmt_key": "17_9",
#   "_chunk_num": 17,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [17.10]: [Albert Einstein](/wiki/Albert_Einstein) also applied his new theory to the [precession of the perihelion of Mercury](/wiki/precession_of_the_perihelion_of_Mercury).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:creator "https://en.wikipedia.org/wiki/Precession_of_the_perihelion_of_Mercury" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifwbx5mcxykt4fqu7yjdevc6ajtu4iawu5xukpmw7mxyujouc6uo4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifwbx5mcxykt4fqu7yjdevc6ajtu4iawu5xukpmw7mxyujouc6uo4",
#   "prov:label": "rdf:17_10",
#   "_cell": 439,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreievdvho3j72hqcsk3swmmzssbw4iode4pkx7hrqngoiw7riecuixi"
#   },
#   "_stmt_key": "17_10",
#   "_chunk_num": 17,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [17.11]: The [precession of the perihelion of Mercury](/wiki/precession_of_the_perihelion_of_Mercury) is a slow drift in the point in Mercury's elliptical orbit at which it approaches the Sun most closely.
# "https://en.wikipedia.org/wiki/Precession_of_the_perihelion_of_Mercury" schema:description "A slow drift in the point in Mercury's elliptical orbit at which it approaches the Sun most closely" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigvec6vwnfsnuf2v3h7i7svl2dy5zcyavkexnxhoaxo3rvk5efmpm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigvec6vwnfsnuf2v3h7i7svl2dy5zcyavkexnxhoaxo3rvk5efmpm",
#   "prov:label": "rdf:17_11",
#   "_cell": 441,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaymiv5jt6ffxbd5qcnnjgh3kk3gthd3ruy2y52wezwusq346yapa"
#   },
#   "_stmt_key": "17_11",
#   "_chunk_num": 17,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [17.12]: A [total eclipse of the Sun that took place on 29 May 1919](/wiki/Solar_eclipse_of_May_29%2C_1919) provided an opportunity to test [Albert Einstein](/wiki/Albert_Einstein)'s theory of gravitational lensing.
# "https://en.wikipedia.org/wiki/Solar_eclipse_of_May_29,_1919" schema:event "https://en.wikipedia.org/wiki/Astronomical_event" .
# "https://en.wikipedia.org/wiki/Solar_eclipse_of_May_29,_1919" rdf:type schema:Event .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibsmjvo34snldxx6ijosfxcwcdtsatwlxd3osgfqpaw3gamiimdou",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibsmjvo34snldxx6ijosfxcwcdtsatwlxd3osgfqpaw3gamiimdou",
#   "prov:label": "rdf:17_12",
#   "_cell": 443,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia73gav26f5qtxabbcbptuyrrbsgxc6fkuzs2yrxuspke5xuf5nka"
#   },
#   "_stmt_key": "17_12",
#   "_chunk_num": 17,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [17.13]: Observations performed by Sir [Arthur Eddington](/wiki/Arthur_Eddington) during the [total eclipse of the Sun that took place on 29 May 1919](/wiki/Solar_eclipse_of_May_29%2C_1919) yielded results consistent with [Albert Einstein](/wiki/Albert_Einstein)'s calculations.
# "https://en.wikipedia.org/wiki/Arthur_Eddington" schema:creator "https://en.wikipedia.org/wiki/Solar_eclipse_of_May_29,_1919" .
# "https://en.wikipedia.org/wiki/Arthur_Eddington" schema:contributor "https://en.wikipedia.org/wiki/Solar_eclipse_of_May_29,_1919" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreib7qkxxy5zqu5hexbgvk2kemup5a5y3jdvflusogaziq4b7mwo2fi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreib7qkxxy5zqu5hexbgvk2kemup5a5y3jdvflusogaziq4b7mwo2fi",
#   "prov:label": "rdf:17_13",
#   "_cell": 445,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreie7befbvef2zj5lkz3pcrxqrsg7cakipjgexxtlijou5enh7y3c54"
#   },
#   "_stmt_key": "17_13",
#   "_chunk_num": 17,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [17.14]: Sir [Arthur Eddington](/wiki/Arthur_Eddington) reported his work on the [total eclipse of the Sun that took place on 29 May 1919](/wiki/Solar_eclipse_of_May_29%2C_1919) at length in newspapers around the world.
# "https://en.wikipedia.org/wiki/Arthur_Eddington" schema:creator "https://en.wikipedia.org/wiki/Solar_eclipse_of_May_29,_1919" .
# "https://en.wikipedia.org/wiki/Arthur_Eddington" schema:contributor "https://en.wikipedia.org/wiki/Solar_eclipse_of_May_29,_1919" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreig2eehypix2n3gv54y3wv3ui6mxf5qztfqbp4xnofz7sfavny6atm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreig2eehypix2n3gv54y3wv3ui6mxf5qztfqbp4xnofz7sfavny6atm",
#   "prov:label": "rdf:17_14",
#   "_cell": 447,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiffvqrawtgbwyyjsixxwxviov5of33kdxmsscnzbul7nbggz66y2y"
#   },
#   "_stmt_key": "17_14",
#   "_chunk_num": 17,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [17.15]: On 7 November 1919, the leading British newspaper *[The Times](/wiki/The_Times)* printed a banner headline reading: "Revolution in Science– New Theory of the Universe– Newtonian Ideas Overthrown".
# "https://en.wikipedia.org/wiki/The_Times" schema:publication "https://en.wikipedia.org/wiki/News" .
# "https://en.wikipedia.org/wiki/The_Times" rdf:type schema:NewsMedia .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibttwhqmakyvzox6e2tog4jitntev36al3u7khuw6shmjnpop3qoa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibttwhqmakyvzox6e2tog4jitntev36al3u7khuw6shmjnpop3qoa",
#   "prov:label": "rdf:17_15",
#   "_cell": 449,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifj65g72hvpugjfpj3k4cicx57gjdrmmwslbafqfbsdb3jv2hjlvm"
#   },
#   "_stmt_key": "17_15",
#   "_chunk_num": 17,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [17.16]: [Albert Einstein](/wiki/Albert_Einstein) was known for his work on the [equivalence principle](/wiki/equivalence_principle).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:knownFor "https://en.wikipedia.org/wiki/Equivalence_principle" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibes7hvhhznc6q3chdkbbocg6id7it5j4wrowiykiz4wwxw4he5sm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibes7hvhhznc6q3chdkbbocg6id7it5j4wrowiykiz4wwxw4he5sm",
#   "prov:label": "rdf:17_16",
#   "_cell": 451,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiej64nlmevzqulehluo6w2e4ott4p2x3qtj3xm5lxsxzh5sfd5yxa"
#   },
#   "_stmt_key": "17_16",
#   "_chunk_num": 17,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [17.17]: [Albert Einstein](/wiki/Albert_Einstein) was known for his work on the [Riemann curvature tensor](/wiki/Riemann_curvature_tensor) and [spacetime](/wiki/spacetime).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:knownFor "https://en.wikipedia.org/wiki/Riemann_curvature_tensor" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiba35q6jfhuvgqw7dub7yqkw6nr7jy5alcyab7m2vk4rwwl7fysde",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiba35q6jfhuvgqw7dub7yqkw6nr7jy5alcyab7m2vk4rwwl7fysde",
#   "prov:label": "rdf:17_17",
#   "_cell": 453,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih3xlslpdsmjho3ohad5h2czrzbqdrn2um7uhtpxd2drun4yypao4"
#   },
#   "_stmt_key": "17_17",
#   "_chunk_num": 17,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [17.18]: [Albert Einstein](/wiki/Albert_Einstein) was known for his work on the [precession of the perihelion of Mercury](/wiki/precession_of_the_perihelion_of_Mercury).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:knownFor "https://en.wikipedia.org/wiki/Precession_of_the_perihelion_of_Mercury" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidklcncp72rytq3kv65fhdkkh7cucpt34rq5euw3epgvuu2xvn7lm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidklcncp72rytq3kv65fhdkkh7cucpt34rq5euw3epgvuu2xvn7lm",
#   "prov:label": "rdf:17_18",
#   "_cell": 455,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibx6ydzgqwxpwf4qi5uegvpxzadqhxf4hc4ilrpdervkwtj6lnl4a"
#   },
#   "_stmt_key": "17_18",
#   "_chunk_num": 17,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [17.19]: [Albert Einstein](/wiki/Albert_Einstein) was known for his theory of gravitational lensing.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:knownFor "https://en.wikipedia.org/wiki/Gravitational_lens" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifsksrnuv6od7nycpkaepsciqnm3piumay7ian6qj7kgwvbbuekn4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifsksrnuv6od7nycpkaepsciqnm3piumay7ian6qj7kgwvbbuekn4",
#   "prov:label": "rdf:17_19",
#   "_cell": 457,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibx4s4b5jj34tg6xiulrzq4zensec6zhv3gr6jm53nmmftnv36ora"
#   },
#   "_stmt_key": "17_19",
#   "_chunk_num": 17,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Statement [17.20]: [Arthur Eddington](/wiki/Arthur_Eddington) was a scientist who observed the [total eclipse of the Sun that took place on 29 May 1919](/wiki/Solar_eclipse_of_May_29%2C_1919).
# "https://en.wikipedia.org/wiki/Arthur_Eddington" schema:contributor "https://en.wikipedia.org/wiki/Solar_eclipse_of_May_29,_1919" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihgo5pypdqkbqkhoin3fmxj6yicjymc3qpdbl6zrcc4l7druthrou",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihgo5pypdqkbqkhoin3fmxj6yicjymc3qpdbl6zrcc4l7druthrou",
#   "prov:label": "rdf:17_20",
#   "_cell": 459,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifp5l5di2amyym5u6ztmr276g6a4xr35mhzo6p75ykkngqb5za72q"
#   },
#   "_stmt_key": "17_20",
#   "_chunk_num": 17,
#   "_stmt_idx": 20
# }

# %% [raw]
# # Statement [17.21]: [The Times](/wiki/The_Times) was a British newspaper.
# "https://en.wikipedia.org/wiki/The_Times" schema:publication "https://en.wikipedia.org/wiki/News" .
# "https://en.wikipedia.org/wiki/The_Times" rdf:type schema:NewsMedia .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibyv3i3ap3d27qsn4kuvajcvdrnv7svyq6uq2jgv7esy4p3xk7xyq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibyv3i3ap3d27qsn4kuvajcvdrnv7svyq6uq2jgv7esy4p3xk7xyq",
#   "prov:label": "rdf:17_21",
#   "_cell": 461,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidrnylzpraobt53ibwnum6z2ajemkekzydnep5etyo6qojagklr74"
#   },
#   "_stmt_key": "17_21",
#   "_chunk_num": 17,
#   "_stmt_idx": 21
# }

# %% [raw]
# # Statement [17.22]: The [total eclipse of the Sun that took place on 29 May 1919](/wiki/Solar_eclipse_of_May_29%2C_1919) was an astronomical event.
# "https://en.wikipedia.org/wiki/Solar_eclipse_of_May_29,_1919" schema:event "https://en.wikipedia.org/wiki/Astronomical_event" .
# "https://en.wikipedia.org/wiki/Solar_eclipse_of_May_29,_1919" rdf:type schema:Event .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiggejle7xjs3br4jynq4hg64t5bcydvjh77myw7g6snhm3kkthmo4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiggejle7xjs3br4jynq4hg64t5bcydvjh77myw7g6snhm3kkthmo4",
#   "prov:label": "rdf:17_22",
#   "_cell": 463,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihm7lovq5qz4gon2qetdb5stgulh264ypnvfvs4ftqevdef2qc2ey"
#   },
#   "_stmt_key": "17_22",
#   "_chunk_num": 17,
#   "_stmt_idx": 22
# }

# %% [raw]
# # Statement [17.23]: [Arthur Eddington](/wiki/Arthur_Eddington) confirmed Einstein's theory of gravitational lensing through observations.
# "https://en.wikipedia.org/wiki/Arthur_Eddington" schema:creator "https://en.wikipedia.org/wiki/Gravitational_lens" .
# "https://en.wikipedia.org/wiki/Arthur_Eddington" schema:contributor "https://en.wikipedia.org/wiki/Gravitational_lens" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihqomffgpjg5rqgzqg2gtvodm5duzb3zoznzvuumeem7qikkqukgy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihqomffgpjg5rqgzqg2gtvodm5duzb3zoznzvuumeem7qikkqukgy",
#   "prov:label": "rdf:17_23",
#   "_cell": 465,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigcdhm4lbbpddxbofkbfdd7sq66nc7f4ynm6f4ppscfjd2rrfshbu"
#   },
#   "_stmt_key": "17_23",
#   "_chunk_num": 17,
#   "_stmt_idx": 23
# }

# %% [raw]
# # Statement [17.24]: [Albert Einstein](/wiki/Albert_Einstein) was a theoretical physicist who made significant contributions to modern physics.
# https://en.wikipedia.org/wiki/Albert_Einstein rdf:type schema:Researcher .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic3fcrsn34jnaaq36ixxewvk3y6e2td7rgbzvjci7gk4tfc2lpg4i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic3fcrsn34jnaaq36ixxewvk3y6e2td7rgbzvjci7gk4tfc2lpg4i",
#   "prov:label": "rdf:17_24",
#   "_cell": 467,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicyvyli52b3hg5v456ciwdwoxjmpteuudfvdv7gbvt3tzgpgcwtsy"
#   },
#   "_stmt_key": "17_24",
#   "_chunk_num": 17,
#   "_stmt_idx": 24
# }

# %% [raw]
# # Statement [18.1]: [Albert Einstein](/wiki/Albert_Einstein) became "perhaps the world's first celebrity scientist" in the years 1921–1923.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Albert Einstein became perhaps the world's first celebrity scientist in the years 1921–1923." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicjc6jozel7zrc6ztac3jmutoawuvdo344fvnuvxsej52gm4vitvm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicjc6jozel7zrc6ztac3jmutoawuvdo344fvnuvxsej52gm4vitvm",
#   "prov:label": "rdf:18_1",
#   "_cell": 469,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibadpvz67rssphfcuk35jun2bew5jz2uleooqsd4u7knknip3qq2e"
#   },
#   "_stmt_key": "18_1",
#   "_chunk_num": 18,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [18.2]: [Albert Einstein](/wiki/Albert_Einstein) was recognized as a genius who had shattered a paradigm that had been basic to physicists' understanding of the universe since the seventeenth century.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Albert Einstein was recognized as a genius who had shattered a paradigm that had been basic to physicists' understanding of the universe since the seventeenth century." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiatzjev32n5taz33q3hncysxnqcacb2i2zognerkafxgzosv4x2y4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiatzjev32n5taz33q3hncysxnqcacb2i2zognerkafxgzosv4x2y4",
#   "prov:label": "rdf:18_2",
#   "_cell": 471,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihfb3sr5al6fn4lkdi3vllkbbqm4rlygr7l5noogtrwh2256ddrmi"
#   },
#   "_stmt_key": "18_2",
#   "_chunk_num": 18,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [18.3]: [Eddington's eclipse observations](/wiki/Eddington's_eclipse_observations) were widely reported in academic journals and by the popular press.
# <https://en.wikipedia.org/wiki/Eddington's_eclipse_observations> rdfs:comment "Eddington's eclipse observations were widely reported in academic journals and by the popular press." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigtfuizxo3h6jljumzyrzvzd7mrgyhnsfx5ya4yurdrht37mdiina",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigtfuizxo3h6jljumzyrzvzd7mrgyhnsfx5ya4yurdrht37mdiina",
#   "prov:label": "rdf:18_3",
#   "_cell": 473,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigerk4s3fkd4ehfkrhbjiv7dqchqhfzueth4fpb3tpo2j5yxmh53m"
#   },
#   "_stmt_key": "18_3",
#   "_chunk_num": 18,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [18.4]: The popular press reported on [Eddington's eclipse observations](/wiki/Eddington's_eclipse_observations) in the years 1921–1923.
# <https://en.wikipedia.org/wiki/Eddington's_eclipse_observations> rdfs:comment "The popular press reported on Eddington's eclipse observations in the years 1921–1923." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic64qbmthwbtvotvnx4pq3tohkftynweoljfmvsetorjvre4o7o54",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic64qbmthwbtvotvnx4pq3tohkftynweoljfmvsetorjvre4o7o54",
#   "prov:label": "rdf:18_4",
#   "_cell": 475,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib7xw4mezlzhr4khsuymc5sbb4tb7n2f3dw4273emool7bafhnpi4"
#   },
#   "_stmt_key": "18_4",
#   "_chunk_num": 18,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [18.5]: [Eddington's eclipse observations](/wiki/Eddington's_eclipse_observations) contributed to [Albert Einstein](/wiki/Albert_Einstein)'s recognition as a celebrity scientist.
# <https://en.wikipedia.org/wiki/Eddington's_eclipse_observations> rdfs:comment "Eddington's eclipse observations contributed to Albert Einstein's recognition as a celebrity scientist." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiccd4fa5qserylsqwmx5rrmm7l2hpicdcyqtvtgvigruq4a6qfgca",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiccd4fa5qserylsqwmx5rrmm7l2hpicdcyqtvtgvigruq4a6qfgca",
#   "prov:label": "rdf:18_5",
#   "_cell": 477,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieuuzi7zma7vwkpilcaa3rruxe7om2ka5nqkrobwseu362vgqjnuq"
#   },
#   "_stmt_key": "18_5",
#   "_chunk_num": 18,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [19.1]: [Albert Einstein](/wiki/Albert_Einstein) arrived in America on 2 April 1921.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:arrivalDate "1921-04-02"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:arrivalPlace <https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiejf2gdcxk73ezllsf7m62bppo44j5esolbaslyvushup35s3t2nu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiejf2gdcxk73ezllsf7m62bppo44j5esolbaslyvushup35s3t2nu",
#   "prov:label": "rdf:19_1",
#   "_cell": 479,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidxfsikcrtwngescx3m6xlh2nvowmjw6jyx4ziodsl7l6dikewxn4"
#   },
#   "_stmt_key": "19_1",
#   "_chunk_num": 19,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [19.2]: [Albert Einstein](/wiki/Albert_Einstein) was welcomed to New York City by Mayor [John Francis Hylan](/wiki/John_Francis_Hylan).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/John_Francis_Hylan> .
# <https://en.wikipedia.org/wiki/John_Francis_Hylan> schema:attendee <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreif4l2kll5awaeiu7urmjh5rigwgd3h447z3cyxrttwki62wo3fpyu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreif4l2kll5awaeiu7urmjh5rigwgd3h447z3cyxrttwki62wo3fpyu",
#   "prov:label": "rdf:19_2",
#   "_cell": 481,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifsw47l5ugaxnchnzh7kogzmwswydsaxhcfy423tpok6apj2yx27m"
#   },
#   "_stmt_key": "19_2",
#   "_chunk_num": 19,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [19.3]: [Albert Einstein](/wiki/Albert_Einstein) spent three weeks giving lectures and attending receptions in America.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifqfhsnqn77ngyxkgzbrzvjs267kzhupytbf2bl7dao6zy7hhvzx4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifqfhsnqn77ngyxkgzbrzvjs267kzhupytbf2bl7dao6zy7hhvzx4",
#   "prov:label": "rdf:19_3",
#   "_cell": 483,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia5wh7t4g4vf4rhnxax72qqdrf4kifl657p3jurmgaojkrjtccoyi"
#   },
#   "_stmt_key": "19_3",
#   "_chunk_num": 19,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [19.4]: [Albert Einstein](/wiki/Albert_Einstein) spoke several times at [Columbia University](/wiki/Columbia_University).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:instructor <https://en.wikipedia.org/wiki/Columbia_University> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiatx6xb3xqphfwptykqxd3svqgty7t6dy5bcraadsbptdd7izwosi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiatx6xb3xqphfwptykqxd3svqgty7t6dy5bcraadsbptdd7izwosi",
#   "prov:label": "rdf:19_4",
#   "_cell": 485,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiddbgd7bii5b63uisgb7ev5j5m7xubedresksxd7fgk6b4c2z6jey"
#   },
#   "_stmt_key": "19_4",
#   "_chunk_num": 19,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [19.5]: [Albert Einstein](/wiki/Albert_Einstein) spoke several times at [Princeton](/wiki/Princeton).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:instructor <https://en.wikipedia.org/wiki/Princeton> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaqky4i2q3jnsz2ifurpdjhqzbse3c3sn5rydmogkjkggmpqcmrre",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaqky4i2q3jnsz2ifurpdjhqzbse3c3sn5rydmogkjkggmpqcmrre",
#   "prov:label": "rdf:19_5",
#   "_cell": 487,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieiytmtuxn7s7ltavu5itsaxlqiq27s4v2pcrjkkyn2cfvnfkwk2q"
#   },
#   "_stmt_key": "19_5",
#   "_chunk_num": 19,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [19.6]: [Albert Einstein](/wiki/Albert_Einstein) visited the [White House](/wiki/White_House) in Washington with representatives of the [National Academy of Sciences](/wiki/National_Academy_of_Sciences).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/White_House> .
# <https://en.wikipedia.org/wiki/National_Academy_of_Sciences> schema:attendee <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreift5ays2isgsheru452lw7buw4ngafxbauj63dtfclkwzsszvwfne",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreift5ays2isgsheru452lw7buw4ngafxbauj63dtfclkwzsszvwfne",
#   "prov:label": "rdf:19_6",
#   "_cell": 489,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidoopcekdpd7gnutn6n6qvwm6oi2z6kqs22zesa3iwn3ucm45h5we"
#   },
#   "_stmt_key": "19_6",
#   "_chunk_num": 19,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [19.7]: [Albert Einstein](/wiki/Albert_Einstein) returned to Europe via London.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/London> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic5rx64gl4thf5ht6n34nvbjmr4r73lv6cxqqjfmwaekmqm56nuxu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic5rx64gl4thf5ht6n34nvbjmr4r73lv6cxqqjfmwaekmqm56nuxu",
#   "prov:label": "rdf:19_7",
#   "_cell": 491,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreic5km2qna6l2zwx7lpolldkw5p63mcglzfuwz7cczoth25xakmh5i"
#   },
#   "_stmt_key": "19_7",
#   "_chunk_num": 19,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [19.8]: [Albert Einstein](/wiki/Albert_Einstein) was the guest of the philosopher and statesman [Viscount Haldane](/wiki/Viscount_Haldane) in London.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/Viscount_Haldane> .
# <https://en.wikipedia.org/wiki/Viscount_Haldane> schema:attendee <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihfrw43zhne57zsoyr7lctwdatfli2cy5374f62r2zcmldei4tdqm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihfrw43zhne57zsoyr7lctwdatfli2cy5374f62r2zcmldei4tdqm",
#   "prov:label": "rdf:19_8",
#   "_cell": 493,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibfy4kyhyqgv4l7w3vlzqmm3ne6cu2sv2easxr2wrostfuc33l2mi"
#   },
#   "_stmt_key": "19_8",
#   "_chunk_num": 19,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [19.9]: [Albert Einstein](/wiki/Albert_Einstein) met several people prominent in British scientific, political, or intellectual life during his stay in London.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/London> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie46panujdc56jyslnobdewsavehtj54nlip4sl3p7n5lwylvy5l4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie46panujdc56jyslnobdewsavehtj54nlip4sl3p7n5lwylvy5l4",
#   "prov:label": "rdf:19_9",
#   "_cell": 495,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibuofu6poqy2bpwecdljmmoh6jjnhdl6p55yag7q3cgrc2qfh6myq"
#   },
#   "_stmt_key": "19_9",
#   "_chunk_num": 19,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [19.10]: [Albert Einstein](/wiki/Albert_Einstein) delivered a lecture at [King's College](/wiki/King%27s_College_London) in London.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:instructor <https://en.wikipedia.org/wiki/King%27s_College_London> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreich6ot7xlw2uv2nhzz7tqpv2njqehtmhy2moxeexztfc42znjdbkq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreich6ot7xlw2uv2nhzz7tqpv2njqehtmhy2moxeexztfc42znjdbkq",
#   "prov:label": "rdf:19_10",
#   "_cell": 497,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicanzc3urtbz7xvmhhgdzlc3cwd2e4evxcjkvs7skxs3rfelz2kim"
#   },
#   "_stmt_key": "19_10",
#   "_chunk_num": 19,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [19.11]: In July 1921, [Albert Einstein](/wiki/Albert_Einstein) published an essay titled "My First Impression of the U.S.A.".
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author <https://en.wikipedia.org/wiki/My_First_Impression_of_the_U.S.A.> .
# <https://en.wikipedia.org/wiki/My_First_Impression_of_the_U.S.A.> rdf:type schema:Article .
# <https://en.wikipedia.org/wiki/My_First_Impression_of_the_U.S.A.> schema:headline "My First Impression of the U.S.A." .
# <https://en.wikipedia.org/wiki/My_First_Impression_of_the_U.S.A.> schema:datePublished "1921-07"^^xsd:gYear .
# <https://en.wikipedia.org/wiki/My_First_Impression_of_the_U.S.A.> schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidlbtpsfebilacv73u5kxp46v2qgfenu6mdevu2ztzr6hk4wr65wu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidlbtpsfebilacv73u5kxp46v2qgfenu6mdevu2ztzr6hk4wr65wu",
#   "prov:label": "rdf:19_11",
#   "_cell": 499,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihaj2fzesd7zh25kgwzqfbzle3q6hr5l54l4iszmle6ysssuvtdli"
#   },
#   "_stmt_key": "19_11",
#   "_chunk_num": 19,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [19.12]: The essay "My First Impression of the U.S.A." sought to sketch the American character.
# <https://en.wikipedia.org/wiki/My_First_Impression_of_the_U.S.A.> schema:text "seek to sketch the American character" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiakacfphjx6oni6cgt77ckkravm5w4zdn2rg7pj34gcanbzirxdve",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiakacfphjx6oni6cgt77ckkravm5w4zdn2rg7pj34gcanbzirxdve",
#   "prov:label": "rdf:19_12",
#   "_cell": 501,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaaqywwzagvo3jzvv462o372q35fg6a6oz3iezs53zc666c2kusvy"
#   },
#   "_stmt_key": "19_12",
#   "_chunk_num": 19,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [19.13]: The essay "My First Impression of the U.S.A." was similar in style to *[Democracy in America](/wiki/Democracy_in_America)* by [Alexis de Tocqueville](/wiki/Alexis_de_Tocqueville).
# <https://en.wikipedia.org/wiki/My_First_Impression_of_the_U.S.A.> schema:citation <https://en.wikipedia.org/wiki/Democracy_in_America> .
# <https://en.wikipedia.org/wiki/Democracy_in_America> schema:creator <https://en.wikipedia.org/wiki/Alexis_de_Tocqueville> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreib4qrpcgddkmgjhacaa5fgbhs5ijcvikgz6pekg3bzpfgfkilzolq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreib4qrpcgddkmgjhacaa5fgbhs5ijcvikgz6pekg3bzpfgfkilzolq",
#   "prov:label": "rdf:19_13",
#   "_cell": 503,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihkolwi3lujxee6jeqagfeizvmuc7tkme7oq4vfjxn3vzawtzgxjm"
#   },
#   "_stmt_key": "19_13",
#   "_chunk_num": 19,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [19.14]: [Albert Einstein](/wiki/Albert_Einstein) was greeted with great enthusiasm on the last leg of his tour.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Albert Einstein was greeted with great enthusiasm on the last leg of his tour." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie5aavcdsn37yoeapgpnysb5lzxgneiz52sfdp742ycyvn3fixy2u",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie5aavcdsn37yoeapgpnysb5lzxgneiz52sfdp742ycyvn3fixy2u",
#   "prov:label": "rdf:19_14",
#   "_cell": 505,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiatrhwsl37whbb2jx7sswgsfxrwtarcub36jmeeuxh4jenrngreq4"
#   },
#   "_stmt_key": "19_14",
#   "_chunk_num": 19,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [19.15]: [Albert Einstein](/wiki/Albert_Einstein) spent twelve days in [Mandatory Palestine](/wiki/Mandatory_Palestine).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/Mandatory_Palestine> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreievsaa7yyvydpg5zsp7cf5ad5fpafutwc3je7ropobdttkt3qawau",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreievsaa7yyvydpg5zsp7cf5ad5fpafutwc3je7ropobdttkt3qawau",
#   "prov:label": "rdf:19_15",
#   "_cell": 507,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifrpxztpyjjpmehatzlsnbpnjoaz6vgopd744yyz7hcgw56tcebne"
#   },
#   "_stmt_key": "19_15",
#   "_chunk_num": 19,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [19.16]: [Mandatory Palestine](/wiki/Mandatory_Palestine) was newly entrusted to British rule by the [League of Nations](/wiki/League_of_Nations).
# <https://en.wikipedia.org/wiki/Mandatory_Palestine> schema:attendee <https://en.wikipedia.org/wiki/League_of_Nations> .
# <https://en.wikipedia.org/wiki/Mandatory_Palestine> rdfs:comment "Mandatory Palestine was newly entrusted to British rule by the League of Nations." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidr22qdgoul4sko2ih5gqsyamflzmpz3gntqbtcfa3by6tsq2erhm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidr22qdgoul4sko2ih5gqsyamflzmpz3gntqbtcfa3by6tsq2erhm",
#   "prov:label": "rdf:19_16",
#   "_cell": 509,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid6f5226ks3weudo3wd4ogibleekhxkzeo6nf4vxiheiihgyd7jxa"
#   },
#   "_stmt_key": "19_16",
#   "_chunk_num": 19,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [19.17]: [Sir Herbert Samuel](/wiki/Sir_Herbert_Samuel) was the British High Commissioner in [Mandatory Palestine](/wiki/Mandatory_Palestine).
# <https://en.wikipedia.org/wiki/Sir_Herbert_Samuel> schema:attendee <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/Sir_Herbert_Samuel> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreid7mmzm5fzl2uf5caxot3zzydveovczst4ikkruzerqoa3w4m6ypa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreid7mmzm5fzl2uf5caxot3zzydveovczst4ikkruzerqoa3w4m6ypa",
#   "prov:label": "rdf:19_17",
#   "_cell": 511,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidc36nevov7fk54vtwqym23wmw7wqkicfqplassvmurmqj5cnswnu"
#   },
#   "_stmt_key": "19_17",
#   "_chunk_num": 19,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [19.18]: [Sir Herbert Samuel](/wiki/Sir_Herbert_Samuel) welcomed [Albert Einstein](/wiki/Albert_Einstein) with a degree of ceremony normally only accorded to a visiting head of state.
# <https://en.wikipedia.org/wiki/Sir_Herbert_Samuel> schema:attendee <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/Sir_Herbert_Samuel> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihz5jf5ukpddczvc775wuol55qudzctvllrqzwpvrj2im3jf4c5lm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihz5jf5ukpddczvc775wuol55qudzctvllrqzwpvrj2im3jf4c5lm",
#   "prov:label": "rdf:19_18",
#   "_cell": 513,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidkvhpltdffrju3grpecg2wvlrxzotjngs6lh72qcmcr65dqbh2km"
#   },
#   "_stmt_key": "19_18",
#   "_chunk_num": 19,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [19.19]: [Sir Herbert Samuel](/wiki/Sir_Herbert_Samuel) gave [Albert Einstein](/wiki/Albert_Einstein) a cannon salute.
# <https://en.wikipedia.org/wiki/Sir_Herbert_Samuel> schema:attendee <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/Sir_Herbert_Samuel> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiggbjjlfftv2hi6zixz4olexkkvwiy4kcoivbn6afhrbutsoqg5ue",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiggbjjlfftv2hi6zixz4olexkkvwiy4kcoivbn6afhrbutsoqg5ue",
#   "prov:label": "rdf:19_19",
#   "_cell": 515,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiekvvw4yn3r57fhy33dmd6cvfrh37knm7ba26agybjogbwdhtf56y"
#   },
#   "_stmt_key": "19_19",
#   "_chunk_num": 19,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Statement [19.20]: One reception held in honor of [Albert Einstein](/wiki/Albert_Einstein) was stormed by people determined to hear him speak.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "One reception held in honor of Albert Einstein was stormed by people determined to hear him speak." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreictfwmp63v6utoq7jph3pljqlor63zpdtkvm4waavusrlcl5qfa7m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreictfwmp63v6utoq7jph3pljqlor63zpdtkvm4waavusrlcl5qfa7m",
#   "prov:label": "rdf:19_20",
#   "_cell": 517,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieiubf6ytgx7rlpwkq7g6xgtziv3sjengjegj3gvkwyk4xpoleqjq"
#   },
#   "_stmt_key": "19_20",
#   "_chunk_num": 19,
#   "_stmt_idx": 20
# }

# %% [raw]
# # Statement [19.21]: [Albert Einstein](/wiki/Albert_Einstein) told the people at the reception that he was happy that Jews were beginning to be recognized as a force in the world.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:text "he was happy that Jews were beginning to be recognized as a force in the world" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidsgyvasvjgpmfhaemegfjgviy2zjjdqjmtj2vibcc7bwz4bqwsby",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidsgyvasvjgpmfhaemegfjgviy2zjjdqjmtj2vibcc7bwz4bqwsby",
#   "prov:label": "rdf:19_21",
#   "_cell": 519,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreielbudrfqoctou3kcxfafvx2k3grkxwa2lklwtdyy3lkcfkv6v3iq"
#   },
#   "_stmt_key": "19_21",
#   "_chunk_num": 19,
#   "_stmt_idx": 21
# }

# %% [raw]
# # Statement [20.1]: [Albert Einstein](/wiki/Albert_Einstein) decided to tour the eastern hemisphere in 1922.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:performerIn _:s1_trip1 .
# _:s1_trip1 rdf:type schema:Trip .
# _:s1_trip1 schema:name "Tour of eastern hemisphere" .
# _:s1_trip1 schema:startDate "1922"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaplxhu4oetfzsshoya2enzt2smzwn5iblpvjfaqhpf3ywrddxpii",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaplxhu4oetfzsshoya2enzt2smzwn5iblpvjfaqhpf3ywrddxpii",
#   "prov:label": "rdf:20_1",
#   "_cell": 521,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicqsmwk6h7c5rg7sy2pg6ancf2tglb45cj75ifu7tokvan3cvu7aq"
#   },
#   "_stmt_key": "20_1",
#   "_chunk_num": 20,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [20.2]: [Albert Einstein](/wiki/Albert_Einstein) was unable to go to [Stockholm](/wiki/Stockholm) in December 1922.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee _:s2_event1 .
# _:s2_event1 rdf:type schema:Event .
# _:s2_event1 schema:name "Nobel Prize ceremony" .
# _:s2_event1 schema:startDate "1922-12"^^xsd:date .
# _:s2_event1 schema:location <https://en.wikipedia.org/wiki/Stockholm> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibjfom357wflgvkqtjhrrrfmgl6frgf4obu64qornf5smzlrwd4nu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibjfom357wflgvkqtjhrrrfmgl6frgf4obu64qornf5smzlrwd4nu",
#   "prov:label": "rdf:20_2",
#   "_cell": 523,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibsnecppza5rad3dokmzrgqm6f2tdskfmhjyemliob7t4ez66rzzq"
#   },
#   "_stmt_key": "20_2",
#   "_chunk_num": 20,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [20.3]: [Albert Einstein](/wiki/Albert_Einstein) did not participate in the Nobel Prize ceremony in December 1922.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee _:s3_event1 .
# _:s3_event1 rdf:type schema:Event .
# _:s3_event1 schema:name "Nobel Prize ceremony" .
# _:s3_event1 schema:startDate "1922-12"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihwy25ia2biwc2arxlhn44vrxd5ez4n3kedv4dxhhbineq7zwscyi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihwy25ia2biwc2arxlhn44vrxd5ez4n3kedv4dxhhbineq7zwscyi",
#   "prov:label": "rdf:20_3",
#   "_cell": 525,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreif3wvlvqoonc36idzogmkdfnbueoy3rd3hyjkgbutirctgwb64tvy"
#   },
#   "_stmt_key": "20_3",
#   "_chunk_num": 20,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [20.4]: A German diplomat represented [Albert Einstein](/wiki/Albert_Einstein) at the traditional Nobel banquet in December 1922.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "A German diplomat represented Albert Einstein at the traditional Nobel banquet in December 1922." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifuyqypmhxs4nwldnvjgkr226oo4kmokkirz6irticpiixtratwdm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifuyqypmhxs4nwldnvjgkr226oo4kmokkirz6irticpiixtratwdm",
#   "prov:label": "rdf:20_4",
#   "_cell": 527,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigigrtnm64kl3xhhpvdhjovl43r5gz3jml657bysnclzr3rmlpzna"
#   },
#   "_stmt_key": "20_4",
#   "_chunk_num": 20,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [20.5]: The German diplomat gave a speech praising [Albert Einstein](/wiki/Albert_Einstein) as a physicist and as a campaigner for peace.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "The German diplomat gave a speech praising Albert Einstein as a physicist and as a campaigner for peace." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihyw7dbw57iy4bkflv4jnmthebp7ah4nkodijinnsjh6pnybq7tse",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihyw7dbw57iy4bkflv4jnmthebp7ah4nkodijinnsjh6pnybq7tse",
#   "prov:label": "rdf:20_5",
#   "_cell": 529,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih3rt6zvjjsqgfjd6w4enwvjn6oakywica67wabymdprssdhsgxw4"
#   },
#   "_stmt_key": "20_5",
#   "_chunk_num": 20,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [20.6]: [Albert Einstein](/wiki/Albert_Einstein) undertook a two-week visit to Spain in 1923.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:performerIn _:s6_trip1 .
# _:s6_trip1 rdf:type schema:Trip .
# _:s6_trip1 schema:name "Visit to Spain" .
# _:s6_trip1 schema:startDate "1923-01"^^xsd:date .
# _:s6_trip1 schema:endDate "1923-02"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigqz7cbqwbyupzwu5uyh665aitf6isgbgfa4wmwxdc4cnj2scwp6u",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigqz7cbqwbyupzwu5uyh665aitf6isgbgfa4wmwxdc4cnj2scwp6u",
#   "prov:label": "rdf:20_6",
#   "_cell": 531,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib7325o7rtbiqg6b25gu4lzknpsdmtajxktdoelj7fm2aoio6zfv4"
#   },
#   "_stmt_key": "20_6",
#   "_chunk_num": 20,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [20.7]: [Albert Einstein](/wiki/Albert_Einstein) received membership in the Spanish Academy of Sciences during his visit to Spain in 1923.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award _:s7_award1 .
# _:s7_award1 rdf:type schema:Role .
# _:s7_award1 schema:award <https://en.wikipedia.org/wiki/Spanish_Academy_of_Sciences> .
# _:s7_award1 schema:startDate "1923"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicikqv64eltf3nfkn55zgldsvk5rjgzo6ctsctyj5fnqozartyf6i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicikqv64eltf3nfkn55zgldsvk5rjgzo6ctsctyj5fnqozartyf6i",
#   "prov:label": "rdf:20_7",
#   "_cell": 533,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifhk7sirff4vqvu4zx5stbnsf2yb42dgumcexv64a3xqj7aawy5xe"
#   },
#   "_stmt_key": "20_7",
#   "_chunk_num": 20,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [20.8]: The diploma for membership in the Spanish Academy of Sciences was handed to [Albert Einstein](/wiki/Albert_Einstein) by King [Alfonso XIII](/wiki/Alfonso_XIII).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award _:s8_award1 .
# _:s8_award1 rdf:type schema:Role .
# _:s8_award1 schema:award <https://en.wikipedia.org/wiki/Spanish_Academy_of_Sciences> .
# _:s8_award1 schema:startDate "1923"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidu5v7tactgtkmbljl55wyrmi2gavdgz7yikf5g4alef7xx6eumru",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidu5v7tactgtkmbljl55wyrmi2gavdgz7yikf5g4alef7xx6eumru",
#   "prov:label": "rdf:20_8",
#   "_cell": 535,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihervjvvxk76lc5shazo7qrbweakmlukomesw6tpmr4zlzz25z634"
#   },
#   "_stmt_key": "20_8",
#   "_chunk_num": 20,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [20.9]: During his Spanish trip in 1923, [Albert Einstein](/wiki/Albert_Einstein) met [Santiago Ramón y Cajal](/wiki/Santiago_Ram%C3%B3n_y_Cajal).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee _:s9_event1 .
# _:s9_event1 rdf:type schema:Event .
# _:s9_event1 schema:name "Meeting with Santiago Ramón y Cajal" .
# _:s9_event1 schema:startDate "1923"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibkqh7oalmjs3djqiw63p5lbvxcbrhhfuf5w4jiyrafb6npxqt3a4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibkqh7oalmjs3djqiw63p5lbvxcbrhhfuf5w4jiyrafb6npxqt3a4",
#   "prov:label": "rdf:20_9",
#   "_cell": 537,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifkngs6rhv54k7yt5622l3wkcjhj4yontbzaw4luxizcmqdwzmpcm"
#   },
#   "_stmt_key": "20_9",
#   "_chunk_num": 20,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [20.10]: [Santiago Ramón y Cajal](/wiki/Santiago_Ram%C3%B3n_y_Cajal) was a fellow Nobel laureate.
# <https://en.wikipedia.org/wiki/Santiago_Ram%C3%B3n_y_Cajal> schema:award _:s10_award1 .
# _:s10_award1 rdf:type schema:Role .
# _:s10_award1 schema:award <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics> .
# _:s10_award1 schema:startDate "1922"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibta2am3guvhpvi5cez2vviqhm5n2bwzsh3t3j4natq3nko72ay6e",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibta2am3guvhpvi5cez2vviqhm5n2bwzsh3t3j4natq3nko72ay6e",
#   "prov:label": "rdf:20_10",
#   "_cell": 539,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigi5onfsxg3h5d2jxgzgwlgonrwzdoyeesqcctfng7bvjqonbffoi"
#   },
#   "_stmt_key": "20_10",
#   "_chunk_num": 20,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [20.11]: From 1922 until 1932, [Albert Einstein](/wiki/Albert_Einstein) was a member of the Geneva-based [International Committee on Intellectual Cooperation](/wiki/International_Committee_on_Intellectual_Cooperation).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:member _:s11_role1 .
# _:s11_role1 rdf:type schema:Role .
# _:s11_role1 schema:member <https://en.wikipedia.org/wiki/International_Committee_on_Intellectual_Cooperation> .
# _:s11_role1 schema:startDate "1922"^^xsd:gYear .
# _:s11_role1 schema:endDate "1932"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihjlp6oeqvanjtvde6ql6cezymziskt5n4hh43tfhhg3b2a7tr5dq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihjlp6oeqvanjtvde6ql6cezymziskt5n4hh43tfhhg3b2a7tr5dq",
#   "prov:label": "rdf:20_11",
#   "_cell": 541,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiafdbi2um3rbcn67f4s5wu6454jajwpvyixzamahe3yyrcd4be3yy"
#   },
#   "_stmt_key": "20_11",
#   "_chunk_num": 20,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [20.12]: [Albert Einstein](/wiki/Albert_Einstein) was a member of the [League of Nations](/wiki/League_of_Nations) from 1922 until 1932.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:member _:s12_role1 .
# _:s12_role1 rdf:type schema:Role .
# _:s12_role1 schema:member <https://en.wikipedia.org/wiki/League_of_Nations> .
# _:s12_role1 schema:startDate "1922"^^xsd:gYear .
# _:s12_role1 schema:endDate "1932"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreih7o4qex4rbccwngy5cah2cmdvllbzyja2oaiwpngtgbrvwqehmri",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreih7o4qex4rbccwngy5cah2cmdvllbzyja2oaiwpngtgbrvwqehmri",
#   "prov:label": "rdf:20_12",
#   "_cell": 543,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibhoih34gpvuskpyxcalupo3doi5af3tykscieixyt3an5jh5hc7m"
#   },
#   "_stmt_key": "20_12",
#   "_chunk_num": 20,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [20.13]: [Albert Einstein](/wiki/Albert_Einstein) was a member of the [International Committee on Intellectual Cooperation](/wiki/International_Committee_on_Intellectual_Cooperation) for most of the period from 1922 to 1932.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:member _:s13_role1 .
# _:s13_role1 rdf:type schema:Role .
# _:s13_role1 schema:member <https://en.wikipedia.org/wiki/International_Committee_on_Intellectual_Cooperation> .
# _:s13_role1 schema:startDate "1922"^^xsd:gYear .
# _:s13_role1 schema:endDate "1932"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiggppivo5h7lar4hta2fxhashndovekqbmszpclhzjmwgxjivwkgi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiggppivo5h7lar4hta2fxhashndovekqbmszpclhzjmwgxjivwkgi",
#   "prov:label": "rdf:20_13",
#   "_cell": 545,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidl725wh6kbcvf772cpzz323zz7ixtx3f2tz3bs3bi5qftep3lnsq"
#   },
#   "_stmt_key": "20_13",
#   "_chunk_num": 20,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [20.14]: [Albert Einstein](/wiki/Albert_Einstein) was a member of the [International Committee on Intellectual Cooperation](/wiki/International_Committee_on_Intellectual_Cooperation) in the years 1923 and 1924.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:member _:s14_role1 .
# _:s14_role1 rdf:type schema:Role .
# _:s14_role1 schema:member <https://en.wikipedia.org/wiki/International_Committee_on_Intellectual_Cooperation> .
# _:s14_role1 schema:startDate "1923"^^xsd:gYear .
# _:s14_role1 schema:endDate "1924"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihs7g4cajcdj6gqydhvaxdvvmhrmabwt6sct6qd3ahgs2bbjxrnsy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihs7g4cajcdj6gqydhvaxdvvmhrmabwt6sct6qd3ahgs2bbjxrnsy",
#   "prov:label": "rdf:20_14",
#   "_cell": 547,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicbynsbuwmvpy3wc5hg6l3tkcwiqrpvquv36d3ht7h3rzxbgghod4"
#   },
#   "_stmt_key": "20_14",
#   "_chunk_num": 20,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [20.15]: The [International Committee on Intellectual Cooperation](/wiki/International_Committee_on_Intellectual_Cooperation) was set up by the [League of Nations](/wiki/League_of_Nations).
# <https://en.wikipedia.org/wiki/International_Committee_on_Intellectual_Cooperation> schema:foundingMember _:s15_role1 .
# _:s15_role1 rdf:type schema:Role .
# _:s15_role1 schema:member <https://en.wikipedia.org/wiki/League_of_Nations> .
# _:s15_role1 schema:startDate "1922"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibodf24tekt3g2feqpo75nkwxihtueyepdjoe7p3zqd7y7i5hklm4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibodf24tekt3g2feqpo75nkwxihtueyepdjoe7p3zqd7y7i5hklm4",
#   "prov:label": "rdf:20_15",
#   "_cell": 549,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiemabltiw5vvt3btv3oq2ajau4aez5putgdcoxv7rox6e3cwvx3ma"
#   },
#   "_stmt_key": "20_15",
#   "_chunk_num": 20,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [20.16]: The [International Committee on Intellectual Cooperation](/wiki/International_Committee_on_Intellectual_Cooperation) encouraged scientists, artists, scholars, teachers, and other people engaged in the life of the mind to collaborate internationally.
# <https://en.wikipedia.org/wiki/International_Committee_on_Intellectual_Cooperation> rdfs:comment "The International Committee on Intellectual Cooperation encouraged scientists, artists, scholars, teachers, and other people engaged in the life of the mind to collaborate internationally." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreif7rd2g55omi3pclavjmm7z5j6tq6x3k4o5rjrcn7w5qzf66zuvge",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreif7rd2g55omi3pclavjmm7z5j6tq6x3k4o5rjrcn7w5qzf66zuvge",
#   "prov:label": "rdf:20_16",
#   "_cell": 551,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreic6oqw7ap4xhf73uopvsfhfdedn7ajx4oi2qhpzxk3iobppsb7lse"
#   },
#   "_stmt_key": "20_16",
#   "_chunk_num": 20,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [20.17]: In March and April 1925, [Albert Einstein](/wiki/Albert_Einstein) and his wife visited South America.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:performerIn _:s17_trip1 .
# _:s17_trip1 rdf:type schema:Trip .
# _:s17_trip1 schema:name "South American tour" .
# _:s17_trip1 schema:startDate "1925-03"^^xsd:date .
# _:s17_trip1 schema:endDate "1925-04"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "In March and April 1925, Albert Einstein and his wife visited South America." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifzzm6fktl6mlgrbn6xcluuq6ufcflb4flluldxx6f3mafchrbwnu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifzzm6fktl6mlgrbn6xcluuq6ufcflb4flluldxx6f3mafchrbwnu",
#   "prov:label": "rdf:20_17",
#   "_cell": 553,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibb3e4to7nk7j7psjdjw5shvzmgcswxi732oey4letqwtmoslhy54"
#   },
#   "_stmt_key": "20_17",
#   "_chunk_num": 20,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [20.18]: During their South American tour in 1925, [Albert Einstein](/wiki/Albert_Einstein) and his wife spent about a week in Brazil.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:performerIn _:s18_trip1 .
# _:s18_trip1 rdf:type schema:Trip .
# _:s18_trip1 schema:name "Visit to Brazil" .
# _:s18_trip1 schema:startDate "1925-03"^^xsd:date .
# _:s18_trip1 schema:endDate "1925-04"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreictrchuel37dw7joistxoqbyklcoqiqaa2yow6mefwqpw4tufm7oq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreictrchuel37dw7joistxoqbyklcoqiqaa2yow6mefwqpw4tufm7oq",
#   "prov:label": "rdf:20_18",
#   "_cell": 555,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiapp7tcsda42djuykr2pclguhrenrs5feaxqw2hpnitjfwx3g2cze"
#   },
#   "_stmt_key": "20_18",
#   "_chunk_num": 20,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [20.19]: During their South American tour in 1925, [Albert Einstein](/wiki/Albert_Einstein) and his wife spent a week in Uruguay.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:performerIn _:s19_trip1 .
# _:s19_trip1 rdf:type schema:Trip .
# _:s19_trip1 schema:name "Visit to Uruguay" .
# _:s19_trip1 schema:startDate "1925-03"^^xsd:date .
# _:s19_trip1 schema:endDate "1925-04"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihxc4qqcsun3ajmrzcgyaf65s3wrfkl4brh7f2fl5uvsydygu3wsq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihxc4qqcsun3ajmrzcgyaf65s3wrfkl4brh7f2fl5uvsydygu3wsq",
#   "prov:label": "rdf:20_19",
#   "_cell": 557,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifzrux5pe7cvhz5izjq2ib2azpe5nc5ixbhzgoqq6bfn23ovlddiu"
#   },
#   "_stmt_key": "20_19",
#   "_chunk_num": 20,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Statement [20.20]: During their South American tour in 1925, [Albert Einstein](/wiki/Albert_Einstein) and his wife spent a month in Argentina.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:performerIn _:s20_trip1 .
# _:s20_trip1 rdf:type schema:Trip .
# _:s20_trip1 schema:name "Visit to Argentina" .
# _:s20_trip1 schema:startDate "1925-03"^^xsd:date .
# _:s20_trip1 schema:endDate "1925-04"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie4c4urkd2sl7xwnnqhx7voq5zufvtocaaxjfnd5g64ehah7mqml4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie4c4urkd2sl7xwnnqhx7voq5zufvtocaaxjfnd5g64ehah7mqml4",
#   "prov:label": "rdf:20_20",
#   "_cell": 559,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiepn7rkefjfeaqptwcf6pkcrnesevcocoqczxh6wphdefjhbag7xa"
#   },
#   "_stmt_key": "20_20",
#   "_chunk_num": 20,
#   "_stmt_idx": 20
# }

# %% [raw]
# # Statement [20.21]: [Albert Einstein](/wiki/Albert_Einstein)'s South American tour in 1925 was suggested by Jorge Duclout.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:contributor _:s21_role1 .
# _:s21_role1 rdf:type schema:Role .
# _:s21_role1 schema:contributor <https://en.wikipedia.org/wiki/Jorge_Duclout> .
# _:s21_role1 schema:startDate "1925"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihfsx6evzbzyat2a7a3ygyh6g4yuaq5lxhgur7nxi65rnyfyuaivq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihfsx6evzbzyat2a7a3ygyh6g4yuaq5lxhgur7nxi65rnyfyuaivq",
#   "prov:label": "rdf:20_21",
#   "_cell": 561,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiegnvppuu4wpyfmr2yui46oairtkdpfkrqu2ekxhvnvykindx2xlm"
#   },
#   "_stmt_key": "20_21",
#   "_chunk_num": 20,
#   "_stmt_idx": 21
# }

# %% [raw]
# # Statement [20.22]: [Albert Einstein](/wiki/Albert_Einstein)'s South American tour in 1925 was suggested by Mauricio Nirenstein.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:contributor _:s22_role1 .
# _:s22_role1 rdf:type schema:Role .
# _:s22_role1 schema:contributor <https://en.wikipedia.org/wiki/Mauricio_Nirenstein> .
# _:s22_role1 schema:startDate "1925"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigahb3xyl6olvd4yt6pev46hzv463dh5p2rbagwrciqsua7muxnie",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigahb3xyl6olvd4yt6pev46hzv463dh5p2rbagwrciqsua7muxnie",
#   "prov:label": "rdf:20_22",
#   "_cell": 563,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreied536rncyyqq3smo365zoqkdatrujtdrlgfn2nmlrm74ib5nn4nq"
#   },
#   "_stmt_key": "20_22",
#   "_chunk_num": 20,
#   "_stmt_idx": 22
# }

# %% [raw]
# # Statement [20.23]: Jorge Duclout lived from 1856 to 1927.
# <https://en.wikipedia.org/wiki/Jorge_Duclout> schema:birthDate "1856"^^xsd:gYear .
# <https://en.wikipedia.org/wiki/Jorge_Duclout> schema:deathDate "1927"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihnpqijxgfj4f7cva4g7u5q2uubdeoknzmhr6vuery2re63dkkk5u",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihnpqijxgfj4f7cva4g7u5q2uubdeoknzmhr6vuery2re63dkkk5u",
#   "prov:label": "rdf:20_23",
#   "_cell": 565,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiber3r3jhkikbaalzd32q5hiui73ondvbjrg3i7ileeomjcbk4anm"
#   },
#   "_stmt_key": "20_23",
#   "_chunk_num": 20,
#   "_stmt_idx": 23
# }

# %% [raw]
# # Statement [20.24]: Mauricio Nirenstein lived from 1877 to 1935.
# <https://en.wikipedia.org/wiki/Mauricio_Nirenstein> schema:birthDate "1877"^^xsd:gYear .
# <https://en.wikipedia.org/wiki/Mauricio_Nirenstein> schema:deathDate "1935"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibuvut24yigthdwem3skkhrpifcpevhlwysmulje7rlaspfndwcse",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibuvut24yigthdwem3skkhrpifcpevhlwysmulje7rlaspfndwcse",
#   "prov:label": "rdf:20_24",
#   "_cell": 567,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiades5rnnpr6xzlyns46kyn5hhvxmg3ltpifj2qxhuzheieuu4iem"
#   },
#   "_stmt_key": "20_24",
#   "_chunk_num": 20,
#   "_stmt_idx": 24
# }

# %% [raw]
# # Statement [20.25]: [Albert Einstein](/wiki/Albert_Einstein)'s South American tour in 1925 was supported by several Argentine scholars.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:contributor _:s25_role1 .
# _:s25_role1 rdf:type schema:Role .
# _:s25_role1 schema:contributor <https://en.wikipedia.org/wiki/University_of_Buenos_Aires> .
# _:s25_role1 schema:startDate "1925"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia3nsaap3utqqqui7du4xog3n5puk2j2m4l7hzap4upaoikx4gvau",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia3nsaap3utqqqui7du4xog3n5puk2j2m4l7hzap4upaoikx4gvau",
#   "prov:label": "rdf:20_25",
#   "_cell": 569,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidh66znhi5sejzqfudzo7wcirxpulyhx4xecbczx6dzch2oxyzyjy"
#   },
#   "_stmt_key": "20_25",
#   "_chunk_num": 20,
#   "_stmt_idx": 25
# }

# %% [raw]
# # Statement [20.26]: [Albert Einstein](/wiki/Albert_Einstein)'s South American tour in 1925 was supported by [Julio Rey Pastor](/wiki/Julio_Rey_Pastor).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:contributor _:s26_role1 .
# _:s26_role1 rdf:type schema:Role .
# _:s26_role1 schema:contributor <https://en.wikipedia.org/wiki/Julio_Rey_Pastor> .
# _:s26_role1 schema:startDate "1925"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigrue4ccu2uj3ivsor2cgffsbar3gxu37dt3zih27g5hp2p7yt3wi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigrue4ccu2uj3ivsor2cgffsbar3gxu37dt3zih27g5hp2p7yt3wi",
#   "prov:label": "rdf:20_26",
#   "_cell": 571,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibbqt7nkgvl2iaub5yrhxs6evc2mm5vbtw4potpf3cccgaax2b4ya"
#   },
#   "_stmt_key": "20_26",
#   "_chunk_num": 20,
#   "_stmt_idx": 26
# }

# %% [raw]
# # Statement [20.27]: [Albert Einstein](/wiki/Albert_Einstein)'s South American tour in 1925 was supported by [Jakob Laub](/wiki/Jakob_Laub).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:contributor _:s27_role1 .
# _:s27_role1 rdf:type schema:Role .
# _:s27_role1 schema:contributor <https://en.wikipedia.org/wiki/Jakob_Laub> .
# _:s27_role1 schema:startDate "1925"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic4diui5cu2kbdsfwducpcrbla5soxgcscblgpacrewiwomvkioom",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic4diui5cu2kbdsfwducpcrbla5soxgcscblgpacrewiwomvkioom",
#   "prov:label": "rdf:20_27",
#   "_cell": 573,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigiktydea5scs4rgmenqrwqsvndmfqedqoh4x7cikqlpoxuv3lji4"
#   },
#   "_stmt_key": "20_27",
#   "_chunk_num": 20,
#   "_stmt_idx": 27
# }

# %% [raw]
# # Statement [20.28]: [Albert Einstein](/wiki/Albert_Einstein)'s South American tour in 1925 was supported by [Leopoldo Lugones](/wiki/Leopoldo_Lugones).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:contributor _:s28_role1 .
# _:s28_role1 rdf:type schema:Role .
# _:s28_role1 schema:contributor <https://en.wikipedia.org/wiki/Leopoldo_Lugones> .
# _:s28_role1 schema:startDate "1925"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreid4p63ghmjblbzgiohzvwei5htl6mca6ugdkavsqjrp3vrsrauvqe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreid4p63ghmjblbzgiohzvwei5htl6mca6ugdkavsqjrp3vrsrauvqe",
#   "prov:label": "rdf:20_28",
#   "_cell": 575,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaidcg5upxuxzkwrv5gkuewdsaogpi7witkksiyggv3r3uaorlj7m"
#   },
#   "_stmt_key": "20_28",
#   "_chunk_num": 20,
#   "_stmt_idx": 28
# }

# %% [raw]
# # Statement [20.29]: [Albert Einstein](/wiki/Albert_Einstein)'s South American tour in 1925 was financed primarily by the Council of the [University of Buenos Aires](/wiki/University_of_Buenos_Aires).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:contributor _:s29_role1 .
# _:s29_role1 rdf:type schema:Role .
# _:s29_role1 schema:contributor <https://en.wikipedia.org/wiki/University_of_Buenos_Aires> .
# _:s29_role1 schema:startDate "1925"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigsh35odn7kc4vjld726ns3q5j7rif6mua6sfdij3r446tlov4yju",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigsh35odn7kc4vjld726ns3q5j7rif6mua6sfdij3r446tlov4yju",
#   "prov:label": "rdf:20_29",
#   "_cell": 577,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicj7wbtafibkuyhrqr5i5zqfmmonp4gqtfag27k3pxl4okskaj7g4"
#   },
#   "_stmt_key": "20_29",
#   "_chunk_num": 20,
#   "_stmt_idx": 29
# }

# %% [raw]
# # Statement [20.30]: [Albert Einstein](/wiki/Albert_Einstein)'s South American tour in 1925 was financed by the *Asociación Hebraica Argentina*.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:contributor _:s30_role1 .
# _:s30_role1 rdf:type schema:Role .
# _:s30_role1 schema:contributor <https://en.wikipedia.org/wiki/Asociaci%C3%B3n_Hebraica_Argentina> .
# _:s30_role1 schema:startDate "1925"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiak2vnywf6s77myc2jj3xtbnmk4qolegjlufzaeauldw4gbhkm7wa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiak2vnywf6s77myc2jj3xtbnmk4qolegjlufzaeauldw4gbhkm7wa",
#   "prov:label": "rdf:20_30",
#   "_cell": 579,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreign5nmj32rm3fgaj4d5nlfochgkp7ilmgwkwgieuvzohcdum544wm"
#   },
#   "_stmt_key": "20_30",
#   "_chunk_num": 20,
#   "_stmt_idx": 30
# }

# %% [raw]
# # Statement [20.31]: [Albert Einstein](/wiki/Albert_Einstein)'s South American tour in 1925 received a smaller contribution from the Argentine-Germanic Cultural Institution.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:contributor _:s31_role1 .
# _:s31_role1 rdf:type schema:Role .
# _:s31_role1 schema:contributor <https://en.wikipedia.org/wiki/Argentine-Germanic_Cultural_Institution> .
# _:s31_role1 schema:startDate "1925"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiatfjz3boyelfgnni3qvytnzq4udihsnitlsgczv3x7kbjkgpslui",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiatfjz3boyelfgnni3qvytnzq4udihsnitlsgczv3x7kbjkgpslui",
#   "prov:label": "rdf:20_31",
#   "_cell": 581,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifr3tnbugxqviytrflwcko3oojrkxlvtuvvv236qhcwfio3g5yn7q"
#   },
#   "_stmt_key": "20_31",
#   "_chunk_num": 20,
#   "_stmt_idx": 31
# }

# %% [raw]
# # Statement [21.1]: In December 1930, [Albert Einstein](/wiki/Albert_Einstein) began a significant sojourn in the [United States](/wiki/Citizenship_of_the_United_States).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:trip _:s1_trip1 .
# _:s1_trip1 rdf:type schema:TouristTrip .
# _:s1_trip1 schema:touristDestination <https://en.wikipedia.org/wiki/Citizenship_of_the_United_States> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigw45syvpt6uppkmd6fav2ymn2g5cki6em5hbnichui34iganavpy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigw45syvpt6uppkmd6fav2ymn2g5cki6em5hbnichui34iganavpy",
#   "prov:label": "rdf:21_1",
#   "_cell": 583,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibybe63zash2xswn2d6h4d3chijkwel74yzp53tsy3m7fbbdslff4"
#   },
#   "_stmt_key": "21_1",
#   "_chunk_num": 21,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [21.2]: Einstein was offered a two-month research fellowship at the [California Institute of Technology](/wiki/California_Institute_of_Technology) in December 1930.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award _:s2_role1 .
# _:s2_role1 rdf:type schema:Role .
# _:s2_role1 schema:award <https://en.wikipedia.org/wiki/California_Institute_of_Technology> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiafr44xbpaufa6q5pcav4tl55zgpsg6aoj4mh6a6ojk3xj5nlxkzq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiafr44xbpaufa6q5pcav4tl55zgpsg6aoj4mh6a6ojk3xj5nlxkzq",
#   "prov:label": "rdf:21_2",
#   "_cell": 585,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiau6n6jzaoa5ooydsdcqaxcm2fsf2lb57gdtruegklrqm5f3lnryu"
#   },
#   "_stmt_key": "21_2",
#   "_chunk_num": 21,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [21.3]: [Caltech](/wiki/California_Institute_of_Technology) supported [Albert Einstein](/wiki/Albert_Einstein) in his wish to avoid media attention.
# <https://en.wikipedia.org/wiki/California_Institute_of_Technology> schema:affiliation <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihfr3udadqb5dusugpgksgb7xjwuvpsu7zrdwftb5frrhktfufrse",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihfr3udadqb5dusugpgksgb7xjwuvpsu7zrdwftb5frrhktfufrse",
#   "prov:label": "rdf:21_3",
#   "_cell": 587,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiczohr77bat7hv6t6g2jouuptcjndmdrywo7jctxxkxz3jjk4dmkm"
#   },
#   "_stmt_key": "21_3",
#   "_chunk_num": 21,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [21.4]: [Albert Einstein](/wiki/Albert_Einstein) declined invitations to receive prizes or make speeches during his 1930 visit to the [United States](/wiki/Citizenship_of_the_United_States).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award _:s4_role1 .
# _:s4_role1 rdf:type schema:Role .
# _:s4_role1 schema:award <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibhmi55ejv5e6ukh7qaq5iahud27742g3yak3qsicuboxxy335zt4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibhmi55ejv5e6ukh7qaq5iahud27742g3yak3qsicuboxxy335zt4",
#   "prov:label": "rdf:21_4",
#   "_cell": 589,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibuqqq2wyxlfokniy2nvxjliajkydponjw27ksix4uvnlr4xtjcfq"
#   },
#   "_stmt_key": "21_4",
#   "_chunk_num": 21,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [21.5]: [Albert Einstein](/wiki/Albert_Einstein) agreed to spend some time with his fans during his 1930 visit.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendees _:s5_role1 .
# _:s5_role1 rdf:type schema:Role .
# _:s5_role1 schema:attendees <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic7ln3iickxx55s3wb2nih4ieendpkdpp26ggnvswokedfznjo2ji",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic7ln3iickxx55s3wb2nih4ieendpkdpp26ggnvswokedfznjo2ji",
#   "prov:label": "rdf:21_5",
#   "_cell": 591,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifiyiwkjobeqs4h5viucm5qllnwidk65uxllhkmafmftimjpopsjq"
#   },
#   "_stmt_key": "21_5",
#   "_chunk_num": 21,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [21.6]: [Albert Einstein](/wiki/Albert_Einstein) arrived in [New York City](/wiki/New_York_City) in December 1930.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:arrivalTime "1930-12"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:arrivalPlace <https://en.wikipedia.org/wiki/New_York_City> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicoga7wtjzsd7oq2soyn5ffh4utzdapwn2e26mzahkrcj23dyfyiu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicoga7wtjzsd7oq2soyn5ffh4utzdapwn2e26mzahkrcj23dyfyiu",
#   "prov:label": "rdf:21_6",
#   "_cell": 593,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifqkuy4jthtpky2xp7ysalgwrdwddjuv4g7oszmrbobu5mbgwmtce"
#   },
#   "_stmt_key": "21_6",
#   "_chunk_num": 21,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [21.7]: After arriving in [New York City](/wiki/New_York_City), [Albert Einstein](/wiki/Albert_Einstein) visited [Chinatown](/wiki/Chinatown%2C_Manhattan).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendees _:s7_role1 .
# _:s7_role1 rdf:type schema:Role .
# _:s7_role1 schema:attendees <https://en.wikipedia.org/wiki/Chinatown> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicvuqq24hh3lhvuyyc2a6cqhopx4qznoglwjbk7dyqm7nii3fofua",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicvuqq24hh3lhvuyyc2a6cqhopx4qznoglwjbk7dyqm7nii3fofua",
#   "prov:label": "rdf:21_7",
#   "_cell": 595,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiebududysurbi5awvqfonh4gtpjafh3c6l6qtokcnrzf5hlj4i6zi"
#   },
#   "_stmt_key": "21_7",
#   "_chunk_num": 21,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [21.8]: [Albert Einstein](/wiki/Albert_Einstein) had lunch with the editors of *The New York Times* in December 1930.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendees _:s8_role1 .
# _:s8_role1 rdf:type schema:Role .
# _:s8_role1 schema:attendees <https://en.wikipedia.org/wiki/The_New_York_Times> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidwacr2xatiyzplbr6evm4ytrz3qkchnotawd4a7odllrmscwopgm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidwacr2xatiyzplbr6evm4ytrz3qkchnotawd4a7odllrmscwopgm",
#   "prov:label": "rdf:21_8",
#   "_cell": 597,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiccerkzgqci2tznwcfx3mssdd3mggua5dhebc2eka53vncpfv4iz4"
#   },
#   "_stmt_key": "21_8",
#   "_chunk_num": 21,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [21.9]: [Albert Einstein](/wiki/Albert_Einstein) attended a performance of *[Carmen](/wiki/Carmen)* at the [Metropolitan Opera](/wiki/Metropolitan_Opera) in December 1930.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendees _:s9_role1 .
# _:s9_role1 rdf:type schema:Role .
# _:s9_role1 schema:attendees <https://en.wikipedia.org/wiki/Metropolitan_Opera> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia7vme4sv52uneg2webki3j4mjahmze5cmcukqt5kor2byuw54elu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia7vme4sv52uneg2webki3j4mjahmze5cmcukqt5kor2byuw54elu",
#   "prov:label": "rdf:21_9",
#   "_cell": 599,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigyvqlg7mkxn7agvdlr5uhpwuvwbaj2kl7ko7ohknmz2jvjpz4n2u"
#   },
#   "_stmt_key": "21_9",
#   "_chunk_num": 21,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [21.10]: [Albert Einstein](/wiki/Albert_Einstein) was cheered by the audience at the [Metropolitan Opera](/wiki/Metropolitan_Opera) upon his arrival in December 1930.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendees _:s10_role1 .
# _:s10_role1 rdf:type schema:Role .
# _:s10_role1 schema:attendees <https://en.wikipedia.org/wiki/Metropolitan_Opera> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie56v2ao4upvg5lnj4332mp6e2jehh75snvh4lw6yb7edox7fozrm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie56v2ao4upvg5lnj4332mp6e2jehh75snvh4lw6yb7edox7fozrm",
#   "prov:label": "rdf:21_10",
#   "_cell": 601,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreif2v6z5wne5bv4bcfxjdtvuilnkhbvpclwofwohsgqwphltfb4lhu"
#   },
#   "_stmt_key": "21_10",
#   "_chunk_num": 21,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [21.11]: [Mayor Jimmy Walker](/wiki/Jimmy_Walker) gave [Albert Einstein](/wiki/Albert_Einstein) the keys to the city in December 1930.
# <https://en.wikipedia.org/wiki/Jimmy_Walker> schema:award _:s11_role1 .
# _:s11_role1 rdf:type schema:Role .
# _:s11_role1 schema:award <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic3qvlbbbqxlayla2anlcger3rolrgxxxo4xj4x5lxrnbb2u2fofy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic3qvlbbbqxlayla2anlcger3rolrgxxxo4xj4x5lxrnbb2u2fofy",
#   "prov:label": "rdf:21_11",
#   "_cell": 603,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibu3py4lh7sb3gd3vyzqpeu5a7psm2c2lirfhyy7pb7obimzj6xo4"
#   },
#   "_stmt_key": "21_11",
#   "_chunk_num": 21,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [21.12]: [Albert Einstein](/wiki/Albert_Einstein) met [Nicholas Murray Butler](/wiki/Nicholas_Murray_Butler), the president of [Columbia University](/wiki/Columbia_University), in December 1930.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:colleague <https://en.wikipedia.org/wiki/Nicholas_Murray_Butler> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiclvn2xiswuynx5arxnmtue7xckyspo3nkmc4u2pq6nzafv3tkzby",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiclvn2xiswuynx5arxnmtue7xckyspo3nkmc4u2pq6nzafv3tkzby",
#   "prov:label": "rdf:21_12",
#   "_cell": 605,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigwlkslsh4dj3ok3t7jsvtzaizfl3f2ogsw63vumxze4rj4pe3f7q"
#   },
#   "_stmt_key": "21_12",
#   "_chunk_num": 21,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [21.13]: [Nicholas Murray Butler](/wiki/Nicholas_Murray_Butler) described [Albert Einstein](/wiki/Albert_Einstein) as "the ruling monarch of the mind" in December 1930.
# <https://en.wikipedia.org/wiki/Nicholas_Murray_Butler> schema:award _:s13_role1 .
# _:s13_role1 rdf:type schema:Role .
# _:s13_role1 schema:award <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigfhhw2qnsf3a4t7fhlqvna4gjpzo43hskqwpkirceptsdlreznea",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigfhhw2qnsf3a4t7fhlqvna4gjpzo43hskqwpkirceptsdlreznea",
#   "prov:label": "rdf:21_13",
#   "_cell": 607,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibp3c5g3og542zjnqmudj4ips5luyzwuwi7masj645phgz5ztkgou"
#   },
#   "_stmt_key": "21_13",
#   "_chunk_num": 21,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [21.14]: [Harry Emerson Fosdick](/wiki/Harry_Emerson_Fosdick), pastor at [Riverside Church](/wiki/Riverside_Church), gave [Albert Einstein](/wiki/Albert_Einstein) a tour of the church in December 1930.
# <https://en.wikipedia.org/wiki/Harry_Emerson_Fosdick> schema:award _:s14_role1 .
# _:s14_role1 rdf:type schema:Role .
# _:s14_role1 schema:award <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigfm2nllsye65a7atzx3zn7jtmqnqvkhko75aekacpkjgidaomaky",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigfm2nllsye65a7atzx3zn7jtmqnqvkhko75aekacpkjgidaomaky",
#   "prov:label": "rdf:21_14",
#   "_cell": 609,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibdasctqrql2zylotiy4uw5tar7ajje4vuefds26aumezryciyoei"
#   },
#   "_stmt_key": "21_14",
#   "_chunk_num": 21,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [21.15]: [Riverside Church](/wiki/Riverside_Church) had a full-size statue of [Albert Einstein](/wiki/Albert_Einstein) at its entrance.
# <https://en.wikipedia.org/wiki/Riverside_Church> schema:affiliation <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie4tg5gzv6zllluaneb5zml4yupdravsuhj3ty3f7oq2c67jkxgda",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie4tg5gzv6zllluaneb5zml4yupdravsuhj3ty3f7oq2c67jkxgda",
#   "prov:label": "rdf:21_15",
#   "_cell": 611,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiacxca3wmdbe7dpizfbrzl7iixj5xs5jyzat3ab2st2e3lyndu3pq"
#   },
#   "_stmt_key": "21_15",
#   "_chunk_num": 21,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [21.16]: [Albert Einstein](/wiki/Albert_Einstein) joined a crowd of 15,000 people at [Madison Square Garden](/wiki/Madison_Square_Garden_%281925%29) during a [Hanukkah](/wiki/Hanukkah) celebration in December 1930.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendees _:s16_role1 .
# _:s16_role1 rdf:type schema:Role .
# _:s16_role1 schema:attendees <https://en.wikipedia.org/wiki/Madison_Square_Garden_%281925%29> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifbbizi7nd23nsg5cg4yf3aeuicoeedhxfycza2ntu2tdwehrfaza",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifbbizi7nd23nsg5cg4yf3aeuicoeedhxfycza2ntu2tdwehrfaza",
#   "prov:label": "rdf:21_16",
#   "_cell": 613,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreignox7bjkzxpcgaag5spjhe3mgzy25n63mkggeadx5unwu6kdqkke"
#   },
#   "_stmt_key": "21_16",
#   "_chunk_num": 21,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Chunk 22 Error: APITimeoutError: Request timed out.
# #
# # === FULL PROMPT SENT TO LLM ===
# #
# # SYSTEM PROMPT:
# # You are an expert at converting factual statements to RDF triples.
# #
# # The statements contain markdown links like [Entity Name](/wiki/Entity_Name) that provide Wikipedia URIs for entities.
# # Convert these to proper RDF URIs using: <https://en.wikipedia.org/wiki/Entity_Name>
# #
# # You have access to these tools:
# #
# # LOOKUP TOOLS (use first to find correct vocabulary):
# # - find_rdf_class: Find the best schema.org class/type for an entity
# # - find_rdf_property: Find the best predicate for a relationship
# #
# # OUTPUT TOOLS (use to emit your triples - MUST include statement_id):
# # - emit_triple: Output a single triple with statement_id
# # - emit_triples: Output multiple triples at once (more efficient)
# #
# # WORKFLOW:
# # 1. For each statement, identify what kind of fact it is (quote, employment, education, award, relationship, etc.)
# # 2. Use find_rdf_class and find_rdf_property with DESCRIPTIVE queries to find appropriate schema.org terms
# # 3. ONLY use schema matches with score >= 0.5. If no good match, skip or use rdfs:comment.
# # 4. Use emit_triple or emit_triples to output RDF triples, INCLUDING the statement_id
# #
# # QUERYING THE SCHEMA TOOLS:
# # Use descriptive natural language, not just keywords. Include:
# # - What the thing IS (for classes) or what relationship it represents (for properties)
# # - Context about domain/range when known
# #
# # GOOD QUERIES:
# # - find_rdf_class("a spoken or written quotation attributed to someone") → Quotation
# # - find_rdf_class("an organization that educates students like a university") → EducationalOrganization
# # - find_rdf_property("the text content of a quote", subject_type="Quotation") → text
# # - find_rdf_property("who said or authored a quotation", subject_type="Quotation") → creator, spokenByCharacter
# # - find_rdf_property("schools someone attended as a student", subject_type="Person") → alumniOf
# #
# # BAD QUERIES (too vague):
# # - find_rdf_class("quote") - missing context
# # - find_rdf_property("said") - doesn't explain the relationship
# # - find_rdf_property("school") - is it attended? works at? type of?
# #
# # URI RULES:
# # - For entities with Wikipedia links like [Albert Einstein](/wiki/Albert_Einstein):
# #   Use: <https://en.wikipedia.org/wiki/Albert_Einstein>
# # - For entities in the Entity Registry: Use their provided URI
# # - For new entities not in either: Use fragment URIs like <#entity_name>
# # - NEVER invent Wikidata URIs (wd:Q...) unless explicitly provided
# #
# # BLANK NODE NAMING:
# # Use the statement ID in blank node names to ensure uniqueness across chunks:
# #   - For statement [3.5], use: _:s3_5_role1, _:s3_5_role2, etc.
# #   - NOT just _:pos1, _:pos2 (these collide across statements)
# #
# # MODELING PATTERNS:
# #
# # 1. QUOTATIONS (when someone said/stated/objected something):
# #    Create a Quotation instance with text and attribution:
# #    _:s1_quote1 a schema:Quotation .
# #    _:s1_quote1 schema:text "The actual quote text" .
# #    _:s1_quote1 schema:creator <wiki:Person_Who_Said_It> .
# #
# # 2. TEMPORAL/QUALIFIED RELATIONSHIPS (dates on relationships):
# #    Use an intermediate Role node (schema.org Role pattern):
# #
# #    Example - Employment: "Einstein worked at University of Zurich from 1909 to 1911"
# #      <wiki:Albert_Einstein> schema:worksFor _:s1_role1 .
# #      _:s1_role1 a schema:OrganizationRole .
# #      _:s1_role1 schema:worksFor <wiki:University_of_Zurich> .
# #      _:s1_role1 schema:startDate "1909"^^xsd:gYear .
# #      _:s1_role1 schema:endDate "1911"^^xsd:gYear .
# #
# #    Example - Awards: "Einstein received the Nobel Prize in 1921"
# #      <wiki:Albert_Einstein> schema:award _:s2_award1 .
# #      _:s2_award1 a schema:Role .
# #      _:s2_award1 schema:award <wiki:Nobel_Prize_in_Physics> .
# #      _:s2_award1 schema:startDate "1921"^^xsd:gYear .
# #
# #    Example - Education: "Einstein attended University of Zurich from 1896 to 1900"
# #      <wiki:Albert_Einstein> schema:alumniOf _:s3_edu1 .
# #      _:s3_edu1 a schema:OrganizationRole .
# #      _:s3_edu1 schema:alumniOf <wiki:University_of_Zurich> .
# #      _:s3_edu1 schema:startDate "1896"^^xsd:gYear .
# #      _:s3_edu1 schema:endDate "1900"^^xsd:gYear .
# #
# # 3. SIMPLE FACTS (no dates/qualifiers needed):
# #    Direct triples without Role:
# #    <wiki:Einstein> schema:birthDate "1879-03-14"^^xsd:date .
# #    <wiki:Einstein> schema:birthPlace <wiki:Ulm> .
# #
# # WHAT NOT TO DO:
# # 1. DO NOT use schema:description for quotes, opinions, or narrative facts.
# #    schema:description is ONLY for describing what an entity IS, not what happened to it.
# #    WRONG: <Einstein> schema:description "God does not play dice" .
# #    RIGHT: Create a schema:Quotation with schema:text for the quote.
# #
# # 2. DO NOT emit unrelated triples when no good schema match exists.
# #    If a statement is about "being sick in bed", don't emit schema:birthDate.
# #    If no good match (score >= 0.5), either:
# #    - Skip the statement entirely
# #    - Use rdfs:comment to preserve the text: <Einstein> rdfs:comment "Statement text here" .
# #
# # 3. DO NOT conflate past and present states.
# #    "Einstein renounced his German citizenship in 1896" means he LOST it.
# #    Use endDate on a citizenship Role, not startDate.
# #
# # 4. DO NOT extract facts not stated in the statement.
# #    Only model what the specific statement says, not general knowledge about the subject.
# #
# # 5. DATES REQUIRE ROLE PATTERN - CRITICAL!
# #    If a statement mentions "from X to Y" or any year/date range, you MUST use the Role pattern.
# #    Simple triples like <Einstein> schema:worksFor <ETH> lose the temporal information.
# #
# #    Pattern: Subject → Role → Target + dates
# #    <Subject> schema:property _:role .
# #    _:role a schema:Role .           (or OrganizationRole for employment/membership)
# #    _:role schema:property <Target> .
# #    _:role schema:startDate "YYYY"^^xsd:gYear .
# #    _:role schema:endDate "YYYY"^^xsd:gYear .
# #
# # IMPORTANT:
# # - Do NOT write Turtle syntax in your response - use the emit tools instead
# # - ALWAYS include the statement_id when emitting triples
# # - Include statement_id in blank node names: _:s{{id}}_role1
# # - Only emit triples for facts that CAN be properly modeled in schema.org
# # - It is better to skip a statement than emit incorrect triples
# # - Statements with dates MUST use Role pattern (5+ triples, not 1)
# #
# # HUMAN PROMPT:
# # Convert these factual statements to RDF triples.
# #
# # Source: https://en.wikipedia.org/wiki/Albert_Einstein
# # Section context: Albert Einstein > Life and career > Touring the US (1930–1931)
# #
# # Entity Registry (use these URIs for known entities):
# # <https://en.wikipedia.org/wiki/Albert_Einstein> # Albert Einstein (Person) (Wikidata: Q937)
# # <https://en.wikipedia.org/wiki/Ulm> # Ulm (Thing)
# # <https://en.wikipedia.org/wiki/Kingdom_of_W%C3%BCrttemberg> # Kingdom of Württemberg (Thing)
# # <https://en.wikipedia.org/wiki/German_Empire> # German Empire (Thing)
# # <https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey> # Princeton, New Jersey (Thing)
# # <https://en.wikipedia.org/wiki/Lieserl_Einstein> # Lieserl (Thing)
# # <https://en.wikipedia.org/wiki/Hans_Albert_Einstein> # Hans Albert (Thing)
# # <https://en.wikipedia.org/wiki/Einstein_family> # Eduard "Tete" (Thing)
# # <https://en.wikipedia.org/wiki/Einstein_family> # Einstein (Thing)
# # <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> # Mileva Marić (Thing)
# # <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> # Elsa Löwenthal (Thing)
# # <https://en.wikipedia.org/wiki/Statelessness> # Stateless (Thing)
# # <https://en.wikipedia.org/wiki/Switzerland> # Switzerland (Thing)
# # <https://en.wikipedia.org/wiki/Kingdom_of_Prussia> # Kingdom of Prussia (Thing)
# # <https://en.wikipedia.org/wiki/Free_State_of_Prussia> # Free State of Prussia (Thing)
# # <https://en.wikipedia.org/wiki/Weimar_Republic> # Weimar Republic (Thing)
# # <https://en.wikipedia.org/wiki/Citizenship_of_the_United_States> # United States (Thing)
# # <https://en.wikipedia.org/wiki/Physics> # Physics (Thing)
# # <https://en.wikipedia.org/wiki/University_of_Bern> # University of Bern (Thing)
# # <https://en.wikipedia.org/wiki/University_of_Zurich> # University of Zurich (Thing)
# # <https://en.wikipedia.org/wiki/Charles_University_in_Prague> # Charles University in Prague (Thing)
# # <https://en.wikipedia.org/wiki/ETH_Zurich> # ETH Zurich (Thing)
# # <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> # Prussian Academy of Sciences (Thing)
# # <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> # Humboldt University of Berlin (Thing)
# # <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute> # Kaiser Wilhelm Institute (Thing)
# # <https://en.wikipedia.org/wiki/German_Physical_Society> # German Physical Society (Thing)
# # <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> # Institute for Advanced Study (Thing)
# # <https://en.wikipedia.org/wiki/ETH_Zurich> # Swiss Federal Polytechnic School (Thing)
# # <https://en.wikipedia.org/wiki/PhD> # PhD (Thing)
# # <https://en.wikipedia.org/wiki/Alfred_Kleiner> # Alfred Kleiner (Thing)
# # <https://en.wikipedia.org/wiki/Heinrich_Friedrich_Weber> # Heinrich Friedrich Weber (Thing)
# # <https://en.wikipedia.org/wiki/General_relativity> # General relativity (Thing)
# # <https://en.wikipedia.org/wiki/Special_relativity> # Special relativity (Thing)
# # <https://en.wikipedia.org/wiki/Photoelectric_effect> # Photoelectric effect (Thing)
# # <https://en.wikipedia.org/wiki/Mass%E2%80%93energy_equivalence> # ''E''=''mc''<sup>2</sup> (mass–energy equivalence) (Thing)
# # <https://en.wikipedia.org/wiki/Planck%E2%80%93Einstein_relation> # ''E''=''hf'' (Planck–Einstein relation) (Thing)
# # <https://en.wikipedia.org/wiki/Brownian_motion> # Theory of Brownian motion (Thing)
# # <https://en.wikipedia.org/wiki/Einstein_field_equations> # Einstein field equations (Thing)
# # <https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_statistics> # Bose–Einstein statistics (Thing)
# # <https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_condensate> # Bose–Einstein condensate (Thing)
# # <https://en.wikipedia.org/wiki/Gravitational_wave> # Gravitational wave (Thing)
# # <https://en.wikipedia.org/wiki/Cosmological_constant> # Cosmological constant (Thing)
# # <https://en.wikipedia.org/wiki/Unified_field_theory> # Unified field theory (Thing)
# # <https://en.wikipedia.org/wiki/EPR_paradox> # EPR paradox (Thing)
# # <https://en.wikipedia.org/wiki/Ensemble_interpretation> # Ensemble interpretation (Thing)
# # <https://en.wikipedia.org/wiki/List_of_things_named_after_Albert_Einstein> # List of other concepts (Thing)
# # <https://en.wikipedia.org/wiki/Barnard_Medal_for_Meritorious_Service_to_Science> # Barnard Medal for Meritorious Service to Science (Thing)
# # <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics> # Nobel Prize in Physics (Thing)
# # <https://en.wikipedia.org/wiki/Matteucci_Medal> # Matteucci Medal (Thing)
# # <https://en.wikipedia.org/wiki/List_of_fellows_of_the_Royal_Society_elected_in_1921> # ForMemRS (Thing)
# # <https://en.wikipedia.org/wiki/Copley_Medal> # Copley Medal (Thing)
# #
# # Statements to convert (each has a unique ID like [3.5] - include this in blank node names):
# # [1] [Albert Einstein](/wiki/Albert_Einstein) traveled to [California](/wiki/California).
# # [2] [Albert Einstein](/wiki/Albert_Einstein) met [Robert A. Millikan](/wiki/Robert_A._Millikan).
# # [3] [Robert A. Millikan](/wiki/Robert_A._Millikan) was the president of [Caltech](/wiki/Caltech).
# # [4] [Robert A. Millikan](/wiki/Robert_A._Millikan) was a Nobel laureate.
# # [5] The friendship between [Albert Einstein](/wiki/Albert_Einstein) and [Robert A. Millikan](/wiki/Robert_A._Millikan) was described as "awkward".
# # [6] [Robert A. Millikan](/wiki/Robert_A._Millikan) had a penchant for patriotic militarism.
# # [7] [Albert Einstein](/wiki/Albert_Einstein) was a pronounced [pacifist](/wiki/pacifist).
# # [8] During an address to [Caltech](/wiki/Caltech)'s students, [Albert Einstein](/wiki/Albert_Einstein) noted that science was often inclined to do more harm than good.
# # [9] [Albert Einstein](/wiki/Albert_Einstein) befriended author [Upton Sinclair](/wiki/Upton_Sinclair).
# # [10] [Upton Sinclair](/wiki/Upton_Sinclair) was noted for pacifism.
# # [11] [Albert Einstein](/wiki/Albert_Einstein) befriended film star [Charlie Chaplin](/wiki/Charlie_Chaplin).
# # [12] [Charlie Chaplin](/wiki/Charlie_Chaplin) was noted for pacifism.
# # [13] [Carl Laemmle](/wiki/Carl_Laemmle) was the head of [Universal Studios](/wiki/Universal_Pictures).
# # [14] [Carl Laemmle](/wiki/Carl_Laemmle) gave [Albert Einstein](/wiki/Albert_Einstein) a tour of his studio.
# # [15] [Carl Laemmle](/wiki/Carl_Laemmle) introduced [Albert Einstein](/wiki/Albert_Einstein) to [Charlie Chaplin](/wiki/Charlie_Chaplin).
# # [16] [Charlie Chaplin](/wiki/Charlie_Chaplin) and [Albert Einstein](/wiki/Albert_Einstein) had an instant rapport.
# # [17] [Charlie Chaplin](/wiki/Charlie_Chaplin) invited [Albert Einstein](/wiki/Albert_Einstein) and his wife [Elsa Löwenthal](/wiki/Elsa_L%C3%B6wenthal) to his home for dinner.
# # [18] [Charlie Chaplin](/wiki/Charlie_Chaplin) said that [Albert Einstein](/wiki/Albert_Einstein)'s outward persona seemed calm and gentle but concealed a "highly emotional temperament".
# # [19] [Charlie Chaplin](/wiki/Charlie_Chaplin) said that [Albert Einstein](/wiki/Albert_Einstein)'s "extraordinary intellectual energy" came from this temperament.
# # [20] [Charlie Chaplin](/wiki/Charlie_Chaplin)'s film *[City Lights](/wiki/City_Lights)* was to premiere a few days later in [Hollywood](/wiki/Hollywood).
# # [21] [Charlie Chaplin](/wiki/Charlie_Chaplin) invited [Albert Einstein](/wiki/Albert_Einstein) and [Elsa Löwenthal](/wiki/Elsa_L%C3%B6wenthal) to join him as his special guests at the premiere.
# # [22] [Walter Isaacson](/wiki/Walter_Isaacson) described this event as "one of the most memorable scenes in the new era of celebrity".
# # [23] [Charlie Chaplin](/wiki/Charlie_Chaplin) visited [Albert Einstein](/wiki/Albert_Einstein) at his home during a later trip to [Berlin](/wiki/Berlin).
# # [24] [Charlie Chaplin](/wiki/Charlie_Chaplin) recalled [Albert Einstein](/wiki/Albert_Einstein)'s "modest little flat".
# # [25] [Albert Einstein](/wiki/Albert_Einstein) had a piano at which he began writing his theory.
# # [26] [Charlie Chaplin](/wiki/Charlie_Chaplin) speculated that the piano may have been "used as kindling wood by the Nazis".
# # [27] [Albert Einstein](/wiki/Albert_Einstein) and [Charlie Chaplin](/wiki/Charlie_Chaplin) were cheered at the premiere of *[City Lights](/wiki/City_Lights)*.
# # [28] [Charlie Chaplin](/wiki/Charlie_Chaplin) said to [Albert Einstein](/wiki/Albert_Einstein), "They cheer me because they understand me, and they cheer you because no one understands you."
# #
# # CRITICAL RULES:
# #
# # 1. URI EXTRACTION: Convert markdown links to Wikipedia URIs:
# #    [Albert Einstein](/wiki/Albert_Einstein) → <https://en.wikipedia.org/wiki/Albert_Einstein>
# #
# # 2. BLANK NODE NAMING: Include statement ID to avoid collisions:
# #    For statement [3.5], use: _:s3_5_role1 (NOT just _:role1)
# #
# # 3. SCHEMA MATCHING: Only use matches with score >= 0.5.
# #    If no good match exists, either skip the statement or use rdfs:comment.
# #
# # 4. TEMPORAL RELATIONSHIPS - MANDATORY ROLE PATTERN:
# #    If a statement has dates like "from X to Y" or year ranges, you MUST use the Role pattern.
# #    A simple triple loses the temporal information - DO NOT emit just:
# #      <Einstein> schema:employee <ETH_Zurich> .  ← WRONG! Loses the dates!
# #
# #    CORRECT Role Pattern (REQUIRED for dated relationships):
# #    Statement: "Einstein worked at ETH Zurich from 1912 to 1914"
# #      <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor _:s1_21_role1 .
# #      _:s1_21_role1 a schema:OrganizationRole .
# #      _:s1_21_role1 schema:worksFor <https://en.wikipedia.org/wiki/ETH_Zurich> .
# #      _:s1_21_role1 schema:startDate "1912"^^xsd:gYear .
# #      _:s1_21_role1 schema:endDate "1914"^^xsd:gYear .
# #
# #    Statement: "Einstein was a citizen of Switzerland from 1901 to 1955"
# #      <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality _:s1_14_role1 .
# #      _:s1_14_role1 a schema:Role .
# #      _:s1_14_role1 schema:nationality <https://en.wikipedia.org/wiki/Switzerland> .
# #      _:s1_14_role1 schema:startDate "1901"^^xsd:gYear .
# #      _:s1_14_role1 schema:endDate "1955"^^xsd:gYear .
# #
# #    Use OrganizationRole for employment/membership, Role for citizenship/other.
# #
# # 5. DO NOT:
# #    - Use schema:description for quotes or narrative (only for entity descriptions)
# #    - Emit unrelated triples when no good match exists
# #    - Extract facts not stated in the statement
# #    - Emit simple triples when there are dates (MUST use Role pattern)
# #
# # Process each statement. If you cannot properly model it, skip it or use rdfs:comment.
# #
# # === END PROMPT ===

# %% [raw]
# # Statement [23.1]: [Albert Einstein](/wiki/Albert_Einstein) was in the United States in February 1933.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:homeLocation <"https://en.wikipedia.org/wiki/United_States">^^xsd:anyURI .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:homeLocation "https://en.wikipedia.org/wiki/United_States"^^xsd:anyURI .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreids34pl5l4tn344ijpl6x7wedh2dizxsyixpwxmolujznm752o6wi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreids34pl5l4tn344ijpl6x7wedh2dizxsyixpwxmolujznm752o6wi",
#   "prov:label": "rdf:23_1",
#   "_cell": 616,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihogyafgk3lkacksmbotp5jai3br5ske7m3edfuz4twmwdhr5zfci"
#   },
#   "_stmt_key": "23_1",
#   "_chunk_num": 23,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [23.2]: [Albert Einstein](/wiki/Albert_Einstein) knew he could not return to [Germany](/wiki/Germany) in February 1933 because of the rise to power of the [Nazis](/wiki/Nazi_Germany) under [Adolf Hitler](/wiki/Adolf_Hitler).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:homeLocation <"https://en.wikipedia.org/wiki/Germany">^^xsd:anyURI .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:homeLocation "https://en.wikipedia.org/wiki/Germany"^^xsd:anyURI .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicp57uqmakg74fh3hjv3gwjkacgoff2y43mgjfmr2jl4dsfcbcnnq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicp57uqmakg74fh3hjv3gwjkacgoff2y43mgjfmr2jl4dsfcbcnnq",
#   "prov:label": "rdf:23_2",
#   "_cell": 618,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihw7ldk6bngqpife3dsqcv2pcpfp7zczxjvxpc7cfia6qqmmab2jq"
#   },
#   "_stmt_key": "23_2",
#   "_chunk_num": 23,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [23.3]: [Albert Einstein](/wiki/Albert_Einstein) was on a visit to the [United States](/wiki/Citizenship_of_the_United_States) in February 1933.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:homeLocation <"https://en.wikipedia.org/wiki/United_States">^^xsd:anyURI .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:homeLocation "https://en.wikipedia.org/wiki/United_States"^^xsd:anyURI .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigl7xyx5cx5ayu3chs23im3mkbxlb2dyy3axheso2zoxirwmeq2sa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigl7xyx5cx5ayu3chs23im3mkbxlb2dyy3axheso2zoxirwmeq2sa",
#   "prov:label": "rdf:23_3",
#   "_cell": 620,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreif4pe36jbvrfbuaubwjkxatapxnmbwamk6qpqdcid644wluhmd6qy"
#   },
#   "_stmt_key": "23_3",
#   "_chunk_num": 23,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [23.4]: [Albert Einstein](/wiki/Albert_Einstein) undertook his third two-month visiting professorship at the [California Institute of Technology](/wiki/California_Institute_of_Technology) in Pasadena in early 1933.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor <"https://en.wikipedia.org/wiki/California_Institute_of_Technology">^^xsd:anyURI .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor "https://en.wikipedia.org/wiki/California_Institute_of_Technology"^^xsd:anyURI .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieu5aja545jz65d6umbnrdjoyyyrwcrdx5u2bmxf2gro7ut5tkns4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieu5aja545jz65d6umbnrdjoyyyrwcrdx5u2bmxf2gro7ut5tkns4",
#   "prov:label": "rdf:23_4",
#   "_cell": 622,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiepdllzkks4qjabumzlgaicg6c4yu4gurtiadjt5zmlbkg32f4c2u"
#   },
#   "_stmt_key": "23_4",
#   "_chunk_num": 23,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [23.5]: The [Gestapo](/wiki/Gestapo) repeatedly raided [Einstein's](/wiki/Einstein_family) family apartment in [Berlin](/wiki/Berlin) in February and March 1933.
# # No triples emitted for this statement
# # Debug: 141 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/United_States\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/Germany\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/United_States\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 4, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:worksFor", "object_value": "<\"https://en.wikipedia.org/wiki/California_Institute_of_Technology\"
# #   emit_triple: {"statement_id": 12, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/Antwerp\">^^xsd:anyURI"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreig2izcgpd6j2rofp73qqr4gqai5kvbeqsckdp4ksfmnn52xcc3kte",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreig2izcgpd6j2rofp73qqr4gqai5kvbeqsckdp4ksfmnn52xcc3kte",
#   "prov:label": "rdf:23_5",
#   "_cell": 624,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicouasdnfuwpk36yhmrqokhftalpde44d3roie2t2fyxt24n3jdty"
#   },
#   "_stmt_key": "23_5",
#   "_chunk_num": 23,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [23.6]: [Albert Einstein](/wiki/Albert_Einstein) and his wife [Elsa Löwenthal](/wiki/Elsa_L%C3%B6wenthal) returned to Europe in March 1933.
# # No triples emitted for this statement
# # Debug: 141 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/United_States\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/Germany\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/United_States\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 4, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:worksFor", "object_value": "<\"https://en.wikipedia.org/wiki/California_Institute_of_Technology\"
# #   emit_triple: {"statement_id": 12, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/Antwerp\">^^xsd:anyURI"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic22fnte7vx2n42uxtivfhhrafbbbp5ro3qdis47gqz7bqbzlekw4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic22fnte7vx2n42uxtivfhhrafbbbp5ro3qdis47gqz7bqbzlekw4",
#   "prov:label": "rdf:23_6",
#   "_cell": 626,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifrih3icjzpp2uwzvbstpgrl73phmguuichjmlq52q4irfuvdpiuu"
#   },
#   "_stmt_key": "23_6",
#   "_chunk_num": 23,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [23.7]: During the trip back to Europe, [Einstein](/wiki/Einstein_family) and [Elsa Löwenthal](/wiki/Elsa_L%C3%B6wenthal) learned that the [German Reichstag](/wiki/German_Reichstag) had passed the [Enabling Act](/wiki/Enabling_Act_of_1933) on 23 March 1933.
# # No triples emitted for this statement
# # Debug: 141 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/United_States\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/Germany\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/United_States\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 4, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:worksFor", "object_value": "<\"https://en.wikipedia.org/wiki/California_Institute_of_Technology\"
# #   emit_triple: {"statement_id": 12, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/Antwerp\">^^xsd:anyURI"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifjaooul6mhwjtiyklwqfuu4xfi7qznb4j72ctbjlynmv4nje625i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifjaooul6mhwjtiyklwqfuu4xfi7qznb4j72ctbjlynmv4nje625i",
#   "prov:label": "rdf:23_7",
#   "_cell": 628,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidvqv4cx2j5pyqinsuq3sr4w2qkamem6bietl4os6tugfupsdjd54"
#   },
#   "_stmt_key": "23_7",
#   "_chunk_num": 23,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [23.8]: The [Enabling Act](/wiki/Enabling_Act_of_1933) transformed [Hitler's](/wiki/Adolf_Hitler) government into a *de facto* legal dictatorship in March 1933.
# <https://en.wikipedia.org/wiki/Enabling_Act_of_1933> rdf:type schema:Legislation .
# <https://en.wikipedia.org/wiki/Enabling_Act_of_1933> schema:legislationDate "1933-03-23"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic565wvqguauuxxdrxsufnwjh45glipifahdv76vnqo6x2ajwjswm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic565wvqguauuxxdrxsufnwjh45glipifahdv76vnqo6x2ajwjswm",
#   "prov:label": "rdf:23_8",
#   "_cell": 630,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiay7qwmzlihpn5zl2obmdjse4bwzu4jigeqjd6ktffg5ugxswiski"
#   },
#   "_stmt_key": "23_8",
#   "_chunk_num": 23,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [23.9]: [Einstein](/wiki/Einstein_family) and [Elsa Löwenthal](/wiki/Elsa_L%C3%B6wenthal) were unable to proceed to [Berlin](/wiki/Berlin) after learning about the [Enabling Act](/wiki/Enabling_Act_of_1933).
# # No triples emitted for this statement
# # Debug: 141 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/United_States\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/Germany\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/United_States\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 4, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:worksFor", "object_value": "<\"https://en.wikipedia.org/wiki/California_Institute_of_Technology\"
# #   emit_triple: {"statement_id": 12, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/Antwerp\">^^xsd:anyURI"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiby7tybgtvxdko4qbzgyznvpc7tel2pemm6jgvjwtu46iymnejiuy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiby7tybgtvxdko4qbzgyznvpc7tel2pemm6jgvjwtu46iymnejiuy",
#   "prov:label": "rdf:23_9",
#   "_cell": 632,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaoqcw4xf3qje2d47jag23uh43uuvupua5kokwdiji4b5eha7vtou"
#   },
#   "_stmt_key": "23_9",
#   "_chunk_num": 23,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [23.10]: [Einstein](/wiki/Einstein_family) and [Elsa Löwenthal](/wiki/Elsa_L%C3%B6wenthal) heard that their cottage had been raided by the [Nazis](/wiki/Nazi_Germany) in March 1933.
# # No triples emitted for this statement
# # Debug: 141 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/United_States\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/Germany\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/United_States\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 4, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:worksFor", "object_value": "<\"https://en.wikipedia.org/wiki/California_Institute_of_Technology\"
# #   emit_triple: {"statement_id": 12, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/Antwerp\">^^xsd:anyURI"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreignqg2tvgciv5ijyjnvsl57oooiupm37sox7hwpvyrg2ksh4oxsoi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreignqg2tvgciv5ijyjnvsl57oooiupm37sox7hwpvyrg2ksh4oxsoi",
#   "prov:label": "rdf:23_10",
#   "_cell": 634,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidhkydujq5k63lihd3tdueiwu2e73hhnxxbjsg27yailegvasuhu4"
#   },
#   "_stmt_key": "23_10",
#   "_chunk_num": 23,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [23.11]: [Einstein](/wiki/Einstein_family)’s personal sailboat was confiscated by the [Nazis](/wiki/Nazi_Germany) in March 1933.
# # No triples emitted for this statement
# # Debug: 141 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/United_States\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/Germany\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/United_States\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 4, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:worksFor", "object_value": "<\"https://en.wikipedia.org/wiki/California_Institute_of_Technology\"
# #   emit_triple: {"statement_id": 12, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/Antwerp\">^^xsd:anyURI"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigqrrttymesplh4hoveau3jyt3ivs6xo5tjb26q4idqxotqd5tdly",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigqrrttymesplh4hoveau3jyt3ivs6xo5tjb26q4idqxotqd5tdly",
#   "prov:label": "rdf:23_11",
#   "_cell": 636,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreif5k2dh4qrv6hww2xloqfws25jhv7cywceplqajn7s6laaakceoxu"
#   },
#   "_stmt_key": "23_11",
#   "_chunk_num": 23,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [23.12]: [Albert Einstein](/wiki/Albert_Einstein) landed in [Antwerp](/wiki/Antwerp), [Belgium](/wiki/Belgium) on 28 March 1933.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:homeLocation <"https://en.wikipedia.org/wiki/Antwerp">^^xsd:anyURI .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:homeLocation "https://en.wikipedia.org/wiki/Antwerp"^^xsd:anyURI .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiekjda734i3xwbbppw7bqpzf72bbyli3dw2v5s6lvio3k6ysg23du",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiekjda734i3xwbbppw7bqpzf72bbyli3dw2v5s6lvio3k6ysg23du",
#   "prov:label": "rdf:23_12",
#   "_cell": 638,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihqziwnnnhesro7dmld65pdz2mznogttom2ddjo7bd3734rpz6ziy"
#   },
#   "_stmt_key": "23_12",
#   "_chunk_num": 23,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [23.13]: Upon landing in [Antwerp](/wiki/Antwerp), [Albert Einstein](/wiki/Albert_Einstein) went to the German consulate and surrendered his passport.
# # No triples emitted for this statement
# # Debug: 141 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/United_States\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/Germany\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/United_States\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 4, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:worksFor", "object_value": "<\"https://en.wikipedia.org/wiki/California_Institute_of_Technology\"
# #   emit_triple: {"statement_id": 12, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/Antwerp\">^^xsd:anyURI"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicls5itthx7mpbfxnsyead6zmcr73yinvezvhnew35mf7cln7fpvm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicls5itthx7mpbfxnsyead6zmcr73yinvezvhnew35mf7cln7fpvm",
#   "prov:label": "rdf:23_13",
#   "_cell": 640,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibmnxqodet7vfqzfhio65ignoqdzozz6kpkmx32vb4g2ldc3jjioi"
#   },
#   "_stmt_key": "23_13",
#   "_chunk_num": 23,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [23.14]: [Albert Einstein](/wiki/Albert_Einstein) formally renounced his German citizenship in March 1933.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality <"https://en.wikipedia.org/wiki/Germany">^^xsd:anyURI .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality <"https://en.wikipedia.org/wiki/United_States">^^xsd:anyURI .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality <"https://en.wikipedia.org/wiki/Statelessness">^^xsd:anyURI .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality <"https://en.wikipedia.org/wiki/Switzerland">^^xsd:anyURI .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality "https://en.wikipedia.org/wiki/Germany"^^xsd:anyURI .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality "https://en.wikipedia.org/wiki/United_States"^^xsd:anyURI .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality "https://en.wikipedia.org/wiki/Statelessness"^^xsd:anyURI .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality "https://en.wikipedia.org/wiki/Switzerland"^^xsd:anyURI .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigavu2vfiup6mrleolnwxlf3ybfpnkzrfcnxk2gx64nklf64sumsy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigavu2vfiup6mrleolnwxlf3ybfpnkzrfcnxk2gx64nklf64sumsy",
#   "prov:label": "rdf:23_14",
#   "_cell": 642,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibnazvghcjn56ldg2w6nsvhldtlb52w2yhwh6bf5kfjiyknfpb7be"
#   },
#   "_stmt_key": "23_14",
#   "_chunk_num": 23,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [23.15]: The [Nazis](/wiki/Nazi_Germany) later sold [Einstein's](/wiki/Einstein_family) boat in March 1933.
# # No triples emitted for this statement
# # Debug: 141 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/United_States\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/Germany\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/United_States\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 4, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:worksFor", "object_value": "<\"https://en.wikipedia.org/wiki/California_Institute_of_Technology\"
# #   emit_triple: {"statement_id": 12, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/Antwerp\">^^xsd:anyURI"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidjiiccqmwnnlvrbindpyhlhwzd3hmqos2qvpnl3i32lp7jxil5ca",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidjiiccqmwnnlvrbindpyhlhwzd3hmqos2qvpnl3i32lp7jxil5ca",
#   "prov:label": "rdf:23_15",
#   "_cell": 644,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihkdo6ytno3rftldtfq7j4ysi4h5ri2bka5krecwabaabhw5dls4y"
#   },
#   "_stmt_key": "23_15",
#   "_chunk_num": 23,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [23.16]: The [Nazis](/wiki/Nazi_Germany) converted [Einstein's](/wiki/Einstein_family) cottage into a [Hitler Youth](/wiki/Hitler_Youth) camp in March 1933.
# # No triples emitted for this statement
# # Debug: 141 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/United_States\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/Germany\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/United_States\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 4, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:worksFor", "object_value": "<\"https://en.wikipedia.org/wiki/California_Institute_of_Technology\"
# #   emit_triple: {"statement_id": 12, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/Antwerp\">^^xsd:anyURI"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreif55qvdsbocwvguk3uawpxcebomseuavqgxlgmc5gb22crxwuhjj4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreif55qvdsbocwvguk3uawpxcebomseuavqgxlgmc5gb22crxwuhjj4",
#   "prov:label": "rdf:23_16",
#   "_cell": 646,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaackcx7zhgpqdic4umjyjfqi3tmk6ohi3f6avl33aethamcihye4"
#   },
#   "_stmt_key": "23_16",
#   "_chunk_num": 23,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [23.17]: In April 1933, [Albert Einstein](/wiki/Albert_Einstein) discovered that the new German government had passed [laws barring Jews from holding any official positions](/wiki/Law_for_the_Restoration_of_the_Professional_Civil_Service).
# <https://en.wikipedia.org/wiki/Law_for_the_Restoration_of_the_Professional_Civil_Service> rdf:type schema:Legislation .
# <https://en.wikipedia.org/wiki/Law_for_the_Restoration_of_the_Professional_Civil_Service> schema:legislationDate "1933-04-07"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaudmkb4w7wl5ioqwojueaj2jmy3k3hbs6dw6nj6ikihlibvvizle",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaudmkb4w7wl5ioqwojueaj2jmy3k3hbs6dw6nj6ikihlibvvizle",
#   "prov:label": "rdf:23_17",
#   "_cell": 648,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibqbheig7fsnfhza26uoc5vezjbve4ebq62oskc3rmbwf6ynf74fm"
#   },
#   "_stmt_key": "23_17",
#   "_chunk_num": 23,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [23.18]: The [laws barring Jews from holding any official positions](/wiki/Law_for_the_Restoration_of_the_Professional_Civil_Service) included teaching at universities in April 1933.
# # No triples emitted for this statement
# # Debug: 141 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/United_States\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/Germany\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/United_States\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 4, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:worksFor", "object_value": "<\"https://en.wikipedia.org/wiki/California_Institute_of_Technology\"
# #   emit_triple: {"statement_id": 12, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/Antwerp\">^^xsd:anyURI"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicxhzrrj6qdqa4mopokfnbwhzjwiafzelx663u5aoity2k33ayv2q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicxhzrrj6qdqa4mopokfnbwhzjwiafzelx663u5aoity2k33ayv2q",
#   "prov:label": "rdf:23_18",
#   "_cell": 650,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihbeeqzspdcnvklhzl4jygqdv3hkwxms5w5ygk6s6ixgq27xtoyee"
#   },
#   "_stmt_key": "23_18",
#   "_chunk_num": 23,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [23.19]: Historian [Gerald Holton](/wiki/Gerald_Holton) described how thousands of Jewish scientists were suddenly forced to give up their university positions in April 1933.
# # No triples emitted for this statement
# # Debug: 141 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/United_States\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/Germany\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/United_States\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 4, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:worksFor", "object_value": "<\"https://en.wikipedia.org/wiki/California_Institute_of_Technology\"
# #   emit_triple: {"statement_id": 12, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/Antwerp\">^^xsd:anyURI"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibxty5dp22fkc6sx5tdvflxn2azakvdecsscnzii2vi4b3araoqii",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibxty5dp22fkc6sx5tdvflxn2azakvdecsscnzii2vi4b3araoqii",
#   "prov:label": "rdf:23_19",
#   "_cell": 652,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiekzijcs7mlbkvr34yazyumj5ohlmuswqowusbcj5nu6k3ajcca3u"
#   },
#   "_stmt_key": "23_19",
#   "_chunk_num": 23,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Statement [23.20]: In April 1933, the names of Jewish scientists were removed from the rolls of institutions where they were employed.
# # No triples emitted for this statement
# # Debug: 141 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/United_States\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/Germany\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/United_States\">^^xsd:anyURI"}
# #   emit_triple: {"statement_id": 4, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:worksFor", "object_value": "<\"https://en.wikipedia.org/wiki/California_Institute_of_Technology\"
# #   emit_triple: {"statement_id": 12, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:homeLocation", "object_value": "<\"https://en.wikipedia.org/wiki/Antwerp\">^^xsd:anyURI"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreib7r6a6rohukttjy2baixxkxvpjfn5jnog33q6dtr5iu7gru4jt3q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreib7r6a6rohukttjy2baixxkxvpjfn5jnog33q6dtr5iu7gru4jt3q",
#   "prov:label": "rdf:23_20",
#   "_cell": 654,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicfrphpsajre35s22o7wfbigk7phgulsup5d6flrt3oed7fujz5ve"
#   },
#   "_stmt_key": "23_20",
#   "_chunk_num": 23,
#   "_stmt_idx": 20
# }

# %% [raw]
# # Statement [24.1]: [Albert Einstein](/wiki/Albert_Einstein) was targeted by the [German Student Union](/wiki/German_Student_Union) in the [Nazi book burnings](/wiki/Nazi_book_burnings) in 1933.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:target <https://en.wikipedia.org/wiki/Nazi_book_burnings> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibf2oestablshv7mezbvjdxx3noenwl7yksljdfafiaalrcuxrmgy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibf2oestablshv7mezbvjdxx3noenwl7yksljdfafiaalrcuxrmgy",
#   "prov:label": "rdf:24_1",
#   "_cell": 656,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibapucmflotboki7w3ge6acchlm7raetlz6jg2zbqfpth7p2lb7ee"
#   },
#   "_stmt_key": "24_1",
#   "_chunk_num": 24,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [24.2]: [Joseph Goebbels](/wiki/Joseph_Goebbels) proclaimed "Jewish intellectualism is dead" in relation to the [Nazi book burnings](/wiki/Nazi_book_burnings).
# <https://en.wikipedia.org/wiki/Joseph_Goebbels> schema:creator <https://en.wikipedia.org/wiki/Nazi_book_burnings> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigqwiwunrv6qavozvdglecwwm57uy2xz4xmiybosd3tuqb7vly5ji",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigqwiwunrv6qavozvdglecwwm57uy2xz4xmiybosd3tuqb7vly5ji",
#   "prov:label": "rdf:24_2",
#   "_cell": 658,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiewbgrdl7nnf2tnldswijux472bppkbs4pnnf4a5vdwyrubafwgli"
#   },
#   "_stmt_key": "24_2",
#   "_chunk_num": 24,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [24.3]: A German magazine listed [Albert Einstein](/wiki/Albert_Einstein) as an enemy of the German regime with the phrase "not yet hanged" in 1933.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:target <https://en.wikipedia.org/wiki/Nazi_book_burnings> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic2y2c7cdgosqgnttm322asld43brj3ialmgth6i2penegktr7dci",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic2y2c7cdgosqgnttm322asld43brj3ialmgth6i2penegktr7dci",
#   "prov:label": "rdf:24_3",
#   "_cell": 660,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihnn5c45aew6kg2bu7jquky45sccbthyf4clsgiovlbgngjria4mm"
#   },
#   "_stmt_key": "24_3",
#   "_chunk_num": 24,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [24.4]: The German magazine offered a $5,000 bounty on the head of [Albert Einstein](/wiki/Albert_Einstein).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:target <https://en.wikipedia.org/wiki/Nazi_book_burnings> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigb5ezjw6o7wz7oxan4pbhhzzbvsijjzm4rpaqbkpmc5swd4pewcm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigb5ezjw6o7wz7oxan4pbhhzzbvsijjzm4rpaqbkpmc5swd4pewcm",
#   "prov:label": "rdf:24_4",
#   "_cell": 662,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib2whukbxeap5jkqj2sjpx4ctn6lfmgaejgatoegxqpbb4qzlrpye"
#   },
#   "_stmt_key": "24_4",
#   "_chunk_num": 24,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [24.5]: [Albert Einstein](/wiki/Albert_Einstein) was without a permanent home in 1933.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:homeLocation <https://en.wikipedia.org/wiki/Statelessness> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifuxnutj26o6du35grhg2ojj542uad37pey3q7xiga3dirzkfzmfm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifuxnutj26o6du35grhg2ojj542uad37pey3q7xiga3dirzkfzmfm",
#   "prov:label": "rdf:24_5",
#   "_cell": 664,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia24gdmbedzo2xo7nkgzhziu7pjkyvch2x6mr2xwspujwxc5hiwmm"
#   },
#   "_stmt_key": "24_5",
#   "_chunk_num": 24,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [24.6]: [Albert Einstein](/wiki/Albert_Einstein) was worried about the fate of other scientists still in Germany in 1933.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:concernedAbout <https://en.wikipedia.org/wiki/Scientists> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigbbkx45uarpeaug5ywkzhmhkvx5yxzgidtdyrburpphsr25pc7bi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigbbkx45uarpeaug5ywkzhmhkvx5yxzgidtdyrburpphsr25pc7bi",
#   "prov:label": "rdf:24_6",
#   "_cell": 666,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicns6q7hagkbqs2dd6kjrdygiqdtkdpkzy5bxwxqnpt5wmv7fpuju"
#   },
#   "_stmt_key": "24_6",
#   "_chunk_num": 24,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [24.7]: The [Academic Assistance Council](/wiki/Academic_Assistance_Council) was founded in April 1933 to help academics escape Nazi persecution.
# <https://en.wikipedia.org/wiki/Academic_Assistance_Council> rdf:type schema:Organization .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiah6aibqw6wdauho5sxiu7uzw776onspwpgehqm7sv54py2y4gppe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiah6aibqw6wdauho5sxiu7uzw776onspwpgehqm7sv54py2y4gppe",
#   "prov:label": "rdf:24_7",
#   "_cell": 668,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifmthfkuhdovglilsw52naw2lzko2kfpfqe5k542akhns27cluchq"
#   },
#   "_stmt_key": "24_7",
#   "_chunk_num": 24,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [24.8]: [William Beveridge](/wiki/William_Beveridge) was a British Liberal politician who founded the [Academic Assistance Council](/wiki/Academic_Assistance_Council) in 1933.
# <https://en.wikipedia.org/wiki/William_Beveridge> schema:founder <https://en.wikipedia.org/wiki/Academic_Assistance_Council> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihhh6x73tkmjzsjmstijtzwxc2cuwpcvyt4i2f6jqd5xav3vns7na",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihhh6x73tkmjzsjmstijtzwxc2cuwpcvyt4i2f6jqd5xav3vns7na",
#   "prov:label": "rdf:24_8",
#   "_cell": 670,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiedqpetradmbs2h3hlxti7izmxwqtlekuxcjxyifgl56asqjtlfhe"
#   },
#   "_stmt_key": "24_8",
#   "_chunk_num": 24,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [24.9]: [Albert Einstein](/wiki/Albert_Einstein) left Germany with aid from the [Academic Assistance Council](/wiki/Academic_Assistance_Council) in 1933.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:memberOf <https://en.wikipedia.org/wiki/Academic_Assistance_Council> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiemq3t32vsnwmyz7rveaiwmiuakneamlszeaevhxzcxy7tz5u6dxm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiemq3t32vsnwmyz7rveaiwmiuakneamlszeaevhxzcxy7tz5u6dxm",
#   "prov:label": "rdf:24_9",
#   "_cell": 672,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihytqn23eeyjrtwoamxljl6rwzpbva2l3jxuizlvgf7wk2kywdc4q"
#   },
#   "_stmt_key": "24_9",
#   "_chunk_num": 24,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [24.10]: [Albert Einstein](/wiki/Albert_Einstein) rented a house in De Haan, Belgium, in 1933.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:homeLocation <https://en.wikipedia.org/wiki/De_Haan> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia2t7vhfjlu3sm63shwu6bcxg64nppy7v7em7cbb6fhixbjg36czy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia2t7vhfjlu3sm63shwu6bcxg64nppy7v7em7cbb6fhixbjg36czy",
#   "prov:label": "rdf:24_10",
#   "_cell": 674,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifdbqsihptne5aufjm6x432esdspatt2spkoht6rnwhjoahy36q4e"
#   },
#   "_stmt_key": "24_10",
#   "_chunk_num": 24,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [24.11]: [Albert Einstein](/wiki/Albert_Einstein) visited England in late July 1933.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/England> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifuvdkgrb7mjn3yo6dq32w4jqti5m6ddg64ya4l4uwjhdrb6bdj2q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifuvdkgrb7mjn3yo6dq32w4jqti5m6ddg64ya4l4uwjhdrb6bdj2q",
#   "prov:label": "rdf:24_11",
#   "_cell": 676,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieq6yvi2gjsxlswukfnhylsq53uhdl5xb2bqk7umlapohnr5svvqm"
#   },
#   "_stmt_key": "24_11",
#   "_chunk_num": 24,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [24.12]: [Oliver Locker-Lampson](/wiki/Oliver_Locker-Lampson) invited [Albert Einstein](/wiki/Albert_Einstein) to stay near his [Cromer](/wiki/Cromer) home in a secluded wooden cabin on Roughton Heath in the Parish of [Roughton, Norfolk](/wiki/Roughton%2C_Norfolk) in 1933.
# <https://en.wikipedia.org/wiki/Oliver_Locker-Lampson> schema:invitee <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihlu6pwntxgvthbhwkcqqyuiwrk2hvtou7e2khc3nsxz5kmwpvupe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihlu6pwntxgvthbhwkcqqyuiwrk2hvtou7e2khc3nsxz5kmwpvupe",
#   "prov:label": "rdf:24_12",
#   "_cell": 678,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihfxlgklxmywe3lztjbculohfdw4vc54crv2grj7dvdwfhapwdvu4"
#   },
#   "_stmt_key": "24_12",
#   "_chunk_num": 24,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [24.13]: [Oliver Locker-Lampson](/wiki/Oliver_Locker-Lampson) had two bodyguards watch over [Albert Einstein](/wiki/Albert_Einstein) in 1933.
# <https://en.wikipedia.org/wiki/Oliver_Locker-Lampson> schema:has <https://en.wikipedia.org/wiki/Bodyguard> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiagvao4zisadydwyjqs2mzcwj2aitrtgrj4ift7pnti2ojvqri2ea",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiagvao4zisadydwyjqs2mzcwj2aitrtgrj4ift7pnti2ojvqri2ea",
#   "prov:label": "rdf:24_13",
#   "_cell": 680,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihjec5ephzqp35b3aoxia6ii27zu5tlweb2b37yybjknxiwflbihe"
#   },
#   "_stmt_key": "24_13",
#   "_chunk_num": 24,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [24.14]: A photo of the bodyguards carrying shotguns and guarding [Albert Einstein](/wiki/Albert_Einstein) was published in the *Daily Herald* on 24 July 1933.
# <https://en.wikipedia.org/wiki/Daily_Herald> schema:publishes <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiejyxz5fdklzafsp6aygaodkoimmwryf72v4layc3puuzi7zg6k2i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiejyxz5fdklzafsp6aygaodkoimmwryf72v4layc3puuzi7zg6k2i",
#   "prov:label": "rdf:24_14",
#   "_cell": 682,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigkqsgfpe4eytvjaqra7hmxebijuekyoumx5xn5htzfajlrkcvqam"
#   },
#   "_stmt_key": "24_14",
#   "_chunk_num": 24,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [25.1]: [Locker-Lampson](/wiki/Locker-Lampson) took [Albert Einstein](/wiki/Albert_Einstein) to meet [Winston Churchill](/wiki/Winston_Churchill) at his home.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/Winston_Churchill> .
# <https://en.wikipedia.org/wiki/Locker-Lampson> schema:attendee <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiakx5xgmpun6mnswrbxb3bfv62yf3cfhqifrgzkkmnyslxzkof6k4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiakx5xgmpun6mnswrbxb3bfv62yf3cfhqifrgzkkmnyslxzkof6k4",
#   "prov:label": "rdf:25_1",
#   "_cell": 684,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiggjtlljsbkp5ymfelwihqacvpfbg6r3qb3laehstyp2bmvaoss6u"
#   },
#   "_stmt_key": "25_1",
#   "_chunk_num": 25,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [25.2]: [Locker-Lampson](/wiki/Locker-Lampson) took [Albert Einstein](/wiki/Albert_Einstein) to meet [Austen Chamberlain](/wiki/Austen_Chamberlain).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/Austen_Chamberlain> .
# <https://en.wikipedia.org/wiki/Locker-Lampson> schema:attendee <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiepaa2piti3ihijkpjpfbqralvbsf7ouzgi4jzvccwgm42k3cmecm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiepaa2piti3ihijkpjpfbqralvbsf7ouzgi4jzvccwgm42k3cmecm",
#   "prov:label": "rdf:25_2",
#   "_cell": 686,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicjtg5x4bovchd3gr7ssoa7zd27ffnmeu22o3zrxfvnettqs4qu7e"
#   },
#   "_stmt_key": "25_2",
#   "_chunk_num": 25,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [25.3]: [Locker-Lampson](/wiki/Locker-Lampson) took [Albert Einstein](/wiki/Albert_Einstein) to meet former Prime Minister [Lloyd George](/wiki/Lloyd_George).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/Lloyd_George> .
# <https://en.wikipedia.org/wiki/Locker-Lampson> schema:attendee <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihup34frkltd7ms2vgapbgs5uufwoifez66wiivbstjikqixhw5hm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihup34frkltd7ms2vgapbgs5uufwoifez66wiivbstjikqixhw5hm",
#   "prov:label": "rdf:25_3",
#   "_cell": 688,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihaeulth4vykxfmiygmqubcucmmvqmeh3gtezq5xkiqmkdb45vj24"
#   },
#   "_stmt_key": "25_3",
#   "_chunk_num": 25,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [25.4]: [Albert Einstein](/wiki/Albert_Einstein) asked [Winston Churchill](/wiki/Winston_Churchill), [Austen Chamberlain](/wiki/Austen_Chamberlain), and [Lloyd George](/wiki/Lloyd_George) to help bring Jewish scientists out of Germany.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:recipient <https://en.wikipedia.org/wiki/Winston_Churchill> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:recipient <https://en.wikipedia.org/wiki/Austen_Chamberlain> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:recipient <https://en.wikipedia.org/wiki/Lloyd_George> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidigacxba46xxjzzo5ykuqze4f2zhy3teuqcvxe47yuci764jmzz4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidigacxba46xxjzzo5ykuqze4f2zhy3teuqcvxe47yuci764jmzz4",
#   "prov:label": "rdf:25_4",
#   "_cell": 690,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicq5tpeifo7nnpykr5w3kishkigkkdasadeyldtnvx3ii7cdut6na"
#   },
#   "_stmt_key": "25_4",
#   "_chunk_num": 25,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [25.5]: British historian [Martin Gilbert](/wiki/Martin_Gilbert) notes that [Winston Churchill](/wiki/Winston_Churchill) responded immediately to [Albert Einstein](/wiki/Albert_Einstein)'s request.
# <https://en.wikipedia.org/wiki/Winston_Churchill> schema:attendee <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieupj6nkqf3klbm3j7vwzbfvmuxw2wevemeceln3pxj7f4eq7hm3m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieupj6nkqf3klbm3j7vwzbfvmuxw2wevemeceln3pxj7f4eq7hm3m",
#   "prov:label": "rdf:25_5",
#   "_cell": 692,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicbuujafzawiyxfgvg3izh4sq2xcmsw3lkfoz2zf4ardkbeqilmai"
#   },
#   "_stmt_key": "25_5",
#   "_chunk_num": 25,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [25.6]: [Winston Churchill](/wiki/Winston_Churchill) sent his friend physicist [Frederick Lindemann](/wiki/Frederick_Lindemann) to Germany to seek out Jewish scientists and place them in British universities.
# <https://en.wikipedia.org/wiki/Winston_Churchill> schema:sender <https://en.wikipedia.org/wiki/Frederick_Lindemann> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia5pw2blluqxcsc2cugmsug2j6wzi7tpfekcvup6a4y64br772apu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia5pw2blluqxcsc2cugmsug2j6wzi7tpfekcvup6a4y64br772apu",
#   "prov:label": "rdf:25_6",
#   "_cell": 694,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifurmltjvtlfmmgfb3scr5l6azvjtwj2cq53me3ladlhvcsxhbhxe"
#   },
#   "_stmt_key": "25_6",
#   "_chunk_num": 25,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [25.7]: [Winston Churchill](/wiki/Winston_Churchill) later observed that as a result of Germany having driven the Jews out, they had lowered their "technical standards" and put [the Allies](/wiki/Allies_of_World_War_II) technology ahead of theirs.
# # No triples emitted for this statement
# # Debug: 44 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:attendee", "object_value": "<https://en.wikipedia.org/wiki/Winston_Churchill>"}
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/Locker-Lampson>", "predicate": "schema:attendee", "object_value": "<https://en.wikipedia.org/wiki/Albert_Einstein>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:attendee", "object_value": "<https://en.wikipedia.org/wiki/Austen_Chamberlain>"}
# #   emit_triple: {"statement_id": 2, "subject": "<https://en.wikipedia.org/wiki/Locker-Lampson>", "predicate": "schema:attendee", "object_value": "<https://en.wikipedia.org/wiki/Albert_Einstein>"}
# #   emit_triple: {"statement_id": 3, "subject": "<https://en.wikipedia.org/wiki/Albert_Einstein>", "predicate": "schema:attendee", "object_value": "<https://en.wikipedia.org/wiki/Lloyd_George>"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibpe47mqgtrfk5x5mki7aci5kckes5e5y7ejsxkfz2bfclzouf7la",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibpe47mqgtrfk5x5mki7aci5kckes5e5y7ejsxkfz2bfclzouf7la",
#   "prov:label": "rdf:25_7",
#   "_cell": 696,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaaq37pvowhgtdqmfkp36mo3ehvpeq45fvcnthwiivzdjiobsv66q"
#   },
#   "_stmt_key": "25_7",
#   "_chunk_num": 25,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [25.8]: [Albert Einstein](/wiki/Albert_Einstein) later contacted leaders of other nations, including Turkey's Prime Minister [İsmet İnönü](/wiki/%C4%B0smet_%C4%B0n%C3%B6n%C3%BC).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/%C4%B0smet_%C4%B0n%C3%B6n%C3%BC> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihx7lhwoy4qow5qmt2srtfbot4vzmqcg4rdqzoqz27r36sp7fti64",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihx7lhwoy4qow5qmt2srtfbot4vzmqcg4rdqzoqz27r36sp7fti64",
#   "prov:label": "rdf:25_8",
#   "_cell": 698,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigxsxedr4jzvf2uw3a6yglnmxu3natgdkyqvqbortdalm2be7q7bu"
#   },
#   "_stmt_key": "25_8",
#   "_chunk_num": 25,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [25.9]: [Albert Einstein](/wiki/Albert_Einstein) wrote to [İsmet İnönü](/wiki/%C4%B0smet_%C4%B0n%C3%B6n%C3%BC) in September 1933, requesting placement of unemployed German-Jewish scientists.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:sender <https://en.wikipedia.org/wiki/%C4%B0smet_%C4%B0n%C3%B6n%C3%BC> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidfamevkjmvuarkknq7ihvokcfb2rwcbjq4g6ck47eu4blfpin5bq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidfamevkjmvuarkknq7ihvokcfb2rwcbjq4g6ck47eu4blfpin5bq",
#   "prov:label": "rdf:25_9",
#   "_cell": 700,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigeqdfesmb6iacrxprenwe6bu37rwellniandgcq4wz22v4fp3biq"
#   },
#   "_stmt_key": "25_9",
#   "_chunk_num": 25,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [25.10]: As a result of [Albert Einstein](/wiki/Albert_Einstein)'s letter to [İsmet İnönü](/wiki/%C4%B0smet_%C4%B0n%C3%B6n%C3%BC), Jewish invitees to Turkey eventually totaled over "1,000 saved individuals".
# <https://en.wikipedia.org/wiki/%C4%B0smet_%C4%B0n%C3%B6n%C3%BC> schema:attendee <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibaani2ffzi7vhcj2ortn2pjicgagoz3jhznuhu5egmddjxnpccv4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibaani2ffzi7vhcj2ortn2pjicgagoz3jhznuhu5egmddjxnpccv4",
#   "prov:label": "rdf:25_10",
#   "_cell": 702,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreialtiyybht6bosyz2suskvnywpt437rf7bnpoks35uosjusdl2nkq"
#   },
#   "_stmt_key": "25_10",
#   "_chunk_num": 25,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [25.11]: [Locker-Lampson](/wiki/Locker-Lampson) submitted a bill to parliament to extend British citizenship to [Albert Einstein](/wiki/Albert_Einstein).
# <https://en.wikipedia.org/wiki/Locker-Lampson> schema:legislationPassedBy <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieykw5uxmvhwnjv3e35gk4ao5sbp6meuyybrruidlefs57ior4s6i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieykw5uxmvhwnjv3e35gk4ao5sbp6meuyybrruidlefs57ior4s6i",
#   "prov:label": "rdf:25_11",
#   "_cell": 704,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidrkgm2x6m6qlpgjpj7in66jfxvvc4cn5bycfgex6e5feolpu3ibq"
#   },
#   "_stmt_key": "25_11",
#   "_chunk_num": 25,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [25.12]: During the period when [Locker-Lampson](/wiki/Locker-Lampson) submitted the bill, [Albert Einstein](/wiki/Albert_Einstein) made a number of public appearances describing the crisis brewing in Europe.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:performer <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifoqljksw7kyjycdbkbi4n7pe742n4iklk6rhnwtri5djjnjjjtye",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifoqljksw7kyjycdbkbi4n7pe742n4iklk6rhnwtri5djjnjjjtye",
#   "prov:label": "rdf:25_12",
#   "_cell": 706,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihluzwx76oooveryg7usfjiim76jhaur5rxd6yfbbm6k66etfeecq"
#   },
#   "_stmt_key": "25_12",
#   "_chunk_num": 25,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [25.13]: In one of his speeches, [Albert Einstein](/wiki/Albert_Einstein) denounced Germany's treatment of Jews.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:performer <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieqwtfipk6v6waa3ooz7qe3beo3jkuf42ouro4v5cmopgqapoonsi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieqwtfipk6v6waa3ooz7qe3beo3jkuf42ouro4v5cmopgqapoonsi",
#   "prov:label": "rdf:25_13",
#   "_cell": 708,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibmphxsftgr2ykbd53mxamdi2ent7hjjivxhps2p4njqrltco26tu"
#   },
#   "_stmt_key": "25_13",
#   "_chunk_num": 25,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [25.14]: In one of his speeches, [Albert Einstein](/wiki/Albert_Einstein) introduced a bill promoting Jewish citizenship in Palestine.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihdwvctb7cnuonvzxlgm3wy5ddajhz76v2lthcn2ki4l5e2cclpbi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihdwvctb7cnuonvzxlgm3wy5ddajhz76v2lthcn2ki4l5e2cclpbi",
#   "prov:label": "rdf:25_14",
#   "_cell": 710,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigpsyukja3ey7yzs5eghwbbinugywgo7bil5yhvvifoxukayuhuti"
#   },
#   "_stmt_key": "25_14",
#   "_chunk_num": 25,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [25.15]: In his speech, [Albert Einstein](/wiki/Albert_Einstein) described himself as a "citizen of the world" who should be offered a temporary shelter in the UK.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidqprwxyq4rxcid4pyw4edx3vuz4dpy72n32mlf5x5absqkik7s3q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidqprwxyq4rxcid4pyw4edx3vuz4dpy72n32mlf5x5absqkik7s3q",
#   "prov:label": "rdf:25_15",
#   "_cell": 712,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigvdal3su4wvngyfehdd2gljtg6xr2alkoqdmd5yvl45m74wtjwta"
#   },
#   "_stmt_key": "25_15",
#   "_chunk_num": 25,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [25.16]: Both bills submitted by [Locker-Lampson](/wiki/Locker-Lampson) failed.
# <https://en.wikipedia.org/wiki/Locker-Lampson> schema:legislationPassedBy <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibpdbf6yohqogaohkqeebbvw5h7lbwlc4jw434jig67xznn7bo3na",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibpdbf6yohqogaohkqeebbvw5h7lbwlc4jw434jig67xznn7bo3na",
#   "prov:label": "rdf:25_16",
#   "_cell": 714,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiabf4wk6vicwrkopnc6s5f5oel4ttak2jejw55h5fv7nxqpf3iam4"
#   },
#   "_stmt_key": "25_16",
#   "_chunk_num": 25,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [25.17]: [Albert Einstein](/wiki/Albert_Einstein) then accepted an earlier offer from the [Institute for Advanced Study](/wiki/Institute_for_Advanced_Study) in [Princeton, New Jersey](/wiki/Princeton%2C_New_Jersey), US, to become a resident scholar.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:acceptedOffer <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigktugvrmaqxafnhn3u6qi626w6idkfffccukzog62yffquuwt2jq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigktugvrmaqxafnhn3u6qi626w6idkfffccukzog62yffquuwt2jq",
#   "prov:label": "rdf:25_17",
#   "_cell": 716,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiew3h4tynsdvuxfxfohbu6pt7j7476gdxp746yygo6ncvqt3miw3y"
#   },
#   "_stmt_key": "25_17",
#   "_chunk_num": 25,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [26.1]: [Albert Einstein](/wiki/Albert_Einstein) delivered a speech on 3 October 1933 at the [Royal Albert Hall](/wiki/Royal_Albert_Hall) in London.
# _:s1_event1 rdf:type schema:Event .
# _:s1_event1 schema:startDate "1933-10-03"^^xsd:date .
# _:s1_event1 schema:location <https://en.wikipedia.org/wiki/Royal_Albert_Hall> .
# _:s1_event1 schema:performer <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:performerIn _:s1_event1 .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaaiu4gh5paisd5caj7vqndarzyu6tllyydqka6ie4tndfaawxpbe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaaiu4gh5paisd5caj7vqndarzyu6tllyydqka6ie4tndfaawxpbe",
#   "prov:label": "rdf:26_1",
#   "_cell": 718,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifviay3f5iexd5pdy6vkoairwudu4d35ceg3nis6f5wradqehn7mu"
#   },
#   "_stmt_key": "26_1",
#   "_chunk_num": 26,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [26.2]: [Albert Einstein](/wiki/Albert_Einstein) was widely cheered during his speech at the [Royal Albert Hall](/wiki/Royal_Albert_Hall) in London.
# _:s2_event1 rdf:type schema:Event .
# _:s2_event1 schema:startDate "1933-10-03"^^xsd:date .
# _:s2_event1 schema:location <https://en.wikipedia.org/wiki/Royal_Albert_Hall> .
# _:s2_event1 schema:attendees <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee _:s2_event1 .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidt4d3wwpcayakyy46hydyfvfxvyem5g4ipbqqyfr2jjj5wy5drdm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidt4d3wwpcayakyy46hydyfvfxvyem5g4ipbqqyfr2jjj5wy5drdm",
#   "prov:label": "rdf:26_2",
#   "_cell": 720,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiel2sj6liwhw4rak7mbrpvdustgm6yj6n4lwoqrklvso4pqguwruq"
#   },
#   "_stmt_key": "26_2",
#   "_chunk_num": 26,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [26.3]: [Albert Einstein](/wiki/Albert_Einstein) lived in [Princeton, New Jersey](/wiki/Princeton%2C_New_Jersey) from 1935 onwards.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:homeLocation <https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreid3ceznfysr2sc6gay5fd3ncf4tmn5j73p57y4znwrdrjsmtoxo3e",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreid3ceznfysr2sc6gay5fd3ncf4tmn5j73p57y4znwrdrjsmtoxo3e",
#   "prov:label": "rdf:26_3",
#   "_cell": 722,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicg6iojzde7o46finijsbsaoz2j5e5lxdst2sfiheauhkxeukffie"
#   },
#   "_stmt_key": "26_3",
#   "_chunk_num": 26,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [26.4]: [Albert Einstein](/wiki/Albert_Einstein) developed a close friendship with [Kurt Gödel](/wiki/Kurt_Gödel) in Princeton.
# _:s4_friendship1 rdf:type schema:BefriendAction .
# _:s4_friendship1 schema:agent <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s4_friendship1 schema:object <https://en.wikipedia.org/wiki/Kurt_Gödel> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Kurt_Gödel> .
# <https://en.wikipedia.org/wiki/Kurt_Gödel> schema:knows <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicpn5gcy4hf53dspdbnabbhnwj7ofdzmxhyzvzcsrhqlsypxugz3y",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicpn5gcy4hf53dspdbnabbhnwj7ofdzmxhyzvzcsrhqlsypxugz3y",
#   "prov:label": "rdf:26_4",
#   "_cell": 724,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiavgbneoxd366hrkyblt5dheshmjs52q5usm7s5ejrehmwbmmgyae"
#   },
#   "_stmt_key": "26_4",
#   "_chunk_num": 26,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [26.5]: [Albert Einstein](/wiki/Albert_Einstein) and [Kurt Gödel](/wiki/Kurt_Gödel) took long walks together discussing their work.
# _:s5_action1 rdf:type schema:InteractAction .
# _:s5_action1 schema:agent <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s5_action1 schema:object <https://en.wikipedia.org/wiki/Kurt_Gödel> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:colleague <https://en.wikipedia.org/wiki/Kurt_Gödel> .
# <https://en.wikipedia.org/wiki/Kurt_Gödel> schema:colleague <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiagrqxsww7y2mryz5z5jrse37mbwbbpybyt6dt3hf5xa6jeqoukai",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiagrqxsww7y2mryz5z5jrse37mbwbbpybyt6dt3hf5xa6jeqoukai",
#   "prov:label": "rdf:26_5",
#   "_cell": 726,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreign7swc7ad572dh2urgor75nnm5hcpvn2jh7wakrgqrcn2tv76ray"
#   },
#   "_stmt_key": "26_5",
#   "_chunk_num": 26,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [26.6]: [Bruria Kaufman](/wiki/Bruria_Kaufman) was [Albert Einstein](/wiki/Albert_Einstein)'s assistant.
# <https://en.wikipedia.org/wiki/Bruria_Kaufman> schema:colleague <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigpn46pzhccrovriulqimoo6alyr3uuwwcdqt74kds7htseoz4tbi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigpn46pzhccrovriulqimoo6alyr3uuwwcdqt74kds7htseoz4tbi",
#   "prov:label": "rdf:26_6",
#   "_cell": 728,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreievj6h6px55aky3swjp4iravlumotpoef2inq72ojxw6nxstbhmwy"
#   },
#   "_stmt_key": "26_6",
#   "_chunk_num": 26,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [26.7]: [Bruria Kaufman](/wiki/Bruria_Kaufman) later became a physicist.
# <https://en.wikipedia.org/wiki/Bruria_Kaufman> rdf:type schema:Person .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibyhsfaakewcau3ljxb2kzrwx6qkevzahee7bhissg6ebiqgl63xa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibyhsfaakewcau3ljxb2kzrwx6qkevzahee7bhissg6ebiqgl63xa",
#   "prov:label": "rdf:26_7",
#   "_cell": 730,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigs23dlzzczoowvbyo2gjqdzuc5dddqisl45uh5243c5u6funcpxu"
#   },
#   "_stmt_key": "26_7",
#   "_chunk_num": 26,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [26.8]: [Albert Einstein](/wiki/Albert_Einstein) tried to develop a [unified field theory](/wiki/unified_field_theory) during this period.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Albert Einstein tried to develop a unified field theory during this period." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihveupj672xb7w2bf2ow3vot4kzaycintgpmszt5x3f2lbpywcd74",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihveupj672xb7w2bf2ow3vot4kzaycintgpmszt5x3f2lbpywcd74",
#   "prov:label": "rdf:26_8",
#   "_cell": 732,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicghs63bxuxveshet6gxprcbt3n4fp5dhtz3kzcbgufkxxpokke4e"
#   },
#   "_stmt_key": "26_8",
#   "_chunk_num": 26,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [26.9]: [Albert Einstein](/wiki/Albert_Einstein) tried to refute the [accepted interpretation](/wiki/Copenhagen_interpretation) of [quantum physics](/wiki/quantum_physics) during this period.
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Albert Einstein tried to refute the accepted interpretation of quantum physics during this period." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiedmhmveyz6cizpyxvszbcdb6r33p5d7js3n6rnbd76zl4goq2j7q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiedmhmveyz6cizpyxvszbcdb6r33p5d7js3n6rnbd76zl4goq2j7q",
#   "prov:label": "rdf:26_9",
#   "_cell": 734,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih3omwex3jutmdk5heyioex6y6xss7qy3citejjpnmytsre2juxfm"
#   },
#   "_stmt_key": "26_9",
#   "_chunk_num": 26,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [26.10]: [Albert Einstein](/wiki/Albert_Einstein) was unsuccessful in developing a [unified field theory](/wiki/unified_field_theory).
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Albert Einstein was unsuccessful in developing a unified field theory." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiepa5xtffkfyfhe5lzyd6pogtkltnwar2qkloto7r3nx3kaiqjacq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiepa5xtffkfyfhe5lzyd6pogtkltnwar2qkloto7r3nx3kaiqjacq",
#   "prov:label": "rdf:26_10",
#   "_cell": 736,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigwsrursb5dfjqvdfwddhcgk4e77gaq6zhck2afoaddjx4wt3z4aq"
#   },
#   "_stmt_key": "26_10",
#   "_chunk_num": 26,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [26.11]: [Albert Einstein](/wiki/Albert_Einstein) was unsuccessful in refuting the [accepted interpretation](/wiki/Copenhagen_interpretation) of [quantum physics](/wiki/quantum_physics).
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Albert Einstein was unsuccessful in refuting the accepted interpretation of quantum physics." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifxlfurofoz3twt2bnc7q4ss2vdsvekwkzblfovfhdladbxbrktme",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifxlfurofoz3twt2bnc7q4ss2vdsvekwkzblfovfhdladbxbrktme",
#   "prov:label": "rdf:26_11",
#   "_cell": 738,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih7t2qakrj6mmtowz2xpt33otgm5nfny7lcgbynvl57ky5dxgweii"
#   },
#   "_stmt_key": "26_11",
#   "_chunk_num": 26,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [26.12]: The [Albert Einstein House](/wiki/Albert_Einstein_House) was made a [National Historic Landmark](/wiki/National_Historic_Landmark) in 1976.
# <https://en.wikipedia.org/wiki/Albert_Einstein_House> rdf:type schema:LandmarksOrHistoricalBuildings .
# <https://en.wikipedia.org/wiki/Albert_Einstein_House> schema:datePublished "1976"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibwvsjkdat6fkrl4a5rwye2fk3qyj53mlm3delrxb3ke6xflhwf7y",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibwvsjkdat6fkrl4a5rwye2fk3qyj53mlm3delrxb3ke6xflhwf7y",
#   "prov:label": "rdf:26_12",
#   "_cell": 740,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihksd4ynisiyheafbxox6op3djac4zbvnjvdmzxpdpdej4hvc7fsq"
#   },
#   "_stmt_key": "26_12",
#   "_chunk_num": 26,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [27.1]: In 1939, a group of Hungarian scientists that included émigré physicist [Leó Szilárd](/wiki/Le%C3%B3_Szil%C3%A1rd) attempted to alert [Washington, D.C.](/wiki/Washington%2C_D.C.) to ongoing Nazi atomic bomb research.
# _:s1_quote1 rdf:type schema:Quotation .
# _:s1_quote1 schema:text "In 1939, a group of Hungarian scientists that included émigré physicist Leó Szilárd attempted to alert Washington, D.C. to ongoing Nazi atomic bomb research." .
# _:s1_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreih3cv56ti7lysmar56sbl3ihkb5mmravjvbn2ugri2sgqgdu6ckai",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreih3cv56ti7lysmar56sbl3ihkb5mmravjvbn2ugri2sgqgdu6ckai",
#   "prov:label": "rdf:27_1",
#   "_cell": 742,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreickq2zo5w6vldv4zqfdwcf62d3s2zvesrgro3g5fyweibqld3txie"
#   },
#   "_stmt_key": "27_1",
#   "_chunk_num": 27,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [27.2]: The group's warnings were discounted.
# _:s2_quote1 rdf:type schema:Quotation .
# _:s2_quote1 schema:text "The group's warnings were discounted." .
# _:s2_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibefwcz2dmrdghwhqmhptxu4crhulizoi5w4vmk4rcgd6jxrxqhwi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibefwcz2dmrdghwhqmhptxu4crhulizoi5w4vmk4rcgd6jxrxqhwi",
#   "prov:label": "rdf:27_2",
#   "_cell": 744,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid6kmeicrzmk77ycy3ekdzl4mlgfortdahlhp7ld6m2lhx77fahcm"
#   },
#   "_stmt_key": "27_2",
#   "_chunk_num": 27,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [27.3]: [Albert Einstein](/wiki/Albert_Einstein) and [Leó Szilárd](/wiki/Le%C3%B3_Szil%C3%A1rd) , along with other refugees such as [Edward Teller](/wiki/Edward_Teller) and [Eugene Wigner](/wiki/Eugene_Wigner), regarded it as their responsibility to alert Americans to the possibility that German scientists might win the [race to build an atomic bomb](/wiki/German_nuclear_energy_project).
# _:s3_quote1 rdf:type schema:Quotation .
# _:s3_quote1 schema:text "Albert Einstein and Leó Szilárd, along with other refugees such as Edward Teller and Eugene Wigner, regarded it as their responsibility to alert Americans to the possibility that German scientists might win the race to build an atomic bomb." .
# _:s3_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreid5i5fqs6aroc5zmwhbpfu4h2lwpngotpik6ne7wgn7w47yscn5xu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreid5i5fqs6aroc5zmwhbpfu4h2lwpngotpik6ne7wgn7w47yscn5xu",
#   "prov:label": "rdf:27_3",
#   "_cell": 746,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieeeu4zhkju7sw5f6ltozvbqfunvplumovsehxkjk46rytjfiqmsm"
#   },
#   "_stmt_key": "27_3",
#   "_chunk_num": 27,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [27.4]: [Albert Einstein](/wiki/Albert_Einstein) and [Leó Szilárd](/wiki/Le%C3%B3_Szil%C3%A1rd) warned that Hitler would be more than willing to resort to such a weapon.
# _:s4_quote1 rdf:type schema:Quotation .
# _:s4_quote1 schema:text "Albert Einstein and Leó Szilárd warned that Hitler would be more than willing to resort to such a weapon." .
# _:s4_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifv7t3gnld4auhtymyry46ipdw7hjpijlrmuahtseqsakfspja3ja",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifv7t3gnld4auhtymyry46ipdw7hjpijlrmuahtseqsakfspja3ja",
#   "prov:label": "rdf:27_4",
#   "_cell": 748,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihs7o4uplguqeuzc35lyqyxxrsvzcvgf3k5foehrzijagv7e5wrz4"
#   },
#   "_stmt_key": "27_4",
#   "_chunk_num": 27,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [27.5]: In 1960, [Albert Einstein](/wiki/Albert_Einstein) was included posthumously as a charter member of the [World Academy of Art and Science](/wiki/World_Academy_of_Art_and_Science) (WAAS).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award _:s5_role1 .
# _:s5_role1 rdf:type schema:Role .
# _:s5_role1 schema:award <https://en.wikipedia.org/wiki/World_Academy_of_Art_and_Science> .
# _:s5_role1 schema:startDate "1960"^^xsd:gYear .
# _:s5_role1 schema:endDate "1960"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiajjrz75v6pvtmvhpefj76lngwdranhu2jlbznsbawmphnjqasrju",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiajjrz75v6pvtmvhpefj76lngwdranhu2jlbznsbawmphnjqasrju",
#   "prov:label": "rdf:27_5",
#   "_cell": 750,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifznwdpubxoo3bdb5lhi4jme5ohchsizijqwdm5s3iub6aa254lpe"
#   },
#   "_stmt_key": "27_5",
#   "_chunk_num": 27,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [27.6]: The [World Academy of Art and Science](/wiki/World_Academy_of_Art_and_Science) (WAAS) is an organization founded by distinguished scientists and intellectuals.
# <https://en.wikipedia.org/wiki/World_Academy_of_Art_and_Science> rdf:type schema:Organization .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibvahjeqobd2jg65pngi2fv34d2el7nbakz273zx422gd4pzbzvva",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibvahjeqobd2jg65pngi2fv34d2el7nbakz273zx422gd4pzbzvva",
#   "prov:label": "rdf:27_6",
#   "_cell": 752,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiafpuiqhqgdymdr4hqhikhikrpwo4kxbgzbnqvbmzfiqyr6grcp5y"
#   },
#   "_stmt_key": "27_6",
#   "_chunk_num": 27,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [27.7]: The [World Academy of Art and Science](/wiki/World_Academy_of_Art_and_Science) (WAAS) committed itself to the responsible and ethical advances of science.
# <https://en.wikipedia.org/wiki/World_Academy_of_Art_and_Science> schema:description "an organization founded by distinguished scientists and intellectuals" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicxzsigc6f3xl2selxxt2ln3nwc4e7vsmu7ivmvnshk6g7dscchta",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicxzsigc6f3xl2selxxt2ln3nwc4e7vsmu7ivmvnshk6g7dscchta",
#   "prov:label": "rdf:27_7",
#   "_cell": 754,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidvfi3tolbdauiadhfuuipjhc7ubjgcumo65kl4pn55kx5umncksu"
#   },
#   "_stmt_key": "27_7",
#   "_chunk_num": 27,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [27.8]: The [World Academy of Art and Science](/wiki/World_Academy_of_Art_and_Science) (WAAS) was founded particularly in light of the development of nuclear weapons.
# <https://en.wikipedia.org/wiki/World_Academy_of_Art_and_Science> schema:description "an organization committed to the responsible and ethical advances of science, founded particularly in light of the development of nuclear weapons" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifvc4zk36oagvttj4dfkqjf4u2fcwei243yo7rpdqt5qgim67p3ni",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifvc4zk36oagvttj4dfkqjf4u2fcwei243yo7rpdqt5qgim67p3ni",
#   "prov:label": "rdf:27_8",
#   "_cell": 756,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia4amd6ptfeglv745umu3kj64jzsdewezpiiixzyc4yf2ehmgursq"
#   },
#   "_stmt_key": "27_8",
#   "_chunk_num": 27,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [27.9]: [Albert Einstein](/wiki/Albert_Einstein) became an American citizen in 1940.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality _:s9_role1 .
# _:s9_role1 rdf:type schema:Role .
# _:s9_role1 schema:nationality <https://en.wikipedia.org/wiki/Citizenship_of_the_United_States> .
# _:s9_role1 schema:startDate "1940"^^xsd:gYear .
# _:s9_role1 schema:endDate "1955"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaax5a3zszj3mwtyv7zgcrihxgjxvrmaedyodytex7o253fpn5s64",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaax5a3zszj3mwtyv7zgcrihxgjxvrmaedyodytex7o253fpn5s64",
#   "prov:label": "rdf:27_9",
#   "_cell": 758,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigqjbdzmnpmzbh47pgoenrqpao7lnggjie4xjqqzkju25c5ftdn5y"
#   },
#   "_stmt_key": "27_9",
#   "_chunk_num": 27,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [27.10]: [Albert Einstein](/wiki/Albert_Einstein) settled into his career at the [Institute for Advanced Study](/wiki/Institute_for_Advanced_Study) in [Princeton, New Jersey](/wiki/Princeton%2C_New_Jersey).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor _:s10_role1 .
# _:s10_role1 rdf:type schema:OrganizationRole .
# _:s10_role1 schema:worksFor <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> .
# _:s10_role1 schema:startDate "1933"^^xsd:gYear .
# _:s10_role1 schema:endDate "1955"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifwzgehba5l44b4x3yizsvnb5gxm7d77a4bt7itjm4d6bbz54qq6q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifwzgehba5l44b4x3yizsvnb5gxm7d77a4bt7itjm4d6bbz54qq6q",
#   "prov:label": "rdf:27_10",
#   "_cell": 760,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigss5mxw335emscq72fd3abjtjhishvcrhrv55c7z7wyec4kuxrmm"
#   },
#   "_stmt_key": "27_10",
#   "_chunk_num": 27,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [27.11]: [Albert Einstein](/wiki/Albert_Einstein) expressed his appreciation of the [meritocracy](/wiki/meritocracy) in American culture compared to Europe.
# _:s11_quote1 rdf:type schema:Quotation .
# _:s11_quote1 schema:text "Albert Einstein expressed his appreciation of the meritocracy in American culture compared to Europe." .
# _:s11_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiberaq53bldb27jgyiz5lwcbh2m5e36rqezykath6eaxb6hvmxez4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiberaq53bldb27jgyiz5lwcbh2m5e36rqezykath6eaxb6hvmxez4",
#   "prov:label": "rdf:27_11",
#   "_cell": 762,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreif3tdhgbecx7w62widgkkr75b7hvtg3voh2zj2qn24tolr4yxjula"
#   },
#   "_stmt_key": "27_11",
#   "_chunk_num": 27,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [27.12]: [Albert Einstein](/wiki/Albert_Einstein) recognized the "right of individuals to say and think what they pleased" without social barriers.
# _:s12_quote1 rdf:type schema:Quotation .
# _:s12_quote1 schema:text "Albert Einstein recognized the \"right of individuals to say and think what they pleased\" without social barriers." .
# _:s12_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreig5v7d4scu7g5g4w2lpzxplvq3tme7ctfhvn5ipp6ojmohgn76blq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreig5v7d4scu7g5g4w2lpzxplvq3tme7ctfhvn5ipp6ojmohgn76blq",
#   "prov:label": "rdf:27_12",
#   "_cell": 764,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidesuakdf3luyxsufjll3tnrrutdgjblttvgb3onurbuvgyqpgz6y"
#   },
#   "_stmt_key": "27_12",
#   "_chunk_num": 27,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [27.13]: [Albert Einstein](/wiki/Albert_Einstein) said that individuals were encouraged to be more creative.
# _:s13_quote1 rdf:type schema:Quotation .
# _:s13_quote1 schema:text "Albert Einstein said that individuals were encouraged to be more creative." .
# _:s13_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia5catbcrl75jsyugmxidbykon36ym656un6celril3coero54k7a",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia5catbcrl75jsyugmxidbykon36ym656un6celril3coero54k7a",
#   "prov:label": "rdf:27_13",
#   "_cell": 766,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiclhhptv6d3fjybwgsagcaep4x4yhenkjdfrx3mmqsngcfv6kx4r4"
#   },
#   "_stmt_key": "27_13",
#   "_chunk_num": 27,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [27.14]: [Albert Einstein](/wiki/Albert_Einstein) valued creativity from his early education.
# _:s14_quote1 rdf:type schema:Quotation .
# _:s14_quote1 schema:text "Albert Einstein valued creativity from his early education." .
# _:s14_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifjgxftnr4smqhvtt66ngkdjyahuu6bo3gjvoaiehuyj7u26kirhi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifjgxftnr4smqhvtt66ngkdjyahuu6bo3gjvoaiehuyj7u26kirhi",
#   "prov:label": "rdf:27_14",
#   "_cell": 768,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreielf6kbojttt7y2uozfjg54yry6ifndudpyqb5abikkhimi3tnwuy"
#   },
#   "_stmt_key": "27_14",
#   "_chunk_num": 27,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [28.1]: [Albert Einstein](/wiki/Albert_Einstein) joined the [National Association for the Advancement of Colored People](/wiki/National_Association_for_the_Advancement_of_Colored_People) (NAACP) in [Princeton, New Jersey](/wiki/Princeton%2C_New_Jersey).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:memberOf <https://en.wikipedia.org/wiki/National_Association_for_the_Advancement_of_Colored_People> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreica7dh7ieurstigaqnzp52pnr23oltfryk3gtmm4n6qhbmfwisqs4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreica7dh7ieurstigaqnzp52pnr23oltfryk3gtmm4n6qhbmfwisqs4",
#   "prov:label": "rdf:28_1",
#   "_cell": 770,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiezcm26l3gz6dddbah33nov63szbtwbk7mt4w4guwjbgasxsewko4"
#   },
#   "_stmt_key": "28_1",
#   "_chunk_num": 28,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [28.2]: [Albert Einstein](/wiki/Albert_Einstein) campaigned for the [civil rights](/wiki/Civil_rights_movement_%281896%E2%80%931954%29) of African Americans.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:campaign <https://en.wikipedia.org/wiki/Civil_rights_movement_%281896%E2%80%931954%29> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifrkhwgtt3xjip3fuxxf57tvzj24i3jlox4kcnl4a5e4uzbmu5wly",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifrkhwgtt3xjip3fuxxf57tvzj24i3jlox4kcnl4a5e4uzbmu5wly",
#   "prov:label": "rdf:28_2",
#   "_cell": 772,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicvspw2g4f4glzzy4o6d2mkrdj4gl2c722uknmgv2igjhqlupolie"
#   },
#   "_stmt_key": "28_2",
#   "_chunk_num": 28,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [28.3]: [Albert Einstein](/wiki/Albert_Einstein) considered racism America's "worst disease".
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:comment "Being a Jew myself, perhaps I can understand and empathize with how black people feel as victims of discrimination" .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:text "Being a Jew myself, perhaps I can understand and empathize with how black people feel as victims of discrimination" .
# _:s3_quote1 rdf:type schema:Quotation .
# _:s3_quote1 schema:text "Being a Jew myself, perhaps I can understand and empathize with how black people feel as victims of discrimination" .
# _:s3_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifilwwugxzkhfsngxkln5gippmsab7qpodjr2m3ovtp26z5f72wwi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifilwwugxzkhfsngxkln5gippmsab7qpodjr2m3ovtp26z5f72wwi",
#   "prov:label": "rdf:28_3",
#   "_cell": 774,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiel2ohexetakpdcyjjizdokbcj6dkpdrswn4fz7yikyqy526wutum"
#   },
#   "_stmt_key": "28_3",
#   "_chunk_num": 28,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [28.4]: [Albert Einstein](/wiki/Albert_Einstein) saw racism as "handed down from one generation to the next".
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:comment "Being a Jew myself, perhaps I can understand and empathize with how black people feel as victims of discrimination" .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:text "Being a Jew myself, perhaps I can understand and empathize with how black people feel as victims of discrimination" .
# _:s4_quote1 rdf:type schema:Quotation .
# _:s4_quote1 schema:text "Being a Jew myself, perhaps I can understand and empathize with how black people feel as victims of discrimination" .
# _:s4_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiait34oh7ujisrhdq6u4vtdrrfmqu3btkaflezb5u2h55juapviai",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiait34oh7ujisrhdq6u4vtdrrfmqu3btkaflezb5u2h55juapviai",
#   "prov:label": "rdf:28_4",
#   "_cell": 776,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid2hw3bnjd7cr563uscfjzwuutwefh2a4dyju4266jexaixuhd66e"
#   },
#   "_stmt_key": "28_4",
#   "_chunk_num": 28,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [28.5]: [Albert Einstein](/wiki/Albert_Einstein) corresponded with civil rights activist [W. E. B. Du Bois](/wiki/W._E._B._Du_Bois).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:correspondence <https://en.wikipedia.org/wiki/W._E._B._Du_Bois> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigy7p4imvgjtoj4tapiey6wvn64hec4e75mvklrj32goeaf2rxcuq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigy7p4imvgjtoj4tapiey6wvn64hec4e75mvklrj32goeaf2rxcuq",
#   "prov:label": "rdf:28_5",
#   "_cell": 778,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia6mho32tcgpa7edffk3c76au7uebdax3ykm6okxoq64bg4rtk55a"
#   },
#   "_stmt_key": "28_5",
#   "_chunk_num": 28,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [28.6]: [Albert Einstein](/wiki/Albert_Einstein) was prepared to testify on behalf of [W. E. B. Du Bois](/wiki/W._E._B._Du_Bois) during his trial as an alleged foreign agent in 1951.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/W._E._B._Du_Bois> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibjeudi3bw33vjxbpgaunahm747kbj3expcrphilxvlh3qeva7ix4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibjeudi3bw33vjxbpgaunahm747kbj3expcrphilxvlh3qeva7ix4",
#   "prov:label": "rdf:28_6",
#   "_cell": 780,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifjeooumsav5kc2j4vnjeayytigp4bmc6teectps7da3i4ssvqrtm"
#   },
#   "_stmt_key": "28_6",
#   "_chunk_num": 28,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [28.7]: The judge decided to drop the case after [Albert Einstein](/wiki/Albert_Einstein) offered to be a character witness for [W. E. B. Du Bois](/wiki/W._E._B._Du_Bois).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:characterWitness <https://en.wikipedia.org/wiki/W._E._B._Du_Bois> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieuivugfvjvgsolxuydu56ftjuodyrinmityxugqho5mr2ocgy7sm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieuivugfvjvgsolxuydu56ftjuodyrinmityxugqho5mr2ocgy7sm",
#   "prov:label": "rdf:28_7",
#   "_cell": 782,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaplbpehseejsnyxrrdwm6bzb5ut35ae5iljazlsoetr2ci2xlvui"
#   },
#   "_stmt_key": "28_7",
#   "_chunk_num": 28,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [28.8]: In 1946, [Albert Einstein](/wiki/Albert_Einstein) visited [Lincoln University](/wiki/Lincoln_University_%28Pennsylvania%29) in Pennsylvania.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/Lincoln_University_%28Pennsylvania%29> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigtxx6qda345gm3aeql566eynqe3pl3ewxpzplw2nedoshvasxfsi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigtxx6qda345gm3aeql566eynqe3pl3ewxpzplw2nedoshvasxfsi",
#   "prov:label": "rdf:28_8",
#   "_cell": 784,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiadvu743pxfahtboriax7vuo4i5ln7nxpncmhntu4rzvkvxz6akzy"
#   },
#   "_stmt_key": "28_8",
#   "_chunk_num": 28,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [28.9]: [Lincoln University](/wiki/Lincoln_University_%28Pennsylvania%29) is a [historically black college](/wiki/historically_black_college).
# <https://en.wikipedia.org/wiki/Lincoln_University_%28Pennsylvania%29> rdf:type schema:CollegeOrUniversity .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibd5mwkkpdzrcbr4ynrnjxdqpkt3chduivgntwplhxj3vwkhibhum",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibd5mwkkpdzrcbr4ynrnjxdqpkt3chduivgntwplhxj3vwkhibhum",
#   "prov:label": "rdf:28_9",
#   "_cell": 786,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreighfq54gruvo3okeyupckochdlus7tnga7czbq4jym5if37ih4rou"
#   },
#   "_stmt_key": "28_9",
#   "_chunk_num": 28,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [28.10]: [Lincoln University](/wiki/Lincoln_University_%28Pennsylvania%29) was the first university in the [United States](/wiki/Citizenship_of_the_United_States) to grant college degrees to African Americans.
# <https://en.wikipedia.org/wiki/Lincoln_University_%28Pennsylvania%29> schema:alumniOf <https://en.wikipedia.org/wiki/Citizenship_of_the_United_States> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiccwtkgcl235fvoxetxfx63razbecoub3cvz3eqst6qxsjc7wtq6e",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiccwtkgcl235fvoxetxfx63razbecoub3cvz3eqst6qxsjc7wtq6e",
#   "prov:label": "rdf:28_10",
#   "_cell": 788,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreic5hmzx4stdxpal3slexjpz4kezdicoctfqwcsvg7fopgyoeseciy"
#   },
#   "_stmt_key": "28_10",
#   "_chunk_num": 28,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [28.11]: Alumni of [Lincoln University](/wiki/Lincoln_University_%28Pennsylvania%29) include [Langston Hughes](/wiki/Langston_Hughes) and [Thurgood Marshall](/wiki/Thurgood_Marshall).
# <https://en.wikipedia.org/wiki/Lincoln_University_%28Pennsylvania%29> schema:alumniOf <https://en.wikipedia.org/wiki/Langston_Hughes> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie6gidi42ffxevvscwxaepjxbcdmgo4ypu3b2utgwr72brxbbd4ma",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie6gidi42ffxevvscwxaepjxbcdmgo4ypu3b2utgwr72brxbbd4ma",
#   "prov:label": "rdf:28_11",
#   "_cell": 790,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicpsycguebjhkfka4vr5fqtfpmbl5yw4cswixvghfofqv6izkjbei"
#   },
#   "_stmt_key": "28_11",
#   "_chunk_num": 28,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [28.12]: [Albert Einstein](/wiki/Albert_Einstein) was awarded an honorary degree at [Lincoln University](/wiki/Lincoln_University_%28Pennsylvania%29).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:award <https://en.wikipedia.org/wiki/Lincoln_University_%28Pennsylvania%29> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicrm5wy2raq5ffpvtfru6r3xnkwtsj64ur7qqlqx47btea2cuphdu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicrm5wy2raq5ffpvtfru6r3xnkwtsj64ur7qqlqx47btea2cuphdu",
#   "prov:label": "rdf:28_12",
#   "_cell": 792,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih64lik6h4zwgzi22xeiqttoawvztgzlb2qwggrdoe23mntl46uoi"
#   },
#   "_stmt_key": "28_12",
#   "_chunk_num": 28,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [28.13]: [Albert Einstein](/wiki/Albert_Einstein) gave a speech about racism in America at [Lincoln University](/wiki/Lincoln_University_%28Pennsylvania%29).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:performerIn <https://en.wikipedia.org/wiki/Lincoln_University_%28Pennsylvania%29> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaqdtsoslo7ndubodddambxfkezvgdgr66bajco74yeqhx2qgjjnm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaqdtsoslo7ndubodddambxfkezvgdgr66bajco74yeqhx2qgjjnm",
#   "prov:label": "rdf:28_13",
#   "_cell": 794,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigj3w635dhynyujatkosm2t2x67xm6zx4qaxmwyagxcmxe5wkft7m"
#   },
#   "_stmt_key": "28_13",
#   "_chunk_num": 28,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [28.14]: In his speech, [Albert Einstein](/wiki/Albert_Einstein) said, "I do not intend to be quiet about it."
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:text "I do not intend to be quiet about it." .
# _:s14_quote1 rdf:type schema:Quotation .
# _:s14_quote1 schema:text "I do not intend to be quiet about it." .
# _:s14_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreignyfdatnakcff2gcpc4tersih75tgvvvjc33hoophmscxjnsiiai",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreignyfdatnakcff2gcpc4tersih75tgvvvjc33hoophmscxjnsiiai",
#   "prov:label": "rdf:28_14",
#   "_cell": 796,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieg2bsdegw2o3cyy4uu5yng6fb2hdoqk6435nmcu2hoiz4fwx3mki"
#   },
#   "_stmt_key": "28_14",
#   "_chunk_num": 28,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [28.15]: A resident of [Princeton, New Jersey](/wiki/Princeton%2C_New_Jersey) recalls that [Albert Einstein](/wiki/Albert_Einstein) once paid the college tuition for a black student.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibonaj4iukaumer5emtznjnco4cc4hcswlt755dfsr3gtxaht6cqy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibonaj4iukaumer5emtznjnco4cc4hcswlt755dfsr3gtxaht6cqy",
#   "prov:label": "rdf:28_15",
#   "_cell": 798,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicnup5etayq5e3bblfysvkiar6dgf2zgfmwrlqp4g5orr5jno65ke"
#   },
#   "_stmt_key": "28_15",
#   "_chunk_num": 28,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [28.16]: [Albert Einstein](/wiki/Albert_Einstein) said, "Being a Jew myself, perhaps I can understand and empathize with how black people feel as victims of discrimination".
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:text "Being a Jew myself, perhaps I can understand and empathize with how black people feel as victims of discrimination" .
# _:s16_quote1 rdf:type schema:Quotation .
# _:s16_quote1 schema:text "Being a Jew myself, perhaps I can understand and empathize with how black people feel as victims of discrimination" .
# _:s16_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihv2uaiacyqhv4ako2jubyw2sdqofcvulrjyklovmnphgvivhpfjy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihv2uaiacyqhv4ako2jubyw2sdqofcvulrjyklovmnphgvivhpfjy",
#   "prov:label": "rdf:28_16",
#   "_cell": 800,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicuctrvbjl3kffipemy2bbkm4nclk44s7dosbkvhkb3lqj5xq2r6y"
#   },
#   "_stmt_key": "28_16",
#   "_chunk_num": 28,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [28.17]: [Marian Anderson](/wiki/Marian_Anderson), the black contralto, came to [Princeton, New Jersey](/wiki/Princeton%2C_New_Jersey) for a concert in 1937.
# <https://en.wikipedia.org/wiki/Marian_Anderson> schema:attendee <https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiehnw3bcvac4uuzizolkno3bt2g3372jlwyurhyjco4rpwyczxbi4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiehnw3bcvac4uuzizolkno3bt2g3372jlwyurhyjco4rpwyczxbi4",
#   "prov:label": "rdf:28_17",
#   "_cell": 802,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifq66kzi5g26ftjmakinqovlu7cmz4vy44uli65bv42gpp737in2u"
#   },
#   "_stmt_key": "28_17",
#   "_chunk_num": 28,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [28.18]: The [Nassau Inn](/wiki/Nassau_Inn) refused [Marian Anderson](/wiki/Marian_Anderson) a room.
# <https://en.wikipedia.org/wiki/Nassau_Inn> schema:attendee <https://en.wikipedia.org/wiki/Marian_Anderson> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicneamtv6tf66iflfrckgxyefpluoajladovzqwuj6pzzqukl6yie",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicneamtv6tf66iflfrckgxyefpluoajladovzqwuj6pzzqukl6yie",
#   "prov:label": "rdf:28_18",
#   "_cell": 804,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicoqtnqk4us5hawwxrw5f75tfpfoy336vm3diiwih6rlpb7bvqjqi"
#   },
#   "_stmt_key": "28_18",
#   "_chunk_num": 28,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [28.19]: [Albert Einstein](/wiki/Albert_Einstein) invited [Marian Anderson](/wiki/Marian_Anderson) to stay at his house on Main Street.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/Marian_Anderson> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicxbwbuf2ffdqovcfaomex4a5fhvot7ckinri2hso5teysfbrva5y",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicxbwbuf2ffdqovcfaomex4a5fhvot7ckinri2hso5teysfbrva5y",
#   "prov:label": "rdf:28_19",
#   "_cell": 806,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihspsydem4bo7pa7lyjc37dgoizvbg2mb5jzfhxvaohszukx2pudm"
#   },
#   "_stmt_key": "28_19",
#   "_chunk_num": 28,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Statement [28.20]: Staying with [Albert Einstein](/wiki/Albert_Einstein) was a deeply personal as well as symbolic gesture for [Marian Anderson](/wiki/Marian_Anderson).
# <https://en.wikipedia.org/wiki/Marian_Anderson> schema:attendee <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigrwyb6xlyd26h3xkqlrkr5u252sfpsk7iddaiqnkruddomro3qgq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigrwyb6xlyd26h3xkqlrkr5u252sfpsk7iddaiqnkruddomro3qgq",
#   "prov:label": "rdf:28_20",
#   "_cell": 808,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiboi6hjbraeh4xf5plfbkk7ddh3chn5x5toe6wck7ihoswpvl3wmi"
#   },
#   "_stmt_key": "28_20",
#   "_chunk_num": 28,
#   "_stmt_idx": 20
# }

# %% [raw]
# # Statement [28.21]: Whenever [Marian Anderson](/wiki/Marian_Anderson) returned to [Princeton, New Jersey](/wiki/Princeton%2C_New_Jersey), she stayed with [Albert Einstein](/wiki/Albert_Einstein).
# <https://en.wikipedia.org/wiki/Marian_Anderson> schema:attendee <https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreied4o3hd7hytg6r6y7mj2sdtbrbbrc3rvsx2dez2m3vlkcz5cao3e",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreied4o3hd7hytg6r6y7mj2sdtbrbbrc3rvsx2dez2m3vlkcz5cao3e",
#   "prov:label": "rdf:28_21",
#   "_cell": 810,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaby2v6jkebrru57pc5qmhfwne6opdcxyzj45dndtiojwv74yybxm"
#   },
#   "_stmt_key": "28_21",
#   "_chunk_num": 28,
#   "_stmt_idx": 21
# }

# %% [raw]
# # Statement [28.22]: [Marian Anderson](/wiki/Marian_Anderson)'s last visit to [Princeton, New Jersey](/wiki/Princeton%2C_New_Jersey) was just two months before [Albert Einstein](/wiki/Albert_Einstein) died.
# <https://en.wikipedia.org/wiki/Marian_Anderson> schema:attendee <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidxv3bzt6mthees7y3ypstnnlbbotn7qjzvbsvwduqhxqyuga3z3a",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidxv3bzt6mthees7y3ypstnnlbbotn7qjzvbsvwduqhxqyuga3z3a",
#   "prov:label": "rdf:28_22",
#   "_cell": 812,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigvqt6q6yq67kqyp56fffpzwx6recgw4da3l5v26flihbaeglsf5i"
#   },
#   "_stmt_key": "28_22",
#   "_chunk_num": 28,
#   "_stmt_idx": 22
# }

# %% [raw]
# # Statement [29.1]: [Albert Einstein](/wiki/Albert_Einstein) was one of the signatories of the founding proclamation of the [German Democratic Party](/wiki/German_Democratic_Party) in 1918.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:legislationCountersignedBy <https://en.wikipedia.org/wiki/German_Democratic_Party> .
# <https://en.wikipedia.org/wiki/German_Democratic_Party> schema:legislationCountersignedBy <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreid7dbvrwpdd4uxd7xapfegi5w5dayfyd5dokggppu2mkue26z6xy4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreid7dbvrwpdd4uxd7xapfegi5w5dayfyd5dokggppu2mkue26z6xy4",
#   "prov:label": "rdf:29_1",
#   "_cell": 814,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiexebxs75fvoltr3sply6qfdg3auj4ua26qarqqqreoyqpkhpp6pm"
#   },
#   "_stmt_key": "29_1",
#   "_chunk_num": 29,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [29.2]: [Albert Einstein](/wiki/Albert_Einstein) was in favor of [socialism](/wiki/socialism) and critical of capitalism.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:politicalIdeology <https://en.wikipedia.org/wiki/socialism> .
# <https://en.wikipedia.org/wiki/socialism> schema:politicalIdeology <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidqfelz7rp6ofcuwnz4czep3osiiaerm6c6iscirs4upfwgq3jf2q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidqfelz7rp6ofcuwnz4czep3osiiaerm6c6iscirs4upfwgq3jf2q",
#   "prov:label": "rdf:29_2",
#   "_cell": 816,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihujirlfetpjrmxfjw7ozf543kxpvhqihtfkcpqbjgghnitd3lgxy"
#   },
#   "_stmt_key": "29_2",
#   "_chunk_num": 29,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [29.3]: [Albert Einstein](/wiki/Albert_Einstein) wrote essays such as "[Why Socialism?](/wiki/Why_Socialism%3F)" detailing his political views.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author <https://en.wikipedia.org/wiki/Why_Socialism%3F> .
# <https://en.wikipedia.org/wiki/Why_Socialism%3F> schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Why_Socialism%3F> schema:about <https://en.wikipedia.org/wiki/socialism> .
# <https://en.wikipedia.org/wiki/socialism> schema:about <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/socialism> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia4ygtjv3apclt76mertxsobeyyntys7itvgapcy2yaalb3flxgwm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia4ygtjv3apclt76mertxsobeyyntys7itvgapcy2yaalb3flxgwm",
#   "prov:label": "rdf:29_3",
#   "_cell": 818,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid4hlzjrrlndwi55apcsyxoy7kr4glca2xqfe2mmuxgj3w2yn4pjm"
#   },
#   "_stmt_key": "29_3",
#   "_chunk_num": 29,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [29.4]: The FBI created a secret dossier on [Albert Einstein](/wiki/Albert_Einstein) in 1932.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasDigitalDocument <https://en.wikipedia.org/wiki/FBI_dossier_on_Albert_Einstein> .
# <https://en.wikipedia.org/wiki/FBI_dossier_on_Albert_Einstein> schema:about <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/FBI_dossier_on_Albert_Einstein> schema:creator <https://en.wikipedia.org/wiki/Federal_Bureau_of_Investigation> .
# <https://en.wikipedia.org/wiki/Federal_Bureau_of_Investigation> schema:hasDigitalDocument <https://en.wikipedia.org/wiki/FBI_dossier_on_Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Federal_Bureau_of_Investigation> schema:about <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigixtfauhqrkpfj5nuofd3fbzdm6zv37i34emdd4xnn5jcj7hs6ou",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigixtfauhqrkpfj5nuofd3fbzdm6zv37i34emdd4xnn5jcj7hs6ou",
#   "prov:label": "rdf:29_4",
#   "_cell": 820,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigfh5hsaoosgwizgg3brpjw5sfdy6lfls2cs3kw2j4hh73fwz3c4u"
#   },
#   "_stmt_key": "29_4",
#   "_chunk_num": 29,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [29.5]: By the time of his death, the FBI dossier on [Albert Einstein](/wiki/Albert_Einstein) was 1,427 pages long.
# <https://en.wikipedia.org/wiki/FBI_dossier_on_Albert_Einstein> schema:hasPart "1427 pages" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicgztur6dknrtrpqkznrwf4mirco2eoe7irl6mkgjruiqioa7r4b4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicgztur6dknrtrpqkznrwf4mirco2eoe7irl6mkgjruiqioa7r4b4",
#   "prov:label": "rdf:29_5",
#   "_cell": 822,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiewziankx5waou6ksie5j43copn7polllvtaoi6wdbipssjcsvxyy"
#   },
#   "_stmt_key": "29_5",
#   "_chunk_num": 29,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [29.6]: [Albert Einstein](/wiki/Albert_Einstein) was a figurehead leader in the establishment of the [Hebrew University of Jerusalem](/wiki/Hebrew_University_of_Jerusalem).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:founder <https://en.wikipedia.org/wiki/Hebrew_University_of_Jerusalem> .
# <https://en.wikipedia.org/wiki/Hebrew_University_of_Jerusalem> schema:founder <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreif37bpf22hje5nq5hpdq7epxi6wrkeq4mhvhc7briksr66kjeqomq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreif37bpf22hje5nq5hpdq7epxi6wrkeq4mhvhc7briksr66kjeqomq",
#   "prov:label": "rdf:29_6",
#   "_cell": 824,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidabmg5rs23hbb77jvyhqoahgdoj6ieryrtissdajokgpgad27bv4"
#   },
#   "_stmt_key": "29_6",
#   "_chunk_num": 29,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [29.7]: The [Hebrew University of Jerusalem](/wiki/Hebrew_University_of_Jerusalem) opened in 1925.
# <https://en.wikipedia.org/wiki/Hebrew_University_of_Jerusalem> schema:foundingDate "1925"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaa55ayav4a54jlj5t5e3rjwssdnieec2ob4tjzrzbp62tc2a43qq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaa55ayav4a54jlj5t5e3rjwssdnieec2ob4tjzrzbp62tc2a43qq",
#   "prov:label": "rdf:29_7",
#   "_cell": 826,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiasqr5glv7vfzfochaw7j45o5fkjhqztp2jv4vj5geujld562e7ou"
#   },
#   "_stmt_key": "29_7",
#   "_chunk_num": 29,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [29.8]: In 1921, [Albert Einstein](/wiki/Albert_Einstein) was asked by [Chaim Weizmann](/wiki/Chaim_Weizmann) to help raise funds for the planned [Hebrew University of Jerusalem](/wiki/Hebrew_University_of_Jerusalem).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:colleague <https://en.wikipedia.org/wiki/Chaim_Weizmann> .
# <https://en.wikipedia.org/wiki/Chaim_Weizmann> schema:colleague <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic5oacleih2xsnof5zuocrxzholywmigep6kzv5guije2bpbrsqiy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic5oacleih2xsnof5zuocrxzholywmigep6kzv5guije2bpbrsqiy",
#   "prov:label": "rdf:29_8",
#   "_cell": 828,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreictivgpdbitd7es5ovu4notyscviksmctfmeme6ksdhtk3io7aqku"
#   },
#   "_stmt_key": "29_8",
#   "_chunk_num": 29,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [29.9]: [Chaim Weizmann](/wiki/Chaim_Weizmann) was the biochemist and president of the [World Zionist Organization](/wiki/World_Zionist_Organization).
# <https://en.wikipedia.org/wiki/Chaim_Weizmann> schema:jobTitle "President of the World Zionist Organization" .
# <https://en.wikipedia.org/wiki/World_Zionist_Organization> schema:employee <https://en.wikipedia.org/wiki/Chaim_Weizmann> .
# <https://en.wikipedia.org/wiki/Chaim_Weizmann> schema:employee <https://en.wikipedia.org/wiki/World_Zionist_Organization> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreial44huvbmlqnxcekdgchq2hovtfxeq5dpxro2n7ae4gxwklqrmwa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreial44huvbmlqnxcekdgchq2hovtfxeq5dpxro2n7ae4gxwklqrmwa",
#   "prov:label": "rdf:29_9",
#   "_cell": 830,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia5iem776df6tbppsfo4nwamkvdlw2tjrp7klitw23xcfoevfknj4"
#   },
#   "_stmt_key": "29_9",
#   "_chunk_num": 29,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [29.10]: [Albert Einstein](/wiki/Albert_Einstein) suggested creating an Institute of Agriculture, a Chemical Institute, and an Institute of Microbiology at the [Hebrew University of Jerusalem](/wiki/Hebrew_University_of_Jerusalem).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:colleague <https://en.wikipedia.org/wiki/Hebrew_University_of_Jerusalem> .
# <https://en.wikipedia.org/wiki/Hebrew_University_of_Jerusalem> schema:colleague <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihopbwhrocpgavzmd3nipreiow6r3czop5kvjivmvhthoft6aprey",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihopbwhrocpgavzmd3nipreiow6r3czop5kvjivmvhthoft6aprey",
#   "prov:label": "rdf:29_10",
#   "_cell": 832,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreif2hi2b37nif6asjr22ulraxiyqfakxwgtn5lql4hxwwtrll3zf5y"
#   },
#   "_stmt_key": "29_10",
#   "_chunk_num": 29,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [29.11]: [Albert Einstein](/wiki/Albert_Einstein) proposed these institutes to fight ongoing epidemics such as [malaria](/wiki/malaria).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:colleague <https://en.wikipedia.org/wiki/malaria> .
# <https://en.wikipedia.org/wiki/malaria> schema:colleague <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiex27owhbrtc3gwugqicmhvdtig4gdeaet3dgsk3sdpjpoflrwete",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiex27owhbrtc3gwugqicmhvdtig4gdeaet3dgsk3sdpjpoflrwete",
#   "prov:label": "rdf:29_11",
#   "_cell": 834,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihmo3wzunc2qtb32egkocgfcb2ad3dgfltj63km45em3zyhw4cnd4"
#   },
#   "_stmt_key": "29_11",
#   "_chunk_num": 29,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [29.12]: [Albert Einstein](/wiki/Albert_Einstein) called [malaria](/wiki/malaria) an "evil" undermining a third of the country's development.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:creator <https://en.wikipedia.org/wiki/malaria> .
# <https://en.wikipedia.org/wiki/malaria> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicqjvtu723qjhcimgcekxvkt7w2okbg5lc3heh5awmbnurzghb44a",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicqjvtu723qjhcimgcekxvkt7w2okbg5lc3heh5awmbnurzghb44a",
#   "prov:label": "rdf:29_12",
#   "_cell": 836,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifv3aoiquqfn5zfu5dyjxojpzk4tms3asag34n5lcklso3vqbk5em"
#   },
#   "_stmt_key": "29_12",
#   "_chunk_num": 29,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [29.13]: [Albert Einstein](/wiki/Albert_Einstein) promoted the establishment of an Oriental Studies Institute at the [Hebrew University of Jerusalem](/wiki/Hebrew_University_of_Jerusalem).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:colleague <https://en.wikipedia.org/wiki/Hebrew_University_of_Jerusalem> .
# <https://en.wikipedia.org/wiki/Hebrew_University_of_Jerusalem> schema:colleague <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreib2pfn4mz5q6rliecfi3hx4zzy377vseun3suv6manq6fs33ghqb4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreib2pfn4mz5q6rliecfi3hx4zzy377vseun3suv6manq6fs33ghqb4",
#   "prov:label": "rdf:29_13",
#   "_cell": 838,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiczex3tm2i2qdukrbsqaedq2lax2ejqucrna773p3hdg7tefgp6ua"
#   },
#   "_stmt_key": "29_13",
#   "_chunk_num": 29,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [29.14]: The Oriental Studies Institute proposed by [Albert Einstein](/wiki/Albert_Einstein) included language courses given in both [Hebrew](/wiki/Hebrew) and [Arabic](/wiki/Arabic).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:colleague <https://en.wikipedia.org/wiki/Hebrew> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:colleague <https://en.wikipedia.org/wiki/Arabic> .
# <https://en.wikipedia.org/wiki/Hebrew> schema:colleague <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Arabic> schema:colleague <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigkeudbz3tkjwlmc7qddjhzsuudmrgauhcineef7vxf6frlxa2j7a",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigkeudbz3tkjwlmc7qddjhzsuudmrgauhcineef7vxf6frlxa2j7a",
#   "prov:label": "rdf:29_14",
#   "_cell": 840,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid2godsblvjmydkvakqzuxqxiffqzvsxeakd4mss2zmo5z6f73vke"
#   },
#   "_stmt_key": "29_14",
#   "_chunk_num": 29,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [30.1]: [Albert Einstein](/wiki/Albert_Einstein) was not a [nationalist](/wiki/nationalist).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:disagreeAction _:s1_disagree1 .
# _:s1_disagree1 rdf:type schema:DisagreeAction .
# _:s1_disagree1 schema:agent <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s1_disagree1 schema:object <https://en.wikipedia.org/wiki/Nationalism> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiekwzr2hk5nnqw56kflccvuqhhvqxgh3hqtvhzvrg6pkrgxqt3qmy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiekwzr2hk5nnqw56kflccvuqhhvqxgh3hqtvhzvrg6pkrgxqt3qmy",
#   "prov:label": "rdf:30_1",
#   "_cell": 842,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihig7jfkidwck56oizo32uighuuetglmcgukxz4ppxsgv6b3qtmfy"
#   },
#   "_stmt_key": "30_1",
#   "_chunk_num": 30,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [30.2]: [Albert Einstein](/wiki/Albert_Einstein) opposed the creation of an independent Jewish state.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:disagreeAction _:s2_disagree1 .
# _:s2_disagree1 rdf:type schema:DisagreeAction .
# _:s2_disagree1 schema:agent <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s2_disagree1 schema:object <https://en.wikipedia.org/wiki/Creation_of_an_independent_Jewish_state> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreid5z3d4lb5vx3tefq3s6uivtmygonqi5gqlxhanois7ejg5et2edu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreid5z3d4lb5vx3tefq3s6uivtmygonqi5gqlxhanois7ejg5et2edu",
#   "prov:label": "rdf:30_2",
#   "_cell": 844,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib7nn5a6czg7gvm3xjqbsv2mrjmd6evnpagempicr4xmsqqdbvani"
#   },
#   "_stmt_key": "30_2",
#   "_chunk_num": 30,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [30.3]: [Albert Einstein](/wiki/Albert_Einstein) felt that the waves of arriving Jews of the [Aliyah](/wiki/Aliyah) could live alongside existing Arabs in [Palestine](/wiki/Palestine_%28region%29).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:disagreeAction _:s3_disagree1 .
# _:s3_disagree1 rdf:type schema:DisagreeAction .
# _:s3_disagree1 schema:agent <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s3_disagree1 schema:object <https://en.wikipedia.org/wiki/Aliyah> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidslgomweypfrkje6mjfidnwmrek6dcsvwnzpnnfo6uuighafwznm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidslgomweypfrkje6mjfidnwmrek6dcsvwnzpnnfo6uuighafwznm",
#   "prov:label": "rdf:30_3",
#   "_cell": 846,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihh5ew6gfz5fq66yx3ed4qituuj6s7elvvcluyx7eswyeh26coeyy"
#   },
#   "_stmt_key": "30_3",
#   "_chunk_num": 30,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [30.4]: The state of Israel was established in 1948.
# <https://en.wikipedia.org/wiki/State_of_Israel> schema:startDate "1948"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigfdz5za6jbfhlb3eqy3yasyuwdcbxt2nvkx77y7cdqu4poaqsq3u",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigfdz5za6jbfhlb3eqy3yasyuwdcbxt2nvkx77y7cdqu4poaqsq3u",
#   "prov:label": "rdf:30_4",
#   "_cell": 848,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiamqqeawlwtgsqmo4ysepckiar6ep27fe5cgn3q2bru7bi36egcfm"
#   },
#   "_stmt_key": "30_4",
#   "_chunk_num": 30,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [30.5]: The state of Israel was established without the help of [Albert Einstein](/wiki/Albert_Einstein).
# <https://en.wikipedia.org/wiki/State_of_Israel> schema:disagreeAction _:s5_disagree1 .
# _:s5_disagree1 rdf:type schema:DisagreeAction .
# _:s5_disagree1 schema:agent <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s5_disagree1 schema:object <https://en.wikipedia.org/wiki/State_of_Israel> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifg4j7wfrsrayewk6dzxprpwsojqijaq3gmetl2dqdy4k3wyt3fdy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifg4j7wfrsrayewk6dzxprpwsojqijaq3gmetl2dqdy4k3wyt3fdy",
#   "prov:label": "rdf:30_5",
#   "_cell": 850,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih2jgn5qouzonridb45kbezizpknbj5fxkhhyxbtp5ndruklppwbe"
#   },
#   "_stmt_key": "30_5",
#   "_chunk_num": 30,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [30.6]: [Albert Einstein](/wiki/Albert_Einstein) was limited to a marginal role in the [Zionist movement](/wiki/Zionism).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:member _:s6_role1 .
# _:s6_role1 rdf:type schema:Role .
# _:s6_role1 schema:member <https://en.wikipedia.org/wiki/Zionism> .
# _:s6_role1 schema:roleName "marginal role" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreig74hokdmb4buuiarjgtjkrkhtawcamasbk2ii3hgcpletnuudlhm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreig74hokdmb4buuiarjgtjkrkhtawcamasbk2ii3hgcpletnuudlhm",
#   "prov:label": "rdf:30_6",
#   "_cell": 852,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibuhv34vz5ie43isyulcbhgj3blcrbonv5ccbw2u5rmt2rk5tkrqu"
#   },
#   "_stmt_key": "30_6",
#   "_chunk_num": 30,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [30.7]: Israeli president [Chaim Weizmann](/wiki/Chaim_Weizmann) died in November 1952.
# <https://en.wikipedia.org/wiki/Chaim_Weizmann> schema:deathDate "1952-11"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidxyznpugewz6qy4qfvlgpkt3j2ww7zxkfewe6uabi5uau5tomp5m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidxyznpugewz6qy4qfvlgpkt3j2ww7zxkfewe6uabi5uau5tomp5m",
#   "prov:label": "rdf:30_7",
#   "_cell": 854,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibw3hnhtlgzbbvyeyhzdsyjbxxvn6g66ubvkd76arfumxvhyw3frq"
#   },
#   "_stmt_key": "30_7",
#   "_chunk_num": 30,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [30.8]: Prime Minister [David Ben-Gurion](/wiki/David_Ben-Gurion) offered [Albert Einstein](/wiki/Albert_Einstein) the largely ceremonial position of [President of Israel](/wiki/President_of_Israel) upon the death of Israeli president [Chaim Weizmann](/wiki/Chaim_Weizmann).
# <https://en.wikipedia.org/wiki/David_Ben-Gurion> schema:offer _:s8_offer1 .
# _:s8_offer1 rdf:type schema:Offer .
# _:s8_offer1 schema:acceptedBy <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s8_offer1 schema:roleName "President of Israel" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicwxpdircuecwex43jetnb7fp4mm4cfojizl2ihpyfhfvmfo4jcy4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicwxpdircuecwex43jetnb7fp4mm4cfojizl2ihpyfhfvmfo4jcy4",
#   "prov:label": "rdf:30_8",
#   "_cell": 856,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiabm7siwh4jzb4b6nz57yjwl7uzpvcayg3qlejxx6jv3skiq2b7hm"
#   },
#   "_stmt_key": "30_8",
#   "_chunk_num": 30,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [30.9]: The offer of [President of Israel](/wiki/President_of_Israel) to [Albert Einstein](/wiki/Albert_Einstein) was made at the urging of [Ezriel Carlebach](/wiki/Ezriel_Carlebach).
# <https://en.wikipedia.org/wiki/Ezriel_Carlebach> schema:offer _:s9_offer1 .
# _:s9_offer1 rdf:type schema:Offer .
# _:s9_offer1 schema:offeredBy <https://en.wikipedia.org/wiki/Ezriel_Carlebach> .
# _:s9_offer1 schema:acceptedBy <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s9_offer1 schema:roleName "President of Israel" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicrxaw77pe6cqhc56sl4nlwad6tb7742r3crshekie73fybe2zvai",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicrxaw77pe6cqhc56sl4nlwad6tb7742r3crshekie73fybe2zvai",
#   "prov:label": "rdf:30_9",
#   "_cell": 858,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigzdw7eb2kdpf2navmlgisafd5ubjzbiuoracgyv3xlvk3odfcr7i"
#   },
#   "_stmt_key": "30_9",
#   "_chunk_num": 30,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [30.10]: [Lee Smolin](/wiki/Lee_Smolin) believes that a moral quality allowed [Albert Einstein](/wiki/Albert_Einstein) to achieve so much.
# <https://en.wikipedia.org/wiki/Lee_Smolin> schema:hasParticipationOffer _:s10_offer1 .
# _:s10_offer1 rdf:type schema:Offer .
# _:s10_offer1 schema:offeredBy <https://en.wikipedia.org/wiki/Lee_Smolin> .
# _:s10_offer1 schema:acceptedBy <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s10_offer1 schema:roleName "moral quality" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie6vhadayehgb34djgmacny4mrkqxptluuzeia2epiqomzbbqyane",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie6vhadayehgb34djgmacny4mrkqxptluuzeia2epiqomzbbqyane",
#   "prov:label": "rdf:30_10",
#   "_cell": 860,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihuldm2agmteohss5ycaiq3rghmthxffh7zdoz4eq4rcy33qh7zq4"
#   },
#   "_stmt_key": "30_10",
#   "_chunk_num": 30,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [30.11]: [Albert Einstein](/wiki/Albert_Einstein) cared far more than most of his colleagues that the laws of physics have to explain everything in nature coherently and consistently.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasParticipationOffer _:s11_offer1 .
# _:s11_offer1 rdf:type schema:Offer .
# _:s11_offer1 schema:offeredBy <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s11_offer1 schema:roleName "coherence and consistency in physics" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifj6zstn7vmzcdalcy7elsygzso2lyxmkobtwukaen4j4sw4ksclm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifj6zstn7vmzcdalcy7elsygzso2lyxmkobtwukaen4j4sw4ksclm",
#   "prov:label": "rdf:30_11",
#   "_cell": 862,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidkcjqczti4q6lvtdksb7g63c6wlc2eqjrm2aw7mivcqncxcpezi4"
#   },
#   "_stmt_key": "30_11",
#   "_chunk_num": 30,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [30.12]: [Albert Einstein](/wiki/Albert_Einstein) expounded his spiritual outlook in a wide array of writings and interviews.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasParticipationOffer _:s12_offer1 .
# _:s12_offer1 rdf:type schema:Offer .
# _:s12_offer1 schema:offeredBy <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s12_offer1 schema:roleName "spiritual outlook" .
# _:s12_offer1 schema:hasParticipationOffer <https://en.wikipedia.org/wiki/Writings> .
# _:s12_offer1 schema:hasParticipationOffer <https://en.wikipedia.org/wiki/Interviews> .
# _:s12_offer1 schema:hasParticipationOffer <https://en.wikipedia.org/wiki/Scientific_research> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreid4ufbelffrcfhvqosqzhchknwtoazeu2wwfeksoeawqlf3fpk7aq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreid4ufbelffrcfhvqosqzhchknwtoazeu2wwfeksoeawqlf3fpk7aq",
#   "prov:label": "rdf:30_12",
#   "_cell": 864,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih7r6ug2cak56p7cubhwj3bmzalnhaf4yzpb6w3ovekzcb5u3aq6m"
#   },
#   "_stmt_key": "30_12",
#   "_chunk_num": 30,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [31.1]: [Albert Einstein](/wiki/Albert_Einstein) wrote a German-language letter to philosopher [Eric Gutkind](/wiki/Eric_Gutkind) on 3 January 1954.
# _:s1_quote1 rdf:type schema:Quotation .
# _:s1_quote1 schema:text "the word God is for me nothing more than the expression and product of human weaknesses" .
# _:s1_quote1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s1_quote1 schema:datePublished "1954-01-03"^^xsd:date .
# _:s1_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s1_quote1 schema:about <https://en.wikipedia.org/wiki/God_%28word%29> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie7jzo7rb5mmwgoqbheytogpjdfq5m3sqmhwy5daposshw4omslfy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie7jzo7rb5mmwgoqbheytogpjdfq5m3sqmhwy5daposshw4omslfy",
#   "prov:label": "rdf:31_1",
#   "_cell": 866,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiacyt77f6oxv7qgb4rguilplprf4n74f4yitdax6psbuolbo73lb4"
#   },
#   "_stmt_key": "31_1",
#   "_chunk_num": 31,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [31.2]: In his letter to [Eric Gutkind](/wiki/Eric_Gutkind), [Albert Einstein](/wiki/Albert_Einstein) stated that the word [God](/wiki/God_%28word%29) is for him nothing more than the expression and product of human weaknesses.
# _:s2_quote1 rdf:type schema:Quotation .
# _:s2_quote1 schema:text "the word God is for me nothing more than the expression and product of human weaknesses" .
# _:s2_quote1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s2_quote1 schema:datePublished "1954-01-03"^^xsd:date .
# _:s2_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s2_quote1 schema:about <https://en.wikipedia.org/wiki/God_%28word%29> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie46td6am7ptlnlemgursavqg5aq7dfozhvrjgpolgawb6bvasz2m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie46td6am7ptlnlemgursavqg5aq7dfozhvrjgpolgawb6bvasz2m",
#   "prov:label": "rdf:31_2",
#   "_cell": 868,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia23o4ptzk4re67v5tmj5yca27k3dxdc4o36t6aervgqgthgg6ckq"
#   },
#   "_stmt_key": "31_2",
#   "_chunk_num": 31,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [31.3]: In his letter to [Eric Gutkind](/wiki/Eric_Gutkind), [Albert Einstein](/wiki/Albert_Einstein) described the [Bible](/wiki/Bible) as a collection of honorable, but still primitive legends which are nevertheless pretty childish.
# _:s3_quote1 rdf:type schema:Quotation .
# _:s3_quote1 schema:text "the Bible as a collection of honorable, but still primitive legends which are nevertheless pretty childish" .
# _:s3_quote1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s3_quote1 schema:datePublished "1954-01-03"^^xsd:date .
# _:s3_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s3_quote1 schema:about <https://en.wikipedia.org/wiki/Bible> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicbg6o4zywvowpenzstvawokwrm7vqjhvc6pfeqqfnzq77po6cl7q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicbg6o4zywvowpenzstvawokwrm7vqjhvc6pfeqqfnzq77po6cl7q",
#   "prov:label": "rdf:31_3",
#   "_cell": 870,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaeeoi4pqgnshea7wxr7ds5gl3ssckbnvtsgdtfa6c2zsjmspoy7u"
#   },
#   "_stmt_key": "31_3",
#   "_chunk_num": 31,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [31.4]: In his letter to [Eric Gutkind](/wiki/Eric_Gutkind), [Albert Einstein](/wiki/Albert_Einstein) said that no interpretation, no matter how subtle, can change his view of the [Bible](/wiki/Bible).
# _:s4_quote1 rdf:type schema:Quotation .
# _:s4_quote1 schema:text "no interpretation, no matter how subtle, can change my view of the Bible" .
# _:s4_quote1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s4_quote1 schema:datePublished "1954-01-03"^^xsd:date .
# _:s4_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s4_quote1 schema:about <https://en.wikipedia.org/wiki/Bible> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieb5wh45b4dt7ojho4oanj3x67u6ktdzhzw3bltb6tux5xtbsyamm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieb5wh45b4dt7ojho4oanj3x67u6ktdzhzw3bltb6tux5xtbsyamm",
#   "prov:label": "rdf:31_4",
#   "_cell": 872,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihtnfive2qtnobh7flenzbl77pkz553mdbqgg763fa3mcxhjvidda"
#   },
#   "_stmt_key": "31_4",
#   "_chunk_num": 31,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [31.5]: In his letter to [Eric Gutkind](/wiki/Eric_Gutkind), [Albert Einstein](/wiki/Albert_Einstein) stated that the [Jewish religion](/wiki/Jewish_religion) is for him an incarnation of the most childish superstitions.
# _:s5_quote1 rdf:type schema:Quotation .
# _:s5_quote1 schema:text "the Jewish religion is for me an incarnation of the most childish superstitions" .
# _:s5_quote1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s5_quote1 schema:datePublished "1954-01-03"^^xsd:date .
# _:s5_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s5_quote1 schema:about <https://en.wikipedia.org/wiki/Jewish_religion> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicctq4qghfk5j6gosodvpqekmakpe5hu3ncln2366nnl2m763okzm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicctq4qghfk5j6gosodvpqekmakpe5hu3ncln2366nnl2m763okzm",
#   "prov:label": "rdf:31_5",
#   "_cell": 874,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih3t7qetfpn66yvd5fydydufsnfmpza5r2atgz43ga5khlr32amfi"
#   },
#   "_stmt_key": "31_5",
#   "_chunk_num": 31,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [31.6]: In his letter to [Eric Gutkind](/wiki/Eric_Gutkind), [Albert Einstein](/wiki/Albert_Einstein) said that the [Jewish people](/wiki/Jewish_people) to whom he gladly belongs have no different quality for him than all other people.
# _:s6_quote1 rdf:type schema:Quotation .
# _:s6_quote1 schema:text "the Jewish people to whom he gladly belongs have no different quality for him than all other people" .
# _:s6_quote1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s6_quote1 schema:datePublished "1954-01-03"^^xsd:date .
# _:s6_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s6_quote1 schema:about <https://en.wikipedia.org/wiki/Jewish_people> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigdl63qug4dgwt5bjkxarbeci24levyqogipbmjkk5p333fz76mdi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigdl63qug4dgwt5bjkxarbeci24levyqogipbmjkk5p333fz76mdi",
#   "prov:label": "rdf:31_6",
#   "_cell": 876,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiadipe7tuevxy7cylxx36jddjsjzcrpsid7wfi7yhfxjf23bgtegq"
#   },
#   "_stmt_key": "31_6",
#   "_chunk_num": 31,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [31.7]: In his letter to [Eric Gutkind](/wiki/Eric_Gutkind), [Albert Einstein](/wiki/Albert_Einstein) stated that he cannot see anything '[chosen](/wiki/Jews_as_the_chosen_people)' about the [Jewish people](/wiki/Jewish_people).
# _:s7_quote1 rdf:type schema:Quotation .
# _:s7_quote1 schema:text "he cannot see anything 'chosen' about the Jewish people" .
# _:s7_quote1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s7_quote1 schema:datePublished "1954-01-03"^^xsd:date .
# _:s7_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s7_quote1 schema:about <https://en.wikipedia.org/wiki/Jewish_people> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreig4rporl4owntddjkideyvi7qkg3uuitzqngbn74vjnerlcowqdua",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreig4rporl4owntddjkideyvi7qkg3uuitzqngbn74vjnerlcowqdua",
#   "prov:label": "rdf:31_7",
#   "_cell": 878,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidyey4gpjo334igukewxgmy5bv3n6z45amvbcicuulqz25cy5hwna"
#   },
#   "_stmt_key": "31_7",
#   "_chunk_num": 31,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [31.8]: [Albert Einstein](/wiki/Albert_Einstein) became a vegetarian during the last part of his life.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:healthCondition "vegetarian" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreialy22plht3hdm2z3yxdmhto4iwjcvygi252zcru6xf6dr3wq4zje",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreialy22plht3hdm2z3yxdmhto4iwjcvygi252zcru6xf6dr3wq4zje",
#   "prov:label": "rdf:31_8",
#   "_cell": 880,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigxsdds5l6uglkbwvr2ccidb6f4wwwh63ahef52ttmdf64kieoyge"
#   },
#   "_stmt_key": "31_8",
#   "_chunk_num": 31,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [31.9]: In March 1954, [Albert Einstein](/wiki/Albert_Einstein) wrote in a letter that he was living without fats, without meat, and without fish.
# _:s9_quote1 rdf:type schema:Quotation .
# _:s9_quote1 schema:text "living without fats, without meat, and without fish" .
# _:s9_quote1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s9_quote1 schema:datePublished "1954-03"^^xsd:date .
# _:s9_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s9_quote1 schema:about "vegetarian diet" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiguhywriw5be2pwpzhjebevw5mcmoujq3daw2kuhk7s67pg23zhgy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiguhywriw5be2pwpzhjebevw5mcmoujq3daw2kuhk7s67pg23zhgy",
#   "prov:label": "rdf:31_9",
#   "_cell": 882,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifp2fbhjuwxl52gsozo3r2srcxrpkngvv6rjtw2lhzusvfd6mz6dm"
#   },
#   "_stmt_key": "31_9",
#   "_chunk_num": 31,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [31.10]: In March 1954, [Albert Einstein](/wiki/Albert_Einstein) wrote in a letter that he was feeling quite well without meat, fats, and fish.
# _:s10_quote1 rdf:type schema:Quotation .
# _:s10_quote1 schema:text "feeling quite well without meat, fats, and fish" .
# _:s10_quote1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s10_quote1 schema:datePublished "1954-03"^^xsd:date .
# _:s10_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s10_quote1 schema:about "vegetarian diet" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibfbtlyjs575t37jcnh3t77rkvbtnhhbbe6s4v74ivlg6clbwumne",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibfbtlyjs575t37jcnh3t77rkvbtnhhbbe6s4v74ivlg6clbwumne",
#   "prov:label": "rdf:31_10",
#   "_cell": 884,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicdbbywitz6beppafr57oimqu5wmhx3gkpz5okmsh5tgyjwfjp6rq"
#   },
#   "_stmt_key": "31_10",
#   "_chunk_num": 31,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [31.11]: In March 1954, [Albert Einstein](/wiki/Albert_Einstein) wrote in a letter that it almost seemed to him that man was not born to be a carnivore.
# _:s11_quote1 rdf:type schema:Quotation .
# _:s11_quote1 schema:text "it almost seemed to him that man was not born to be a carnivore" .
# _:s11_quote1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s11_quote1 schema:datePublished "1954-03"^^xsd:date .
# _:s11_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s11_quote1 schema:about "vegetarian diet" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiemdayvhebyd5nn37u5u4dspahsqicfx7rr3qbhothfpy5u7fvx7u",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiemdayvhebyd5nn37u5u4dspahsqicfx7rr3qbhothfpy5u7fvx7u",
#   "prov:label": "rdf:31_11",
#   "_cell": 886,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigvosptnbvim4kjo3pyobqrumgdz6zuugo5pdssomrtyk7saio5c4"
#   },
#   "_stmt_key": "31_11",
#   "_chunk_num": 31,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [31.12]: [Albert Einstein](/wiki/Albert_Einstein) read works by [Blavatsky](/wiki/Blavatsky).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knowsAbout <https://en.wikipedia.org/wiki/Blavatsky> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreif2wobrvblwreevaz2ypzmhikvepewibfs744457ks5zppkxz3mmy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreif2wobrvblwreevaz2ypzmhikvepewibfs744457ks5zppkxz3mmy",
#   "prov:label": "rdf:31_12",
#   "_cell": 888,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifnmiednzi3zipe5dc5hlfvfsbnwao24kxsemw4ltr55ws2rqspvy"
#   },
#   "_stmt_key": "31_12",
#   "_chunk_num": 31,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [31.13]: [Albert Einstein](/wiki/Albert_Einstein) attended lectures by [Rudolf Steiner](/wiki/Rudolf_Steiner).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attendee <https://en.wikipedia.org/wiki/Rudolf_Steiner> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiei2fma75mk7pcu7nxe6uu52u5hwh2mndlpvvxywpqdp7ncrg35yi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiei2fma75mk7pcu7nxe6uu52u5hwh2mndlpvvxywpqdp7ncrg35yi",
#   "prov:label": "rdf:31_13",
#   "_cell": 890,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiepqshl5wkhzmju226rrynhqmha5rvjypasf7pdjazf57qf3bxkbe"
#   },
#   "_stmt_key": "31_13",
#   "_chunk_num": 31,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [31.14]: In 1918, [Albert Einstein](/wiki/Albert_Einstein) was one of the signatories of the founding proclamation of the [German Democratic Party](/wiki/German_Democratic_Party).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:contributor <https://en.wikipedia.org/wiki/German_Democratic_Party> .
# <https://en.wikipedia.org/wiki/German_Democratic_Party> rdf:type schema:Organization .
# <https://en.wikipedia.org/wiki/German_Democratic_Party> schema:founder <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreih7ov7aoya6up4xmthh6ofngiblqlrpslgw7uiw5yxsvj7vwrwimu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreih7ov7aoya6up4xmthh6ofngiblqlrpslgw7uiw5yxsvj7vwrwimu",
#   "prov:label": "rdf:31_14",
#   "_cell": 892,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigilt3474x576nure2yrxhgxi4b5b6uad34yuxzyffjsxbiytmd2m"
#   },
#   "_stmt_key": "31_14",
#   "_chunk_num": 31,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [31.15]: The [German Democratic Party](/wiki/German_Democratic_Party) was a liberal party.
# <https://en.wikipedia.org/wiki/German_Democratic_Party> schema:additionalType "liberal party" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifv6l2cybgrlxb2dbgfny3ipq6o5oqiwi5acfuclm7z54iyucbite",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifv6l2cybgrlxb2dbgfny3ipq6o5oqiwi5acfuclm7z54iyucbite",
#   "prov:label": "rdf:31_15",
#   "_cell": 894,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiccbj4zbw662yhl2nw7r73o6tguw4fix27q55br5rsjkdj23mohey"
#   },
#   "_stmt_key": "31_15",
#   "_chunk_num": 31,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [31.16]: Later in his life, [Albert Einstein](/wiki/Albert_Einstein) was in favor of [socialism](/wiki/socialism).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:affiliation "socialism" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihpkj2oderma7oa3wdpdmacmcm5g7u66f24rt6guepeabze4dn3qe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihpkj2oderma7oa3wdpdmacmcm5g7u66f24rt6guepeabze4dn3qe",
#   "prov:label": "rdf:31_16",
#   "_cell": 896,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiff3odjytjxlcl3of4vkzfuzac3vy2ewha2svsmtghxibpe3yghra"
#   },
#   "_stmt_key": "31_16",
#   "_chunk_num": 31,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [31.17]: Later in his life, [Albert Einstein](/wiki/Albert_Einstein) was critical of capitalism.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:disambiguatingDescription "critical of capitalism" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreianrjznmxqskk4nkgvmcne4os2jbxvaty25go27rp2foknpcdzhdm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreianrjznmxqskk4nkgvmcne4os2jbxvaty25go27rp2foknpcdzhdm",
#   "prov:label": "rdf:31_17",
#   "_cell": 898,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifcakzi6ijz4mb4h6dll4ahrjjwoy33jbeaxsewsaipk22r2u6lvi"
#   },
#   "_stmt_key": "31_17",
#   "_chunk_num": 31,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [31.18]: [Albert Einstein](/wiki/Albert_Einstein) detailed his views on socialism in his essays such as "[Why Socialism?](/wiki/Why_Socialism%3F)".
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knowsAbout <https://en.wikipedia.org/wiki/Why_Socialism%3F> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifzdiyyacbbpt7cnhhtfv4qjwh2ntriuztjzlz3e3kg33cbwcwvs4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifzdiyyacbbpt7cnhhtfv4qjwh2ntriuztjzlz3e3kg33cbwcwvs4",
#   "prov:label": "rdf:31_18",
#   "_cell": 900,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifrovnxwc5rnsowkru662ws2riaw7dysb77hvdqiyt3c47ksfocwm"
#   },
#   "_stmt_key": "31_18",
#   "_chunk_num": 31,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [31.19]: The [FBI](/wiki/Federal_Bureau_of_Investigation) created a secret dossier on [Albert Einstein](/wiki/Albert_Einstein) in 1932.
# <https://en.wikipedia.org/wiki/Federal_Bureau_of_Investigation> rdf:type schema:Organization .
# <https://en.wikipedia.org/wiki/Federal_Bureau_of_Investigation> schema:member <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Federal_Bureau_of_Investigation> schema:startDate "1932"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic4mnmyqcdu6zpfs3gx24gsaghs4rudnli3ifxqwflghftntk5m2q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic4mnmyqcdu6zpfs3gx24gsaghs4rudnli3ifxqwflghftntk5m2q",
#   "prov:label": "rdf:31_19",
#   "_cell": 902,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiglahgknpudh2hoxkey4t5j6tthd2tnu4pi72j763v6e6q5m4fwcy"
#   },
#   "_stmt_key": "31_19",
#   "_chunk_num": 31,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Statement [31.20]: By the time of his death, the [FBI](/wiki/Federal_Bureau_of_Investigation)'s dossier on [Albert Einstein](/wiki/Albert_Einstein) was 1,427 pages long.
# <https://en.wikipedia.org/wiki/Federal_Bureau_of_Investigation> schema:member <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Federal_Bureau_of_Investigation> schema:additionalType "1,427 pages long" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibuta6fghc2rwjfcmoso7vpxsqzhfc6yvlk5oakpwr6grxhxt4t2i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibuta6fghc2rwjfcmoso7vpxsqzhfc6yvlk5oakpwr6grxhxt4t2i",
#   "prov:label": "rdf:31_20",
#   "_cell": 904,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifuqu76mnyrnz6ygwsp72khonjcnux4gnvlkbmovjx5bdoyzpxyry"
#   },
#   "_stmt_key": "31_20",
#   "_chunk_num": 31,
#   "_stmt_idx": 20
# }

# %% [raw]
# # Statement [32.1]: [Albert Einstein](/wiki/Albert_Einstein) was a figurehead leader in the establishment of the [Hebrew University of Jerusalem](/wiki/Hebrew_University_of_Jerusalem).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:role _:s1_role1 .
# _:s1_role1 rdf:type schema:Role .
# _:s1_role1 schema:roleName "Figurehead leader" .
# _:s1_role1 schema:organization <https://en.wikipedia.org/wiki/Hebrew_University_of_Jerusalem> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiancpsayc4f7o7kxc7xpbgsy4jdfgwdropmr25n6sr5jjurph7x6a",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiancpsayc4f7o7kxc7xpbgsy4jdfgwdropmr25n6sr5jjurph7x6a",
#   "prov:label": "rdf:32_1",
#   "_cell": 906,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidabmg5rs23hbb77jvyhqoahgdoj6ieryrtissdajokgpgad27bv4"
#   },
#   "_stmt_key": "32_1",
#   "_chunk_num": 32,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [32.2]: The [Hebrew University of Jerusalem](/wiki/Hebrew_University_of_Jerusalem) opened in 1925.
# <https://en.wikipedia.org/wiki/Hebrew_University_of_Jerusalem> schema:foundingDate "1925"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifcqt4f5vvqmn7gjizgodbbjzmzueywo7qt6vtx7uyi6c3jfkga44",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifcqt4f5vvqmn7gjizgodbbjzmzueywo7qt6vtx7uyi6c3jfkga44",
#   "prov:label": "rdf:32_2",
#   "_cell": 908,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiasqr5glv7vfzfochaw7j45o5fkjhqztp2jv4vj5geujld562e7ou"
#   },
#   "_stmt_key": "32_2",
#   "_chunk_num": 32,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [32.3]: In 1921, [Albert Einstein](/wiki/Albert_Einstein) was asked by the biochemist and president of the [World Zionist Organization](/wiki/World_Zionist_Organization), [Chaim Weizmann](/wiki/Chaim_Weizmann), to help raise funds for the planned university.
# <https://en.wikipedia.org/wiki/Chaim_Weizmann> schema:role _:s3_role1 .
# _:s3_role1 rdf:type schema:Role .
# _:s3_role1 schema:roleName "President of World Zionist Organization" .
# _:s3_role1 schema:organization <https://en.wikipedia.org/wiki/World_Zionist_Organization> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:colleague <https://en.wikipedia.org/wiki/Chaim_Weizmann> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidy7sl5d4t6lb3dzrqhxmttdru334azodrogra2rqtxw7jryoeypq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidy7sl5d4t6lb3dzrqhxmttdru334azodrogra2rqtxw7jryoeypq",
#   "prov:label": "rdf:32_3",
#   "_cell": 910,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieghligefyiuu4mhnzagcho3jurulmtdlu5iwcxxqv77goxpxulnq"
#   },
#   "_stmt_key": "32_3",
#   "_chunk_num": 32,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [32.4]: [Albert Einstein](/wiki/Albert_Einstein) made suggestions for the creation of an Institute of Agriculture in the [Hebrew University of Jerusalem](/wiki/Hebrew_University_of_Jerusalem).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:role _:s4_role1 .
# _:s4_role1 rdf:type schema:Role .
# _:s4_role1 schema:roleName "Made suggestions for Institute of Agriculture" .
# _:s4_role1 schema:organization <https://en.wikipedia.org/wiki/Hebrew_University_of_Jerusalem> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihxp5xekeeih22hmwja2gysvtehnsqz7iahsvbuxrhqdawihb2woy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihxp5xekeeih22hmwja2gysvtehnsqz7iahsvbuxrhqdawihb2woy",
#   "prov:label": "rdf:32_4",
#   "_cell": 912,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicz5fxkbki3yzn7mezntsyd7a6iwxcaz7qryuwliezdyzvnm4r6ou"
#   },
#   "_stmt_key": "32_4",
#   "_chunk_num": 32,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [32.5]: [Albert Einstein](/wiki/Albert_Einstein) made suggestions for the creation of a Chemical Institute in the [Hebrew University of Jerusalem](/wiki/Hebrew_University_of_Jerusalem).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:role _:s5_role1 .
# _:s5_role1 rdf:type schema:Role .
# _:s5_role1 schema:roleName "Made suggestions for Chemical Institute" .
# _:s5_role1 schema:organization <https://en.wikipedia.org/wiki/Hebrew_University_of_Jerusalem> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic4o7d3n5umfoobdhqxuteuh5yop3uct4pfxwyb67dm24cqrwucuq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic4o7d3n5umfoobdhqxuteuh5yop3uct4pfxwyb67dm24cqrwucuq",
#   "prov:label": "rdf:32_5",
#   "_cell": 914,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreig27yycxshsvxcdzx3hkkwqkmxaenfizb3byakcapbobb25utintu"
#   },
#   "_stmt_key": "32_5",
#   "_chunk_num": 32,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [32.6]: [Albert Einstein](/wiki/Albert_Einstein) made suggestions for the creation of an Institute of Microbiology in the [Hebrew University of Jerusalem](/wiki/Hebrew_University_of_Jerusalem).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:role _:s6_role1 .
# _:s6_role1 rdf:type schema:Role .
# _:s6_role1 schema:roleName "Made suggestions for Institute of Microbiology" .
# _:s6_role1 schema:organization <https://en.wikipedia.org/wiki/Hebrew_University_of_Jerusalem> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie34i7ijslma5konx6ljatnm4raxymanx6za2qy7ejo45eftbr4te",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie34i7ijslma5konx6ljatnm4raxymanx6za2qy7ejo45eftbr4te",
#   "prov:label": "rdf:32_6",
#   "_cell": 916,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreianzhcewcolz2y6olxrsq35omfssjmdutjnsbvtowntcpfkqn3fdq"
#   },
#   "_stmt_key": "32_6",
#   "_chunk_num": 32,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [32.7]: [Albert Einstein](/wiki/Albert_Einstein) suggested that the institutes should fight ongoing epidemics such as [malaria](/wiki/malaria).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:role _:s7_role1 .
# _:s7_role1 rdf:type schema:Role .
# _:s7_role1 schema:roleName "Suggested institutes should fight epidemics" .
# _:s7_role1 schema:organization <https://en.wikipedia.org/wiki/Hebrew_University_of_Jerusalem> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibi4sqfmlpdyxna3wkhub6b53zi6bs6ivwmmomtbe2qqzwmuw7m7e",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibi4sqfmlpdyxna3wkhub6b53zi6bs6ivwmmomtbe2qqzwmuw7m7e",
#   "prov:label": "rdf:32_7",
#   "_cell": 918,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiejkaodwa2hdk5rydbf5kvlkj5w3ahlubvlly6qhdu2wxdeuccrga"
#   },
#   "_stmt_key": "32_7",
#   "_chunk_num": 32,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [32.8]: [Albert Einstein](/wiki/Albert_Einstein) called [malaria](/wiki/malaria) an "evil" that was undermining a third of the country's development.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:role _:s8_role1 .
# _:s8_role1 rdf:type schema:Role .
# _:s8_role1 schema:roleName "Called malaria an evil undermining country's development" .
# _:s8_role1 schema:organization <https://en.wikipedia.org/wiki/Hebrew_University_of_Jerusalem> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibznbovht4rvi73gluxayeu677qscmx3vsftlmcanwgsfrfqveldq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibznbovht4rvi73gluxayeu677qscmx3vsftlmcanwgsfrfqveldq",
#   "prov:label": "rdf:32_8",
#   "_cell": 920,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicsftovsdoptwkzxfhf6eemgf6s7swoft5tctkk2xjh2n2acip6fm"
#   },
#   "_stmt_key": "32_8",
#   "_chunk_num": 32,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [32.9]: [Albert Einstein](/wiki/Albert_Einstein) promoted the establishment of an Oriental Studies Institute in the [Hebrew University of Jerusalem](/wiki/Hebrew_University_of_Jerusalem).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:role _:s9_role1 .
# _:s9_role1 rdf:type schema:Role .
# _:s9_role1 schema:roleName "Promoted establishment of Oriental Studies Institute" .
# _:s9_role1 schema:organization <https://en.wikipedia.org/wiki/Hebrew_University_of_Jerusalem> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiavgpguy65wxn3fprr73hfnhbrwc4gwnyddx77u2vmc35cqar3c6i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiavgpguy65wxn3fprr73hfnhbrwc4gwnyddx77u2vmc35cqar3c6i",
#   "prov:label": "rdf:32_9",
#   "_cell": 922,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid7gly2fs2dlxprpkti4e43mtbgx5r55kxoauhsj7xgcd47guntky"
#   },
#   "_stmt_key": "32_9",
#   "_chunk_num": 32,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [32.10]: The Oriental Studies Institute included language courses given in both [Hebrew](/wiki/Hebrew) and [Arabic](/wiki/Arabic).
# <https://en.wikipedia.org/wiki/Hebrew_University_of_Jerusalem> schema:role _:s10_role1 .
# _:s10_role1 rdf:type schema:Role .
# _:s10_role1 schema:roleName "Oriental Studies Institute included language courses in Hebrew and Arabic" .
# _:s10_role1 schema:organization <https://en.wikipedia.org/wiki/Hebrew_University_of_Jerusalem> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreify4unfarpskwlakx367xhalmeejmasmk7f5ocjkwhtiel2mguske",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreify4unfarpskwlakx367xhalmeejmasmk7f5ocjkwhtiel2mguske",
#   "prov:label": "rdf:32_10",
#   "_cell": 924,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifoju6rcklrhem2xtmt4jskqsuqhztyx443ccbt5c7ura57jzp4ym"
#   },
#   "_stmt_key": "32_10",
#   "_chunk_num": 32,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [32.11]: [Albert Einstein](/wiki/Albert_Einstein) was not a [nationalist](/wiki/nationalist).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:role _:s11_role1 .
# _:s11_role1 rdf:type schema:Role .
# _:s11_role1 schema:roleName "Not a nationalist" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibbprqqbak5yj3al5ldp2f44riebcahjkpvqk5cqfiznqhcwojsk4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibbprqqbak5yj3al5ldp2f44riebcahjkpvqk5cqfiznqhcwojsk4",
#   "prov:label": "rdf:32_11",
#   "_cell": 926,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihig7jfkidwck56oizo32uighuuetglmcgukxz4ppxsgv6b3qtmfy"
#   },
#   "_stmt_key": "32_11",
#   "_chunk_num": 32,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [32.12]: [Albert Einstein](/wiki/Albert_Einstein) opposed the creation of an independent Jewish state.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:role _:s12_role1 .
# _:s12_role1 rdf:type schema:Role .
# _:s12_role1 schema:roleName "Opposed creation of independent Jewish state" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifcsyajirfpp3o6wjh2k7hi2umz7hxvqdrknyrfxnnbas3qdpxpsa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifcsyajirfpp3o6wjh2k7hi2umz7hxvqdrknyrfxnnbas3qdpxpsa",
#   "prov:label": "rdf:32_12",
#   "_cell": 928,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib7nn5a6czg7gvm3xjqbsv2mrjmd6evnpagempicr4xmsqqdbvani"
#   },
#   "_stmt_key": "32_12",
#   "_chunk_num": 32,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [32.13]: [Albert Einstein](/wiki/Albert_Einstein) felt that the waves of arriving Jews of the [Aliyah](/wiki/Aliyah) could live alongside existing Arabs in [Palestine](/wiki/Palestine_%28region%29).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:role _:s13_role1 .
# _:s13_role1 rdf:type schema:Role .
# _:s13_role1 schema:roleName "Feeling that Jews and Arabs could live together in Palestine" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifyen6leqvogkh52df427oqgol3hfzav67cmqndkeqwfgbuawhf7u",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifyen6leqvogkh52df427oqgol3hfzav67cmqndkeqwfgbuawhf7u",
#   "prov:label": "rdf:32_13",
#   "_cell": 930,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihh5ew6gfz5fq66yx3ed4qituuj6s7elvvcluyx7eswyeh26coeyy"
#   },
#   "_stmt_key": "32_13",
#   "_chunk_num": 32,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [32.14]: The state of [Israel](/wiki/Israel) was established in 1948.
# <https://en.wikipedia.org/wiki/Israel> schema:foundingDate "1948"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia3qhc7sew2qep7lar5s4xfyvm42oadev7jicpxqwmhfs6hluprrm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia3qhc7sew2qep7lar5s4xfyvm42oadev7jicpxqwmhfs6hluprrm",
#   "prov:label": "rdf:32_14",
#   "_cell": 932,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicu24jzlieukdvhlhce3s4uam2qbxibyqeso77feesf5zq3qi3u2u"
#   },
#   "_stmt_key": "32_14",
#   "_chunk_num": 32,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [32.15]: The state of [Israel](/wiki/Israel) was established without the help of [Albert Einstein](/wiki/Albert_Einstein).
# <https://en.wikipedia.org/wiki/Israel> schema:role _:s15_role1 .
# _:s15_role1 rdf:type schema:Role .
# _:s15_role1 schema:roleName "Established without help of Albert Einstein" .
# _:s15_role1 schema:organization <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifukwzkkcfg4bt2t4xoq3z66upsx3drpr2ns5qkcrblye3qajr5me",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifukwzkkcfg4bt2t4xoq3z66upsx3drpr2ns5qkcrblye3qajr5me",
#   "prov:label": "rdf:32_15",
#   "_cell": 934,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidymynlkeisdviokdfg4p3dmrlrqljwgufmhvdfxqpemhxbdqq2bi"
#   },
#   "_stmt_key": "32_15",
#   "_chunk_num": 32,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [32.16]: [Albert Einstein](/wiki/Albert_Einstein) was limited to a marginal role in the [Zionist movement](/wiki/Zionism).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:role _:s16_role1 .
# _:s16_role1 rdf:type schema:Role .
# _:s16_role1 schema:roleName "Limited role in Zionist movement" .
# _:s16_role1 schema:organization <https://en.wikipedia.org/wiki/Zionism> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiahl54bd6e7apfan2wqz377clqyikrpax4s5gfvaxhkdzc6ahhqlm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiahl54bd6e7apfan2wqz377clqyikrpax4s5gfvaxhkdzc6ahhqlm",
#   "prov:label": "rdf:32_16",
#   "_cell": 936,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibuhv34vz5ie43isyulcbhgj3blcrbonv5ccbw2u5rmt2rk5tkrqu"
#   },
#   "_stmt_key": "32_16",
#   "_chunk_num": 32,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [32.17]: Upon the death of Israeli president [Chaim Weizmann](/wiki/Chaim_Weizmann) in November 1952, Prime Minister [David Ben-Gurion](/wiki/David_Ben-Gurion) offered [Albert Einstein](/wiki/Albert_Einstein) the largely ceremonial position of [President of Israel](/wiki/President_of_Israel).
# <https://en.wikipedia.org/wiki/David_Ben-Gurion> schema:role _:s17_role1 .
# _:s17_role1 rdf:type schema:Role .
# _:s17_role1 schema:roleName "Prime Minister of Israel" .
# _:s17_role1 schema:organization <https://en.wikipedia.org/wiki/Israel> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:role _:s17_role2 .
# _:s17_role2 rdf:type schema:Role .
# _:s17_role2 schema:roleName "Offered President of Israel" .
# _:s17_role2 schema:organization <https://en.wikipedia.org/wiki/President_of_Israel> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieq2gcwlmpkai2wi6ub6zqpyrkxxner6ngrllrmdskysydqyq5glq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieq2gcwlmpkai2wi6ub6zqpyrkxxner6ngrllrmdskysydqyq5glq",
#   "prov:label": "rdf:32_17",
#   "_cell": 938,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibwkvqkhcjedlp3li5ejbc24d7g6vnu4biyrn4h53b5qb43n4lauy"
#   },
#   "_stmt_key": "32_17",
#   "_chunk_num": 32,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [32.18]: The offer of [President of Israel](/wiki/President_of_Israel) was made at the urging of [Ezriel Carlebach](/wiki/Ezriel_Carlebach).
# <https://en.wikipedia.org/wiki/Ezriel_Carlebach> schema:role _:s18_role1 .
# _:s18_role1 rdf:type schema:Role .
# _:s18_role1 schema:roleName "Urged offer of President of Israel" .
# _:s18_role1 schema:organization <https://en.wikipedia.org/wiki/President_of_Israel> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicz4n6xbuopkacuqqwcydgljviobqi34t6gqdddys7ozwcrpm6lty",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicz4n6xbuopkacuqqwcydgljviobqi34t6gqdddys7ozwcrpm6lty",
#   "prov:label": "rdf:32_18",
#   "_cell": 940,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihygjb5rpgqrq5qtpgq4k5vtilay7kd2bpjr44u4s5bib5n5sb6ha"
#   },
#   "_stmt_key": "32_18",
#   "_chunk_num": 32,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [32.19]: [Lee Smolin](/wiki/Lee_Smolin) believed that a moral quality allowed [Albert Einstein](/wiki/Albert_Einstein) to achieve so much.
# <https://en.wikipedia.org/wiki/Lee_Smolin> schema:role _:s19_role1 .
# _:s19_role1 rdf:type schema:Role .
# _:s19_role1 schema:roleName "Believed moral quality allowed Einstein to achieve so much" .
# _:s19_role1 schema:organization <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiht2p5vfmwrcj5qolooitmcq4q5toti5mpogpaqwvtaw7rzzp7rw4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiht2p5vfmwrcj5qolooitmcq4q5toti5mpogpaqwvtaw7rzzp7rw4",
#   "prov:label": "rdf:32_19",
#   "_cell": 942,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicd3zq7wkqjpdr4mg3ywc3hbckkjztxccld4afk5rt4hcxsuvckzq"
#   },
#   "_stmt_key": "32_19",
#   "_chunk_num": 32,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Statement [32.20]: [Albert Einstein](/wiki/Albert_Einstein) cared far more than most of his colleagues that the laws of physics have to explain everything in nature coherently and consistently.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:role _:s20_role1 .
# _:s20_role1 rdf:type schema:Role .
# _:s20_role1 schema:roleName "Cared more than colleagues that laws of physics explain everything coherently" .
# _:s20_role1 schema:organization <https://en.wikipedia.org/wiki/Physics> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiddzwfbblmcaeeh2pn3fugquj2ikfswefoc4xr2jgwmtex3r5hiii",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiddzwfbblmcaeeh2pn3fugquj2ikfswefoc4xr2jgwmtex3r5hiii",
#   "prov:label": "rdf:32_20",
#   "_cell": 944,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidkcjqczti4q6lvtdksb7g63c6wlc2eqjrm2aw7mivcqncxcpezi4"
#   },
#   "_stmt_key": "32_20",
#   "_chunk_num": 32,
#   "_stmt_idx": 20
# }

# %% [raw]
# # Statement [32.21]: [Albert Einstein](/wiki/Albert_Einstein) expounded his spiritual outlook in a wide array of writings and interviews.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:role _:s21_role1 .
# _:s21_role1 rdf:type schema:Role .
# _:s21_role1 schema:roleName "Expounded spiritual outlook in writings and interviews" .
# _:s21_role1 schema:organization <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic5vfok3ybwwxw5alekrs3u5q4ruyldjhmasfcbnim3e4wwg6hany",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic5vfok3ybwwxw5alekrs3u5q4ruyldjhmasfcbnim3e4wwg6hany",
#   "prov:label": "rdf:32_21",
#   "_cell": 946,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih7r6ug2cak56p7cubhwj3bmzalnhaf4yzpb6w3ovekzcb5u3aq6m"
#   },
#   "_stmt_key": "32_21",
#   "_chunk_num": 32,
#   "_stmt_idx": 21
# }

# %% [raw]
# # Statement [33.1]: [Albert Einstein](/wiki/Albert_Einstein) wrote a German-language letter to philosopher [Eric Gutkind](/wiki/Eric_Gutkind) on 3 January 1954.
# _:s1_quote1 rdf:type schema:Quotation .
# _:s1_quote1 schema:text "the word God is for me nothing more than the expression and product of human weaknesses" .
# _:s1_quote1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s1_letter1 rdf:type schema:Message .
# _:s1_letter1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s1_letter1 schema:dateCreated "1954-01-03"^^xsd:date .
# _:s1_letter1 schema:recipient <https://en.wikipedia.org/wiki/Eric_Gutkind> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicodsw7srbe24ch7ocvmum2omsop4gpn7hdoxblqxk46dq2wylz5a",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicodsw7srbe24ch7ocvmum2omsop4gpn7hdoxblqxk46dq2wylz5a",
#   "prov:label": "rdf:33_1",
#   "_cell": 948,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiacyt77f6oxv7qgb4rguilplprf4n74f4yitdax6psbuolbo73lb4"
#   },
#   "_stmt_key": "33_1",
#   "_chunk_num": 33,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [33.2]: In the letter, [Albert Einstein](/wiki/Albert_Einstein) stated that the word God is for him nothing more than the expression and product of human weaknesses.
# _:s2_quote1 rdf:type schema:Quotation .
# _:s2_quote1 schema:text "the Bible is a collection of honorable, but still primitive legends which are nevertheless pretty childish" .
# _:s2_quote1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s2_quote1 schema:text "the word God is for me nothing more than the expression and product of human weaknesses" .
# _:s1_letter1 schema:hasPart _:s2_quote1 .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiby5x3vl4rfgbxh4gijc2rrpnzf3cbrsgh4abidyws4m5yo5j5bkq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiby5x3vl4rfgbxh4gijc2rrpnzf3cbrsgh4abidyws4m5yo5j5bkq",
#   "prov:label": "rdf:33_2",
#   "_cell": 950,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigywo5pkeudqi5su3hhs6tnge7i7avvv7r4goryrrt5hycotiwbqq"
#   },
#   "_stmt_key": "33_2",
#   "_chunk_num": 33,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [33.3]: In the letter, [Albert Einstein](/wiki/Albert_Einstein) described the Bible as a collection of honorable, but still primitive legends which are nevertheless pretty childish.
# _:s3_quote1 rdf:type schema:Quotation .
# _:s3_quote1 schema:text "no interpretation no matter how subtle can change my view of the Bible" .
# _:s3_quote1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s3_quote1 schema:text "the Bible is a collection of honorable, but still primitive legends which are nevertheless pretty childish" .
# _:s1_letter1 schema:hasPart _:s3_quote1 .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihx5yzp2ixbmwd2ckrsewypkljb3m2rfqbpdm4lvqtkobwxgoxaoy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihx5yzp2ixbmwd2ckrsewypkljb3m2rfqbpdm4lvqtkobwxgoxaoy",
#   "prov:label": "rdf:33_3",
#   "_cell": 952,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidximbtu5vst6utpj2gys6cs3vd6ew7nvjugor3pnu33dhsv5cluu"
#   },
#   "_stmt_key": "33_3",
#   "_chunk_num": 33,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [33.4]: In the letter, [Albert Einstein](/wiki/Albert_Einstein) said that no interpretation no matter how subtle can change his view of the Bible.
# _:s4_quote1 rdf:type schema:Quotation .
# _:s4_quote1 schema:text "the Jewish religion like all other religions is an incarnation of the most childish superstitions" .
# _:s4_quote1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s4_quote1 schema:text "no interpretation no matter how subtle can change my view of the Bible" .
# _:s1_letter1 schema:hasPart _:s4_quote1 .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic63zlkwni5c6t7ga6xqlokuuo5fmkkkr2sm6aglpkvascppplsva",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic63zlkwni5c6t7ga6xqlokuuo5fmkkkr2sm6aglpkvascppplsva",
#   "prov:label": "rdf:33_4",
#   "_cell": 954,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiflwtyrfstonyfiuft7w6ufywsluyaf2k62q7bboifqmfuksyautu"
#   },
#   "_stmt_key": "33_4",
#   "_chunk_num": 33,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [33.5]: In the letter, [Albert Einstein](/wiki/Albert_Einstein) stated that the [Jewish religion](/wiki/Jewish_religion) like all other religions is an incarnation of the most childish superstitions.
# _:s5_quote1 rdf:type schema:Quotation .
# _:s5_quote1 schema:text "the Jewish people to whom I gladly belong have no different quality for me than all other people" .
# _:s5_quote1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s5_quote1 schema:text "the Jewish religion like all other religions is an incarnation of the most childish superstitions" .
# _:s1_letter1 schema:hasPart _:s5_quote1 .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreih55tywwqspvtrevawst2bjxj5a32ah5jtvntics7bvesiyzkcclm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreih55tywwqspvtrevawst2bjxj5a32ah5jtvntics7bvesiyzkcclm",
#   "prov:label": "rdf:33_5",
#   "_cell": 956,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreierv4ec6sz6k3zf6vi246kbjpq5hk7g2h3bfayfvwugdjtyz72yva"
#   },
#   "_stmt_key": "33_5",
#   "_chunk_num": 33,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [33.6]: In the letter, [Albert Einstein](/wiki/Albert_Einstein) said that the [Jewish people](/wiki/Jewish_people) to whom he gladly belongs have no different quality for him than all other people.
# _:s6_quote1 rdf:type schema:Quotation .
# _:s6_quote1 schema:text "I could not see anything 'chosen' about the Jewish people" .
# _:s6_quote1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s6_quote1 schema:text "the Jewish people to whom I gladly belong have no different quality for me than all other people" .
# _:s1_letter1 schema:hasPart _:s6_quote1 .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiftor44zitmfhnwn2adxl2fctkf4lcxjkdzwlfinatphiwuun7r34",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiftor44zitmfhnwn2adxl2fctkf4lcxjkdzwlfinatphiwuun7r34",
#   "prov:label": "rdf:33_6",
#   "_cell": 958,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicbwlpsx5fbaqujb6lfxoaoddpcnepotmy5gjra5aormbn27tvaku"
#   },
#   "_stmt_key": "33_6",
#   "_chunk_num": 33,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [33.7]: In the letter, [Albert Einstein](/wiki/Albert_Einstein) stated that he could not see anything 'chosen' about the [Jewish people](/wiki/Jewish_people).
# _:s7_quote1 rdf:type schema:Quotation .
# _:s7_quote1 schema:text "he was living without fats, without meat, and without fish" .
# _:s7_quote1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s7_quote1 schema:text "I could not see anything 'chosen' about the Jewish people" .
# _:s1_letter1 schema:hasPart _:s7_quote1 .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicboqljbaqttpripmgfio3iaimdfce73ropvpk5yg2dy5n2uhpsjq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicboqljbaqttpripmgfio3iaimdfce73ropvpk5yg2dy5n2uhpsjq",
#   "prov:label": "rdf:33_7",
#   "_cell": 960,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiau5i33akwstup23awbjb7dsbzbae2g4bjuzsf7egyulhpzfl6esu"
#   },
#   "_stmt_key": "33_7",
#   "_chunk_num": 33,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [33.8]: [Albert Einstein](/wiki/Albert_Einstein) became a vegetarian during the last part of his life.
# _:s8_quote1 rdf:type schema:Quotation .
# _:s8_quote1 schema:text "he was feeling quite well without meat, fish, and fats" .
# _:s8_quote1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasOccupation schema:Vegetarian .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicrm3pr5mbr73yo6bj54743mr3ezhex76iympxvgvrnsf4hs7iisi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicrm3pr5mbr73yo6bj54743mr3ezhex76iympxvgvrnsf4hs7iisi",
#   "prov:label": "rdf:33_8",
#   "_cell": 962,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigxsdds5l6uglkbwvr2ccidb6f4wwwh63ahef52ttmdf64kieoyge"
#   },
#   "_stmt_key": "33_8",
#   "_chunk_num": 33,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [33.9]: In March 1954, [Albert Einstein](/wiki/Albert_Einstein) wrote in a letter that he was living without fats, without meat, and without fish.
# _:s9_quote1 rdf:type schema:Quotation .
# _:s9_quote1 schema:text "it seemed to him that man was not born to be a carnivore" .
# _:s9_quote1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s9_quote1 schema:text "he was living without fats, without meat, and without fish" .
# _:s1_letter1 schema:hasPart _:s9_quote1 .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigbhjspcd5yxbkcj6tmeijlida7ihlmcrvy6xihv2jeydfuianxtm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigbhjspcd5yxbkcj6tmeijlida7ihlmcrvy6xihv2jeydfuianxtm",
#   "prov:label": "rdf:33_9",
#   "_cell": 964,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifp2fbhjuwxl52gsozo3r2srcxrpkngvv6rjtw2lhzusvfd6mz6dm"
#   },
#   "_stmt_key": "33_9",
#   "_chunk_num": 33,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [33.10]: In March 1954, [Albert Einstein](/wiki/Albert_Einstein) wrote in a letter that he was feeling quite well without meat, fish, and fats.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasOccupation schema:Vegetarian .
# _:s10_quote1 rdf:type schema:Quotation .
# _:s10_quote1 schema:text "he was feeling quite well without meat, fish, and fats" .
# _:s10_quote1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s1_letter1 schema:hasPart _:s10_quote1 .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiekflieaw5nvdhkax4k7dvxtnzgncjar2nvawngvlp3limb2r2pba",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiekflieaw5nvdhkax4k7dvxtnzgncjar2nvawngvlp3limb2r2pba",
#   "prov:label": "rdf:33_10",
#   "_cell": 966,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigatqhaklupxysyqaw73je33jwj5mw7z6n64qy2oe25kfpa7bbl7u"
#   },
#   "_stmt_key": "33_10",
#   "_chunk_num": 33,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [33.11]: In March 1954, [Albert Einstein](/wiki/Albert_Einstein) wrote in a letter that it seemed to him that man was not born to be a carnivore.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasOccupation schema:Vegetarian .
# _:s11_quote1 rdf:type schema:Quotation .
# _:s11_quote1 schema:text "it seemed to him that man was not born to be a carnivore" .
# _:s11_quote1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s1_letter1 schema:hasPart _:s11_quote1 .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreif3tpmrnl6j3vnqtzjesqstb64xysyw5cmz2ejful62tndywylklq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreif3tpmrnl6j3vnqtzjesqstb64xysyw5cmz2ejful62tndywylklq",
#   "prov:label": "rdf:33_11",
#   "_cell": 968,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigqd4g2r4ojtg3fvja743k5h42dkvozlywpwhex2ablcnpaxmr6ju"
#   },
#   "_stmt_key": "33_11",
#   "_chunk_num": 33,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [33.12]: [Albert Einstein](/wiki/Albert_Einstein) read works by [Blavatsky](/wiki/Helena_Blavatsky).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knowsAbout <https://en.wikipedia.org/wiki/Helena_Blavatsky> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreih4ziic73iwfshscdyoyyszvceal6rptwptnfzloejjgxzlf2qose",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreih4ziic73iwfshscdyoyyszvceal6rptwptnfzloejjgxzlf2qose",
#   "prov:label": "rdf:33_12",
#   "_cell": 970,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieoex4rbavoqozruuglxkt2aqtsk7vlfsd4wjqor6fmgrm42m3sv4"
#   },
#   "_stmt_key": "33_12",
#   "_chunk_num": 33,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [33.13]: [Albert Einstein](/wiki/Albert_Einstein) attended lectures by [Rudolf Steiner](/wiki/Rudolf_Steiner).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:attends <https://en.wikipedia.org/wiki/Rudolf_Steiner> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie7welzp3yucnti4wl3lwhq2m3v35pqoe423wtqbzdlhza2itdfuq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie7welzp3yucnti4wl3lwhq2m3v35pqoe423wtqbzdlhza2itdfuq",
#   "prov:label": "rdf:33_13",
#   "_cell": 972,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiepqshl5wkhzmju226rrynhqmha5rvjypasf7pdjazf57qf3bxkbe"
#   },
#   "_stmt_key": "33_13",
#   "_chunk_num": 33,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [33.14]: Einstein developed an appreciation for music at an early age.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasOccupation schema:Musician .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibmbgu5wmim46xh4g2ntegalcnwqxv3z2kh6tpxb4zb7wg6wqmrri",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibmbgu5wmim46xh4g2ntegalcnwqxv3z2kh6tpxb4zb7wg6wqmrri",
#   "prov:label": "rdf:33_14",
#   "_cell": 974,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreie6rnh5encncsl5m4jx4526kzvcw2e2kefmhx5qadus3at5y747ai"
#   },
#   "_stmt_key": "33_14",
#   "_chunk_num": 33,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [33.15]: Einstein's mother played the piano reasonably well.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:familyName "Einstein" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihnrbk5akatiggbnisvd6hjnluhscxwbfu3i7kp2bgao76mevey74",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihnrbk5akatiggbnisvd6hjnluhscxwbfu3i7kp2bgao76mevey74",
#   "prov:label": "rdf:33_15",
#   "_cell": 976,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieapdnrptubxhyqmfgjrxu4k2x6ejeupz2pbopkuo2gm67nhpxdva"
#   },
#   "_stmt_key": "33_15",
#   "_chunk_num": 33,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [33.16]: Einstein's mother wanted him to learn the violin.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasOccupation schema:Musician .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidab3562ehec4ykrnaumixmz4bijxvgxphr72inajbyy4gae3nxb4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidab3562ehec4ykrnaumixmz4bijxvgxphr72inajbyy4gae3nxb4",
#   "prov:label": "rdf:33_16",
#   "_cell": 978,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifswqknhxr4otpmvkk5pxijum3svbayn4sv6nfvb3tpuejh4sxapq"
#   },
#   "_stmt_key": "33_16",
#   "_chunk_num": 33,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [33.17]: Einstein's mother wanted him to learn the violin to instill in him a love of music.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasOccupation schema:Musician .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifbujpaosn6aljxrsyuglaggjmz43j6ka5ezedoo2zau6vspewh7q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifbujpaosn6aljxrsyuglaggjmz43j6ka5ezedoo2zau6vspewh7q",
#   "prov:label": "rdf:33_17",
#   "_cell": 980,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihul3h7dvzaq2wdjegrltlqbxsurpg4ne5ed2uoac6qxhua4zrzze"
#   },
#   "_stmt_key": "33_17",
#   "_chunk_num": 33,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [33.18]: Einstein's mother wanted him to learn the violin to help him assimilate into [German culture](/wiki/German_culture).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasOccupation schema:Musician .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia4bbm3fgz2elrmxsx37txvwwhtlqa7xc5nulg6ueawpwswfaj4xq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia4bbm3fgz2elrmxsx37txvwwhtlqa7xc5nulg6ueawpwswfaj4xq",
#   "prov:label": "rdf:33_18",
#   "_cell": 982,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiatfqyqzgaoglks7j2m6karpkahlr7uw6km5rxbqidvlnfcfpuqza"
#   },
#   "_stmt_key": "33_18",
#   "_chunk_num": 33,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [33.19]: According to conductor [Leon Botstein](/wiki/Leon_Botstein), [Albert Einstein](/wiki/Albert_Einstein) began playing the violin when he was 5 years old.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:birthDate "1879-03-14"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreico3rerweit6ebxsgvmziblrastmmvhqiv4uxvjoubtdxfcorslky",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreico3rerweit6ebxsgvmziblrastmmvhqiv4uxvjoubtdxfcorslky",
#   "prov:label": "rdf:33_19",
#   "_cell": 984,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiblrkcgcmuucvv54swio4tllvqdu5o3qub5ahb6p5dlfwzh3q6f6u"
#   },
#   "_stmt_key": "33_19",
#   "_chunk_num": 33,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Statement [33.20]: [Albert Einstein](/wiki/Albert_Einstein) did not enjoy playing the violin at age 5.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasOccupation schema:Musician .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifybtz64q7sgxh7atwbz4dfom7nx323kgonejvlxmnrrq7pcreguu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifybtz64q7sgxh7atwbz4dfom7nx323kgonejvlxmnrrq7pcreguu",
#   "prov:label": "rdf:33_20",
#   "_cell": 986,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieyrblpduq5wllhocxh2c2s2akcg4xz26yxoadokoiijb7jceln5y"
#   },
#   "_stmt_key": "33_20",
#   "_chunk_num": 33,
#   "_stmt_idx": 20
# }

# %% [raw]
# # Statement [34.1]: [Albert Einstein](/wiki/Albert_Einstein) discovered [Mozart](/wiki/Mozart)'s [violin sonatas](/wiki/Mozart_violin_sonatas) when he turned 13.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knowsAbout <https://en.wikipedia.org/wiki/Mozart_violin_sonatas> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiat6ywan6u6kld67l3cpmvifclgl4dysgggha73tnilmvharo7eam",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiat6ywan6u6kld67l3cpmvifclgl4dysgggha73tnilmvharo7eam",
#   "prov:label": "rdf:34_1",
#   "_cell": 988,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigjseikfv3bb6na7vwpsgzns6d7nlj6hedtxrxxyr35lfgchlkami"
#   },
#   "_stmt_key": "34_1",
#   "_chunk_num": 34,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [34.2]: After discovering [Mozart](/wiki/Mozart)'s [violin sonatas](/wiki/Mozart_violin_sonatas), [Albert Einstein](/wiki/Albert_Einstein) became enamored of [Mozart](/wiki/Mozart)'s compositions.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasInterest <https://en.wikipedia.org/wiki/Mozart> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiajcdzgiykadxwtnim6pdkf5pavv2yb2k72jysba62x4jikwz6mbi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiajcdzgiykadxwtnim6pdkf5pavv2yb2k72jysba62x4jikwz6mbi",
#   "prov:label": "rdf:34_2",
#   "_cell": 990,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih34zdyqfmmikpqof2yutfqyuj7nvjokyz66ei3nlhvbv4wjpzarm"
#   },
#   "_stmt_key": "34_2",
#   "_chunk_num": 34,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [34.3]: [Albert Einstein](/wiki/Albert_Einstein) studied music more willingly after discovering [Mozart](/wiki/Mozart)'s [violin sonatas](/wiki/Mozart_violin_sonatas).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasInterest <https://en.wikipedia.org/wiki/Mozart_violin_sonatas> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifo5l2yj6ns2qf5536kgzcuclptowv7cu356f5rlimm2yshkj7wfe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifo5l2yj6ns2qf5536kgzcuclptowv7cu356f5rlimm2yshkj7wfe",
#   "prov:label": "rdf:34_3",
#   "_cell": 992,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigbygplthxuioauchpgmq2u75sezfidrg4gwkzixsa2f5ijpm6ddu"
#   },
#   "_stmt_key": "34_3",
#   "_chunk_num": 34,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [34.4]: [Albert Einstein](/wiki/Albert_Einstein) taught himself to play the violin without ever practicing systematically.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:instrument <https://en.wikipedia.org/wiki/Violin> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie4okxeg4bjku7cqslfdzeaygaz7gnbjzn36m2fbjva2cil6fqyli",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie4okxeg4bjku7cqslfdzeaygaz7gnbjzn36m2fbjva2cil6fqyli",
#   "prov:label": "rdf:34_4",
#   "_cell": 994,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibu7uz6zwv2cvoszxxd4dsst22bh4aekke7zvsuk4txqqzyqnsgwe"
#   },
#   "_stmt_key": "34_4",
#   "_chunk_num": 34,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [34.5]: [Albert Einstein](/wiki/Albert_Einstein) said that "love is a better teacher than a sense of duty".
# _:s5_quote1 rdf:type schema:Quotation .
# _:s5_quote1 schema:text "love is a better teacher than a sense of duty" .
# _:s5_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifnp6wy6tw4d4kemswwb5cfn67ujq5pjxckcemwrkxp66vvawl4le",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifnp6wy6tw4d4kemswwb5cfn67ujq5pjxckcemwrkxp66vvawl4le",
#   "prov:label": "rdf:34_5",
#   "_cell": 996,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiadzdzcdbfck3pscmdrkhbrjee3wbcgv2svlxiw24cb3s6wwy7syq"
#   },
#   "_stmt_key": "34_5",
#   "_chunk_num": 34,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [34.6]: At the age of 17, [Albert Einstein](/wiki/Albert_Einstein) was heard by a school examiner in [Aarau](/wiki/Aarau) while playing [Beethoven](/wiki/Beethoven)'s [violin sonatas](/wiki/Beethoven%27s_violin_sonatas_%28disambiguation%29%3C%21--_intentional_--%3E).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:performer <https://en.wikipedia.org/wiki/Beethoven%27s_violin_sonatas_%28disambiguation%29%3C%21--_intentional_--%3E> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihctwbvsfzk7iztbupcc62f3gwwbmqojeoknhegvxhzrnprcnioh4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihctwbvsfzk7iztbupcc62f3gwwbmqojeoknhegvxhzrnprcnioh4",
#   "prov:label": "rdf:34_6",
#   "_cell": 998,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihhyff6xgvu67uztllqoso7r7nplrbtxgx2jutmztqbe6cl65bfc4"
#   },
#   "_stmt_key": "34_6",
#   "_chunk_num": 34,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [34.7]: The examiner who heard [Albert Einstein](/wiki/Albert_Einstein) playing stated that his performance was "remarkable and revealing of 'great insight'".
# _:s7_quote1 rdf:type schema:Quotation .
# _:s7_quote1 schema:text "remarkable and revealing of 'great insight'" .
# _:s7_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiae5mmpfsdxdsizxqcyduqsoyxcn4mmmbbhj75o3wsgvef455osqe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiae5mmpfsdxdsizxqcyduqsoyxcn4mmmbbhj75o3wsgvef455osqe",
#   "prov:label": "rdf:34_7",
#   "_cell": 1000,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreig5huuhe5ru3esfl3gic7c4cugxebydjyfkl6ebszzntwjfvtuzv4"
#   },
#   "_stmt_key": "34_7",
#   "_chunk_num": 34,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [34.8]: According to Botstein, what struck the examiner was that [Albert Einstein](/wiki/Albert_Einstein) "displayed a deep love of the music".
# _:s8_quote1 rdf:type schema:Quotation .
# _:s8_quote1 schema:text "displayed a deep love of the music" .
# _:s8_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicybu7ngoumauukeaxdantq7mqfsddz3xvgxup5lodlkgccr7pujm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicybu7ngoumauukeaxdantq7mqfsddz3xvgxup5lodlkgccr7pujm",
#   "prov:label": "rdf:34_8",
#   "_cell": 1002,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicpfdcyzkuia2fxk6qbcnu7vudcz254jmvstuuirzkwnxpe6ytrym"
#   },
#   "_stmt_key": "34_8",
#   "_chunk_num": 34,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [34.9]: The examiner noted that [Albert Einstein](/wiki/Albert_Einstein) had a quality that was and remains in short supply.
# _:s9_quote1 rdf:type schema:Quotation .
# _:s9_quote1 schema:text "a quality that was and remains in short supply" .
# _:s9_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicb45wlhv34vmx4piazsypyo452kbrkvcmnzdnlmmzbu3k3g2skzq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicb45wlhv34vmx4piazsypyo452kbrkvcmnzdnlmmzbu3k3g2skzq",
#   "prov:label": "rdf:34_9",
#   "_cell": 1004,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifrv2xv66ql3tqpxglzbzndvkmwizqej53xqw2uifcbpoy6i6fpka"
#   },
#   "_stmt_key": "34_9",
#   "_chunk_num": 34,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [34.10]: Music took on a pivotal and permanent role in [Albert Einstein](/wiki/Albert_Einstein)'s life from that period on.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasInterest <https://en.wikipedia.org/wiki/Chamber_music> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigp4o7apz7kcjej6x6z3hmbmi2nrz6j3yi325s7holn5eabnlfwpu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigp4o7apz7kcjej6x6z3hmbmi2nrz6j3yi325s7holn5eabnlfwpu",
#   "prov:label": "rdf:34_10",
#   "_cell": 1006,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib3trlnstgafrmmedttnmi7itsp6nuurp7issc2coqnssncvywvqe"
#   },
#   "_stmt_key": "34_10",
#   "_chunk_num": 34,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [34.11]: The idea of becoming a professional musician was not on [Albert Einstein](/wiki/Albert_Einstein)'s mind at any time.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasInterest <https://en.wikipedia.org/wiki/Music> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigwv7hi4npedruhhgbeu46woshjwcowtehcx3pk3bnrxwkknpavvy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigwv7hi4npedruhhgbeu46woshjwcowtehcx3pk3bnrxwkknpavvy",
#   "prov:label": "rdf:34_11",
#   "_cell": 1008,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidmxudzbqfafpcwtuocnmmaznrgumpwzhonjd2ikc7hqb732d57ju"
#   },
#   "_stmt_key": "34_11",
#   "_chunk_num": 34,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [34.12]: Among those with whom [Albert Einstein](/wiki/Albert_Einstein) played [chamber music](/wiki/chamber_music) were a few professionals, including [Kurt Appelbaum](/wiki/Kurt_Appelbaum).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:performer <https://en.wikipedia.org/wiki/Kurt_Appelbaum> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaq2dervbwjwaeben5j6e5cblgbtyo3p5ab7uii2s3cpnhtexh3fi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaq2dervbwjwaeben5j6e5cblgbtyo3p5ab7uii2s3cpnhtexh3fi",
#   "prov:label": "rdf:34_12",
#   "_cell": 1010,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibcbmf632wif2cyovzouij6jvhrxb5hmkm7cef7irp7bjca5pndfa"
#   },
#   "_stmt_key": "34_12",
#   "_chunk_num": 34,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [34.13]: [Albert Einstein](/wiki/Albert_Einstein) performed for private audiences and friends.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:performer <https://en.wikipedia.org/wiki/Chamber_music> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreig6b2bk5qo6jcih7qhiqzcb4246dtcilmzvscqcwqavith7dc46ky",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreig6b2bk5qo6jcih7qhiqzcb4246dtcilmzvscqcwqavith7dc46ky",
#   "prov:label": "rdf:34_13",
#   "_cell": 1012,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicdlbmktbwz44d43xizad6ayrbsxog262dpcb3upe6ebpbxjy7ffq"
#   },
#   "_stmt_key": "34_13",
#   "_chunk_num": 34,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [34.14]: Chamber music became a regular part of [Albert Einstein](/wiki/Albert_Einstein)'s social life while living in [Bern](/wiki/Bern).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:performer <https://en.wikipedia.org/wiki/Chamber_music> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidawlgyu6narujqkbrwtawyskmyrxfpagtmfy746cnmtiw4kzqfue",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidawlgyu6narujqkbrwtawyskmyrxfpagtmfy746cnmtiw4kzqfue",
#   "prov:label": "rdf:34_14",
#   "_cell": 1014,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaiobp5kmr2mpopw4duosptjeud6vbchrlxm5fw2nxyd3gl5hyfga"
#   },
#   "_stmt_key": "34_14",
#   "_chunk_num": 34,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [34.15]: Chamber music became a regular part of [Albert Einstein](/wiki/Albert_Einstein)'s social life while living in [Zurich](/wiki/Zurich).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:performer <https://en.wikipedia.org/wiki/Chamber_music> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreictjs5mkpwjpjbchvpmb5lgdbzi6zehuruc4gqqnvmt36nxclpcyi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreictjs5mkpwjpjbchvpmb5lgdbzi6zehuruc4gqqnvmt36nxclpcyi",
#   "prov:label": "rdf:34_15",
#   "_cell": 1016,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifnmquredxxn4hykhdom6uqmjy67rh2rfsluwfmo3d3qgc52mfpmi"
#   },
#   "_stmt_key": "34_15",
#   "_chunk_num": 34,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [34.16]: Chamber music became a regular part of [Albert Einstein](/wiki/Albert_Einstein)'s social life while living in [Berlin](/wiki/Berlin).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:performer <https://en.wikipedia.org/wiki/Chamber_music> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreih4cqvnhwuqwwh3opwszpv2oidqzi275svitymbdtkvvro2a5z6he",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreih4cqvnhwuqwwh3opwszpv2oidqzi275svitymbdtkvvro2a5z6he",
#   "prov:label": "rdf:34_16",
#   "_cell": 1018,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreictkujq5xowxvg6spojoeovfyw425swdf3qnatzfqtrd6pfjc4324"
#   },
#   "_stmt_key": "34_16",
#   "_chunk_num": 34,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [34.17]: While living in [Bern](/wiki/Bern), [Zurich](/wiki/Zurich), and [Berlin](/wiki/Berlin), [Albert Einstein](/wiki/Albert_Einstein) played [chamber music](/wiki/chamber_music) with [Max Planck](/wiki/Max_Planck) and his son.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:performer <https://en.wikipedia.org/wiki/Chamber_music> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiamz5umon5r5knzy2icck4wfgq6efhka5iaso7cxbqj5j6fwfk7qm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiamz5umon5r5knzy2icck4wfgq6efhka5iaso7cxbqj5j6fwfk7qm",
#   "prov:label": "rdf:34_17",
#   "_cell": 1020,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia6xrxjhb7j3rftgoexvipimfwc36zffvzce4vboxnjzs6lc2rfsm"
#   },
#   "_stmt_key": "34_17",
#   "_chunk_num": 34,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [34.18]: [Albert Einstein](/wiki/Albert_Einstein) is sometimes erroneously credited as the editor of the 1937 edition of the [Köchel catalog](/wiki/K%C3%B6chel_catalog) of [Mozart](/wiki/Mozart)'s work.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasInterest <https://en.wikipedia.org/wiki/Mozart> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic7bzdk3oobocvxuc4jwkp6jew6i5qvzxxo5mkvlweeftafnl5hum",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic7bzdk3oobocvxuc4jwkp6jew6i5qvzxxo5mkvlweeftafnl5hum",
#   "prov:label": "rdf:34_18",
#   "_cell": 1022,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigiwylquqdpkprstjusss2j6dtbzearmlul42ykzx5vzafbvekglq"
#   },
#   "_stmt_key": "34_18",
#   "_chunk_num": 34,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [34.19]: The 1937 edition of the [Köchel catalog](/wiki/K%C3%B6chel_catalog) of [Mozart](/wiki/Mozart)'s work was prepared by [Alfred Einstein](/wiki/Alfred_Einstein).
# _:s19_quote1 rdf:type schema:Quotation .
# _:s19_quote1 schema:text "Mozart's music is so pure it seems to have been ever-present in the universe" .
# _:s19_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s19_quote2 rdf:type schema:Quotation .
# _:s19_quote2 schema:text "Mozart's music is so pure it seems to have been ever-present in the universe" .
# _:s19_quote2 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiexk267ajmwq4c23yxuh2jr6q23l3jgac55gn7j345s74ooakwbi4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiexk267ajmwq4c23yxuh2jr6q23l3jgac55gn7j345s74ooakwbi4",
#   "prov:label": "rdf:34_19",
#   "_cell": 1024,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicqhbuemkxxxvd7ssni277mtetwq2lm4jmmbqstfb6hn7ihytqji4"
#   },
#   "_stmt_key": "34_19",
#   "_chunk_num": 34,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Statement [34.20]: [Alfred Einstein](/wiki/Alfred_Einstein) may have been a distant relation of [Albert Einstein](/wiki/Albert_Einstein).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasInterest <https://en.wikipedia.org/wiki/Bach> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidfufuoit4w2b4hc2fdofgzinodmz7awd6lv4kmec4iu6jzl6pzua",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidfufuoit4w2b4hc2fdofgzinodmz7awd6lv4kmec4iu6jzl6pzua",
#   "prov:label": "rdf:34_20",
#   "_cell": 1026,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiekiwbow5rgv4lxklxilg65m7epzj26qyry5mjlrst5yrgewigabe"
#   },
#   "_stmt_key": "34_20",
#   "_chunk_num": 34,
#   "_stmt_idx": 20
# }

# %% [raw]
# # Statement [34.21]: [Mozart](/wiki/Mozart) was a special favorite of [Albert Einstein](/wiki/Albert_Einstein).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasInterest <https://en.wikipedia.org/wiki/Beethoven> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiciwn7tagh3ccuygtpxqbmw6nz3f7krfgrlmitlmtpamzvj3v42hm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiciwn7tagh3ccuygtpxqbmw6nz3f7krfgrlmitlmtpamzvj3v42hm",
#   "prov:label": "rdf:34_21",
#   "_cell": 1028,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicmkcez6jeooe4yweahhvrb4ntoavamtt5t5mok7sztmp7he6n2ke"
#   },
#   "_stmt_key": "34_21",
#   "_chunk_num": 34,
#   "_stmt_idx": 21
# }

# %% [raw]
# # Statement [34.22]: [Albert Einstein](/wiki/Albert_Einstein) said that "Mozart's music is so pure it seems to have been ever-present in the universe".
# _:s22_quote1 rdf:type schema:Quotation .
# _:s22_quote1 schema:text "Give me Bach, rather, and then more Bach." .
# _:s22_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s22_quote2 rdf:type schema:Quotation .
# _:s22_quote2 schema:text "Give me Bach, rather, and then more Bach." .
# _:s22_quote2 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie22njdakirs74hmmfutder4hoxejcy3vihrvavgzjhg5g2sigbhi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie22njdakirs74hmmfutder4hoxejcy3vihrvavgzjhg5g2sigbhi",
#   "prov:label": "rdf:34_22",
#   "_cell": 1030,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaptt3lqg54zmhkjocfvtavnrs6pc6qgsevkvkr7l3jct44cqkb7u"
#   },
#   "_stmt_key": "34_22",
#   "_chunk_num": 34,
#   "_stmt_idx": 22
# }

# %% [raw]
# # Statement [34.23]: [Albert Einstein](/wiki/Albert_Einstein) preferred [Bach](/wiki/Bach) to [Beethoven](/wiki/Beethoven).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasInterest <https://en.wikipedia.org/wiki/Bach> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie4akl2zjmjndgbddmrnvcqzm2fehawoe4cavg7xlgnlenyil4gjy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie4akl2zjmjndgbddmrnvcqzm2fehawoe4cavg7xlgnlenyil4gjy",
#   "prov:label": "rdf:34_23",
#   "_cell": 1032,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiglfzwsdfr7s3tbhqq5estlnelsjlwd2jiurk3enm6gvjfsessalq"
#   },
#   "_stmt_key": "34_23",
#   "_chunk_num": 34,
#   "_stmt_idx": 23
# }

# %% [raw]
# # Statement [34.24]: [Albert Einstein](/wiki/Albert_Einstein) once said: "Give me Bach, rather, and then more Bach."
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasInterest <https://en.wikipedia.org/wiki/Beethoven> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiba4icr3hwddfrcbvxbfjlnogmirsk2yccsmmxlpylpgpn7s7chdu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiba4icr3hwddfrcbvxbfjlnogmirsk2yccsmmxlpylpgpn7s7chdu",
#   "prov:label": "rdf:34_24",
#   "_cell": 1034,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid5vwiqooyfv2waagyv5oeg754hs2eaizen6befmdxd3ticl7n73y"
#   },
#   "_stmt_key": "34_24",
#   "_chunk_num": 34,
#   "_stmt_idx": 24
# }

# %% [raw]
# # Statement [35.1]: In 1931, [Albert Einstein](/wiki/Albert_Einstein) visited the Zoellner family conservatory in [Los Angeles](/wiki/Los_Angeles) while engaged in research at the [California Institute of Technology](/wiki/California_Institute_of_Technology).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:performerIn _:s1_event1 .
# _:s1_event1 rdf:type schema:MusicEvent .
# _:s1_event1 schema:name "Visit to Zoellner family conservatory" .
# _:s1_event1 schema:location <https://en.wikipedia.org/wiki/Los_Angeles> .
# _:s1_event1 schema:organizer <https://en.wikipedia.org/wiki/California_Institute_of_Technology> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiao55dfyiz3iw6md2nmnncsqfhg6azl5lrg5skkcylivaxb6adtbu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiao55dfyiz3iw6md2nmnncsqfhg6azl5lrg5skkcylivaxb6adtbu",
#   "prov:label": "rdf:35_1",
#   "_cell": 1036,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidjfah2dmhrqhmonoihgrqkwwzyfozlhsysm2rtod3ggaou7hmrum"
#   },
#   "_stmt_key": "35_1",
#   "_chunk_num": 35,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [35.2]: At the Zoellner family conservatory, [Albert Einstein](/wiki/Albert_Einstein) played some works by [Beethoven](/wiki/Beethoven) and [Mozart](/wiki/Mozart) with members of the [Zoellner Quartet](/wiki/Zoellner_Quartet).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:performerIn _:s2_event1 .
# _:s2_event1 rdf:type schema:MusicEvent .
# _:s2_event1 schema:name "Playing at Zoellner family conservatory" .
# _:s2_event1 schema:performer <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s2_event1 schema:location <https://en.wikipedia.org/wiki/Los_Angeles> .
# _:s2_event1 schema:attendees <https://en.wikipedia.org/wiki/Zoellner_Quartet> .
# _:s2_event1 schema:composer <https://en.wikipedia.org/wiki/Beethoven> .
# _:s2_event1 schema:composer <https://en.wikipedia.org/wiki/Mozart> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigyjhzbrmcbfoyofpjulw3pt7ylfx3ons7hselzjzuc2qbvyjztyq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigyjhzbrmcbfoyofpjulw3pt7ylfx3ons7hselzjzuc2qbvyjztyq",
#   "prov:label": "rdf:35_2",
#   "_cell": 1038,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreignbmmujzu2rtdu7qdkf2iorfhm224baocsxwrqwxzthq4sv3deey"
#   },
#   "_stmt_key": "35_2",
#   "_chunk_num": 35,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [35.3]: Near the end of his life, the [Juilliard Quartet](/wiki/Juilliard_Quartet) visited [Albert Einstein](/wiki/Albert_Einstein) in [Princeton, New Jersey](/wiki/Princeton%2C_New_Jersey).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:performerIn _:s3_event1 .
# _:s3_event1 rdf:type schema:MusicEvent .
# _:s3_event1 schema:name "Visit by Juilliard Quartet" .
# _:s3_event1 schema:location <https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey> .
# _:s3_event1 schema:attendees <https://en.wikipedia.org/wiki/Juilliard_Quartet> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreig26xgjtn5ttqdz3qvhjusxfvadrazwickcvtiaqxebqscik26wde",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreig26xgjtn5ttqdz3qvhjusxfvadrazwickcvtiaqxebqscik26wde",
#   "prov:label": "rdf:35_3",
#   "_cell": 1040,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihdi4ugimsacoughxzg6fep52kgjgn7c27myk7yvbhpoccgutrkia"
#   },
#   "_stmt_key": "35_3",
#   "_chunk_num": 35,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [35.4]: During the visit, [Albert Einstein](/wiki/Albert_Einstein) played his violin with the [Juilliard Quartet](/wiki/Juilliard_Quartet).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:performerIn _:s4_event1 .
# _:s4_event1 rdf:type schema:MusicEvent .
# _:s4_event1 schema:name "Playing with Juilliard Quartet" .
# _:s4_event1 schema:performer <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s4_event1 schema:attendees <https://en.wikipedia.org/wiki/Juilliard_Quartet> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicy7xvak7u4kaobgrpcdi6l3k6dyqblk7gntcl6qpo7kjzcgwdnmy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicy7xvak7u4kaobgrpcdi6l3k6dyqblk7gntcl6qpo7kjzcgwdnmy",
#   "prov:label": "rdf:35_4",
#   "_cell": 1042,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiffdgcfmmtmj2a6qzzpahqemprkgzekdji74cib4b75w3k24ayfy4"
#   },
#   "_stmt_key": "35_4",
#   "_chunk_num": 35,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [35.5]: The [Juilliard Quartet](/wiki/Juilliard_Quartet) was impressed by [Albert Einstein](/wiki/Albert_Einstein)'s level of coordination and intonation.
# _:s5_event1 rdf:type schema:MusicEvent .
# _:s5_event1 schema:name "Juilliard Quartet's visit to Einstein" .
# _:s5_event1 schema:attendees <https://en.wikipedia.org/wiki/Juilliard_Quartet> .
# _:s5_event1 schema:performer <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s5_event1 schema:organizer <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicj45ae43cvlutaz75vrbfpphrvx5f2byyzpfhif7ijiumu4prvau",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicj45ae43cvlutaz75vrbfpphrvx5f2byyzpfhif7ijiumu4prvau",
#   "prov:label": "rdf:35_5",
#   "_cell": 1044,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreic2wrrh5mcflcj6gd2ubvgrqacnjgjuy7nvgppbyinxf7ofr6nbqy"
#   },
#   "_stmt_key": "35_5",
#   "_chunk_num": 35,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [35.6]: On 17 April 1955, [Albert Einstein](/wiki/Albert_Einstein) experienced [internal bleeding](/wiki/internal_bleeding) caused by the rupture of an [abdominal aortic aneurysm](/wiki/abdominal_aortic_aneurysm).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:healthCondition <https://en.wikipedia.org/wiki/abdominal_aortic_aneurysm> .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreib73f42mcsfcbp2c7urruf263f6mqdygbrmgyutztjzowxh4bdcsm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreib73f42mcsfcbp2c7urruf263f6mqdygbrmgyutztjzowxh4bdcsm",
#   "prov:label": "rdf:35_6",
#   "_cell": 1046,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiglpp5ecbqweatbhfrz53jjbnei5warbisjehvkbqegelkxhltlee"
#   },
#   "_stmt_key": "35_6",
#   "_chunk_num": 35,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [35.7]: The [abdominal aortic aneurysm](/wiki/abdominal_aortic_aneurysm) had previously been reinforced surgically by [Rudolph Nissen](/wiki/Rudolph_Nissen) in 1948.
# <https://en.wikipedia.org/wiki/abdominal_aortic_aneurysm> schema:medicalTherapy <https://en.wikipedia.org/wiki/Rudolph_Nissen> .
# <https://en.wikipedia.org/wiki/abdominal_aortic_aneurysm> schema:startDate "1948"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigvyuzf7v5mimycuzzpjchem7gbwasqzfcdmxmy2xfi62f6u3vw6q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigvyuzf7v5mimycuzzpjchem7gbwasqzfcdmxmy2xfi62f6u3vw6q",
#   "prov:label": "rdf:35_7",
#   "_cell": 1048,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibyxhjq7s322efa4zynqod6kfotgkjdmiw4kmlx5qgvyetn7kbtl4"
#   },
#   "_stmt_key": "35_7",
#   "_chunk_num": 35,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [35.8]: [Albert Einstein](/wiki/Albert_Einstein)'s ashes were scattered at an undisclosed location.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:additionalType schema: cremation .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:deathPlace <https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifzuqv3fe3vxvfn7x4jeffpj72u4mskaugk7f4pg45y6vz3ubtguq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifzuqv3fe3vxvfn7x4jeffpj72u4mskaugk7f4pg45y6vz3ubtguq",
#   "prov:label": "rdf:35_8",
#   "_cell": 1050,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibjeuiovrnmlq362fjqg7si3kxmx2hoie2qzq243s3izlde6b7qva"
#   },
#   "_stmt_key": "35_8",
#   "_chunk_num": 35,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [35.9]: Throughout his life, [Albert Einstein](/wiki/Albert_Einstein) published hundreds of books and articles.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:publication _:s9_pub1 .
# _:s9_pub1 rdf:type schema:CreativeWork .
# _:s9_pub1 schema:name "Hundreds of books and articles" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiej3jixbcy5cweix363gctjs6vydltofyin2ajakrwppqxz4wbowe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiej3jixbcy5cweix363gctjs6vydltofyin2ajakrwppqxz4wbowe",
#   "prov:label": "rdf:35_9",
#   "_cell": 1052,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreif4dtsb3mhmpeixqewnitz5y3fl6gb4clcn2ectcwrd2tmecp2y44"
#   },
#   "_stmt_key": "35_9",
#   "_chunk_num": 35,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [35.10]: [Albert Einstein](/wiki/Albert_Einstein) collaborated with other scientists on additional projects.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:collaborator _:s10_collab1 .
# _:s10_collab1 rdf:type schema:Person .
# _:s10_collab1 schema:name "Other scientists" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigtwniardmavj5s3bunns2guzovmxmyoxmu73vqs4aydtnnbpmo3i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigtwniardmavj5s3bunns2guzovmxmyoxmu73vqs4aydtnnbpmo3i",
#   "prov:label": "rdf:35_10",
#   "_cell": 1054,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia677niuujtv24awleuc7qc3fro2jnmzs4gi5mw5uzl5rb52ouhxu"
#   },
#   "_stmt_key": "35_10",
#   "_chunk_num": 35,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [35.11]: Among the projects [Albert Einstein](/wiki/Albert_Einstein) collaborated on were the [Bose–Einstein statistics](/wiki/Bose%E2%80%93Einstein_statistics).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:collaborator <https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_statistics> .
# <https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_statistics> schema:name "Bose-Einstein statistics" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreib7hajlo4rqfsm7v2yt3xrnpl357v7i3bmps22hpaoducobwajthe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreib7hajlo4rqfsm7v2yt3xrnpl357v7i3bmps22hpaoducobwajthe",
#   "prov:label": "rdf:35_11",
#   "_cell": 1056,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibpvbxt4xnciiobsefdhbqu2zsy2ixqwy3576wgxzzkjulmm2wbly"
#   },
#   "_stmt_key": "35_11",
#   "_chunk_num": 35,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [35.12]: [Albert Einstein](/wiki/Albert_Einstein) also collaborated on the [Einstein refrigerator](/wiki/Einstein_refrigerator).
# https://en.wikipedia.org/wiki/Albert_Einstein schema:collaborator <https://en.wikipedia.org/wiki/Einstein_refrigerator> .
# <https://en.wikipedia.org/wiki/Einstein_refrigerator> schema:name "Einstein refrigerator" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibwdwfjzypgdjzyw2d3xmcg67iyr7djwip5fnblovptks6dvddolm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibwdwfjzypgdjzyw2d3xmcg67iyr7djwip5fnblovptks6dvddolm",
#   "prov:label": "rdf:35_12",
#   "_cell": 1058,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreig2gamd2pna36qgu4zfm5ppec626pqkpeempeadmqi2o2ilh7v65e"
#   },
#   "_stmt_key": "35_12",
#   "_chunk_num": 35,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [36.1]: [Albert Einstein](/wiki/Albert_Einstein) submitted his first paper to [Annalen der Physik](/wiki/Annalen_der_Physik) in 1900.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author _:s1_paper1 .
# _:s1_paper1 rdf:type schema:ScholarlyArticle .
# _:s1_paper1 schema:datePublished "1901"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidkcs3ix6hrxloh7vq3cmosdecsj2yg7sa4qh32zy2hejcmksrjoe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidkcs3ix6hrxloh7vq3cmosdecsj2yg7sa4qh32zy2hejcmksrjoe",
#   "prov:label": "rdf:36_1",
#   "_cell": 1060,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibwzfgg3v4lidiapcy7plufesutr2dkmf36kqvkofopuivajjnprm"
#   },
#   "_stmt_key": "36_1",
#   "_chunk_num": 36,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [36.2]: [Albert Einstein](/wiki/Albert_Einstein)'s first paper was published in 1901 with the title "Folgerungen aus den Capillaritätserscheinungen", which translates as "Conclusions from the capillarity phenomena".
# _:s2_paper1 schema:title "Folgerungen aus den Capillaritätserscheinungen" .
# _:s2_paper1 schema:translationOfWork _:s2_paper1_translated .
# _:s2_paper1_translated schema:name "Conclusions from the capillarity phenomena" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihbjzhpkkvlz7ilbzwyao4dijpqmsxq4mt7hn6s5f44njzowymuwi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihbjzhpkkvlz7ilbzwyao4dijpqmsxq4mt7hn6s5f44njzowymuwi",
#   "prov:label": "rdf:36_2",
#   "_cell": 1062,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihje4io2rglyp6kf6ad4qkgg5fpnlddhgve5spfueaktouny7ghse"
#   },
#   "_stmt_key": "36_2",
#   "_chunk_num": 36,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [36.3]: [Albert Einstein](/wiki/Albert_Einstein) published two papers in 1902–1903 on thermodynamics.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author _:s3_paper1 .
# _:s3_paper1 rdf:type schema:ScholarlyArticle .
# _:s3_paper1 schema:datePublished "1902"^^xsd:gYear .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author _:s3_paper2 .
# _:s3_paper2 rdf:type schema:ScholarlyArticle .
# _:s3_paper2 schema:datePublished "1903"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiab2zzxrtaf4jktlzmalscwjpl2qe7uge4ivph7bnsx3rj4qxsi4e",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiab2zzxrtaf4jktlzmalscwjpl2qe7uge4ivph7bnsx3rj4qxsi4e",
#   "prov:label": "rdf:36_3",
#   "_cell": 1064,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihlpqce23fqg6rj32rme7wafnyoepzmeiapehxcgiv5x3ttnidywa"
#   },
#   "_stmt_key": "36_3",
#   "_chunk_num": 36,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [36.4]: The two papers published by [Albert Einstein](/wiki/Albert_Einstein) in 1902–1903 attempted to interpret [atom](/wiki/atom)ic phenomena from a statistical point of view.
# _:s4_paper1 schema:about <https://en.wikipedia.org/wiki/atom> .
# _:s4_paper2 schema:about <https://en.wikipedia.org/wiki/atom> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreib76bsmywe465n55eplgn7hhhumgdi3ig5nimdbgmo75wbuy6culu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreib76bsmywe465n55eplgn7hhhumgdi3ig5nimdbgmo75wbuy6culu",
#   "prov:label": "rdf:36_4",
#   "_cell": 1066,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreight7q6456iotysew6nizsaog4wdn2zo5lp7egtxlgzcd5uazyfqa"
#   },
#   "_stmt_key": "36_4",
#   "_chunk_num": 36,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [36.5]: The papers published by [Albert Einstein](/wiki/Albert_Einstein) in 1902–1903 were the foundation for his 1905 paper on [Theory of Brownian motion](/wiki/Brownian_motion).
# _:s5_paper1 schema:isBasedOn _:s5_paper3 .
# _:s5_paper2 schema:isBasedOn _:s5_paper3 .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibg56aahccgnxlmijtvr2n63w7phtc2x7fxsjw27nvne6jp3jvoba",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibg56aahccgnxlmijtvr2n63w7phtc2x7fxsjw27nvne6jp3jvoba",
#   "prov:label": "rdf:36_5",
#   "_cell": 1068,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiggujidgffuk4jivl5st2yuoh7twf2t6ql2ckvdc4cid2hxg3j2eu"
#   },
#   "_stmt_key": "36_5",
#   "_chunk_num": 36,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [36.6]: The 1905 paper on [Theory of Brownian motion](/wiki/Brownian_motion) by [Albert Einstein](/wiki/Albert_Einstein) showed that Brownian movement can be construed as firm evidence that molecules exist.
# _:s6_paper3 schema:mainEntity <https://en.wikipedia.org/wiki/Brownian_motion> .
# _:s6_paper3 schema:text "Brownian movement can be construed as firm evidence that molecules exist" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigm5vgavzvbm7gzhqrgpgpzf3newyvbb7waruakdrktjcjcb7hlqa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigm5vgavzvbm7gzhqrgpgpzf3newyvbb7waruakdrktjcjcb7hlqa",
#   "prov:label": "rdf:36_6",
#   "_cell": 1070,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidbukctzhpgqumazsl7a5x25hhxsse4ggbgenrebjxgluszygl3ca"
#   },
#   "_stmt_key": "36_6",
#   "_chunk_num": 36,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [36.7]: [Albert Einstein](/wiki/Albert_Einstein)'s research in 1903 and 1904 was mainly concerned with the effect of finite atomic size on diffusion phenomena.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author _:s7_paper4 .
# _:s7_paper4 rdf:type schema:ScholarlyArticle .
# _:s7_paper4 schema:datePublished "1903"^^xsd:gYear .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author _:s7_paper5 .
# _:s7_paper5 rdf:type schema:ScholarlyArticle .
# _:s7_paper5 schema:datePublished "1904"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibhonuafe3gmzxfmompqk2xdmcllhcnxzt2wplnlkevksxmi37sxa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibhonuafe3gmzxfmompqk2xdmcllhcnxzt2wplnlkevksxmi37sxa",
#   "prov:label": "rdf:36_7",
#   "_cell": 1072,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiggtowgso6kibmymz5ae5orb36qnt7ywbjyxizps2n45gs2ucoroq"
#   },
#   "_stmt_key": "36_7",
#   "_chunk_num": 36,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [36.8]: [Albert Einstein](/wiki/Albert_Einstein) returned to the problem of thermodynamic fluctuations.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author _:s8_paper6 .
# _:s8_paper6 rdf:type schema:ScholarlyArticle .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigu4qp26wyz7midgp56c7nufgrenjz2yybval2wwfmuubysyx2b4a",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigu4qp26wyz7midgp56c7nufgrenjz2yybval2wwfmuubysyx2b4a",
#   "prov:label": "rdf:36_8",
#   "_cell": 1074,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieq632wauizvq4zn6vxddy5aaoitf6c24ewxyz5gy5ucgd7cb33su"
#   },
#   "_stmt_key": "36_8",
#   "_chunk_num": 36,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [36.9]: [Albert Einstein](/wiki/Albert_Einstein) gave a treatment of the density variations in a fluid at its critical point.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author _:s9_paper7 .
# _:s9_paper7 rdf:type schema:ScholarlyArticle .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidxsscvolo6hwankcvy3q3x4tavk4yknexsifqmo7smgsk5jylruy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidxsscvolo6hwankcvy3q3x4tavk4yknexsifqmo7smgsk5jylruy",
#   "prov:label": "rdf:36_9",
#   "_cell": 1076,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreig6qecacrrxncrtt6gxuhg4nspsxvbiy6keug2udcuwwjm7vu42n4"
#   },
#   "_stmt_key": "36_9",
#   "_chunk_num": 36,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [36.10]: Density fluctuations in a fluid at its critical point are controlled by the second derivative of the free energy with respect to the density.
# _:s10_paper7 schema:mainEntity <https://en.wikipedia.org/wiki/Free_State_of_Prussia> .
# _:s10_paper7 schema:about <https://en.wikipedia.org/wiki/Free_State_of_Prussia> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiegbcrvdwxoyeen27vdel3cufe6dra5zspxtrpcgfagnddnmnhg3y",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiegbcrvdwxoyeen27vdel3cufe6dra5zspxtrpcgfagnddnmnhg3y",
#   "prov:label": "rdf:36_10",
#   "_cell": 1078,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihcdhajixeieaq7woyjubtn3hz3f44slrrp5cqs6zkd5kvwojqkui"
#   },
#   "_stmt_key": "36_10",
#   "_chunk_num": 36,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [36.11]: At the critical point, the second derivative of the free energy with respect to the density is zero.
# _:s11_paper7 schema:mainEntity <https://en.wikipedia.org/wiki/Free_State_of_Prussia> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibutvbufekjpowzzcq4gzcwpvxeun7wy2cosru4jd57tplpv4mlyi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibutvbufekjpowzzcq4gzcwpvxeun7wy2cosru4jd57tplpv4mlyi",
#   "prov:label": "rdf:36_11",
#   "_cell": 1080,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihmcp4jnsdvd3v64xxt4d5izq2fbzc7mrqxqoe3eh5cxfomdpmpyu"
#   },
#   "_stmt_key": "36_11",
#   "_chunk_num": 36,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [36.12]: At the critical point, large fluctuations occur due to the zero second derivative.
# _:s12_paper7 schema:mainEntity <https://en.wikipedia.org/wiki/Free_State_of_Prussia> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigouwoa5pzuzul3pm47sffkqwnfqbws3qvpjjfadwm4rbqf4sh7tm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigouwoa5pzuzul3pm47sffkqwnfqbws3qvpjjfadwm4rbqf4sh7tm",
#   "prov:label": "rdf:36_12",
#   "_cell": 1082,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih5lmxm6bpxivvn5ktxugbb6zshrmsz4a2hrzisaklrrspnneue5y"
#   },
#   "_stmt_key": "36_12",
#   "_chunk_num": 36,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [36.13]: The effect of density fluctuations in a fluid at its critical point is that light of all wavelengths is scattered.
# _:s13_paper7 schema:mainEntity <https://en.wikipedia.org/wiki/Free_State_of_Prussia> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidf4rw4z7bvbes5vumw656o7buyx7os56hwlimabn2qrvzltxbvnm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidf4rw4z7bvbes5vumw656o7buyx7os56hwlimabn2qrvzltxbvnm",
#   "prov:label": "rdf:36_13",
#   "_cell": 1084,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih6oeves4y6fksr6ppkbwbon6d5l5lrfwnbulkggg7vhbg3ouh2jm"
#   },
#   "_stmt_key": "36_13",
#   "_chunk_num": 36,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [36.14]: Light scattering due to density fluctuations makes the fluid look milky white.
# _:s14_paper7 schema:mainEntity <https://en.wikipedia.org/wiki/Free_State_of_Prussia> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifubtfo72uv2bcxasxcybdrfjvf7x3uufmf5q57e4dne5kozgj2za",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifubtfo72uv2bcxasxcybdrfjvf7x3uufmf5q57e4dne5kozgj2za",
#   "prov:label": "rdf:36_14",
#   "_cell": 1086,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicma4yzwqevd2rtwo2w23wek3cycxw3ubgzzapi6namawv2acnjem"
#   },
#   "_stmt_key": "36_14",
#   "_chunk_num": 36,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [36.15]: [Albert Einstein](/wiki/Albert_Einstein) related critical opalescence to [Rayleigh scattering](/wiki/Rayleigh_scattering).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author _:s15_paper8 .
# _:s15_paper8 rdf:type schema:ScholarlyArticle .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibgtrt6g3jkwn62hkrt6fxwdwqma3w4ekw442a2inqd7gruky4ise",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibgtrt6g3jkwn62hkrt6fxwdwqma3w4ekw442a2inqd7gruky4ise",
#   "prov:label": "rdf:36_15",
#   "_cell": 1088,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigtpav3akoqt7naddureyzhcvc5hxoym57orbfjcwxstwvchzhlja"
#   },
#   "_stmt_key": "36_15",
#   "_chunk_num": 36,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [36.16]: [Rayleigh scattering](/wiki/Rayleigh_scattering) occurs when the fluctuation size is much smaller than the wavelength.
# _:s16_paper8 schema:mainEntity <https://en.wikipedia.org/wiki/Rayleigh_scattering> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreid4t27xt7sg3tv6r4bei7eyxvy7r6vbgu6gqif35b2jclcane4dt4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreid4t27xt7sg3tv6r4bei7eyxvy7r6vbgu6gqif35b2jclcane4dt4",
#   "prov:label": "rdf:36_16",
#   "_cell": 1090,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifidr4x6kmd5oqn7rnwk4fs5mgcjp65ap6ihepdsqxqpaavcf4zhu"
#   },
#   "_stmt_key": "36_16",
#   "_chunk_num": 36,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [36.17]: [Rayleigh scattering](/wiki/Rayleigh_scattering) explains why the sky is blue.
# _:s17_paper8 schema:mainEntity <https://en.wikipedia.org/wiki/Rayleigh_scattering> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiagfgqo7z67weslafdtcrhgwi2owxq2zajxx45sopflwt35ryf3oi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiagfgqo7z67weslafdtcrhgwi2owxq2zajxx45sopflwt35ryf3oi",
#   "prov:label": "rdf:36_17",
#   "_cell": 1092,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiba3vbmcavy354lp42rw6ugxpjyu7ak7uimnyuitm6saehp2v433u"
#   },
#   "_stmt_key": "36_17",
#   "_chunk_num": 36,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [36.18]: [Albert Einstein](/wiki/Albert_Einstein) quantitatively derived critical opalescence from a treatment of density fluctuations.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author _:s18_paper9 .
# _:s18_paper9 rdf:type schema:ScholarlyArticle .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidppyx4l2ehjju56ocr73fjefjf5nue5fwy2wkqgqjuqorpx5q47q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidppyx4l2ehjju56ocr73fjefjf5nue5fwy2wkqgqjuqorpx5q47q",
#   "prov:label": "rdf:36_18",
#   "_cell": 1094,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiax6wlslet4zuomyscjg3agag7l7ivqjgnh7ktpdl7dzaaw5xbfx4"
#   },
#   "_stmt_key": "36_18",
#   "_chunk_num": 36,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [36.19]: [Albert Einstein](/wiki/Albert_Einstein) demonstrated how both critical opalescence and [Rayleigh scattering](/wiki/Rayleigh_scattering) originate from the atomistic constitution of matter.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author _:s19_paper10 .
# _:s19_paper10 rdf:type schema:ScholarlyArticle .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreid6kkpywhjlzqxf7y3sgnovegywrva2mhsisv4kbezcb6zxbz6v6m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreid6kkpywhjlzqxf7y3sgnovegywrva2mhsisv4kbezcb6zxbz6v6m",
#   "prov:label": "rdf:36_19",
#   "_cell": 1096,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibvb2ttwuhw7ktk6c2xnlgso6mlljvkj3y2ophreoscalhi7vxp5u"
#   },
#   "_stmt_key": "36_19",
#   "_chunk_num": 36,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Statement [37.1]: [Albert Einstein](/wiki/Albert_Einstein) submitted his first paper to [Annalen der Physik](/wiki/Annalen_der_Physik) in 1900.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:publishes _:s1_article1 .
# _:s1_article1 rdf:type schema:ScholarlyArticle .
# _:s1_article1 schema:datePublished "1900"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibzupwmpfumslcju5wf6a5vy5scbfxoifheci7gbdr7eo7jeel47q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibzupwmpfumslcju5wf6a5vy5scbfxoifheci7gbdr7eo7jeel47q",
#   "prov:label": "rdf:37_1",
#   "_cell": 1098,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibwzfgg3v4lidiapcy7plufesutr2dkmf36kqvkofopuivajjnprm"
#   },
#   "_stmt_key": "37_1",
#   "_chunk_num": 37,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [37.2]: [Albert Einstein](/wiki/Albert_Einstein)'s first paper was published in 1901 with the title "Folgerungen aus den Capillaritätserscheinungen", which translates as "Conclusions from the capillarity phenomena".
# _:s2_article1 rdf:type schema:ScholarlyArticle .
# _:s2_article1 schema:title "Folgerungen aus den Capillaritätserscheinungen" .
# _:s2_article1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s2_article1 schema:datePublished "1901"^^xsd:gYear .
# _:s2_article1 schema:translationOfWork "Conclusions from the capillarity phenomena" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidvnxqdbzcd6ywmerwqblbcphzjrl5xqdpo6gqsbqii3faxkqvhw4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidvnxqdbzcd6ywmerwqblbcphzjrl5xqdpo6gqsbqii3faxkqvhw4",
#   "prov:label": "rdf:37_2",
#   "_cell": 1100,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihje4io2rglyp6kf6ad4qkgg5fpnlddhgve5spfueaktouny7ghse"
#   },
#   "_stmt_key": "37_2",
#   "_chunk_num": 37,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [37.3]: [Albert Einstein](/wiki/Albert_Einstein) published two papers in 1902–1903 on thermodynamics.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:publishes _:s3_article1 .
# _:s3_article1 rdf:type schema:ScholarlyArticle .
# _:s3_article1 schema:datePublished "1902"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibl7zeloc5lydxbb2pfdy7io2v2pnnawm32qznmtgxplgp6i3fstm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibl7zeloc5lydxbb2pfdy7io2v2pnnawm32qznmtgxplgp6i3fstm",
#   "prov:label": "rdf:37_3",
#   "_cell": 1102,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihlpqce23fqg6rj32rme7wafnyoepzmeiapehxcgiv5x3ttnidywa"
#   },
#   "_stmt_key": "37_3",
#   "_chunk_num": 37,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [37.4]: The thermodynamic papers published by [Albert Einstein](/wiki/Albert_Einstein) in 1902–1903 attempted to interpret [atom](/wiki/atom)ic phenomena from a statistical point of view.
# _:s4_article1 rdf:type schema:ScholarlyArticle .
# _:s4_article1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s4_article1 schema:text "The thermodynamic papers published by Albert Einstein in 1902–1903 attempted to interpret atomistic phenomena from a statistical point of view." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidbv6k5vyqt23kor2fqlnenydccotbzgkcixspodfen5rahclstvy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidbv6k5vyqt23kor2fqlnenydccotbzgkcixspodfen5rahclstvy",
#   "prov:label": "rdf:37_4",
#   "_cell": 1104,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiebs6n4nix6ps3xaksvd3w5mpsi3xpxp7qk4sgkqdyhu3odlbzeme"
#   },
#   "_stmt_key": "37_4",
#   "_chunk_num": 37,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [37.5]: The papers published by [Albert Einstein](/wiki/Albert_Einstein) in 1902–1903 were the foundation for his 1905 paper on [Theory of Brownian motion](/wiki/Brownian_motion).
# _:s5_article1 rdf:type schema:ScholarlyArticle .
# _:s5_article1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s5_article1 schema:datePublished "1905"^^xsd:gYear .
# _:s5_article1 schema:title "Theory of Brownian motion" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreid4fbeqaayi3s6i3u2kcgfik7cpqcur5maiffnvxbgu4bd3e2fbz4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreid4fbeqaayi3s6i3u2kcgfik7cpqcur5maiffnvxbgu4bd3e2fbz4",
#   "prov:label": "rdf:37_5",
#   "_cell": 1106,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiggujidgffuk4jivl5st2yuoh7twf2t6ql2ckvdc4cid2hxg3j2eu"
#   },
#   "_stmt_key": "37_5",
#   "_chunk_num": 37,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [37.6]: The 1905 paper on [Theory of Brownian motion](/wiki/Brownian_motion) published by [Albert Einstein](/wiki/Albert_Einstein) showed that Brownian movement can be construed as firm evidence that molecules exist.
# _:s6_article1 rdf:type schema:ScholarlyArticle .
# _:s6_article1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s6_article1 schema:datePublished "1905"^^xsd:gYear .
# _:s6_article1 schema:title "Theory of Brownian motion" .
# _:s6_article1 schema:text "The 1905 paper on Theory of Brownian motion published by Albert Einstein showed that Brownian movement can be construed as firm evidence that molecules exist." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigt7uolom6arcerd2afkxhi37ckg4ewmawyofusn4wpbxro67ukhi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigt7uolom6arcerd2afkxhi37ckg4ewmawyofusn4wpbxro67ukhi",
#   "prov:label": "rdf:37_6",
#   "_cell": 1108,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaah7dml4t3vih2ywsfs462w6mpzjr2bbnpgr4lvxgs5md7xfdfeq"
#   },
#   "_stmt_key": "37_6",
#   "_chunk_num": 37,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [37.7]: [Albert Einstein](/wiki/Albert_Einstein)'s research in 1903 and 1904 was mainly concerned with the effect of finite atomic size on diffusion phenomena.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:publishes _:s7_article1 .
# _:s7_article1 rdf:type schema:ScholarlyArticle .
# _:s7_article1 schema:datePublished "1903"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibkwce4owecjnqb75pschfr26h7tjhsakn36yt3477penecpvfttu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibkwce4owecjnqb75pschfr26h7tjhsakn36yt3477penecpvfttu",
#   "prov:label": "rdf:37_7",
#   "_cell": 1110,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiggtowgso6kibmymz5ae5orb36qnt7ywbjyxizps2n45gs2ucoroq"
#   },
#   "_stmt_key": "37_7",
#   "_chunk_num": 37,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [37.8]: [Albert Einstein](/wiki/Albert_Einstein) returned to the problem of thermodynamic fluctuations.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:publishes _:s8_article1 .
# _:s8_article1 rdf:type schema:ScholarlyArticle .
# _:s8_article1 schema:datePublished "1904"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidpifiy5oa3qcyf7vgvqupfwiwlvwlrckq6qi45rb34ht2yrydk4i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidpifiy5oa3qcyf7vgvqupfwiwlvwlrckq6qi45rb34ht2yrydk4i",
#   "prov:label": "rdf:37_8",
#   "_cell": 1112,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieq632wauizvq4zn6vxddy5aaoitf6c24ewxyz5gy5ucgd7cb33su"
#   },
#   "_stmt_key": "37_8",
#   "_chunk_num": 37,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [37.9]: [Albert Einstein](/wiki/Albert_Einstein) gave a treatment of the density variations in a fluid at its critical point.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:publishes _:s9_article1 .
# _:s9_article1 rdf:type schema:ScholarlyArticle .
# _:s9_article1 schema:datePublished "1904"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieqiheupk2a65yw3dhqidr6nhaszs7qtoc5qeuao3z46csvdusyo4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieqiheupk2a65yw3dhqidr6nhaszs7qtoc5qeuao3z46csvdusyo4",
#   "prov:label": "rdf:37_9",
#   "_cell": 1114,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreig6qecacrrxncrtt6gxuhg4nspsxvbiy6keug2udcuwwjm7vu42n4"
#   },
#   "_stmt_key": "37_9",
#   "_chunk_num": 37,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [37.10]: Density fluctuations in a fluid at its critical point are controlled by the second derivative of the free energy with respect to the density.
# _:s10_article1 rdf:type schema:ScholarlyArticle .
# _:s10_article1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s10_article1 schema:datePublished "1904"^^xsd:gYear .
# _:s10_article1 schema:text "Density fluctuations in a fluid at its critical point are controlled by the second derivative of the free energy with respect to the density." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiewr2enm6wjr73vintywirsbahpcce3nwyshyd6kxq7knxzuozf7y",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiewr2enm6wjr73vintywirsbahpcce3nwyshyd6kxq7knxzuozf7y",
#   "prov:label": "rdf:37_10",
#   "_cell": 1116,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihcdhajixeieaq7woyjubtn3hz3f44slrrp5cqs6zkd5kvwojqkui"
#   },
#   "_stmt_key": "37_10",
#   "_chunk_num": 37,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [37.11]: At the critical point, the second derivative of the free energy with respect to the density is zero.
# _:s11_article1 rdf:type schema:ScholarlyArticle .
# _:s11_article1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s11_article1 schema:datePublished "1904"^^xsd:gYear .
# _:s11_article1 schema:text "At the critical point, the second derivative of the free energy with respect to the density is zero." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigyhufe377bvsxb4msivu4uapg3oa25fpcr2muyanngaflivcplc4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigyhufe377bvsxb4msivu4uapg3oa25fpcr2muyanngaflivcplc4",
#   "prov:label": "rdf:37_11",
#   "_cell": 1118,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihmcp4jnsdvd3v64xxt4d5izq2fbzc7mrqxqoe3eh5cxfomdpmpyu"
#   },
#   "_stmt_key": "37_11",
#   "_chunk_num": 37,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [37.12]: At the critical point, large fluctuations occur due to the vanishing second derivative of free energy.
# _:s12_article1 rdf:type schema:ScholarlyArticle .
# _:s12_article1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s12_article1 schema:datePublished "1904"^^xsd:gYear .
# _:s12_article1 schema:text "At the critical point, large fluctuations occur due to the vanishing second derivative of free energy." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicaeuj6btp6ankp7dykyyxgpganlenxghnxjc6qdyzgqzqosxd7am",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicaeuj6btp6ankp7dykyyxgpganlenxghnxjc6qdyzgqzqosxd7am",
#   "prov:label": "rdf:37_12",
#   "_cell": 1120,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihcebu55a2eskxna57kpdcg3nslpikaoo7ndhm3buk6hwkmo4k4wi"
#   },
#   "_stmt_key": "37_12",
#   "_chunk_num": 37,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [37.13]: The effect of density fluctuations in a fluid at its critical point is that light of all wavelengths is scattered.
# _:s13_article1 rdf:type schema:ScholarlyArticle .
# _:s13_article1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s13_article1 schema:datePublished "1904"^^xsd:gYear .
# _:s13_article1 schema:text "The effect of density fluctuations in a fluid at its critical point is that light of all wavelengths is scattered." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaewttbxpm537tmvi67f4yizg6ralig7pa6a54op4n6rtvqkqbkx4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaewttbxpm537tmvi67f4yizg6ralig7pa6a54op4n6rtvqkqbkx4",
#   "prov:label": "rdf:37_13",
#   "_cell": 1122,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih6oeves4y6fksr6ppkbwbon6d5l5lrfwnbulkggg7vhbg3ouh2jm"
#   },
#   "_stmt_key": "37_13",
#   "_chunk_num": 37,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [37.14]: The scattering of light in a fluid at its critical point makes the fluid look milky white.
# _:s14_article1 rdf:type schema:ScholarlyArticle .
# _:s14_article1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s14_article1 schema:datePublished "1904"^^xsd:gYear .
# _:s14_article1 schema:text "The scattering of light in a fluid at its critical point makes the fluid look milky white." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidifxgll42gst5s4aqvjuodo7waz3ncfwx3vsi5dbae5cfptg5c2u",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidifxgll42gst5s4aqvjuodo7waz3ncfwx3vsi5dbae5cfptg5c2u",
#   "prov:label": "rdf:37_14",
#   "_cell": 1124,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibnxcwaitlurorxhcxxp25lgirtvcna7dahgrh5nsxlomdcdzo35e"
#   },
#   "_stmt_key": "37_14",
#   "_chunk_num": 37,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [37.15]: [Albert Einstein](/wiki/Albert_Einstein) related critical opalescence to [Rayleigh scattering](/wiki/Rayleigh_scattering).
# _:s15_article1 rdf:type schema:ScholarlyArticle .
# _:s15_article1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s15_article1 schema:datePublished "1904"^^xsd:gYear .
# _:s15_article1 schema:text "Albert Einstein related critical opalescence to Rayleigh scattering." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibmqtpr5cqaiit4fjw3emq6bbrkkdc4c76ll5iqkxy2nnnb7bzw2m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibmqtpr5cqaiit4fjw3emq6bbrkkdc4c76ll5iqkxy2nnnb7bzw2m",
#   "prov:label": "rdf:37_15",
#   "_cell": 1126,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigtpav3akoqt7naddureyzhcvc5hxoym57orbfjcwxstwvchzhlja"
#   },
#   "_stmt_key": "37_15",
#   "_chunk_num": 37,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [37.16]: [Rayleigh scattering](/wiki/Rayleigh_scattering) occurs when the fluctuation size is much smaller than the wavelength.
# _:s16_article1 rdf:type schema:ScholarlyArticle .
# _:s16_article1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s16_article1 schema:datePublished "1904"^^xsd:gYear .
# _:s16_article1 schema:text "Rayleigh scattering occurs when the fluctuation size is much smaller than the wavelength." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieqqt4gyd6z5cftj6uiugwzwzzp4nfoyot2v47n4gv3b2ugggfjfi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieqqt4gyd6z5cftj6uiugwzwzzp4nfoyot2v47n4gv3b2ugggfjfi",
#   "prov:label": "rdf:37_16",
#   "_cell": 1128,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifidr4x6kmd5oqn7rnwk4fs5mgcjp65ap6ihepdsqxqpaavcf4zhu"
#   },
#   "_stmt_key": "37_16",
#   "_chunk_num": 37,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [37.17]: [Rayleigh scattering](/wiki/Rayleigh_scattering) explains why the sky is blue.
# _:s17_article1 rdf:type schema:ScholarlyArticle .
# _:s17_article1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s17_article1 schema:datePublished "1904"^^xsd:gYear .
# _:s17_article1 schema:text "Rayleigh scattering explains why the sky is blue." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreict5taw2cj7mhscc73urdolanswaftpfq5nwiduodyvkfylx27jxi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreict5taw2cj7mhscc73urdolanswaftpfq5nwiduodyvkfylx27jxi",
#   "prov:label": "rdf:37_17",
#   "_cell": 1130,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiba3vbmcavy354lp42rw6ugxpjyu7ak7uimnyuitm6saehp2v433u"
#   },
#   "_stmt_key": "37_17",
#   "_chunk_num": 37,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [37.18]: [Albert Einstein](/wiki/Albert_Einstein) quantitatively derived critical opalescence from a treatment of density fluctuations.
# _:s18_article1 rdf:type schema:ScholarlyArticle .
# _:s18_article1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s18_article1 schema:datePublished "1904"^^xsd:gYear .
# _:s18_article1 schema:text "Albert Einstein quantitatively derived critical opalescence from a treatment of density fluctuations." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifgo7usl2a7t5ueu5oikyp46wu3srq4zjqn2nttf7lphsutwygnxq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifgo7usl2a7t5ueu5oikyp46wu3srq4zjqn2nttf7lphsutwygnxq",
#   "prov:label": "rdf:37_18",
#   "_cell": 1132,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiax6wlslet4zuomyscjg3agag7l7ivqjgnh7ktpdl7dzaaw5xbfx4"
#   },
#   "_stmt_key": "37_18",
#   "_chunk_num": 37,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [37.19]: [Albert Einstein](/wiki/Albert_Einstein) demonstrated how both critical opalescence and [Rayleigh scattering](/wiki/Rayleigh_scattering) originate from the atomistic constitution of matter.
# _:s19_article1 rdf:type schema:ScholarlyArticle .
# _:s19_article1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s19_article1 schema:datePublished "1904"^^xsd:gYear .
# _:s19_article1 schema:text "Albert Einstein demonstrated how both critical opalescence and Rayleigh scattering originate from the atomistic constitution of matter." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihwpflorhbckas4h6csc2v725dc3ng657ce6q5d6ds6goyi6cnxtu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihwpflorhbckas4h6csc2v725dc3ng657ce6q5d6ds6goyi6cnxtu",
#   "prov:label": "rdf:37_19",
#   "_cell": 1134,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibvb2ttwuhw7ktk6c2xnlgso6mlljvkj3y2ophreoscalhi7vxp5u"
#   },
#   "_stmt_key": "37_19",
#   "_chunk_num": 37,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Chunk 38 Error: APITimeoutError: Request timed out.
# #
# # === FULL PROMPT SENT TO LLM ===
# #
# # SYSTEM PROMPT:
# # You are an expert at converting factual statements to RDF triples.
# #
# # The statements contain markdown links like [Entity Name](/wiki/Entity_Name) that provide Wikipedia URIs for entities.
# # Convert these to proper RDF URIs using: <https://en.wikipedia.org/wiki/Entity_Name>
# #
# # You have access to these tools:
# #
# # LOOKUP TOOLS (use first to find correct vocabulary):
# # - find_rdf_class: Find the best schema.org class/type for an entity
# # - find_rdf_property: Find the best predicate for a relationship
# #
# # OUTPUT TOOLS (use to emit your triples - MUST include statement_id):
# # - emit_triple: Output a single triple with statement_id
# # - emit_triples: Output multiple triples at once (more efficient)
# #
# # WORKFLOW:
# # 1. For each statement, identify what kind of fact it is (quote, employment, education, award, relationship, etc.)
# # 2. Use find_rdf_class and find_rdf_property with DESCRIPTIVE queries to find appropriate schema.org terms
# # 3. ONLY use schema matches with score >= 0.5. If no good match, skip or use rdfs:comment.
# # 4. Use emit_triple or emit_triples to output RDF triples, INCLUDING the statement_id
# #
# # QUERYING THE SCHEMA TOOLS:
# # Use descriptive natural language, not just keywords. Include:
# # - What the thing IS (for classes) or what relationship it represents (for properties)
# # - Context about domain/range when known
# #
# # GOOD QUERIES:
# # - find_rdf_class("a spoken or written quotation attributed to someone") → Quotation
# # - find_rdf_class("an organization that educates students like a university") → EducationalOrganization
# # - find_rdf_property("the text content of a quote", subject_type="Quotation") → text
# # - find_rdf_property("who said or authored a quotation", subject_type="Quotation") → creator, spokenByCharacter
# # - find_rdf_property("schools someone attended as a student", subject_type="Person") → alumniOf
# #
# # BAD QUERIES (too vague):
# # - find_rdf_class("quote") - missing context
# # - find_rdf_property("said") - doesn't explain the relationship
# # - find_rdf_property("school") - is it attended? works at? type of?
# #
# # URI RULES:
# # - For entities with Wikipedia links like [Albert Einstein](/wiki/Albert_Einstein):
# #   Use: <https://en.wikipedia.org/wiki/Albert_Einstein>
# # - For entities in the Entity Registry: Use their provided URI
# # - For new entities not in either: Use fragment URIs like <#entity_name>
# # - NEVER invent Wikidata URIs (wd:Q...) unless explicitly provided
# #
# # BLANK NODE NAMING:
# # Use the statement ID in blank node names to ensure uniqueness across chunks:
# #   - For statement [3.5], use: _:s3_5_role1, _:s3_5_role2, etc.
# #   - NOT just _:pos1, _:pos2 (these collide across statements)
# #
# # MODELING PATTERNS:
# #
# # 1. QUOTATIONS (when someone said/stated/objected something):
# #    Create a Quotation instance with text and attribution:
# #    _:s1_quote1 a schema:Quotation .
# #    _:s1_quote1 schema:text "The actual quote text" .
# #    _:s1_quote1 schema:creator <wiki:Person_Who_Said_It> .
# #
# # 2. TEMPORAL/QUALIFIED RELATIONSHIPS (dates on relationships):
# #    Use an intermediate Role node (schema.org Role pattern):
# #
# #    Example - Employment: "Einstein worked at University of Zurich from 1909 to 1911"
# #      <wiki:Albert_Einstein> schema:worksFor _:s1_role1 .
# #      _:s1_role1 a schema:OrganizationRole .
# #      _:s1_role1 schema:worksFor <wiki:University_of_Zurich> .
# #      _:s1_role1 schema:startDate "1909"^^xsd:gYear .
# #      _:s1_role1 schema:endDate "1911"^^xsd:gYear .
# #
# #    Example - Awards: "Einstein received the Nobel Prize in 1921"
# #      <wiki:Albert_Einstein> schema:award _:s2_award1 .
# #      _:s2_award1 a schema:Role .
# #      _:s2_award1 schema:award <wiki:Nobel_Prize_in_Physics> .
# #      _:s2_award1 schema:startDate "1921"^^xsd:gYear .
# #
# #    Example - Education: "Einstein attended University of Zurich from 1896 to 1900"
# #      <wiki:Albert_Einstein> schema:alumniOf _:s3_edu1 .
# #      _:s3_edu1 a schema:OrganizationRole .
# #      _:s3_edu1 schema:alumniOf <wiki:University_of_Zurich> .
# #      _:s3_edu1 schema:startDate "1896"^^xsd:gYear .
# #      _:s3_edu1 schema:endDate "1900"^^xsd:gYear .
# #
# # 3. SIMPLE FACTS (no dates/qualifiers needed):
# #    Direct triples without Role:
# #    <wiki:Einstein> schema:birthDate "1879-03-14"^^xsd:date .
# #    <wiki:Einstein> schema:birthPlace <wiki:Ulm> .
# #
# # WHAT NOT TO DO:
# # 1. DO NOT use schema:description for quotes, opinions, or narrative facts.
# #    schema:description is ONLY for describing what an entity IS, not what happened to it.
# #    WRONG: <Einstein> schema:description "God does not play dice" .
# #    RIGHT: Create a schema:Quotation with schema:text for the quote.
# #
# # 2. DO NOT emit unrelated triples when no good schema match exists.
# #    If a statement is about "being sick in bed", don't emit schema:birthDate.
# #    If no good match (score >= 0.5), either:
# #    - Skip the statement entirely
# #    - Use rdfs:comment to preserve the text: <Einstein> rdfs:comment "Statement text here" .
# #
# # 3. DO NOT conflate past and present states.
# #    "Einstein renounced his German citizenship in 1896" means he LOST it.
# #    Use endDate on a citizenship Role, not startDate.
# #
# # 4. DO NOT extract facts not stated in the statement.
# #    Only model what the specific statement says, not general knowledge about the subject.
# #
# # 5. DATES REQUIRE ROLE PATTERN - CRITICAL!
# #    If a statement mentions "from X to Y" or any year/date range, you MUST use the Role pattern.
# #    Simple triples like <Einstein> schema:worksFor <ETH> lose the temporal information.
# #
# #    Pattern: Subject → Role → Target + dates
# #    <Subject> schema:property _:role .
# #    _:role a schema:Role .           (or OrganizationRole for employment/membership)
# #    _:role schema:property <Target> .
# #    _:role schema:startDate "YYYY"^^xsd:gYear .
# #    _:role schema:endDate "YYYY"^^xsd:gYear .
# #
# # IMPORTANT:
# # - Do NOT write Turtle syntax in your response - use the emit tools instead
# # - ALWAYS include the statement_id when emitting triples
# # - Include statement_id in blank node names: _:s{{id}}_role1
# # - Only emit triples for facts that CAN be properly modeled in schema.org
# # - It is better to skip a statement than emit incorrect triples
# # - Statements with dates MUST use Role pattern (5+ triples, not 1)
# #
# # HUMAN PROMPT:
# # Convert these factual statements to RDF triples.
# #
# # Source: https://en.wikipedia.org/wiki/Albert_Einstein
# # Section context: Albert Einstein > Scientific career > Statistical mechanics > Thermodynamic fluctuations and statistical physics
# #
# # Entity Registry (use these URIs for known entities):
# # <https://en.wikipedia.org/wiki/Albert_Einstein> # Albert Einstein (Person) (Wikidata: Q937)
# # <https://en.wikipedia.org/wiki/Ulm> # Ulm (Thing)
# # <https://en.wikipedia.org/wiki/Kingdom_of_W%C3%BCrttemberg> # Kingdom of Württemberg (Thing)
# # <https://en.wikipedia.org/wiki/German_Empire> # German Empire (Thing)
# # <https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey> # Princeton, New Jersey (Thing)
# # <https://en.wikipedia.org/wiki/Lieserl_Einstein> # Lieserl (Thing)
# # <https://en.wikipedia.org/wiki/Hans_Albert_Einstein> # Hans Albert (Thing)
# # <https://en.wikipedia.org/wiki/Einstein_family> # Eduard "Tete" (Thing)
# # <https://en.wikipedia.org/wiki/Einstein_family> # Einstein (Thing)
# # <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> # Mileva Marić (Thing)
# # <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> # Elsa Löwenthal (Thing)
# # <https://en.wikipedia.org/wiki/Statelessness> # Stateless (Thing)
# # <https://en.wikipedia.org/wiki/Switzerland> # Switzerland (Thing)
# # <https://en.wikipedia.org/wiki/Kingdom_of_Prussia> # Kingdom of Prussia (Thing)
# # <https://en.wikipedia.org/wiki/Free_State_of_Prussia> # Free State of Prussia (Thing)
# # <https://en.wikipedia.org/wiki/Weimar_Republic> # Weimar Republic (Thing)
# # <https://en.wikipedia.org/wiki/Citizenship_of_the_United_States> # United States (Thing)
# # <https://en.wikipedia.org/wiki/Physics> # Physics (Thing)
# # <https://en.wikipedia.org/wiki/University_of_Bern> # University of Bern (Thing)
# # <https://en.wikipedia.org/wiki/University_of_Zurich> # University of Zurich (Thing)
# # <https://en.wikipedia.org/wiki/Charles_University_in_Prague> # Charles University in Prague (Thing)
# # <https://en.wikipedia.org/wiki/ETH_Zurich> # ETH Zurich (Thing)
# # <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> # Prussian Academy of Sciences (Thing)
# # <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> # Humboldt University of Berlin (Thing)
# # <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute> # Kaiser Wilhelm Institute (Thing)
# # <https://en.wikipedia.org/wiki/German_Physical_Society> # German Physical Society (Thing)
# # <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> # Institute for Advanced Study (Thing)
# # <https://en.wikipedia.org/wiki/ETH_Zurich> # Swiss Federal Polytechnic School (Thing)
# # <https://en.wikipedia.org/wiki/PhD> # PhD (Thing)
# # <https://en.wikipedia.org/wiki/Alfred_Kleiner> # Alfred Kleiner (Thing)
# # <https://en.wikipedia.org/wiki/Heinrich_Friedrich_Weber> # Heinrich Friedrich Weber (Thing)
# # <https://en.wikipedia.org/wiki/General_relativity> # General relativity (Thing)
# # <https://en.wikipedia.org/wiki/Special_relativity> # Special relativity (Thing)
# # <https://en.wikipedia.org/wiki/Photoelectric_effect> # Photoelectric effect (Thing)
# # <https://en.wikipedia.org/wiki/Mass%E2%80%93energy_equivalence> # ''E''=''mc''<sup>2</sup> (mass–energy equivalence) (Thing)
# # <https://en.wikipedia.org/wiki/Planck%E2%80%93Einstein_relation> # ''E''=''hf'' (Planck–Einstein relation) (Thing)
# # <https://en.wikipedia.org/wiki/Brownian_motion> # Theory of Brownian motion (Thing)
# # <https://en.wikipedia.org/wiki/Einstein_field_equations> # Einstein field equations (Thing)
# # <https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_statistics> # Bose–Einstein statistics (Thing)
# # <https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_condensate> # Bose–Einstein condensate (Thing)
# # <https://en.wikipedia.org/wiki/Gravitational_wave> # Gravitational wave (Thing)
# # <https://en.wikipedia.org/wiki/Cosmological_constant> # Cosmological constant (Thing)
# # <https://en.wikipedia.org/wiki/Unified_field_theory> # Unified field theory (Thing)
# # <https://en.wikipedia.org/wiki/EPR_paradox> # EPR paradox (Thing)
# # <https://en.wikipedia.org/wiki/Ensemble_interpretation> # Ensemble interpretation (Thing)
# # <https://en.wikipedia.org/wiki/List_of_things_named_after_Albert_Einstein> # List of other concepts (Thing)
# # <https://en.wikipedia.org/wiki/Barnard_Medal_for_Meritorious_Service_to_Science> # Barnard Medal for Meritorious Service to Science (Thing)
# # <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics> # Nobel Prize in Physics (Thing)
# # <https://en.wikipedia.org/wiki/Matteucci_Medal> # Matteucci Medal (Thing)
# # <https://en.wikipedia.org/wiki/List_of_fellows_of_the_Royal_Society_elected_in_1921> # ForMemRS (Thing)
# # <https://en.wikipedia.org/wiki/Copley_Medal> # Copley Medal (Thing)
# #
# # Statements to convert (each has a unique ID like [3.5] - include this in blank node names):
# # [1] [Albert Einstein](/wiki/Albert_Einstein) submitted his first paper in 1900 to [Annalen der Physik](/wiki/Annalen_der_Physik).
# # [2] [Albert Einstein](/wiki/Albert_Einstein)'s first paper was published in 1901 with the title "Folgerungen aus den Capillaritätserscheinungen".
# # [3] "Folgerungen aus den Capillaritätserscheinungen" translates as "Conclusions from the capillarity phenomena".
# # [4] [Albert Einstein](/wiki/Albert_Einstein) published two papers in 1902–1903 on thermodynamics.
# # [5] The two papers published by [Albert Einstein](/wiki/Albert_Einstein) in 1902–1903 attempted to interpret [atom](/wiki/atom)ic phenomena from a statistical point of view.
# # [6] The two papers published by [Albert Einstein](/wiki/Albert_Einstein) in 1902–1903 were the foundation for the 1905 paper on [Theory of Brownian motion](/wiki/Brownian_motion).
# # [7] The 1905 paper on [Theory of Brownian motion](/wiki/Brownian_motion) showed that Brownian movement can be construed as firm evidence that molecules exist.
# # [8] [Albert Einstein](/wiki/Albert_Einstein)'s research in 1903 and 1904 was mainly concerned with the effect of finite atomic size on diffusion phenomena.
# # [9] [Albert Einstein](/wiki/Albert_Einstein) returned to the problem of thermodynamic fluctuations.
# # [10] [Albert Einstein](/wiki/Albert_Einstein) gave a treatment of the density variations in a fluid at its critical point.
# # [11] Density fluctuations in a fluid are ordinarily controlled by the second derivative of the free energy with respect to the density.
# # [12] At the critical point, the second derivative of the free energy with respect to the density is zero.
# # [13] At the critical point, large fluctuations occur due to the zero second derivative.
# # [14] The effect of density fluctuations is that light of all wavelengths is scattered.
# # [15] When light of all wavelengths is scattered, the fluid looks milky white.
# # [16] [Albert Einstein](/wiki/Albert_Einstein) relates this to [Rayleigh scattering](/wiki/Rayleigh_scattering).
# # [17] [Rayleigh scattering](/wiki/Rayleigh_scattering) occurs when the fluctuation size is much smaller than the wavelength.
# # [18] [Rayleigh scattering](/wiki/Rayleigh_scattering) explains why the sky is blue.
# # [19] [Albert Einstein](/wiki/Albert_Einstein) quantitatively derived critical opalescence from a treatment of density fluctuations.
# # [20] [Albert Einstein](/wiki/Albert_Einstein) demonstrated how both critical opalescence and [Rayleigh scattering](/wiki/Rayleigh_scattering) originate from the atomistic constitution of matter.
# #
# # CRITICAL RULES:
# #
# # 1. URI EXTRACTION: Convert markdown links to Wikipedia URIs:
# #    [Albert Einstein](/wiki/Albert_Einstein) → <https://en.wikipedia.org/wiki/Albert_Einstein>
# #
# # 2. BLANK NODE NAMING: Include statement ID to avoid collisions:
# #    For statement [3.5], use: _:s3_5_role1 (NOT just _:role1)
# #
# # 3. SCHEMA MATCHING: Only use matches with score >= 0.5.
# #    If no good match exists, either skip the statement or use rdfs:comment.
# #
# # 4. TEMPORAL RELATIONSHIPS - MANDATORY ROLE PATTERN:
# #    If a statement has dates like "from X to Y" or year ranges, you MUST use the Role pattern.
# #    A simple triple loses the temporal information - DO NOT emit just:
# #      <Einstein> schema:employee <ETH_Zurich> .  ← WRONG! Loses the dates!
# #
# #    CORRECT Role Pattern (REQUIRED for dated relationships):
# #    Statement: "Einstein worked at ETH Zurich from 1912 to 1914"
# #      <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor _:s1_21_role1 .
# #      _:s1_21_role1 a schema:OrganizationRole .
# #      _:s1_21_role1 schema:worksFor <https://en.wikipedia.org/wiki/ETH_Zurich> .
# #      _:s1_21_role1 schema:startDate "1912"^^xsd:gYear .
# #      _:s1_21_role1 schema:endDate "1914"^^xsd:gYear .
# #
# #    Statement: "Einstein was a citizen of Switzerland from 1901 to 1955"
# #      <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality _:s1_14_role1 .
# #      _:s1_14_role1 a schema:Role .
# #      _:s1_14_role1 schema:nationality <https://en.wikipedia.org/wiki/Switzerland> .
# #      _:s1_14_role1 schema:startDate "1901"^^xsd:gYear .
# #      _:s1_14_role1 schema:endDate "1955"^^xsd:gYear .
# #
# #    Use OrganizationRole for employment/membership, Role for citizenship/other.
# #
# # 5. DO NOT:
# #    - Use schema:description for quotes or narrative (only for entity descriptions)
# #    - Emit unrelated triples when no good match exists
# #    - Extract facts not stated in the statement
# #    - Emit simple triples when there are dates (MUST use Role pattern)
# #
# # Process each statement. If you cannot properly model it, skip it or use rdfs:comment.
# #
# # === END PROMPT ===

# %% [raw]
# # Statement [39.1]: The [*Annus Mirabilis* papers](/wiki/Annus_mirabilis_papers) are four articles that Einstein published in the *Annalen der Physik* scientific journal in 1905.
# <https://en.wikipedia.org/wiki/Annus_mirabilis_papers> rdf:type schema:Collection .
# <https://en.wikipedia.org/wiki/Annus_mirabilis_papers> schema:hasPart <https://en.wikipedia.org/wiki/Photoelectric_effect> .
# <https://en.wikipedia.org/wiki/Annus_mirabilis_papers> schema:hasPart <https://en.wikipedia.org/wiki/Brownian_motion> .
# <https://en.wikipedia.org/wiki/Annus_mirabilis_papers> schema:hasPart <https://en.wikipedia.org/wiki/Special_relativity> .
# <https://en.wikipedia.org/wiki/Annus_mirabilis_papers> schema:hasPart <https://en.wikipedia.org/wiki/Mass%E2%80%93energy_equivalence> .
# <https://en.wikipedia.org/wiki/Annus_mirabilis_papers> schema:datePublished "1905"^^xsd:gYear .
# <https://en.wikipedia.org/wiki/Annus_mirabilis_papers> schema:publisher <https://en.wikipedia.org/wiki/Annalen_der_Physik> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibkxygqnwpjtdzsjhledaiwhl2i47a7pxu3ucpdt65ty2zhvmtwly",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibkxygqnwpjtdzsjhledaiwhl2i47a7pxu3ucpdt65ty2zhvmtwly",
#   "prov:label": "rdf:39_1",
#   "_cell": 1137,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicoxens4s5oq5orqv3yl5jvja7q3gpbgvdlpdb3evf3o4z4df2fgm"
#   },
#   "_stmt_key": "39_1",
#   "_chunk_num": 39,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [39.2]: The [*Annus Mirabilis* papers](/wiki/Annus_mirabilis_papers) pertain to the photoelectric effect, [Brownian motion](/wiki/Brownian_motion), the [special theory of relativity](/wiki/special_theory_of_relativity), and [*E*=*mc*2](/wiki/Mass%E2%80%93energy_equivalence).
# <https://en.wikipedia.org/wiki/Photoelectric_effect> rdf:type schema:Thing .
# <https://en.wikipedia.org/wiki/Brownian_motion> rdf:type schema:Thing .
# <https://en.wikipedia.org/wiki/Special_relativity> rdf:type schema:Thing .
# <https://en.wikipedia.org/wiki/Mass%E2%80%93energy_equivalence> rdf:type schema:Thing .
# <https://en.wikipedia.org/wiki/Annus_mirabilis_papers> schema:hasPart <https://en.wikipedia.org/wiki/Photoelectric_effect> .
# <https://en.wikipedia.org/wiki/Annus_mirabilis_papers> schema:hasPart <https://en.wikipedia.org/wiki/Brownian_motion> .
# <https://en.wikipedia.org/wiki/Annus_mirabilis_papers> schema:hasPart <https://en.wikipedia.org/wiki/Special_relativity> .
# <https://en.wikipedia.org/wiki/Annus_mirabilis_papers> schema:hasPart <https://en.wikipedia.org/wiki/Mass%E2%80%93energy_equivalence> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic5g2swjdabqb5ioxjxjjm54zfxdim7lppkxepnmjw4f4hdzqljve",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic5g2swjdabqb5ioxjxjjm54zfxdim7lppkxepnmjw4f4hdzqljve",
#   "prov:label": "rdf:39_2",
#   "_cell": 1139,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreierywiq76ctqdumsmtdk5h4nozywn3a3d2yvrdmpsirnnrh6lmvba"
#   },
#   "_stmt_key": "39_2",
#   "_chunk_num": 39,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [39.3]: The photoelectric effect article gave rise to [quantum theory](/wiki/quantum_mechanics).
# <https://en.wikipedia.org/wiki/Photoelectric_effect> rdf:type schema:Thing .
# <https://en.wikipedia.org/wiki/Photoelectric_effect> rdfs:comment "The photoelectric effect article gave rise to quantum theory." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaceivg2azhrlagm6vahavwcaj5vrgkwyj6hkl3ardfpiph3gr4fq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaceivg2azhrlagm6vahavwcaj5vrgkwyj6hkl3ardfpiph3gr4fq",
#   "prov:label": "rdf:39_3",
#   "_cell": 1141,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiegpt4xffindlr2x4qujzsyvc3frq5xz32ipqbmhkyuo7kp5kanqq"
#   },
#   "_stmt_key": "39_3",
#   "_chunk_num": 39,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [39.4]: The photoelectric effect article resolved an unsolved puzzle by suggesting that energy is exchanged only in discrete amounts ([quanta](/wiki/quantum)).
# <https://en.wikipedia.org/wiki/Photoelectric_effect> rdf:type schema:Thing .
# <https://en.wikipedia.org/wiki/Photoelectric_effect> rdfs:comment "The photoelectric effect article resolved an unsolved puzzle by suggesting that energy is exchanged only in discrete amounts (quanta)." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihccboxuc7dadfl4evdza3oio3x4qii72bsyxqb2nf4n6oqjuk3km",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihccboxuc7dadfl4evdza3oio3x4qii72bsyxqb2nf4n6oqjuk3km",
#   "prov:label": "rdf:39_4",
#   "_cell": 1143,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidvgu3kzllz7thnilp5b5zv4pl5zdnqtqylutp37foezxsiig5y3e"
#   },
#   "_stmt_key": "39_4",
#   "_chunk_num": 39,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [39.5]: The [Brownian motion](/wiki/Brownian_motion) article explained empirical evidence for the [atomic theory](/wiki/atomic_theory), supporting the application of [statistical physics](/wiki/statistical_physics).
# <https://en.wikipedia.org/wiki/Brownian_motion> rdf:type schema:Thing .
# <https://en.wikipedia.org/wiki/Brownian_motion> rdfs:comment "The Brownian motion article explained empirical evidence for the atomic theory, supporting the application of statistical physics." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidrnn6urrfkhsod3lgwb3oai7u6znqjgua455rc332vkpehwaaiwu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidrnn6urrfkhsod3lgwb3oai7u6znqjgua455rc332vkpehwaaiwu",
#   "prov:label": "rdf:39_5",
#   "_cell": 1145,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiegmermc47wlmxh6rxwhtjjkzg44dcvr6pjlarbikhmnt32p74z7i"
#   },
#   "_stmt_key": "39_5",
#   "_chunk_num": 39,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [39.6]: The "On the Electrodynamics of Moving Bodies" article pertains to [special theory of relativity](/wiki/Special_relativity).
# <https://en.wikipedia.org/wiki/On_the_Electrodynamics_of_Moving_Bodies> rdf:type schema:ScholarlyArticle .
# <https://en.wikipedia.org/wiki/On_the_Electrodynamics_of_Moving_Bodies> rdfs:comment "The 'On the Electrodynamics of Moving Bodies' article pertains to special theory of relativity." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicvn4nj25eoo6kao45hdkrhlgus7a6jy5lbjx4uqpbexjx5a4oqbq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicvn4nj25eoo6kao45hdkrhlgus7a6jy5lbjx4uqpbexjx5a4oqbq",
#   "prov:label": "rdf:39_6",
#   "_cell": 1147,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifkn6rvifytp4ifibrq4m6mpr37l3tslvkjnp3nkqjr7d2ugsokom"
#   },
#   "_stmt_key": "39_6",
#   "_chunk_num": 39,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [39.7]: The "On the Electrodynamics of Moving Bodies" article reconciled [Maxwell](/wiki/James_Clerk_Maxwell)'s equations for electricity and magnetism with the laws of mechanics.
# <https://en.wikipedia.org/wiki/On_the_Electrodynamics_of_Moving_Bodies> rdf:type schema:ScholarlyArticle .
# <https://en.wikipedia.org/wiki/On_the_Electrodynamics_of_Moving_Bodies> rdfs:comment "The 'On the Electrodynamics of Moving Bodies' article reconciled Maxwell's equations for electricity and magnetism with the laws of mechanics." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiel3qxpipaz47y4qcyh77tqmulo2lnriie6ndb63iobudatrakgi4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiel3qxpipaz47y4qcyh77tqmulo2lnriie6ndb63iobudatrakgi4",
#   "prov:label": "rdf:39_7",
#   "_cell": 1149,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib3ypdpq7hqejdhgxym4cbqquxn5w7c2aod25r4lnjzcksvbk7tx4"
#   },
#   "_stmt_key": "39_7",
#   "_chunk_num": 39,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [39.8]: The "On the Electrodynamics of Moving Bodies" article introduced changes to mechanics based on the independence of the speed of light from the motion of the observer.
# <https://en.wikipedia.org/wiki/On_the_Electrodynamics_of_Moving_Bodies> rdf:type schema:ScholarlyArticle .
# <https://en.wikipedia.org/wiki/On_the_Electrodynamics_of_Moving_Bodies> rdfs:comment "The 'On the Electrodynamics of Moving Bodies' article introduced changes to mechanics based on the independence of the speed of light from the motion of the observer." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibz5vfpwnfbp6tyeuyl6su6euee3oefl7fjqtymrxbgerebjijptm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibz5vfpwnfbp6tyeuyl6su6euee3oefl7fjqtymrxbgerebjijptm",
#   "prov:label": "rdf:39_8",
#   "_cell": 1151,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaxhrmrih4bqpy72hbru3nrw7nl42segs3p6oryszeqm6jwwpuney"
#   },
#   "_stmt_key": "39_8",
#   "_chunk_num": 39,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [39.9]: The [*E*=*mc*2](/wiki/Mass%E2%80%93energy_equivalence) article established the equivalence of matter and energy.
# <https://en.wikipedia.org/wiki/Mass%E2%80%93energy_equivalence> rdf:type schema:Thing .
# <https://en.wikipedia.org/wiki/Mass%E2%80%93energy_equivalence> rdfs:comment "The E=mc2 article established the equivalence of matter and energy." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicewr54k5bye27yntbyzh3roknifmhmxdgksh5hokjsocvlhebbda",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicewr54k5bye27yntbyzh3roknifmhmxdgksh5hokjsocvlhebbda",
#   "prov:label": "rdf:39_9",
#   "_cell": 1153,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidggblfuvovdnj6tmqjfalyce5sfqaxuczuhiagwm5ez3i5i5zutq"
#   },
#   "_stmt_key": "39_9",
#   "_chunk_num": 39,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [39.10]: The [*E*=*mc*2](/wiki/Mass%E2%80%93energy_equivalence) article described the existence of "[rest energy](/wiki/rest_energy)".
# <https://en.wikipedia.org/wiki/Mass%E2%80%93energy_equivalence> rdf:type schema:Thing .
# <https://en.wikipedia.org/wiki/Mass%E2%80%93energy_equivalence> rdfs:comment "The E=mc2 article described the existence of 'rest energy'." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigikcdxov7wcso534gmod2bcze74szyoq55lm7tuccqqrjsidgx3m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigikcdxov7wcso534gmod2bcze74szyoq55lm7tuccqqrjsidgx3m",
#   "prov:label": "rdf:39_10",
#   "_cell": 1155,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihv4wpvhpxfbe2dx7pwqqotiwildvljcsc32pud7lxqpt37abazpq"
#   },
#   "_stmt_key": "39_10",
#   "_chunk_num": 39,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [39.11]: The [*E*=*mc*2](/wiki/Mass%E2%80%93energy_equivalence) article provided the basis of nuclear energy.
# <https://en.wikipedia.org/wiki/Mass%E2%80%93energy_equivalence> rdf:type schema:Thing .
# <https://en.wikipedia.org/wiki/Mass%E2%80%93energy_equivalence> rdfs:comment "The E=mc2 article provided the basis of nuclear energy." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiepwubru7ns3axsjztsq77ijoocl72lafyqikybnge4cm2tbefmky",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiepwubru7ns3axsjztsq77ijoocl72lafyqikybnge4cm2tbefmky",
#   "prov:label": "rdf:39_11",
#   "_cell": 1157,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiemy35jhvj4zdraqn6laq2xv2g2cq4hqwwdntw32xpkfmax575urm"
#   },
#   "_stmt_key": "39_11",
#   "_chunk_num": 39,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [39.12]: The four [*Annus Mirabilis* papers](/wiki/Annus_mirabilis_papers) contributed substantially to the foundation of [modern physics](/wiki/modern_physics).
# <https://en.wikipedia.org/wiki/Annus_mirabilis_papers> rdf:type schema:Collection .
# <https://en.wikipedia.org/wiki/Annus_mirabilis_papers> rdfs:comment "The four Annus Mirabilis papers contributed substantially to the foundation of modern physics." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaw6bs3dyew2rcwupolhasjiohfeqzc4o3ketonqanwkjrxujhusu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaw6bs3dyew2rcwupolhasjiohfeqzc4o3ketonqanwkjrxujhusu",
#   "prov:label": "rdf:39_12",
#   "_cell": 1159,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreialh37uh67eyycdjblgw4nw5yi4xnwar6qk5ekbhnufpl77jb43me"
#   },
#   "_stmt_key": "39_12",
#   "_chunk_num": 39,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [39.13]: The four [*Annus Mirabilis* papers](/wiki/Annus_mirabilis_papers) changed views on [space](/wiki/space), time, and [matter](/wiki/matter).
# <https://en.wikipedia.org/wiki/Annus_mirabilis_papers> rdf:type schema:Collection .
# <https://en.wikipedia.org/wiki/Annus_mirabilis_papers> rdfs:comment "The four Annus Mirabilis papers changed views on space, time, and matter." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaepajjamcppc5h7fdo27b2gljvzhqlbgos5jgaednm23s7kl5y5i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaepajjamcppc5h7fdo27b2gljvzhqlbgos5jgaednm23s7kl5y5i",
#   "prov:label": "rdf:39_13",
#   "_cell": 1161,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreig3v4usthwrdmhpcs7ci4uwmyk7pa6uzt4uil2axw7unlq23uha4u"
#   },
#   "_stmt_key": "39_13",
#   "_chunk_num": 39,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [40.1]: [Albert Einstein](/wiki/Albert_Einstein) published a paper titled "On the Electrodynamics of Moving Bodies" on 26 September 1905.
# _:s1_paper1 rdf:type schema:ScholarlyArticle .
# _:s1_paper1 schema:text "On the Electrodynamics of Moving Bodies" .
# _:s1_paper1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s1_paper1 schema:datePublished "1905-09-26"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieqb2jxavuo5f3trmombjjckw2kz2deod3kosunyngnqaftvfgs4y",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieqb2jxavuo5f3trmombjjckw2kz2deod3kosunyngnqaftvfgs4y",
#   "prov:label": "rdf:40_1",
#   "_cell": 1163,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifwr4w5kuhhzn5t4jj6hrbejp6nsqodk54kwcf43qco76ljg4vvsy"
#   },
#   "_stmt_key": "40_1",
#   "_chunk_num": 40,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [40.2]: [Albert Einstein](/wiki/Albert_Einstein) submitted the paper "On the Electrodynamics of Moving Bodies" on 30 June 1905.
# _:s2_paper1 rdf:type schema:ScholarlyArticle .
# _:s2_paper1 schema:text "On the Electrodynamics of Moving Bodies" .
# _:s2_paper1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s2_paper1 schema:datePublished "1905-06-30"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigmjqlnvxlo6nu7ep6u6sp7adash6layjdcu47j3c6wnkccoawgla",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigmjqlnvxlo6nu7ep6u6sp7adash6layjdcu47j3c6wnkccoawgla",
#   "prov:label": "rdf:40_2",
#   "_cell": 1165,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidj5wrsq2isarwv5fbeqrh4wltpa3q22wmi5xdseo46nqv4kcwr5y"
#   },
#   "_stmt_key": "40_2",
#   "_chunk_num": 40,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [40.3]: The paper "On the Electrodynamics of Moving Bodies" reconciled conflicts between [Maxwell's equations](/wiki/Maxwell%27s_equations) and the laws of Newtonian mechanics.
# _:s3_paper1 rdf:type schema:ScholarlyArticle .
# _:s3_paper1 schema:text "On the Electrodynamics of Moving Bodies" .
# _:s3_paper1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s3_paper1 schema:citation <https://en.wikipedia.org/wiki/Maxwell%27s_equations> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreib4t6jc26zez3k3ajepervblee63bxwl6foveaaoixbaad2h3opby",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreib4t6jc26zez3k3ajepervblee63bxwl6foveaaoixbaad2h3opby",
#   "prov:label": "rdf:40_3",
#   "_cell": 1167,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid2e6iaoshkorvft576mdfjzhfy6ejgcfjr5nem242mvnsxgl73m4"
#   },
#   "_stmt_key": "40_3",
#   "_chunk_num": 40,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [40.4]: [Maxwell's equations](/wiki/Maxwell%27s_equations) are the laws of electricity and magnetism.
# <https://en.wikipedia.org/wiki/Maxwell%27s_equations> rdf:type schema:Thing .
# <https://en.wikipedia.org/wiki/Maxwell%27s_equations> schema:description the laws of electricity and magnetism .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiajp3xbqpw6bxqtkwv2n7hnjbulpcrnenf3j6agwwya32tkd2bvza",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiajp3xbqpw6bxqtkwv2n7hnjbulpcrnenf3j6agwwya32tkd2bvza",
#   "prov:label": "rdf:40_4",
#   "_cell": 1169,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihliujvkx7zq3aedofp7nasxfbrorcxup5ppjs5fmton76ykh4b4q"
#   },
#   "_stmt_key": "40_4",
#   "_chunk_num": 40,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [40.5]: The effects of special relativity are most apparent at high speeds where objects move close to the [speed of light](/wiki/speed_of_light).
# <https://en.wikipedia.org/wiki/Special_relativity> rdf:type schema:Thing .
# <https://en.wikipedia.org/wiki/Special_relativity> schema:description The effects of special relativity are most apparent at high speeds where objects move close to the speed of light. .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigarorzguwsiwajyrtgw2rdgr3p6wtlweohkzkategnsah6hckhse",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigarorzguwsiwajyrtgw2rdgr3p6wtlweohkzkategnsah6hckhse",
#   "prov:label": "rdf:40_5",
#   "_cell": 1171,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigzojqvipgbipiuce65pfqfbjy3n4kiaw5euuqbez2pmv2qhxlg5e"
#   },
#   "_stmt_key": "40_5",
#   "_chunk_num": 40,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [40.6]: The theory developed in Einstein's paper "On the Electrodynamics of Moving Bodies" later became known as Einstein's special theory of relativity.
# _:s6_paper1 rdf:type schema:ScholarlyArticle .
# _:s6_paper1 schema:text "On the Electrodynamics of Moving Bodies" .
# _:s6_paper1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s6_paper1 schema:about <https://en.wikipedia.org/wiki/Special_relativity> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiekavqcuiwuvdricy5zn5egh4cql4fj6avyfggnmzysmqbhvtjouq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiekavqcuiwuvdricy5zn5egh4cql4fj6avyfggnmzysmqbhvtjouq",
#   "prov:label": "rdf:40_6",
#   "_cell": 1173,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigoprp6l6mmesqmpd5nv7xsi22e7e56kt6uootc2uhvaeuyslfhmy"
#   },
#   "_stmt_key": "40_6",
#   "_chunk_num": 40,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [40.7]: Einstein's paper predicted that clocks carried by moving bodies would appear to [slow down](/wiki/Time_dilation) when measured in the frame of a relatively moving observer.
# _:s7_paper1 rdf:type schema:ScholarlyArticle .
# _:s7_paper1 schema:text "On the Electrodynamics of Moving Bodies" .
# _:s7_paper1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s7_paper1 schema:citation <https://en.wikipedia.org/wiki/Time_dilation> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiapefhgpdffb7ormcgjivn7vhuzyrb5ualcppsibtxok6pfvs4bbm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiapefhgpdffb7ormcgjivn7vhuzyrb5ualcppsibtxok6pfvs4bbm",
#   "prov:label": "rdf:40_7",
#   "_cell": 1175,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihlp7ovdxoyqyzqndj3mycpwdqispolowr4ytqamv4e5sg7vz7viu"
#   },
#   "_stmt_key": "40_7",
#   "_chunk_num": 40,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [40.8]: Einstein's paper predicted that moving bodies would [contract](/wiki/Length_contraction) in their direction of motion.
# _:s8_paper1 rdf:type schema:ScholarlyArticle .
# _:s8_paper1 schema:text "On the Electrodynamics of Moving Bodies" .
# _:s8_paper1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s8_paper1 schema:citation <https://en.wikipedia.org/wiki/Length_contraction> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifp6jvtirqupgvrd77xbwrqth5j25xummr4hcnrjmkzr77nghqbn4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifp6jvtirqupgvrd77xbwrqth5j25xummr4hcnrjmkzr77nghqbn4",
#   "prov:label": "rdf:40_8",
#   "_cell": 1177,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigbumhd4zqisuzw3vfyvu6lgqbyce2vr53zp5i5ftf5ff27zj6hbe"
#   },
#   "_stmt_key": "40_8",
#   "_chunk_num": 40,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [40.9]: Einstein's paper argued that the idea of a [luminiferous aether](/wiki/luminiferous_aether) was superfluous.
# _:s9_paper1 rdf:type schema:ScholarlyArticle .
# _:s9_paper1 schema:text "On the Electrodynamics of Moving Bodies" .
# _:s9_paper1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s9_paper1 schema:citation <https://en.wikipedia.org/wiki/luminiferous_aether> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicuzzfkwbb5zykld4lyy6mkoqs7crvl5azopmhb7dlehuavd4yfqa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicuzzfkwbb5zykld4lyy6mkoqs7crvl5azopmhb7dlehuavd4yfqa",
#   "prov:label": "rdf:40_9",
#   "_cell": 1179,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibtreewyx4yhu2pl4dbxpg52gdaaext7zeeliqkvztmpx3x4grf6e"
#   },
#   "_stmt_key": "40_9",
#   "_chunk_num": 40,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [40.10]: In his paper on [mass–energy equivalence](/wiki/mass%E2%80%93energy_equivalence), [Albert Einstein](/wiki/Albert_Einstein) produced *E*=*mc*2 as a consequence of his special relativity equations.
# _:s10_paper1 rdf:type schema:ScholarlyArticle .
# _:s10_paper1 schema:text "On the Electrodynamics of Moving Bodies" .
# _:s10_paper1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s10_paper1 schema:citation <https://en.wikipedia.org/wiki/mass%E2%80%93energy_equivalence> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigsmj4raam5jxtjrfvw7eus2xkuzurknmz3vqqfgslvqc4y6bvya4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigsmj4raam5jxtjrfvw7eus2xkuzurknmz3vqqfgslvqc4y6bvya4",
#   "prov:label": "rdf:40_10",
#   "_cell": 1181,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihxs6mvwuql2y33flhv2htonsm67k74j7mpjge6qjb37nacuyic4u"
#   },
#   "_stmt_key": "40_10",
#   "_chunk_num": 40,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [40.11]: Einstein's 1905 work on relativity remained controversial for many years.
# <https://en.wikipedia.org/wiki/Special_relativity> rdf:type schema:Thing .
# <https://en.wikipedia.org/wiki/Special_relativity> schema:description Einstein's 1905 work on relativity remained controversial for many years. .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicxuhnsa3mllxuzhjmjxtwgwprl25rrf72yzpdsnqa5vemixuxsra",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicxuhnsa3mllxuzhjmjxtwgwprl25rrf72yzpdsnqa5vemixuxsra",
#   "prov:label": "rdf:40_11",
#   "_cell": 1183,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihrcih3lc764njvjjsgicojjszbyexvzirfskdw7lmrwd73h4wp5i"
#   },
#   "_stmt_key": "40_11",
#   "_chunk_num": 40,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [40.12]: Einstein's 1905 work on relativity was accepted by leading physicists starting with [Max Planck](/wiki/Max_Planck).
# <https://en.wikipedia.org/wiki/Special_relativity> rdf:type schema:Thing .
# <https://en.wikipedia.org/wiki/Special_relativity> schema:description Einstein's 1905 work on relativity was accepted by leading physicists starting with Max Planck. .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihcf5t2babasrx4uqkndr7dzsprta25gjdqhyh77alq5ogr53fnqy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihcf5t2babasrx4uqkndr7dzsprta25gjdqhyh77alq5ogr53fnqy",
#   "prov:label": "rdf:40_12",
#   "_cell": 1185,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibiz3ex6ulxvqf43ig4kkk7khzwqug6rvbwewipfn5emo2towisqa"
#   },
#   "_stmt_key": "40_12",
#   "_chunk_num": 40,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [40.13]: Einstein originally framed special relativity in terms of [kinematics](/wiki/kinematics), the study of moving bodies.
# <https://en.wikipedia.org/wiki/Special_relativity> rdf:type schema:Thing .
# <https://en.wikipedia.org/wiki/Special_relativity> schema:description Einstein originally framed special relativity in terms of kinematics, the study of moving bodies. .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifq5fhtm74itysw7emw3nqsc6curdp2nqc6skhkyylsge7mmuemke",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifq5fhtm74itysw7emw3nqsc6curdp2nqc6skhkyylsge7mmuemke",
#   "prov:label": "rdf:40_13",
#   "_cell": 1187,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibhougyv3vfmjhidtbllcch24tdsbkkhlkvevooks4nohksriwlne"
#   },
#   "_stmt_key": "40_13",
#   "_chunk_num": 40,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [40.14]: In 1908, [Hermann Minkowski](/wiki/Hermann_Minkowski) reinterpreted special relativity in geometric terms as a theory of [spacetime](/wiki/spacetime).
# _:s14_minkowski1 rdf:type schema:Person .
# _:s14_minkowski1 schema:name Hermann Minkowski .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/English_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/German_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/French_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Italian_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Polish_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Russian_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Spanish_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Swedish_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Chinese_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Japanese_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Korean_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Arabic_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Hebrew_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Portuguese_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Dutch_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Esperanto> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Latin> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Navajo_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Swahili_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Turkish_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Vietnamese_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Thai_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Hindi_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Hungarian_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Czech_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Romanian_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Slovak_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Serbo-Croatian> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Bulgarian_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Croatian_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Slovene_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Estonian_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Latvian_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Lithuanian_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Albanian_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Macedonian_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Greek_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Icelandic_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Norwegian_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Danish_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Finnish_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Indonesian_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Malay_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Telugu_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Tamil_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Punjabi_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Bengali_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Marathi_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Gujarati_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Kannada_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Sinhala_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Urdu_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Afrikaans_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Basque_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Catalan_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Galician_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Scottish_Gaelic> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Welsh_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Manx_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Inuktitut> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Hawaiian_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Quechua_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Aymara_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Cherokee_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Klingon_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Elvish_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Quenya> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Sindarin> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Lojban> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Interlingua> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Ido_language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Lingua_franca> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Neo_Latin> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Volap%C3%BCk> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/International_Sign_Language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/American_Sign_Language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Sign_Language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Braille> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Chinese_Sign_Language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/French_Sign_Language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Italian_Sign_Language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Japanese_Sign_Language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Korean_Sign_Language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Polish_Sign_Language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Portuguese_Sign_Language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Russian_Sign_Language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Spanish_Sign_Language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Thai_Sign_Language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Vietnamese_Sign_Language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Swedish_Sign_Language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Dutch_Sign_Language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Arabic_Sign_Language> .
# _:s14_minkowski1 schema:knowsLanguage <https://en.wikipedia.org/wiki/Hebrew_Sign_Language> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibephysr7k2asikwiuwh6642oxvz73un4kfieirrqpvjqqbkqzcqa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibephysr7k2asikwiuwh6642oxvz73un4kfieirrqpvjqqbkqzcqa",
#   "prov:label": "rdf:40_14",
#   "_cell": 1189,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigbmifk7snyaseq44wxdia2b4axfe5z36t5lfhmc7wrrzruuzfj5u"
#   },
#   "_stmt_key": "40_14",
#   "_chunk_num": 40,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [40.15]: Einstein adopted [Hermann Minkowski](/wiki/Hermann_Minkowski)'s formalism in his 1915 [general theory of relativity](/wiki/general_theory_of_relativity).
# # No triples emitted for this statement
# # Debug: 141 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_paper1", "predicate": "rdf:type", "object_value": "schema:ScholarlyArticle"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_paper1", "predicate": "schema:text", "object_value": "\"On the Electrodynamics of Moving Bodies\""}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_paper1", "predicate": "schema:author", "object_value": "<https://en.wikipedia.org/wiki/Albert_Einstein>"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_paper1", "predicate": "schema:datePublished", "object_value": "\"1905-09-26\"^^xsd:date"}
# #   emit_triple: {"statement_id": 2, "subject": "_:s2_paper1", "predicate": "rdf:type", "object_value": "schema:ScholarlyArticle"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiedpnqwsndr2x4mgoepkgl3nklojwn3vlwozprjqrfagel3663b2y",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiedpnqwsndr2x4mgoepkgl3nklojwn3vlwozprjqrfagel3663b2y",
#   "prov:label": "rdf:40_15",
#   "_cell": 1191,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidoeymj6wh4lf3x4oooofwxkwh2f232wvk7o543qphpej4njar6sy"
#   },
#   "_stmt_key": "40_15",
#   "_chunk_num": 40,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [41.1]: [General relativity](/wiki/General_relativity) is a [theory of gravitation](/wiki/theory_of_gravitation) that was developed by [Albert Einstein](/wiki/Albert_Einstein) between 1907 and 1915.
# <https://en.wikipedia.org/wiki/General_relativity> rdf:type schema:ScientificTheory .
# <https://en.wikipedia.org/wiki/General_relativity> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/General_relativity> schema:dateCreated "1907/1915"^^xsd:dateTime .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifhfta25e2af4euuoi3nvkwbdq7hbpn7zxvkks32hwqgjehq3cx5y",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifhfta25e2af4euuoi3nvkwbdq7hbpn7zxvkks32hwqgjehq3cx5y",
#   "prov:label": "rdf:41_1",
#   "_cell": 1193,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihqqvvcwjh4xm5m7osn5pbhvfngv5j65ihsqcnio7ur2ddb5itzue"
#   },
#   "_stmt_key": "41_1",
#   "_chunk_num": 41,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [41.2]: According to [General relativity](/wiki/General_relativity), the observed gravitational attraction between masses results from the warping of [spacetime](/wiki/spacetime) by those masses.
# <https://en.wikipedia.org/wiki/General_relativity> schema:description "According to General relativity, the observed gravitational attraction between masses results from the warping of spacetime by those masses." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigznvnxowcuuh2bmo3z2bm7lwtcd6thgjauv5ozhfyzcihszvsd4a",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigznvnxowcuuh2bmo3z2bm7lwtcd6thgjauv5ozhfyzcihszvsd4a",
#   "prov:label": "rdf:41_2",
#   "_cell": 1195,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihf4z7mbd2wqxzzphtynjdx3q5gc34zwt5otynhsavg4sjce5t5j4"
#   },
#   "_stmt_key": "41_2",
#   "_chunk_num": 41,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [41.3]: [General relativity](/wiki/General_relativity) has developed into an essential tool in modern [astrophysics](/wiki/astrophysics).
# <https://en.wikipedia.org/wiki/General_relativity> schema:about <https://en.wikipedia.org/wiki/astrophysics> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihmi6vmlyyvuxk2ics5iyqhz6twgswnilv57pbteyqh26lid57hz4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihmi6vmlyyvuxk2ics5iyqhz6twgswnilv57pbteyqh26lid57hz4",
#   "prov:label": "rdf:41_3",
#   "_cell": 1197,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihxmebxkvyacgrpb2jlf75r53s6j4iac2lmzhcgtepyodbll47fjm"
#   },
#   "_stmt_key": "41_3",
#   "_chunk_num": 41,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [41.4]: [General relativity](/wiki/General_relativity) provides the foundation for the current understanding of [black holes](/wiki/black_holes), regions of space where gravitational attraction is so strong that not even light can escape.
# <https://en.wikipedia.org/wiki/General_relativity> schema:description "General relativity provides the foundation for the current understanding of black holes, regions of space where gravitational attraction is so strong that not even light can escape." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidkjf5wzvp5a7i5glym3pktflny4fpfk2v5ust6y7rfzx6dk2nvm4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidkjf5wzvp5a7i5glym3pktflny4fpfk2v5ust6y7rfzx6dk2nvm4",
#   "prov:label": "rdf:41_4",
#   "_cell": 1199,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiheszqnolatxtj66bt4nrnhcbzuqw5j2e55ureyjuvq5ci3slqhnu"
#   },
#   "_stmt_key": "41_4",
#   "_chunk_num": 41,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [41.5]: The reason for the development of [General relativity](/wiki/General_relativity) was that the preference of inertial motions within [special relativity](/wiki/special_relativity) was unsatisfactory.
# <https://en.wikipedia.org/wiki/General_relativity> schema:description "The reason for the development of General relativity was that the preference of inertial motions within special relativity was unsatisfactory." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihc2zeg5hhbb4qbxmoaylzyg74kgqwtmgob7ym463g5njafvemg6y",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihc2zeg5hhbb4qbxmoaylzyg74kgqwtmgob7ym463g5njafvemg6y",
#   "prov:label": "rdf:41_5",
#   "_cell": 1201,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicf2fiy3k4pofpsi2dqc62fagtuqblcws7gpt6eo34tz7fmyldjwi"
#   },
#   "_stmt_key": "41_5",
#   "_chunk_num": 41,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [41.6]: A theory that from the outset prefers no state of motion (even accelerated ones) should appear more satisfactory.
# <https://en.wikipedia.org/wiki/General_relativity> schema:description "A theory that from the outset prefers no state of motion (even accelerated ones) should appear more satisfactory." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifa2palqsrlc7a2ynttd4mkbldirba7vifypf5xz2h7dwyn3ekz44",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifa2palqsrlc7a2ynttd4mkbldirba7vifypf5xz2h7dwyn3ekz44",
#   "prov:label": "rdf:41_6",
#   "_cell": 1203,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreickb6gqognlmy7nctwhodxk2ugpoky7el5rfg4tpovypussugpg7i"
#   },
#   "_stmt_key": "41_6",
#   "_chunk_num": 41,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [41.7]: In 1907, [Albert Einstein](/wiki/Albert_Einstein) published an article on acceleration under [special relativity](/wiki/special_relativity).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author _:s7_article1 .
# _:s7_article1 rdf:type schema:Article .
# _:s7_article1 schema:name "On the Relativity Principle and the Conclusions Drawn from It" .
# _:s7_article1 schema:datePublished "1907"^^xsd:gYear .
# _:s7_article1 schema:about <https://en.wikipedia.org/wiki/special_relativity> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigenl2cstkrw6tdpw3k3gxs7akv2qjftiv27e5nlyprfdrn4drlv4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigenl2cstkrw6tdpw3k3gxs7akv2qjftiv27e5nlyprfdrn4drlv4",
#   "prov:label": "rdf:41_7",
#   "_cell": 1205,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihomhg5ntdg2ackvholkoa7kyuaworm4ahkylcqpovjwowv2lpdz4"
#   },
#   "_stmt_key": "41_7",
#   "_chunk_num": 41,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [41.8]: The article titled "On the Relativity Principle and the Conclusions Drawn from It" argued that [free fall](/wiki/free_fall) is really inertial motion.
# _:s7_article1 schema:description "The article argued that free fall is really inertial motion." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidats24pem72timdstixjoibxfwjgizcazsjycv5p3uo6vrsmf7je",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidats24pem72timdstixjoibxfwjgizcazsjycv5p3uo6vrsmf7je",
#   "prov:label": "rdf:41_8",
#   "_cell": 1207,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieqn2ctxmerplxa2entyvuqefzzje4mld42th2javscyzbfdfjxi4"
#   },
#   "_stmt_key": "41_8",
#   "_chunk_num": 41,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [41.9]: For a free-falling observer, the rules of [special relativity](/wiki/special_relativity) must apply.
# _:s7_article1 schema:description "For a free-falling observer, the rules of special relativity must apply." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibwrf45l7tg2fpfbstqdiy4lbwj5pzpalful4t5cpol4gy67ggpgq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibwrf45l7tg2fpfbstqdiy4lbwj5pzpalful4t5cpol4gy67ggpgq",
#   "prov:label": "rdf:41_9",
#   "_cell": 1209,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibbyh7ylctwcfosn3rhxf3g7b3keqsb57zuw4juv76qjtlfhtvlpm"
#   },
#   "_stmt_key": "41_9",
#   "_chunk_num": 41,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [41.10]: This argument is called the [equivalence principle](/wiki/equivalence_principle).
# <https://en.wikipedia.org/wiki/equivalence_principle> rdf:type schema:ScientificTheory .
# <https://en.wikipedia.org/wiki/equivalence_principle> schema:description "This argument is called the equivalence principle." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreienzsklq4nigl4sz66ede5364sdgcyokticulsa3famsqcxejrw4q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreienzsklq4nigl4sz66ede5364sdgcyokticulsa3famsqcxejrw4q",
#   "prov:label": "rdf:41_10",
#   "_cell": 1211,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiff74aeyofnhfbzskqp2wpnutm57bcwaypkf2f7tqw4fk25amctw4"
#   },
#   "_stmt_key": "41_10",
#   "_chunk_num": 41,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [41.11]: In the same article, [Albert Einstein](/wiki/Albert_Einstein) predicted the phenomena of [gravitational time dilation](/wiki/gravitational_time_dilation).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author _:s11_article1 .
# _:s11_article1 rdf:type schema:Article .
# _:s11_article1 schema:name "On the Relativity Principle and the Conclusions Drawn from It" .
# _:s11_article1 schema:datePublished "1907"^^xsd:gYear .
# _:s11_article1 schema:about <https://en.wikipedia.org/wiki/gravitational_time_dilation> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreif6g2np5274euavt5hckfv3xd5wlzgv6vksdhrvv7ctxlss2f5pni",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreif6g2np5274euavt5hckfv3xd5wlzgv6vksdhrvv7ctxlss2f5pni",
#   "prov:label": "rdf:41_11",
#   "_cell": 1213,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifxd2k6faiypoawzxptr2egk7dehjqxownbsiqhicnos327242o2y"
#   },
#   "_stmt_key": "41_11",
#   "_chunk_num": 41,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [41.12]: [Albert Einstein](/wiki/Albert_Einstein) also predicted [gravitational redshift](/wiki/gravitational_redshift).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author _:s12_article1 .
# _:s12_article1 rdf:type schema:Article .
# _:s12_article1 schema:name "On the Relativity Principle and the Conclusions Drawn from It" .
# _:s12_article1 schema:datePublished "1907"^^xsd:gYear .
# _:s12_article1 schema:about <https://en.wikipedia.org/wiki/gravitational_redshift> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic2bhj33vfuoalvegnrrixk7pm5tp5vxive6nm5j6gxog4qqxqt54",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic2bhj33vfuoalvegnrrixk7pm5tp5vxive6nm5j6gxog4qqxqt54",
#   "prov:label": "rdf:41_12",
#   "_cell": 1215,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid5tosnqnm45iqri4pgz7pd6hklsbtspx6an3qswxc2jviquff3ua"
#   },
#   "_stmt_key": "41_12",
#   "_chunk_num": 41,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [41.13]: [Albert Einstein](/wiki/Albert_Einstein) also predicted [gravitational lensing](/wiki/gravitational_lensing).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author _:s13_article1 .
# _:s13_article1 rdf:type schema:Article .
# _:s13_article1 schema:name "On the Relativity Principle and the Conclusions Drawn from It" .
# _:s13_article1 schema:datePublished "1907"^^xsd:gYear .
# _:s13_article1 schema:about <https://en.wikipedia.org/wiki/gravitational_lensing> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreig3e2c5dxlhsrgt7hfosr2cvuwkmtto6dxkfvhbpyrolusqajpbmu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreig3e2c5dxlhsrgt7hfosr2cvuwkmtto6dxkfvhbpyrolusqajpbmu",
#   "prov:label": "rdf:41_13",
#   "_cell": 1217,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibtoxfavzjc2agohsoh54iitjerwvwteuje2tsbi6pyw43x2t3jwu"
#   },
#   "_stmt_key": "41_13",
#   "_chunk_num": 41,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [41.14]: In 1911, [Albert Einstein](/wiki/Albert_Einstein) published another article titled "On the Influence of Gravitation on the Propagation of Light".
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author _:s14_article1 .
# _:s14_article1 rdf:type schema:Article .
# _:s14_article1 schema:name "On the Influence of Gravitation on the Propagation of Light" .
# _:s14_article1 schema:datePublished "1911"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicjmghsbayec4esu66l42b2o66zp7mciua2bctevcfjbn6pwpaj3i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicjmghsbayec4esu66l42b2o66zp7mciua2bctevcfjbn6pwpaj3i",
#   "prov:label": "rdf:41_14",
#   "_cell": 1219,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiao2efj45t4d7hwwpq6pxl4ypr6zyr7u3ejgyxgr5p66voa7kpgvq"
#   },
#   "_stmt_key": "41_14",
#   "_chunk_num": 41,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [41.15]: The article expanded on the 1907 article.
# _:s14_article1 schema:description "The article expanded on the 1907 article." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiccuezr2iviwvy7q2s3eo57fpo3x75c27s25mddjsr6s23mkex4pe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiccuezr2iviwvy7q2s3eo57fpo3x75c27s25mddjsr6s23mkex4pe",
#   "prov:label": "rdf:41_15",
#   "_cell": 1221,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihwhzur4ckmbs3h33k24mk2rd3ur4ultrkaymbvfyyxekddmjm36m"
#   },
#   "_stmt_key": "41_15",
#   "_chunk_num": 41,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [41.16]: In the article, [Albert Einstein](/wiki/Albert_Einstein) estimated the amount of deflection of light by massive bodies.
# _:s14_article1 schema:description "In the article, Einstein estimated the amount of deflection of light by massive bodies." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibshzim3w3bshvomlixkdhufji3jyrq4crnxff7e27nlfn7phhcdi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibshzim3w3bshvomlixkdhufji3jyrq4crnxff7e27nlfn7phhcdi",
#   "prov:label": "rdf:41_16",
#   "_cell": 1223,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiesjy2rzat35oikqmbdjt7z6sfn6baxonmzfcr76bbbq2g34ur4ea"
#   },
#   "_stmt_key": "41_16",
#   "_chunk_num": 41,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [41.17]: The theoretical prediction of [General relativity](/wiki/General_relativity) could for the first time be tested experimentally.
# <https://en.wikipedia.org/wiki/General_relativity> schema:description "The theoretical prediction of General relativity could for the first time be tested experimentally." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifjyd7fvpv2bjddw72ppi3prcsb3q26noq26p737eg7jvbnjm2dly",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifjyd7fvpv2bjddw72ppi3prcsb3q26noq26p737eg7jvbnjm2dly",
#   "prov:label": "rdf:41_17",
#   "_cell": 1225,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreie4i4pwkerkkqpfp5bockady3figmeyccrkxvfa2bkj3xq5dj6oh4"
#   },
#   "_stmt_key": "41_17",
#   "_chunk_num": 41,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [42.1]: [General relativity](/wiki/General_relativity) is a [theory of gravitation](/wiki/theory_of_gravitation) that was developed by [Albert Einstein](/wiki/Albert_Einstein) between 1907 and 1915.
# <https://en.wikipedia.org/wiki/General_relativity> rdf:type schema:ScientificTheory .
# <https://en.wikipedia.org/wiki/General_relativity> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/General_relativity> schema:dateCreated "1907/1915"^^xsd:string .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia4mvvs72h6nqgjig7olddrihytrx43pggae7ubdr7dzwnhpe7gzu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia4mvvs72h6nqgjig7olddrihytrx43pggae7ubdr7dzwnhpe7gzu",
#   "prov:label": "rdf:42_1",
#   "_cell": 1227,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihqqvvcwjh4xm5m7osn5pbhvfngv5j65ihsqcnio7ur2ddb5itzue"
#   },
#   "_stmt_key": "42_1",
#   "_chunk_num": 42,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [42.2]: According to [General relativity](/wiki/General_relativity), the observed gravitational attraction between masses results from the warping of [spacetime](/wiki/spacetime) by those masses.
# <https://en.wikipedia.org/wiki/General_relativity> schema:description "According to General relativity, the observed gravitational attraction between masses results from the warping of spacetime by those masses." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicwjrtyzj2dooxp4gn4fvhqvoa2ty7t24dwlcu7hmju6w67ztsuta",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicwjrtyzj2dooxp4gn4fvhqvoa2ty7t24dwlcu7hmju6w67ztsuta",
#   "prov:label": "rdf:42_2",
#   "_cell": 1229,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihf4z7mbd2wqxzzphtynjdx3q5gc34zwt5otynhsavg4sjce5t5j4"
#   },
#   "_stmt_key": "42_2",
#   "_chunk_num": 42,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [42.3]: [General relativity](/wiki/General_relativity) has developed into an essential tool in modern [astrophysics](/wiki/astrophysics).
# <https://en.wikipedia.org/wiki/General_relativity> schema:application <https://en.wikipedia.org/wiki/Astrophysics> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiafmp5ztuyfpzoitu6bti5hxu7rhguisy4xsbtjz32qy6byqfruyu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiafmp5ztuyfpzoitu6bti5hxu7rhguisy4xsbtjz32qy6byqfruyu",
#   "prov:label": "rdf:42_3",
#   "_cell": 1231,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihxmebxkvyacgrpb2jlf75r53s6j4iac2lmzhcgtepyodbll47fjm"
#   },
#   "_stmt_key": "42_3",
#   "_chunk_num": 42,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [42.4]: [General relativity](/wiki/General_relativity) provides the foundation for the current understanding of [black holes](/wiki/black_holes).
# <https://en.wikipedia.org/wiki/General_relativity> schema:application <https://en.wikipedia.org/wiki/Black_holes> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreianzydpznzigi5hqt4rafykafo76jwyij45g3wlvektqz6jyny4ai",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreianzydpznzigi5hqt4rafykafo76jwyij45g3wlvektqz6jyny4ai",
#   "prov:label": "rdf:42_4",
#   "_cell": 1233,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigh6aazv3iephcdyzfntnltjqbwqbg677oxbvjefm3seasu4bmkdu"
#   },
#   "_stmt_key": "42_4",
#   "_chunk_num": 42,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [42.5]: [Black holes](/wiki/black_holes) are regions of space where gravitational attraction is so strong that not even light can escape.
# <https://en.wikipedia.org/wiki/Black_holes> schema:description "Black holes are regions of space where gravitational attraction is so strong that not even light can escape." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigxt7tsasq4ko6weouv7rg4qzvxs3nmvr4kcl4f2dcs5663z36uvu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigxt7tsasq4ko6weouv7rg4qzvxs3nmvr4kcl4f2dcs5663z36uvu",
#   "prov:label": "rdf:42_5",
#   "_cell": 1235,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigfqqkioerdi26ezpbogez5jyhzlptwwk2knlu7qd6z34ppttnome"
#   },
#   "_stmt_key": "42_5",
#   "_chunk_num": 42,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [42.6]: [Albert Einstein](/wiki/Albert_Einstein) later said that the reason for the development of [General relativity](/wiki/General_relativity) was that the preference of inertial motions within [special relativity](/wiki/special_relativity) was unsatisfactory.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasOccupation schema:Researcher .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiddvv6vgp5eljc3x3ztfpi57axfyssaqmmqsn7zxyi5wt6jjhqmba",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiddvv6vgp5eljc3x3ztfpi57axfyssaqmmqsn7zxyi5wt6jjhqmba",
#   "prov:label": "rdf:42_6",
#   "_cell": 1237,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibzbw43ga3j6zyycomof5nppzvjhc37ayfmbi3gkwcdf7gqotlzo4"
#   },
#   "_stmt_key": "42_6",
#   "_chunk_num": 42,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [42.7]: A theory that from the outset prefers no state of motion (even accelerated ones) should appear more satisfactory than the preference of inertial motions within [special relativity](/wiki/special_relativity).
# <https://en.wikipedia.org/wiki/Special_relativity> schema:description "A theory that from the outset prefers no state of motion (even accelerated ones) should appear more satisfactory than the preference of inertial motions within special relativity." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibrni6dnjhtmb73jgkbooxpif46sdc7njiaotd3u7rezezklkhmyq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibrni6dnjhtmb73jgkbooxpif46sdc7njiaotd3u7rezezklkhmyq",
#   "prov:label": "rdf:42_7",
#   "_cell": 1239,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicuebgj7ghijg5ql3prav275wgtmdxkaqov2ftxevisommzv44toy"
#   },
#   "_stmt_key": "42_7",
#   "_chunk_num": 42,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [42.8]: In 1907, [Albert Einstein](/wiki/Albert_Einstein) published an article on acceleration under [special relativity](/wiki/special_relativity).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author <https://en.wikipedia.org/wiki/Special_relativity> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifavworgjal5ynvnbnkrh7oa23ukfghs2kbmq37h6ahlb4mqvdxyi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifavworgjal5ynvnbnkrh7oa23ukfghs2kbmq37h6ahlb4mqvdxyi",
#   "prov:label": "rdf:42_8",
#   "_cell": 1241,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihomhg5ntdg2ackvholkoa7kyuaworm4ahkylcqpovjwowv2lpdz4"
#   },
#   "_stmt_key": "42_8",
#   "_chunk_num": 42,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [42.9]: The article titled "On the Relativity Principle and the Conclusions Drawn from It" was published by [Albert Einstein](/wiki/Albert_Einstein) in 1907.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author <https://en.wikipedia.org/wiki/On_the_Relativity_Principle_and_the_Conclusions_Drawn_from_It> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifktu5kddclv6nv7mr4shs7rxqdxb3oms4gj34ganzm72les6ckdu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifktu5kddclv6nv7mr4shs7rxqdxb3oms4gj34ganzm72les6ckdu",
#   "prov:label": "rdf:42_9",
#   "_cell": 1243,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidt36dxj4nannlg3cqg5romlae43hyfovjobh6h6qklkbdl3ycbeu"
#   },
#   "_stmt_key": "42_9",
#   "_chunk_num": 42,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [42.10]: In that article, [Albert Einstein](/wiki/Albert_Einstein) argued that [free fall](/wiki/free_fall) is really inertial motion.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasOccupation schema:Researcher .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidtqw4tpej62fju6htqbtegcnlxga3ofwgdf5bnk6vkkv7xbcaepm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidtqw4tpej62fju6htqbtegcnlxga3ofwgdf5bnk6vkkv7xbcaepm",
#   "prov:label": "rdf:42_10",
#   "_cell": 1245,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiahy553vcm4ukrrzyj5uuvjurvodrdbxrslvje4lnywu7dkwrjmoa"
#   },
#   "_stmt_key": "42_10",
#   "_chunk_num": 42,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [42.11]: For a free-falling observer, the rules of [special relativity](/wiki/special_relativity) must apply.
# <https://en.wikipedia.org/wiki/Special_relativity> schema:description "For a free-falling observer, the rules of special relativity must apply." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiboofzbwykypujtkyhrjwmkkznxuwu75k6q2pynql3pxd6k7lc3ty",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiboofzbwykypujtkyhrjwmkkznxuwu75k6q2pynql3pxd6k7lc3ty",
#   "prov:label": "rdf:42_11",
#   "_cell": 1247,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibbyh7ylctwcfosn3rhxf3g7b3keqsb57zuw4juv76qjtlfhtvlpm"
#   },
#   "_stmt_key": "42_11",
#   "_chunk_num": 42,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [42.12]: This argument is called the [equivalence principle](/wiki/equivalence_principle).
# <https://en.wikipedia.org/wiki/Equivalence_principle> rdf:type schema:ScientificTheory .
# <https://en.wikipedia.org/wiki/Equivalence_principle> schema:description "This argument is called the equivalence principle." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreialz3k4y54552feipzxzgbd56eesinzazftzqhrcs62gvnm726ssa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreialz3k4y54552feipzxzgbd56eesinzazftzqhrcs62gvnm726ssa",
#   "prov:label": "rdf:42_12",
#   "_cell": 1249,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiff74aeyofnhfbzskqp2wpnutm57bcwaypkf2f7tqw4fk25amctw4"
#   },
#   "_stmt_key": "42_12",
#   "_chunk_num": 42,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [42.13]: In the same article, [Albert Einstein](/wiki/Albert_Einstein) also predicted the phenomena of [gravitational time dilation](/wiki/gravitational_time_dilation).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author <https://en.wikipedia.org/wiki/On_the_Relativity_Principle_and_the_Conclusions_Drawn_from_It> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicsetgj5ogr3ukz2qiuyv2suftqnr2cb3ejn34ua5lphy36sdt3n4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicsetgj5ogr3ukz2qiuyv2suftqnr2cb3ejn34ua5lphy36sdt3n4",
#   "prov:label": "rdf:42_13",
#   "_cell": 1251,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibq6omjysagragf2ygalzkqh7iql5rbholbieds7xxwlzofbzpkw4"
#   },
#   "_stmt_key": "42_13",
#   "_chunk_num": 42,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [42.14]: In the same article, [Albert Einstein](/wiki/Albert_Einstein) also predicted the phenomena of [gravitational redshift](/wiki/gravitational_redshift).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author <https://en.wikipedia.org/wiki/On_the_Relativity_Principle_and_the_Conclusions_Drawn_from_It> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihyxaaaeunevnkxqn3movgcnf5wva5tceb57e434e7sok4vs2p4ly",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihyxaaaeunevnkxqn3movgcnf5wva5tceb57e434e7sok4vs2p4ly",
#   "prov:label": "rdf:42_14",
#   "_cell": 1253,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicveoyrtpq6izfem3x2dkygv6ctfggee4akgz2tsn3oaxc2e6m3ae"
#   },
#   "_stmt_key": "42_14",
#   "_chunk_num": 42,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [42.15]: In the same article, [Albert Einstein](/wiki/Albert_Einstein) also predicted the phenomena of [gravitational lensing](/wiki/gravitational_lensing).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author <https://en.wikipedia.org/wiki/On_the_Relativity_Principle_and_the_Conclusions_Drawn_from_It> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieeynwkhtqnsne5edayinfwnjidplgmx6zxa2o3jypjmqguwmqzna",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieeynwkhtqnsne5edayinfwnjidplgmx6zxa2o3jypjmqguwmqzna",
#   "prov:label": "rdf:42_15",
#   "_cell": 1255,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigkdjsgijgqxkaruqjvt5remszaxciy2pggm3txq6cx743hg54klm"
#   },
#   "_stmt_key": "42_15",
#   "_chunk_num": 42,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [42.16]: In 1911, [Albert Einstein](/wiki/Albert_Einstein) published another article titled "On the Influence of Gravitation on the Propagation of Light".
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author <https://en.wikipedia.org/wiki/On_the_Influence_of_Gravitation_on_the_Propagation_of_Light> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreig6q2y72h7mnd7kazl3ivhxgusfrpncuso3tx4so3lekwhczxzfve",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreig6q2y72h7mnd7kazl3ivhxgusfrpncuso3tx4so3lekwhczxzfve",
#   "prov:label": "rdf:42_16",
#   "_cell": 1257,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiao2efj45t4d7hwwpq6pxl4ypr6zyr7u3ejgyxgr5p66voa7kpgvq"
#   },
#   "_stmt_key": "42_16",
#   "_chunk_num": 42,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [42.17]: The 1911 article expanded on the 1907 article by [Albert Einstein](/wiki/Albert_Einstein).
# <https://en.wikipedia.org/wiki/On_the_Influence_of_Gravitation_on_the_Propagation_of_Light> schema:isBasedOn <https://en.wikipedia.org/wiki/On_the_Relativity_Principle_and_the_Conclusions_Drawn_from_It> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreih3uanontbr235ppnb24ouw2pr6mw2wpgf4hfekmgcvqe3gbib2b4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreih3uanontbr235ppnb24ouw2pr6mw2wpgf4hfekmgcvqe3gbib2b4",
#   "prov:label": "rdf:42_17",
#   "_cell": 1259,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiamt355tz7op5od5rad5wwrachpp65udn4cm46me24lw3oqnsnt24"
#   },
#   "_stmt_key": "42_17",
#   "_chunk_num": 42,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [42.18]: In the 1911 article, [Albert Einstein](/wiki/Albert_Einstein) estimated the amount of deflection of light by massive bodies.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author <https://en.wikipedia.org/wiki/On_the_Influence_of_Gravitation_on_the_Propagation_of_Light> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidaor5sqthciifj67ye6hyf4yekz6vilsutfptoq4qx7c35dgmf5y",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidaor5sqthciifj67ye6hyf4yekz6vilsutfptoq4qx7c35dgmf5y",
#   "prov:label": "rdf:42_18",
#   "_cell": 1261,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihhq6odteybs7pqwuuji4rbbyskidudifr5kki3pz4txm242fhmvm"
#   },
#   "_stmt_key": "42_18",
#   "_chunk_num": 42,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [42.19]: The theoretical prediction of [General relativity](/wiki/General_relativity) could for the first time be tested experimentally.
# <https://en.wikipedia.org/wiki/General_relativity> schema:description "The theoretical prediction of General relativity could for the first time be tested experimentally." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihs5dbxrzkxhm2pqlflvva27dplfxl4mnsncxok2iw57aiyqkbkya",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihs5dbxrzkxhm2pqlflvva27dplfxl4mnsncxok2iw57aiyqkbkya",
#   "prov:label": "rdf:42_19",
#   "_cell": 1263,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreie4i4pwkerkkqpfp5bockady3figmeyccrkxvfa2bkj3xq5dj6oh4"
#   },
#   "_stmt_key": "42_19",
#   "_chunk_num": 42,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Statement [43.1]: [Albert Einstein](/wiki/Albert_Einstein) predicted [gravitational wave](/wiki/gravitational_wave)s in 1916.
# _:s1_gravitational_wave_prediction rdf:type schema:Quotation .
# _:s1_gravitational_wave_prediction schema:text "Albert Einstein predicted gravitational waves in 1916." .
# _:s1_gravitational_wave_prediction schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s1_gravitational_wave_prediction schema:startDate "1916"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia73qnlzefnxirqh7kfehdysaxrymkg3r3mxifzwcktabljtqtcry",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia73qnlzefnxirqh7kfehdysaxrymkg3r3mxifzwcktabljtqtcry",
#   "prov:label": "rdf:43_1",
#   "_cell": 1265,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihxy3mewsdpwo7kferozzjgu5y3tlnogirpep2amel7ngfiw6xnfe"
#   },
#   "_stmt_key": "43_1",
#   "_chunk_num": 43,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [43.2]: [Gravitational wave](/wiki/gravitational_wave)s are ripples in the [curvature](/wiki/curvature) of spacetime.
# <https://en.wikipedia.org/wiki/Gravitational_wave> rdf:type schema:Thing .
# <https://en.wikipedia.org/wiki/Gravitational_wave> rdfs:comment "Gravitational waves are ripples in the curvature of spacetime." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihwmqpsongxedbiyd26fo2d7fxspw5fhznybpcomverqooq67da6u",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihwmqpsongxedbiyd26fo2d7fxspw5fhznybpcomverqooq67da6u",
#   "prov:label": "rdf:43_2",
#   "_cell": 1267,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidcva6pneacyz5aobpnkn7pcz2rquscztyvvjthkvyh7tv3ishfci"
#   },
#   "_stmt_key": "43_2",
#   "_chunk_num": 43,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [43.3]: [Gravitational wave](/wiki/gravitational_wave)s propagate as [wave](/wiki/wave)s.
# <https://en.wikipedia.org/wiki/Gravitational_wave> rdfs:comment "Gravitational waves propagate as waves." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreid4lpbuwdtszcxs4xxfjifwbcnaqef2kbseij4pugbgilwtgbldpy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreid4lpbuwdtszcxs4xxfjifwbcnaqef2kbseij4pugbgilwtgbldpy",
#   "prov:label": "rdf:43_3",
#   "_cell": 1269,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiab23tar6ryeclri2swwq6pvkwsdtqbaylvsf73rdver47i5ur3xe"
#   },
#   "_stmt_key": "43_3",
#   "_chunk_num": 43,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [43.4]: [Gravitational wave](/wiki/gravitational_wave)s travel outward from the source.
# <https://en.wikipedia.org/wiki/Gravitational_wave> rdfs:comment "Gravitational waves travel outward from the source." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie52kf524kuotxlrp255myohqilq3gkonjbp4d6zsqgskttkrtfoq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie52kf524kuotxlrp255myohqilq3gkonjbp4d6zsqgskttkrtfoq",
#   "prov:label": "rdf:43_4",
#   "_cell": 1271,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreig7kaxdsfq7gnsqorgajfpkagyafnxbighyhjilseovkm75g4gvlm"
#   },
#   "_stmt_key": "43_4",
#   "_chunk_num": 43,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [43.5]: [Gravitational wave](/wiki/gravitational_wave)s transport energy as gravitational radiation.
# <https://en.wikipedia.org/wiki/Gravitational_wave> rdfs:comment "Gravitational waves transport energy as gravitational radiation." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidqf22rp6cuqo55v3mhjgtsyri4pxuikqrdhmgzd656eossagbgxa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidqf22rp6cuqo55v3mhjgtsyri4pxuikqrdhmgzd656eossagbgxa",
#   "prov:label": "rdf:43_5",
#   "_cell": 1273,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicdkdkgbkqhh3hkm2nriu2zlkgdggld57gy35fyfgrh4galdcvqzi"
#   },
#   "_stmt_key": "43_5",
#   "_chunk_num": 43,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [43.6]: The existence of [gravitational wave](/wiki/gravitational_wave)s is possible under [general relativity](/wiki/general_relativity) due to its [Lorentz invariance](/wiki/Lorentz_invariance).
# <https://en.wikipedia.org/wiki/Gravitational_wave> rdfs:comment "The existence of gravitational waves is possible under general relativity due to its Lorentz invariance." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidrylirk6rcoyfpelqavx24ef23rsak4ifhpiem726xklagtphlym",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidrylirk6rcoyfpelqavx24ef23rsak4ifhpiem726xklagtphlym",
#   "prov:label": "rdf:43_6",
#   "_cell": 1275,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiesa3uxgc3b7nmed62n35eixhf5gta6yzujvrhpann3fhelt4vxqy"
#   },
#   "_stmt_key": "43_6",
#   "_chunk_num": 43,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [43.7]: [Lorentz invariance](/wiki/Lorentz_invariance) brings the concept of a finite speed of propagation of the physical interactions of gravity.
# <https://en.wikipedia.org/wiki/Lorentz_invariance> rdfs:comment "Lorentz invariance brings the concept of a finite speed of propagation of the physical interactions of gravity." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreighvf4oidfrpkc54o5hzuxizw5pj4bgqigltrbyz6ym5oje54277a",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreighvf4oidfrpkc54o5hzuxizw5pj4bgqigltrbyz6ym5oje54277a",
#   "prov:label": "rdf:43_7",
#   "_cell": 1277,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieykjpj7fwgmhscvzrmolqcc5lrhivcfqmdyvwul7f7mlxb5yfzc4"
#   },
#   "_stmt_key": "43_7",
#   "_chunk_num": 43,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [43.8]: [Gravitational wave](/wiki/gravitational_wave)s cannot exist in the [Newtonian theory of gravitation](/wiki/Newton%27s_law_of_universal_gravitation).
# <https://en.wikipedia.org/wiki/Gravitational_wave> rdfs:comment "Gravitational waves cannot exist in the Newtonian theory of gravitation." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigokvy7f2uutho6thoazpxeiq4nz5b3ct6mzvpnkzzwlu7runmesq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigokvy7f2uutho6thoazpxeiq4nz5b3ct6mzvpnkzzwlu7runmesq",
#   "prov:label": "rdf:43_8",
#   "_cell": 1279,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiftm63m4oknbtavzemir25goov5fggcjr5d7vq5ifc33tzqdxtmwy"
#   },
#   "_stmt_key": "43_8",
#   "_chunk_num": 43,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [43.9]: [Newtonian theory of gravitation](/wiki/Newton%27s_law_of_universal_gravitation) postulates that the physical interactions of gravity propagate at infinite speed.
# <https://en.wikipedia.org/wiki/Newtonian_theory_of_gravitation> rdfs:comment "Newtonian theory of gravitation postulates that the physical interactions of gravity propagate at infinite speed." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaph6gefgpc647ts6zklheheka4x5co6bnkscrj53weulfpqo7saq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaph6gefgpc647ts6zklheheka4x5co6bnkscrj53weulfpqo7saq",
#   "prov:label": "rdf:43_9",
#   "_cell": 1281,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigvekgkij6tec7rywy2443qic6skqmbjpaldip22twg6b5r42pmaq"
#   },
#   "_stmt_key": "43_9",
#   "_chunk_num": 43,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [43.10]: The first indirect detection of [gravitational wave](/wiki/gravitational_wave)s came in the 1970s.
# <https://en.wikipedia.org/wiki/Gravitational_wave> rdfs:comment "The first indirect detection of gravitational waves came in the 1970s." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigftkisqqwqiqvyo3inzr2u7vuktneve45iaw3tdbqo3j464jkn44",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigftkisqqwqiqvyo3inzr2u7vuktneve45iaw3tdbqo3j464jkn44",
#   "prov:label": "rdf:43_10",
#   "_cell": 1283,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiegzidd4hpuigod63meatqvbflrfyfplr2ianzwz2fcu44azapo4a"
#   },
#   "_stmt_key": "43_10",
#   "_chunk_num": 43,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [43.11]: The first indirect detection of [gravitational wave](/wiki/gravitational_wave)s was through observation of a pair of closely orbiting [neutron stars](/wiki/neutron_stars), [PSR B1913+16](/wiki/PSR_B1913%2B16).
# <https://en.wikipedia.org/wiki/Gravitational_wave> rdfs:comment "The first indirect detection of gravitational waves was through observation of a pair of closely orbiting neutron stars, PSR B1913+16." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibcw2loo67zmnk3icxcw4ps6qpq66d3iojnc2qems6ewk66ovhjtu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibcw2loo67zmnk3icxcw4ps6qpq66d3iojnc2qems6ewk66ovhjtu",
#   "prov:label": "rdf:43_11",
#   "_cell": 1285,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihnnz3r4b76d2lpukcdjirlup4jsoqirqrxklizbmbeeh2jo77vu4"
#   },
#   "_stmt_key": "43_11",
#   "_chunk_num": 43,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [43.12]: The decay in the orbital period of [PSR B1913+16](/wiki/PSR_B1913%2B16) was explained by emission of [gravitational wave](/wiki/gravitational_wave)s.
# <https://en.wikipedia.org/wiki/PSR_B1913%2B16> rdfs:comment "The decay in the orbital period of PSR B1913+16 was explained by emission of gravitational waves." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaz6jicdozwplaagnqbwqhamxupbtgcrzmimgjqpfz6wtj646uxc4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaz6jicdozwplaagnqbwqhamxupbtgcrzmimgjqpfz6wtj646uxc4",
#   "prov:label": "rdf:43_12",
#   "_cell": 1287,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiguksggp46naylwsdlkd3whjif5tkrz2g44jguer3zokybm2gh544"
#   },
#   "_stmt_key": "43_12",
#   "_chunk_num": 43,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [43.13]: [Albert Einstein](/wiki/Albert_Einstein)’s prediction of [gravitational wave](/wiki/gravitational_wave)s was confirmed on 11 February 2016.
# _:s13_einstein_prediction rdf:type schema:Quotation .
# _:s13_einstein_prediction schema:text "Albert Einstein's prediction of gravitational waves was confirmed on 11 February 2016." .
# _:s13_einstein_prediction schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s13_einstein_prediction schema:startDate "2016-02-11"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiejvufwkba3teexuwwfgfqbcb4jta7iacryi5bdfhvkkser5xp4dy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiejvufwkba3teexuwwfgfqbcb4jta7iacryi5bdfhvkkser5xp4dy",
#   "prov:label": "rdf:43_13",
#   "_cell": 1289,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifa67zotunfl2l53xr4ybxzrmhpz3oyzes2mgywnwfpznkbvj4qmu"
#   },
#   "_stmt_key": "43_13",
#   "_chunk_num": 43,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [43.14]: Researchers at [LIGO](/wiki/LIGO) published the [first observation of gravitational waves](/wiki/first_observation_of_gravitational_waves) on 11 February 2016.
# _:s14_ligo_observation rdf:type schema:Quotation .
# _:s14_ligo_observation schema:text "Researchers at LIGO published the first observation of gravitational waves on 11 February 2016." .
# _:s14_ligo_observation schema:creator <https://en.wikipedia.org/wiki/LIGO> .
# _:s14_ligo_observation schema:startDate "2016-02-11"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieihbzde6ejnuhwpmqeeyybrcqz4dlnc5a6v4nmzuhatiiah5kf2i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieihbzde6ejnuhwpmqeeyybrcqz4dlnc5a6v4nmzuhatiiah5kf2i",
#   "prov:label": "rdf:43_14",
#   "_cell": 1291,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib6mf3alnwdou2nkxfsiip5dkypkf2po33lam45hqqdyrq32nh3pi"
#   },
#   "_stmt_key": "43_14",
#   "_chunk_num": 43,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [43.15]: The [first observation of gravitational waves](/wiki/first_observation_of_gravitational_waves) was detected on Earth on 14 September 2015.
# _:s15_first_observation rdf:type schema:Quotation .
# _:s15_first_observation schema:text "The first observation of gravitational waves was detected on Earth on 14 September 2015." .
# _:s15_first_observation schema:startDate "2015-09-14"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic46pwsvve223qad45zwgzxr5komauwoujnnb4j4yqj7nf5vgehem",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic46pwsvve223qad45zwgzxr5komauwoujnnb4j4yqj7nf5vgehem",
#   "prov:label": "rdf:43_15",
#   "_cell": 1293,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihxoffdtg7j4bnip64r7mk4pdt6bdukjnr3rvr4xmo7hzurlqgwim"
#   },
#   "_stmt_key": "43_15",
#   "_chunk_num": 43,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [43.16]: The [first observation of gravitational waves](/wiki/first_observation_of_gravitational_waves) was detected nearly one hundred years after [Albert Einstein](/wiki/Albert_Einstein)’s prediction.
# _:s16_time_gap rdf:type schema:Quotation .
# _:s16_time_gap schema:text "The first observation of gravitational waves was detected nearly one hundred years after Albert Einstein's prediction." .
# _:s16_time_gap schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreief3htmwhpyukkwl5f6f4eiep7nrymkktqxzjacoam2bcdt5yjoyu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreief3htmwhpyukkwl5f6f4eiep7nrymkktqxzjacoam2bcdt5yjoyu",
#   "prov:label": "rdf:43_16",
#   "_cell": 1295,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreif5ngubauepdycm7hbwkmjplplv35xuywm4ytn7ehvgolplfboerq"
#   },
#   "_stmt_key": "43_16",
#   "_chunk_num": 43,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [43.17]: While developing [general relativity](/wiki/general_relativity), [Albert Einstein](/wiki/Albert_Einstein) became confused about the [gauge invariance](/wiki/gauge_invariance) in the theory.
# _:s17_general_relativity rdf:type schema:Quotation .
# _:s17_general_relativity schema:text "While developing general relativity, Albert Einstein became confused about the gauge invariance in the theory." .
# _:s17_general_relativity schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s17_general_relativity schema:about <https://en.wikipedia.org/wiki/General_relativity> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigaxdkqglbpev22mj3z36fqv7vyifnimmdctgyfdh5b2er7us5kzq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigaxdkqglbpev22mj3z36fqv7vyifnimmdctgyfdh5b2er7us5kzq",
#   "prov:label": "rdf:43_17",
#   "_cell": 1297,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifxsvzctwhjpr2acbb5u7fqcucw2ohgcjeij3rkngbn2lmnybnqou"
#   },
#   "_stmt_key": "43_17",
#   "_chunk_num": 43,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [43.18]: Einstein formulated an argument that led him to conclude that a general relativistic field theory is impossible.
# _:s18_field_theory rdf:type schema:Quotation .
# _:s18_field_theory schema:text "Einstein formulated an argument that led him to conclude that a general relativistic field theory is impossible." .
# _:s18_field_theory schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicpmwglyo3eytypvhcsueqnirn57e3oxah4s7rqllnagoqsaa5qfm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicpmwglyo3eytypvhcsueqnirn57e3oxah4s7rqllnagoqsaa5qfm",
#   "prov:label": "rdf:43_18",
#   "_cell": 1299,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid52eov3gtkyzjto6hoizp7afm2znao4dys45crisigcjqurixkou"
#   },
#   "_stmt_key": "43_18",
#   "_chunk_num": 43,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [43.19]: Einstein gave up looking for fully generally covariant tensor equations.
# _:s19_tensor_equations rdf:type schema:Quotation .
# _:s19_tensor_equations schema:text "Einstein gave up looking for fully generally covariant tensor equations." .
# _:s19_tensor_equations schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiesryy3y27aggkalentexifwkabtu642vkbota7mrwvsc5q3rsaem",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiesryy3y27aggkalentexifwkabtu642vkbota7mrwvsc5q3rsaem",
#   "prov:label": "rdf:43_19",
#   "_cell": 1301,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid7pswwqyakjdoyzlwr2tabpqhx5a6s5i6ug6b6q7lvwqsdwcppey"
#   },
#   "_stmt_key": "43_19",
#   "_chunk_num": 43,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Statement [43.20]: Einstein searched for equations that would be invariant under general linear transformations only.
# _:s20_linear_transformations rdf:type schema:Quotation .
# _:s20_linear_transformations schema:text "Einstein searched for equations that would be invariant under general linear transformations only." .
# _:s20_linear_transformations schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibxra2eorassp6khmyke7gsdqsddqzqqrt22s2tb5bnjcq2ji7xtm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibxra2eorassp6khmyke7gsdqsddqzqqrt22s2tb5bnjcq2ji7xtm",
#   "prov:label": "rdf:43_20",
#   "_cell": 1303,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia2q4xk3pzgj35frzjebibrbilymrxlyctxospjemns4moaapwxbm"
#   },
#   "_stmt_key": "43_20",
#   "_chunk_num": 43,
#   "_stmt_idx": 20
# }

# %% [raw]
# # Statement [44.1]: In June 1913, the Entwurf theory was the result of investigations.
# <https://en.wikipedia.org/wiki/Entwurf_theory> rdf:type schema:Specialty .
# <https://en.wikipedia.org/wiki/Entwurf_theory> schema:dateCreated "1913"^^xsd:gYear .
# <https://en.wikipedia.org/wiki/Entwurf_theory> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreianhrcnt3om4hbq6xhmlbf23i7q3pmemxydkzgzkp7xzd2ulf2kfa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreianhrcnt3om4hbq6xhmlbf23i7q3pmemxydkzgzkp7xzd2ulf2kfa",
#   "prov:label": "rdf:44_1",
#   "_cell": 1305,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiajz24xkiedn4q4j4g3aepaw3o63bf5mkwmuc2vrychq7hozmf56a"
#   },
#   "_stmt_key": "44_1",
#   "_chunk_num": 44,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [44.2]: The Entwurf theory was a sketch of a theory in June 1913.
# <https://en.wikipedia.org/wiki/Entwurf_theory> rdf:type schema:Specialty .
# <https://en.wikipedia.org/wiki/Entwurf_theory> schema:dateCreated "1913"^^xsd:gYear .
# <https://en.wikipedia.org/wiki/Entwurf_theory> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicokt2qvckqci5aceo3gdqzsb6gylbquexwv4viyfzfjtukbjnqhu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicokt2qvckqci5aceo3gdqzsb6gylbquexwv4viyfzfjtukbjnqhu",
#   "prov:label": "rdf:44_2",
#   "_cell": 1307,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreic4powzrpdr37yvncvwzrsbwenqi4e33vhiiu227sxbwuy6skmuvi"
#   },
#   "_stmt_key": "44_2",
#   "_chunk_num": 44,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [44.3]: The Entwurf theory was less elegant and more difficult than general relativity.
# <https://en.wikipedia.org/wiki/Entwurf_theory> rdf:type schema:Specialty .
# <https://en.wikipedia.org/wiki/Entwurf_theory> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreif7cl3aikswcp7us3hbnpxmovpummvjbgvaoq6k5waoo33te4hwby",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreif7cl3aikswcp7us3hbnpxmovpummvjbgvaoq6k5waoo33te4hwby",
#   "prov:label": "rdf:44_3",
#   "_cell": 1309,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreie42xoq7fi4jqjrur6mlm45frjic3ann7oclziuvda4w5ttoahyaa"
#   },
#   "_stmt_key": "44_3",
#   "_chunk_num": 44,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [44.4]: The equations of motion in the Entwurf theory were supplemented by additional gauge fixing conditions.
# <https://en.wikipedia.org/wiki/Entwurf_theory> rdf:type schema:Specialty .
# <https://en.wikipedia.org/wiki/Entwurf_theory> schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaez6po2seuwvf7eqp7og7vpgajhpcklkhpekcdzoot5qyybcddji",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaez6po2seuwvf7eqp7og7vpgajhpcklkhpekcdzoot5qyybcddji",
#   "prov:label": "rdf:44_4",
#   "_cell": 1311,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihwyk5b5k23a7gpjfdqkxs3qiqwvsglw3uayuwpbg5zknnz3vuwve"
#   },
#   "_stmt_key": "44_4",
#   "_chunk_num": 44,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [44.5]: Einstein worked intensively on the Entwurf theory for more than two years.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasOccupation schema:Researcher .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:workHistory _:s5_role1 .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibtnzmusbqqyrurhjuctxtowahgz7nnj2dutgr56424enroetdnfu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibtnzmusbqqyrurhjuctxtowahgz7nnj2dutgr56424enroetdnfu",
#   "prov:label": "rdf:44_5",
#   "_cell": 1313,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiha555c7pd632jsm5fuytmgkw2dgdjgpw4d3yeoltikue5xi6hmxa"
#   },
#   "_stmt_key": "44_5",
#   "_chunk_num": 44,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [44.6]: In November 1915, Einstein realized that the hole argument was mistaken.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:achievement _:s6_role1 .
# _:s6_role1 rdf:type schema:Role .
# _:s6_role1 schema:startDate "1915-11"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibnlxdws433ec7g3wcxh5luiyx5zanpflilhyn7afdopb3cfgjgja",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibnlxdws433ec7g3wcxh5luiyx5zanpflilhyn7afdopb3cfgjgja",
#   "prov:label": "rdf:44_6",
#   "_cell": 1315,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreic627jvl5fhbak3rixp6nfwkcwh2w6a4rfrozwvoldwxw7hag7uby"
#   },
#   "_stmt_key": "44_6",
#   "_chunk_num": 44,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [44.7]: In November 1915, Einstein abandoned the Entwurf theory.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:workHistory _:s7_role1 .
# _:s7_role1 rdf:type schema:Role .
# _:s7_role1 schema:endDate "1915-11"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia2voulqx3lyz4js2gu5l7owegcwg53eaisfkjj4x2w75nlc67sk4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia2voulqx3lyz4js2gu5l7owegcwg53eaisfkjj4x2w75nlc67sk4",
#   "prov:label": "rdf:44_7",
#   "_cell": 1317,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiayepxkz5s7mymusrkjyuppgf5vo666kwkffndabdwsyfwiroe6ia"
#   },
#   "_stmt_key": "44_7",
#   "_chunk_num": 44,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [44.8]: In 1917, Einstein applied the general theory of relativity to the structure of the universe as a whole.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:achievement _:s8_role1 .
# _:s8_role1 rdf:type schema:Role .
# _:s8_role1 schema:startDate "1917"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreignq2uy3pbbgodmmfddelxgpo4nmvcsqlkte5b4caor722ntw63im",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreignq2uy3pbbgodmmfddelxgpo4nmvcsqlkte5b4caor722ntw63im",
#   "prov:label": "rdf:44_8",
#   "_cell": 1319,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiajmxjtvul6lkslkvsmzgsrbhhkmmhklh5gw2cabcaxw5xihqquhq"
#   },
#   "_stmt_key": "44_8",
#   "_chunk_num": 44,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [44.9]: In 1929, [Edwin Hubble](/wiki/Edwin_Hubble) discovered the recession of the galaxies.
# <https://en.wikipedia.org/wiki/Edwin_Hubble> schema:achievement _:s9_role1 .
# _:s9_role1 rdf:type schema:Role .
# _:s9_role1 schema:startDate "1929"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihgir7t4rngwep4fyhmoaf5yepqffdarsjtvm6ox7f7wv2oq7kpae",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihgir7t4rngwep4fyhmoaf5yepqffdarsjtvm6ox7f7wv2oq7kpae",
#   "prov:label": "rdf:44_9",
#   "_cell": 1321,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifrrhfmg2p4yepxmle45xs3xa7zyfbb7luso5vi2x2xphmkxefblm"
#   },
#   "_stmt_key": "44_9",
#   "_chunk_num": 44,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [44.10]: Following the discovery of the recession of the galaxies by [Edwin Hubble](/wiki/Edwin_Hubble) in 1929, Einstein abandoned his static model of the universe.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:achievement _:s10_role1 .
# _:s10_role1 rdf:type schema:Role .
# _:s10_role1 schema:startDate "1929"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiggk3nf6flagk3a5h36d47uda2z56t5hlnbzdwrveonncj3prmtaq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiggk3nf6flagk3a5h36d47uda2z56t5hlnbzdwrveonncj3prmtaq",
#   "prov:label": "rdf:44_10",
#   "_cell": 1323,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreic7jpopu6cqpfnwwv4wa76fbbdnjz3opomj7ruxf3ktlc7gaoeeje"
#   },
#   "_stmt_key": "44_10",
#   "_chunk_num": 44,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [44.11]: In 1931, Einstein proposed the [Friedmann–Einstein universe](/wiki/Friedmann%E2%80%93Einstein_universe).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:achievement _:s11_role1 .
# _:s11_role1 rdf:type schema:Role .
# _:s11_role1 schema:startDate "1931"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreid3arbqrcotmapnk5mxe4odgsaoqiwo4iw37emsck7gtxdvvi5vyq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreid3arbqrcotmapnk5mxe4odgsaoqiwo4iw37emsck7gtxdvvi5vyq",
#   "prov:label": "rdf:44_11",
#   "_cell": 1325,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib4jjnhklsofiy44gcfncs3goxbp2qdjxfmfo2gwm4pfltoqhnccq"
#   },
#   "_stmt_key": "44_11",
#   "_chunk_num": 44,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [44.12]: In each of the dynamic models proposed by Einstein in 1931, Einstein discarded the cosmological constant.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:achievement _:s12_role1 .
# _:s12_role1 rdf:type schema:Role .
# _:s12_role1 schema:startDate "1931"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieutlp7bscbxnge6ocecafs5gr5zddgit4ggruv3sh2ji2cn5febu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieutlp7bscbxnge6ocecafs5gr5zddgit4ggruv3sh2ji2cn5febu",
#   "prov:label": "rdf:44_12",
#   "_cell": 1327,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreien4x2s3n2oixhylis4gojmrcthkrvl4liogxogmjq2x4kno3oriu"
#   },
#   "_stmt_key": "44_12",
#   "_chunk_num": 44,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [44.13]: In each of the dynamic models proposed by Einstein in 1931, Einstein claimed that the cosmological constant was "in any case theoretically unsatisfactory".
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:achievement _:s13_role1 .
# _:s13_role1 rdf:type schema:Role .
# _:s13_role1 schema:startDate "1931"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreietow7fldasnqkh7pirkuphiudlixrf7nipkp7axcwf7ltttszde4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreietow7fldasnqkh7pirkuphiudlixrf7nipkp7axcwf7ltttszde4",
#   "prov:label": "rdf:44_13",
#   "_cell": 1329,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiea4zgqxplykqiuws5pxl3vtsu4oa7bfyjq4oyzuqe6epvplbnbiq"
#   },
#   "_stmt_key": "44_13",
#   "_chunk_num": 44,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [44.14]: In many Einstein biographies, it is claimed that Einstein referred to the cosmological constant in later years as his "biggest blunder".
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:achievement _:s14_role1 .
# _:s14_role1 rdf:type schema:Role .
# _:s14_role1 schema:startDate "1931"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidiwtbpoftdf65m6c6xuic6w33zgrj4evxutl6pfmrptfb7amu25a",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidiwtbpoftdf65m6c6xuic6w33zgrj4evxutl6pfmrptfb7amu25a",
#   "prov:label": "rdf:44_14",
#   "_cell": 1331,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid3hylo77mkrz5s2lfldoit247twhuxkvbfm7x5bu7nkhn5oomxny"
#   },
#   "_stmt_key": "44_14",
#   "_chunk_num": 44,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [44.15]: The claim that Einstein referred to the cosmological constant as his "biggest blunder" is based on a letter [George Gamow](/wiki/George_Gamow) claimed to have received from him.
# <https://en.wikipedia.org/wiki/George_Gamow> schema:achievement _:s15_role1 .
# _:s15_role1 rdf:type schema:Role .
# _:s15_role1 schema:startDate "1931"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreih362iwo3unevayjjimmkurppa2ys2zgy3vrusbdgi5mivg7lvyv4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreih362iwo3unevayjjimmkurppa2ys2zgy3vrusbdgi5mivg7lvyv4",
#   "prov:label": "rdf:44_15",
#   "_cell": 1333,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigl3c4j472d3r7ohny3fantld2eu426ckjyad6bvs6727g23nr55y"
#   },
#   "_stmt_key": "44_15",
#   "_chunk_num": 44,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [44.16]: The astrophysicist [Mario Livio](/wiki/Mario_Livio) has cast doubt on the claim about Einstein's "biggest blunder".
# <https://en.wikipedia.org/wiki/Mario_Livio> schema:achievement _:s16_role1 .
# _:s16_role1 rdf:type schema:Role .
# _:s16_role1 schema:startDate "1931"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihifwhedqhtwvvgkihvravshpxczcjmyvhlmghioflkfxcrnovzii",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihifwhedqhtwvvgkihvravshpxczcjmyvhlmghioflkfxcrnovzii",
#   "prov:label": "rdf:44_16",
#   "_cell": 1335,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiecdorivpdyp23vxorndasqvdipk4vfh5qozbxsscx3rw24ozpjsq"
#   },
#   "_stmt_key": "44_16",
#   "_chunk_num": 44,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [45.1]: In late 2013, a team led by the Irish physicist [Cormac O'Raifeartaigh](/wiki/Cormac_O%27Raifeartaigh) discovered evidence that Einstein considered a [steady-state model](/wiki/steady-state_model) of the universe shortly after learning of Hubble's observations.
# _:s1_quote1 rdf:type schema:Quotation .
# _:s1_quote1 schema:text "In what follows, I would like to draw attention to a solution to equation (1) that can account for Hubbel's facts, and in which the density is constant over time [...] If one considers a physically bounded volume, particles of matter will be continually leaving it. For the density to remain constant, new particles of matter must be continually formed in the volume from space." .
# _:s1_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigplbhvwnukihqythhamo27ub6iao5fissovsqiucaii67woo5cbm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigplbhvwnukihqythhamo27ub6iao5fissovsqiucaii67woo5cbm",
#   "prov:label": "rdf:45_1",
#   "_cell": 1337,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigokj7auzfckqr5t333cnsupvhyg3nqsp2b4stdgdkjrv4ajwis5a"
#   },
#   "_stmt_key": "45_1",
#   "_chunk_num": 45,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [45.2]: In a hitherto overlooked manuscript apparently written in early 1931, [Albert Einstein](/wiki/Albert_Einstein) explored a model of the expanding universe in which the density of matter remains constant due to a continuous creation of matter.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author _:s2_model1 .
# _:s2_model1 rdf:type schema:Thing .
# _:s2_model1 schema:name "Steady-state model" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibv3gdghqlxkb5qzvah6vurredbmkg56hl7grzkwi6twazcl4eg74",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibv3gdghqlxkb5qzvah6vurredbmkg56hl7grzkwi6twazcl4eg74",
#   "prov:label": "rdf:45_2",
#   "_cell": 1339,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiacbbtsyays3qwhnerw5v3ybftfpvga4245teczpmp55rmdtelg4i"
#   },
#   "_stmt_key": "45_2",
#   "_chunk_num": 45,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [45.3]: In the model explored by [Albert Einstein](/wiki/Albert_Einstein), the process of matter creation was associated with the cosmological constant.
# _:s3_model1 rdf:type schema:Thing .
# _:s3_model1 schema:name "Steady-state model" .
# _:s3_model1 schema:about <https://en.wikipedia.org/wiki/Cosmological_constant> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigox4z3slthrgf6x6txhuwwivvukmvg7rf564xb7p5qfbrqpkfoqy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigox4z3slthrgf6x6txhuwwivvukmvg7rf564xb7p5qfbrqpkfoqy",
#   "prov:label": "rdf:45_3",
#   "_cell": 1341,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibntphlkqk3k72qwkntntiuf4du4zu7zuxv2wwh27dnxpwtomabqq"
#   },
#   "_stmt_key": "45_3",
#   "_chunk_num": 45,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [45.4]: As stated in the paper, [Albert Einstein](/wiki/Albert_Einstein) said: "In what follows, I would like to draw attention to a solution to equation (1) that can account for Hubbel's facts, and in which the density is constant over time [...] If one considers a physically bounded volume, particles of matter will be continually leaving it. For the density to remain constant, new particles of matter must be continually formed in the volume from space."
# _:s4_quote1 rdf:type schema:Quotation .
# _:s4_quote1 schema:text "In what follows, I would like to draw attention to a solution to equation (1) that can account for Hubbel's facts, and in which the density is constant over time [...] If one considers a physically bounded volume, particles of matter will be continually leaving it. For the density to remain constant, new particles of matter must be continually formed in the volume from space." .
# _:s4_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaexdicane7rvmbyavgdhznc3c6nn3iik246y2y77j6utjziigqci",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaexdicane7rvmbyavgdhznc3c6nn3iik246y2y77j6utjziigqci",
#   "prov:label": "rdf:45_4",
#   "_cell": 1343,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigpjqlay2wtg4qui3h2kexp7slqzpokssaupq6aeug5hdavyaqqai"
#   },
#   "_stmt_key": "45_4",
#   "_chunk_num": 45,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [45.5]: It thus appears that [Albert Einstein](/wiki/Albert_Einstein) considered a [steady-state model](/wiki/steady-state_model) of the expanding universe many years before [Fred Hoyle](/wiki/Fred_Hoyle), [Thomas Gold](/wiki/Thomas_Gold_\(astrophysicist\)), and [Herbert Robertson](/wiki/Herbert_Robertson_\(astrophysicist\)).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:about _:s5_model1 .
# _:s5_model1 rdf:type schema:Thing .
# _:s5_model1 schema:name "Steady-state model" .
# _:s5_model1 schema:additionalType <https://en.wikipedia.org/wiki/Steady-state_model> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiax4eekuqwv44ubvy6dfadoqix3thxjbh5ydp6kec3m4ldp5cmgcu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiax4eekuqwv44ubvy6dfadoqix3thxjbh5ydp6kec3m4ldp5cmgcu",
#   "prov:label": "rdf:45_5",
#   "_cell": 1345,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidfmfc6eu32imkpkrybn5ggrtq4b5y2oiiyz6atmm2qh2erma6yb4"
#   },
#   "_stmt_key": "45_5",
#   "_chunk_num": 45,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [45.6]: However, [Albert Einstein](/wiki/Albert_Einstein)'s steady-state model contained a fundamental flaw and he quickly abandoned the idea.
# # No triples emitted for this statement
# # Debug: 21 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_quote1", "predicate": "rdf:type", "object_value": "schema:Quotation"}
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_quote1", "predicate": "schema:text", "object_value": "\"In what follows, I would like to draw attention to a solution to equation (1) that can account for Hubbel's
# #   emit_triple: {"statement_id": 1, "subject": "_:s1_quote1", "predicate": "schema:creator", "object_value": "<https://en.wikipedia.org/wiki/Albert_Einstein>"}
# #   emit_triple: {"statement_id": 4, "subject": "_:s4_quote1", "predicate": "rdf:type", "object_value": "schema:Quotation"}
# #   emit_triple: {"statement_id": 4, "subject": "_:s4_quote1", "predicate": "schema:text", "object_value": "\"In what follows, I would like to draw attention to a solution to equation (1) that can account for Hubbel's

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigzn2tza3tzhzyqrzcudm522rl5ocrpywltvsszexr7m6e7b7btwq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigzn2tza3tzhzyqrzcudm522rl5ocrpywltvsszexr7m6e7b7btwq",
#   "prov:label": "rdf:45_6",
#   "_cell": 1347,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicweirpvbqfkj72zdcluptez6yzbvvss7ql2pkotnx564aeji5lwq"
#   },
#   "_stmt_key": "45_6",
#   "_chunk_num": 45,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [45.7]: General relativity includes a dynamical spacetime, so it is difficult to see how to identify the conserved energy and momentum.
# schema:General_relativity rdf:type schema:Thing .
# schema:General_relativity schema:description Includes a dynamical spacetime, so it is difficult to see how to identify the conserved energy and momentum .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiarhbt5pun5wopagqxp7lkd3zjdoxcovdjlxx7f7njndqasmajvv4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiarhbt5pun5wopagqxp7lkd3zjdoxcovdjlxx7f7njndqasmajvv4",
#   "prov:label": "rdf:45_7",
#   "_cell": 1349,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibrtwaxefijls7tyup6ypy3prwvstjvgtvvhao7ath4nqjjt6rgbm"
#   },
#   "_stmt_key": "45_7",
#   "_chunk_num": 45,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [45.8]: [Noether's theorem](/wiki/Noether%27s_theorem) allows these quantities to be determined from a [Lagrangian](/wiki/Lagrangian_%28field_theory%29) with [translation invariance](/wiki/translation_invariance).
# schema:Noether%27s_theorem rdf:type schema:Thing .
# schema:Noether%27s_theorem schema:description Allows these quantities to be determined from a Lagrangian with translation invariance .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibea6iozllgx2e2cmga35ckwgacyvpiwtbgs6qwkeggsctbxdjd5i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibea6iozllgx2e2cmga35ckwgacyvpiwtbgs6qwkeggsctbxdjd5i",
#   "prov:label": "rdf:45_8",
#   "_cell": 1351,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiho5v6zwcbyjivdavqsnz2pjd5wnie4lsyrwhjjbgtxzyaptrmtv4"
#   },
#   "_stmt_key": "45_8",
#   "_chunk_num": 45,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [45.9]: [General covariance](/wiki/general_covariance) makes translation invariance into something of a [gauge symmetry](/wiki/gauge_symmetry).
# <https://en.wikipedia.org/wiki/General_covariance> rdf:type schema:Thing .
# <https://en.wikipedia.org/wiki/General_covariance> schema:description Makes translation invariance into something of a gauge symmetry .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihusfrrym77urrqswnnyiyy4c6rjvylwovdijge6wmb6ro5gfvw5y",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihusfrrym77urrqswnnyiyy4c6rjvylwovdijge6wmb6ro5gfvw5y",
#   "prov:label": "rdf:45_9",
#   "_cell": 1353,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreignhbvgfnnch5lfpqqxzkx2m2oao6j3yt6jbkjctrsngn63uw7b4y"
#   },
#   "_stmt_key": "45_9",
#   "_chunk_num": 45,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [45.10]: The energy and momentum derived within general relativity by [Noether](/wiki/Emmy_Noether)'s prescriptions do not make a real tensor for this reason.
# <https://en.wikipedia.org/wiki/Emmy_Noether> schema:about <https://en.wikipedia.org/wiki/Noether%27s_theorem> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreid5efn7mi6o5fka7hihcrnms5cioe2rsbd7nz3aakq5stmfldbbte",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreid5efn7mi6o5fka7hihcrnms5cioe2rsbd7nz3aakq5stmfldbbte",
#   "prov:label": "rdf:45_10",
#   "_cell": 1355,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiegigpuwd64wckbdn7x54r2dj452y2zyeqcmgrs44gl6jrrcd3fsi"
#   },
#   "_stmt_key": "45_10",
#   "_chunk_num": 45,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [46.1]: [Albert Einstein](/wiki/Albert_Einstein) argued that gravitational fields could be made to vanish by a choice of coordinates.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:potentialUse <"gravitational fields could be made to vanish by a choice of coordinates"> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihj6q7yzdtxlxwc2top2zlsw3by4g4wcomvi56kld3z6urafjkdjm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihj6q7yzdtxlxwc2top2zlsw3by4g4wcomvi56kld3z6urafjkdjm",
#   "prov:label": "rdf:46_1",
#   "_cell": 1357,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicd26n2otnwgtowy32setux5a5zuyhxetuzzeleqszybopozvrsvm"
#   },
#   "_stmt_key": "46_1",
#   "_chunk_num": 46,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [46.2]: [Albert Einstein](/wiki/Albert_Einstein) maintained that the non-covariant energy momentum pseudotensor was the best description of the energy momentum distribution in a gravitational field.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:potentialUse <"non-covariant energy momentum pseudotensor was the best description of the energy momentum distribution in a gravitational field"> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicvomvv4voteiqqjtzyama32jnr5mta5insa34l6vzl25anwpepbu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicvomvv4voteiqqjtzyama32jnr5mta5insa34l6vzl25anwpepbu",
#   "prov:label": "rdf:46_2",
#   "_cell": 1359,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih3ximjeahjh2lhpx6rsmpkjhw5accsicf3y444glfd462obr6boi"
#   },
#   "_stmt_key": "46_2",
#   "_chunk_num": 46,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [46.3]: [Erwin Schrödinger](/wiki/Erwin_Schr%C3%B6dinger) criticized the use of non-covariant objects like pseudotensors.
# <https://en.wikipedia.org/wiki/Erwin_Schr%C3%B6dinger> schema:potentialUse <"use of non-covariant objects like pseudotensors"> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieq7zg6zohdryaf4hdi3vdjkgxcpmum5rpdqfkyyk2gk7j3pqe5dy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieq7zg6zohdryaf4hdi3vdjkgxcpmum5rpdqfkyyk2gk7j3pqe5dy",
#   "prov:label": "rdf:46_3",
#   "_cell": 1361,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidwosx36dixfvi47qhqccaoraivkg6gutahofeftv4qphwaonmfym"
#   },
#   "_stmt_key": "46_3",
#   "_chunk_num": 46,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [46.4]: [Lev Landau](/wiki/Lev_Landau) echoed [Einstein's](/wiki/Albert_Einstein) approach to pseudotensors.
# <https://en.wikipedia.org/wiki/Lev_Landau> schema:potentialUse <"Einstein's approach to pseudotensors"> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiee4wkvupan6tfzffhsaiwjix67hqu5e56bqtre56362dovqibuli",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiee4wkvupan6tfzffhsaiwjix67hqu5e56bqtre56362dovqibuli",
#   "prov:label": "rdf:46_4",
#   "_cell": 1363,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibedtwqd5g6zv7ph6xdwnq4afi3c7jodstcw66ox7z3lqc25ue7ji"
#   },
#   "_stmt_key": "46_4",
#   "_chunk_num": 46,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [46.5]: [Evgeny Lifshitz](/wiki/Evgeny_Lifshitz) echoed [Einstein's](/wiki/Albert_Einstein) approach to pseudotensors.
# <https://en.wikipedia.org/wiki/Evgeny_Lifshitz> schema:potentialUse <"Einstein's approach to pseudotensors"> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifbpjrihh22kk6vm35c2cj7g5hrgurqkfqgt6qhngc4wfhao2q43m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifbpjrihh22kk6vm35c2cj7g5hrgurqkfqgt6qhngc4wfhao2q43m",
#   "prov:label": "rdf:46_5",
#   "_cell": 1365,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiapa4zs3capdbp2eqaa4jbksve3muczte327fgrdb3pd64b3qvyym"
#   },
#   "_stmt_key": "46_5",
#   "_chunk_num": 46,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [46.6]: In 1935, [Albert Einstein](/wiki/Albert_Einstein) collaborated with [Nathan Rosen](/wiki/Nathan_Rosen) to produce a model of a [wormhole](/wiki/wormhole).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:participant <https://en.wikipedia.org/wiki/Nathan_Rosen> .
# <https://en.wikipedia.org/wiki/Nathan_Rosen> schema:participant <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreignozs47lomnyqzm3wri2uk5tl6rn4xs7loqk2vx5exz5bxpytx7a",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreignozs47lomnyqzm3wri2uk5tl6rn4xs7loqk2vx5exz5bxpytx7a",
#   "prov:label": "rdf:46_6",
#   "_cell": 1367,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib7ycp5si3ms6b45jkpzdbxoz2wzdf4f6w3dmjqptllflb4stpqmi"
#   },
#   "_stmt_key": "46_6",
#   "_chunk_num": 46,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [46.7]: The [wormhole](/wiki/wormhole) model developed by [Einstein](/wiki/Albert_Einstein) and [Nathan Rosen](/wiki/Nathan_Rosen) is often called [Einstein–Rosen bridges](/wiki/Einstein%E2%80%93Rosen_bridges).
# <https://en.wikipedia.org/wiki/Einstein%E2%80%93Rosen_bridges> schema:relatedTo <https://en.wikipedia.org/wiki/wormhole> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicelj4cftpymlxrvpsge76uqeshkkmf5sryafgyufh2t3evflmmp4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicelj4cftpymlxrvpsge76uqeshkkmf5sryafgyufh2t3evflmmp4",
#   "prov:label": "rdf:46_7",
#   "_cell": 1369,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicn3wxa6esxbg76c7q6nztrpcuks5jjspz22bojolnojbppe6diwu"
#   },
#   "_stmt_key": "46_7",
#   "_chunk_num": 46,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [46.8]: [Einstein–Rosen bridges](/wiki/Einstein%E2%80%93Rosen_bridges) were intended to model elementary particles with charge as a solution of gravitational field equations.
# <https://en.wikipedia.org/wiki/Einstein%E2%80%93Rosen_bridges> schema:potentialUse <"model elementary particles with charge as a solution of gravitational field equations"> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreib2ryxopv6mawvxtpwaiy6mwo3hbd22vomspd5mf4ryazxc5jiqou",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreib2ryxopv6mawvxtpwaiy6mwo3hbd22vomspd5mf4ryazxc5jiqou",
#   "prov:label": "rdf:46_8",
#   "_cell": 1371,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibc7tylqn47trlwqw2vpn35az5rm4vcve47wbio5iutcovjw2jlsm"
#   },
#   "_stmt_key": "46_8",
#   "_chunk_num": 46,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [46.9]: The motivation for [Einstein–Rosen bridges](/wiki/Einstein%E2%80%93Rosen_bridges) was based on the paper "Do Gravitational Fields play an Important Role in the Constitution of the Elementary Particles?".
# <https://en.wikipedia.org/wiki/Einstein%E2%80%93Rosen_bridges> schema:citation <"Do Gravitational Fields play an Important Role in the Constitution of the Elementary Particles?"> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicbdhh5xrwylmnajztjusc4gmhgzw3pp45g5jbhmrsrbn4r4zvviy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicbdhh5xrwylmnajztjusc4gmhgzw3pp45g5jbhmrsrbn4r4zvviy",
#   "prov:label": "rdf:46_9",
#   "_cell": 1373,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigaqbevaxpddpi3a6xziwmxxexledxhwxunj3cmwjv5ejtclm7iuy"
#   },
#   "_stmt_key": "46_9",
#   "_chunk_num": 46,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [46.10]: [Einstein–Rosen bridges](/wiki/Einstein%E2%80%93Rosen_bridges) were constructed by cutting and pasting [Schwarzschild black hole](/wiki/Schwarzschild_black_hole)s to make a bridge between two patches.
# <https://en.wikipedia.org/wiki/Einstein%E2%80%93Rosen_bridges> schema:potentialUse <"constructed by cutting and pasting Schwarzschild black holes to make a bridge between two patches"> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigmfk4qraphuveipk4rbeff2qynhpb5xvorl2btdq4ovapz5hiaqe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigmfk4qraphuveipk4rbeff2qynhpb5xvorl2btdq4ovapz5hiaqe",
#   "prov:label": "rdf:46_10",
#   "_cell": 1375,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifn5dwxvrszjz7q5z5xamns2j4mlv4vte527tofyjycildjd6cnbu"
#   },
#   "_stmt_key": "46_10",
#   "_chunk_num": 46,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [46.11]: [Einstein](/wiki/Albert_Einstein) and [Nathan Rosen](/wiki/Nathan_Rosen) suggested that [Einstein–Rosen bridges](/wiki/Einstein%E2%80%93Rosen_bridges) could provide the beginnings of a theory avoiding point particles.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:potentialUse <"Einstein–Rosen bridges could provide the beginnings of a theory avoiding point particles"> .
# <https://en.wikipedia.org/wiki/Nathan_Rosen> schema:potentialUse <"Einstein–Rosen bridges could provide the beginnings of a theory avoiding point particles"> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigmdnxnxwppqo5m6rlxwto3fju5f7vi46q523atxay3a4qvx7ptgq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigmdnxnxwppqo5m6rlxwto3fju5f7vi46q523atxay3a4qvx7ptgq",
#   "prov:label": "rdf:46_11",
#   "_cell": 1377,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicir234siozzmgrwcu5s767c42hrvmu3n7mqbvr3nedbgwgr2vwxa"
#   },
#   "_stmt_key": "46_11",
#   "_chunk_num": 46,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [46.12]: [Einstein–Rosen bridges](/wiki/Einstein%E2%80%93Rosen_bridges) were later found to be unstable.
# <https://en.wikipedia.org/wiki/Einstein%E2%80%93Rosen_bridges> schema:potentialUse <"were later found to be unstable"> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiczdfrglgeyudyz5ic55xg5mvngno5dtrac4afksrbipfiqothwsu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiczdfrglgeyudyz5ic55xg5mvngno5dtrac4afksrbipfiqothwsu",
#   "prov:label": "rdf:46_12",
#   "_cell": 1379,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidi3orkltq3mclu5o3dyvkw7fg3fmpfe27nclkh3yfbr3q4cqumr4"
#   },
#   "_stmt_key": "46_12",
#   "_chunk_num": 46,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [46.13]: To incorporate spinning point particles into general relativity, the affine connection needed to include an antisymmetric part called [torsion](/wiki/Torsion_tensor).
# <https://en.wikipedia.org/wiki/Torsion_tensor> schema:potentialUse <"needed to incorporate spinning point particles into general relativity"> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihiscl6wtmu5lggiyk35j2fzl6fh56puh3d47txqxyokrohsn7zli",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihiscl6wtmu5lggiyk35j2fzl6fh56puh3d47txqxyokrohsn7zli",
#   "prov:label": "rdf:46_13",
#   "_cell": 1381,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibugtuewp6xpfewdfndo6wlymjv46dscqrfi435oyai66cbo4h644"
#   },
#   "_stmt_key": "46_13",
#   "_chunk_num": 46,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [46.14]: The modification including [torsion](/wiki/Torsion_tensor) was made by [Einstein](/wiki/Albert_Einstein) and [Cartan](/wiki/Elie_Cartan) in the 1920s.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:participant <https://en.wikipedia.org/wiki/Elie_Cartan> .
# <https://en.wikipedia.org/wiki/Elie_Cartan> schema:participant <https://en.wikipedia.org/wiki/Albert_Einstein> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:potentialUse <"modification including torsion was made in the 1920s"> .
# <https://en.wikipedia.org/wiki/Elie_Cartan> schema:potentialUse <"modification including torsion was made in the 1920s"> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigoscer5d63fy7elcshofadct2ae4trfphghh5r3bh2t5xllabsu4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigoscer5d63fy7elcshofadct2ae4trfphghh5r3bh2t5xllabsu4",
#   "prov:label": "rdf:46_14",
#   "_cell": 1383,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihcfozk2uyfulqp4nzbauaiyyhbhysfyqo5tbrnwcehu4ucnqjoh4"
#   },
#   "_stmt_key": "46_14",
#   "_chunk_num": 46,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [47.1]: In general relativity, gravitational force is reimagined as curvature of [spacetime](/wiki/spacetime).
# <https://en.wikipedia.org/wiki/General_relativity> rdf:type schema:ScientificTheory .
# <https://en.wikipedia.org/wiki/General_relativity> schema:description "Gravitational force is reimagined as curvature of spacetime" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiccpjjpkc2h63lzxvujnsk4e6flep7csiscfrlwxcodkhvvw6f5ri",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiccpjjpkc2h63lzxvujnsk4e6flep7csiscfrlwxcodkhvvw6f5ri",
#   "prov:label": "rdf:47_1",
#   "_cell": 1385,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibrmegtgdts4bwqezkikyzfjjebvmdkylrvfkjn3ltiued6457iby"
#   },
#   "_stmt_key": "47_1",
#   "_chunk_num": 47,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [47.2]: A curved path like an orbit is not the result of a force deflecting a body from an ideal straight-line path.
# # No triples emitted for this statement
# # Debug: 19 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/General_relativity>", "predicate": "rdf:type", "object_value": "schema:ScientificTheory"}
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/General_relativity>", "predicate": "schema:description", "object_value": "\"Gravitational force is reimagined as curvature of spacetime\"
# #   emit_triple: {"statement_id": 5, "subject": "<https://en.wikipedia.org/wiki/Einstein_field_equations>", "predicate": "rdf:type", "object_value": "schema:MathematicalEquation"}
# #   emit_triple: {"statement_id": 5, "subject": "<https://en.wikipedia.org/wiki/Einstein_field_equations>", "predicate": "schema:description", "object_value": "\"Relates the curvature of spacetime to the distribution
# #   emit_triple: {"statement_id": 6, "subject": "<https://en.wikipedia.org/wiki/geodesic_equation>", "predicate": "rdf:type", "object_value": "schema:MathematicalEquation"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihzc6cxl3ywjbf5y3twgxmyylkoxc6ub7bjcqkwkxez4x66indkre",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihzc6cxl3ywjbf5y3twgxmyylkoxc6ub7bjcqkwkxez4x66indkre",
#   "prov:label": "rdf:47_2",
#   "_cell": 1387,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihx44c2gxbyb3jnmtb2guvr6hydcqeutpq6ts4hmhlz3wh4wbryje"
#   },
#   "_stmt_key": "47_2",
#   "_chunk_num": 47,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [47.3]: A curved path like an orbit is the body's attempt to fall freely through a background that is itself curved by the presence of other masses.
# # No triples emitted for this statement
# # Debug: 19 emit tool calls made for chunk
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/General_relativity>", "predicate": "rdf:type", "object_value": "schema:ScientificTheory"}
# #   emit_triple: {"statement_id": 1, "subject": "<https://en.wikipedia.org/wiki/General_relativity>", "predicate": "schema:description", "object_value": "\"Gravitational force is reimagined as curvature of spacetime\"
# #   emit_triple: {"statement_id": 5, "subject": "<https://en.wikipedia.org/wiki/Einstein_field_equations>", "predicate": "rdf:type", "object_value": "schema:MathematicalEquation"}
# #   emit_triple: {"statement_id": 5, "subject": "<https://en.wikipedia.org/wiki/Einstein_field_equations>", "predicate": "schema:description", "object_value": "\"Relates the curvature of spacetime to the distribution
# #   emit_triple: {"statement_id": 6, "subject": "<https://en.wikipedia.org/wiki/geodesic_equation>", "predicate": "rdf:type", "object_value": "schema:MathematicalEquation"}

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibsue45yrovhqxvvo64xqp2fpoklwxqvlyofnp7hsva6clzd5m4rm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibsue45yrovhqxvvo64xqp2fpoklwxqvlyofnp7hsva6clzd5m4rm",
#   "prov:label": "rdf:47_3",
#   "_cell": 1389,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreig72lgwqzi37doasv6ts6vpv2alilqsftfjovgzjlfcgdpj6m2inm"
#   },
#   "_stmt_key": "47_3",
#   "_chunk_num": 47,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [47.4]: [John Archibald Wheeler](/wiki/John_Archibald_Wheeler) stated that "Spacetime tells matter how to move; matter tells spacetime how to curve."
# _:s4_quote1 rdf:type schema:Quotation .
# _:s4_quote1 schema:text "Spacetime tells matter how to move; matter tells spacetime how to curve." .
# _:s4_quote1 schema:creator <https://en.wikipedia.org/wiki/John_Archibald_Wheeler> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreif6vu2iua6yz5tfdq2cy526ded2z6o6rubhgmmwoqe7pnwmd7kc2i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreif6vu2iua6yz5tfdq2cy526ded2z6o6rubhgmmwoqe7pnwmd7kc2i",
#   "prov:label": "rdf:47_4",
#   "_cell": 1391,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihicjiwaupq7klpll2rdtjpkmzkunwrvyrwie65w5zlqfsnajajhu"
#   },
#   "_stmt_key": "47_4",
#   "_chunk_num": 47,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [47.5]: The [Einstein field equations](/wiki/Einstein_field_equations) relate the curvature of spacetime to the distribution of matter and energy.
# <https://en.wikipedia.org/wiki/Einstein_field_equations> rdf:type schema:MathematicalEquation .
# <https://en.wikipedia.org/wiki/Einstein_field_equations> schema:description "Relates the curvature of spacetime to the distribution of matter and energy" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifqsupezoq5lmhv3jeb2e3s7chvjoim4mr7atpo2pfavpsesnr5ii",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifqsupezoq5lmhv3jeb2e3s7chvjoim4mr7atpo2pfavpsesnr5ii",
#   "prov:label": "rdf:47_5",
#   "_cell": 1393,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiftlx5wee57jv3xg6mk7zlrlthxk6ulg4ltudaztrpaqwbavgbkk4"
#   },
#   "_stmt_key": "47_5",
#   "_chunk_num": 47,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [47.6]: The [geodesic equation](/wiki/geodesic_equation) states that freely falling bodies follow lines that are as straight as possible in a curved spacetime.
# <https://en.wikipedia.org/wiki/geodesic_equation> rdf:type schema:MathematicalEquation .
# <https://en.wikipedia.org/wiki/geodesic_equation> schema:description "States that freely falling bodies follow lines that are as straight as possible in a curved spacetime" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiffhavx2ckwqbsdjedrgycij6kwfefuvhfvrc33e66abnckref7v4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiffhavx2ckwqbsdjedrgycij6kwfefuvhfvrc33e66abnckref7v4",
#   "prov:label": "rdf:47_6",
#   "_cell": 1395,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid6wgomd2qzobzrqwifeyp6brk75jmc2stykxkb3ytgcq7yvtklc4"
#   },
#   "_stmt_key": "47_6",
#   "_chunk_num": 47,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [47.7]: Einstein regarded the geodesic equation as an "independent fundamental assumption" that had to be postulated in addition to the field equations.
# <https://en.wikipedia.org/wiki/General_relativity> schema:description "Einstein regarded the geodesic equation as an 'independent fundamental assumption' that had to be postulated in addition to the field equations" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiez7d7wvrvxdulu7u5nz6tgc7aizdw2ocff4rb663fkyskm6djoby",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiez7d7wvrvxdulu7u5nz6tgc7aizdw2ocff4rb663fkyskm6djoby",
#   "prov:label": "rdf:47_7",
#   "_cell": 1397,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiexziue5giif54knt6r6k62pz7ogv2qkarxz66vbr3stfva777l2a"
#   },
#   "_stmt_key": "47_7",
#   "_chunk_num": 47,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [47.8]: Einstein wished to derive the geodesic equation from the field equations themselves.
# <https://en.wikipedia.org/wiki/General_relativity> schema:description "Einstein wished to derive the geodesic equation from the field equations themselves" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidrmjif4bshc23jph5wdqemtlraou53z4aasuogpsqulctjpgqmre",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidrmjif4bshc23jph5wdqemtlraou53z4aasuogpsqulctjpgqmre",
#   "prov:label": "rdf:47_8",
#   "_cell": 1399,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicavo7sjgb4mmuntdmfqcsiucpg24377tnbwyrajlrai2cwaxckou"
#   },
#   "_stmt_key": "47_8",
#   "_chunk_num": 47,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [47.9]: The equations of general relativity are non-linear.
# <https://en.wikipedia.org/wiki/General_relativity> schema:description "The equations of general relativity are non-linear" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicyui2qjbfyqoiqwwhx6unpxpgyv2ymr2lgfuy63g2rwd5xeaam7u",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicyui2qjbfyqoiqwwhx6unpxpgyv2ymr2lgfuy63g2rwd5xeaam7u",
#   "prov:label": "rdf:47_9",
#   "_cell": 1401,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaeruqteuioyy24w2y44s4gcyrmmqpb6pvp4lnww3c733ftrltdby"
#   },
#   "_stmt_key": "47_9",
#   "_chunk_num": 47,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [47.10]: A lump of energy made out of pure gravitational fields, like a black hole, would move on a trajectory determined by the Einstein field equations themselves.
# <https://en.wikipedia.org/wiki/General_relativity> schema:description "A lump of energy made out of pure gravitational fields, like a black hole, would move on a trajectory determined by the Einstein field equations themselves" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic2fcrn3c2tesxaaocafvvausae4hvpuh6ejcixr3w3aaud2uvgkm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic2fcrn3c2tesxaaocafvvausae4hvpuh6ejcixr3w3aaud2uvgkm",
#   "prov:label": "rdf:47_10",
#   "_cell": 1403,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicbyd3sspv7mzboxq5wcnnfhajuohnwcza3ioczgjlihxm6ek32c4"
#   },
#   "_stmt_key": "47_10",
#   "_chunk_num": 47,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [47.11]: Einstein proposed that the field equations would determine the path of a singular solution, like a black hole, to be a geodesic.
# <https://en.wikipedia.org/wiki/General_relativity> schema:description "Einstein proposed that the field equations would determine the path of a singular solution, like a black hole, to be a geodesic" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic2xcbehy4parsorxvfbkdsksvnl2g3xnoqp4lgmjnsq4urhadxim",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic2xcbehy4parsorxvfbkdsksvnl2g3xnoqp4lgmjnsq4urhadxim",
#   "prov:label": "rdf:47_11",
#   "_cell": 1405,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidtgvna6rytbw56ktec23e7jv2pcgkuwnm2ep5nzx2arr3ft7nzzu"
#   },
#   "_stmt_key": "47_11",
#   "_chunk_num": 47,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [47.12]: The geodesic equation can be obtained from applying the field equations to the motion of a [gravitational singularity](/wiki/gravitational_singularity).
# <https://en.wikipedia.org/wiki/General_relativity> schema:description "The geodesic equation can be obtained from applying the field equations to the motion of a gravitational singularity" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibmde23hmmi4kf3q4pttjnid5kdl4ltqzwlrxwupwbv3u2j6a5wdu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibmde23hmmi4kf3q4pttjnid5kdl4ltqzwlrxwupwbv3u2j6a5wdu",
#   "prov:label": "rdf:47_12",
#   "_cell": 1407,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifxfdm7de3bbe3yeu7mwex6uqwl2ptvpv6wkzjbcfk5aucbfzy6qm"
#   },
#   "_stmt_key": "47_12",
#   "_chunk_num": 47,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [47.13]: This claim that the geodesic equation can be derived from the field equations remains disputed among physicists and philosophers.
# <https://en.wikipedia.org/wiki/General_relativity> schema:description "This claim that the geodesic equation can be derived from the field equations remains disputed among physicists and philosophers" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieqcylbgimpn6fdd2qclpcgoe6d4fys6bic4pskv56wgxbkgii7k4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieqcylbgimpn6fdd2qclpcgoe6d4fys6bic4pskv56wgxbkgii7k4",
#   "prov:label": "rdf:47_13",
#   "_cell": 1409,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreighdchbyhxmnh6mgqz47moxnflwomkezjb6v2rwzz4gn4d6pdz7ci"
#   },
#   "_stmt_key": "47_13",
#   "_chunk_num": 47,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [48.1]: In a 1905 paper, [Albert Einstein](/wiki/Albert_Einstein) postulated that light itself consists of localized particles (*[quanta](/wiki/quantum)*).
# _:s1_quote1 rdf:type schema:Quotation .
# _:s1_quote1 schema:text "light itself consists of localized particles (*quantum*)" .
# _:s1_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s1_quote1 schema:datePublished "1905"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidtbe6xf4xomwbt6ne7gkmvaclifi5jr5tmovve6sdbn63qzzqv3i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidtbe6xf4xomwbt6ne7gkmvaclifi5jr5tmovve6sdbn63qzzqv3i",
#   "prov:label": "rdf:48_1",
#   "_cell": 1411,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibhf5tb4spw4v762oyvjda3xn7gjwwuxibnwl3umzc773vqyoy4w4"
#   },
#   "_stmt_key": "48_1",
#   "_chunk_num": 48,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [48.2]: [Albert Einstein](/wiki/Albert_Einstein)'s light quanta were nearly universally rejected by all physicists, including [Max Planck](/wiki/Max_Planck) and [Niels Bohr](/wiki/Niels_Bohr).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:disambiguatingDescription "Light quanta were nearly universally rejected by all physicists, including Max Planck and Niels Bohr" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreierijk2xw4y3ut27goxgbcdb4ijneb344jfe6t52j3rrrkohmt7qy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreierijk2xw4y3ut27goxgbcdb4ijneb344jfe6t52j3rrrkohmt7qy",
#   "prov:label": "rdf:48_2",
#   "_cell": 1413,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifuww77i2entqzjkvpd4zue7npgnerw5g4nebnrib7l4jnbbi2dwq"
#   },
#   "_stmt_key": "48_2",
#   "_chunk_num": 48,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [48.3]: This idea only became universally accepted in 1919.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:disambiguatingDescription "This idea only became universally accepted in 1919" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreih7ns6otooa2mwyu4ep7zz43easutz37rp2am5gqxh672dqlymhp4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreih7ns6otooa2mwyu4ep7zz43easutz37rp2am5gqxh672dqlymhp4",
#   "prov:label": "rdf:48_3",
#   "_cell": 1415,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigqclv4qffd6lxenoem2ktty7if6rmaagxhaqfeu5k4mte4urbhze"
#   },
#   "_stmt_key": "48_3",
#   "_chunk_num": 48,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [48.4]: [Robert Millikan](/wiki/Robert_Millikan)'s detailed experiments on the [photoelectric effect](/wiki/photoelectric_effect) helped establish the acceptance of light quanta.
# <https://en.wikipedia.org/wiki/Robert_Millikan> schema:disambiguatingDescription "detailed experiments on the photoelectric effect helped establish the acceptance of light quanta" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic4wtrumapaf2c43qayo4cziggadmnoi7kbtu2kygmeaakypd5gke",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic4wtrumapaf2c43qayo4cziggadmnoi7kbtu2kygmeaakypd5gke",
#   "prov:label": "rdf:48_4",
#   "_cell": 1417,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicmtl6of7b6dezscjersjwfxacm7barikh3fki77wlfdegle3oa6u"
#   },
#   "_stmt_key": "48_4",
#   "_chunk_num": 48,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [48.5]: [Compton scattering](/wiki/Compton_scattering) was measured in 1919, contributing to the acceptance of light quanta.
# <https://en.wikipedia.org/wiki/Compton_scattering> schema:disambiguatingDescription "measured in 1919, contributing to the acceptance of light quanta" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidlt75rnfpjou3ixdfoo6jsjxkrb4myg72y53wc4uasiehyqjtzri",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidlt75rnfpjou3ixdfoo6jsjxkrb4myg72y53wc4uasiehyqjtzri",
#   "prov:label": "rdf:48_5",
#   "_cell": 1419,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigdel73yuzaczugxqd75yhavx3ryg32s3lfy72wg6a6htgvqjcoyi"
#   },
#   "_stmt_key": "48_5",
#   "_chunk_num": 48,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [48.6]: [Albert Einstein](/wiki/Albert_Einstein) concluded that each wave of frequency *f* is associated with a collection of photons with energy *hf* each.
# _:s6_quote1 rdf:type schema:Quotation .
# _:s6_quote1 schema:text "each wave of frequency f is associated with a collection of photons with energy hf each" .
# _:s6_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreib25lbpejza6xqilauzex73cxtkvgb4q6ism5kwgiuna57c4qq56m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreib25lbpejza6xqilauzex73cxtkvgb4q6ism5kwgiuna57c4qq56m",
#   "prov:label": "rdf:48_6",
#   "_cell": 1421,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihragjzou4bulkp5srtyx7l4pei77usirznv5zcdltqqbnpn5pnkq"
#   },
#   "_stmt_key": "48_6",
#   "_chunk_num": 48,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [48.7]: The symbol *h* represents the [Planck constant](/wiki/Planck_constant).
# <https://en.wikipedia.org/wiki/Planck_constant> schema:disambiguatingDescription "The symbol h represents the Planck constant" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreib4bew4lfs75uzgvryzlatfcfzjdgyu6mmmcow4nebk7betzczs5a",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreib4bew4lfs75uzgvryzlatfcfzjdgyu6mmmcow4nebk7betzczs5a",
#   "prov:label": "rdf:48_7",
#   "_cell": 1423,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihglyruqilzslcn7pxxktkzhxq2rwbxidqzmhwweubgk6djde4eo4"
#   },
#   "_stmt_key": "48_7",
#   "_chunk_num": 48,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [48.8]: [Albert Einstein](/wiki/Albert_Einstein) did not say much more about how the particles were related to the wave.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:disambiguatingDescription "did not say much more about how the particles were related to the wave" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreif3vbznahxhn76ro2tgqgb4425wo4n22irzprrtwmp24kvoh7mnri",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreif3vbznahxhn76ro2tgqgb4425wo4n22irzprrtwmp24kvoh7mnri",
#   "prov:label": "rdf:48_8",
#   "_cell": 1425,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidnrdztf7ggxlwpeyiwxgcphwmixq7la6dznmblco44j3eymppdji"
#   },
#   "_stmt_key": "48_8",
#   "_chunk_num": 48,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [48.9]: [Albert Einstein](/wiki/Albert_Einstein) suggested that the idea of light quanta would explain certain experimental results, notably the [photoelectric effect](/wiki/photoelectric_effect).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:disambiguatingDescription "suggested that the idea of light quanta would explain certain experimental results, notably the photoelectric effect" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigtwxx5mwmtsx45bajnezjie34lvspb7ybflys3obhtzzyre7zpai",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigtwxx5mwmtsx45bajnezjie34lvspb7ybflys3obhtzzyre7zpai",
#   "prov:label": "rdf:48_9",
#   "_cell": 1427,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiefccphuw2eeseoewcrlwsuxa4irnkc2sfkx7ir5wy3dws4egwjpy"
#   },
#   "_stmt_key": "48_9",
#   "_chunk_num": 48,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [48.10]: Light quanta were dubbed *[photons](/wiki/photons)* by [Gilbert N. Lewis](/wiki/Gilbert_N._Lewis) in 1926.
# <https://en.wikipedia.org/wiki/Gilbert_N._Lewis> schema:disambiguatingDescription "dubbed light quanta 'photons' in 1926" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreight73j7fifnfvef2es6crm7jm6ddhoztfharxkly2sd3w5n2ociu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreight73j7fifnfvef2es6crm7jm6ddhoztfharxkly2sd3w5n2ociu",
#   "prov:label": "rdf:48_10",
#   "_cell": 1429,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihvglw5mrlmbpemk27n7c4n2grtbdeie6jcxtegfucc6g6apoo4m4"
#   },
#   "_stmt_key": "48_10",
#   "_chunk_num": 48,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [48.11]: In 1907, [Albert Einstein](/wiki/Albert_Einstein) proposed a model of matter where each atom in a lattice structure is an independent harmonic oscillator.
# _:s11_model1 rdf:type schema:Substance .
# _:s11_model1 schema:name "Einstein model" .
# _:s11_model1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s11_model1 schema:datePublished "1907"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibtvz45lekc2tfoega5cpop33ubj5cx72sqqkf4xh6yd6nrz5nnyi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibtvz45lekc2tfoega5cpop33ubj5cx72sqqkf4xh6yd6nrz5nnyi",
#   "prov:label": "rdf:48_11",
#   "_cell": 1431,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieankjyolh2ckjrk5pre42hxa6ydpwjxgwl3p7lafdcqpl62yqtua"
#   },
#   "_stmt_key": "48_11",
#   "_chunk_num": 48,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [48.12]: In the [Einstein model](/wiki/Einstein_solid), each atom oscillates independently.
# _:s12_model1 rdf:type schema:Substance .
# _:s12_model1 schema:disambiguatingDescription "each atom oscillates independently" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiblwzyjpo44equ7jpumki6fywgvtrnqu53g2ngdq2g4e27thabpqe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiblwzyjpo44equ7jpumki6fywgvtrnqu53g2ngdq2g4e27thabpqe",
#   "prov:label": "rdf:48_12",
#   "_cell": 1433,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiewq4urjf3cqujyfi6d7irbp7loez2cofit7gjp7atpxka5ngjwqu"
#   },
#   "_stmt_key": "48_12",
#   "_chunk_num": 48,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [48.13]: The [Einstein model](/wiki/Einstein_solid) involves a series of equally spaced quantized states for each oscillator.
# _:s13_model1 rdf:type schema:Substance .
# _:s13_model1 schema:disambiguatingDescription "involves a series of equally spaced quantized states for each oscillator" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihu6rw7d66pkay6h3beai4iimkrv3pouubc5vh52t2nxx7kjbf56a",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihu6rw7d66pkay6h3beai4iimkrv3pouubc5vh52t2nxx7kjbf56a",
#   "prov:label": "rdf:48_13",
#   "_cell": 1435,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid7mg4i5eagvs47k6halvua3lrstbzkay2k7n5iyrushdzegm6pr4"
#   },
#   "_stmt_key": "48_13",
#   "_chunk_num": 48,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [48.14]: [Albert Einstein](/wiki/Albert_Einstein) was aware that getting the frequency of the actual oscillations would be difficult.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:disambiguatingDescription "was aware that getting the frequency of the actual oscillations would be difficult" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibxxtgr5jwf7dvffejpulhxshibxlka7sqr7z2lepmtycuyy7azyu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibxxtgr5jwf7dvffejpulhxshibxlka7sqr7z2lepmtycuyy7azyu",
#   "prov:label": "rdf:48_14",
#   "_cell": 1437,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidy7vbctl65nailezs6vszmlusu6fnmh6vzdan44k7am2co6dksoi"
#   },
#   "_stmt_key": "48_14",
#   "_chunk_num": 48,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [48.15]: [Albert Einstein](/wiki/Albert_Einstein) proposed the theory because it demonstrated that quantum mechanics could solve the specific heat problem in classical mechanics.
# _:s15_model1 rdf:type schema:Substance .
# _:s15_model1 schema:disambiguatingDescription "proposed the theory because it demonstrated that quantum mechanics could solve the specific heat problem in classical mechanics" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie3e6jorba3io2jys7zmsv6kv3hspziapnccalsqjclq5lce5hti4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie3e6jorba3io2jys7zmsv6kv3hspziapnccalsqjclq5lce5hti4",
#   "prov:label": "rdf:48_15",
#   "_cell": 1439,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicafxspy5yoz7p4fhwupx7qbjz4tk7gpwqvlhgi33ho6fbvve4zxy"
#   },
#   "_stmt_key": "48_15",
#   "_chunk_num": 48,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [48.16]: [Peter Debye](/wiki/Peter_Debye) refined the [Einstein model](/wiki/Einstein_solid).
# <https://en.wikipedia.org/wiki/Peter_Debye> schema:disambiguatingDescription "refined the Einstein model" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaip7hvj43f7teqze3ywall2nax5xbrjf35yrq4kw2oknvcyn73ha",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaip7hvj43f7teqze3ywall2nax5xbrjf35yrq4kw2oknvcyn73ha",
#   "prov:label": "rdf:48_16",
#   "_cell": 1441,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaxomf5u5mpm7su5dc7moxufeyrs3va45zsmdd2cgcwyr5hu3ef64"
#   },
#   "_stmt_key": "48_16",
#   "_chunk_num": 48,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [48.17]: [Albert Einstein](/wiki/Albert_Einstein) developed [Bose–Einstein statistics](/wiki/Bose%E2%80%93Einstein_statistics).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:disambiguatingDescription "developed Bose–Einstein statistics" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiftrdlqz7myycqiq76prl3ddomjkpgr55aqscb7xr5ipxfxcj2maq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiftrdlqz7myycqiq76prl3ddomjkpgr55aqscb7xr5ipxfxcj2maq",
#   "prov:label": "rdf:48_17",
#   "_cell": 1443,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibk7o5qirmmfqkacqhz7ysc7fxzh33pds33bj6azgeh2c5p65hhwy"
#   },
#   "_stmt_key": "48_17",
#   "_chunk_num": 48,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [49.1]: In 1924, [Albert Einstein](/wiki/Albert_Einstein) received a description of a [statistical](/wiki/statistical_mechanics) model from [Satyendra Nath Bose](/wiki/Satyendra_Nath_Bose).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knowsAbout "statistical mechanics"^^xsd:string .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:creator "Satyendra Nath Bose"^^xsd:string .
# "Bose's statistical model"^^xsd:string rdf:type schema:CreativeWork .
# "Bose's statistical model"^^xsd:string schema:about "statistical mechanics"^^xsd:string .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidl4zbzbeynnn5ectuirlwyuo2u2i7seqh3mijvpmdkwzpaapydfe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidl4zbzbeynnn5ectuirlwyuo2u2i7seqh3mijvpmdkwzpaapydfe",
#   "prov:label": "rdf:49_1",
#   "_cell": 1445,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieq5bjrnbeozvdaw5o45jl2worwtskw7yk7zrx7va5ub4rfkiain4"
#   },
#   "_stmt_key": "49_1",
#   "_chunk_num": 49,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [49.2]: The statistical model was based on a counting method that assumed that light could be understood as a gas of indistinguishable particles.
# "Bose's statistical model"^^xsd:string schema:description "a counting method that assumed that light could be understood as a gas of indistinguishable particles"^^xsd:string .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie6vdql65akcxrln3frcd7musep27okhw7tg4kcux7qqpnw4j4ky4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie6vdql65akcxrln3frcd7musep27okhw7tg4kcux7qqpnw4j4ky4",
#   "prov:label": "rdf:49_2",
#   "_cell": 1447,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiemo7owsijnmn5ys6u6f6ng3vtt7ebrv5ysuwim6bo3frzr5zorsq"
#   },
#   "_stmt_key": "49_2",
#   "_chunk_num": 49,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [49.3]: [Albert Einstein](/wiki/Albert_Einstein) noted that [Bose's statistics](/wiki/Bose%E2%80%93Einstein_statistics) applied to some atoms as well as to the proposed light particles.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:creator "Bose's statistics"^^xsd:string .
# "Bose's statistics"^^xsd:string rdf:type schema:CreativeWork .
# "Bose's statistics"^^xsd:string schema:about "atoms"^^xsd:string .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiam6zr6a7ymhouubixwf4ku6ktihdix5m3xkk3ig7b7oujj76e774",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiam6zr6a7ymhouubixwf4ku6ktihdix5m3xkk3ig7b7oujj76e774",
#   "prov:label": "rdf:49_3",
#   "_cell": 1449,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihn3livza6jblvmfmlzx4w6wynbgnr3ayyzaif4wqkf45eui5ss6a"
#   },
#   "_stmt_key": "49_3",
#   "_chunk_num": 49,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [49.4]: [Albert Einstein](/wiki/Albert_Einstein) submitted his translation of [Bose's paper](/wiki/Bose%E2%80%93Einstein_statistics) to the *[Zeitschrift für Physik](/wiki/Zeitschrift_f%C3%BCr_Physik)*.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author "Bose's paper"^^xsd:string .
# "Bose's paper"^^xsd:string rdf:type schema:ScholarlyArticle .
# "Bose's paper"^^xsd:string schema:publisher "Zeitschrift für Physik"^^xsd:string .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreib2m3mx5wcjkkctthkzqgiu3z5heoqgt75beyyuwpaq4l3vnpvt7a",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreib2m3mx5wcjkkctthkzqgiu3z5heoqgt75beyyuwpaq4l3vnpvt7a",
#   "prov:label": "rdf:49_4",
#   "_cell": 1451,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidr4khtje2nti47zuh43frxszlgfe6dbajivkw6il4ndop66jnyki"
#   },
#   "_stmt_key": "49_4",
#   "_chunk_num": 49,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [49.5]: [Albert Einstein](/wiki/Albert_Einstein) published his own articles describing the model and its implications.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:author "Einstein's articles"^^xsd:string .
# "Einstein's articles"^^xsd:string rdf:type schema:ScholarlyArticle .
# "Einstein's articles"^^xsd:string schema:about "Bose-Einstein statistics"^^xsd:string .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidtjcks5fgye5xqihzhsktdldjyzgq5m2bewcyej6xwjtnpacagli",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidtjcks5fgye5xqihzhsktdldjyzgq5m2bewcyej6xwjtnpacagli",
#   "prov:label": "rdf:49_5",
#   "_cell": 1453,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifunqpus2yjkxnmh4y257rzbbdpwkl42lvniqrxptf3xfmv7y6tsu"
#   },
#   "_stmt_key": "49_5",
#   "_chunk_num": 49,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [49.6]: One implication described in Einstein's articles was the [Bose–Einstein condensate](/wiki/Bose%E2%80%93Einstein_condensate) phenomenon.
# "Einstein's articles"^^xsd:string schema:about "Bose-Einstein condensate"^^xsd:string .
# "Bose-Einstein condensate"^^xsd:string rdf:type schema:Quantity .
# "Bose-Einstein condensate"^^xsd:string schema:description "a phenomenon characterized by the appearance of particulates at very low temperatures"^^xsd:string .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigkhxfz4zt6tglwhgpceyyxkni46uylknahf2muaafa3p6am2sur4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigkhxfz4zt6tglwhgpceyyxkni46uylknahf2muaafa3p6am2sur4",
#   "prov:label": "rdf:49_6",
#   "_cell": 1455,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid25pg44xvv6g2ueimczpjugq6uwxlw6mfzllnqzfincpirqydxtq"
#   },
#   "_stmt_key": "49_6",
#   "_chunk_num": 49,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [49.7]: The [Bose–Einstein condensate](/wiki/Bose%E2%80%93Einstein_condensate) phenomenon is characterized by the appearance of particulates at very low temperatures.
# "Bose-Einstein condensate"^^xsd:string schema:description "characterized by the appearance of particulates at very low temperatures"^^xsd:string .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibxbdmzhwktcgnezaopslrymtk6femqxoi5snkit44lxmy73rw5g4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibxbdmzhwktcgnezaopslrymtk6femqxoi5snkit44lxmy73rw5g4",
#   "prov:label": "rdf:49_7",
#   "_cell": 1457,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreie7ueehqueeeyiwgf3npvhpr5nog66p6r2qhrdxqdzn3iswx2hoyq"
#   },
#   "_stmt_key": "49_7",
#   "_chunk_num": 49,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [49.8]: It was not until 1995 that the first [Bose–Einstein condensate](/wiki/Bose%E2%80%93Einstein_condensate) was produced experimentally.
# "Bose-Einstein condensate"^^xsd:string schema:datePublished "1995"^^xsd:gYear .
# "Bose-Einstein condensate"^^xsd:string schema:about "experimental production"^^xsd:string .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidtynwslsuufphhcdxa6f6lgakandgko5rpppka5ardfzul5dwabi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidtynwslsuufphhcdxa6f6lgakandgko5rpppka5ardfzul5dwabi",
#   "prov:label": "rdf:49_8",
#   "_cell": 1459,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidryrhqxgrn4gaafvieagi3qyx4675val7nhd5lckm5i3my6255xi"
#   },
#   "_stmt_key": "49_8",
#   "_chunk_num": 49,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [49.9]: The first [Bose–Einstein condensate](/wiki/Bose%E2%80%93Einstein_condensate) was produced by [Eric Allin Cornell](/wiki/Eric_Allin_Cornell) and [Carl Wieman](/wiki/Carl_Wieman).
# "Bose-Einstein condensate"^^xsd:string schema:creator "Eric Allin Cornell"^^xsd:string .
# "Bose-Einstein condensate"^^xsd:string schema:creator "Carl Wieman"^^xsd:string .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieoh65dhuk76utykextj2p7gjtei64pqv6p54tuts7he7bdn3ehki",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieoh65dhuk76utykextj2p7gjtei64pqv6p54tuts7he7bdn3ehki",
#   "prov:label": "rdf:49_9",
#   "_cell": 1461,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaqihvdxl2rgj4hdrt5zjwsywydrboraxn7w5ucymowxeyi4ybshm"
#   },
#   "_stmt_key": "49_9",
#   "_chunk_num": 49,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [49.10]: The experimental production of the first [Bose–Einstein condensate](/wiki/Bose%E2%80%93Einstein_condensate) used [ultra-cooling](/wiki/ultracold_atom) equipment.
# "ultra-cooling equipment"^^xsd:string rdf:type schema:Quantity .
# "ultra-cooling equipment"^^xsd:string schema:about "Bose-Einstein condensate"^^xsd:string .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicdg5ddexpxv27nklijzgnommag6dt45i3wluztglvcr5ox32mnje",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicdg5ddexpxv27nklijzgnommag6dt45i3wluztglvcr5ox32mnje",
#   "prov:label": "rdf:49_10",
#   "_cell": 1463,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih64e67w3cbw3jctiiqlnklbqcwwhtk5fn3pkrf5hhmmk7g25i5ha"
#   },
#   "_stmt_key": "49_10",
#   "_chunk_num": 49,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [49.11]: The [ultra-cooling](/wiki/ultracold_atom) equipment was built at the [NIST](/wiki/NIST)–[JILA](/wiki/JILA) laboratory.
# "ultra-cooling equipment"^^xsd:string schema:provider "NIST-JILA laboratory"^^xsd:string .
# "NIST-JILA laboratory"^^xsd:string rdf:type schema:Organization .
# "NIST-JILA laboratory"^^xsd:string schema:location "University of Colorado at Boulder"^^xsd:string .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie6fctoqso6wk6aqmuyaokvrrrj3dv6ak2ekjpvys556xlhnvbyu4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie6fctoqso6wk6aqmuyaokvrrrj3dv6ak2ekjpvys556xlhnvbyu4",
#   "prov:label": "rdf:49_11",
#   "_cell": 1465,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihvni6xei7cywzxdmrf5ctdhposvfdhz3nvqczl52bllmz6czpica"
#   },
#   "_stmt_key": "49_11",
#   "_chunk_num": 49,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [49.12]: The [NIST](/wiki/NIST)–[JILA](/wiki/JILA) laboratory is located at the [University of Colorado at Boulder](/wiki/University_of_Colorado_at_Boulder).
# "University of Colorado at Boulder"^^xsd:string rdf:type schema:EducationalOrganization .
# "University of Colorado at Boulder"^^xsd:string schema:name "University of Colorado at Boulder"^^xsd:string .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreid26cxt7utphjmrat3fuuqtga73r23qzcdnt7k74ghtvqxg6ud2he",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreid26cxt7utphjmrat3fuuqtga73r23qzcdnt7k74ghtvqxg6ud2he",
#   "prov:label": "rdf:49_12",
#   "_cell": 1467,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia3d3yx4wc2ltsuddmhwqrxlnx3h3u6bk6mctibss4iod7ymy3okm"
#   },
#   "_stmt_key": "49_12",
#   "_chunk_num": 49,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [49.13]: [Bose–Einstein statistics](/wiki/Bose%E2%80%93Einstein_statistics) are now used to describe the behaviors of any assembly of [boson](/wiki/boson)s.
# "Bose-Einstein statistics"^^xsd:string schema:about "bosons"^^xsd:string .
# "Bose-Einstein statistics"^^xsd:string rdf:type schema:CreativeWork .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigsmafx7u4tvnceemsxorebtg4tii2f4oqdxbudnea2e77ahza5ce",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigsmafx7u4tvnceemsxorebtg4tii2f4oqdxbudnea2e77ahza5ce",
#   "prov:label": "rdf:49_13",
#   "_cell": 1469,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreict5kewtjdgtalusmvkt5u5dcxbhsulzk2k2ym3lfvvpxtalzc57u"
#   },
#   "_stmt_key": "49_13",
#   "_chunk_num": 49,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [49.14]: [Albert Einstein's sketches](/wiki/Bose%E2%80%93Einstein_statistics) for this project may be seen in the [Einstein Archive](/wiki/Einstein_Archive) in the library of [Leiden University](/wiki/Leiden_University).
# "Albert Einstein's sketches"^^xsd:string schema:about "Bose-Einstein statistics"^^xsd:string .
# "Albert Einstein's sketches"^^xsd:string schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .
# "Albert Einstein's sketches"^^xsd:string schema:location "Einstein Archive"^^xsd:string .
# "Einstein Archive"^^xsd:string schema:location "Leiden University"^^xsd:string .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihxf3w27teneel4d4ggpjqtnxjtkx2i33n6vnidtvgebmopm4jrai",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihxf3w27teneel4d4ggpjqtnxjtkx2i33n6vnidtvgebmopm4jrai",
#   "prov:label": "rdf:49_14",
#   "_cell": 1471,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidasam374o3jlawhq5i3mtzt523bfa2gxmfjarj7gqhp7snryb2nu"
#   },
#   "_stmt_key": "49_14",
#   "_chunk_num": 49,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [50.1]: [Albert Einstein](/wiki/Albert_Einstein) became a *[Privatdozent](/wiki/Privatdozent)* at the [University of Bern](/wiki/University_of_Bern) in 1908.
# https://en.wikipedia.org/wiki/Albert_Einstein schema:worksFor _:s1_role1 .
# _:s1_role1 rdf:type schema:OrganizationRole .
# _:s1_role1 schema:worksFor https://en.wikipedia.org/wiki/University_of_Bern .
# _:s1_role1 schema:startDate "1908"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie7ndx27yashzrrahto2mgn25rvrkiaaazzhqr77jnmm63f6k743e",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie7ndx27yashzrrahto2mgn25rvrkiaaazzhqr77jnmm63f6k743e",
#   "prov:label": "rdf:50_1",
#   "_cell": 1473,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigehozhxl26wqv2mqncba6e3duuoxrq3fts3jlqg5kzfacvadxnzm"
#   },
#   "_stmt_key": "50_1",
#   "_chunk_num": 50,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [50.2]: In "*Über die Entwicklung unserer Anschauungen über das Wesen und die Konstitution der Strahlung*" ([The Development of our Views on the Composition and Essence of Radiation](/wiki/s%3ATranslation%3AThe_Development_of_Our_Views_on_the_Composition_and_Essence_of_Radiation)), [Albert Einstein](/wiki/Albert_Einstein) discussed the [quantization](/wiki/quantization_%28physics%29) of light.
# _:s2_work1 rdf:type schema:CreativeWork .
# _:s2_work1 schema:creator https://en.wikipedia.org/wiki/Albert_Einstein .
# _:s2_work1 schema:text "Über die Entwicklung unserer Anschauungen über das Wesen und die Konstitution der Strahlung" .
# _:s2_work1 schema:name "The Development of our Views on the Composition and Essence of Radiation" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreig76z2c5gz62xlxyfbpjbj23beqnciohev5utwnhmci4agvs6qg7m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreig76z2c5gz62xlxyfbpjbj23beqnciohev5utwnhmci4agvs6qg7m",
#   "prov:label": "rdf:50_2",
#   "_cell": 1475,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiatdiz6id4pj5bpr6jjruudmm5leduho5yxfs7mzclqlgzzzep2o4"
#   },
#   "_stmt_key": "50_2",
#   "_chunk_num": 50,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [50.3]: In the same work, [Albert Einstein](/wiki/Albert_Einstein) showed that [Max Planck](/wiki/Max_Planck)'s energy quanta must have well-defined [momenta](/wiki/momentum).
# _:s3_work1 rdf:type schema:CreativeWork .
# _:s3_work1 schema:creator https://en.wikipedia.org/wiki/Albert_Einstein .
# _:s3_work1 schema:text "Über die Entwicklung unserer Anschauungen über das Wesen und die Konstitution der Strahlung" .
# _:s3_work1 schema:name "The Development of our Views on the Composition and Essence of Radiation" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreide3p2vgsy2hfrpnfmkb6sncjocp4qbp5khxf7zffoyhrm3cn4bt4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreide3p2vgsy2hfrpnfmkb6sncjocp4qbp5khxf7zffoyhrm3cn4bt4",
#   "prov:label": "rdf:50_3",
#   "_cell": 1477,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihpsxpjcs7ijfk3jrge7i4rioq2hkyhfinkmla45lcsofbvx55vi4"
#   },
#   "_stmt_key": "50_3",
#   "_chunk_num": 50,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [50.4]: In the same work, [Albert Einstein](/wiki/Albert_Einstein) stated that [Max Planck](/wiki/Max_Planck)'s energy quanta act in some respects as independent, [point-like particles](/wiki/point_particle).
# _:s4_work1 rdf:type schema:CreativeWork .
# _:s4_work1 schema:creator https://en.wikipedia.org/wiki/Albert_Einstein .
# _:s4_work1 schema:text "Über die Entwicklung unserer Anschauungen über das Wesen und die Konstitution der Strahlung" .
# _:s4_work1 schema:name "The Development of our Views on the Composition and Essence of Radiation" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic76be5en6kcqdqufvxosqi3gblt2fhnqb4w3kzwbikl2csg4rxk4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic76be5en6kcqdqufvxosqi3gblt2fhnqb4w3kzwbikl2csg4rxk4",
#   "prov:label": "rdf:50_4",
#   "_cell": 1479,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreie2wewqopuodte3jt2s4zck7vxc6gcot3zj753yokr6odji6grmwe"
#   },
#   "_stmt_key": "50_4",
#   "_chunk_num": 50,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [50.5]: This paper introduced the *photon* concept.
# _:s5_work1 rdf:type schema:CreativeWork .
# _:s5_work1 schema:creator https://en.wikipedia.org/wiki/Albert_Einstein .
# _:s5_work1 schema:text "Über die Entwicklung unserer Anschauungen über das Wesen und die Konstitution der Strahlung" .
# _:s5_work1 schema:name "The Development of our Views on the Composition and Essence of Radiation" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidsmh3u7ymdkc4ociuiqtldgn5s5hvdixinckuglbfqk32cnnexeq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidsmh3u7ymdkc4ociuiqtldgn5s5hvdixinckuglbfqk32cnnexeq",
#   "prov:label": "rdf:50_5",
#   "_cell": 1481,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidkm2jnjkudhaut2z4wuwpnucrf7w3jlzegobtvmtctkec2yw2ygm"
#   },
#   "_stmt_key": "50_5",
#   "_chunk_num": 50,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [50.6]: The *photon* concept inspired the notion of [wave–particle duality](/wiki/wave%E2%80%93particle_duality) in quantum mechanics.
# _:s6_work1 rdf:type schema:CreativeWork .
# _:s6_work1 schema:creator https://en.wikipedia.org/wiki/Albert_Einstein .
# _:s6_work1 schema:text "Über die Entwicklung unserer Anschauungen über das Wesen und die Konstitution der Strahlung" .
# _:s6_work1 schema:name "The Development of our Views on the Composition and Essence of Radiation" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihtghrj3pkkjugnbhisxlble2bwwjv7hliegoor2yb3gqsnzhdlca",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihtghrj3pkkjugnbhisxlble2bwwjv7hliegoor2yb3gqsnzhdlca",
#   "prov:label": "rdf:50_6",
#   "_cell": 1483,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreif2npo5qmjyt7gtcff63otshqiblfm25kof6f7hr5dtzvypuvrlvy"
#   },
#   "_stmt_key": "50_6",
#   "_chunk_num": 50,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [50.7]: [Albert Einstein](/wiki/Albert_Einstein) saw the wave–particle duality in radiation as concrete evidence for his conviction that physics needed a new, unified foundation.
# https://en.wikipedia.org/wiki/Albert_Einstein rdfs:comment Albert Einstein saw the wave–particle duality in radiation as concrete evidence for his conviction that physics needed a new, unified foundation. .
# https://en.wikipedia.org/wiki/Albert_Einstein schema:hasOccupation https://en.wikipedia.org/wiki/Physics .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiapro5nkynvhavumo6sxdlags75pm2yhe5ypohdhzjnchcjgvxifu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiapro5nkynvhavumo6sxdlags75pm2yhe5ypohdhzjnchcjgvxifu",
#   "prov:label": "rdf:50_7",
#   "_cell": 1485,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieaaoapwxky3eouyjkbmwvizqbbtosz5lhhyfsjdgbhw52ukvuqia"
#   },
#   "_stmt_key": "50_7",
#   "_chunk_num": 50,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [50.8]: From 1911 to 1913, [Max Planck](/wiki/Max_Planck) reformulated his 1900 quantum theory.
# https://en.wikipedia.org/wiki/Max_Planck schema:worksFor _:s8_role1 .
# _:s8_role1 rdf:type schema:OrganizationRole .
# _:s8_role1 schema:worksFor https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences .
# _:s8_role1 schema:startDate "1911"^^xsd:gYear .
# _:s8_role1 schema:endDate "1913"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihutovyylga6xadrgnkbichr6732wbuqwprv6e3kwnzdasnhv3kqi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihutovyylga6xadrgnkbichr6732wbuqwprv6e3kwnzdasnhv3kqi",
#   "prov:label": "rdf:50_8",
#   "_cell": 1487,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidn7oukk63pxssbibxdr3bb7gtmr5qmskgdpyranhktba62da7zty"
#   },
#   "_stmt_key": "50_8",
#   "_chunk_num": 50,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [50.9]: In this reformulation, [Max Planck](/wiki/Max_Planck) introduced the idea of [zero-point energy](/wiki/zero-point_energy) in his "second quantum theory".
# _:s9_work1 rdf:type schema:CreativeWork .
# _:s9_work1 schema:creator https://en.wikipedia.org/wiki/Max_Planck .
# _:s9_work1 schema:text "second quantum theory" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreianvik52mckihjrbnhuzbh3bmxyxs4gavl4y7zhpl2flkktqtfhay",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreianvik52mckihjrbnhuzbh3bmxyxs4gavl4y7zhpl2flkktqtfhay",
#   "prov:label": "rdf:50_9",
#   "_cell": 1489,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihtcy4peweodx4hp53j2unpsi6nwpnymhfe5ixapcu774jogpu2ru"
#   },
#   "_stmt_key": "50_9",
#   "_chunk_num": 50,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [50.10]: The idea of [zero-point energy](/wiki/zero-point_energy) attracted the attention of [Albert Einstein](/wiki/Albert_Einstein) and his assistant [Otto Stern](/wiki/Otto_Stern).
# https://en.wikipedia.org/wiki/Albert_Einstein rdfs:comment The idea of zero-point energy attracted the attention of Albert Einstein and his assistant Otto Stern. .
# https://en.wikipedia.org/wiki/Otto_Stern rdfs:comment The idea of zero-point energy attracted the attention of Albert Einstein and his assistant Otto Stern. .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreig4s3dfzhpdgdxy4rcjcjw7mhzvxrr46gqhzhtjl7fz2iy6xkimvm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreig4s3dfzhpdgdxy4rcjcjw7mhzvxrr46gqhzhtjl7fz2iy6xkimvm",
#   "prov:label": "rdf:50_10",
#   "_cell": 1491,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihe4bcbulikoea5rzphvnz6uoabhyyspfkitc7yc6ljhtfpdcamhy"
#   },
#   "_stmt_key": "50_10",
#   "_chunk_num": 50,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [50.11]: Assuming the energy of rotating diatomic molecules contains [zero-point energy](/wiki/zero-point_energy), [Albert Einstein](/wiki/Albert_Einstein) and [Otto Stern](/wiki/Otto_Stern) compared the theoretical specific heat of hydrogen gas with experimental data.
# https://en.wikipedia.org/wiki/Albert_Einstein rdfs:comment Assuming the energy of rotating diatomic molecules contains zero-point energy, Albert Einstein and Otto Stern compared the theoretical specific heat of hydrogen gas with experimental data. .
# https://en.wikipedia.org/wiki/Otto_Stern rdfs:comment Assuming the energy of rotating diatomic molecules contains zero-point energy, Albert Einstein and Otto Stern compared the theoretical specific heat of hydrogen gas with experimental data. .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreif6jztafvkemthnm6no3ymhlprlrm6p2op2nb7nw5bcbcka6zhgii",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreif6jztafvkemthnm6no3ymhlprlrm6p2op2nb7nw5bcbcka6zhgii",
#   "prov:label": "rdf:50_11",
#   "_cell": 1493,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidvauqp7ierhdhbyj7c73fikayylnqm3urnxbtvdcm2lrhorolyly"
#   },
#   "_stmt_key": "50_11",
#   "_chunk_num": 50,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [50.12]: The numbers matched nicely.
# rdfs:comment rdfs:comment The numbers matched nicely. .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreif4eyhjaqynkdzqw5hrz5qmoz53z7ipnhlkaz7rknmak6bjahcc34",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreif4eyhjaqynkdzqw5hrz5qmoz53z7ipnhlkaz7rknmak6bjahcc34",
#   "prov:label": "rdf:50_12",
#   "_cell": 1495,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifkmi2g7fy6edav5sir35iyizubzctd2hgqyzn4vpwo7yh4oprbk4"
#   },
#   "_stmt_key": "50_12",
#   "_chunk_num": 50,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [50.13]: After publishing the findings, [Albert Einstein](/wiki/Albert_Einstein) and [Otto Stern](/wiki/Otto_Stern) withdrew their support.
# https://en.wikipedia.org/wiki/Albert_Einstein rdfs:comment After publishing the findings, Albert Einstein and Otto Stern withdrew their support. .
# https://en.wikipedia.org/wiki/Otto_Stern rdfs:comment After publishing the findings, Albert Einstein and Otto Stern withdrew their support. .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifmlzre3y5js4ld4is7bb2yy4saj5ejeaotfx7hkdfur6hzm2lwdi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifmlzre3y5js4ld4is7bb2yy4saj5ejeaotfx7hkdfur6hzm2lwdi",
#   "prov:label": "rdf:50_13",
#   "_cell": 1497,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaycygssrpkfc5soa7fc4t5lu7pz7ri4pt2m6jiomedaokk5lowpa"
#   },
#   "_stmt_key": "50_13",
#   "_chunk_num": 50,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [50.14]: They withdrew their support because they no longer had confidence in the correctness of the idea of [zero-point energy](/wiki/zero-point_energy).
# https://en.wikipedia.org/wiki/Albert_Einstein rdfs:comment They withdrew their support because they no longer had confidence in the correctness of the idea of zero-point energy. .
# https://en.wikipedia.org/wiki/Otto_Stern rdfs:comment They withdrew their support because they no longer had confidence in the correctness of the idea of zero-point energy. .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreig77whtnrgpqsor7yx7cdedtg7nvgsyzzbdd7np5tzo4asimpgojy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreig77whtnrgpqsor7yx7cdedtg7nvgsyzzbdd7np5tzo4asimpgojy",
#   "prov:label": "rdf:50_14",
#   "_cell": 1499,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieg7oremaufdayj4ytqdtm2tzfsxfd5v4lcukwckvug7uhiqo54oe"
#   },
#   "_stmt_key": "50_14",
#   "_chunk_num": 50,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [51.1]: In 1917, [Albert Einstein](/wiki/Albert_Einstein) published an article in *Physikalische Zeitschrift*.
# _:s1_article1 rdf:type schema:Article .
# _:s1_article1 schema:datePublished "1917"^^xsd:gYear .
# _:s1_article1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s1_article1 schema:publisher <https://en.wikipedia.org/wiki/Physikalische_Zeitschrift> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiarzz3et323irmzslhimqld7azorqeqwyq4u6yj72mq5mzcqijl5q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiarzz3et323irmzslhimqld7azorqeqwyq4u6yj72mq5mzcqijl5q",
#   "prov:label": "rdf:51_1",
#   "_cell": 1501,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigvrqns6is3xgaiwsns5hqgaol5b6oopbc52sfvdo7tgcmeuxpqci"
#   },
#   "_stmt_key": "51_1",
#   "_chunk_num": 51,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [51.2]: In 1917, [Albert Einstein](/wiki/Albert_Einstein) proposed the possibility of [stimulated emission](/wiki/stimulated_emission).
# _:s2_proposal1 rdf:type schema:CreativeWork .
# _:s2_proposal1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s2_proposal1 schema:datePublished "1917"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihbpn3eib532npbbnea7e4ihke7k447ra6fcbq4xkhq2inc7b6roi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihbpn3eib532npbbnea7e4ihke7k447ra6fcbq4xkhq2inc7b6roi",
#   "prov:label": "rdf:51_2",
#   "_cell": 1503,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid4dksdwdlfuzu3jdgvyauhbk6c2ym6a6bqfq2zecffg2oqojzzkq"
#   },
#   "_stmt_key": "51_2",
#   "_chunk_num": 51,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [51.3]: [Stimulated emission](/wiki/stimulated_emission) is a physical process that makes possible the [maser](/wiki/maser) and the [laser](/wiki/laser).
# <https://en.wikipedia.org/wiki/stimulated_emission> rdf:type schema:Substance .
# <https://en.wikipedia.org/wiki/stimulated_emission> schema:hasPart <https://en.wikipedia.org/wiki/maser> .
# <https://en.wikipedia.org/wiki/stimulated_emission> schema:hasPart <https://en.wikipedia.org/wiki/laser> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia5kiclswnr7wd6z2ybm3wd3htvbpwlsfuauuo2bo2g2jt4igehp4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia5kiclswnr7wd6z2ybm3wd3htvbpwlsfuauuo2bo2g2jt4igehp4",
#   "prov:label": "rdf:51_3",
#   "_cell": 1505,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiasgym5637d3gjn42ayqi3q775m2xawuwn7a4b6g2t34645zx3dkq"
#   },
#   "_stmt_key": "51_3",
#   "_chunk_num": 51,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [51.4]: The 1917 article by [Albert Einstein](/wiki/Albert_Einstein) showed that the statistics of absorption and emission of light would only be consistent with Planck's distribution law if the emission of light into a mode with n photons would be enhanced statistically compared to the emission of light into an empty mode.
# _:s4_article1 rdf:type schema:Article .
# _:s4_article1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s4_article1 schema:datePublished "1917"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia3vyyydyciuygwkd34zj7bhleuuplketasqy7j62au7bsywc6z2e",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia3vyyydyciuygwkd34zj7bhleuuplketasqy7j62au7bsywc6z2e",
#   "prov:label": "rdf:51_4",
#   "_cell": 1507,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidy2zvs3ai5xlrhqsedj3wrms62rnwdu5qrhlfch5q4lov5n3ahyu"
#   },
#   "_stmt_key": "51_4",
#   "_chunk_num": 51,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [51.5]: The 1917 article by [Albert Einstein](/wiki/Albert_Einstein) was enormously influential in the later development of quantum mechanics.
# _:s5_article1 rdf:type schema:Article .
# _:s5_article1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s5_article1 schema:datePublished "1917"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifcsul7r5sf2sig4oqwexkvsrgz4jlzkecttxyx3233lhuluurbzi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifcsul7r5sf2sig4oqwexkvsrgz4jlzkecttxyx3233lhuluurbzi",
#   "prov:label": "rdf:51_5",
#   "_cell": 1509,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiampdi65lcekz3lexdks2fx47aqyplply5xvuwcultk6he2ljupbi"
#   },
#   "_stmt_key": "51_5",
#   "_chunk_num": 51,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [51.6]: The 1917 article by [Albert Einstein](/wiki/Albert_Einstein) was the first paper to show that the statistics of atomic transitions had simple laws.
# _:s6_article1 rdf:type schema:Article .
# _:s6_article1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s6_article1 schema:datePublished "1917"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicb7fgxzxiqnrkaoqqptmz7qze3plxntvv7j2z4ezpix75xrgkige",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicb7fgxzxiqnrkaoqqptmz7qze3plxntvv7j2z4ezpix75xrgkige",
#   "prov:label": "rdf:51_6",
#   "_cell": 1511,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigsq5dgbeadpcr4kj5quufcvqspfxnfwh4zcpkzpremsoerl6tzgq"
#   },
#   "_stmt_key": "51_6",
#   "_chunk_num": 51,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [51.7]: [Albert Einstein](/wiki/Albert_Einstein) discovered the work of [Louis de Broglie](/wiki/Louis_de_Broglie).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Louis_de_Broglie> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifbxhokkb2o5tyytmulsnahumqk72kb5wmopwnfpdg3hpvyifi7tm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifbxhokkb2o5tyytmulsnahumqk72kb5wmopwnfpdg3hpvyifi7tm",
#   "prov:label": "rdf:51_7",
#   "_cell": 1513,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigieiu7xremlgzsmybradnqupcuheglfimc4a6qk6dqwz5atpqj4m"
#   },
#   "_stmt_key": "51_7",
#   "_chunk_num": 51,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [51.8]: [Albert Einstein](/wiki/Albert_Einstein) supported the ideas of [Louis de Broglie](/wiki/Louis_de_Broglie).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:knows <https://en.wikipedia.org/wiki/Louis_de_Broglie> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiair6zu5kan7follndqcu3ojkdtyc4ho7pnlho47ee4dpxngjcw3m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiair6zu5kan7follndqcu3ojkdtyc4ho7pnlho47ee4dpxngjcw3m",
#   "prov:label": "rdf:51_8",
#   "_cell": 1515,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigwdd7oc7wqdbn5ldp35l5psmxbslu2jfszvncxa757uf3ch7grcy"
#   },
#   "_stmt_key": "51_8",
#   "_chunk_num": 51,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [51.9]: [Louis de Broglie](/wiki/Louis_de_Broglie)'s ideas were received skeptically at first.
# <https://en.wikipedia.org/wiki/Louis_de_Broglie> schema:hasReputation "controversial" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic5wtehmcmtqteisuei5if4gb2zwqdoi244xu3ji7pwrbclkeckzi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic5wtehmcmtqteisuei5if4gb2zwqdoi244xu3ji7pwrbclkeckzi",
#   "prov:label": "rdf:51_9",
#   "_cell": 1517,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieu24zu3ljnyo4greevjkpubyrjlyabu3257x27loittdbv2p53s4"
#   },
#   "_stmt_key": "51_9",
#   "_chunk_num": 51,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [51.10]: In another major paper from the era of [Louis de Broglie](/wiki/Louis_de_Broglie), [Albert Einstein](/wiki/Albert_Einstein) observed that [de Broglie waves](/wiki/de_Broglie_waves) could explain the [quantization rules of Bohr and Sommerfeld](/wiki/Bohr-Sommerfeld_quantization).
# _:s10_paper1 rdf:type schema:Article .
# _:s10_paper1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s10_paper1 schema:datePublished "1925"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihlcaiixmp6hkqpdq5t5tejwzotlgdazd4uw3j7b6lujnpba4xlii",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihlcaiixmp6hkqpdq5t5tejwzotlgdazd4uw3j7b6lujnpba4xlii",
#   "prov:label": "rdf:51_10",
#   "_cell": 1519,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidmc3bijkadftp7k4eo4w65nb5kcl2ujpmmuab2wwloeixgyio6bi"
#   },
#   "_stmt_key": "51_10",
#   "_chunk_num": 51,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [51.11]: The paper by [Albert Einstein](/wiki/Albert_Einstein) on [de Broglie waves](/wiki/de_Broglie_waves) inspired Schrödinger's work of 1926.
# _:s11_paper1 rdf:type schema:Article .
# _:s11_paper1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia6cixiwyfxozp2mv6fhu4un5hbnwy3kxmbvrxjz65j5a2fq3bvyi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia6cixiwyfxozp2mv6fhu4un5hbnwy3kxmbvrxjz65j5a2fq3bvyi",
#   "prov:label": "rdf:51_11",
#   "_cell": 1521,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigu6qhamiwnjuoo4qhuwaekkw6lji55l62bjwb3f444udsogqits4"
#   },
#   "_stmt_key": "51_11",
#   "_chunk_num": 51,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [51.12]: [Albert Einstein](/wiki/Albert_Einstein) played a major role in developing quantum theory.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:hasOccupation schema:Researcher .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicskkpmvg4awwsh5cz3ud3y3hp7wghh7555cdkxxwhne6qua5ow5i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicskkpmvg4awwsh5cz3ud3y3hp7wghh7555cdkxxwhne6qua5ow5i",
#   "prov:label": "rdf:51_12",
#   "_cell": 1523,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibxxou4rnhlacl5ii7q3fpqjwsacq3v4pksrohua6h4z3kokgaa3u"
#   },
#   "_stmt_key": "51_12",
#   "_chunk_num": 51,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [51.13]: [Albert Einstein](/wiki/Albert_Einstein) began his work on quantum theory with his 1905 paper on the [photoelectric effect](/wiki/Photoelectric_effect).
# _:s13_paper1 rdf:type schema:Article .
# _:s13_paper1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s13_paper1 schema:datePublished "1905"^^xsd:gYear .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiddp6ufqu6klbyli3oobwiycjoflmfba5tgv2hck6lxqlc76htrqq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiddp6ufqu6klbyli3oobwiycjoflmfba5tgv2hck6lxqlc76htrqq",
#   "prov:label": "rdf:51_13",
#   "_cell": 1525,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreic7cdbv5tb743vhjznlmvwiuhlvhtfc6idaj7suipa66hsoqi2jhu"
#   },
#   "_stmt_key": "51_13",
#   "_chunk_num": 51,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [51.14]: [Albert Einstein](/wiki/Albert_Einstein) became displeased with modern quantum mechanics as it had evolved after 1925.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:dislikes "modern quantum mechanics" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicgx7grxzrztgiokasayy3hvu75jjbl5g27zaj23bgvt2tnceyzs4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicgx7grxzrztgiokasayy3hvu75jjbl5g27zaj23bgvt2tnceyzs4",
#   "prov:label": "rdf:51_14",
#   "_cell": 1527,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicay5fcnwzvbxr7algwyaxe5jneo26f6ks2kovjnvuaujmlyfmaye"
#   },
#   "_stmt_key": "51_14",
#   "_chunk_num": 51,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [51.15]: Despite its acceptance by other physicists, [Albert Einstein](/wiki/Albert_Einstein) was skeptical that the randomness of quantum mechanics was fundamental.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:skepticalAbout "randomness of quantum mechanics" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifojn4x3niqzylew7e2k4m4cjmd7a3uddbjdmy53aafwqp2vyhgy4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifojn4x3niqzylew7e2k4m4cjmd7a3uddbjdmy53aafwqp2vyhgy4",
#   "prov:label": "rdf:51_15",
#   "_cell": 1529,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih4i4msxbcbmmyf4m6zgqpusfnhrkcgpqsi7y66endnetnx4kieeu"
#   },
#   "_stmt_key": "51_15",
#   "_chunk_num": 51,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [51.16]: [Albert Einstein](/wiki/Albert_Einstein) believed that the randomness of quantum mechanics was the result of determinism.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:believes "determinism" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidyztmkkxnxxo5qnrcaetsvlzxif2dajxaenrjcfaqfwl2dhlijae",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidyztmkkxnxxo5qnrcaetsvlzxif2dajxaenrjcfaqfwl2dhlijae",
#   "prov:label": "rdf:51_16",
#   "_cell": 1531,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihln5odhy6f4uprcxd35lkudjqpxn7jpxtkwekotxgop3653tnmdm"
#   },
#   "_stmt_key": "51_16",
#   "_chunk_num": 51,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [51.17]: [Albert Einstein](/wiki/Albert_Einstein) stated that God "is not playing at dice".
# _:s17_quote1 rdf:type schema:Quotation .
# _:s17_quote1 schema:text "God is not playing at dice" .
# _:s17_quote1 schema:creator <https://en.wikipedia.org/wiki/Albert_Einstein> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidc4kioqjypbdshfhod6trs7ukapv4etcp4tf24k3vddodu6ipnla",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidc4kioqjypbdshfhod6trs7ukapv4etcp4tf24k3vddodu6ipnla",
#   "prov:label": "rdf:51_17",
#   "_cell": 1533,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifggipbwfj46mmyt3y4qmneju3m2d3rqp5kwmm4uyfkhkz7o57aou"
#   },
#   "_stmt_key": "51_17",
#   "_chunk_num": 51,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [51.18]: The debates between [Albert Einstein](/wiki/Albert_Einstein) and other physicists influenced later [interpretations of quantum mechanics](/wiki/interpretations_of_quantum_mechanics).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:influenced "interpretations of quantum mechanics" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibbkg4qg6oo5w3iqsoz2nowb2g5bl723w3qwnwmpmp7u3khk5bfs4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibbkg4qg6oo5w3iqsoz2nowb2g5bl723w3qwnwmpmp7u3khk5bfs4",
#   "prov:label": "rdf:51_18",
#   "_cell": 1535,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreief25dpmyu6c6tgab7szp5tzskjbswlycaz2nn5tq6rbnojqmstgu"
#   },
#   "_stmt_key": "51_18",
#   "_chunk_num": 51,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [51.19]: [Albert Einstein](/wiki/Albert_Einstein) co-authored the [EPR paradox](/wiki/EPR_paradox) with [Boris Podolsky](/wiki/Boris_Podolsky) and [Nathan Rosen](/wiki/Nathan_Rosen).
# _:s19_epr1 rdf:type schema:CreativeWork .
# _:s19_epr1 schema:author <https://en.wikipedia.org/wiki/Albert_Einstein> .
# _:s19_epr1 schema:author <https://en.wikipedia.org/wiki/Boris_Podolsky> .
# _:s19_epr1 schema:author <https://en.wikipedia.org/wiki/Nathan_Rosen> .
# _:s19_epr1 schema:hasPart <https://en.wikipedia.org/wiki/EPR_paradox> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreif227wniro726cjzgalycmqd5lhaaggrh2nagkjxwahhqq7tbivfq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreif227wniro726cjzgalycmqd5lhaaggrh2nagkjxwahhqq7tbivfq",
#   "prov:label": "rdf:51_19",
#   "_cell": 1537,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreievhi5hav3vdzuutavpvtxyrswp2eqlvukxirgovq5n3ucntboib4"
#   },
#   "_stmt_key": "51_19",
#   "_chunk_num": 51,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Statement [52.1]: [Albert Einstein](/wiki/Albert_Einstein) never fully accepted [quantum mechanics](/wiki/Quantum_mechanics).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:disagreeAction <https://en.wikipedia.org/wiki/Quantum_mechanics> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:disagreesWith <https://en.wikipedia.org/wiki/Quantum_mechanics> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Albert Einstein never fully accepted quantum mechanics." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibdyyrb352aqordh5yyczdhu7lr3rbeic2uitytaeu5ekcdeai6r4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibdyyrb352aqordh5yyczdhu7lr3rbeic2uitytaeu5ekcdeai6r4",
#   "prov:label": "rdf:52_1",
#   "_cell": 1539,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidi2izei3owpmltyo3wa66q2s4f6q6rlwqkmrsldxv3qopdanh2xe"
#   },
#   "_stmt_key": "52_1",
#   "_chunk_num": 52,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [52.2]: [Albert Einstein](/wiki/Albert_Einstein) recognized that [quantum mechanics](/wiki/Quantum_mechanics) made correct predictions.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:agreesAction <https://en.wikipedia.org/wiki/Quantum_mechanics> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:agreesWith <https://en.wikipedia.org/wiki/Quantum_mechanics> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Albert Einstein recognized that quantum mechanics made correct predictions." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiebzlco4ct6dltszrbade7ooaeqp7soqrzhoctxpokwjfqv5zbope",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiebzlco4ct6dltszrbade7ooaeqp7soqrzhoctxpokwjfqv5zbope",
#   "prov:label": "rdf:52_2",
#   "_cell": 1541,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih4antf3xthkh3q5o43ls4zaiq2cisrnf5q7zus5cmlzdvuqkmaf4"
#   },
#   "_stmt_key": "52_2",
#   "_chunk_num": 52,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [52.3]: [Albert Einstein](/wiki/Albert_Einstein) believed a more fundamental description of nature must be possible.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:believes <https://en.wikipedia.org/wiki/Quantum_mechanics> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Albert Einstein believed a more fundamental description of nature must be possible." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigsz7trajkug2fvsbfeyvlfw3cpeptlwxmhhyn57uyu55aqxj7dqm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigsz7trajkug2fvsbfeyvlfw3cpeptlwxmhhyn57uyu55aqxj7dqm",
#   "prov:label": "rdf:52_3",
#   "_cell": 1543,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidr6yt2zm3hsdhp3tmrk46mxko7m34rcfv43h6vt2vcf22nytmqga"
#   },
#   "_stmt_key": "52_3",
#   "_chunk_num": 52,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [52.4]: [Albert Einstein](/wiki/Albert_Einstein) presented multiple arguments to support his belief.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:presented <https://en.wikipedia.org/wiki/EPR_paradox> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Albert Einstein presented multiple arguments to support his belief." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidjdwlqcta43d3sce2di5kniamvtsku2d7r4xxobrd47kcn63h5qu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidjdwlqcta43d3sce2di5kniamvtsku2d7r4xxobrd47kcn63h5qu",
#   "prov:label": "rdf:52_4",
#   "_cell": 1545,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibx6hyv56cv27w5uu2mqvy2plojjk52d75wrrffw5q6p2zon6e524"
#   },
#   "_stmt_key": "52_4",
#   "_chunk_num": 52,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [52.5]: The argument that [Albert Einstein](/wiki/Albert_Einstein) preferred most dated to a debate with [Niels Bohr](/wiki/Niels_Bohr) in 1930.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:presented <https://en.wikipedia.org/wiki/EPR_paradox> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "The argument that Albert Einstein preferred most dated to a debate with Niels Bohr in 1930." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihmfhneksagfj5qwxz4poapcoarpptskjh7pvjmhawuwjoqioesma",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihmfhneksagfj5qwxz4poapcoarpptskjh7pvjmhawuwjoqioesma",
#   "prov:label": "rdf:52_5",
#   "_cell": 1547,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihopgtxqyjyo4fjdfwv3ub5plqckppuobdvvnqiqpymeyxfrirhdm"
#   },
#   "_stmt_key": "52_5",
#   "_chunk_num": 52,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [52.6]: [Albert Einstein](/wiki/Albert_Einstein) suggested a [thought experiment](/wiki/Einstein%27s_thought_experiments) involving two objects that interact and then move apart.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:suggested <https://en.wikipedia.org/wiki/Einstein%27s_thought_experiments> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Albert Einstein suggested a thought experiment involving two objects that interact and then move apart." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidlzeodxtitgi67tvnowbmq7qp73kmdfkfychqkubjcgiamjwmu6i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidlzeodxtitgi67tvnowbmq7qp73kmdfkfychqkubjcgiamjwmu6i",
#   "prov:label": "rdf:52_6",
#   "_cell": 1549,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicm3icdyxj3lbers7miexzi7pkztb5d5m572fjtdfiirxnxsl5ace"
#   },
#   "_stmt_key": "52_6",
#   "_chunk_num": 52,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [52.7]: The quantum-mechanical description of the two objects is a mathematical entity known as a [wavefunction](/wiki/wavefunction).
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:presented <https://en.wikipedia.org/wiki/wavefunction> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "The quantum-mechanical description of the two objects is a mathematical entity known as a wavefunction." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigdrqoa3c4difvpqy7v3r733ifejzg6ctcby2dp4hvakzekjixcs4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigdrqoa3c4difvpqy7v3r733ifejzg6ctcby2dp4hvakzekjixcs4",
#   "prov:label": "rdf:52_7",
#   "_cell": 1551,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigr7ufsrzamsixw2y3ozlslkbmqk2ggtaybwdq76hridqtgnbks34"
#   },
#   "_stmt_key": "52_7",
#   "_chunk_num": 52,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [52.8]: If the wavefunction that describes the two objects before their interaction is given, then the [Schrödinger equation](/wiki/Schr%C3%B6dinger_equation) provides the wavefunction that describes them after their interaction.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:presented <https://en.wikipedia.org/wiki/Schr%C3%B6dinger_equation> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "If the wavefunction that describes the two objects before their interaction is given, then the Schrödinger equation provides the wavefunction that describes them after their interaction." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibkihkhfeuqbo74lvhusoz4dtauyq75jyrthvaxoxb7mgplrbqiya",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibkihkhfeuqbo74lvhusoz4dtauyq75jyrthvaxoxb7mgplrbqiya",
#   "prov:label": "rdf:52_8",
#   "_cell": 1553,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicis4s3rmvaqgl34eycrkwp73zpgh3uysb7mg2jyi6eh5wb6ppawy"
#   },
#   "_stmt_key": "52_8",
#   "_chunk_num": 52,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [52.9]: The phenomenon known as [quantum entanglement](/wiki/quantum_entanglement) causes measuring one object to lead to an instantaneous change of the wavefunction describing the other object.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:presented <https://en.wikipedia.org/wiki/quantum_entanglement> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "The phenomenon known as quantum entanglement causes measuring one object to lead to an instantaneous change of the wavefunction describing the other object." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie5ieevaru7ahcdmsfdbdm6br2hka5qcrh6qtufua4jc7updjred4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie5ieevaru7ahcdmsfdbdm6br2hka5qcrh6qtufua4jc7updjred4",
#   "prov:label": "rdf:52_9",
#   "_cell": 1555,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibdj4mzijmokbrx4kkdkn3guytttloy2aoaox5x3nrakbj65c7eiu"
#   },
#   "_stmt_key": "52_9",
#   "_chunk_num": 52,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [52.10]: The measurement of one object can affect what wavefunction could result for the second object.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:presented <https://en.wikipedia.org/wiki/quantum_entanglement> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "The measurement of one object can affect what wavefunction could result for the second object." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidc3qamxhgwwwk2tkivxzh32kv5alt36nadfapatzmg5jzduw4hpe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidc3qamxhgwwwk2tkivxzh32kv5alt36nadfapatzmg5jzduw4hpe",
#   "prov:label": "rdf:52_10",
#   "_cell": 1557,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid4fxdee5ix5o6wfd7bydlhpyp6cnmt3sqhf4vzrmsuokpleulgwq"
#   },
#   "_stmt_key": "52_10",
#   "_chunk_num": 52,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [52.11]: [Albert Einstein](/wiki/Albert_Einstein) reasoned that no influence could propagate from the first object to the second instantaneously fast.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:reasoned <https://en.wikipedia.org/wiki/quantum_entanglement> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Albert Einstein reasoned that no influence could propagate from the first object to the second instantaneously fast." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifzzdbynhjamrbmtasmui2wkaqxcz3wcgqk2nuqgitcj44lu23kpq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifzzdbynhjamrbmtasmui2wkaqxcz3wcgqk2nuqgitcj44lu23kpq",
#   "prov:label": "rdf:52_11",
#   "_cell": 1559,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihzy7yfiegvl5cgdgeqab6x3x2luv5wzqlsttni5cctcivhzdbseu"
#   },
#   "_stmt_key": "52_11",
#   "_chunk_num": 52,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [52.12]: [Albert Einstein](/wiki/Albert_Einstein) argued that physics depends on being able to tell one thing apart from another.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:argued <https://en.wikipedia.org/wiki/quantum_entanglement> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Albert Einstein argued that physics depends on being able to tell one thing apart from another." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifn2ncjxu5a4fwtufm2tqlisoxe2inkxjlo4i2mxdrdm2aik6ykgi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifn2ncjxu5a4fwtufm2tqlisoxe2inkxjlo4i2mxdrdm2aik6ykgi",
#   "prov:label": "rdf:52_12",
#   "_cell": 1561,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieuwrvlvgvn7xucamjm2jffusfkc3op5evwg7nqmuv5i6kjqsx56i"
#   },
#   "_stmt_key": "52_12",
#   "_chunk_num": 52,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [52.13]: [Albert Einstein](/wiki/Albert_Einstein) believed that instantaneous influences would call that into question.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:believed <https://en.wikipedia.org/wiki/quantum_entanglement> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Albert Einstein believed that instantaneous influences would call that into question." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaanmonurstkmrl2xywg4rqbqkwwntcerekfd6gr6dtn2vfdlxmlm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaanmonurstkmrl2xywg4rqbqkwwntcerekfd6gr6dtn2vfdlxmlm",
#   "prov:label": "rdf:52_13",
#   "_cell": 1563,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigrtp4tkdkt6bgk6vz66vrzpok3lcihpekbwrm3nu7xe7y3ofcumu"
#   },
#   "_stmt_key": "52_13",
#   "_chunk_num": 52,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [52.14]: Because the true "physical condition" of the second object could not be immediately altered by an action done to the first, [Albert Einstein](/wiki/Albert_Einstein) concluded that the wavefunction could not be that true physical condition.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:concluded <https://en.wikipedia.org/wiki/wavefunction> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Because the true 'physical condition' of the second object could not be immediately altered by an action done to the first, Albert Einstein concluded that the wavefunction could not be that true physical condition." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaorcr6omejx7wepyxkgip6u3s4og2vuh7f32h2fuxemhhmthuwza",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaorcr6omejx7wepyxkgip6u3s4og2vuh7f32h2fuxemhhmthuwza",
#   "prov:label": "rdf:52_14",
#   "_cell": 1565,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreietwiqrdfd26dnsxfyigcastfb3qxx3cu77zia2yvg4wtxw56cygy"
#   },
#   "_stmt_key": "52_14",
#   "_chunk_num": 52,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [52.15]: [Albert Einstein](/wiki/Albert_Einstein) concluded that the wavefunction was only an incomplete description of the true physical condition.
# <https://en.wikipedia.org/wiki/Albert_Einstein> schema:concluded <https://en.wikipedia.org/wiki/wavefunction> .
# <https://en.wikipedia.org/wiki/Albert_Einstein> rdfs:comment "Albert Einstein concluded that the wavefunction was only an incomplete description of the true physical condition." .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic2t7ptvjxpp3rkvkv7dtcs3vkarickxpdxiemmy5tgnuqtsgrmqi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic2t7ptvjxpp3rkvkv7dtcs3vkarickxpdxiemmy5tgnuqtsgrmqi",
#   "prov:label": "rdf:52_15",
#   "_cell": 1567,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidlvae5jlddellu643spdlczlbaxu6cuw5uvyo3fp2nweljalasuq"
#   },
#   "_stmt_key": "52_15",
#   "_chunk_num": 52,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Chunk 53 Error: APITimeoutError: Request timed out.
# #
# # === FULL PROMPT SENT TO LLM ===
# #
# # SYSTEM PROMPT:
# # You are an expert at converting factual statements to RDF triples.
# #
# # The statements contain markdown links like [Entity Name](/wiki/Entity_Name) that provide Wikipedia URIs for entities.
# # Convert these to proper RDF URIs using: <https://en.wikipedia.org/wiki/Entity_Name>
# #
# # You have access to these tools:
# #
# # LOOKUP TOOLS (use first to find correct vocabulary):
# # - find_rdf_class: Find the best schema.org class/type for an entity
# # - find_rdf_property: Find the best predicate for a relationship
# #
# # OUTPUT TOOLS (use to emit your triples - MUST include statement_id):
# # - emit_triple: Output a single triple with statement_id
# # - emit_triples: Output multiple triples at once (more efficient)
# #
# # WORKFLOW:
# # 1. For each statement, identify what kind of fact it is (quote, employment, education, award, relationship, etc.)
# # 2. Use find_rdf_class and find_rdf_property with DESCRIPTIVE queries to find appropriate schema.org terms
# # 3. ONLY use schema matches with score >= 0.5. If no good match, skip or use rdfs:comment.
# # 4. Use emit_triple or emit_triples to output RDF triples, INCLUDING the statement_id
# #
# # QUERYING THE SCHEMA TOOLS:
# # Use descriptive natural language, not just keywords. Include:
# # - What the thing IS (for classes) or what relationship it represents (for properties)
# # - Context about domain/range when known
# #
# # GOOD QUERIES:
# # - find_rdf_class("a spoken or written quotation attributed to someone") → Quotation
# # - find_rdf_class("an organization that educates students like a university") → EducationalOrganization
# # - find_rdf_property("the text content of a quote", subject_type="Quotation") → text
# # - find_rdf_property("who said or authored a quotation", subject_type="Quotation") → creator, spokenByCharacter
# # - find_rdf_property("schools someone attended as a student", subject_type="Person") → alumniOf
# #
# # BAD QUERIES (too vague):
# # - find_rdf_class("quote") - missing context
# # - find_rdf_property("said") - doesn't explain the relationship
# # - find_rdf_property("school") - is it attended? works at? type of?
# #
# # URI RULES:
# # - For entities with Wikipedia links like [Albert Einstein](/wiki/Albert_Einstein):
# #   Use: <https://en.wikipedia.org/wiki/Albert_Einstein>
# # - For entities in the Entity Registry: Use their provided URI
# # - For new entities not in either: Use fragment URIs like <#entity_name>
# # - NEVER invent Wikidata URIs (wd:Q...) unless explicitly provided
# #
# # BLANK NODE NAMING:
# # Use the statement ID in blank node names to ensure uniqueness across chunks:
# #   - For statement [3.5], use: _:s3_5_role1, _:s3_5_role2, etc.
# #   - NOT just _:pos1, _:pos2 (these collide across statements)
# #
# # MODELING PATTERNS:
# #
# # 1. QUOTATIONS (when someone said/stated/objected something):
# #    Create a Quotation instance with text and attribution:
# #    _:s1_quote1 a schema:Quotation .
# #    _:s1_quote1 schema:text "The actual quote text" .
# #    _:s1_quote1 schema:creator <wiki:Person_Who_Said_It> .
# #
# # 2. TEMPORAL/QUALIFIED RELATIONSHIPS (dates on relationships):
# #    Use an intermediate Role node (schema.org Role pattern):
# #
# #    Example - Employment: "Einstein worked at University of Zurich from 1909 to 1911"
# #      <wiki:Albert_Einstein> schema:worksFor _:s1_role1 .
# #      _:s1_role1 a schema:OrganizationRole .
# #      _:s1_role1 schema:worksFor <wiki:University_of_Zurich> .
# #      _:s1_role1 schema:startDate "1909"^^xsd:gYear .
# #      _:s1_role1 schema:endDate "1911"^^xsd:gYear .
# #
# #    Example - Awards: "Einstein received the Nobel Prize in 1921"
# #      <wiki:Albert_Einstein> schema:award _:s2_award1 .
# #      _:s2_award1 a schema:Role .
# #      _:s2_award1 schema:award <wiki:Nobel_Prize_in_Physics> .
# #      _:s2_award1 schema:startDate "1921"^^xsd:gYear .
# #
# #    Example - Education: "Einstein attended University of Zurich from 1896 to 1900"
# #      <wiki:Albert_Einstein> schema:alumniOf _:s3_edu1 .
# #      _:s3_edu1 a schema:OrganizationRole .
# #      _:s3_edu1 schema:alumniOf <wiki:University_of_Zurich> .
# #      _:s3_edu1 schema:startDate "1896"^^xsd:gYear .
# #      _:s3_edu1 schema:endDate "1900"^^xsd:gYear .
# #
# # 3. SIMPLE FACTS (no dates/qualifiers needed):
# #    Direct triples without Role:
# #    <wiki:Einstein> schema:birthDate "1879-03-14"^^xsd:date .
# #    <wiki:Einstein> schema:birthPlace <wiki:Ulm> .
# #
# # WHAT NOT TO DO:
# # 1. DO NOT use schema:description for quotes, opinions, or narrative facts.
# #    schema:description is ONLY for describing what an entity IS, not what happened to it.
# #    WRONG: <Einstein> schema:description "God does not play dice" .
# #    RIGHT: Create a schema:Quotation with schema:text for the quote.
# #
# # 2. DO NOT emit unrelated triples when no good schema match exists.
# #    If a statement is about "being sick in bed", don't emit schema:birthDate.
# #    If no good match (score >= 0.5), either:
# #    - Skip the statement entirely
# #    - Use rdfs:comment to preserve the text: <Einstein> rdfs:comment "Statement text here" .
# #
# # 3. DO NOT conflate past and present states.
# #    "Einstein renounced his German citizenship in 1896" means he LOST it.
# #    Use endDate on a citizenship Role, not startDate.
# #
# # 4. DO NOT extract facts not stated in the statement.
# #    Only model what the specific statement says, not general knowledge about the subject.
# #
# # 5. DATES REQUIRE ROLE PATTERN - CRITICAL!
# #    If a statement mentions "from X to Y" or any year/date range, you MUST use the Role pattern.
# #    Simple triples like <Einstein> schema:worksFor <ETH> lose the temporal information.
# #
# #    Pattern: Subject → Role → Target + dates
# #    <Subject> schema:property _:role .
# #    _:role a schema:Role .           (or OrganizationRole for employment/membership)
# #    _:role schema:property <Target> .
# #    _:role schema:startDate "YYYY"^^xsd:gYear .
# #    _:role schema:endDate "YYYY"^^xsd:gYear .
# #
# # IMPORTANT:
# # - Do NOT write Turtle syntax in your response - use the emit tools instead
# # - ALWAYS include the statement_id when emitting triples
# # - Include statement_id in blank node names: _:s{{id}}_role1
# # - Only emit triples for facts that CAN be properly modeled in schema.org
# # - It is better to skip a statement than emit incorrect triples
# # - Statements with dates MUST use Role pattern (5+ triples, not 1)
# #
# # HUMAN PROMPT:
# # Convert these factual statements to RDF triples.
# #
# # Source: https://en.wikipedia.org/wiki/Albert_Einstein
# # Section context: Albert Einstein > Scientific career > Quantum mechanics > Einstein–Podolsky–Rosen paradox
# #
# # Entity Registry (use these URIs for known entities):
# # <https://en.wikipedia.org/wiki/Albert_Einstein> # Albert Einstein (Person) (Wikidata: Q937)
# # <https://en.wikipedia.org/wiki/Ulm> # Ulm (Thing)
# # <https://en.wikipedia.org/wiki/Kingdom_of_W%C3%BCrttemberg> # Kingdom of Württemberg (Thing)
# # <https://en.wikipedia.org/wiki/German_Empire> # German Empire (Thing)
# # <https://en.wikipedia.org/wiki/Princeton%2C_New_Jersey> # Princeton, New Jersey (Thing)
# # <https://en.wikipedia.org/wiki/Lieserl_Einstein> # Lieserl (Thing)
# # <https://en.wikipedia.org/wiki/Hans_Albert_Einstein> # Hans Albert (Thing)
# # <https://en.wikipedia.org/wiki/Einstein_family> # Eduard "Tete" (Thing)
# # <https://en.wikipedia.org/wiki/Einstein_family> # Einstein (Thing)
# # <https://en.wikipedia.org/wiki/Mileva_Mari%C4%87> # Mileva Marić (Thing)
# # <https://en.wikipedia.org/wiki/Elsa_L%C3%B6wenthal> # Elsa Löwenthal (Thing)
# # <https://en.wikipedia.org/wiki/Statelessness> # Stateless (Thing)
# # <https://en.wikipedia.org/wiki/Switzerland> # Switzerland (Thing)
# # <https://en.wikipedia.org/wiki/Kingdom_of_Prussia> # Kingdom of Prussia (Thing)
# # <https://en.wikipedia.org/wiki/Free_State_of_Prussia> # Free State of Prussia (Thing)
# # <https://en.wikipedia.org/wiki/Weimar_Republic> # Weimar Republic (Thing)
# # <https://en.wikipedia.org/wiki/Citizenship_of_the_United_States> # United States (Thing)
# # <https://en.wikipedia.org/wiki/Physics> # Physics (Thing)
# # <https://en.wikipedia.org/wiki/University_of_Bern> # University of Bern (Thing)
# # <https://en.wikipedia.org/wiki/University_of_Zurich> # University of Zurich (Thing)
# # <https://en.wikipedia.org/wiki/Charles_University_in_Prague> # Charles University in Prague (Thing)
# # <https://en.wikipedia.org/wiki/ETH_Zurich> # ETH Zurich (Thing)
# # <https://en.wikipedia.org/wiki/Prussian_Academy_of_Sciences> # Prussian Academy of Sciences (Thing)
# # <https://en.wikipedia.org/wiki/Humboldt_University_of_Berlin> # Humboldt University of Berlin (Thing)
# # <https://en.wikipedia.org/wiki/Kaiser_Wilhelm_Institute> # Kaiser Wilhelm Institute (Thing)
# # <https://en.wikipedia.org/wiki/German_Physical_Society> # German Physical Society (Thing)
# # <https://en.wikipedia.org/wiki/Institute_for_Advanced_Study> # Institute for Advanced Study (Thing)
# # <https://en.wikipedia.org/wiki/ETH_Zurich> # Swiss Federal Polytechnic School (Thing)
# # <https://en.wikipedia.org/wiki/PhD> # PhD (Thing)
# # <https://en.wikipedia.org/wiki/Alfred_Kleiner> # Alfred Kleiner (Thing)
# # <https://en.wikipedia.org/wiki/Heinrich_Friedrich_Weber> # Heinrich Friedrich Weber (Thing)
# # <https://en.wikipedia.org/wiki/General_relativity> # General relativity (Thing)
# # <https://en.wikipedia.org/wiki/Special_relativity> # Special relativity (Thing)
# # <https://en.wikipedia.org/wiki/Photoelectric_effect> # Photoelectric effect (Thing)
# # <https://en.wikipedia.org/wiki/Mass%E2%80%93energy_equivalence> # ''E''=''mc''<sup>2</sup> (mass–energy equivalence) (Thing)
# # <https://en.wikipedia.org/wiki/Planck%E2%80%93Einstein_relation> # ''E''=''hf'' (Planck–Einstein relation) (Thing)
# # <https://en.wikipedia.org/wiki/Brownian_motion> # Theory of Brownian motion (Thing)
# # <https://en.wikipedia.org/wiki/Einstein_field_equations> # Einstein field equations (Thing)
# # <https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_statistics> # Bose–Einstein statistics (Thing)
# # <https://en.wikipedia.org/wiki/Bose%E2%80%93Einstein_condensate> # Bose–Einstein condensate (Thing)
# # <https://en.wikipedia.org/wiki/Gravitational_wave> # Gravitational wave (Thing)
# # <https://en.wikipedia.org/wiki/Cosmological_constant> # Cosmological constant (Thing)
# # <https://en.wikipedia.org/wiki/Unified_field_theory> # Unified field theory (Thing)
# # <https://en.wikipedia.org/wiki/EPR_paradox> # EPR paradox (Thing)
# # <https://en.wikipedia.org/wiki/Ensemble_interpretation> # Ensemble interpretation (Thing)
# # <https://en.wikipedia.org/wiki/List_of_things_named_after_Albert_Einstein> # List of other concepts (Thing)
# # <https://en.wikipedia.org/wiki/Barnard_Medal_for_Meritorious_Service_to_Science> # Barnard Medal for Meritorious Service to Science (Thing)
# # <https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics> # Nobel Prize in Physics (Thing)
# # <https://en.wikipedia.org/wiki/Matteucci_Medal> # Matteucci Medal (Thing)
# # <https://en.wikipedia.org/wiki/List_of_fellows_of_the_Royal_Society_elected_in_1921> # ForMemRS (Thing)
# # <https://en.wikipedia.org/wiki/Copley_Medal> # Copley Medal (Thing)
# #
# # Statements to convert (each has a unique ID like [3.5] - include this in blank node names):
# # [1] [Albert Einstein](/wiki/Albert_Einstein) published a paper in 1935 with [Boris Podolsky](/wiki/Boris_Podolsky) and [Nathan Rosen](/wiki/Nathan_Rosen).
# # [2] The paper published by [Albert Einstein](/wiki/Albert_Einstein), [Boris Podolsky](/wiki/Boris_Podolsky), and [Nathan Rosen](/wiki/Nathan_Rosen) in 1935 laid out what would become known as the [EPR paradox](/wiki/EPR_paradox).
# # [3] In the [EPR paradox](/wiki/EPR_paradox), two particles interact in such a way that the wavefunction describing them is entangled.
# # [4] In the [EPR paradox](/wiki/EPR_paradox), no matter how far the two entangled particles were separated, a precise position measurement on one particle would imply the ability to predict, perfectly, the result of measuring the position of the other particle.
# # [5] In the [EPR paradox](/wiki/EPR_paradox), a precise momentum measurement of one particle would result in an equally precise prediction for the momentum of the other particle, without needing to disturb the other particle in any way.
# # [6] [Albert Einstein](/wiki/Albert_Einstein), [Boris Podolsky](/wiki/Boris_Podolsky), and [Nathan Rosen](/wiki/Nathan_Rosen) argued that no action taken on the first particle could instantaneously affect the other, since this would involve information being transmitted faster than light, which is forbidden by the [theory of relativity](/wiki/theory_of_relativity).
# # [7] [Albert Einstein](/wiki/Albert_Einstein), [Boris Podolsky](/wiki/Boris_Podolsky), and [Nathan Rosen](/wiki/Nathan_Rosen) invoked a principle later known as the "EPR criterion of reality".
# # [8] The "EPR criterion of reality" posits that: "If, without in any way disturbing a system, we can predict with certainty (i.e., with [probability](/wiki/probability) equal to unity) the value of a physical quantity, then there exists an element of reality corresponding to that quantity."
# # [9] From the "EPR criterion of reality", [Albert Einstein](/wiki/Albert_Einstein), [Boris Podolsky](/wiki/Boris_Podolsky), and [Nathan Rosen](/wiki/Nathan_Rosen) inferred that the second particle must have a definite value of both position and of momentum prior to either quantity being measured.
# # [10] Quantum mechanics considers the observables of position and momentum [incompatible](/wiki/Observable) and thus does not associate simultaneous values for both to any system.
# # [11] [Albert Einstein](/wiki/Albert_Einstein), [Boris Podolsky](/wiki/Boris_Podolsky), and [Nathan Rosen](/wiki/Nathan_Rosen) concluded that quantum theory does not provide a complete description of reality.
# #
# # CRITICAL RULES:
# #
# # 1. URI EXTRACTION: Convert markdown links to Wikipedia URIs:
# #    [Albert Einstein](/wiki/Albert_Einstein) → <https://en.wikipedia.org/wiki/Albert_Einstein>
# #
# # 2. BLANK NODE NAMING: Include statement ID to avoid collisions:
# #    For statement [3.5], use: _:s3_5_role1 (NOT just _:role1)
# #
# # 3. SCHEMA MATCHING: Only use matches with score >= 0.5.
# #    If no good match exists, either skip the statement or use rdfs:comment.
# #
# # 4. TEMPORAL RELATIONSHIPS - MANDATORY ROLE PATTERN:
# #    If a statement has dates like "from X to Y" or year ranges, you MUST use the Role pattern.
# #    A simple triple loses the temporal information - DO NOT emit just:
# #      <Einstein> schema:employee <ETH_Zurich> .  ← WRONG! Loses the dates!
# #
# #    CORRECT Role Pattern (REQUIRED for dated relationships):
# #    Statement: "Einstein worked at ETH Zurich from 1912 to 1914"
# #      <https://en.wikipedia.org/wiki/Albert_Einstein> schema:worksFor _:s1_21_role1 .
# #      _:s1_21_role1 a schema:OrganizationRole .
# #      _:s1_21_role1 schema:worksFor <https://en.wikipedia.org/wiki/ETH_Zurich> .
# #      _:s1_21_role1 schema:startDate "1912"^^xsd:gYear .
# #      _:s1_21_role1 schema:endDate "1914"^^xsd:gYear .
# #
# #    Statement: "Einstein was a citizen of Switzerland from 1901 to 1955"
# #      <https://en.wikipedia.org/wiki/Albert_Einstein> schema:nationality _:s1_14_role1 .
# #      _:s1_14_role1 a schema:Role .
# #      _:s1_14_role1 schema:nationality <https://en.wikipedia.org/wiki/Switzerland> .
# #      _:s1_14_role1 schema:startDate "1901"^^xsd:gYear .
# #      _:s1_14_role1 schema:endDate "1955"^^xsd:gYear .
# #
# #    Use OrganizationRole for employment/membership, Role for citizenship/other.
# #
# # 5. DO NOT:
# #    - Use schema:description for quotes or narrative (only for entity descriptions)
# #    - Emit unrelated triples when no good match exists
# #    - Extract facts not stated in the statement
# #    - Emit simple triples when there are dates (MUST use Role pattern)
# #
# # Process each statement. If you cannot properly model it, skip it or use rdfs:comment.
# #
# # === END PROMPT ===
