# %% [markdown]
# # RDF Triples: Albert Einstein
#
# ## Provenance
#
# ```yaml
# source_url: https://en.wikipedia.org/wiki/Albert_Einstein
# article_title: Albert Einstein
# license: CC BY-SA 4.0
# license_url: https://creativecommons.org/licenses/by-sa/4.0/
# source_notebook: facts.ipynb
# generated_by: wiki_to_kg_pipeline.ipynb
# generated_at: 2025-12-19T06:58:53.858259
# llm_provider: lm_studio
# llm_model: qwen/qwen3-coder-30b
# llm_temperature: 1
# rdf_format: Turtle
# ```
#
# ## RDF Prefixes
#
# ```turtle
# @prefix schema: <https://schema.org/> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix wiki3: <https://wiki3.ai/vocab/> .
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix repro: <https://w3id.org/reproduceme#> .
# @prefix pplan: <http://purl.org/net/p-plan#> .
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @base <https://en.wikipedia.org/wiki/Albert_Einstein> .
#
# ```
#
# ## Processing Instructions
#
# This notebook contains RDF triples in Turtle format, one cell per source statement.
# Each content cell is followed by a signature cell with CID provenance.
#
# To regenerate a specific cell: delete both the content cell and its signature, then re-run the pipeline.
#
# ## Prompt Template
#
# ```
# You are an expert at converting factual statements to RDF triples in Turtle format.
#
# Convert the following factual statements to RDF using schema.org vocabulary where possible.
#
# Source: {source_url}
# Section: {breadcrumb}
#
# Use these prefixes:
# {prefixes}
#
# Entity registry (use these URIs):
# {entity_registry}
#
# Guidelines:
# - Use schema.org properties (schema:birthDate, schema:birthPlace, schema:worksFor, etc.)
# - For relationships not in schema.org, use wiki3: prefix
# - Include rdfs:label for entities
# - Use xsd datatypes for dates and numbers
# - Entity URIs should use the source URL as base with fragment identifiers
#
# ---
# {facts}
# ---
#
# Generate Turtle RDF:
#
# ```

# %% [raw]
# {
#   "source_url": "https://en.wikipedia.org/wiki/Albert_Einstein",
#   "entities": {
#     "albert_einstein": {
#       "id": "person_albert_einstein",
#       "uri": "https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein",
#       "label": "Albert Einstein",
#       "type": "Person",
#       "descriptions": [
#         "Subject of Wikipedia article: Albert Einstein"
#       ],
#       "source_chunks": [],
#       "aliases": [
#         "Einstein"
#       ]
#     }
#   },
#   "aliases": {
#     "einstein": "albert_einstein"
#   }
# }

# %% [raw]
# # Statement [1.1]: Albert Einstein was a German-born theoretical physicist.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Theoretical physicist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality <https://www.wikidata.org/wiki/Q183> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:jobTitle "Theoretical physicist" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality <https://www.wikidata.org/wiki/Q183> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicxz66m7d767qn2bkycaw6grgovpazqka6xzmwulohesqctnv5nj4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicxz66m7d767qn2bkycaw6grgovpazqka6xzmwulohesqctnv5nj4",
#   "prov:label": "rdf:1_1",
#   "_cell": 2,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidzxkexaeiao5uxciqnucsadz3cod2fglntxhpkxdaorcqeg64fdu"
#   },
#   "_stmt_key": "1_1",
#   "_chunk_num": 1,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [1.2]: Albert Einstein developed the theory of relativity.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifok55yvgjqijwqu7aniilcre2jwklsvlwamog5fv7v4r7ynplafm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifok55yvgjqijwqu7aniilcre2jwklsvlwamog5fv7v4r7ynplafm",
#   "prov:label": "rdf:1_2",
#   "_cell": 4,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreic2kqscf7ptx4tdwafdmkeymott6wbzjqmtinefpwvfr52owmg5iq"
#   },
#   "_stmt_key": "1_2",
#   "_chunk_num": 1,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [1.3]: Albert Einstein made important contributions to quantum theory.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Physicist" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaa434j7eitdt5ua6siz5ajpmksqegv7xilattgbny5lfhba7capu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaa434j7eitdt5ua6siz5ajpmksqegv7xilattgbny5lfhba7capu",
#   "prov:label": "rdf:1_3",
#   "_cell": 6,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifh35pocaccr3gcvtouuyepbycyjtflp2szcbprnidytyptrfv5qq"
#   },
#   "_stmt_key": "1_3",
#   "_chunk_num": 1,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [1.4]: Albert Einstein's mass–energy equivalence formula E = mc2 arises from special relativity.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Theoretical physicist" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreideosxjx47kqul6csrtsqpgwnoulw76geiogxtbs67c56xvivozoe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreideosxjx47kqul6csrtsqpgwnoulw76geiogxtbs67c56xvivozoe",
#   "prov:label": "rdf:1_4",
#   "_cell": 8,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiblioxiopkfsgu3mletskewrbyojs4xqgo7l3cr7wtxjvkjk55lsu"
#   },
#   "_stmt_key": "1_4",
#   "_chunk_num": 1,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [1.5]: Albert Einstein received the 1921 Nobel Prize in Physics.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "1921 Nobel Prize in Physics" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiavqpznjaeovklrs35npwvurwb4ip3hzicakx5eioqsk6boy6xppa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiavqpznjaeovklrs35npwvurwb4ip3hzicakx5eioqsk6boy6xppa",
#   "prov:label": "rdf:1_5",
#   "_cell": 10,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreif2ejaq6jvtpscboo4nvyhcsxp6hn6nnibt6fd2zkxqxc4m7ecjqq"
#   },
#   "_stmt_key": "1_5",
#   "_chunk_num": 1,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [1.6]: Albert Einstein was born on 14 March 1879.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiax57mtbasp5775nd7atnz6bdpx2ahvzjjjfug3w6sei7wq64lw7q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiax57mtbasp5775nd7atnz6bdpx2ahvzjjjfug3w6sei7wq64lw7q",
#   "prov:label": "rdf:1_6",
#   "_cell": 12,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiglvpvjmaoqwvr4fniry4z5d26jgonjgrwpfzrajhet7pv272kj4y"
#   },
#   "_stmt_key": "1_6",
#   "_chunk_num": 1,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [1.7]: Albert Einstein died on 18 April 1955.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihs3slpmftupknllcc2sh56lkt7n7vrcwvh6rg6g7dghsf6zasrmu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihs3slpmftupknllcc2sh56lkt7n7vrcwvh6rg6g7dghsf6zasrmu",
#   "prov:label": "rdf:1_7",
#   "_cell": 14,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifq4z7yaxzo74os56xmfqgqjbhcv6t4hmpsetz7wgmtcj5nzkxuvq"
#   },
#   "_stmt_key": "1_7",
#   "_chunk_num": 1,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [1.8]: Albert Einstein moved to Switzerland in 1895.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:residence "Switzerland" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidymubcpblz5fstrfsaaelp4dqa4vge4t32gicx226pc6jmrozl3q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidymubcpblz5fstrfsaaelp4dqa4vge4t32gicx226pc6jmrozl3q",
#   "prov:label": "rdf:1_8",
#   "_cell": 16,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihg3uj7fbo3raaaumbchdsbbrlzrgao63zigzppetsq5jq4iiwmd4"
#   },
#   "_stmt_key": "1_8",
#   "_chunk_num": 1,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [1.9]: Albert Einstein forsaking his German citizenship in 1896.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "German" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibxl3a5g37ycmrhopbefd2fpnvp2srb3yuojjpyh5b6i5vtusqc5i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibxl3a5g37ycmrhopbefd2fpnvp2srb3yuojjpyh5b6i5vtusqc5i",
#   "prov:label": "rdf:1_9",
#   "_cell": 18,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidsbzdftrk2hkjg2o34dvqyvaxrzwukbp3aas7pjbxbcjtcrjc3le"
#   },
#   "_stmt_key": "1_9",
#   "_chunk_num": 1,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [1.10]: Albert Einstein enrolled in the mathematics and physics teaching diploma program at the Swiss federal polytechnic school in Zurich in 1897.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Swiss Federal Polytechnic School" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifv273oxly6ipdnnmhr65a3hzjzcqgaiv6vnwwb2ydcfcrs4pzs2q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifv273oxly6ipdnnmhr65a3hzjzcqgaiv6vnwwb2ydcfcrs4pzs2q",
#   "prov:label": "rdf:1_10",
#   "_cell": 20,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaebhdtdbesbwhrqmszrn45f4omi273x2emjctsnrrpneraulkw2m"
#   },
#   "_stmt_key": "1_10",
#   "_chunk_num": 1,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [1.11]: Albert Einstein graduated from the Swiss federal polytechnic school in Zurich in 1900.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "University of Zurich" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihkxyc4j445gzpj3b443el2jp2gfraay32jspkg7b7tmsorhig6mu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihkxyc4j445gzpj3b443el2jp2gfraay32jspkg7b7tmsorhig6mu",
#   "prov:label": "rdf:1_11",
#   "_cell": 22,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiewfwx3bo4viysondkuegr25jzhkmpljwt774lsdmtl3dymblxwga"
#   },
#   "_stmt_key": "1_11",
#   "_chunk_num": 1,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [1.12]: Albert Einstein acquired Swiss citizenship in 1901.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "Swiss" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifk625tqz7zaf6c4v65z4owp4tqhfxabl3jpkblcwplp37lsupvbq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifk625tqz7zaf6c4v65z4owp4tqhfxabl3jpkblcwplp37lsupvbq",
#   "prov:label": "rdf:1_12",
#   "_cell": 24,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigceipseak6utdqshowt3idybc2stsgyhojkysvoqg3vev7pqsary"
#   },
#   "_stmt_key": "1_12",
#   "_chunk_num": 1,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [1.13]: Albert Einstein worked at the Swiss Patent Office in Bern.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor "Swiss Patent Office" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreif2nlu6xekj6vwts53b5j3m4nzzxvobkbufm6obj2e7i5x6d3cutu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreif2nlu6xekj6vwts53b5j3m4nzzxvobkbufm6obj2e7i5x6d3cutu",
#   "prov:label": "rdf:1_13",
#   "_cell": 26,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia5dcbo4jffx7qup2fgxllzpmlvigt4cxgvqsvw5ryzoicyad6ota"
#   },
#   "_stmt_key": "1_13",
#   "_chunk_num": 1,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [1.14]: Albert Einstein submitted a successful PhD dissertation to the University of Zurich in 1905.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Academic" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidslqboxnvjlqltzwa62d3q3p6qvwxhmf4ko3rv2vitlsjkhidsja",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidslqboxnvjlqltzwa62d3q3p6qvwxhmf4ko3rv2vitlsjkhidsja",
#   "prov:label": "rdf:1_14",
#   "_cell": 28,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigjkoe4gidntmsxrckusfr7v4bk2iyinkll3cjlunp4mnibwoir3y"
#   },
#   "_stmt_key": "1_14",
#   "_chunk_num": 1,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [1.15]: Albert Einstein moved to Berlin in 1914.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:residence "Berlin" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaxqgggng6sgx3mtsnxykgoba5rzzbxewctmg3fa333du4uzy2zzm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaxqgggng6sgx3mtsnxykgoba5rzzbxewctmg3fa333du4uzy2zzm",
#   "prov:label": "rdf:1_15",
#   "_cell": 30,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibz3xclkm547wg4ctp6bx47icqtqg24nlmr4yb4rcacip25fvzwgu"
#   },
#   "_stmt_key": "1_15",
#   "_chunk_num": 1,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [1.16]: Albert Einstein joined the Prussian Academy of Sciences in Berlin in 1914.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor "Prussian Academy of Sciences" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreig5ss5fbjnhmr4g4kandrujqwq45untobig72iapflmo5ph6t5rva",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreig5ss5fbjnhmr4g4kandrujqwq45untobig72iapflmo5ph6t5rva",
#   "prov:label": "rdf:1_16",
#   "_cell": 32,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigzwd5lisdnrd2xv7cxj6l65ii5ybcfxz5rwhas2fgkdecdampajm"
#   },
#   "_stmt_key": "1_16",
#   "_chunk_num": 1,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [1.17]: Albert Einstein joined the Humboldt University of Berlin in 1914.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:worksFor "Humboldt University of Berlin" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiflnz6qow5nxldttaqhf4rv7nfayt3dejsmirrore6mzv6r6qhzy4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiflnz6qow5nxldttaqhf4rv7nfayt3dejsmirrore6mzv6r6qhzy4",
#   "prov:label": "rdf:1_17",
#   "_cell": 34,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiga4lthptk5toteo3znmayv3tdktzceu5tnmask4f7yvigzub6ni4"
#   },
#   "_stmt_key": "1_17",
#   "_chunk_num": 1,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [1.18]: Albert Einstein became director of the Kaiser Wilhelm Institute for Physics in 1917.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreielsoridfqeq4j4xevtuqgtcavbtmpuo7enmd4yiy63ylbo6gpqku",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreielsoridfqeq4j4xevtuqgtcavbtmpuo7enmd4yiy63ylbo6gpqku",
#   "prov:label": "rdf:1_18",
#   "_cell": 36,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiftpf2asjzobxcefikewgpox3sywreanqn2sb7xe63ggqhobani64"
#   },
#   "_stmt_key": "1_18",
#   "_chunk_num": 1,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [1.19]: Albert Einstein became a German citizen again in 1914.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "German" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidcvbvvwujrie33rbnycm3iwgq7lj5btflz4x6uerz7onlc6n4qdi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidcvbvvwujrie33rbnycm3iwgq7lj5btflz4x6uerz7onlc6n4qdi",
#   "prov:label": "rdf:1_19",
#   "_cell": 38,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifvty5nfzjwtoz3uuuzqg6fclmuoykzj2pcbu22eqcf7pambjs6ge"
#   },
#   "_stmt_key": "1_19",
#   "_chunk_num": 1,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Statement [1.20]: Albert Einstein was a subject of the Kingdom of Prussia.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "Prussian" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreih4343hjtvkfx6yc5b6zjz3yzjmkrryf4g4baip7f43be4afqjisi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreih4343hjtvkfx6yc5b6zjz3yzjmkrryf4g4baip7f43be4afqjisi",
#   "prov:label": "rdf:1_20",
#   "_cell": 40,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreida3wrtlnkrmnwknwdadzmsas5fwf5ci2jkydrny2q4q7675cgcbq"
#   },
#   "_stmt_key": "1_20",
#   "_chunk_num": 1,
#   "_stmt_idx": 20
# }

# %% [raw]
# # Statement [1.21]: Adolf Hitler came to power in Germany in 1933.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibqlojep7jik6jd7apj36ba25agg7h6kbhtb3kfpaerp3l6p2uw7m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibqlojep7jik6jd7apj36ba25agg7h6kbhtb3kfpaerp3l6p2uw7m",
#   "prov:label": "rdf:1_21",
#   "_cell": 42,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibspspd2d7brd2ulg4j5u5cmjuyez6jd6m47hra25cquejiec5nv4"
#   },
#   "_stmt_key": "1_21",
#   "_chunk_num": 1,
#   "_stmt_idx": 21
# }

# %% [raw]
# # Statement [1.22]: Albert Einstein was visiting the United States when Adolf Hitler came to power in Germany.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:residence "United States" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihqwajlykfgfyzjgr4dya5m5k5xyyj2t4bpnbr4yi4wi5spfepazi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihqwajlykfgfyzjgr4dya5m5k5xyyj2t4bpnbr4yi4wi5spfepazi",
#   "prov:label": "rdf:1_22",
#   "_cell": 44,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreie2iyohvsklcfp7g4dqudavyw7vclcjtyg6b7alh5alcdziyc2umi"
#   },
#   "_stmt_key": "1_22",
#   "_chunk_num": 1,
#   "_stmt_idx": 22
# }

# %% [raw]
# # Statement [1.23]: Albert Einstein decided to remain in the United States after Adolf Hitler came to power in Germany.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "American" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidvflt6u3ghy6fenjcuac27phso22jmaz7sk5agjltd4a5sd6fpv4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidvflt6u3ghy6fenjcuac27phso22jmaz7sk5agjltd4a5sd6fpv4",
#   "prov:label": "rdf:1_23",
#   "_cell": 46,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibeewy2fz3ubxgihvfbzgprqz23pjcd4w2ksjfo4splmaobmqt3sy"
#   },
#   "_stmt_key": "1_23",
#   "_chunk_num": 1,
#   "_stmt_idx": 23
# }

# %% [raw]
# # Statement [1.24]: Albert Einstein was granted American citizenship in 1940.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "U.S. Citizenship" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiamq3ppuzbczv5jbk27z3xeam2kwczrry2ecxc3n4tkp6bf4lt5qq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiamq3ppuzbczv5jbk27z3xeam2kwczrry2ecxc3n4tkp6bf4lt5qq",
#   "prov:label": "rdf:1_24",
#   "_cell": 48,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibazw7h272lghwhb4al5fjnnk2fkoazewgxihbc267srvlvb542bq"
#   },
#   "_stmt_key": "1_24",
#   "_chunk_num": 1,
#   "_stmt_idx": 24
# }

# %% [raw]
# # Statement [1.25]: Albert Einstein endorsed a letter to President Franklin D. Roosevelt on the eve of World War II.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigrpj3n6ab5dloetpmbyeex4j473hr5hkugq6cggbs3cmwfiot6jq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigrpj3n6ab5dloetpmbyeex4j473hr5hkugq6cggbs3cmwfiot6jq",
#   "prov:label": "rdf:1_25",
#   "_cell": 50,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifzsuwyvva6qr7hg6j4z2hnrhl5vrz7troyorbfnwa3kac7cp2l7q"
#   },
#   "_stmt_key": "1_25",
#   "_chunk_num": 1,
#   "_stmt_idx": 25
# }

# %% [raw]
# # Statement [1.26]: President Franklin D. Roosevelt received a letter from Albert Einstein on the eve of World War II.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifckibhb7v5tnkzptklfturdi5zch7a7gaxds5kzsbi6jur4srgbi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifckibhb7v5tnkzptklfturdi5zch7a7gaxds5kzsbi6jur4srgbi",
#   "prov:label": "rdf:1_26",
#   "_cell": 52,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaasdmvirz5mcwobicjxwaitz7rg2waa667pvgxtjlyb6rlpokwtu"
#   },
#   "_stmt_key": "1_26",
#   "_chunk_num": 1,
#   "_stmt_idx": 26
# }

# %% [raw]
# # Statement [1.27]: Albert Einstein alerted President Franklin D. Roosevelt to the potential German nuclear weapons program.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifjibmsgluc5miyazpniwvs2skbmcfqdlmnvvvkvhpvnuek5fxhi4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifjibmsgluc5miyazpniwvs2skbmcfqdlmnvvvkvhpvnuek5fxhi4",
#   "prov:label": "rdf:1_27",
#   "_cell": 54,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieuitlmj5rarzxjsf55aka6wlfsn7yg4mtfulvxnijlbn2yqekiyq"
#   },
#   "_stmt_key": "1_27",
#   "_chunk_num": 1,
#   "_stmt_idx": 27
# }

# %% [raw]
# # Statement [1.28]: Albert Einstein recommended that the United States begin similar research to the German nuclear weapons program.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifbegjq26cplzdm4ly6hkliyrurfm4e7c2cp7vqspzunryur5v3pm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifbegjq26cplzdm4ly6hkliyrurfm4e7c2cp7vqspzunryur5v3pm",
#   "prov:label": "rdf:1_28",
#   "_cell": 56,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaebrt5io2xha6ya4pu47xm4zsrft7vot6zmb7ldiwzllpyrsblhu"
#   },
#   "_stmt_key": "1_28",
#   "_chunk_num": 1,
#   "_stmt_idx": 28
# }

# %% [raw]
# # Statement [1.29]: The Manhattan Project was carried out as a result of Albert Einstein's recommendation.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "Scientist" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifpyqcwnfbitln6wzuvrqtts7gih2xxku2bhn7p4smpvu733qmqqy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifpyqcwnfbitln6wzuvrqtts7gih2xxku2bhn7p4smpvu733qmqqy",
#   "prov:label": "rdf:1_29",
#   "_cell": 58,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifil3cydve6var4dym7p2lexunbom6iqunpzlx2wncz6p6wopjshu"
#   },
#   "_stmt_key": "1_29",
#   "_chunk_num": 1,
#   "_stmt_idx": 29
# }

# %% [raw]
# # Statement [2.1]: In 1905, Albert Einstein published four groundbreaking papers.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Researcher .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Researcher .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1905"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidpadclsjz7pzqqjjswoiqqouhxfae2tyetr55kz5zjakcsywm4y4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidpadclsjz7pzqqjjswoiqqouhxfae2tyetr55kz5zjakcsywm4y4",
#   "prov:label": "rdf:2_1",
#   "_cell": 60,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicsv26jwqmj7f6fkd6lx45lzpf2tchmqogyqojbtvg6vkkhggxqra"
#   },
#   "_stmt_key": "2_1",
#   "_chunk_num": 2,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [2.2]: In 1905, the year 1905 is sometimes described as Albert Einstein's annus mirabilis.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1905"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic24nv33kw7vgvppgzoefepw4pujz5jchzyqglrotmpnmbnfez7bq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic24nv33kw7vgvppgzoefepw4pujz5jchzyqglrotmpnmbnfez7bq",
#   "prov:label": "rdf:2_2",
#   "_cell": 62,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigmzllxm6kh2ycp6y4lo3bpmbhss2i7gqvgx43tzkljxwxe5677pe"
#   },
#   "_stmt_key": "2_2",
#   "_chunk_num": 2,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [2.3]: In 1905, Albert Einstein outlined a theory of the photoelectric effect in one of his four groundbreaking papers.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1905"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihflbt4xkreivbxpbczke3nmsasfpl6pdm2eoavijxfq73pbxcdb4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihflbt4xkreivbxpbczke3nmsasfpl6pdm2eoavijxfq73pbxcdb4",
#   "prov:label": "rdf:2_3",
#   "_cell": 64,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiggqylmko37i4t26ywjxatdwei4mounym2yzkm6bx4bqynllv4yja"
#   },
#   "_stmt_key": "2_3",
#   "_chunk_num": 2,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [2.4]: In 1905, Albert Einstein explained Brownian motion in one of his four groundbreaking papers.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1905"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibxe3qlzcnojlrkcajdnooyvrukeitpljgz72ycsi4ndzzgkb6nfq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibxe3qlzcnojlrkcajdnooyvrukeitpljgz72ycsi4ndzzgkb6nfq",
#   "prov:label": "rdf:2_4",
#   "_cell": 66,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiamqfseoefavvhwz6finxyfb7pslzv6dkizv34ujrcok4yrr5bpgi"
#   },
#   "_stmt_key": "2_4",
#   "_chunk_num": 2,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [2.5]: In 1905, Albert Einstein introduced his special theory of relativity in one of his four groundbreaking papers.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1905"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreib3jpfdb6lymhaj43hmloo2t37ktyr32bil6mx2qb6bdth33o3v5e",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreib3jpfdb6lymhaj43hmloo2t37ktyr32bil6mx2qb6bdth33o3v5e",
#   "prov:label": "rdf:2_5",
#   "_cell": 68,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreierh4h3gfol3eh7jgdi2cu5b53bb6kvmyli6oxaxptq244e77ufqq"
#   },
#   "_stmt_key": "2_5",
#   "_chunk_num": 2,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [2.6]: In 1905, Albert Einstein demonstrated that if the special theory of relativity is correct, mass and energy are equivalent to each other.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1905"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieay35hgjh56xwxur2gg5jr2m726iyuf6o47qh62buuargmub4q7m",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieay35hgjh56xwxur2gg5jr2m726iyuf6o47qh62buuargmub4q7m",
#   "prov:label": "rdf:2_6",
#   "_cell": 70,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihtqhw4dwbaolghj4ffvkbtge5xgr4d3mmqzem6uuvfrdomnxuwuy"
#   },
#   "_stmt_key": "2_6",
#   "_chunk_num": 2,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [2.7]: In 1915, Albert Einstein proposed a general theory of relativity.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1915"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia2cyuq443tzpgd2k6js3voejqfmopss3gt6hgdez2flbp2a5lzwu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia2cyuq443tzpgd2k6js3voejqfmopss3gt6hgdez2flbp2a5lzwu",
#   "prov:label": "rdf:2_7",
#   "_cell": 72,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicwstfez2g7n6y47l2fgtj5hdy6tirg3wdj7scif2eubnkxfqaola"
#   },
#   "_stmt_key": "2_7",
#   "_chunk_num": 2,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [2.8]: In 1915, the general theory of relativity that Albert Einstein proposed extended his system of mechanics to incorporate gravitation.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1915"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihazl22tq7kq2ibg462cmzz7h6ijn5gkhykyfhzanb2yrzgmu7foy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihazl22tq7kq2ibg462cmzz7h6ijn5gkhykyfhzanb2yrzgmu7foy",
#   "prov:label": "rdf:2_8",
#   "_cell": 74,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibbjzf3baemz64tfimfugppt6z26mdn5dend7v4b5e5yshkgz3wh4"
#   },
#   "_stmt_key": "2_8",
#   "_chunk_num": 2,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [2.9]: In 1916, Albert Einstein published a paper that laid out the implications of general relativity for the modeling of the structure and evolution of the universe as a whole.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1916"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigb3qopd7wehrchtd7pdkrjs26qdfhstemmmp7obsol37euy7pwcu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigb3qopd7wehrchtd7pdkrjs26qdfhstemmmp7obsol37euy7pwcu",
#   "prov:label": "rdf:2_9",
#   "_cell": 76,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifn65yiyoxj77krhgszp5p3w7tqejhjl7jcy2kgrsxedid3rydkbm"
#   },
#   "_stmt_key": "2_9",
#   "_chunk_num": 2,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [2.10]: In 1916, the paper published by Albert Einstein the following year introduced the cosmological constant.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1916"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigzlftdgs3afpd5vk6yejhdkesfzu6razpt27qha6kxbhavvtukaq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigzlftdgs3afpd5vk6yejhdkesfzu6razpt27qha6kxbhavvtukaq",
#   "prov:label": "rdf:2_10",
#   "_cell": 78,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreietm4s7qgy3krxjjymobnhkg3dmu7vqf6bp5xhlzzw55nfrex4ybi"
#   },
#   "_stmt_key": "2_10",
#   "_chunk_num": 2,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [2.11]: In 1916, the paper published by Albert Einstein the following year is regarded as the first step in the field of modern theoretical cosmology.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1916"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreia4ex77cyibgsbsffcvcidipofp6g6x5myqy4ymos2umalwaz2bmu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreia4ex77cyibgsbsffcvcidipofp6g6x5myqy4ymos2umalwaz2bmu",
#   "prov:label": "rdf:2_11",
#   "_cell": 80,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreif6x7edrs63vxmhdbxqiuhnz3ndjdyx4f6vjrb67q7h25mo3dgwmy"
#   },
#   "_stmt_key": "2_11",
#   "_chunk_num": 2,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [2.12]: In 1917, Albert Einstein wrote a paper.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1917"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibgfsgjffp5vvs6zzgili7mh3tfwj2sa7j5r4bylhw3rh6z4tixde",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibgfsgjffp5vvs6zzgili7mh3tfwj2sa7j5r4bylhw3rh6z4tixde",
#   "prov:label": "rdf:2_12",
#   "_cell": 82,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaq6rcgqjswdstzj5ztlhxpfglir4gdx5k6gyt4gnojmnpn3urlea"
#   },
#   "_stmt_key": "2_12",
#   "_chunk_num": 2,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [2.13]: In 1917, the paper written by Albert Einstein introduced the concepts of spontaneous emission and stimulated emission.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1917"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreid2nff7meo45oo6ldeouasq4na6vjtcfrnbumzitpguogiqgwvkqu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreid2nff7meo45oo6ldeouasq4na6vjtcfrnbumzitpguogiqgwvkqu",
#   "prov:label": "rdf:2_13",
#   "_cell": 84,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihbstd7wo2hlpxzg2nsej3qjxzfwbqhmci4nawagmbz6dmob56leq"
#   },
#   "_stmt_key": "2_13",
#   "_chunk_num": 2,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [2.14]: In 1917, the paper written by Albert Einstein contained information that would be beneficial to developments in physics later on, such as quantum electrodynamics and quantum optics.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1917"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieqcrpbkobkddgzvvoq5yhyft6nhk2o2cxxvq4mivdxnaf63rjzgu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieqcrpbkobkddgzvvoq5yhyft6nhk2o2cxxvq4mivdxnaf63rjzgu",
#   "prov:label": "rdf:2_14",
#   "_cell": 86,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidtoiq3hewggwbmdmql4aztkthvfnnaaf5chswslmpstphrs5b3c4"
#   },
#   "_stmt_key": "2_14",
#   "_chunk_num": 2,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [2.15]: During the middle part of his career, Albert Einstein made important contributions to statistical mechanics.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1905"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaknht4tq5r33a5xhjet6bbbohb5kw2onphjlfussjbwqhdg7j4iq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaknht4tq5r33a5xhjet6bbbohb5kw2onphjlfussjbwqhdg7j4iq",
#   "prov:label": "rdf:2_15",
#   "_cell": 88,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibemkquu6h42ev2okoomerxrl75x65vnmbbrpjeb3jbpsqtfl7oa4"
#   },
#   "_stmt_key": "2_15",
#   "_chunk_num": 2,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [2.16]: During the middle part of his career, Albert Einstein made important contributions to quantum theory.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1905"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidtwyzqx3jsijbxwb3bje4ow6g3fazuqpkl2mhtgdfgcnw5k6zlem",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidtwyzqx3jsijbxwb3bje4ow6g3fazuqpkl2mhtgdfgcnw5k6zlem",
#   "prov:label": "rdf:2_16",
#   "_cell": 90,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreianywpnsx2gm3tcdenxjk7bxtgs3yhu2vjqpkndnlh3diuxa3xidi"
#   },
#   "_stmt_key": "2_16",
#   "_chunk_num": 2,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [2.17]: Especially notable during the middle part of his career was Albert Einstein's work on the quantum physics of radiation.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1905"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigyxwat2ydb2efy6gepspsokklbvvbbnpncllx4sd4nrsusygzq6a",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigyxwat2ydb2efy6gepspsokklbvvbbnpncllx4sd4nrsusygzq6a",
#   "prov:label": "rdf:2_17",
#   "_cell": 92,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifduune7mk3ogs23nbleqc2v3imzxaozuld47riubk6ymncf5izla"
#   },
#   "_stmt_key": "2_17",
#   "_chunk_num": 2,
#   "_stmt_idx": 17
# }

# %% [raw]
# # Statement [2.18]: In his work on the quantum physics of radiation, Albert Einstein proposed that light consists of particles.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1905"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicribxqc36w53aimqoe66sdeyo2vg3qi7ikm6adcuegn5rufbvow4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicribxqc36w53aimqoe66sdeyo2vg3qi7ikm6adcuegn5rufbvow4",
#   "prov:label": "rdf:2_18",
#   "_cell": 94,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiduesvrta5wgxiq4z5qvkop6hu2ksa6ruynv243ilplao3npyjclq"
#   },
#   "_stmt_key": "2_18",
#   "_chunk_num": 2,
#   "_stmt_idx": 18
# }

# %% [raw]
# # Statement [2.19]: The particles that Albert Einstein proposed in his work on the quantum physics of radiation are subsequently called photons.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1905"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiazrqknlfhw3lw6okhcp4ctx73yrtde3b33cums75nmfv7lzfwpra",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiazrqknlfhw3lw6okhcp4ctx73yrtde3b33cums75nmfv7lzfwpra",
#   "prov:label": "rdf:2_19",
#   "_cell": 96,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid3xkhmuvukacdr6utkgmbpknl2dja6bmej3rmbqnvsq36ansq2jy"
#   },
#   "_stmt_key": "2_19",
#   "_chunk_num": 2,
#   "_stmt_idx": 19
# }

# %% [raw]
# # Statement [2.20]: With physicist Satyendra Nath Bose, Albert Einstein laid the groundwork for Bose–Einstein statistics.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1905"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihnfukpolvedsmmqfyr4rrwfs6e2t55ueck5xetgk2zlz6gqgij6i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihnfukpolvedsmmqfyr4rrwfs6e2t55ueck5xetgk2zlz6gqgij6i",
#   "prov:label": "rdf:2_20",
#   "_cell": 98,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib43t7rkxwhposvc4a6lum4zdkh2evhwr4ghawgd5j6id2fasw7hm"
#   },
#   "_stmt_key": "2_20",
#   "_chunk_num": 2,
#   "_stmt_idx": 20
# }

# %% [raw]
# # Statement [2.21]: For much of the last phase of his academic life, Albert Einstein worked on two endeavors.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1955"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicg3hjgivqpu3msyqwjygliwwv77pbhnq4tukjtnac35xbrq226lu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicg3hjgivqpu3msyqwjygliwwv77pbhnq4tukjtnac35xbrq226lu",
#   "prov:label": "rdf:2_21",
#   "_cell": 100,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibyo4o4jzass5fzazukivgiajfg63723b7hqzvlt5p6rs7b4wwqge"
#   },
#   "_stmt_key": "2_21",
#   "_chunk_num": 2,
#   "_stmt_idx": 21
# }

# %% [raw]
# # Statement [2.22]: First, Albert Einstein advocated against quantum theory's introduction of fundamental randomness into science's picture of the world.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1955"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihrqwvx72nntudcgacoubwl3maudo3pwdvqs5aemsfabxtx2oep6e",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihrqwvx72nntudcgacoubwl3maudo3pwdvqs5aemsfabxtx2oep6e",
#   "prov:label": "rdf:2_22",
#   "_cell": 102,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihebqayyylkrac37f3caujtkkqbbi6v3pettqjy7iz53trbaxbvce"
#   },
#   "_stmt_key": "2_22",
#   "_chunk_num": 2,
#   "_stmt_idx": 22
# }

# %% [raw]
# # Statement [2.23]: First, Albert Einstein objected that "God does not play dice."
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1955"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreih5mayeq42yez42pfxodqfggigxfdlod53hyedl3muarrjzu7x3iq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreih5mayeq42yez42pfxodqfggigxfdlod53hyedl3muarrjzu7x3iq",
#   "prov:label": "rdf:2_23",
#   "_cell": 104,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreie3ehi446h77t7hiiavziqcqbvdclwqfnw4n5emk6m34fryyjie4y"
#   },
#   "_stmt_key": "2_23",
#   "_chunk_num": 2,
#   "_stmt_idx": 23
# }

# %% [raw]
# # Statement [2.24]: Second, Albert Einstein attempted to devise a unified field theory.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1955"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiczmxel7s4y3shlgwrgw6nb65hklwdyyv5vn66o5agrt4btqtqj64",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiczmxel7s4y3shlgwrgw6nb65hklwdyyv5vn66o5agrt4btqtqj64",
#   "prov:label": "rdf:2_24",
#   "_cell": 106,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia6nwdfgrlmqzoa5clzoqdydifd5b7zuugsqphlwsvvnvdhjc3w24"
#   },
#   "_stmt_key": "2_24",
#   "_chunk_num": 2,
#   "_stmt_idx": 24
# }

# %% [raw]
# # Statement [2.25]: Second, the unified field theory that Albert Einstein attempted to devise generalized his geometric theory of gravitation to include electromagnetism.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1955"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreieopdynmycgckrmjvnrbuexcqty5tekopzaiihw4zyrcojakn5z2q",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreieopdynmycgckrmjvnrbuexcqty5tekopzaiihw4zyrcojakn5z2q",
#   "prov:label": "rdf:2_25",
#   "_cell": 108,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifmxveefu5lkjj66ybljyx3zjscqkut6chrzomfsylonoibbiln2i"
#   },
#   "_stmt_key": "2_25",
#   "_chunk_num": 2,
#   "_stmt_idx": 25
# }

# %% [raw]
# # Statement [2.26]: As a result of his work on the two endeavors, Albert Einstein became increasingly isolated from mainstream modern physics.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:datePublished "1955"^^xsd:date .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie3a43kdrfsc37twb7aitgjh2ejlpubnubbhrwsojque6i3t4jmay",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie3a43kdrfsc37twb7aitgjh2ejlpubnubbhrwsojque6i3t4jmay",
#   "prov:label": "rdf:2_26",
#   "_cell": 110,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifv23diwnfsoszfjnxhrbr7bvtcru3ufqcstb2tnvrbvwyuf6rnuy"
#   },
#   "_stmt_key": "2_26",
#   "_chunk_num": 2,
#   "_stmt_idx": 26
# }

# %% [raw]
# # Statement [3.1]: Albert Einstein was born in Ulm in the Kingdom of Württemberg in the German Empire on 14 March 1879
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Ulm" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Kingdom of Württemberg" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "German Empire" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Ulm" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "Kingdom of Württemberg" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace "German Empire" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidjoyst7lmwwzohvvpngljtd3nx3rziak6l3ritlds6gzy4oklqp4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidjoyst7lmwwzohvvpngljtd3nx3rziak6l3ritlds6gzy4oklqp4",
#   "prov:label": "rdf:3_1",
#   "_cell": 112,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibs3pum4kbuvwqhrmmwmqyhq6c22xennvt5ffjktlffxr4a6puyuq"
#   },
#   "_stmt_key": "3_1",
#   "_chunk_num": 3,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [3.2]: Hermann Einstein was the father of Albert Einstein
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parent "<https://en.wikipedia.org/wiki/Hermann_Einstein>" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidk3dz3gh6yo75qxp6pykcbgrewbva3xcrimfdxqo6dnqp3n7dufu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidk3dz3gh6yo75qxp6pykcbgrewbva3xcrimfdxqo6dnqp3n7dufu",
#   "prov:label": "rdf:3_2",
#   "_cell": 114,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifa3c6xsavj6evqbnbcjmyahmgy23vz3izhuka4hq5lnbmkfoz2ci"
#   },
#   "_stmt_key": "3_2",
#   "_chunk_num": 3,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [3.3]: Pauline Koch was the mother of Albert Einstein
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:parent "<https://en.wikipedia.org/wiki/Pauline_Koch>" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic3rcetytshva7we4xhniuwhr6poh5oo4hcsxpaddznlhgshxhuty",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic3rcetytshva7we4xhniuwhr6poh5oo4hcsxpaddznlhgshxhuty",
#   "prov:label": "rdf:3_3",
#   "_cell": 116,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreig7j7y3ffqlw2xha7put2zuxr46d2t4ird7n4itrdgtwwnzlymmsq"
#   },
#   "_stmt_key": "3_3",
#   "_chunk_num": 3,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [3.4]: Hermann Einstein was a salesman and engineer
# "<https://en.wikipedia.org/wiki/Hermann_Einstein>" schema:hasOccupation "salesman" .
# "<https://en.wikipedia.org/wiki/Hermann_Einstein>" schema:hasOccupation "engineer" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihhoxwhbkhsrnz2azjq42jmhmpvsa5g5q3kjg35kcy724v4uwqvkq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihhoxwhbkhsrnz2azjq42jmhmpvsa5g5q3kjg35kcy724v4uwqvkq",
#   "prov:label": "rdf:3_4",
#   "_cell": 118,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaby6yakxmsfqjrgrokeqzdf3yuvxh4en3ogzrgzy6s6tu75lu4ju"
#   },
#   "_stmt_key": "3_4",
#   "_chunk_num": 3,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [3.5]: Jakob was the uncle of Albert Einstein
# "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" schema:sibling "<https://en.wikipedia.org/wiki/Jakob_Einstein>" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiceb7cmzyzlj52qjnzoooxelh553onwlvpzquywkg4czvypxx54ja",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiceb7cmzyzlj52qjnzoooxelh553onwlvpzquywkg4czvypxx54ja",
#   "prov:label": "rdf:3_5",
#   "_cell": 120,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieo2jfupl56bkrqifqwuzvznjjcidxuzrbc3gdamjfiamls7omktu"
#   },
#   "_stmt_key": "3_5",
#   "_chunk_num": 3,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [3.6]: Elektrotechnische Fabrik J. Einstein & Cie was a company founded by Hermann Einstein and his uncle Jakob
# "<https://en.wikipedia.org/wiki/Elektrotechnische_Fabrik_J._Einstein_%26_Cie>" rdf:type "schema:Corporation" .
# "<https://en.wikipedia.org/wiki/Elektrotechnische_Fabrik_J._Einstein_%26_Cie>" schema:founder "<https://en.wikipedia.org/wiki/Hermann_Einstein>" .
# "<https://en.wikipedia.org/wiki/Elektrotechnische_Fabrik_J._Einstein_%26_Cie>" schema:founder "<https://en.wikipedia.org/wiki/Jakob_Einstein>" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiev2ok5j2ht55hxoivebtfjviygzwgvsbsajkjkdncs3pprpi5mzi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiev2ok5j2ht55hxoivebtfjviygzwgvsbsajkjkdncs3pprpi5mzi",
#   "prov:label": "rdf:3_6",
#   "_cell": 122,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia4xunhvupmn6rjsj424wgknetrxkvszh6geuajoxlg5qek6rb73y"
#   },
#   "_stmt_key": "3_6",
#   "_chunk_num": 3,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [3.7]: Elektrotechnische Fabrik J. Einstein & Cie manufactured electrical equipment based on direct current
# "<https://en.wikipedia.org/wiki/Elektrotechnische_Fabrik_J._Einstein_%26_Cie>" schema:manufacturer "electrical equipment based on direct current" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicgngduomhd7cemdung2d32xw44p3lmf4uc5nz2qoo6v623crh7ci",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicgngduomhd7cemdung2d32xw44p3lmf4uc5nz2qoo6v623crh7ci",
#   "prov:label": "rdf:3_7",
#   "_cell": 124,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreic6zlnqeow5xg6ozkp77mwubbah3fq4gvmgxt74lfeimywdr22bee"
#   },
#   "_stmt_key": "3_7",
#   "_chunk_num": 3,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [3.8]: Albert Einstein was a secular Ashkenazi Jew
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "Jew" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiemzjfkk6s5qknd4duub45la7z73akfqpnz55wwdjjuwudvlnsmxe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiemzjfkk6s5qknd4duub45la7z73akfqpnz55wwdjjuwudvlnsmxe",
#   "prov:label": "rdf:3_8",
#   "_cell": 126,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreif5md65f7ssyfttdyof7qi3qwaotqjmgeinrdqx4sekpft2yjahfm"
#   },
#   "_stmt_key": "3_8",
#   "_chunk_num": 3,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [3.9]: When Albert Einstein was very young, his parents worried that he had a learning disability
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:relatedTo "learning disability" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibnaqhq7xtb3hd7avbgh2g4nexl7a2rht3esua4dtimmrdypbodzq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibnaqhq7xtb3hd7avbgh2g4nexl7a2rht3esua4dtimmrdypbodzq",
#   "prov:label": "rdf:3_9",
#   "_cell": 128,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiaaolqii2xx5s3txuoeqyaznbsgv24j4gwsqzjioeezqh4mxr3tqy"
#   },
#   "_stmt_key": "3_9",
#   "_chunk_num": 3,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [3.10]: Albert Einstein was slow to learn to talk when he was very young
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:relatedTo "slow to learn to talk" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie6lazujszzaigwcu75xbyo3xp672natm2ltll5bz3fdauclgdrfq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie6lazujszzaigwcu75xbyo3xp672natm2ltll5bz3fdauclgdrfq",
#   "prov:label": "rdf:3_10",
#   "_cell": 130,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihyid2yjeyuzo4z7ai4ah5syy6s75f27jbtpkgv2jcjk5zfi4d4mq"
#   },
#   "_stmt_key": "3_10",
#   "_chunk_num": 3,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [3.11]: When Albert Einstein was five and sick in bed, his father brought him a compass
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:relatedTo "compass" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifd4atcsovzjbqlwthmt7g7futqiomuuzd6m67y7roxiuvzgar33e",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifd4atcsovzjbqlwthmt7g7futqiomuuzd6m67y7roxiuvzgar33e",
#   "prov:label": "rdf:3_11",
#   "_cell": 132,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifbsr3w3mpwtsm5qr5l2wn4ci4aprj4kiocbcqnmsuqr7xd2fybwy"
#   },
#   "_stmt_key": "3_11",
#   "_chunk_num": 3,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [3.12]: The compass sparked Albert Einstein's lifelong fascination with electromagnetism
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:relatedTo "electromagnetism" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic7xsoisvoybzx5w7k4izr3lmxixdryhhyi74gp3xny5u74mnizuq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic7xsoisvoybzx5w7k4izr3lmxixdryhhyi74gp3xny5u74mnizuq",
#   "prov:label": "rdf:3_12",
#   "_cell": 134,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifdrmli6aunuqmkz27adofter755ov5ubscob3fedp3yuejor76nu"
#   },
#   "_stmt_key": "3_12",
#   "_chunk_num": 3,
#   "_stmt_idx": 12
# }

# %% [raw]
# # Statement [3.13]: Albert Einstein realized that something deeply hidden had to be behind things
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:relatedTo "something deeply hidden" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifuu2hklxl6erladqgk57442erwo3spelwg5vozg347xdxf3dmir4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifuu2hklxl6erladqgk57442erwo3spelwg5vozg347xdxf3dmir4",
#   "prov:label": "rdf:3_13",
#   "_cell": 136,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigiwpgwmvatjbhujqdowq6g5q54nz7jhy2crow5b7ovm52zitu67q"
#   },
#   "_stmt_key": "3_13",
#   "_chunk_num": 3,
#   "_stmt_idx": 13
# }

# %% [raw]
# # Statement [3.14]: Albert Einstein attended St. Peter's Catholic elementary school in Munich from the age of five
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:attendee "<https://en.wikipedia.org/wiki/St._Peter's_Catholic_elementary_school>" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigt2334rjkeqovnr5ah3w23z3bo22iioynqwa6av2f7zfdgfesafq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigt2334rjkeqovnr5ah3w23z3bo22iioynqwa6av2f7zfdgfesafq",
#   "prov:label": "rdf:3_14",
#   "_cell": 138,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiblrnrkvkeefrdcnb3c2g4jzlnrejk5jhra322fdyhsk2yn7nm7wy"
#   },
#   "_stmt_key": "3_14",
#   "_chunk_num": 3,
#   "_stmt_idx": 14
# }

# %% [raw]
# # Statement [3.15]: When Albert Einstein was eight, he was transferred to the Luitpold Gymnasium
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:attendee "<https://en.wikipedia.org/wiki/Luitpold_Gymnasium>" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibkq3ql4oh5ycujyvvfwklccgqtssvxnf3yejaflgzhjw4ggdg2gq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibkq3ql4oh5ycujyvvfwklccgqtssvxnf3yejaflgzhjw4ggdg2gq",
#   "prov:label": "rdf:3_15",
#   "_cell": 140,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiby2nxo7hu5hyopwgdapp7rfrgjeip3aevxjp6ddrcrl6sfzsv3ym"
#   },
#   "_stmt_key": "3_15",
#   "_chunk_num": 3,
#   "_stmt_idx": 15
# }

# %% [raw]
# # Statement [3.16]: The Luitpold Gymnasium provided Albert Einstein with advanced primary and then secondary school education
# <https://en.wikipedia.org/wiki/Luitpold_Gymnasium> schema:attendee "<https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein>" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidgdaptza26wx7dcdgduirjg4n7lo6tvf5w6dxrjhz36km5soypiy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidgdaptza26wx7dcdgduirjg4n7lo6tvf5w6dxrjhz36km5soypiy",
#   "prov:label": "rdf:3_16",
#   "_cell": 142,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieuc6z5nuhmiarxgxp7m7lpvo5va3pnaugu4kv2e7ohj4e5t4chpm"
#   },
#   "_stmt_key": "3_16",
#   "_chunk_num": 3,
#   "_stmt_idx": 16
# }

# %% [raw]
# # Statement [4.1]: In 1894, Hermann and Jakob's company tendered for a contract to install electric lighting in Munich.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace <https://www.wikidata.org/wiki/Q183> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:name "Albert Einstein" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthPlace <https://www.wikidata.org/wiki/Q183> .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathPlace <https://www.wikidata.org/wiki/Q183> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiaylvcmkv5jig7wh5js77e7lhfr6dfjat5d4lteplmgwrptnt4kjm",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiaylvcmkv5jig7wh5js77e7lhfr6dfjat5d4lteplmgwrptnt4kjm",
#   "prov:label": "rdf:4_1",
#   "_cell": 144,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreia2xgahgiatytktjg7wulzkzkmtc7kf6jtzzrkb3zsfcwg2e7vrym"
#   },
#   "_stmt_key": "4_1",
#   "_chunk_num": 4,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [4.2]: The company without success lacked the capital required to update their technology from direct current to alternating current.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation <https://www.wikidata.org/wiki/Q183> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreig66lbu2oqljkoq5geurnmokmjrtkehtmyxilh4xehtiffdybpl2i",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreig66lbu2oqljkoq5geurnmokmjrtkehtmyxilh4xehtiffdybpl2i",
#   "prov:label": "rdf:4_2",
#   "_cell": 146,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreige4maaohj3xc52a4sy2cqmdjicauncpm7bdt2inywrv3fg3fb3ya"
#   },
#   "_stmt_key": "4_2",
#   "_chunk_num": 4,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [4.3]: The failure of their bid forced Hermann and Jakob's company to sell their Munich factory.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation <https://www.wikidata.org/wiki/Q183> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiby5xjd6aujjhwlfndl2tl7fnlgpjzpvnonmdyo6tnls4o5knoqxu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiby5xjd6aujjhwlfndl2tl7fnlgpjzpvnonmdyo6tnls4o5knoqxu",
#   "prov:label": "rdf:4_3",
#   "_cell": 148,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreighkuxzo4lzi7m5su4gvqclv4juduu5wyjfqezq3mdv65ufrhlczy"
#   },
#   "_stmt_key": "4_3",
#   "_chunk_num": 4,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [4.4]: The Einstein family moved to Italy, first to Milan and then to Pavia.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation <https://www.wikidata.org/wiki/Q183> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreicjlluc4itp5zja6imv6w2tsxkreqbyljwd656qibjfyhkmzoopj4",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreicjlluc4itp5zja6imv6w2tsxkreqbyljwd656qibjfyhkmzoopj4",
#   "prov:label": "rdf:4_4",
#   "_cell": 150,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibpzp7wbcqziuajm5lo3hagfcpo6tetxxen645tk7nimtq4lgrize"
#   },
#   "_stmt_key": "4_4",
#   "_chunk_num": 4,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [4.5]: Einstein stayed behind in Munich at age fifteen to finish his schooling.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation <https://www.wikidata.org/wiki/Q183> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifqbru74wpv6bzmilpnher3spwdu3gfp3s53eg5vr6lopakv6x7em",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifqbru74wpv6bzmilpnher3spwdu3gfp3s53eg5vr6lopakv6x7em",
#   "prov:label": "rdf:4_5",
#   "_cell": 152,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreie5fd6dgxcarjese2one2zts7lccxif33ugy4yuqrse7rv56xcfz4"
#   },
#   "_stmt_key": "4_5",
#   "_chunk_num": 4,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [4.6]: Einstein's father wanted him to study electrical engineering.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation <https://www.wikidata.org/wiki/Q183> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihrizcmt7ycdbf25ay5czfeyfhhjozwycxpbxqoprnhfskcxuymda",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihrizcmt7ycdbf25ay5czfeyfhhjozwycxpbxqoprnhfskcxuymda",
#   "prov:label": "rdf:4_6",
#   "_cell": 154,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiag5olkhflsn3ejvmkxhj33x77r3pepjcdtwyir4522hnkpoehk54"
#   },
#   "_stmt_key": "4_6",
#   "_chunk_num": 4,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [4.7]: Einstein was a fractious pupil who found the Gymnasium's regimen and teaching methods far from congenial.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation <https://www.wikidata.org/wiki/Q183> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreigya2amgbwimgilyfns3hoilky44sm36vesni2qbjatppumwf7hhi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreigya2amgbwimgilyfns3hoilky44sm36vesni2qbjatppumwf7hhi",
#   "prov:label": "rdf:4_7",
#   "_cell": 156,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidsmddmh3tnmg6sf2pyv5knwmieuvcwm76en7mubyujcafqqf4x6m"
#   },
#   "_stmt_key": "4_7",
#   "_chunk_num": 4,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [4.8]: Einstein later wrote that the school's policy of strict rote learning was harmful to creativity.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation <https://www.wikidata.org/wiki/Q183> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie2qqqv2fu4h4y23pk7guh2uxtwomatz2uuluc4agpw4tnixc36uy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie2qqqv2fu4h4y23pk7guh2uxtwomatz2uuluc4agpw4tnixc36uy",
#   "prov:label": "rdf:4_8",
#   "_cell": 158,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreig7geefsvredzr7odcrx7jigjg55x6mnda3yzg6ccc5telp7cqiu4"
#   },
#   "_stmt_key": "4_8",
#   "_chunk_num": 4,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [4.9]: At the end of December 1894, a letter from a doctor persuaded the Luitpold's authorities to release Einstein from its care.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation <https://www.wikidata.org/wiki/Q183> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreiean32wncnv3v7xgelaiq7j2kbtwwffbwxbhc4ewjh23pvgovg4se",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreiean32wncnv3v7xgelaiq7j2kbtwwffbwxbhc4ewjh23pvgovg4se",
#   "prov:label": "rdf:4_9",
#   "_cell": 160,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreib7fq7rhtbtkaftzyxhjnlz6zpwn5pqy5groz7ouz3u77iyry2fkm"
#   },
#   "_stmt_key": "4_9",
#   "_chunk_num": 4,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [4.10]: Einstein joined his family in Pavia.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation <https://www.wikidata.org/wiki/Q183> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihoij5fym4pttcfwifjtgeve2w7mulr2rm5252k4antyz46jaacqa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihoij5fym4pttcfwifjtgeve2w7mulr2rm5252k4antyz46jaacqa",
#   "prov:label": "rdf:4_10",
#   "_cell": 162,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreidujz66v2lvtk43qyckqa42ptnhqqkkdsilszyeaooaqwjv7kflxq"
#   },
#   "_stmt_key": "4_10",
#   "_chunk_num": 4,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [4.11]: While in Italy as a teenager, Einstein wrote an essay entitled "On the Investigation of the State of the Ether in a Magnetic Field".
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:homeLocation <https://www.wikidata.org/wiki/Q183> .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibv7wnswfc2c5i5ujca4opch2sknovo6nfzkafwtchdaveilkylke",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibv7wnswfc2c5i5ujca4opch2sknovo6nfzkafwtchdaveilkylke",
#   "prov:label": "rdf:4_11",
#   "_cell": 164,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreiavtdtzx264refmhox7pggfh35amod7rxlxy6e4zrmcn73ay6dbda"
#   },
#   "_stmt_key": "4_11",
#   "_chunk_num": 4,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [5.1]: Albert Einstein excelled at physics and mathematics from an early age
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knownFor "physics and mathematics" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreie2xsetk4s6tvzf5fssnfwrtm5ciivvcptvlvmllvfpzktotozpjq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreie2xsetk4s6tvzf5fssnfwrtm5ciivvcptvlvmllvfpzktotozpjq",
#   "prov:label": "rdf:5_1",
#   "_cell": 166,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigsxhw64vufqkra5j4sfddt7zx2cvntkewmvlmtscxrovwpklr67m"
#   },
#   "_stmt_key": "5_1",
#   "_chunk_num": 5,
#   "_stmt_idx": 1
# }

# %% [raw]
# # Statement [5.2]: Albert Einstein acquired the mathematical expertise normally only found in a child several years his senior
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:knownFor "mathematical expertise" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic53ahdadnl77tlndkun2cygwaoeqqmj6e33ovc7p734sheuqq7gi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic53ahdadnl77tlndkun2cygwaoeqqmj6e33ovc7p734sheuqq7gi",
#   "prov:label": "rdf:5_2",
#   "_cell": 168,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreigpye4x2guxmwn3xdzvxqmktfs46gcuaa3ao6i2ky2ighjb7mthoy"
#   },
#   "_stmt_key": "5_2",
#   "_chunk_num": 5,
#   "_stmt_idx": 2
# }

# %% [raw]
# # Statement [5.3]: Albert Einstein began teaching himself algebra when he was twelve years old
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:study "algebra" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:ageWhenStartedStudy "12 years old" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreibmvpkoqreorkyeai3te66brz4ohrcgbp3p5x2e62g63tsdlfmqqe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreibmvpkoqreorkyeai3te66brz4ohrcgbp3p5x2e62g63tsdlfmqqe",
#   "prov:label": "rdf:5_3",
#   "_cell": 170,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreic2j5fpjry5x2on4faacmax4nkamfaix6qobzpsisvrb6sqrysg6q"
#   },
#   "_stmt_key": "5_3",
#   "_chunk_num": 5,
#   "_stmt_idx": 3
# }

# %% [raw]
# # Statement [5.4]: Albert Einstein began teaching himself calculus when he was twelve years old
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:study "calculus" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:ageWhenStartedStudy "12 years old" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidqo4bo7sccrcqchp3lju7sbymease7cm6jbgu3s7gsjkxnymipxy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidqo4bo7sccrcqchp3lju7sbymease7cm6jbgu3s7gsjkxnymipxy",
#   "prov:label": "rdf:5_4",
#   "_cell": 172,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreieyt3slbfcbvtkr3rffifseumt3mcdnt263ohb54xzo7k5row2ikm"
#   },
#   "_stmt_key": "5_4",
#   "_chunk_num": 5,
#   "_stmt_idx": 4
# }

# %% [raw]
# # Statement [5.5]: Albert Einstein began teaching himself Euclidean geometry when he was twelve years old
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:study "Euclidean geometry" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:ageWhenStartedStudy "12 years old" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreih4p5q56o33hinwwirqmspijhzdocsnmlztnbhuy5ve5l467cg7oa",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreih4p5q56o33hinwwirqmspijhzdocsnmlztnbhuy5ve5l467cg7oa",
#   "prov:label": "rdf:5_5",
#   "_cell": 174,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreihy5c6xnpfuptsfuld5kwqden5zh2jf7k675hyk4hn6ctmmggyzny"
#   },
#   "_stmt_key": "5_5",
#   "_chunk_num": 5,
#   "_stmt_idx": 5
# }

# %% [raw]
# # Statement [5.6]: Albert Einstein discovered an original proof of the Pythagorean theorem before his thirteenth birthday
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:discovery "original proof of the Pythagorean theorem" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:ageWhenDiscovered "12 years old" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreih53otm6tihprx5zncumhshkhewanqgdyibgkxkrxyqusvebfswlq",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreih53otm6tihprx5zncumhshkhewanqgdyibgkxkrxyqusvebfswlq",
#   "prov:label": "rdf:5_6",
#   "_cell": 176,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreid333l5bj7ucatxu5llljerhwn3l263ukslgj2zveozgg6r7fozii"
#   },
#   "_stmt_key": "5_6",
#   "_chunk_num": 5,
#   "_stmt_idx": 6
# }

# %% [raw]
# # Statement [5.7]: Max Talmud was a family tutor of Albert Einstein
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:tutor "Max Talmud" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreige4zaqq5z7uwfa5kzrtkgxe4xy4dmt5vdtfkok34lcvbyn53lphe",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreige4zaqq5z7uwfa5kzrtkgxe4xy4dmt5vdtfkok34lcvbyn53lphe",
#   "prov:label": "rdf:5_7",
#   "_cell": 178,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreih54ixpvloqd5rctsu3uz4ewtpqlme6tcgid42t3vywp3a6rgkrqq"
#   },
#   "_stmt_key": "5_7",
#   "_chunk_num": 5,
#   "_stmt_idx": 7
# }

# %% [raw]
# # Statement [5.8]: Max Talmud said that only a short time after he had given the twelve year old Albert Einstein a geometry textbook, the boy had worked through the whole book
# "Max Talmud" schema:statement "only a short time after he had given the twelve year old Albert Einstein a geometry textbook, the boy had worked through the whole book" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreic5prcnxchbrqjuhukr3tcr5yfet47ilwjb24coyzyreswr6xjhey",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreic5prcnxchbrqjuhukr3tcr5yfet47ilwjb24coyzyreswr6xjhey",
#   "prov:label": "rdf:5_8",
#   "_cell": 180,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibsupaz7lalqzsbptsu6eoc6xhbpqvb52s22idplre2tzhblnpntq"
#   },
#   "_stmt_key": "5_8",
#   "_chunk_num": 5,
#   "_stmt_idx": 8
# }

# %% [raw]
# # Statement [5.9]: Max Talmud said that Albert Einstein devoted himself to higher mathematics after working through the geometry textbook
# "Max Talmud" schema:statement "Albert Einstein devoted himself to higher mathematics after working through the geometry textbook" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreifk3cwrxfzojcwryyc7f2zu5g7lyjterqaj4ptyljt4wox4fq7k5a",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreifk3cwrxfzojcwryyc7f2zu5g7lyjterqaj4ptyljt4wox4fq7k5a",
#   "prov:label": "rdf:5_9",
#   "_cell": 182,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreianiodyfcc3pkmsrws7g3tfusm3s352tm4qv3yxowowkoch4wogfa"
#   },
#   "_stmt_key": "5_9",
#   "_chunk_num": 5,
#   "_stmt_idx": 9
# }

# %% [raw]
# # Statement [5.10]: Max Talmud said that the flight of Albert Einstein's mathematical genius was so high that Max Talmud could not follow
# "Max Talmud" schema:statement "the flight of Albert Einstein's mathematical genius was so high that Max Talmud could not follow" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreihmkm4xeez7k6jxzzxyvnu3ez4tmffpxqgfd2z3hhsridwsquzadi",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreihmkm4xeez7k6jxzzxyvnu3ez4tmffpxqgfd2z3hhsridwsquzadi",
#   "prov:label": "rdf:5_10",
#   "_cell": 184,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreibm5kaj6h4nozdzx3vz3ursijjwxqlu2q4xl6lfpxsr5u5dluxlwa"
#   },
#   "_stmt_key": "5_10",
#   "_chunk_num": 5,
#   "_stmt_idx": 10
# }

# %% [raw]
# # Statement [5.11]: Albert Einstein recorded that he had mastered integral and differential calculus while he was fourteen years old
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:mastered "integral and differential calculus" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:ageWhenMastered "14 years old" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreidyoz5n4kd2tquiufhcr5roj6f67lot6tzgisz2atdknvkdac2zfu",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreidyoz5n4kd2tquiufhcr5roj6f67lot6tzgisz2atdknvkdac2zfu",
#   "prov:label": "rdf:5_11",
#   "_cell": 186,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreicybrz6j5j3u4r5fwx5e3pzac24kpwfrwibwjggv4udfpytxhisby"
#   },
#   "_stmt_key": "5_11",
#   "_chunk_num": 5,
#   "_stmt_idx": 11
# }

# %% [raw]
# # Statement [5.12]: Albert Einstein was confident that nature could be understood as a mathematical structure when he was twelve years old
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:believed "nature could be understood as a mathematical structure" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:ageWhenBelieved "12 years old" .

# %% [raw]
# {
#   "@context": {
#     "prov": "http://www.w3.org/ns/prov#",
#     "repro": "https://w3id.org/reproduceme#",
#     "dcterms": "http://purl.org/dc/terms/",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "prov:wasDerivedFrom": {
#       "@type": "@id"
#     },
#     "prov:wasGeneratedBy": {
#       "@type": "@id"
#     }
#   },
#   "@id": "ipfs://bafkreianxb5nda3gj53jrpguz4ndopisftpxqfrrgfhwz2rtwmkbgyzkiy",
#   "@type": [
#     "prov:Entity",
#     "repro:OutputData"
#   ],
#   "dcterms:identifier": "bafkreianxb5nda3gj53jrpguz4ndopisftpxqfrrgfhwz2rtwmkbgyzkiy",
#   "prov:label": "rdf:5_12",
#   "_cell": 188,
#   "_type": "rdf",
#   "prov:wasDerivedFrom": {
#     "@id": "ipfs://bafkreifkdbjydtvgpowcaxxovxketc6hhp3antwabmymemualijomnmu2m"
#   },
#   "_stmt_key": "5_12",
#   "_chunk_num": 5,
#   "_stmt_idx": 12
# }
