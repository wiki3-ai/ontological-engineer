# %% [markdown]
# # RDF Triples: Albert Einstein
#
# ## Provenance
#
# ```yaml
# source_url: https://en.wikipedia.org/wiki/Albert_Einstein
# article_title: Albert Einstein
# license: CC BY-SA 4.0
# license_url: https://creativecommons.org/licenses/by-sa/4.0/
# source_notebook: facts.ipynb
# generated_by: wiki_to_kg_pipeline.ipynb
# generated_at: 2025-12-19T04:54:01.630598
# llm_provider: lm_studio
# llm_model: qwen/qwen3-coder-30b
# llm_temperature: 1
# rdf_format: Turtle
# ```
#
# ## RDF Prefixes
#
# ```turtle
# @prefix schema: <https://schema.org/> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix wiki3: <https://wiki3.ai/vocab/> .
# @base <https://en.wikipedia.org/wiki/Albert_Einstein> .
#
# ```
#
# ## Processing Instructions
#
# This notebook contains RDF triples in Turtle format, one cell per source statement.
# Each content cell is followed by a signature cell with CID provenance.
#
# To regenerate a specific cell: delete both the content cell and its signature, then re-run the pipeline.
#
# ## Prompt Template
#
# ```
# You are an expert at converting factual statements to RDF triples in Turtle format.
#
# Convert the following factual statements to RDF using schema.org vocabulary where possible.
#
# Source: {source_url}
# Section: {breadcrumb}
#
# Use these prefixes:
# {prefixes}
#
# Entity registry (use these URIs):
# {entity_registry}
#
# Guidelines:
# - Use schema.org properties (schema:birthDate, schema:birthPlace, schema:worksFor, etc.)
# - For relationships not in schema.org, use wiki3: prefix
# - Include rdfs:label for entities
# - Use xsd datatypes for dates and numbers
# - Entity URIs should use the source URL as base with fragment identifiers
#
# ---
# {facts}
# ---
#
# Generate Turtle RDF:
#
# ```

# %% [raw]
# {
#   "source_url": "https://en.wikipedia.org/wiki/Albert_Einstein",
#   "entities": {
#     "albert_einstein": {
#       "id": "person_albert_einstein",
#       "uri": "https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein",
#       "label": "Albert Einstein",
#       "type": "Person",
#       "descriptions": [
#         "Subject of Wikipedia article: Albert Einstein"
#       ],
#       "source_chunks": [],
#       "aliases": [
#         "Einstein"
#       ]
#     }
#   },
#   "aliases": {
#     "einstein": "albert_einstein"
#   }
# }

# %% [raw]
# # Chunk 1 Error: ValidationError: 1 validation error for emit_triple
# statement_id
#   Input should be a valid string

# %% [raw]
# # Chunk 2 Error: ValidationError: 1 validation error for emit_triple
# statement_id
#   Input should be a valid string

# %% [raw]
# # Statement [1.1]: Albert Einstein was a German-born theoretical physicist.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> rdf:type schema:Person .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation schema:Researcher .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:givenName "Albert" .
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:familyName "Einstein" .

# %% [raw]
# {"cell": 4, "stmt_key": "1_1", "chunk_num": 1, "stmt_idx": 1, "type": "rdf", "cid": "24225bc9fe38a93ae47e704e23db2c6abd98ffd4b26521cd7affb7ac8a50a159", "from_cid": "79ba89701100776971220da0a401e76270f4532db3b9deab8c0e88a0437b851d"}

# %% [raw]
# # Statement [1.2]: Albert Einstein developed the theory of relativity.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:work "Theory of relativity" .

# %% [raw]
# {"cell": 6, "stmt_key": "1_2", "chunk_num": 1, "stmt_idx": 2, "type": "rdf", "cid": "9c5c3932ea3c691d99a0a7d732590e5b9ead25413d6a84b1e97a6e2979e3e581", "from_cid": "5a542422fdf3bf263b00a36289863a73f58394c193434857daa58f74eb30dd44"}

# %% [raw]
# # Statement [1.3]: Albert Einstein made important contributions to quantum theory.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:work "Contributions to quantum theory" .

# %% [raw]
# {"cell": 8, "stmt_key": "1_3", "chunk_num": 1, "stmt_idx": 3, "type": "rdf", "cid": "c8e04f20e738ca4be8d46605eea9793209ea93d07215a32ab6d0129dcdf306c1", "from_cid": "a7df5ee100428ecc2acdd4a608f0e0584ccab7ea59105f16a0789e1f3896bd84"}

# %% [raw]
# # Statement [1.4]: Albert Einstein's mass–energy equivalence formula E = mc2 arises from special relativity.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:work "Mass-energy equivalence formula E = mc2" .

# %% [raw]
# {"cell": 10, "stmt_key": "1_4", "chunk_num": 1, "stmt_idx": 4, "type": "rdf", "cid": "60010c3c1dd48a9cc39a1ec892eb759bd46910085738e671c019f9b306b19c3f", "from_cid": "2b43ae873d4591a9b62c93928968870e4cb97819df5ec51fda774d549577ab95"}

# %% [raw]
# # Statement [1.5]: Albert Einstein received the 1921 Nobel Prize in Physics.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:award "Nobel Prize in Physics" .

# %% [raw]
# {"cell": 12, "stmt_key": "1_5", "chunk_num": 1, "stmt_idx": 5, "type": "rdf", "cid": "68a8c620ef56718ba13f08c0aa35f798252a7de7e0f904b422f922440d72ed9b", "from_cid": "ba22410f26b37c84173b8dae0e295dfe3b7cd6a033f147acaaf0b8b8cf904984"}

# %% [raw]
# # Statement [1.6]: Albert Einstein was born on 14 March 1879.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:birthDate "1879-03-14"^^xsd:date .

# %% [raw]
# {"cell": 14, "stmt_key": "1_6", "chunk_num": 1, "stmt_idx": 6, "type": "rdf", "cid": "17efd930824fefffd68fe09b73e08df7d00f5ca5292d0dbb7a4447ed0f7176fc", "from_cid": "cbabea9601d0b563c2b511c733d1ebc9339a9346cf2e62049c93fbebafe949e6"}

# %% [raw]
# # Statement [1.7]: Albert Einstein died on 18 April 1955.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:deathDate "1955-04-18"^^xsd:date .

# %% [raw]
# {"cell": 16, "stmt_key": "1_7", "chunk_num": 1, "stmt_idx": 7, "type": "rdf", "cid": "f2dc96f616747a9ab5885a91fbe5aa7f6feb115aa7f44de37c663c8bec825165", "from_cid": "b0e67f805f2eff1d2efaec2c0d0484e2afa7c3b1f224f3fb1993127adcaaf4ac"}

# %% [raw]
# # Statement [1.8]: Albert Einstein was a subject of the Kingdom of Württemberg.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality schema:Country .

# %% [raw]
# {"cell": 18, "stmt_key": "1_8", "chunk_num": 1, "stmt_idx": 8, "type": "rdf", "cid": "29c4ed8b96397281b14d8507dfdeef7ef0a897a417a9c0719d77650db735be98", "from_cid": "2854db29b44aa8c2fad35bb9ced1c0b374d60663ed2073d862f38c7efac779a4"}

# %% [raw]
# # Statement [1.9]: Albert Einstein moved to Switzerland in 1895.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:residence "Switzerland" .

# %% [raw]
# {"cell": 20, "stmt_key": "1_9", "chunk_num": 1, "stmt_idx": 9, "type": "rdf", "cid": "88c5104f699f5190fd4ecf83baf7d5d4c02ef456962ab3fc7dbcdc7ea77d895d", "from_cid": "e6dd13f285db88000a302238e410c5798980ef6f28365ef24e50ea61c422cc1f"}

# %% [raw]
# # Statement [1.10]: Albert Einstein forsake his German citizenship in 1896.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema: citizenship "German" .

# %% [raw]
# {"cell": 22, "stmt_key": "1_10", "chunk_num": 1, "stmt_idx": 10, "type": "rdf", "cid": "8af22b5e8929044dba55bbef4bf2d54a1c0739b8e1b659754811795d8ddbcba9", "from_cid": "40152d387ad1eae8b528599d12e84b81868984e9aa931350719019d44c61a76b"}

# %% [raw]
# # Statement [1.11]: Albert Einstein enrolled in the mathematics and physics teaching diploma program at the Swiss federal polytechnic school in Zurich in 1897.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Swiss federal polytechnic school in Zurich" .

# %% [raw]
# {"cell": 24, "stmt_key": "1_11", "chunk_num": 1, "stmt_idx": 11, "type": "rdf", "cid": "6d5481a0551af9df158bfb8dcf710864c0582f1166852d4c73aa94f959ceec50", "from_cid": "0409c73184920d8f1832598b79d2f1cc46bfbbe88c48a726c62f69220a2d56d3"}

# %% [raw]
# # Statement [1.12]: Albert Einstein graduated from the Swiss federal polytechnic school in Zurich in 1900.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:alumniOf "Swiss federal polytechnic school in Zurich" .

# %% [raw]
# {"cell": 26, "stmt_key": "1_12", "chunk_num": 1, "stmt_idx": 12, "type": "rdf", "cid": "4739f596242a550756fffb0268e445273d0a591e28f07faf3c55ccafb8cd9103", "from_cid": "962dafb0bb954624e68d5421a3aea727531eb4da7fff1721b26bd8f0c0aef630"}

# %% [raw]
# # Statement [1.13]: Albert Einstein acquired Swiss citizenship in 1898.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema: citizenship "Swiss" .

# %% [raw]
# {"cell": 28, "stmt_key": "1_13", "chunk_num": 1, "stmt_idx": 13, "type": "rdf", "cid": "ca870298be43454d463e279788edda0a06568776fd68c2fc9bc223ab326f9936", "from_cid": "2d75bc8815c7dd177225c0c99e5fd073f8b583b60aaabec2f3af1aeebd4411bd"}

# %% [raw]
# # Statement [1.14]: Albert Einstein worked at the Swiss Patent Office in Bern.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:employee "Swiss Patent Office" .

# %% [raw]
# {"cell": 30, "stmt_key": "1_14", "chunk_num": 1, "stmt_idx": 14, "type": "rdf", "cid": "48ffdffd870f7bf7ca1a0b9d0f2f02bf6deac5624e86521f07d682356227ee0f", "from_cid": "1d1882ee24a5bfe147e8a6bad797b17541a7c15cd584ab6ec7197205800fce98"}

# %% [raw]
# # Statement [1.15]: Albert Einstein submitted a successful PhD dissertation to the University of Zurich in 1905.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:hasOccupation "PhD" .

# %% [raw]
# {"cell": 32, "stmt_key": "1_15", "chunk_num": 1, "stmt_idx": 15, "type": "rdf", "cid": "910be1cc293dcd4dfffe468fb9ac525b645d3138ed224bbe1205369779b754e6", "from_cid": "c95389c3206d9b257889549163faf02ad23086a96bd892ba35fc63501b3911de"}

# %% [raw]
# # Statement [1.16]: Albert Einstein moved to Berlin in 1914.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:residence "Berlin" .

# %% [raw]
# {"cell": 34, "stmt_key": "1_16", "chunk_num": 1, "stmt_idx": 16, "type": "rdf", "cid": "fd620679f329f7b8004cdf4100225301f3a9a1acd87f6cd45d326b6ed4cb3ca4", "from_cid": "39ddc4b533bcfd8dc14dfe0df9f40a1381b5c6ad91e603c8880243f5d2d73635"}

# %% [raw]
# # Statement [1.17]: Albert Einstein joined the Prussian Academy of Sciences in 1914.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation "Prussian Academy of Sciences" .

# %% [raw]
# {"cell": 36, "stmt_key": "1_17", "chunk_num": 1, "stmt_idx": 17, "type": "rdf", "cid": "6361ebc60b360e197cf53276dd4dc2a3f8ac12e285034a2c13e09c5e3b596324", "from_cid": "31c9dd638470030ee5635805c7a4b847204a3e5cf363f35271450d02e74e7bbe"}

# %% [raw]
# # Statement [1.18]: Albert Einstein joined the Humboldt University of Berlin in 1914.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation "Humboldt University of Berlin" .

# %% [raw]
# {"cell": 38, "stmt_key": "1_18", "chunk_num": 1, "stmt_idx": 18, "type": "rdf", "cid": "3ce0d99f15948ceacfb0dace5abdecefd0387a6d5a8241d4781e5d09be7ebb96", "from_cid": "c0e2e677cd5d9ba6476f2d60315dcc6a9e444a766d6024ae17f8aa0d9a07cd47"}

# %% [raw]
# # Statement [1.19]: Albert Einstein became director of the Kaiser Wilhelm Institute for Physics in 1917.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:affiliation "Kaiser Wilhelm Institute for Physics" .

# %% [raw]
# {"cell": 40, "stmt_key": "1_19", "chunk_num": 1, "stmt_idx": 19, "type": "rdf", "cid": "44196a8925de8b6d161d96da20b15a2e68cf9a43624f76db90eef57a4396d785", "from_cid": "b3797409272e0dc442a144b19eebee58b44806c1ba907f727b66340ee081a8f7"}

# %% [raw]
# # Statement [1.20]: Albert Einstein became a subject of the Kingdom of Prussia in 1914.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:nationality "Prussia" .

# %% [raw]
# {"cell": 42, "stmt_key": "1_20", "chunk_num": 1, "stmt_idx": 20, "type": "rdf", "cid": "d9758418a80008b00c921d3fdd284a177031379c054d54f5680d8bd9a01d642a", "from_cid": "7a072cc16d27bf569714f137738b887f05c5324c95fd645b8210c40f64c4c8e3"}

# %% [raw]
# # Statement [1.21]: Adolf Hitler came to power in Germany in 1933.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:work "Adolf Hitler came to power in Germany" .

# %% [raw]
# {"cell": 44, "stmt_key": "1_21", "chunk_num": 1, "stmt_idx": 21, "type": "rdf", "cid": "1da863c30d290d86409c9456a3a605720564c2c07d6239c7a3a5340a6925dc92", "from_cid": "327c9e3d0fe188f5459b89ed3a262698267c91f99cf9e20d7450a112820badaf"}

# %% [raw]
# # Statement [1.22]: Albert Einstein was visiting the United States in 1933.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:residence "United States" .

# %% [raw]
# {"cell": 46, "stmt_key": "1_22", "chunk_num": 1, "stmt_idx": 22, "type": "rdf", "cid": "fbae7df0ae91e1ba8c170bcb8daea04d39ea09a3813745de78eca1eef25db540", "from_cid": "975a7140245ff451fb59c5a1ba8760915d48880d9451ec81f3b58765dd813d25"}

# %% [raw]
# # Statement [1.23]: Albert Einstein decided to remain in the United States in 1933.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:residence "United States" .

# %% [raw]
# {"cell": 48, "stmt_key": "1_23", "chunk_num": 1, "stmt_idx": 23, "type": "rdf", "cid": "23a172b77609b8f73096fde9b15b787114b19661f088f688f07f7403059a3fe4", "from_cid": "81d420f2062e790719ed4d2c6b14b5fc6747a70a808baa89ce8df9d99e112a9c"}

# %% [raw]
# # Statement [1.24]: Albert Einstein was granted American citizenship in 1940.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema: citizenship "American" .

# %% [raw]
# {"cell": 50, "stmt_key": "1_24", "chunk_num": 1, "stmt_idx": 24, "type": "rdf", "cid": "f71d3d84d739b245f1105e828e1c2f2fabd8cddbbc860ea0c7dffd4c54d9b408", "from_cid": "20cdbe7d7f4b31ec70f00be952d6ab4553819258d741c22d7bf28d5750f79a0c"}

# %% [raw]
# # Statement [1.25]: Albert Einstein endorsed a letter to President Franklin D. Roosevelt in 1939.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:work "Endorsed a letter to President Franklin D. Roosevelt" .

# %% [raw]
# {"cell": 52, "stmt_key": "1_25", "chunk_num": 1, "stmt_idx": 25, "type": "rdf", "cid": "67184a582efdba4974b387c3f49564bea6cdb88920b66ecc334a7e5fdebf974c", "from_cid": "f35920481868d3d63a1f593d0c63829d140d3040018dd677100dfd6ead5dc536"}

# %% [raw]
# # Statement [1.26]: President Franklin D. Roosevelt was alerted to the potential German nuclear weapons program by Albert Einstein in 1939.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:work "Alerted President Franklin D. Roosevelt to German nuclear weapons program" .

# %% [raw]
# {"cell": 54, "stmt_key": "1_26", "chunk_num": 1, "stmt_idx": 26, "type": "rdf", "cid": "469fd90cc09648a24a149c5a7676d00d07a9647860fc52cc1153c6bfc34bf0d2", "from_cid": "0215b53dfbaa68c601f564fe80d639e96876b0f66894af459f87759fdd0b5b2d"}

# %% [raw]
# # Statement [1.27]: Albert Einstein recommended that the United States begin nuclear weapons research in 1939.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:work "Recommended nuclear weapons research" .

# %% [raw]
# {"cell": 56, "stmt_key": "1_27", "chunk_num": 1, "stmt_idx": 27, "type": "rdf", "cid": "3600c768edeb41f62e19f0ea122c790ef08054e89a576160d2b8605acc262acc", "from_cid": "a01d7ab277f97391151796f3a4f0eaa77ad31bbbde9b4d3e9144a380bae02dc6"}

# %% [raw]
# # Statement [1.28]: The Manhattan Project was carried out as a result of Albert Einstein's recommendation in 1939.
# <https://en.wikipedia.org/wiki/Albert_Einstein#person_albert_einstein> schema:work "Manhattan Project" .

# %% [raw]
# {"cell": 58, "stmt_key": "1_28", "chunk_num": 1, "stmt_idx": 28, "type": "rdf", "cid": "9d35ac58ce64894d8f6ad277468eaa692ca7b28c619ace27a8ff725bdcc01c00", "from_cid": "68122621b2933b8ff45902945044480235f6f9e24d35d5cc5162c7e12354a8ba"}
